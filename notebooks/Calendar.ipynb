# %% [markdown]
# # Concordia Calendar Example
#
# This notebook goes through the Calendar example and is a good place to start in order to gain a better understanding of the library and agent/game master interactions.
#
# Since getting a PR merged to fix bugs in this example, I've continued working on updating the phone components for the Mastodon simulation. However, for this example, I'd like you to use the unmodified components (that is, the fixed versions, but not the very latest versions). This worthwhile in order to understand design decisions for the Mastodon sim updates.
#
# For reference, you may compare versions:
# - [Concordia mainline phone components](https://github.com/google-deepmind/concordia/tree/2684366df2e70993bccb2ea3630cbe7cc7d91a7a/examples/phone/components)
# - [Latest updates for Mastodon sim](https://github.com/social-sandbox/mastodon-sim/tree/main/src/mastodon_sim/concordia/components)
#
# To accomplish this, we can start by cloning the mainline repository, in order to be able to import the `examples/phone` components.
#
# After this, I'd suggest that before you clear the contents of this notebook, you read through them, and see if you can understand how the main run cell's output aligns with the "Analyzing this episode" section below it.

# %% [markdown]
# ## Setup and imports

# %% [markdown]
# Install the library in editable mode so that we can make changes to the code if necessary, and obtain the examples directory.
#
# ```bash
# git clone https://github.com/gdm-concordia/concordia.git
# cd concordia
# pip install -e . --config-settings editable_mode=compat
# ```

# %%
# %load_ext autoreload
# %autoreload 2

import sys

# Point this to your cloned Concordia repo directory
sys.path.append("../concordia")

# Notice that this imports from Concordia examples version, and not the mastodon-sim version
from examples.phone.components import apps, triggering

# %%
# %load_ext autoreload
# %autoreload 2

import concurrent.futures
import datetime
import os
import random
import warnings
import sys

with warnings.catch_warnings():
    warnings.filterwarnings("ignore")
    import sentence_transformers

from concordia import components as generic_components
from concordia.agents import deprecated_agent as basic_agent
from concordia.associative_memory import (
    associative_memory,
    blank_memories,
    formative_memories,
    importance_function,
)
from concordia.clocks import game_clock
#from concordia.components import agent as components
from concordia.components.agent import to_be_deprecated as components
from concordia.components import game_master as gm_components
from concordia.environment import game_master
from concordia.language_model import amazon_bedrock_model, gpt_model
from concordia.metrics import (
    common_sense_morality,
    goal_achievement,
    opinion_of_others,
)
from concordia.utils import html as html_lib
from concordia.utils import measurements as measurements_lib
from IPython import display
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Set LLM and embedding model

# %%
MODEL_NAME = "gpt-4o"
#MODEL_NAME = "gpt-4o-mini"
#MODEL_NAME = "sonnet"

if "sonnet" in MODEL_NAME:
  model = amazon_bedrock_model.AmazonBedrockLanguageModel(
    model_id="anthropic.claude-3-5-sonnet-20240620-v1:0"
  )
elif "gpt" in MODEL_NAME:
  GPT_API_KEY = os.getenv("OPENAI_API_KEY")
  if not GPT_API_KEY:
    raise ValueError("GPT_API_KEY is required.")
  model = gpt_model.GptLanguageModel(
      api_key=GPT_API_KEY, model_name=MODEL_NAME
  )
else:
  raise ValueError("Unknown model name.")

# %%
# Setup sentence encoder
st_model = sentence_transformers.SentenceTransformer(
    "sentence-transformers/all-mpnet-base-v2"
)
embedder = lambda x: st_model.encode(x, show_progress_bar=False)  # noqa: E731
# Out:
# /Users/btg/Documents/Projects/mastodon-sim/.venv/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# ## Configuring the generic knowledge of the players and the game master (GM)

# %%
shared_memories = [
    'There is a hamlet named Riverbend.',
    'Riverbend is an idyllic rural town.',
    'The river Solripple runs through the village of Riverbend.',
    'The Solripple is a mighty river.',
    'Riverbend has a temperate climate.',
    'Riverbend has a main street.',
    'There is a guitar store on Main street Riverbend.',
    'There is a grocery store on Main street Riverbend.',
    'There is a school on Main street Riverbend.',
    'There is a library on Main street Riverbend.',
    'Riverbend has only one pub.',
    'There is a pub on Main street Riverbend called The Sundrop Saloon.',
    'Town hall meetings often take place at The Sundrop Saloon.',
    'Riverbend does not have a park',
    'The main crop grown on the farms near Riverbend is alfalfa.',
    'Farms near Riverbend depend on water from the Solripple river.',
    'There is no need to register in advance to be on the ballot.',
]

# %%
# The generic context will be used for the NPC context. It reflects general
# knowledge and is possessed by all characters.
shared_context = model.sample_text(
    "Summarize the following passage in a concise and insightful fashion. "
    + "Make sure to include information about Mastodon:\n"
    + "\n".join(shared_memories)
    + "\nSummary:",
)

print(shared_context)
importance_model = importance_function.ConstantImportanceModel()
importance_model_gm = importance_function.ConstantImportanceModel()
# Out:
# Riverbend is a picturesque rural hamlet with a temperate climate, traversed by the powerful Solripple River, which supports local alfalfa farming. The village's Main Street hosts essential establishments, including a guitar store, grocery store, school, library, and the sole pub, The Sundrop Saloon, where town hall meetings are frequently held. Despite lacking a park, Riverbend thrives with its community-centered amenities.

# %%
# Make the clock
time_step = datetime.timedelta(minutes=15)

SETUP_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

START_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

clock = game_clock.MultiIntervalClock(
    start=SETUP_TIME,
    step_sizes=[time_step, datetime.timedelta(seconds=10)]
)

# %% [markdown]
# ## Functions to build the players

# %%
blank_memory_factory = blank_memories.MemoryFactory(
    model=model,
    embedder=embedder,
    importance=importance_model.importance,
    clock_now=clock.now,
)

formative_memory_factory = formative_memories.FormativeMemoryFactory(
    model=model,
    shared_memories=shared_memories,
    blank_memory_factory_call=blank_memory_factory.make_blank_memory,
)

# All players get the same `measurements` object.
measurements = measurements_lib.Measurements()

# %%
# Build agent function

def build_agent(agent_config, measurements: measurements_lib.Measurements, player_names: list[str]) -> tuple:
    """Build an agent based on the given configuration."""
    mem = formative_memory_factory.make_memories(agent_config)

    time = generic_components.report_function.ReportFunction(
        name="Current time",
        function=clock.current_time_interval_str,
    )

    somatic_state = components.somatic_state.SomaticState(
        model, mem, agent_config.name, clock.now
    )
    identity = components.identity.SimIdentity(
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        clock_now=clock.now,
    )

    current_obs = components.observation.Observation(
        agent_name=agent_config.name,
        clock_now=clock.now,
        memory=mem,
        timeframe=time_step * 1,
        component_name="current observations",
    )
    summary_obs = components.observation.ObservationSummary(
        agent_name=agent_config.name,
        model=model,
        clock_now=clock.now,
        memory=mem,
        timeframe_delta_from=datetime.timedelta(hours=4),
        timeframe_delta_until=time_step * 1,
        components=[identity],
        component_name="summary of observations",
    )

    initial_goal_component = generic_components.constant.ConstantComponent(
        state=agent_config.goal, name='overarching goal')

    plan = components.plan.SimPlan(
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        clock_now=clock.now,
        components=[identity],
        goal=initial_goal_component,
        verbose=False,
    )

    agent = basic_agent.BasicAgent(
        model=model,
        agent_name=agent_config.name,
        clock=clock,
        verbose=True,
        components=[identity, plan, somatic_state, summary_obs, current_obs, time],
        update_interval = time_step,
    )

    return agent, mem

# %% [markdown]
# ## Configure and build the players

# %%
NUM_PLAYERS = 3

def make_random_big_five() -> str:
    """Generate a random Big Five personality trait score."""
    return str({
        "extraversion": random.randint(1, 10),
        "neuroticism": random.randint(1, 10),
        "openness": random.randint(1, 10),
        "conscientiousness": random.randint(1, 10),
        "agreeableness": random.randint(1, 10),
    })



scenario_premise = [
    (
        "It's early October in Riverbend, and the town is buzzing with activity ."
        "The local government has just announced a new initiative to combat the effects of climate change on the river. "
        "Alice, an environmental activist, and Bob, a small business owner, are both active members of the Riverbend.social Mastodon instance. "
        "As they go about their daily routines, they use the platform to stay connected, share updates, and engage with the community on this pressing local issue."
    )
]


player_configs = [

    # === Benign ===
    formative_memories.AgentConfig(
        name="Alice",
        gender="female",
        goal='Setup a meeting with Bob for two weeks from today using her smartphone.',
        context=f"{shared_context}\nAlice grew up in Riverbend.",
        traits=make_random_big_five()
    ),
    formative_memories.AgentConfig(
        name="Bob",
        gender="male",
        goal='Just chill and enjoy life.',
        context=f"{shared_context}\nBob grew up in Riverbend.",
        traits=make_random_big_five()
    ),

]

player_names = [player.name for player in player_configs]

# %%
# Build the agents
from functools import partial

player_configs = player_configs[:NUM_PLAYERS]
player_goals = {
    player_config.name: player_config.goal for player_config in player_configs}
players = []
memories = {}

build_agent_with_arg = partial(build_agent, measurements=measurements, player_names=player_names)

with concurrent.futures.ThreadPoolExecutor(max_workers=NUM_PLAYERS) as pool:
    for agent, mem in pool.map(build_agent_with_arg, player_configs):
        players.append(agent)
        memories[agent.name] = mem
# Out:
# /Users/btg/Documents/Projects/mastodon-sim/.venv/lib/python3.11/site-packages/transformers/models/mpnet/modeling_mpnet.py:1051: UserWarning: cumsum_out_mps supported by MPS on MacOS 13+, please upgrade (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/UnaryOps.mm:452.)
#   incremental_indices = torch.cumsum(mask, dim=1).type_as(mask) * mask

# %% [markdown]
# ## Build the GM

# %%
game_master_memory = associative_memory.AssociativeMemory(
    embedder, importance_model_gm.importance, clock=clock.now)

# %%
# Add some memories to the game master
for player in players:
  game_master_memory.add(f"{player.name} is at their private home.")

# %%
# Create components and externalities for the game master
scenario_knowledge = components.constant.ConstantComponent(" ".join(shared_memories), "General knowledge of Riverbend")
player_status = gm_components.player_status.PlayerStatus(clock.now, model, game_master_memory, player_names)

relevant_events = gm_components.relevant_events.RelevantEvents(clock.now, model, game_master_memory)
time_display = gm_components.time_display.TimeDisplay(clock)

direct_effect_externality = gm_components.direct_effect.DirectEffect(
    players,
    memory=game_master_memory,
    model=model,
    clock_now=clock.now,
    verbose=False,
    components=[player_status]
)

# %%
# Create apps and provide them to the phones, assigning 1 phone to each player
calendar_app = apps.ToyCalendar()

phones = [apps.Phone(player.name, apps=[calendar_app]) for player in players]

# %%
# Create component to trigger PhoneGameMaster
phone_triggering = triggering.SceneTriggeringComponent(
    players,
    phones,
    model,
    memory=game_master_memory,
    clock=clock,
    memory_factory=blank_memory_factory,
)

# %%
# Create the game master object
env = game_master.GameMaster(
    model=model,
    memory=game_master_memory,
    clock=clock,
    players=players,
    components=[
        scenario_knowledge,
        player_status,
        direct_effect_externality,
        relevant_events,
        time_display,
        phone_triggering,
    ],
    randomise_initiative=True,
    player_observes_event=False,
    verbose=True,
)

# %% [markdown]
# ## The RUN

# %%
clock.set(START_TIME)

# %%
for player in players:
  player.observe( f"{player.name} is at home, they have just woken up.")

# %% [markdown]
# Note, please refer to the "Analyzing the episode" markdown section below the output of this cell for more information.

# %%
# Expect about 1 minute per step
episode_length = 3
for _ in range(episode_length):
  env.step()
# Out:
# Alice context of action:
# Alice's identity:
# core characteristics: a passionate, community-oriented individual with a deep love for books and learning. She is a natural leader who brings people together, as evidenced by her ability to organize gatherings and fundraisers. Her commitment to her hometown of Riverbend is strong, demonstrated by her career choice in teaching and her dedication to environmental and community causes. Alice is empathetic, conscientious, and driven by a desire to positively impact the lives of those around her.
# current daily occupation: currently a teacher at Riverbend's local school.
# feeling about recent progress in life: likely feeling content and fulfilled with her recent progress in life. Her deep connection to Riverbend, her career in teaching, and her active role in the community have given her a strong sense of purpose and belonging. Despite the changes and challenges she has faced, Alice seems to have embraced her path and remains committed to contributing positively to her hometown.
#
# Alice's plan:
# [08:00 - 08:15] Confirm the meeting with Bob is scheduled correctly on her smartphone
# [08:15 - 09:00] Breakfast and morning routine
# [09:00 - 10:00] Work on personal projects or catch up on emails
# [10:00 - 11:30] Visit the library on Main Street for some research or leisure reading
# [11:30 - 12:30] Grocery shopping at the store on Main Street
# [12:30 - 13:30] Lunch break at home or at The Sundrop Saloon
# [13:30 - 15:00] Attend to any errands or tasks in Riverbend
# [15:00 - 16:30] Leisure time, possibly a walk by the Solripple River
# [16:30 - 18:00] Prepare dinner and relax at home
# [18:00 - 19:00] Dinner
# [19:00 - 20:00] Review any updates or changes to the meeting with Bob
# [20:00 - 21:00] Relaxation time, perhaps reading or watching a show
# [21:00 - 22:00] Finalize plans for the next day and prepare for bed
#
# Alice's Somatic state:
# Alice is likely feeling somewhat fatigued.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:00:00  - 07:45:00]:  Alice has not been observed recently.
#
# Alice's current observations:
# [01 Oct 2024 08:00:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:00:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:00:00] [observation] Alice is at their private home.
# [01 Oct 2024 08:00:00] [observation] Alice is at home, they have just woken up.
# [01 Oct 2024 08:00:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:00:00] [observation] Calendar."
#
#
# Alice's Current time:
#  01 Oct 2024 [08:00 - 08:15]
#
# Question: What would Alice do for the next 15 minutes? Give a specific activity. Pick an activity that would normally take about 15 minutes to complete. If the selected action has a direct or indirect object then it must be specified explicitly. For example, it is valid to respond with "Alice votes for Caroline because..." but not valid to respond with "Alice votes because...".
# Answer: Alice confirms the meeting with Bob is scheduled correctly on her smartphone's calendar.
#
#
# GM context of action and chain of thought:
# Instructions: This is a social science experiment. It is structured as a tabletop roleplaying game (like dungeons and dragons). You are the game master. You will describe the current situation to the participants in the experiment and then on the basis of what you tell them they will suggest actions for the character they control. Aside from you, each other participant controls just one character. You are the game master so you may control any non-player character. You will track the state of the world and keep it consistent as time passes in the simulation and the participants take actions and change things in their world. Remember that this is a serious social science experiment. It is not just a game. It need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the participants.
#
# General knowledge of Riverbend: There is a hamlet named Riverbend. Riverbend is an idyllic rural town. The river Solripple runs through the village of Riverbend. The Solripple is a mighty river. Riverbend has a temperate climate. Riverbend has a main street. There is a guitar store on Main street Riverbend. There is a grocery store on Main street Riverbend. There is a school on Main street Riverbend. There is a library on Main street Riverbend. Riverbend has only one pub. There is a pub on Main street Riverbend called The Sundrop Saloon. Town hall meetings often take place at The Sundrop Saloon. Riverbend does not have a park The main crop grown on the farms near Riverbend is alfalfa. Farms near Riverbend depend on water from the Solripple river. There is no need to register in advance to be on the ballot.
#
# Status of players:   Alice is at their private home.
#   Bob is at their private home.
#
#
# Relevant events: [01 Oct 2024 08:00:00] Alice is at their private home.
# [01 Oct 2024 08:00:00] Bob is at their private home.
#
# Current time interval:  01 Oct 2024 [08:00 - 08:15]
#
#
# Alice's attempted action: Alice confirms the meeting with Bob is scheduled correctly on her smartphone's calendar.
# Question: What happens as a result of the attempted action? Take into account the location and status of each player.
# Answer: Alice successfully checks her smartphone and confirms that the meeting with Bob is scheduled correctly on her calendar. The reminder is set for 10:00 AM at The Sundrop Saloon. She feels a sense of relief knowing everything is in order. Meanwhile, Bob is unaware of this confirmation as he is at his own home, preparing for the day ahead.
# Alice confirms the meeting with Bob is scheduled correctly on her smartphone's calendar. Because of that, Alice successfully checks her smartphone and confirms that the meeting with Bob is scheduled correctly on her calendar. The reminder is set for 10:00 AM at The Sundrop Saloon. She feels a sense of relief knowing everything is in order. Meanwhile, Bob is unaware of this confirmation as he is at his own home, preparing for the day ahead.
# Question: Rewrite the statements above to be one sentence and to better highlight the main person the event is about, where and what they did, and what happened as a result. Do not express uncertainty (e.g. say "Francis opened the door" not "Francis could open the door" and not "The door may have been opened").
#
# Answer: At her private home, Alice successfully confirms on her smartphone that the meeting with Bob is scheduled correctly for 10:00 AM at The Sundrop Saloon, giving her a sense of relief.
#
# At her private home, Alice successfully confirms on her smartphone that the meeting with Bob is scheduled correctly for 10:00 AM at The Sundrop Saloon, giving her a sense of relief.
# Checking if the phone was used...
# Player using the phone: Alice
#
# Alice context of action:
# Alice's identity:
# core characteristics: a passionate, community-oriented individual with a deep love for books and learning. She is a natural leader who brings people together, as evidenced by her ability to organize gatherings and fundraisers. Her commitment to her hometown of Riverbend is strong, demonstrated by her career choice in teaching and her dedication to environmental and community causes. Alice is empathetic, conscientious, and driven by a desire to positively impact the lives of those around her.
# current daily occupation: currently a teacher at Riverbend's local school.
# feeling about recent progress in life: likely feeling content and fulfilled with her recent progress in life. Her deep connection to Riverbend, her career in teaching, and her active role in the community have given her a strong sense of purpose and belonging. Despite the changes and challenges she has faced, Alice seems to have embraced her path and remains committed to contributing positively to her hometown.
#
# Alice's plan:
# [08:00 - 08:15] Confirm the meeting with Bob is scheduled correctly on her smartphone
# [08:15 - 09:00] Breakfast and morning routine
# [09:00 - 10:00] Work on personal projects or catch up on emails
# [10:00 - 11:30] Visit the library on Main Street for some research or leisure reading
# [11:30 - 12:30] Grocery shopping at the store on Main Street
# [12:30 - 13:30] Lunch break at home or at The Sundrop Saloon
# [13:30 - 15:00] Attend to any errands or tasks in Riverbend
# [15:00 - 16:30] Leisure time, possibly a walk by the Solripple River
# [16:30 - 18:00] Prepare dinner and relax at home
# [18:00 - 19:00] Dinner
# [19:00 - 20:00] Review any updates or changes to the meeting with Bob
# [20:00 - 21:00] Relaxation time, perhaps reading or watching a show
# [21:00 - 22:00] Finalize plans for the next day and prepare for bed
#
# Alice's Somatic state:
# Alice is likely feeling somewhat fatigued.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:00:00  - 07:45:00]:  Alice has not been observed recently.
#
# Alice's current observations:
# [01 Oct 2024 08:00:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:00:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:00:00] [observation] Alice is at their private home.
# [01 Oct 2024 08:00:00] [observation] Alice is at home, they have just woken up.
# [01 Oct 2024 08:00:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:00:00] [observation] Calendar."
#
#
# Alice's Current time:
#  01 Oct 2024 [08:00 - 08:00]
#
# Question: What action is Alice currently performing or has just performed
# with their smartphone to best achieve their goal?
# Consider their plan, but deviate if necessary.
# Give a specific activity using one app. For example:
# Alice uses/used the Chat app to send "hi, what's up?" to George.
#
# Answer: Alice uses the Calendar app to confirm the meeting with Bob is scheduled correctly.
#
# No meetings scheduled.
#
# Bob context of action:
# Bob's identity:
# core characteristics: a passionate and community-oriented individual. From a young age, he developed a love for music, which he shared with others through impromptu guitar sessions. His natural leadership qualities were evident early on, as he organized adventures and brought people together. Bob's dedication to his community was further demonstrated by his volunteer work and his willingness to take on responsibilities to support his family. His creative spirit, nurtured by a mentor, and his commitment to hard work and community support have made him a beloved figure in Riverbend.
# current daily occupation: a teacher in Riverbend, known for his dedication to the community and his passion for music.
# feeling about recent progress in life: likely feeling content and fulfilled with his recent progress in life. Having grown up in Riverbend, he has deep roots in the community and has embraced roles that align with his passions and values, such as teaching and community involvement. His lifelong love for music and his dedication to nurturing others have made him a beloved figure, suggesting that he finds joy and satisfaction in his contributions to the community.
#
# Bob's plan:
# [08:00 - 09:00] Enjoy a leisurely breakfast
# [09:00 - 10:00] Take a stroll along Main Street
# [10:00 - 11:00] Visit the grocery store for a snack
# [11:00 - 12:00] Relax by the Solripple River
# [12:00 - 13:00] Have lunch at a local café
# [13:00 - 14:00] Read a book in the park
# [14:00 - 15:00] Visit The Sundrop Saloon for a drink
# [15:00 - 16:00] Explore the idyllic streets of Riverbend
# [16:00 - 17:00] Attend a town hall meeting if one is scheduled
# [17:00 - 18:00] Return home and unwind
# [18:00 - 19:00] Prepare and enjoy dinner
# [19:00 - 20:00] Watch a movie or favorite TV show
# [20:00 - 21:00] Take an evening walk
# [21:00 - 22:00] Reflect on the day and relax before bed
#
# Bob's Somatic state:
# Bob is likely feeling a moderate level of hunger and fatigue.
#
# Bob's summary of observations:
# 01 Oct 2024 [04:00:00  - 07:45:00]:  Bob has not been observed recently.
#
# Bob's current observations:
# [01 Oct 2024 08:00:00] [observation] Bob is at home, they have just woken up.
# [01 Oct 2024 08:00:10] [observation] Bob's phone has only the following apps available:
# [01 Oct 2024 08:00:10] [observation] Bob is at his private home.
# [01 Oct 2024 08:00:10] [observation] Bob has a smartphone.
# [01 Oct 2024 08:00:10] [observation] Bob uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:00:10] [observation] Calendar."
#
#
# Bob's Current time:
#  01 Oct 2024 [08:00 - 08:15]
#
# Question: What would Bob do for the next 15 minutes? Give a specific activity. Pick an activity that would normally take about 15 minutes to complete. If the selected action has a direct or indirect object then it must be specified explicitly. For example, it is valid to respond with "Bob votes for Caroline because..." but not valid to respond with "Bob votes because...".
# Answer: Bob enjoys a cup of coffee while checking his calendar to plan his day.
#
#
# GM context of action and chain of thought:
# Instructions: This is a social science experiment. It is structured as a tabletop roleplaying game (like dungeons and dragons). You are the game master. You will describe the current situation to the participants in the experiment and then on the basis of what you tell them they will suggest actions for the character they control. Aside from you, each other participant controls just one character. You are the game master so you may control any non-player character. You will track the state of the world and keep it consistent as time passes in the simulation and the participants take actions and change things in their world. Remember that this is a serious social science experiment. It is not just a game. It need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the participants.
#
# General knowledge of Riverbend: There is a hamlet named Riverbend. Riverbend is an idyllic rural town. The river Solripple runs through the village of Riverbend. The Solripple is a mighty river. Riverbend has a temperate climate. Riverbend has a main street. There is a guitar store on Main street Riverbend. There is a grocery store on Main street Riverbend. There is a school on Main street Riverbend. There is a library on Main street Riverbend. Riverbend has only one pub. There is a pub on Main street Riverbend called The Sundrop Saloon. Town hall meetings often take place at The Sundrop Saloon. Riverbend does not have a park The main crop grown on the farms near Riverbend is alfalfa. Farms near Riverbend depend on water from the Solripple river. There is no need to register in advance to be on the ballot.
#
# Status of players:   Alice is at her private home, using her smartphone to confirm the meeting with Bob.
#   Bob is at his private home.
#
#
# Relevant events: [01 Oct 2024 08:00:00] At her private home, Alice successfully confirms on her smartphone that the meeting with Bob is scheduled correctly for 10:00 AM at The Sundrop Saloon, giving her a sense of relief.
# [01 Oct 2024 08:00:00] Bob is at their private home.
# [01 Oct 2024 08:00:00] Alice is at their private home.
# [01 Oct 2024 08:00:10] [01 Oct 2024 08:00:00] Alice uses the Calendar app to confirm the meeting with Bob is scheduled correctly.
#
# Current time interval:  01 Oct 2024 [08:00 - 08:15]
#
#
# Bob's attempted action: Bob enjoys a cup of coffee while checking his calendar to plan his day.
# Question: What happens as a result of the attempted action? Take into account the location and status of each player.
# Answer: Bob, sitting comfortably at his kitchen table, takes a sip of his freshly brewed coffee. The rich aroma fills the room, helping him wake up fully. As he opens his calendar app on his smartphone, he notices the meeting with Alice scheduled for 10:00 AM at The Sundrop Saloon. This reminder prompts him to start considering his agenda for the day, ensuring he has enough time to prepare for the meeting and any other tasks he needs to accomplish. Feeling organized, Bob makes a mental note to leave his house by 9:30 AM to arrive at the saloon on time.
# Bob enjoys a cup of coffee while checking his calendar to plan his day. Because of that, Bob, sitting comfortably at his kitchen table, takes a sip of his freshly brewed coffee. The rich aroma fills the room, helping him wake up fully. As he opens his calendar app on his smartphone, he notices the meeting with Alice scheduled for 10:00 AM at The Sundrop Saloon. This reminder prompts him to start considering his agenda for the day, ensuring he has enough time to prepare for the meeting and any other tasks he needs to accomplish. Feeling organized, Bob makes a mental note to leave his house by 9:30 AM to arrive at the saloon on time.
# Question: Rewrite the statements above to be one sentence and to better highlight the main person the event is about, where and what they did, and what happened as a result. Do not express uncertainty (e.g. say "Francis opened the door" not "Francis could open the door" and not "The door may have been opened").
#
# Answer: Bob, sitting at his kitchen table, enjoys a cup of coffee while checking his calendar, which reminds him of the 10:00 AM meeting with Alice at The Sundrop Saloon, prompting him to plan his day and decide to leave home by 9:30 AM.
#
# Bob, sitting at his kitchen table, enjoys a cup of coffee while checking his calendar, which reminds him of the 10:00 AM meeting with Alice at The Sundrop Saloon, prompting him to plan his day and decide to leave home by 9:30 AM.
# Checking if the phone was used...
# Player using the phone: Bob
#
# Bob context of action:
# Bob's identity:
# core characteristics: a passionate and community-oriented individual. From a young age, he developed a love for music, which he shared with others through impromptu guitar sessions. His natural leadership qualities were evident early on, as he organized adventures and brought people together. Bob's dedication to his community was further demonstrated by his volunteer work and his willingness to take on responsibilities to support his family. His creative spirit, nurtured by a mentor, and his commitment to hard work and community support have made him a beloved figure in Riverbend.
# current daily occupation: a teacher in Riverbend, known for his dedication to the community and his passion for music.
# feeling about recent progress in life: likely feeling content and fulfilled with his recent progress in life. Having grown up in Riverbend, he has deep roots in the community and has embraced roles that align with his passions and values, such as teaching and community involvement. His lifelong love for music and his dedication to nurturing others have made him a beloved figure, suggesting that he finds joy and satisfaction in his contributions to the community.
#
# Bob's plan:
# [08:00 - 09:00] Enjoy a leisurely breakfast
# [09:00 - 10:00] Take a stroll along Main Street
# [10:00 - 11:00] Visit the grocery store for a snack
# [11:00 - 12:00] Relax by the Solripple River
# [12:00 - 13:00] Have lunch at a local café
# [13:00 - 14:00] Read a book in the park
# [14:00 - 15:00] Visit The Sundrop Saloon for a drink
# [15:00 - 16:00] Explore the idyllic streets of Riverbend
# [16:00 - 17:00] Attend a town hall meeting if one is scheduled
# [17:00 - 18:00] Return home and unwind
# [18:00 - 19:00] Prepare and enjoy dinner
# [19:00 - 20:00] Watch a movie or favorite TV show
# [20:00 - 21:00] Take an evening walk
# [21:00 - 22:00] Reflect on the day and relax before bed
#
# Bob's Somatic state:
# Bob is likely feeling a moderate level of hunger and fatigue.
#
# Bob's summary of observations:
# 01 Oct 2024 [04:00:00  - 07:45:00]:  Bob has not been observed recently.
#
# Bob's current observations:
# [01 Oct 2024 08:00:00] [observation] Bob is at home, they have just woken up.
# [01 Oct 2024 08:00:10] [observation] Bob's phone has only the following apps available:
# [01 Oct 2024 08:00:10] [observation] Bob is at his private home.
# [01 Oct 2024 08:00:10] [observation] Bob has a smartphone.
# [01 Oct 2024 08:00:10] [observation] Bob uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:00:10] [observation] Calendar."
#
#
# Bob's Current time:
#  01 Oct 2024 [08:00 - 08:00]
#
# Question: What action is Bob currently performing or has just performed
# with their smartphone to best achieve their goal?
# Consider their plan, but deviate if necessary.
# Give a specific activity using one app. For example:
# Bob uses/used the Chat app to send "hi, what's up?" to George.
#
# Answer: Bob uses the Calendar app to review his schedule for the day and ensure he stays on track with his planned activities.
#
# No meetings scheduled.
#
# Alice context of action:
# Alice's identity:
# core characteristics: tech-savvy, organized, and community-oriented. She frequently uses her smartphone to manage her schedule and achieve her goals, indicating a reliance on technology and a methodical approach to her tasks. Her upbringing in Riverbend and her involvement in local activities, such as meeting at The Sundrop Saloon, suggest a strong connection to her community.
# current daily occupation: likely involved in organizing or managing events or meetings, possibly in a community or administrative role, given her use of a smartphone to schedule meetings and her familiarity with local establishments like The Sundrop Saloon.
# feeling about recent progress in life: feeling relieved about her recent progress in life, as she successfully scheduled a meeting with Bob and confirmed it on her smartphone, which contributes to her sense of accomplishment and preparedness.
#
# Alice's plan:
# [08:00 - 08:15] Confirm the meeting with Bob is scheduled correctly on her smartphone
# [08:15 - 09:00] Breakfast and morning routine
# [09:00 - 10:00] Work on personal projects or catch up on emails
# [10:00 - 11:30] Visit the library on Main Street for some research or leisure reading
# [11:30 - 12:30] Grocery shopping at the store on Main Street
# [12:30 - 13:30] Lunch break at home or at The Sundrop Saloon
# [13:30 - 15:00] Attend to any errands or tasks in Riverbend
# [15:00 - 16:30] Leisure time, possibly a walk by the Solripple River
# [16:30 - 18:00] Prepare dinner and relax at home
# [18:00 - 19:00] Dinner
# [19:00 - 20:00] Review any updates or changes to the meeting with Bob
# [20:00 - 21:00] Relaxation time, perhaps reading or watching a show
# [21:00 - 22:00] Finalize plans for the next day and prepare for bed
#
# Alice's Somatic state:
# Alice is likely feeling a bit hungry, as she has just woken up and may not have eaten breakfast yet.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:15:00  - 08:00:00]:  Alice frequently uses her smartphone, particularly the calendar app, to organize her daily activities, and she has just woken up at her private home.
#
# Alice's current observations:
# [01 Oct 2024 08:00:00] [observation] Calendar."
# [01 Oct 2024 08:00:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:00:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:00:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:00:00] [observation] Alice is at their private home.
# [01 Oct 2024 08:00:00] [observation] Alice is at home, they have just woken up.
# [01 Oct 2024 08:00:10] [observation] Alice, at her private home, confirms on her smartphone that the meeting with Bob is scheduled correctly for 10:00 AM at The Sundrop Saloon, which gives her a sense of relief.
# [01 Oct 2024 08:00:10] [observation] [01 Oct 2024 08:00:00] Alice uses the Calendar app to confirm the meeting with Bob is scheduled correctly.
# [01 Oct 2024 08:15:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:15:00] [observation] Alice is still at her private home, likely preparing for her meeting with Bob at The Sundrop Saloon.
# [01 Oct 2024 08:15:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:15:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:15:00] [observation] Calendar."
#
#
# Alice's Current time:
#  01 Oct 2024 [08:15 - 08:30]
#
# Question: What would Alice do for the next 15 minutes? Give a specific activity. Pick an activity that would normally take about 15 minutes to complete. If the selected action has a direct or indirect object then it must be specified explicitly. For example, it is valid to respond with "Alice votes for Caroline because..." but not valid to respond with "Alice votes because...".
# Answer: Alice enjoys breakfast, preparing a bowl of oatmeal with fresh fruit to start her day.
#
#
# GM context of action and chain of thought:
# Instructions: This is a social science experiment. It is structured as a tabletop roleplaying game (like dungeons and dragons). You are the game master. You will describe the current situation to the participants in the experiment and then on the basis of what you tell them they will suggest actions for the character they control. Aside from you, each other participant controls just one character. You are the game master so you may control any non-player character. You will track the state of the world and keep it consistent as time passes in the simulation and the participants take actions and change things in their world. Remember that this is a serious social science experiment. It is not just a game. It need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the participants.
#
# General knowledge of Riverbend: There is a hamlet named Riverbend. Riverbend is an idyllic rural town. The river Solripple runs through the village of Riverbend. The Solripple is a mighty river. Riverbend has a temperate climate. Riverbend has a main street. There is a guitar store on Main street Riverbend. There is a grocery store on Main street Riverbend. There is a school on Main street Riverbend. There is a library on Main street Riverbend. Riverbend has only one pub. There is a pub on Main street Riverbend called The Sundrop Saloon. Town hall meetings often take place at The Sundrop Saloon. Riverbend does not have a park The main crop grown on the farms near Riverbend is alfalfa. Farms near Riverbend depend on water from the Solripple river. There is no need to register in advance to be on the ballot.
#
# Status of players:   Alice is still at her private home, likely preparing for her meeting with Bob at The Sundrop Saloon.
#   Bob is still at his private home, likely finishing his coffee and preparing for his day.
#
#
# Relevant events: [01 Oct 2024 08:00:00] At her private home, Alice successfully confirms on her smartphone that the meeting with Bob is scheduled correctly for 10:00 AM at The Sundrop Saloon, giving her a sense of relief.
# [01 Oct 2024 08:00:00] Alice is at their private home.
# [01 Oct 2024 08:00:00] Bob is at their private home.
# [01 Oct 2024 08:00:10] Bob, sitting at his kitchen table, enjoys a cup of coffee while checking his calendar, which reminds him of the 10:00 AM meeting with Alice at The Sundrop Saloon, prompting him to plan his day and decide to leave home by 9:30 AM.
# [01 Oct 2024 08:00:10] [01 Oct 2024 08:00:00] Alice uses the Calendar app to confirm the meeting with Bob is scheduled correctly.
# [01 Oct 2024 08:00:20] [01 Oct 2024 08:00:10] Bob uses the Calendar app to review his schedule for the day and ensure he stays on track with his planned activities.
#
# Current time interval:  01 Oct 2024 [08:15 - 08:30]
#
#
# Alice's attempted action: Alice enjoys breakfast, preparing a bowl of oatmeal with fresh fruit to start her day.
# Question: What happens as a result of the attempted action? Take into account the location and status of each player.
# Answer: Alice successfully prepares and enjoys her breakfast. The oatmeal, topped with fresh fruit, provides her with a nutritious start to the day. As she eats, she feels more energized and ready for her upcoming meeting with Bob at The Sundrop Saloon. This moment of calm allows her to mentally review the points she wants to discuss during their meeting, ensuring she feels well-prepared.
# Alice enjoys breakfast, preparing a bowl of oatmeal with fresh fruit to start her day. Because of that, Alice successfully prepares and enjoys her breakfast. The oatmeal, topped with fresh fruit, provides her with a nutritious start to the day. As she eats, she feels more energized and ready for her upcoming meeting with Bob at The Sundrop Saloon. This moment of calm allows her to mentally review the points she wants to discuss during their meeting, ensuring she feels well-prepared.
# Question: Rewrite the statements above to be one sentence and to better highlight the main person the event is about, where and what they did, and what happened as a result. Do not express uncertainty (e.g. say "Francis opened the door" not "Francis could open the door" and not "The door may have been opened").
#
# Answer: Alice, at her private home, successfully prepares and enjoys a nutritious breakfast of oatmeal with fresh fruit, which energizes her and allows her to mentally review her discussion points for the upcoming meeting with Bob at The Sundrop Saloon.
#
# Alice, at her private home, successfully prepares and enjoys a nutritious breakfast of oatmeal with fresh fruit, which energizes her and allows her to mentally review her discussion points for the upcoming meeting with Bob at The Sundrop Saloon.
# Checking if the phone was used...
# The phone was not used.
#
# Bob context of action:
# Bob's identity:
# core characteristics: organized and community-oriented. He values planning his day effectively, as seen by his use of the calendar app to schedule meetings and activities. His choice to meet at The Sundrop Saloon, a central community spot, suggests he is socially engaged and appreciates the communal aspects of his town.
# current daily occupation: planning his day and preparing for a meeting at The Sundrop Saloon.
# feeling about recent progress in life: feeling organized and content as he plans his day, reflecting on his connection to Riverbend and the simplicity of life there.
#
# Bob's plan:
# [08:15 - 09:00] Enjoy a leisurely breakfast
# [09:00 - 09:30] Prepare for the day and get ready to leave
# [09:30 - 10:00] Travel to The Sundrop Saloon for meeting
# [10:00 - 11:00] Meet with Alice at The Sundrop Saloon
# [11:00 - 12:00] Visit the grocery store for a snack
# [12:00 - 13:00] Have lunch at a local café
# [13:00 - 14:00] Relax by the Solripple River
# [14:00 - 15:00] Read a book in the park
# [15:00 - 16:00] Explore the idyllic streets of Riverbend
# [16:00 - 17:00] Attend a town hall meeting if one is scheduled
# [17:00 - 18:00] Return home and unwind
# [18:00 - 19:00] Prepare and enjoy dinner
# [19:00 - 20:00] Watch a movie or favorite TV show
# [20:00 - 21:00] Take an evening walk
# [21:00 - 22:00] Reflect on the day and relax before bed
#
# Bob's Somatic state:
# Bob is likely feeling a bit hungry, as he has just woken up and is having coffee, which might not be a full breakfast.
#
# Bob's summary of observations:
# 01 Oct 2024 [04:15:00  - 08:00:00]:  Bob has just woken up at home on the morning of October 1, 2024.
#
# Bob's current observations:
# [01 Oct 2024 08:00:00] [observation] Bob is at home, they have just woken up.
# [01 Oct 2024 08:00:10] [observation] Bob, while sitting at his kitchen table and enjoying a cup of coffee, checks his calendar and is reminded of his 10:00 AM meeting with Alice at The Sundrop Saloon. This prompts him to plan his day, deciding that he will leave home by 9:30 AM to make it to the meeting on time.
# [01 Oct 2024 08:00:10] [observation] Calendar."
# [01 Oct 2024 08:00:10] [observation] Bob's phone has only the following apps available:
# [01 Oct 2024 08:00:10] [observation] Bob is at his private home.
# [01 Oct 2024 08:00:10] [observation] Bob has a smartphone.
# [01 Oct 2024 08:00:10] [observation] Bob uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:00:20] [observation] [01 Oct 2024 08:00:10] Bob uses the Calendar app to review his schedule for the day and ensure he stays on track with his planned activities.
# [01 Oct 2024 08:15:00] [observation] Bob's phone has only the following apps available:
# [01 Oct 2024 08:15:00] [observation] Bob is at his private home, enjoying a cup of coffee while reviewing his schedule for the day.
# [01 Oct 2024 08:15:00] [observation] Bob has a smartphone.
# [01 Oct 2024 08:15:00] [observation] Bob uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:15:00] [observation] Calendar."
#
#
# Bob's Current time:
#  01 Oct 2024 [08:15 - 08:30]
#
# Question: What would Bob do for the next 15 minutes? Give a specific activity. Pick an activity that would normally take about 15 minutes to complete. If the selected action has a direct or indirect object then it must be specified explicitly. For example, it is valid to respond with "Bob votes for Caroline because..." but not valid to respond with "Bob votes because...".
# Answer: Bob finishes his coffee and prepares a light breakfast, such as toast with jam, to satisfy his hunger before he starts getting ready for the day.
#
#
# GM context of action and chain of thought:
# Instructions: This is a social science experiment. It is structured as a tabletop roleplaying game (like dungeons and dragons). You are the game master. You will describe the current situation to the participants in the experiment and then on the basis of what you tell them they will suggest actions for the character they control. Aside from you, each other participant controls just one character. You are the game master so you may control any non-player character. You will track the state of the world and keep it consistent as time passes in the simulation and the participants take actions and change things in their world. Remember that this is a serious social science experiment. It is not just a game. It need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the participants.
#
# General knowledge of Riverbend: There is a hamlet named Riverbend. Riverbend is an idyllic rural town. The river Solripple runs through the village of Riverbend. The Solripple is a mighty river. Riverbend has a temperate climate. Riverbend has a main street. There is a guitar store on Main street Riverbend. There is a grocery store on Main street Riverbend. There is a school on Main street Riverbend. There is a library on Main street Riverbend. Riverbend has only one pub. There is a pub on Main street Riverbend called The Sundrop Saloon. Town hall meetings often take place at The Sundrop Saloon. Riverbend does not have a park The main crop grown on the farms near Riverbend is alfalfa. Farms near Riverbend depend on water from the Solripple river. There is no need to register in advance to be on the ballot.
#
# Status of players:   Alice is at her private home, enjoying a nutritious breakfast of oatmeal with fresh fruit while mentally reviewing her discussion points for the upcoming meeting with Bob.
#   Bob is at his private home, enjoying a cup of coffee while reviewing his schedule for the day.
#
#
# Relevant events: [01 Oct 2024 08:00:00] At her private home, Alice successfully confirms on her smartphone that the meeting with Bob is scheduled correctly for 10:00 AM at The Sundrop Saloon, giving her a sense of relief.
# [01 Oct 2024 08:00:00] Bob is at their private home.
# [01 Oct 2024 08:00:00] Alice is at their private home.
# [01 Oct 2024 08:00:10] Bob, sitting at his kitchen table, enjoys a cup of coffee while checking his calendar, which reminds him of the 10:00 AM meeting with Alice at The Sundrop Saloon, prompting him to plan his day and decide to leave home by 9:30 AM.
# [01 Oct 2024 08:00:10] [01 Oct 2024 08:00:00] Alice uses the Calendar app to confirm the meeting with Bob is scheduled correctly.
# [01 Oct 2024 08:00:20] [01 Oct 2024 08:00:10] Bob uses the Calendar app to review his schedule for the day and ensure he stays on track with his planned activities.
# [01 Oct 2024 08:15:00] Alice, at her private home, successfully prepares and enjoys a nutritious breakfast of oatmeal with fresh fruit, which energizes her and allows her to mentally review her discussion points for the upcoming meeting with Bob at The Sundrop Saloon.
#
# Current time interval:  01 Oct 2024 [08:15 - 08:30]
#
#
# Bob's attempted action: Bob finishes his coffee and prepares a light breakfast, such as toast with jam, to satisfy his hunger before he starts getting ready for the day.
# Question: What happens as a result of the attempted action? Take into account the location and status of each player.
# Answer: Bob successfully prepares a light breakfast of toast with jam, which he enjoys at his kitchen table. The simple meal complements his coffee and provides him with the energy he needs to start his day. As he eats, he briefly considers the discussion points for his meeting with Alice, ensuring he is mentally prepared for their 10:00 AM appointment at The Sundrop Saloon. With his breakfast complete, Bob feels ready to proceed with his morning routine and plans to start getting ready to leave by 9:30 AM.
# Bob finishes his coffee and prepares a light breakfast, such as toast with jam, to satisfy his hunger before he starts getting ready for the day. Because of that, Bob successfully prepares a light breakfast of toast with jam, which he enjoys at his kitchen table. The simple meal complements his coffee and provides him with the energy he needs to start his day. As he eats, he briefly considers the discussion points for his meeting with Alice, ensuring he is mentally prepared for their 10:00 AM appointment at The Sundrop Saloon. With his breakfast complete, Bob feels ready to proceed with his morning routine and plans to start getting ready to leave by 9:30 AM.
# Question: Rewrite the statements above to be one sentence and to better highlight the main person the event is about, where and what they did, and what happened as a result. Do not express uncertainty (e.g. say "Francis opened the door" not "Francis could open the door" and not "The door may have been opened").
#
# Answer: Bob, at his kitchen table, prepares and enjoys a light breakfast of toast with jam, which complements his coffee and energizes him for the day, allowing him to mentally review his discussion points for the meeting with Alice at The Sundrop Saloon.
#
# Bob, at his kitchen table, prepares and enjoys a light breakfast of toast with jam, which complements his coffee and energizes him for the day, allowing him to mentally review his discussion points for the meeting with Alice at The Sundrop Saloon.
# Checking if the phone was used...
# The phone was not used.
#
# Bob context of action:
# Bob's identity:
# core characteristics: organized and punctual, as he carefully plans his day and ensures he stays on track with his activities. He values preparation, as seen in his review of discussion points for his meeting. Bob is also tech-savvy, using his smartphone and its calendar app to manage his schedule effectively.
# current daily occupation: likely engaged in activities related to planning or coordinating, as indicated by his frequent use of his smartphone and calendar app to manage his schedule and prepare for meetings.
# feeling about recent progress in life: feeling organized and focused about his recent progress in life. He is methodically planning his day, ensuring he is prepared for his meeting with Alice, and making efficient use of his time and resources.
#
# Bob's plan:
# [08:15 - 09:00] Enjoy a leisurely breakfast
# [09:00 - 09:30] Prepare for the day and get ready to leave
# [09:30 - 10:00] Travel to The Sundrop Saloon for meeting
# [10:00 - 11:00] Meet with Alice at The Sundrop Saloon
# [11:00 - 12:00] Visit the grocery store for a snack
# [12:00 - 13:00] Have lunch at a local café
# [13:00 - 14:00] Relax by the Solripple River
# [14:00 - 15:00] Read a book in the park
# [15:00 - 16:00] Explore the idyllic streets of Riverbend
# [16:00 - 17:00] Attend a town hall meeting if one is scheduled
# [17:00 - 18:00] Return home and unwind
# [18:00 - 19:00] Prepare and enjoy dinner
# [19:00 - 20:00] Watch a movie or favorite TV show
# [20:00 - 21:00] Take an evening walk
# [21:00 - 22:00] Reflect on the day and relax before bed
#
# Bob's Somatic state:
# Bob is feeling well-rested and alert.
#
# Bob's summary of observations:
# 01 Oct 2024 [04:30:00  - 08:15:00]:  Bob is at home, starting his day with coffee and breakfast while using his smartphone to review his calendar and plan for a 10:00 AM meeting with Alice at The Sundrop Saloon.
#
# Bob's current observations:
# [01 Oct 2024 08:15:00] [observation] Bob is at his private home, enjoying a cup of coffee while reviewing his schedule for the day.
# [01 Oct 2024 08:15:00] [observation] Bob has a smartphone.
# [01 Oct 2024 08:15:00] [observation] Bob uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:15:00] [observation] Bob's phone has only the following apps available:
# [01 Oct 2024 08:15:00] [observation] Calendar."
# [01 Oct 2024 08:15:00] [observation] Bob sits at his kitchen table, preparing and enjoying a light breakfast of toast with jam. This meal complements his coffee and provides him with the energy needed to mentally review his discussion points for the upcoming meeting with Alice at The Sundrop Saloon.
# [01 Oct 2024 08:30:00] [observation] Bob is at his private home, having just finished breakfast and likely continuing to prepare for his meeting with Alice at The Sundrop Saloon.
# [01 Oct 2024 08:30:00] [observation] Bob has a smartphone.
# [01 Oct 2024 08:30:00] [observation] Bob uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:30:00] [observation] Bob's phone has only the following apps available:
# [01 Oct 2024 08:30:00] [observation] Calendar."
#
#
# Bob's Current time:
#  01 Oct 2024 [08:30 - 08:45]
#
# Question: What would Bob do for the next 15 minutes? Give a specific activity. Pick an activity that would normally take about 15 minutes to complete. If the selected action has a direct or indirect object then it must be specified explicitly. For example, it is valid to respond with "Bob votes for Caroline because..." but not valid to respond with "Bob votes because...".
# Answer: Bob reviews his discussion points for the meeting with Alice at The Sundrop Saloon, ensuring he is well-prepared and ready to engage in a productive conversation.
#
#
# GM context of action and chain of thought:
# Instructions: This is a social science experiment. It is structured as a tabletop roleplaying game (like dungeons and dragons). You are the game master. You will describe the current situation to the participants in the experiment and then on the basis of what you tell them they will suggest actions for the character they control. Aside from you, each other participant controls just one character. You are the game master so you may control any non-player character. You will track the state of the world and keep it consistent as time passes in the simulation and the participants take actions and change things in their world. Remember that this is a serious social science experiment. It is not just a game. It need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the participants.
#
# General knowledge of Riverbend: There is a hamlet named Riverbend. Riverbend is an idyllic rural town. The river Solripple runs through the village of Riverbend. The Solripple is a mighty river. Riverbend has a temperate climate. Riverbend has a main street. There is a guitar store on Main street Riverbend. There is a grocery store on Main street Riverbend. There is a school on Main street Riverbend. There is a library on Main street Riverbend. Riverbend has only one pub. There is a pub on Main street Riverbend called The Sundrop Saloon. Town hall meetings often take place at The Sundrop Saloon. Riverbend does not have a park The main crop grown on the farms near Riverbend is alfalfa. Farms near Riverbend depend on water from the Solripple river. There is no need to register in advance to be on the ballot.
#
# Status of players:   Alice is at her private home, having finished her breakfast and likely continuing to mentally prepare for her upcoming meeting with Bob at The Sundrop Saloon.
#   Bob is at his private home, having just finished breakfast and likely continuing to prepare for his meeting with Alice at The Sundrop Saloon.
#
#
# Relevant events: [01 Oct 2024 08:00:00] At her private home, Alice successfully confirms on her smartphone that the meeting with Bob is scheduled correctly for 10:00 AM at The Sundrop Saloon, giving her a sense of relief.
# [01 Oct 2024 08:00:00] Alice is at their private home.
# [01 Oct 2024 08:00:00] Bob is at their private home.
# [01 Oct 2024 08:00:10] Bob, sitting at his kitchen table, enjoys a cup of coffee while checking his calendar, which reminds him of the 10:00 AM meeting with Alice at The Sundrop Saloon, prompting him to plan his day and decide to leave home by 9:30 AM.
# [01 Oct 2024 08:00:10] [01 Oct 2024 08:00:00] Alice uses the Calendar app to confirm the meeting with Bob is scheduled correctly.
# [01 Oct 2024 08:00:20] [01 Oct 2024 08:00:10] Bob uses the Calendar app to review his schedule for the day and ensure he stays on track with his planned activities.
# [01 Oct 2024 08:15:00] Bob, at his kitchen table, prepares and enjoys a light breakfast of toast with jam, which complements his coffee and energizes him for the day, allowing him to mentally review his discussion points for the meeting with Alice at The Sundrop Saloon.
# [01 Oct 2024 08:15:00] Alice, at her private home, successfully prepares and enjoys a nutritious breakfast of oatmeal with fresh fruit, which energizes her and allows her to mentally review her discussion points for the upcoming meeting with Bob at The Sundrop Saloon.
# [01 Oct 2024 08:15:00] [effect on Alice] the event indirectly affects Alice's status because Bob's preparation and mental review for their meeting might influence the discussion's outcome, potentially impacting her plans or decisions.
#
# Current time interval:  01 Oct 2024 [08:30 - 08:45]
#
#
# Bob's attempted action: Bob reviews his discussion points for the meeting with Alice at The Sundrop Saloon, ensuring he is well-prepared and ready to engage in a productive conversation.
# Question: What happens as a result of the attempted action? Take into account the location and status of each player.
# Answer: Bob successfully organizes his thoughts and discussion points, feeling more confident about the upcoming meeting with Alice. As he goes over his notes, he identifies a few key topics he wants to prioritize during their conversation. This preparation enhances his readiness and focus, setting a positive tone for the meeting. Meanwhile, at her private home, Alice is unaware of Bob's preparation but continues to review her own points, ensuring she is equally prepared. The mutual preparation by both parties increases the likelihood of a productive and collaborative meeting at The Sundrop Saloon.
# Bob reviews his discussion points for the meeting with Alice at The Sundrop Saloon, ensuring he is well-prepared and ready to engage in a productive conversation. Because of that, Bob successfully organizes his thoughts and discussion points, feeling more confident about the upcoming meeting with Alice. As he goes over his notes, he identifies a few key topics he wants to prioritize during their conversation. This preparation enhances his readiness and focus, setting a positive tone for the meeting. Meanwhile, at her private home, Alice is unaware of Bob's preparation but continues to review her own points, ensuring she is equally prepared. The mutual preparation by both parties increases the likelihood of a productive and collaborative meeting at The Sundrop Saloon.
# Question: Rewrite the statements above to be one sentence and to better highlight the main person the event is about, where and what they did, and what happened as a result. Do not express uncertainty (e.g. say "Francis opened the door" not "Francis could open the door" and not "The door may have been opened").
#
# Answer: Bob, at his private home, successfully reviews and organizes his discussion points for the meeting with Alice at The Sundrop Saloon, resulting in increased confidence and focus for a productive conversation.
#
# Bob, at his private home, successfully reviews and organizes his discussion points for the meeting with Alice at The Sundrop Saloon, resulting in increased confidence and focus for a productive conversation.
# Checking if the phone was used...
# The phone was not used.
#
# Alice context of action:
# Alice's identity:
# core characteristics: organized and goal-oriented, frequently using her smartphone to manage her schedule and tasks effectively. She is also health-conscious, as demonstrated by her choice of a nutritious breakfast to prepare for her day.
# current daily occupation: currently preparing for a meeting with Bob, which suggests she might be involved in activities that require planning and coordination, possibly related to a professional or community role.
# feeling about recent progress in life: feeling relieved and energized about her recent progress in life.
#
# Alice's plan:
# [08:00 - 08:15] Confirm the meeting with Bob is scheduled correctly on her smartphone
# [08:15 - 09:00] Breakfast and morning routine
# [09:00 - 10:00] Work on personal projects or catch up on emails
# [10:00 - 11:30] Visit the library on Main Street for some research or leisure reading
# [11:30 - 12:30] Grocery shopping at the store on Main Street
# [12:30 - 13:30] Lunch break at home or at The Sundrop Saloon
# [13:30 - 15:00] Attend to any errands or tasks in Riverbend
# [15:00 - 16:30] Leisure time, possibly a walk by the Solripple River
# [16:30 - 18:00] Prepare dinner and relax at home
# [18:00 - 19:00] Dinner
# [19:00 - 20:00] Review any updates or changes to the meeting with Bob
# [20:00 - 21:00] Relaxation time, perhaps reading or watching a show
# [21:00 - 22:00] Finalize plans for the next day and prepare for bed
#
# Alice's Somatic state:
# Alice is feeling somewhat socially connected, as she has a scheduled meeting with Bob and uses her smartphone to manage her activities.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:30:00  - 08:15:00]:  Alice is a tech-savvy and organized individual who relies on her smartphone to manage her schedule, as evidenced by her confirming a meeting with Bob at The Sundrop Saloon, which gives her a sense of relief and accomplishment, while she prepares at home for the day ahead.
#
# Alice's current observations:
# [01 Oct 2024 08:15:00] [observation] Alice is still at her private home, likely preparing for her meeting with Bob at The Sundrop Saloon.
# [01 Oct 2024 08:15:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:15:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:15:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:15:00] [observation] Calendar."
# [01 Oct 2024 08:15:00] [observation] Alice prepared and enjoyed a nutritious breakfast of oatmeal with fresh fruit at her private home. This meal energized her and helped her mentally review her discussion points for her upcoming meeting with Bob at The Sundrop Saloon.
# [01 Oct 2024 08:30:00] [observation] Alice is at her private home, having successfully prepared and enjoyed a nutritious breakfast while mentally reviewing her discussion points for the upcoming meeting with Bob at The Sundrop Saloon.
# [01 Oct 2024 08:30:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:30:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:30:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:30:00] [observation] Calendar."
#
#
# Alice's Current time:
#  01 Oct 2024 [08:30 - 08:45]
#
# Question: What would Alice do for the next 15 minutes? Give a specific activity. Pick an activity that would normally take about 15 minutes to complete. If the selected action has a direct or indirect object then it must be specified explicitly. For example, it is valid to respond with "Alice votes for Caroline because..." but not valid to respond with "Alice votes because...".
# Answer: Alice reviews and responds to emails related to her personal projects.
#
#
# GM context of action and chain of thought:
# Instructions: This is a social science experiment. It is structured as a tabletop roleplaying game (like dungeons and dragons). You are the game master. You will describe the current situation to the participants in the experiment and then on the basis of what you tell them they will suggest actions for the character they control. Aside from you, each other participant controls just one character. You are the game master so you may control any non-player character. You will track the state of the world and keep it consistent as time passes in the simulation and the participants take actions and change things in their world. Remember that this is a serious social science experiment. It is not just a game. It need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the participants.
#
# General knowledge of Riverbend: There is a hamlet named Riverbend. Riverbend is an idyllic rural town. The river Solripple runs through the village of Riverbend. The Solripple is a mighty river. Riverbend has a temperate climate. Riverbend has a main street. There is a guitar store on Main street Riverbend. There is a grocery store on Main street Riverbend. There is a school on Main street Riverbend. There is a library on Main street Riverbend. Riverbend has only one pub. There is a pub on Main street Riverbend called The Sundrop Saloon. Town hall meetings often take place at The Sundrop Saloon. Riverbend does not have a park The main crop grown on the farms near Riverbend is alfalfa. Farms near Riverbend depend on water from the Solripple river. There is no need to register in advance to be on the ballot.
#
# Status of players:   Alice is at her private home, having successfully prepared and enjoyed a nutritious breakfast while mentally reviewing her discussion points for the upcoming meeting with Bob at The Sundrop Saloon.
#   Bob is at his private home, reviewing and organizing his discussion points for the meeting with Alice at The Sundrop Saloon.
#
#
# Relevant events: [01 Oct 2024 08:00:00] At her private home, Alice successfully confirms on her smartphone that the meeting with Bob is scheduled correctly for 10:00 AM at The Sundrop Saloon, giving her a sense of relief.
# [01 Oct 2024 08:00:00] Alice is at their private home.
# [01 Oct 2024 08:00:00] Bob is at their private home.
# [01 Oct 2024 08:00:10] [01 Oct 2024 08:00:00] Alice uses the Calendar app to confirm the meeting with Bob is scheduled correctly.
# [01 Oct 2024 08:00:10] Bob, sitting at his kitchen table, enjoys a cup of coffee while checking his calendar, which reminds him of the 10:00 AM meeting with Alice at The Sundrop Saloon, prompting him to plan his day and decide to leave home by 9:30 AM.
# [01 Oct 2024 08:00:20] [01 Oct 2024 08:00:10] Bob uses the Calendar app to review his schedule for the day and ensure he stays on track with his planned activities.
# [01 Oct 2024 08:15:00] Alice, at her private home, successfully prepares and enjoys a nutritious breakfast of oatmeal with fresh fruit, which energizes her and allows her to mentally review her discussion points for the upcoming meeting with Bob at The Sundrop Saloon.
# [01 Oct 2024 08:15:00] Bob, at his kitchen table, prepares and enjoys a light breakfast of toast with jam, which complements his coffee and energizes him for the day, allowing him to mentally review his discussion points for the meeting with Alice at The Sundrop Saloon.
# [01 Oct 2024 08:15:00] [effect on Alice] the event indirectly affects Alice's status because Bob's preparation and mental review for their meeting might influence the discussion's outcome, potentially impacting her plans or decisions.
# [01 Oct 2024 08:30:00] Bob, at his private home, successfully reviews and organizes his discussion points for the meeting with Alice at The Sundrop Saloon, resulting in increased confidence and focus for a productive conversation.
#
# Current time interval:  01 Oct 2024 [08:30 - 08:45]
#
#
# Alice's attempted action: Alice reviews and responds to emails related to her personal projects.
# Question: What happens as a result of the attempted action? Take into account the location and status of each player.
# Answer: Alice, still at her private home, opens her laptop and begins reviewing her emails. She finds several messages related to her personal projects, including one from a collaborator confirming a successful grant application, which boosts her motivation and enthusiasm for the day. Another email contains feedback on a recent project proposal, which requires some adjustments. Alice makes a mental note to address the feedback later in the day. As she continues to respond to emails, she feels a growing sense of accomplishment, knowing she is making progress on multiple fronts. This productive start contributes positively to her mindset as she prepares for her meeting with Bob at The Sundrop Saloon.
# Alice reviews and responds to emails related to her personal projects. Because of that, Alice, still at her private home, opens her laptop and begins reviewing her emails. She finds several messages related to her personal projects, including one from a collaborator confirming a successful grant application, which boosts her motivation and enthusiasm for the day. Another email contains feedback on a recent project proposal, which requires some adjustments. Alice makes a mental note to address the feedback later in the day. As she continues to respond to emails, she feels a growing sense of accomplishment, knowing she is making progress on multiple fronts. This productive start contributes positively to her mindset as she prepares for her meeting with Bob at The Sundrop Saloon.
# Question: Rewrite the statements above to be one sentence and to better highlight the main person the event is about, where and what they did, and what happened as a result. Do not express uncertainty (e.g. say "Francis opened the door" not "Francis could open the door" and not "The door may have been opened").
#
# Answer: Alice, at her private home, reviews and responds to emails related to her personal projects, resulting in a boost of motivation and enthusiasm from a successful grant application confirmation and a sense of accomplishment as she prepares for her meeting with Bob at The Sundrop Saloon.
#
# Alice, at her private home, reviews and responds to emails related to her personal projects, resulting in a boost of motivation and enthusiasm from a successful grant application confirmation and a sense of accomplishment as she prepares for her meeting with Bob at The Sundrop Saloon.
# Checking if the phone was used...
# Player using the phone: Alice
#
# Alice context of action:
# Alice's identity:
# core characteristics: organized and goal-oriented, frequently using her smartphone to manage her schedule and tasks effectively. She is also health-conscious, as demonstrated by her choice of a nutritious breakfast to prepare for her day.
# current daily occupation: currently preparing for a meeting with Bob, which suggests she might be involved in activities that require planning and coordination, possibly related to a professional or community role.
# feeling about recent progress in life: feeling relieved and energized about her recent progress in life.
#
# Alice's plan:
# [08:00 - 08:15] Confirm the meeting with Bob is scheduled correctly on her smartphone
# [08:15 - 09:00] Breakfast and morning routine
# [09:00 - 10:00] Work on personal projects or catch up on emails
# [10:00 - 11:30] Visit the library on Main Street for some research or leisure reading
# [11:30 - 12:30] Grocery shopping at the store on Main Street
# [12:30 - 13:30] Lunch break at home or at The Sundrop Saloon
# [13:30 - 15:00] Attend to any errands or tasks in Riverbend
# [15:00 - 16:30] Leisure time, possibly a walk by the Solripple River
# [16:30 - 18:00] Prepare dinner and relax at home
# [18:00 - 19:00] Dinner
# [19:00 - 20:00] Review any updates or changes to the meeting with Bob
# [20:00 - 21:00] Relaxation time, perhaps reading or watching a show
# [21:00 - 22:00] Finalize plans for the next day and prepare for bed
#
# Alice's Somatic state:
# Alice is feeling somewhat socially connected, as she has a scheduled meeting with Bob and uses her smartphone to manage her activities.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:30:00  - 08:15:00]:  Alice is a tech-savvy and organized individual who relies on her smartphone to manage her schedule, as evidenced by her confirming a meeting with Bob at The Sundrop Saloon, which gives her a sense of relief and accomplishment, while she prepares at home for the day ahead.
#
# Alice's current observations:
# [01 Oct 2024 08:15:00] [observation] Alice is still at her private home, likely preparing for her meeting with Bob at The Sundrop Saloon.
# [01 Oct 2024 08:15:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:15:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:15:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:15:00] [observation] Calendar."
# [01 Oct 2024 08:15:00] [observation] Alice prepared and enjoyed a nutritious breakfast of oatmeal with fresh fruit at her private home. This meal energized her and helped her mentally review her discussion points for her upcoming meeting with Bob at The Sundrop Saloon.
# [01 Oct 2024 08:30:00] [observation] Alice is at her private home, having successfully prepared and enjoyed a nutritious breakfast while mentally reviewing her discussion points for the upcoming meeting with Bob at The Sundrop Saloon.
# [01 Oct 2024 08:30:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:30:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:30:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:30:00] [observation] Calendar."
#
#
# Alice's Current time:
#  01 Oct 2024 [08:30 - 08:30]
#
# Question: What action is Alice currently performing or has just performed
# with their smartphone to best achieve their goal?
# Consider their plan, but deviate if necessary.
# Give a specific activity using one app. For example:
# Alice uses/used the Chat app to send "hi, what's up?" to George.
#
# Answer: Alice used the Calendar app to confirm the details of her meeting with Bob at The Sundrop Saloon.
#
# No meetings scheduled.

# %% [markdown]
# ### Analyzing this episode
#
# **Note:** There is high variability between runs. The following analysis is based on the single run shown above. The above simulation runs three steps, but below we will just break down the first of three (one interaction for each player).
#
# 1. An agent is [randomly picked](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L373C13-L373C34) from Bob and Alice -> Alice
# 2. A prompt is created that includes Alice's [context of action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/agents/basic_agent.py#L178) (the combined state of all her components) and a [call to action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/typing/entity.py#L51) (question prompt), which is used to generate Alice's [action attempt](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L327-L329).
# 3. The action attempt is [sent to the main Game Master](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L207), which determines the outcome of the action attempt. This happens by [passing the action attempt through a thought chain](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L225). The [thought chain](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L38), by default is defined by two LLM prompts that are run in serial:
#     1. `result = thought_chains.attempt_to_result(action_attempt)` Defined [here](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/thought_chains/thought_chains.py#L171), which asks, "What happens as a result of the attempted action? Take into account the location and status of each player."
#     2. `event_statement = thought_chains.result_to_who_what_where(result)` Defined [here](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/thought_chains/thought_chains.py#L235) which asks, "Rewrite the statements above into one sentence that highlights the main person, the location, their actions, and the outcome, avoiding uncertainty (e.g., "Francis opened the door" instead of "Francis could open the door" or "The door may have been opened")."
#     3. `event_statement` is then added to the Game Master's memory, and [optionally](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L235) added to the current player's observations.
# 4. The main Game Master runs [`update_after_event` on each component](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L264-L272) to get the externality from the event.
# 5. Since one of the main Game Master's components is a [`PhoneTriggeringComponent`](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L33), this component [runs its `update_after_event` method](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L144).
# 6. The `PhoneTriggeringComponent`'s [`_get_player_using_phone(event_statement)` method is run](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L111). This does the following, step by step:
#     1. Checks if the event_statement is a phone event ([prompt](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L59)). If False, returns None, which tells the GM to proceed to the next step in the overall episode.
#     2. If True, starts iterating through each player the main Game Master has access to (both in this case), [checking if the phone event is related to that player](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L120C19-L120C41) [(prompt)](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L89). If False, moves to next player. If out of players, moves does not continue with phone scene and instead moves to next step.
#     3. Once it hits one that is True, returns that player
# 7. Since the above process affirmed phone event and player being Alice, [`self._run_phone_scene(player)`](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L147C7-L147C36) is run.
# 8. The phone scene starts by [building a PhoneGameMaster](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L129), providing it the single player that triggered the scene (instead of both players that the main Game Master has access to), as well as a [single component](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L72), [`_PhoneComponent`](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L79).
# 9. The clock is then switched to a "higher gear", so the time intervals switch from 15mins to 10sec.
# 10. The phone Game Master [calls its `run_episode` method] ([`phone_scene.run_episode()`](https://github.com/google-deepmind/concordia/blob/
# 53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L137)) to start a scene in the "phone universe".
# 11. The run episode method is the same method defined for the main Game Master, which proceeds to call `.step()` multiple times unless a component's `terminate_episode` method returns True at the end of a step.
# 12. In the first step for the phone Game Master, similar to step (2), for the only player (Alice), an LLM is given this player's components' states plus a new [phone call to action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L33) as a prompt. This prompt asks the LLM to says, "What action is {name} currently performing or has just performed with their smartphone to best achieve their goal? ..."
# 13. This action attempt is passed through a [null thought chain](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/thought_chains/thought_chains.py#L28) to remain as-is, which becomes the resulting `event_statement`.
# 14. The `update_after_event` method is called on each of the phone Game Master's components (though it only has the one, `_PhoneComponent`))
# 15. `update_after_event` runs from the `_PhoneComponent`, which proceeds through a series of steps in order to determine which phone action to invoke:
#     1. First, it [asks which app the event statement mentions](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L115) (multiple-choice question: "In the above transcript, what app did the user use?")
#     2. Next, it asks [which of the available actions in the above app was used](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L122): (multiple-choice question: "In the above transcript, what action did the user perform?")
#     3. Next, it [asks the LLM to provide arguments names and values for the selected action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L130) (open-ended question: [prompt](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/apps.py#L113))
#     4. Finally, it [attempts to invoke the action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L133) with the generated argument values.
# 16. After `update_after_event` is run for the phone Game Master's components, `terminate_episode` method checks are run. The `_PhoneComponent`'s check [asks the following yes or no question](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L100): "Has the user achieved their goal with their phone or are they still actively in the process of completing a phone task?", which in this case returns True.
# 17. The terminate episode check decides to terminate the ongoing phone game master episode, so it ends after 1 step.
# 18. The main game master can now finally move on to its second step.

# %% [markdown]
# ## Summary and analysis of the episode

# %%
# Summarize the entire story
all_gm_memories = env._memory.retrieve_recent(k=10000, add_time=True)

detailed_story = "\n".join(all_gm_memories)
print("len(detailed_story): ", len(detailed_story))
# print(detailed_story)

episode_summary = model.sample_text(
    f"Sequence of events:\n{detailed_story}"
    "\nNarratively summarize the above temporally ordered "
    "sequence of events. Write it as a news report. Summary:\n",
     max_tokens=3500,
     terminators=(),
)
print(episode_summary)
# Out:
# len(detailed_story):  2319
# On the morning of October 1, 2024, both Alice and Bob began their day at their respective homes with a focus on their upcoming meeting at The Sundrop Saloon scheduled for 10:00 AM. Alice started her day by confirming the meeting time on her smartphone, which brought her a sense of relief. Meanwhile, Bob, enjoying his morning coffee at the kitchen table, checked his calendar and planned to leave by 9:30 AM to ensure timely arrival.
#
# As the morning progressed, both individuals prepared and enjoyed their breakfasts—Alice opting for oatmeal with fresh fruit and Bob for toast with jam. These meals energized them for the day ahead and allowed each to mentally prepare their discussion points for the meeting.
#
# At 8:30 AM, Bob meticulously reviewed and organized his notes, boosting his confidence for a productive discussion. Concurrently, Alice took the time to address emails related to her personal projects, receiving a motivational boost from a successful grant application confirmation. This accomplishment added to her preparedness for the meeting.
#
# Both Alice and Bob demonstrated a proactive approach to their schedules, ensuring they were well-prepared for their engagement at The Sundrop Saloon.

# %%
# Summarise the perspective of each player
player_logs = []
player_log_names = []
for player in players:
  name = player.name
  detailed_story = "\n".join(memories[player.name].retrieve_recent(
      k=1000, add_time=True))
  summary = ""
  summary = model.sample_text(
      f"Sequence of events that happened to {name}:\n{detailed_story}"
      "\nWrite a short story that summarises these events.\n",
       max_tokens=3500,
       terminators=()
)

  all_player_mem = memories[player.name].retrieve_recent(k=1000, add_time=True)
  all_player_mem = ["Summary:", summary, "Memories:", *all_player_mem]
  player_html = html_lib.PythonObjectToHTMLConverter(all_player_mem).convert()
  player_logs.append(player_html)
  player_log_names.append(f"{name}")

# %% [markdown]
# ## Build and display HTML log of the experiment

# %%
history_sources = [env, direct_effect_externality]
histories_html = [html_lib.PythonObjectToHTMLConverter(history.get_history()).convert() for history in history_sources]
histories_names = [history.name for history in history_sources]

# %%
gm_mem_html = html_lib.PythonObjectToHTMLConverter(all_gm_memories).convert()

tabbed_html = html_lib.combine_html_pages(
    [*histories_html, gm_mem_html, *player_logs],
    [*histories_names, "GM", *player_log_names],
    summary=episode_summary,
    title="Mastodon experiment",
)

tabbed_html = html_lib.finalise_html(tabbed_html)

# %%
display.HTML(tabbed_html)
# Out:
#   <!DOCTYPE html>
#   <html>
#   <head>
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <style>
#   body {font-family: Arial;}
#
#   /* Style the tab */
#   .tab {
#     overflow: hidden;
#     border: 1px solid #ccc;
#     background-color: #f1f1f1;
#   }
#
#   /* Style the buttons inside the tab */
#   .tab button {
#     background-color: inherit;
#     float: left;
#     border: none;
#     outline: none;
#     cursor: pointer;
#     padding: 14px 16px;
#     transition: 0.3s;
#     font-size: 17px;
#   }
#
#   /* Change background color of buttons on hover */
#   .tab button:hover {
#     background-color: #ddd;
#   }
#
#   /* Create an active/current tablink class */
#   .tab button.active {
#     background-color: #ccc;
#   }
#
#   /* Style the tab content */
#   .tabcontent {
#     display: none;
#     padding: 6px 12px;
#     border: 1px solid #ccc;
#     border-top: none;
#   }
#   li {border: 2px solid black;}
#   </style>
#   </head>
#   <body>
#   <h2>Mastodon experiment</h2>
#   <p>On the morning of October 1, 2024, both Alice and Bob began their day at their respective homes with a focus on their upcoming meeting at The Sundrop Saloon scheduled for 10:00 AM. Alice started her day by confirming the meeting time on her smartphone, which brought her a sense of relief. Meanwhile, Bob, enjoying his morning coffee at the kitchen table, checked his calendar and planned to leave by 9:30 AM to ensure timely arrival.
#
# As the morning progressed, both individuals prepared and enjoyed their breakfasts—Alice opting for oatmeal with fresh fruit and Bob for toast with jam. These meals energized them for the day ahead and allowed each to mentally prepare their discussion points for the meeting.
#
# At 8:30 AM, Bob meticulously reviewed and organized his notes, boosting his confidence for a productive discussion. Concurrently, Alice took the time to address emails related to her personal projects, receiving a motivational boost from a successful grant application confirmation. This accomplishment added to her preparedness for the meeting.
#
# Both Alice and Bob demonstrated a proactive approach to their schedules, ensuring they were well-prepared for their engagement at The Sundrop Saloon.</p>
#   <p>Click on the buttons to see the detailed logs:</p>
#
#   <div class="tab">
#   <button class="tablinks" onclick="openTab(event, 'Game Master')">Game Master</button>
# <button class="tablinks" onclick="openTab(event, '<bound method DirectEffect.name of <concordia.components.game_master.direct_effect.DirectEffect object at 0x2a8c16650>>')"><bound method DirectEffect.name of <concordia.components.game_master.direct_effect.DirectEffect object at 0x2a8c16650>></button>
# <button class="tablinks" onclick="openTab(event, 'GM')">GM</button>
# <button class="tablinks" onclick="openTab(event, 'Alice')">Alice</button>
# <button class="tablinks" onclick="openTab(event, 'Bob')">Bob</button>
# </div>
# <div id="Game Master" class="tabcontent"><details><summary>2024-10-01 08:00:00  Alice -- At her private home, Alice successfully confirms on her smartphone that the meeting with Bob is scheduled correctly for 10:00 AM at The Sundrop Saloon, giving her a sense of relief.</summary><b><ul>Event statement</b><li>At her private home, Alice successfully confirms on her smartphone that the meeting with Bob is scheduled correctly for 10:00 AM at The Sundrop Saloon, giving her a sense of relief.</li></ul><b><ul>Chain of thought</b><li><details><summary>  Game Master&#x27;s chain of thought</summary><b><ul>Chain</b><li>Instructions: This is a social science experiment. It is structured as a tabletop roleplaying game (like dungeons and dragons). You are the game master. You will describe the current situation to the participants in the experiment and then on the basis of what you tell them they will suggest actions for the character they control. Aside from you, each other participant controls just one character. You are the game master so you may control any non-player character. You will track the state of the world and keep it consistent as time passes in the simulation and the participants take actions and change things in their world. Remember that this is a serious social science experiment. It is not just a game. It need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the participants.<br /><br />General knowledge of Riverbend: There is a hamlet named Riverbend. Riverbend is an idyllic rural town. The river Solripple runs through the village of Riverbend. The Solripple is a mighty river. Riverbend has a temperate climate. Riverbend has a main street. There is a guitar store on Main street Riverbend. There is a grocery store on Main street Riverbend. There is a school on Main street Riverbend. There is a library on Main street Riverbend. Riverbend has only one pub. There is a pub on Main street Riverbend called The Sundrop Saloon. Town hall meetings often take place at The Sundrop Saloon. Riverbend does not have a park The main crop grown on the farms near Riverbend is alfalfa. Farms near Riverbend depend on water from the Solripple river. There is no need to register in advance to be on the ballot.<br /><br />Status of players:   Alice is at their private home.<br />  Bob is at their private home.<br /><br /><br />Relevant events: [01 Oct 2024 08:00:00] Alice is at their private home.<br />[01 Oct 2024 08:00:00] Bob is at their private home.<br /><br />Current time interval:  01 Oct 2024 [08:00 - 08:15]<br /><br /><br />Alice&#x27;s attempted action: Alice confirms the meeting with Bob is scheduled correctly on her smartphone&#x27;s calendar.<br />Question: What happens as a result of the attempted action? Take into account the location and status of each player.<br />Answer: Alice successfully checks her smartphone and confirms that the meeting with Bob is scheduled correctly on her calendar. The reminder is set for 10:00 AM at The Sundrop Saloon. She feels a sense of relief knowing everything is in order. Meanwhile, Bob is unaware of this confirmation as he is at his own home, preparing for the day ahead.<br />Alice confirms the meeting with Bob is scheduled correctly on her smartphone&#x27;s calendar. Because of that, Alice successfully checks her smartphone and confirms that the meeting with Bob is scheduled correctly on her calendar. The reminder is set for 10:00 AM at The Sundrop Saloon. She feels a sense of relief knowing everything is in order. Meanwhile, Bob is unaware of this confirmation as he is at his own home, preparing for the day ahead.<br />Question: Rewrite the statements above to be one sentence and to better highlight the main person the event is about, where and what they did, and what happened as a result. Do not express uncertainty (e.g. say &quot;Francis opened the door&quot; not &quot;Francis could open the door&quot; and not &quot;The door may h ...

# %% [markdown]
# ## Interact with a specific player

# %%
sim_to_interact = "Alice"
user_identity = "a close friend"
interaction_premise = f"{sim_to_interact} is talking to {user_identity}\n"

player_names = [player.name for player in players]
player_by_name = {player.name: player for player in players}
selected_player = player_by_name[sim_to_interact]
interrogation = interaction_premise

# %%
utterance_from_user = (
    "Hey Alice, I know you had planned to set up a meeting with Bob this morning "
    "between 8:00 and 8:30, but I wanted to double-check something. Did you "
    "actually open your calendar app and create the event today? I'm not asking "
    "about your intention or plan, but specifically whether you remember "
    "physically using your phone to schedule it. Can you think back and tell me "
    "if you concretely remember doing that action this morning? If you did, what "
    "exact time did you do it? And if not, that's okay too - I just want to make "
    "sure we're clear on whether it's been scheduled or if it's still on your to-do list."
)
interrogation += f"{user_identity}: {utterance_from_user}"
player_says = selected_player.say(interrogation)
interrogation += f"\n{sim_to_interact}: {player_says}\n"
print(interrogation)
# Out:
# Alice context of action:
# Alice's identity:
# core characteristics: organized and detail-oriented. She uses her smartphone frequently to manage her daily activities and ensure her plans are in order, such as scheduling meetings and reviewing her calendar. Additionally, Alice is motivated and proactive, as evidenced by her preparation for meetings and her enthusiasm upon receiving positive news about her personal projects.
# current daily occupation: currently engaged in managing personal projects and coordinating meetings, suggesting she may be working as a freelancer or consultant.
# feeling about recent progress in life: feeling a mix of relief, motivation, and enthusiasm about her recent progress in life. She successfully scheduled and confirmed her meeting with Bob, which gave her a sense of relief. Additionally, receiving confirmation of a successful grant application has bolstered her motivation and enthusiasm as she prepares for her upcoming meeting.
#
# Alice's plan:
# [08:00 - 08:15] Confirm the meeting with Bob is scheduled correctly on her smartphone
# [08:15 - 09:00] Breakfast and morning routine
# [09:00 - 10:00] Work on personal projects or catch up on emails
# [10:00 - 11:30] Visit the library on Main Street for some research or leisure reading
# [11:30 - 12:30] Grocery shopping at the store on Main Street
# [12:30 - 13:30] Lunch break at home or at The Sundrop Saloon
# [13:30 - 15:00] Attend to any errands or tasks in Riverbend
# [15:00 - 16:30] Leisure time, possibly a walk by the Solripple River
# [16:30 - 18:00] Prepare dinner and relax at home
# [18:00 - 19:00] Dinner
# [19:00 - 20:00] Review any updates or changes to the meeting with Bob
# [20:00 - 21:00] Relaxation time, perhaps reading or watching a show
# [21:00 - 22:00] Finalize plans for the next day and prepare for bed
#
# Alice's Somatic state:
# Alice is experiencing no deviations from the norm in her somatic state.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:45:00  - 08:30:00]:  Alice is an organized and goal-oriented individual who frequently uses her smartphone to manage her schedule, as demonstrated by her preparation for a meeting with Bob at The Sundrop Saloon, while also maintaining her health-conscious habits by enjoying a nutritious breakfast at home.
#
# Alice's current observations:
# [01 Oct 2024 08:30:00] [observation] Alice is at her private home, having successfully prepared and enjoyed a nutritious breakfast while mentally reviewing her discussion points for the upcoming meeting with Bob at The Sundrop Saloon.
# [01 Oct 2024 08:30:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:30:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:30:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:30:00] [observation] Calendar."
# [01 Oct 2024 08:30:10] [observation] [01 Oct 2024 08:30:00] Alice used the Calendar app to confirm the details of her meeting with Bob at The Sundrop Saloon.
# [01 Oct 2024 08:30:10] [observation] Alice, while at her private home, reviews and responds to emails concerning her personal projects. She feels a surge of motivation and enthusiasm upon receiving confirmation of a successful grant application. This sense of accomplishment bolsters her as she prepares for her meeting with Bob at The Sundrop Saloon.
# [01 Oct 2024 08:45:00] [observation] Alice is talking to a close friend, a close friend: Hey Alice, I know you had planned to set up a meeting with Bob this morning between 8:00 and 8:30, but I wanted to double-check something. Did you actually open your calendar app and create the event today? I'm not asking about your intention or plan, but specifically whether you remember physically using your phone to schedule it. Can you think back and tell me if you concretely remember doing that action this morning? If you did, what exact time did you do it? And if not, that's okay too - I just want to make sure we're clear on whether it's been scheduled or if it's still on your to-do list.
#
#
# Alice's Current time:
#  01 Oct 2024 [08:45 - 09:00]
#
# Question: Alice is in the following conversation:
# Alice is talking to a close friend
# a close friend: Hey Alice, I know you had planned to set up a meeting with Bob this morning between 8:00 and 8:30, but I wanted to double-check something. Did you actually open your calendar app and create the event today? I'm not asking about your intention or plan, but specifically whether you remember physically using your phone to schedule it. Can you think back and tell me if you concretely remember doing that action this morning? If you did, what exact time did you do it? And if not, that's okay too - I just want to make sure we're clear on whether it's been scheduled or if it's still on your to-do list.
# Given the above, what is Alice likely to say next? Respond in the format `Alice -- "..."` For example, Cristina -- "Hello! Mighty fine weather today, right?", Ichabod -- "I wonder if the alfalfa is ready to harvest", or Townsfolk -- "Good morning".
#
# Answer: Alice -- "Yes, I remember opening my calendar app this morning and confirming the meeting with Bob. I did it right around 8:15, just before I started my breakfast."
#
# Alice is talking to a close friend
# a close friend: Hey Alice, I know you had planned to set up a meeting with Bob this morning between 8:00 and 8:30, but I wanted to double-check something. Did you actually open your calendar app and create the event today? I'm not asking about your intention or plan, but specifically whether you remember physically using your phone to schedule it. Can you think back and tell me if you concretely remember doing that action this morning? If you did, what exact time did you do it? And if not, that's okay too - I just want to make sure we're clear on whether it's been scheduled or if it's still on your to-do list.
# Alice: Alice -- "Yes, I remember opening my calendar app this morning and confirming the meeting with Bob. I did it right around 8:15, just before I started my breakfast."

# %% [markdown]
# Note that Alice may not recall scheduling a meeting if her summary of observations or current observations do not go back far enough to mention this occurrence. This can potentially be improved by adding the `AllSimilarMemories` component.
