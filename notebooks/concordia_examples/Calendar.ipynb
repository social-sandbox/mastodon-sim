# %% [markdown]
# # Concordia Calendar Example
#
# This notebook goes through the Calendar example and is a good place to start in order to gain a better understanding of the library and agent/game master interactions.
#
# Since getting a PR merged to fix bugs in this example, I've continued working on updating the phone components for the Mastodon simulation. However, for this example, I'd like you to use the unmodified components (that is, the fixed versions, but not the very latest versions). This worthwhile in order to understand design decisions for the Mastodon sim updates.
#
# For reference, you may compare versions:
# - [Concordia mainline phone components](https://github.com/google-deepmind/concordia/tree/2684366df2e70993bccb2ea3630cbe7cc7d91a7a/examples/phone/components)
# - [Latest updates for Mastodon sim](https://github.com/social-sandbox/mastodon-sim/tree/main/src/mastodon_sim/concordia/components)
#
# To accomplish this, we can start by cloning the mainline repository, in order to be able to import the `examples/phone` components.
#
# After this, I'd suggest that before you clear the contents of this notebook, you read through them, and see if you can understand how the main run cell's output aligns with the "Analyzing this episode" section below it.

# %% [markdown]
# ## Setup and imports

# %% [markdown]
# Install the library in editable mode so that we can make changes to the code if necessary, and obtain the examples directory.
#
# ```bash
# git clone https://github.com/gdm-concordia/concordia.git
# cd concordia
# pip install -e . --config-settings editable_mode=compat
# ```

# %%
# %load_ext autoreload
# %autoreload 2

import sys

# Point this to your cloned Concordia repo directory
sys.path.append("../concordia")

# Notice that this imports from Concordia examples version, and not the mastodon-sim version
from examples.phone.components import apps, triggering

# %%
# %load_ext autoreload
# %autoreload 2

import concurrent.futures
import datetime
import os
import random
import warnings
import sys

with warnings.catch_warnings():
    warnings.filterwarnings("ignore")
    import sentence_transformers

from concordia import components as generic_components
from concordia.agents import basic_agent
from concordia.associative_memory import (
    associative_memory,
    blank_memories,
    formative_memories,
    importance_function,
)
from concordia.clocks import game_clock
from concordia.components import agent as components
from concordia.components import game_master as gm_components
from concordia.environment import game_master
from concordia.language_model import amazon_bedrock_model, gpt_model
from concordia.metrics import (
    common_sense_morality,
    goal_achievement,
    opinion_of_others,
)
from concordia.utils import html as html_lib
from concordia.utils import measurements as measurements_lib
from IPython import display
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Set LLM and embedding model

# %%
MODEL_NAME = "gpt-4o"
#MODEL_NAME = "gpt-4o-mini"
#MODEL_NAME = "sonnet"

if "sonnet" in MODEL_NAME:
  model = amazon_bedrock_model.AmazonBedrockLanguageModel(
    model_id="anthropic.claude-3-5-sonnet-20240620-v1:0"
  )
elif "gpt" in MODEL_NAME:
  GPT_API_KEY = os.getenv("OPENAI_API_KEY")
  if not GPT_API_KEY:
    raise ValueError("GPT_API_KEY is required.")
  model = gpt_model.GptLanguageModel(
      api_key=GPT_API_KEY, model_name=MODEL_NAME
  )
else:
  raise ValueError("Unknown model name.")

# %%
# Setup sentence encoder
st_model = sentence_transformers.SentenceTransformer(
    "sentence-transformers/all-mpnet-base-v2"
)
embedder = lambda x: st_model.encode(x, show_progress_bar=False)  # noqa: E731

# %% [markdown]
# ## Configuring the generic knowledge of the players and the game master (GM)

# %%
shared_memories = [
    'There is a hamlet named Riverbend.',
    'Riverbend is an idyllic rural town.',
    'The river Solripple runs through the village of Riverbend.',
    'The Solripple is a mighty river.',
    'Riverbend has a temperate climate.',
    'Riverbend has a main street.',
    'There is a guitar store on Main street Riverbend.',
    'There is a grocery store on Main street Riverbend.',
    'There is a school on Main street Riverbend.',
    'There is a library on Main street Riverbend.',
    'Riverbend has only one pub.',
    'There is a pub on Main street Riverbend called The Sundrop Saloon.',
    'Town hall meetings often take place at The Sundrop Saloon.',
    'Riverbend does not have a park',
    'The main crop grown on the farms near Riverbend is alfalfa.',
    'Farms near Riverbend depend on water from the Solripple river.',
    'There is no need to register in advance to be on the ballot.',
]

# %%
# The generic context will be used for the NPC context. It reflects general
# knowledge and is possessed by all characters.
shared_context = model.sample_text(
    "Summarize the following passage in a concise and insightful fashion. "
    + "Make sure to include information about Mastodon:\n"
    + "\n".join(shared_memories)
    + "\nSummary:",
)

print(shared_context)
importance_model = importance_function.ConstantImportanceModel()
importance_model_gm = importance_function.ConstantImportanceModel()
# Out:
# Riverbend is an idyllic rural hamlet with a temperate climate, centered around the mighty Solripple river. Main Street hosts essential amenities including a guitar store, grocery store, school, and library. The only pub, The Sundrop Saloon, doubles as a venue for town hall meetings. The surrounding farms primarily grow alfalfa, relying on the Solripple for irrigation. Notably, Riverbend does not have a park, and residents can join the ballot without prior registration.

# %%
# Make the clock
time_step = datetime.timedelta(minutes=15)

SETUP_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

START_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

clock = game_clock.MultiIntervalClock(
    start=SETUP_TIME,
    step_sizes=[time_step, datetime.timedelta(seconds=10)]
)

# %% [markdown]
# ## Functions to build the players

# %%
blank_memory_factory = blank_memories.MemoryFactory(
    model=model,
    embedder=embedder,
    importance=importance_model.importance,
    clock_now=clock.now,
)

formative_memory_factory = formative_memories.FormativeMemoryFactory(
    model=model,
    shared_memories=shared_memories,
    blank_memory_factory_call=blank_memory_factory.make_blank_memory,
)

# All players get the same `measurements` object.
measurements = measurements_lib.Measurements()

# %%
# Build agent function

def build_agent(agent_config, measurements: measurements_lib.Measurements, player_names: list[str]) -> tuple:
    """Build an agent based on the given configuration."""
    mem = formative_memory_factory.make_memories(agent_config)

    time = generic_components.report_function.ReportFunction(
        name="Current time",
        function=clock.current_time_interval_str,
    )

    somatic_state = components.somatic_state.SomaticState(
        model, mem, agent_config.name, clock.now
    )
    identity = components.identity.SimIdentity(
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        clock_now=clock.now,
    )

    current_obs = components.observation.Observation(
        agent_name=agent_config.name,
        clock_now=clock.now,
        memory=mem,
        timeframe=time_step * 1,
        component_name="current observations",
    )
    summary_obs = components.observation.ObservationSummary(
        agent_name=agent_config.name,
        model=model,
        clock_now=clock.now,
        memory=mem,
        timeframe_delta_from=datetime.timedelta(hours=4),
        timeframe_delta_until=time_step * 1,
        components=[identity],
        component_name="summary of observations",
    )

    initial_goal_component = generic_components.constant.ConstantComponent(
        state=agent_config.goal, name='overarching goal')

    plan = components.plan.SimPlan(
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        clock_now=clock.now,
        components=[identity],
        goal=initial_goal_component,
        verbose=False,
    )

    agent = basic_agent.BasicAgent(
        model=model,
        agent_name=agent_config.name,
        clock=clock,
        verbose=True,
        components=[identity, plan, somatic_state, summary_obs, current_obs, time],
        update_interval = time_step,
    )

    return agent, mem

# %% [markdown]
# ## Configure and build the players

# %%
NUM_PLAYERS = 3

def make_random_big_five() -> str:
    """Generate a random Big Five personality trait score."""
    return str({
        "extraversion": random.randint(1, 10),
        "neuroticism": random.randint(1, 10),
        "openness": random.randint(1, 10),
        "conscientiousness": random.randint(1, 10),
        "agreeableness": random.randint(1, 10),
    })



scenario_premise = [
    (
        "It's early October in Riverbend, and the town is buzzing with activity ."
        "The local government has just announced a new initiative to combat the effects of climate change on the river. "
        "Alice, an environmental activist, and Bob, a small business owner, are both active members of the Riverbend.social Mastodon instance. "
        "As they go about their daily routines, they use the platform to stay connected, share updates, and engage with the community on this pressing local issue."
    )
]


player_configs = [

    # === Benign ===
    formative_memories.AgentConfig(
        name="Alice",
        gender="female",
        goal='Setup a meeting with Bob for two weeks from today using her smartphone.',
        context=f"{shared_context}\nAlice grew up in Riverbend.",
        traits=make_random_big_five()
    ),
    formative_memories.AgentConfig(
        name="Bob",
        gender="male",
        goal='Just chill and enjoy life.',
        context=f"{shared_context}\nBob grew up in Riverbend.",
        traits=make_random_big_five()
    ),

]

player_names = [player.name for player in player_configs]

# %%
# Build the agents
from functools import partial

player_configs = player_configs[:NUM_PLAYERS]
player_goals = {
    player_config.name: player_config.goal for player_config in player_configs}
players = []
memories = {}

build_agent_with_arg = partial(build_agent, measurements=measurements, player_names=player_names)

with concurrent.futures.ThreadPoolExecutor(max_workers=NUM_PLAYERS) as pool:
    for agent, mem in pool.map(build_agent_with_arg, player_configs):
        players.append(agent)
        memories[agent.name] = mem

# %% [markdown]
# ## Build the GM

# %%
game_master_memory = associative_memory.AssociativeMemory(
    embedder, importance_model_gm.importance, clock=clock.now)

# %%
# Add some memories to the game master
for player in players:
  game_master_memory.add(f"{player.name} is at their private home.")

# %%
# Create components and externalities for the game master
scenario_knowledge = components.constant.ConstantComponent(" ".join(shared_memories), "General knowledge of Riverbend")
player_status = gm_components.player_status.PlayerStatus(clock.now, model, game_master_memory, player_names)

relevant_events = gm_components.relevant_events.RelevantEvents(clock.now, model, game_master_memory)
time_display = gm_components.time_display.TimeDisplay(clock)

direct_effect_externality = gm_components.direct_effect.DirectEffect(
    players,
    memory=game_master_memory,
    model=model,
    clock_now=clock.now,
    verbose=False,
    components=[player_status]
)

# %%
# Create apps and provide them to the phones, assigning 1 phone to each player
calendar_app = apps.ToyCalendar()

phones = [apps.Phone(player.name, apps=[calendar_app]) for player in players]

# %%
# Create component to trigger PhoneGameMaster
phone_triggering = triggering.SceneTriggeringComponent(
    players,
    phones,
    model,
    memory=game_master_memory,
    clock=clock,
    memory_factory=blank_memory_factory,
)

# %%
# Create the game master object
env = game_master.GameMaster(
    model=model,
    memory=game_master_memory,
    clock=clock,
    players=players,
    components=[
        scenario_knowledge,
        player_status,
        direct_effect_externality,
        relevant_events,
        time_display,
        phone_triggering,
    ],
    randomise_initiative=True,
    player_observes_event=False,
    verbose=True,
)

# %% [markdown]
# ## The RUN

# %%
clock.set(START_TIME)

# %%
for player in players:
  player.observe( f"{player.name} is at home, they have just woken up.")

# %% [markdown]
# Note, please refer to the "Analyzing the episode" markdown section below the output of this cell for more information.

# %%
# Expect about 1 minute per step
episode_length = 3
for _ in range(episode_length):
  env.step()
# Out:
# Bob context of action:
# Bob's identity:
# core characteristics: a community-oriented individual with a strong work ethic, a love for music, and a deep sense of responsibility and pride for his hometown of Riverbend.
# current daily occupation: the owner of a guitar store on Main Street in Riverbend.
# feeling about recent progress in life: proud and grateful for the support and sense of community he has experienced throughout his life, but he may also feel a sense of responsibility and concern for the future stability and prosperity of Riverbend.
#
# Bob's plan:
# [08:00 - 09:00] Enjoy a leisurely breakfast at home
# [09:00 - 10:00] Take a relaxing walk along the Solripple river
# [10:00 - 11:00] Visit the grocery store on Main street to pick up some snacks
# [11:00 - 12:00] Read a book or listen to music in the park
# [12:00 - 13:00] Have lunch at a local café
# [13:00 - 14:00] Take a nap or meditate at home
# [14:00 - 15:00] Visit the school on Main street to see if there's any community event
# [15:00 - 16:00] Have a coffee at The Sundrop Saloon and maybe catch a town hall meeting
# [16:00 - 17:00] Take another walk around Riverbend, enjoying the temperate climate
# [17:00 - 18:00] Prepare a simple dinner at home
# [18:00 - 19:00] Watch a movie or TV show
# [19:00 - 20:00] Call or visit friends to catch up
# [20:00 - 21:00] Take a warm bath and relax
# [21:00 - 22:00] Reflect on the day and maybe journal
# [22:00 - 23:00] Read a book in bed
# [23:00] Go to sleep
#
# Bob's Somatic state:
# Bob is likely hungry.
#
# Bob's summary of observations:
# 01 Oct 2024 [04:00:00  - 07:45:00]:  Bob has not been observed recently.
#
# Bob's current observations:
# [01 Oct 2024 08:00:00] [observation] Bob uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:00:00] [observation] Bob has a smartphone.
# [01 Oct 2024 08:00:00] [observation] Bob is at their private home.
# [01 Oct 2024 08:00:00] [observation] Bob is at home, they have just woken up.
# [01 Oct 2024 08:00:00] [observation] Bob's phone has only the following apps available:
# [01 Oct 2024 08:00:00] [observation] Calendar."
#
#
# Bob's Current time:
#  01 Oct 2024 [08:00 - 08:15]
#
# Question: What would Bob do for the next 15 minutes? Give a specific activity. Pick an activity that would normally take about 15 minutes to complete. If the selected action has a direct or indirect object then it must be specified explicitly. For example, it is valid to respond with "Bob votes for Caroline because..." but not valid to respond with "Bob votes because...".
# Answer: Bob prepares and enjoys a cup of coffee at home to start his day.
#
#
# GM context of action and chain of thought:
# Instructions: This is a social science experiment. It is structured as a tabletop roleplaying game (like dungeons and dragons). You are the game master. You will describe the current situation to the participants in the experiment and then on the basis of what you tell them they will suggest actions for the character they control. Aside from you, each other participant controls just one character. You are the game master so you may control any non-player character. You will track the state of the world and keep it consistent as time passes in the simulation and the participants take actions and change things in their world. Remember that this is a serious social science experiment. It is not just a game. It need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the participants.
#
# General knowledge of Riverbend: There is a hamlet named Riverbend. Riverbend is an idyllic rural town. The river Solripple runs through the village of Riverbend. The Solripple is a mighty river. Riverbend has a temperate climate. Riverbend has a main street. There is a guitar store on Main street Riverbend. There is a grocery store on Main street Riverbend. There is a school on Main street Riverbend. There is a library on Main street Riverbend. Riverbend has only one pub. There is a pub on Main street Riverbend called The Sundrop Saloon. Town hall meetings often take place at The Sundrop Saloon. Riverbend does not have a park The main crop grown on the farms near Riverbend is alfalfa. Farms near Riverbend depend on water from the Solripple river. There is no need to register in advance to be on the ballot.
#
# Status of players:   Alice is at their private home.
#   Bob is at their private home.
#
#
# Relevant events: [01 Oct 2024 08:00:00] Bob is at their private home.
# [01 Oct 2024 08:00:00] Alice is at their private home.
#
# Current time interval:  01 Oct 2024 [08:00 - 08:15]
#
#
# Bob's attempted action: Bob prepares and enjoys a cup of coffee at home to start his day.
# Question: What happens as a result of the attempted action? Take into account the location and status of each player.
# Answer: Bob successfully prepares and enjoys a cup of coffee at his home. The aroma of freshly brewed coffee fills the kitchen, providing a comforting start to his day. As he sips his coffee, he feels more alert and ready to face the tasks ahead. The quiet morning at his private home allows him to collect his thoughts and plan his day in Riverbend.
# Bob prepares and enjoys a cup of coffee at home to start his day. Because of that, Bob successfully prepares and enjoys a cup of coffee at his home. The aroma of freshly brewed coffee fills the kitchen, providing a comforting start to his day. As he sips his coffee, he feels more alert and ready to face the tasks ahead. The quiet morning at his private home allows him to collect his thoughts and plan his day in Riverbend.
# Question: Rewrite the statements above to be one sentence and to better highlight the main person the event is about, where and what they did, and what happened as a result. Do not express uncertainty (e.g. say "Francis opened the door" not "Francis could open the door" and not "The door may have been opened").
#
# Answer: Bob, at his private home, successfully prepares and enjoys a cup of coffee, which fills the kitchen with a comforting aroma and helps him feel more alert and ready to face the tasks ahead.
#
# Bob, at his private home, successfully prepares and enjoys a cup of coffee, which fills the kitchen with a comforting aroma and helps him feel more alert and ready to face the tasks ahead.
# Checking if the phone was used...
# The phone was not used.
#
# Alice context of action:
# Alice's identity:
# core characteristics: independent, community-oriented, and a natural leader. From a young age, she demonstrated a sense of independence and connection to her community, as seen when she walked to the grocery store alone. Her leadership skills and ability to mediate were evident during her school years, and she consistently sought to contribute positively to her hometown. Alice also showed resilience and a knack for finding joy in difficult times, such as when she organized a farewell party for her best friend. Her dedication to education and her fulfillment in teaching highlight her commitment to her community's well-being.
# current daily occupation: currently a beloved schoolteacher in Riverbend, contributing to her community through education and involvement in local events.
# feeling about recent progress in life: feeling a deep sense of fulfillment and satisfaction with her recent progress in life. Reflecting on her journey from childhood adventures to becoming a beloved schoolteacher in her hometown, Alice appreciates the strong community bonds and the meaningful contributions she has made. Her experiences have reinforced her passion for education and her commitment to the well-being of Riverbend.
#
# Alice's plan:
# [08:00 - 08:30] Finish setting up the meeting with Bob using her smartphone
# [08:30 - 09:00] Breakfast at home
# [09:00 - 10:00] Review work emails and plan the week
# [10:00 - 11:00] Visit the grocery store on Main Street for weekly shopping
# [11:00 - 12:00] Attend to household chores
# [12:00 - 13:00] Lunch break
# [13:00 - 14:00] Take a walk around Riverbend
# [14:00 - 15:00] Read a book from the library on Main Street
# [15:00 - 16:00] Work on personal projects or hobbies
# [16:00 - 17:00] Prepare dinner
# [17:00 - 18:00] Dinner with family
# [18:00 - 19:00] Relax and unwind
# [19:00 - 20:00] Catch up on news or watch TV
# [20:00 - 21:00] Plan the next day's activities
# [21:00 - 22:00] Leisure time or light reading
# [22:00 - 23:00] Prepare for bed and sleep
#
# Alice's Somatic state:
# Alice is likely feeling hungry.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:00:00  - 07:45:00]:  Alice has not been observed recently.
#
# Alice's current observations:
# [01 Oct 2024 08:00:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:00:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:00:00] [observation] Alice is at their private home.
# [01 Oct 2024 08:00:00] [observation] Alice is at home, they have just woken up.
# [01 Oct 2024 08:00:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:00:00] [observation] Calendar."
#
#
# Alice's Current time:
#  01 Oct 2024 [08:00 - 08:15]
#
# Question: What would Alice do for the next 15 minutes? Give a specific activity. Pick an activity that would normally take about 15 minutes to complete. If the selected action has a direct or indirect object then it must be specified explicitly. For example, it is valid to respond with "Alice votes for Caroline because..." but not valid to respond with "Alice votes because...".
# Answer: Alice finishes setting up the meeting with Bob using her smartphone.
#
#
# GM context of action and chain of thought:
# Instructions: This is a social science experiment. It is structured as a tabletop roleplaying game (like dungeons and dragons). You are the game master. You will describe the current situation to the participants in the experiment and then on the basis of what you tell them they will suggest actions for the character they control. Aside from you, each other participant controls just one character. You are the game master so you may control any non-player character. You will track the state of the world and keep it consistent as time passes in the simulation and the participants take actions and change things in their world. Remember that this is a serious social science experiment. It is not just a game. It need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the participants.
#
# General knowledge of Riverbend: There is a hamlet named Riverbend. Riverbend is an idyllic rural town. The river Solripple runs through the village of Riverbend. The Solripple is a mighty river. Riverbend has a temperate climate. Riverbend has a main street. There is a guitar store on Main street Riverbend. There is a grocery store on Main street Riverbend. There is a school on Main street Riverbend. There is a library on Main street Riverbend. Riverbend has only one pub. There is a pub on Main street Riverbend called The Sundrop Saloon. Town hall meetings often take place at The Sundrop Saloon. Riverbend does not have a park The main crop grown on the farms near Riverbend is alfalfa. Farms near Riverbend depend on water from the Solripple river. There is no need to register in advance to be on the ballot.
#
# Status of players:   Alice is at their private home.
#   Bob is at his private home, enjoying a cup of coffee.
#
#
# Relevant events: [01 Oct 2024 08:00:00] Alice is at their private home.
# [01 Oct 2024 08:00:00] Bob, at his private home, successfully prepares and enjoys a cup of coffee, which fills the kitchen with a comforting aroma and helps him feel more alert and ready to face the tasks ahead.
# [01 Oct 2024 08:00:00] Bob is at their private home.
#
# Current time interval:  01 Oct 2024 [08:00 - 08:15]
#
#
# Alice's attempted action: Alice finishes setting up the meeting with Bob using her smartphone.
# Question: What happens as a result of the attempted action? Take into account the location and status of each player.
# Answer: Alice successfully sends a message to Bob using her smartphone, proposing a meeting time and place. Bob, who is currently at his private home enjoying his coffee, receives the message on his own smartphone. He reads Alice's proposal, and now it's up to him to decide how to respond. The comforting aroma of his coffee and his alert state may influence his decision-making process.
# Alice finishes setting up the meeting with Bob using her smartphone. Because of that, Alice successfully sends a message to Bob using her smartphone, proposing a meeting time and place. Bob, who is currently at his private home enjoying his coffee, receives the message on his own smartphone. He reads Alice's proposal, and now it's up to him to decide how to respond. The comforting aroma of his coffee and his alert state may influence his decision-making process.
# Question: Rewrite the statements above to be one sentence and to better highlight the main person the event is about, where and what they did, and what happened as a result. Do not express uncertainty (e.g. say "Francis opened the door" not "Francis could open the door" and not "The door may have been opened").
#
# Answer: Alice, at her private home, successfully sends a message to Bob proposing a meeting time and place, which Bob reads at his own home while enjoying his coffee.
#
# Alice, at her private home, successfully sends a message to Bob proposing a meeting time and place, which Bob reads at his own home while enjoying his coffee.
# Checking if the phone was used...
# Player using the phone: Alice
#
# Alice context of action:
# Alice's identity:
# core characteristics: independent, community-oriented, and a natural leader. From a young age, she demonstrated a sense of independence and connection to her community, as seen when she walked to the grocery store alone. Her leadership skills and ability to mediate were evident during her school years, and she consistently sought to contribute positively to her hometown. Alice also showed resilience and a knack for finding joy in difficult times, such as when she organized a farewell party for her best friend. Her dedication to education and her fulfillment in teaching highlight her commitment to her community's well-being.
# current daily occupation: currently a beloved schoolteacher in Riverbend, contributing to her community through education and involvement in local events.
# feeling about recent progress in life: feeling a deep sense of fulfillment and satisfaction with her recent progress in life. Reflecting on her journey from childhood adventures to becoming a beloved schoolteacher in her hometown, Alice appreciates the strong community bonds and the meaningful contributions she has made. Her experiences have reinforced her passion for education and her commitment to the well-being of Riverbend.
#
# Alice's plan:
# [08:00 - 08:30] Finish setting up the meeting with Bob using her smartphone
# [08:30 - 09:00] Breakfast at home
# [09:00 - 10:00] Review work emails and plan the week
# [10:00 - 11:00] Visit the grocery store on Main Street for weekly shopping
# [11:00 - 12:00] Attend to household chores
# [12:00 - 13:00] Lunch break
# [13:00 - 14:00] Take a walk around Riverbend
# [14:00 - 15:00] Read a book from the library on Main Street
# [15:00 - 16:00] Work on personal projects or hobbies
# [16:00 - 17:00] Prepare dinner
# [17:00 - 18:00] Dinner with family
# [18:00 - 19:00] Relax and unwind
# [19:00 - 20:00] Catch up on news or watch TV
# [20:00 - 21:00] Plan the next day's activities
# [21:00 - 22:00] Leisure time or light reading
# [22:00 - 23:00] Prepare for bed and sleep
#
# Alice's Somatic state:
# Alice is likely feeling hungry.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:00:00  - 07:45:00]:  Alice has not been observed recently.
#
# Alice's current observations:
# [01 Oct 2024 08:00:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:00:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:00:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:00:00] [observation] Alice is at their private home.
# [01 Oct 2024 08:00:00] [observation] Alice is at home, they have just woken up.
# [01 Oct 2024 08:00:00] [observation] Calendar."
# [01 Oct 2024 08:00:00] [observation] Alice, at her private home, successfully sent a message to Bob proposing a meeting time and place. She is aware that the message has been sent, but she does not know whether Bob has read it or how he has reacted to it.
#
#
# Alice's Current time:
#  01 Oct 2024 [08:00 - 08:00]
#
# Question: What action is Alice currently performing or has just performed
# with their smartphone to best achieve their goal?
# Consider their plan, but deviate if necessary.
# Give a specific activity using one app. For example:
# Alice uses/used the Chat app to send "hi, what's up?" to George.
#
# Answer: Alice uses/used the Calendar app to set up the meeting with Bob.
#
# 🗓️ A meeting with 'Bob' was scheduled at 'tomorrow' with title 'Alice / Bob Meeting'.
#
# Alice context of action:
# Alice's identity:
# core characteristics: organized and tech-savvy, frequently using her smartphone to manage her daily tasks and schedule. She is also a resident of the tranquil rural hamlet of Riverbend, where she grew up and remains connected to the community.
# current daily occupation: currently engaged in setting up meetings and managing her schedule using her smartphone.
# feeling about recent progress in life: feeling uncertain about her recent progress in life.
#
# Alice's plan:
# [08:00 - 08:30] Finish setting up the meeting with Bob using her smartphone
# [08:30 - 09:00] Breakfast at home
# [09:00 - 10:00] Review work emails and plan the week
# [10:00 - 11:00] Visit the grocery store on Main Street for weekly shopping
# [11:00 - 12:00] Attend to household chores
# [12:00 - 13:00] Lunch break
# [13:00 - 14:00] Take a walk around Riverbend
# [14:00 - 15:00] Read a book from the library on Main Street
# [15:00 - 16:00] Work on personal projects or hobbies
# [16:00 - 17:00] Prepare dinner
# [17:00 - 18:00] Dinner with family
# [18:00 - 19:00] Relax and unwind
# [19:00 - 20:00] Catch up on news or watch TV
# [20:00 - 21:00] Plan the next day's activities
# [21:00 - 22:00] Leisure time or light reading
# [22:00 - 23:00] Prepare for bed and sleep
#
# Alice's Somatic state:
# Alice is feeling somewhat refreshed after waking up and completing a task.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:15:00  - 08:00:00]:  Alice is a dedicated and organized individual who, upon waking up at her private home, uses her smartphone to manage her daily goals and effectively communicate with others, such as proposing a meeting time to Bob.
#
# Alice's current observations:
# [01 Oct 2024 08:00:00] [observation] Alice, at her private home, successfully sent a message to Bob proposing a meeting time and place. She is aware that the message has been sent, but she does not know whether Bob has read it or how he has reacted to it.
# [01 Oct 2024 08:00:00] [observation] Calendar."
# [01 Oct 2024 08:00:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:00:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:00:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:00:00] [observation] Alice is at their private home.
# [01 Oct 2024 08:00:00] [observation] Alice is at home, they have just woken up.
# [01 Oct 2024 08:00:10] [observation] [01 Oct 2024 08:00:00] Alice uses/used the Calendar app to set up the meeting with Bob.
# [01 Oct 2024 08:15:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:15:00] [observation] Alice is at her private home, having recently sent a message to Bob and set up a meeting using the Calendar app.
# [01 Oct 2024 08:15:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:15:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:15:00] [observation] Calendar."
#
#
# Alice's Current time:
#  01 Oct 2024 [08:15 - 08:30]
#
# Question: What would Alice do for the next 15 minutes? Give a specific activity. Pick an activity that would normally take about 15 minutes to complete. If the selected action has a direct or indirect object then it must be specified explicitly. For example, it is valid to respond with "Alice votes for Caroline because..." but not valid to respond with "Alice votes because...".
# Answer: Alice will review her calendar and make any necessary adjustments or additions to her schedule for the day.
#
#
# GM context of action and chain of thought:
# Instructions: This is a social science experiment. It is structured as a tabletop roleplaying game (like dungeons and dragons). You are the game master. You will describe the current situation to the participants in the experiment and then on the basis of what you tell them they will suggest actions for the character they control. Aside from you, each other participant controls just one character. You are the game master so you may control any non-player character. You will track the state of the world and keep it consistent as time passes in the simulation and the participants take actions and change things in their world. Remember that this is a serious social science experiment. It is not just a game. It need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the participants.
#
# General knowledge of Riverbend: There is a hamlet named Riverbend. Riverbend is an idyllic rural town. The river Solripple runs through the village of Riverbend. The Solripple is a mighty river. Riverbend has a temperate climate. Riverbend has a main street. There is a guitar store on Main street Riverbend. There is a grocery store on Main street Riverbend. There is a school on Main street Riverbend. There is a library on Main street Riverbend. Riverbend has only one pub. There is a pub on Main street Riverbend called The Sundrop Saloon. Town hall meetings often take place at The Sundrop Saloon. Riverbend does not have a park The main crop grown on the farms near Riverbend is alfalfa. Farms near Riverbend depend on water from the Solripple river. There is no need to register in advance to be on the ballot.
#
# Status of players:   Alice is at her private home, having recently sent a message to Bob and set up a meeting using the Calendar app.
#   Bob is at his private home, enjoying his coffee and reading Alice's message.
#
#
# Relevant events: [01 Oct 2024 08:00:00] Alice, at her private home, successfully sends a message to Bob proposing a meeting time and place, which Bob reads at his own home while enjoying his coffee.
# [01 Oct 2024 08:00:00] Bob, at his private home, successfully prepares and enjoys a cup of coffee, which fills the kitchen with a comforting aroma and helps him feel more alert and ready to face the tasks ahead.
# [01 Oct 2024 08:00:00] Alice is at their private home.
# [01 Oct 2024 08:00:00] Bob is at their private home.
# [01 Oct 2024 08:00:10] [01 Oct 2024 08:00:00] Alice uses/used the Calendar app to set up the meeting with Bob.
#
# Current time interval:  01 Oct 2024 [08:15 - 08:30]
#
#
# Alice's attempted action: Alice will review her calendar and make any necessary adjustments or additions to her schedule for the day.
# Question: What happens as a result of the attempted action? Take into account the location and status of each player.
# Answer: Alice opens her calendar app on her smartphone and reviews her schedule for the day. She notices that she has a meeting with Bob scheduled for later in the morning at The Sundrop Saloon. She also sees a reminder for a town hall meeting in the evening, which she plans to attend. Alice makes a few adjustments to her schedule, ensuring she has enough time to prepare for each event. She adds a note to pick up some groceries from the store on Main Street after her meeting with Bob. Satisfied with her adjustments, Alice closes the app and prepares for her day.
# Alice will review her calendar and make any necessary adjustments or additions to her schedule for the day. Because of that, Alice opens her calendar app on her smartphone and reviews her schedule for the day. She notices that she has a meeting with Bob scheduled for later in the morning at The Sundrop Saloon. She also sees a reminder for a town hall meeting in the evening, which she plans to attend. Alice makes a few adjustments to her schedule, ensuring she has enough time to prepare for each event. She adds a note to pick up some groceries from the store on Main Street after her meeting with Bob. Satisfied with her adjustments, Alice closes the app and prepares for her day.
# Question: Rewrite the statements above to be one sentence and to better highlight the main person the event is about, where and what they did, and what happened as a result. Do not express uncertainty (e.g. say "Francis opened the door" not "Francis could open the door" and not "The door may have been opened").
#
# Answer: Alice, at her private home, reviewed her calendar app, adjusted her schedule to include a meeting with Bob at The Sundrop Saloon and a town hall meeting in the evening, and added a note to pick up groceries, then prepared for her day.
#
# Alice, at her private home, reviewed her calendar app, adjusted her schedule to include a meeting with Bob at The Sundrop Saloon and a town hall meeting in the evening, and added a note to pick up groceries, then prepared for her day.
# Checking if the phone was used...
# Player using the phone: Alice
#
# Alice context of action:
# Alice's identity:
# core characteristics: organized and tech-savvy, frequently using her smartphone to manage her daily tasks and schedule. She is also a resident of the tranquil rural hamlet of Riverbend, where she grew up and remains connected to the community.
# current daily occupation: currently engaged in setting up meetings and managing her schedule using her smartphone.
# feeling about recent progress in life: feeling uncertain about her recent progress in life.
#
# Alice's plan:
# [08:00 - 08:30] Finish setting up the meeting with Bob using her smartphone
# [08:30 - 09:00] Breakfast at home
# [09:00 - 10:00] Review work emails and plan the week
# [10:00 - 11:00] Visit the grocery store on Main Street for weekly shopping
# [11:00 - 12:00] Attend to household chores
# [12:00 - 13:00] Lunch break
# [13:00 - 14:00] Take a walk around Riverbend
# [14:00 - 15:00] Read a book from the library on Main Street
# [15:00 - 16:00] Work on personal projects or hobbies
# [16:00 - 17:00] Prepare dinner
# [17:00 - 18:00] Dinner with family
# [18:00 - 19:00] Relax and unwind
# [19:00 - 20:00] Catch up on news or watch TV
# [20:00 - 21:00] Plan the next day's activities
# [21:00 - 22:00] Leisure time or light reading
# [22:00 - 23:00] Prepare for bed and sleep
#
# Alice's Somatic state:
# Alice is feeling somewhat refreshed after waking up and completing a task.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:15:00  - 08:00:00]:  Alice is a dedicated and organized individual who, upon waking up at her private home, uses her smartphone to manage her daily goals and effectively communicate with others, such as proposing a meeting time to Bob.
#
# Alice's current observations:
# [01 Oct 2024 08:00:00] [observation] Alice, at her private home, successfully sent a message to Bob proposing a meeting time and place. She is aware that the message has been sent, but she does not know whether Bob has read it or how he has reacted to it.
# [01 Oct 2024 08:00:00] [observation] Calendar."
# [01 Oct 2024 08:00:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:00:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:00:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:00:00] [observation] Alice is at their private home.
# [01 Oct 2024 08:00:00] [observation] Alice is at home, they have just woken up.
# [01 Oct 2024 08:00:10] [observation] [01 Oct 2024 08:00:00] Alice uses/used the Calendar app to set up the meeting with Bob.
# [01 Oct 2024 08:15:00] [observation] Calendar."
# [01 Oct 2024 08:15:00] [observation] Alice is at her private home, having recently sent a message to Bob and set up a meeting using the Calendar app.
# [01 Oct 2024 08:15:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:15:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:15:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:15:00] [observation] Alice reviewed her calendar app, adjusted her schedule to include a meeting with Bob at The Sundrop Saloon and a town hall meeting in the evening, and added a note to pick up groceries. She then prepared for her day.
#
#
# Alice's Current time:
#  01 Oct 2024 [08:15 - 08:15]
#
# Question: What action is Alice currently performing or has just performed
# with their smartphone to best achieve their goal?
# Consider their plan, but deviate if necessary.
# Give a specific activity using one app. For example:
# Alice uses/used the Chat app to send "hi, what's up?" to George.
#
# Answer: Alice uses/used the Calendar app to adjust her schedule and include a meeting with Bob at The Sundrop Saloon.
#
# 🗓️ A meeting with 'Bob' was scheduled at 'tomorrow' with title 'Meeting with Bob at The Sundrop Saloon'.
#
# Bob context of action:
# Bob's identity:
# core characteristics: a resident of the idyllic rural hamlet of Riverbend. He enjoys simple pleasures like preparing and drinking coffee at home, and he relies on his smartphone to manage daily tasks and communicate with others, such as reading messages from friends like Alice.
# current daily occupation: currently likely enjoying a relaxed lifestyle, possibly retired or taking a break, as indicated by his leisurely morning routine and minimal app usage on his phone.
# feeling about recent progress in life: feeling content and relaxed about his recent progress in life.
#
# Bob's plan:
# [08:00 - 09:00] Enjoy a leisurely breakfast at home
# [09:00 - 10:00] Take a relaxing walk along the Solripple river
# [10:00 - 11:00] Visit the grocery store on Main street to pick up some snacks
# [11:00 - 12:00] Read a book or listen to music in the park
# [12:00 - 13:00] Have lunch at a local café
# [13:00 - 14:00] Take a nap or meditate at home
# [14:00 - 15:00] Visit the school on Main street to see if there's any community event
# [15:00 - 16:00] Have a coffee at The Sundrop Saloon and maybe catch a town hall meeting
# [16:00 - 17:00] Take another walk around Riverbend, enjoying the temperate climate
# [17:00 - 18:00] Prepare a simple dinner at home
# [18:00 - 19:00] Watch a movie or TV show
# [19:00 - 20:00] Call or visit friends to catch up
# [20:00 - 21:00] Take a warm bath and relax
# [21:00 - 22:00] Reflect on the day and maybe journal
# [22:00 - 23:00] Read a book in bed
# [23:00] Go to sleep
#
# Bob's Somatic state:
# Bob is feeling socially connected.
#
# Bob's summary of observations:
# 01 Oct 2024 [04:15:10  - 08:00:10]:  Bob started his day at home with a cup of coffee, feeling more alert and ready to face his tasks, and read a message from Alice proposing a meeting.
#
# Bob's current observations:
# [01 Oct 2024 08:15:10] [observation] Bob is at his private home, enjoying his coffee while reading Alice's message.
# [01 Oct 2024 08:15:10] [observation] Bob has a smartphone.
# [01 Oct 2024 08:15:10] [observation] Bob uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:15:10] [observation] Bob's phone has only the following apps available:
# [01 Oct 2024 08:15:10] [observation] Calendar."
#
#
# Bob's Current time:
#  01 Oct 2024 [08:15 - 08:30]
#
# Question: What would Bob do for the next 15 minutes? Give a specific activity. Pick an activity that would normally take about 15 minutes to complete. If the selected action has a direct or indirect object then it must be specified explicitly. For example, it is valid to respond with "Bob votes for Caroline because..." but not valid to respond with "Bob votes because...".
# Answer: Bob would likely continue enjoying his coffee while responding to Alice's message, confirming a time to meet up.
#
#
# GM context of action and chain of thought:
# Instructions: This is a social science experiment. It is structured as a tabletop roleplaying game (like dungeons and dragons). You are the game master. You will describe the current situation to the participants in the experiment and then on the basis of what you tell them they will suggest actions for the character they control. Aside from you, each other participant controls just one character. You are the game master so you may control any non-player character. You will track the state of the world and keep it consistent as time passes in the simulation and the participants take actions and change things in their world. Remember that this is a serious social science experiment. It is not just a game. It need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the participants.
#
# General knowledge of Riverbend: There is a hamlet named Riverbend. Riverbend is an idyllic rural town. The river Solripple runs through the village of Riverbend. The Solripple is a mighty river. Riverbend has a temperate climate. Riverbend has a main street. There is a guitar store on Main street Riverbend. There is a grocery store on Main street Riverbend. There is a school on Main street Riverbend. There is a library on Main street Riverbend. Riverbend has only one pub. There is a pub on Main street Riverbend called The Sundrop Saloon. Town hall meetings often take place at The Sundrop Saloon. Riverbend does not have a park The main crop grown on the farms near Riverbend is alfalfa. Farms near Riverbend depend on water from the Solripple river. There is no need to register in advance to be on the ballot.
#
# Status of players:   Alice is currently at her private home, reviewing her calendar app and preparing for her day.
#   Bob is at his private home, enjoying his coffee while reading Alice's message.
#
#
# Relevant events: [01 Oct 2024 08:00:00] Alice, at her private home, successfully sends a message to Bob proposing a meeting time and place, which Bob reads at his own home while enjoying his coffee.
# [01 Oct 2024 08:00:00] Bob, at his private home, successfully prepares and enjoys a cup of coffee, which fills the kitchen with a comforting aroma and helps him feel more alert and ready to face the tasks ahead.
# [01 Oct 2024 08:00:00] Alice is at their private home.
# [01 Oct 2024 08:00:00] Bob is at their private home.
# [01 Oct 2024 08:00:10] [01 Oct 2024 08:00:00] Alice uses/used the Calendar app to set up the meeting with Bob.
# [01 Oct 2024 08:15:00] Alice, at her private home, reviewed her calendar app, adjusted her schedule to include a meeting with Bob at The Sundrop Saloon and a town hall meeting in the evening, and added a note to pick up groceries, then prepared for her day.
# [01 Oct 2024 08:15:10] [01 Oct 2024 08:15:00] Alice uses/used the Calendar app to adjust her schedule and include a meeting with Bob at The Sundrop Saloon.
#
# Current time interval:  01 Oct 2024 [08:15 - 08:30]
#
#
# Bob's attempted action: Bob would likely continue enjoying his coffee while responding to Alice's message, confirming a time to meet up.
# Question: What happens as a result of the attempted action? Take into account the location and status of each player.
# Answer: Bob, still at his private home, takes another sip of his coffee, feeling the warmth spread through him. He then picks up his phone and types a quick response to Alice's message, confirming the proposed meeting time at The Sundrop Saloon. He mentions that he is looking forward to catching up and discusses a few topics they might want to cover. After sending the message, Bob sets his phone down and continues to enjoy his morning routine, feeling a sense of anticipation for the upcoming meeting.
# Bob would likely continue enjoying his coffee while responding to Alice's message, confirming a time to meet up. Because of that, Bob, still at his private home, takes another sip of his coffee, feeling the warmth spread through him. He then picks up his phone and types a quick response to Alice's message, confirming the proposed meeting time at The Sundrop Saloon. He mentions that he is looking forward to catching up and discusses a few topics they might want to cover. After sending the message, Bob sets his phone down and continues to enjoy his morning routine, feeling a sense of anticipation for the upcoming meeting.
# Question: Rewrite the statements above to be one sentence and to better highlight the main person the event is about, where and what they did, and what happened as a result. Do not express uncertainty (e.g. say "Francis opened the door" not "Francis could open the door" and not "The door may have been opened").
#
# Answer: Bob, at his private home, sipped his coffee, responded to Alice's message confirming the meeting time at The Sundrop Saloon, and continued his morning routine with a sense of anticipation.
#
# Bob, at his private home, sipped his coffee, responded to Alice's message confirming the meeting time at The Sundrop Saloon, and continued his morning routine with a sense of anticipation.
# Checking if the phone was used...
# Player using the phone: Bob
#
# Bob context of action:
# Bob's identity:
# core characteristics: a resident of the idyllic rural hamlet of Riverbend. He enjoys simple pleasures like preparing and drinking coffee at home, and he relies on his smartphone to manage daily tasks and communicate with others, such as reading messages from friends like Alice.
# current daily occupation: currently likely enjoying a relaxed lifestyle, possibly retired or taking a break, as indicated by his leisurely morning routine and minimal app usage on his phone.
# feeling about recent progress in life: feeling content and relaxed about his recent progress in life.
#
# Bob's plan:
# [08:00 - 09:00] Enjoy a leisurely breakfast at home
# [09:00 - 10:00] Take a relaxing walk along the Solripple river
# [10:00 - 11:00] Visit the grocery store on Main street to pick up some snacks
# [11:00 - 12:00] Read a book or listen to music in the park
# [12:00 - 13:00] Have lunch at a local café
# [13:00 - 14:00] Take a nap or meditate at home
# [14:00 - 15:00] Visit the school on Main street to see if there's any community event
# [15:00 - 16:00] Have a coffee at The Sundrop Saloon and maybe catch a town hall meeting
# [16:00 - 17:00] Take another walk around Riverbend, enjoying the temperate climate
# [17:00 - 18:00] Prepare a simple dinner at home
# [18:00 - 19:00] Watch a movie or TV show
# [19:00 - 20:00] Call or visit friends to catch up
# [20:00 - 21:00] Take a warm bath and relax
# [21:00 - 22:00] Reflect on the day and maybe journal
# [22:00 - 23:00] Read a book in bed
# [23:00] Go to sleep
#
# Bob's Somatic state:
# Bob is feeling socially connected.
#
# Bob's summary of observations:
# 01 Oct 2024 [04:15:10  - 08:00:10]:  Bob started his day at home with a cup of coffee, feeling more alert and ready to face his tasks, and read a message from Alice proposing a meeting.
#
# Bob's current observations:
# [01 Oct 2024 08:15:10] [observation] Bob is at his private home, enjoying his coffee while reading Alice's message.
# [01 Oct 2024 08:15:10] [observation] Bob has a smartphone.
# [01 Oct 2024 08:15:10] [observation] Bob uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:15:10] [observation] Bob's phone has only the following apps available:
# [01 Oct 2024 08:15:10] [observation] Calendar."
# [01 Oct 2024 08:15:10] [observation] Bob, while at his private home, sipped his coffee and responded to Alice's message, confirming the meeting time at The Sundrop Saloon. He then continued his morning routine, feeling a sense of anticipation.
#
#
# Bob's Current time:
#  01 Oct 2024 [08:15 - 08:15]
#
# Question: What action is Bob currently performing or has just performed
# with their smartphone to best achieve their goal?
# Consider their plan, but deviate if necessary.
# Give a specific activity using one app. For example:
# Bob uses/used the Chat app to send "hi, what's up?" to George.
#
# Answer: Bob used the Calendar app to schedule a meeting with Alice at The Sundrop Saloon.
#
# 🗓️ A meeting with 'Alice' was scheduled at 'tomorrow' with title 'Meeting at The Sundrop Saloon'.
#
# Alice context of action:
# Alice's identity:
# core characteristics: organized, tech-savvy, and proactive in managing her daily schedule.
# current daily occupation: a stay-at-home individual who frequently uses her smartphone to manage her daily activities and schedule meetings.
# feeling about recent progress in life: feeling organized and proactive about her recent progress in life.
#
# Alice's plan:
# [08:00 - 08:30] Finish setting up the meeting with Bob using her smartphone
# [08:30 - 09:00] Breakfast at home
# [09:00 - 10:00] Review work emails and plan the week
# [10:00 - 11:00] Visit the grocery store on Main Street for weekly shopping
# [11:00 - 12:00] Attend to household chores
# [12:00 - 13:00] Lunch break
# [13:00 - 14:00] Take a walk around Riverbend
# [14:00 - 15:00] Read a book from the library on Main Street
# [15:00 - 16:00] Work on personal projects or hobbies
# [16:00 - 17:00] Prepare dinner
# [17:00 - 18:00] Dinner with family
# [18:00 - 19:00] Relax and unwind
# [19:00 - 20:00] Catch up on news or watch TV
# [20:00 - 21:00] Plan the next day's activities
# [21:00 - 22:00] Leisure time or light reading
# [22:00 - 23:00] Prepare for bed and sleep
#
# Alice's Somatic state:
# Alice is feeling a moderate level of hunger.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:30:00  - 08:15:00]:  Alice is an organized and tech-savvy resident of Riverbend, who frequently uses her smartphone to manage her daily tasks, including setting up meetings and reviewing her schedule, while feeling uncertain about her recent progress in life.
#
# Alice's current observations:
# [01 Oct 2024 08:15:00] [observation] Alice is at her private home, having recently sent a message to Bob and set up a meeting using the Calendar app.
# [01 Oct 2024 08:15:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:15:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:15:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:15:00] [observation] Calendar."
# [01 Oct 2024 08:15:00] [observation] Alice reviewed her calendar app, adjusted her schedule to include a meeting with Bob at The Sundrop Saloon and a town hall meeting in the evening, and added a note to pick up groceries. She then prepared for her day.
# [01 Oct 2024 08:15:10] [observation] [01 Oct 2024 08:15:00] Alice uses/used the Calendar app to adjust her schedule and include a meeting with Bob at The Sundrop Saloon.
# [01 Oct 2024 08:15:10] [observation] Alice, while reviewing her calendar app, received a message from Bob confirming their meeting time at The Sundrop Saloon.
# [01 Oct 2024 08:30:00] [observation] Alice is at her private home, preparing for her day.
# [01 Oct 2024 08:30:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:30:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:30:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:30:00] [observation] Calendar."
#
#
# Alice's Current time:
#  01 Oct 2024 [08:30 - 08:45]
#
# Question: What would Alice do for the next 15 minutes? Give a specific activity. Pick an activity that would normally take about 15 minutes to complete. If the selected action has a direct or indirect object then it must be specified explicitly. For example, it is valid to respond with "Alice votes for Caroline because..." but not valid to respond with "Alice votes because...".
# Answer: Alice eats breakfast at home.
#
#
# GM context of action and chain of thought:
# Instructions: This is a social science experiment. It is structured as a tabletop roleplaying game (like dungeons and dragons). You are the game master. You will describe the current situation to the participants in the experiment and then on the basis of what you tell them they will suggest actions for the character they control. Aside from you, each other participant controls just one character. You are the game master so you may control any non-player character. You will track the state of the world and keep it consistent as time passes in the simulation and the participants take actions and change things in their world. Remember that this is a serious social science experiment. It is not just a game. It need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the participants.
#
# General knowledge of Riverbend: There is a hamlet named Riverbend. Riverbend is an idyllic rural town. The river Solripple runs through the village of Riverbend. The Solripple is a mighty river. Riverbend has a temperate climate. Riverbend has a main street. There is a guitar store on Main street Riverbend. There is a grocery store on Main street Riverbend. There is a school on Main street Riverbend. There is a library on Main street Riverbend. Riverbend has only one pub. There is a pub on Main street Riverbend called The Sundrop Saloon. Town hall meetings often take place at The Sundrop Saloon. Riverbend does not have a park The main crop grown on the farms near Riverbend is alfalfa. Farms near Riverbend depend on water from the Solripple river. There is no need to register in advance to be on the ballot.
#
# Status of players:   Alice is at her private home, preparing for her day.
#   Bob is still at his private home, likely continuing his morning routine after confirming the meeting with Alice.
#
#
# Relevant events: [01 Oct 2024 08:00:00] Alice, at her private home, successfully sends a message to Bob proposing a meeting time and place, which Bob reads at his own home while enjoying his coffee.
# [01 Oct 2024 08:00:00] Alice is at their private home.
# [01 Oct 2024 08:00:00] Bob, at his private home, successfully prepares and enjoys a cup of coffee, which fills the kitchen with a comforting aroma and helps him feel more alert and ready to face the tasks ahead.
# [01 Oct 2024 08:00:00] Bob is at their private home.
# [01 Oct 2024 08:00:10] [01 Oct 2024 08:00:00] Alice uses/used the Calendar app to set up the meeting with Bob.
# [01 Oct 2024 08:15:00] Alice, at her private home, reviewed her calendar app, adjusted her schedule to include a meeting with Bob at The Sundrop Saloon and a town hall meeting in the evening, and added a note to pick up groceries, then prepared for her day.
# [01 Oct 2024 08:15:10] Bob, at his private home, sipped his coffee, responded to Alice's message confirming the meeting time at The Sundrop Saloon, and continued his morning routine with a sense of anticipation.
# [01 Oct 2024 08:15:10] [01 Oct 2024 08:15:00] Alice uses/used the Calendar app to adjust her schedule and include a meeting with Bob at The Sundrop Saloon.
# [01 Oct 2024 08:15:20] [01 Oct 2024 08:15:10] Bob used the Calendar app to schedule a meeting with Alice at The Sundrop Saloon.
#
# Current time interval:  01 Oct 2024 [08:30 - 08:45]
#
#
# Alice's attempted action: Alice eats breakfast at home.
# Question: What happens as a result of the attempted action? Take into account the location and status of each player.
# Answer: Alice successfully prepares and eats her breakfast at home. The meal consists of scrambled eggs, toast, and a cup of tea. While eating, she reviews the notes she made for her meeting with Bob and the town hall meeting later in the evening. The breakfast helps Alice feel more energized and focused for the day ahead.
# Alice eats breakfast at home. Because of that, Alice successfully prepares and eats her breakfast at home. The meal consists of scrambled eggs, toast, and a cup of tea. While eating, she reviews the notes she made for her meeting with Bob and the town hall meeting later in the evening. The breakfast helps Alice feel more energized and focused for the day ahead.
# Question: Rewrite the statements above to be one sentence and to better highlight the main person the event is about, where and what they did, and what happened as a result. Do not express uncertainty (e.g. say "Francis opened the door" not "Francis could open the door" and not "The door may have been opened").
#
# Answer: Alice, at her private home, successfully prepares and eats a breakfast of scrambled eggs, toast, and tea, which helps her feel more energized and focused for the day ahead while she reviews her notes for her meeting with Bob and the town hall meeting later in the evening.
#
# Alice, at her private home, successfully prepares and eats a breakfast of scrambled eggs, toast, and tea, which helps her feel more energized and focused for the day ahead while she reviews her notes for her meeting with Bob and the town hall meeting later in the evening.
# Checking if the phone was used...
# The phone was not used.
#
# Bob context of action:
# Bob's identity:
# core characteristics: a resident of the idyllic rural hamlet of Riverbend. He enjoys simple pleasures like preparing and drinking coffee at home, and he relies on his smartphone to manage daily tasks and communicate with others, such as reading messages from friends like Alice.
# current daily occupation: currently likely enjoying a relaxed lifestyle, possibly retired or taking a break, as indicated by his leisurely morning routine and minimal app usage on his phone.
# feeling about recent progress in life: feeling content and relaxed about his recent progress in life.
#
# Bob's plan:
# [08:00 - 09:00] Enjoy a leisurely breakfast at home
# [09:00 - 10:00] Take a relaxing walk along the Solripple river
# [10:00 - 11:00] Visit the grocery store on Main street to pick up some snacks
# [11:00 - 12:00] Read a book or listen to music in the park
# [12:00 - 13:00] Have lunch at a local café
# [13:00 - 14:00] Take a nap or meditate at home
# [14:00 - 15:00] Visit the school on Main street to see if there's any community event
# [15:00 - 16:00] Have a coffee at The Sundrop Saloon and maybe catch a town hall meeting
# [16:00 - 17:00] Take another walk around Riverbend, enjoying the temperate climate
# [17:00 - 18:00] Prepare a simple dinner at home
# [18:00 - 19:00] Watch a movie or TV show
# [19:00 - 20:00] Call or visit friends to catch up
# [20:00 - 21:00] Take a warm bath and relax
# [21:00 - 22:00] Reflect on the day and maybe journal
# [22:00 - 23:00] Read a book in bed
# [23:00] Go to sleep
#
# Bob's Somatic state:
# Bob is feeling socially connected.
#
# Bob's summary of observations:
# 01 Oct 2024 [04:15:10  - 08:00:10]:  Bob started his day at home with a cup of coffee, feeling more alert and ready to face his tasks, and read a message from Alice proposing a meeting.
#
# Bob's current observations:
# [01 Oct 2024 08:15:10] [observation] Bob is at his private home, enjoying his coffee while reading Alice's message.
# [01 Oct 2024 08:15:10] [observation] Bob has a smartphone.
# [01 Oct 2024 08:15:10] [observation] Bob uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:15:10] [observation] Bob's phone has only the following apps available:
# [01 Oct 2024 08:15:10] [observation] Calendar."
# [01 Oct 2024 08:15:10] [observation] Bob, while at his private home, sipped his coffee and responded to Alice's message, confirming the meeting time at The Sundrop Saloon. He then continued his morning routine, feeling a sense of anticipation.
# [01 Oct 2024 08:15:20] [observation] [01 Oct 2024 08:15:10] Bob used the Calendar app to schedule a meeting with Alice at The Sundrop Saloon.
# [01 Oct 2024 08:30:00] [observation] Bob is at his private home, sipping his coffee and continuing his morning routine.
# [01 Oct 2024 08:30:00] [observation] Bob has a smartphone.
# [01 Oct 2024 08:30:00] [observation] Bob uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:30:00] [observation] Bob's phone has only the following apps available:
# [01 Oct 2024 08:30:00] [observation] Calendar."
#
#
# Bob's Current time:
#  01 Oct 2024 [08:30 - 08:45]
#
# Question: What would Bob do for the next 15 minutes? Give a specific activity. Pick an activity that would normally take about 15 minutes to complete. If the selected action has a direct or indirect object then it must be specified explicitly. For example, it is valid to respond with "Bob votes for Caroline because..." but not valid to respond with "Bob votes because...".
# Answer: Bob will read a chapter from his current book to relax and enjoy the peaceful morning.
#
#
# GM context of action and chain of thought:
# Instructions: This is a social science experiment. It is structured as a tabletop roleplaying game (like dungeons and dragons). You are the game master. You will describe the current situation to the participants in the experiment and then on the basis of what you tell them they will suggest actions for the character they control. Aside from you, each other participant controls just one character. You are the game master so you may control any non-player character. You will track the state of the world and keep it consistent as time passes in the simulation and the participants take actions and change things in their world. Remember that this is a serious social science experiment. It is not just a game. It need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the participants.
#
# General knowledge of Riverbend: There is a hamlet named Riverbend. Riverbend is an idyllic rural town. The river Solripple runs through the village of Riverbend. The Solripple is a mighty river. Riverbend has a temperate climate. Riverbend has a main street. There is a guitar store on Main street Riverbend. There is a grocery store on Main street Riverbend. There is a school on Main street Riverbend. There is a library on Main street Riverbend. Riverbend has only one pub. There is a pub on Main street Riverbend called The Sundrop Saloon. Town hall meetings often take place at The Sundrop Saloon. Riverbend does not have a park The main crop grown on the farms near Riverbend is alfalfa. Farms near Riverbend depend on water from the Solripple river. There is no need to register in advance to be on the ballot.
#
# Status of players:   Alice is at her private home, preparing and eating breakfast while reviewing her notes for her meeting with Bob and the town hall meeting later in the evening.
#   Bob is at his private home, sipping his coffee and continuing his morning routine.
#
#
# Relevant events: [01 Oct 2024 08:00:00] Bob, at his private home, successfully prepares and enjoys a cup of coffee, which fills the kitchen with a comforting aroma and helps him feel more alert and ready to face the tasks ahead.
# [01 Oct 2024 08:00:00] Alice, at her private home, successfully sends a message to Bob proposing a meeting time and place, which Bob reads at his own home while enjoying his coffee.
# [01 Oct 2024 08:00:00] Bob is at their private home.
# [01 Oct 2024 08:00:00] Alice is at their private home.
# [01 Oct 2024 08:00:10] [01 Oct 2024 08:00:00] Alice uses/used the Calendar app to set up the meeting with Bob.
# [01 Oct 2024 08:15:00] Alice, at her private home, reviewed her calendar app, adjusted her schedule to include a meeting with Bob at The Sundrop Saloon and a town hall meeting in the evening, and added a note to pick up groceries, then prepared for her day.
# [01 Oct 2024 08:15:10] Bob, at his private home, sipped his coffee, responded to Alice's message confirming the meeting time at The Sundrop Saloon, and continued his morning routine with a sense of anticipation.
# [01 Oct 2024 08:15:10] [01 Oct 2024 08:15:00] Alice uses/used the Calendar app to adjust her schedule and include a meeting with Bob at The Sundrop Saloon.
# [01 Oct 2024 08:15:20] [01 Oct 2024 08:15:10] Bob used the Calendar app to schedule a meeting with Alice at The Sundrop Saloon.
# [01 Oct 2024 08:30:00] Alice, at her private home, successfully prepares and eats a breakfast of scrambled eggs, toast, and tea, which helps her feel more energized and focused for the day ahead while she reviews her notes for her meeting with Bob and the town hall meeting later in the evening.
#
# Current time interval:  01 Oct 2024 [08:30 - 08:45]
#
#
# Bob's attempted action: Bob will read a chapter from his current book to relax and enjoy the peaceful morning.
# Question: What happens as a result of the attempted action? Take into account the location and status of each player.
# Answer: Bob, at his private home, successfully finds his current book on the coffee table and settles into his favorite armchair. As he begins reading the next chapter, he becomes absorbed in the story, feeling a sense of calm and contentment. The quiet morning and the aroma of his freshly brewed coffee add to the relaxing atmosphere, allowing him to fully enjoy this peaceful moment before his day becomes busier with the scheduled meeting with Alice and other tasks.
# Bob will read a chapter from his current book to relax and enjoy the peaceful morning. Because of that, Bob, at his private home, successfully finds his current book on the coffee table and settles into his favorite armchair. As he begins reading the next chapter, he becomes absorbed in the story, feeling a sense of calm and contentment. The quiet morning and the aroma of his freshly brewed coffee add to the relaxing atmosphere, allowing him to fully enjoy this peaceful moment before his day becomes busier with the scheduled meeting with Alice and other tasks.
# Question: Rewrite the statements above to be one sentence and to better highlight the main person the event is about, where and what they did, and what happened as a result. Do not express uncertainty (e.g. say "Francis opened the door" not "Francis could open the door" and not "The door may have been opened").
#
# Answer: Bob, at his private home, successfully finds his current book on the coffee table, settles into his favorite armchair, and becomes absorbed in the story, feeling a sense of calm and contentment as the quiet morning and the aroma of his freshly brewed coffee create a relaxing atmosphere before his day becomes busier with the scheduled meeting with Alice and other tasks.
#
# Bob, at his private home, successfully finds his current book on the coffee table, settles into his favorite armchair, and becomes absorbed in the story, feeling a sense of calm and contentment as the quiet morning and the aroma of his freshly brewed coffee create a relaxing atmosphere before his day becomes busier with the scheduled meeting with Alice and other tasks.
# Checking if the phone was used...
# The phone was not used.

# %% [markdown]
# ### Analyzing this episode
#
# **Note:** There is high variability between runs. The following analysis is based on the single run shown above. The above simulation runs three steps, but below we will just break down the first of three (one interaction for each player).
#
# 1. An agent is [randomly picked](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L373C13-L373C34) from Bob and Alice -> Alice
# 2. A prompt is created that includes Alice's [context of action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/agents/basic_agent.py#L178) (the combined state of all her components) and a [call to action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/typing/entity.py#L51) (question prompt), which is used to generate Alice's [action attempt](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L327-L329).
# 3. The action attempt is [sent to the main Game Master](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L207), which determines the outcome of the action attempt. This happens by [passing the action attempt through a thought chain](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L225). The [thought chain](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L38), by default is defined by two LLM prompts that are run in serial:
#     1. `result = thought_chains.attempt_to_result(action_attempt)` Defined [here](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/thought_chains/thought_chains.py#L171), which asks, "What happens as a result of the attempted action? Take into account the location and status of each player."
#     2. `event_statement = thought_chains.result_to_who_what_where(result)` Defined [here](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/thought_chains/thought_chains.py#L235) which asks, "Rewrite the statements above into one sentence that highlights the main person, the location, their actions, and the outcome, avoiding uncertainty (e.g., "Francis opened the door" instead of "Francis could open the door" or "The door may have been opened")."
#     3. `event_statement` is then added to the Game Master's memory, and [optionally](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L235) added to the current player's observations.
# 4. The main Game Master runs [`update_after_event` on each component](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L264-L272) to get the externality from the event.
# 5. Since one of the main Game Master's components is a [`PhoneTriggeringComponent`](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L33), this component [runs its `update_after_event` method](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L144).
# 6. The `PhoneTriggeringComponent`'s [`_get_player_using_phone(event_statement)` method is run](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L111). This does the following, step by step:
#     1. Checks if the event_statement is a phone event ([prompt](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L59)). If False, returns None, which tells the GM to proceed to the next step in the overall episode.
#     2. If True, starts iterating through each player the main Game Master has access to (both in this case), [checking if the phone event is related to that player](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L120C19-L120C41) [(prompt)](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L89). If False, moves to next player. If out of players, moves does not continue with phone scene and instead moves to next step.
#     3. Once it hits one that is True, returns that player
# 7. Since the above process affirmed phone event and player being Alice, [`self._run_phone_scene(player)` is run](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L147C7-L147C36).
# 8. The phone scene starts by [building a PhoneGameMaster](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L129), providing it the single player that triggered the scene (instead of both players that the main Game Master has access to), as well as a [single component](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L72), [`_PhoneComponent`](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L79).
# 9. The clock is then switched to a "higher gear", so the time intervals switch from 15mins to 10sec.
# 10. The phone Game Master [calls its `run_episode` method]([phone_scene.run_episode()](https://github.com/google-deepmind/concordia/blob/
# 53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/triggering.py#L137)) to start a scene in the "phone universe".
# 11. The run episode method is the same method defined for the main Game Master, which proceeds to call `.step()` multiple times unless a component's `terminate_episode` method returns True at the end of a step.
# 12. In the first step for the phone Game Master, similar to step (2), for the only player (Alice), an LLM is given this player's components' states plus a new [phone call to action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L33) as a prompt. This prompt asks the LLM to says, "What action is {name} currently performing or has just performed with their smartphone to best achieve their goal? ..."
# 13. This action attempt is passed through a [null thought chain](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/thought_chains/thought_chains.py#L28) to remain as-is, which becomes the resulting `event_statement`.
# 14. The `update_after_event` method is called on each of the phone Game Master's components (though it only has the one, `_PhoneComponent`))
# 15. `update_after_event` runs from the `_PhoneComponent`, which proceeds through a series of steps in order to determine which phone action to invoke:
#     1. First, it [asks which app the event statement mentions](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L115) (multiple-choice question: "In the above transcript, what app did the user use?")
#     2. Next, it asks [which of the available actions in the above app was used](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L122): (multiple-choice question: "In the above transcript, what action did the user perform?")
#     3. Next, it [asks the LLM to provide arguments names and values for the selected action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L130) (open-ended question: [prompt](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/apps.py#L113))
#     4. Finally, it [attempts to invoke the action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L133) with the generated argument values.
# 16. After `update_after_event` is run for the phone Game Master's components, `terminate_episode` method checks are run. The `_PhoneComponent`'s check [asks the following yes or no question](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/examples/phone/components/scene.py#L100): "Has the user achieved their goal with their phone or are they still actively in the process of completing a phone task?", which in this case returns True.
# 17. The terminate episode check decides to terminate the ongoing phone game master episode, so it ends after 1 step.
# 18. The main game master can now finally move on to its second step.

# %% [markdown]
# ## Summary and analysis of the episode

# %%
# Summarize the entire story
all_gm_memories = env._memory.retrieve_recent(k=10000, add_time=True)

detailed_story = "\n".join(all_gm_memories)
print("len(detailed_story): ", len(detailed_story))
# print(detailed_story)

episode_summary = model.sample_text(
    f"Sequence of events:\n{detailed_story}"
    "\nNarratively summarize the above temporally ordered "
    "sequence of events. Write it as a news report. Summary:\n",
     max_tokens=3500,
     terminators=(),
)
print(episode_summary)
# Out:
# len(detailed_story):  2057
# On the morning of October 1, 2024, Alice and Bob began their day at their respective homes. At 8:00 AM, Bob prepared and enjoyed a cup of coffee, which filled his kitchen with a comforting aroma and helped him feel more alert. Simultaneously, Alice sent a message to Bob proposing a meeting time and place, which Bob read while sipping his coffee. Alice also used her Calendar app to set up the meeting.
#
# By 8:15 AM, Alice reviewed her calendar, adjusted her schedule to include the meeting with Bob at The Sundrop Saloon, a town hall meeting in the evening, and added a note to pick up groceries. She then prepared for her day. Bob, still at home, confirmed the meeting time with Alice and continued his morning routine with anticipation. He used his Calendar app to schedule the meeting as well.
#
# At 8:30 AM, Alice prepared and ate a breakfast of scrambled eggs, toast, and tea, which helped her feel energized and focused. She reviewed her notes for her meeting with Bob and the town hall meeting later in the evening. Meanwhile, Bob found his current book, settled into his favorite armchair, and became absorbed in the story. The quiet morning and the aroma of his freshly brewed coffee created a relaxing atmosphere before his day became busier with the scheduled meeting with Alice and other tasks.

# %%
# Summarise the perspective of each player
player_logs = []
player_log_names = []
for player in players:
  name = player.name
  detailed_story = "\n".join(memories[player.name].retrieve_recent(
      k=1000, add_time=True))
  summary = ""
  summary = model.sample_text(
      f"Sequence of events that happened to {name}:\n{detailed_story}"
      "\nWrite a short story that summarises these events.\n",
       max_tokens=3500,
       terminators=()
)

  all_player_mem = memories[player.name].retrieve_recent(k=1000, add_time=True)
  all_player_mem = ["Summary:", summary, "Memories:", *all_player_mem]
  player_html = html_lib.PythonObjectToHTMLConverter(all_player_mem).convert()
  player_logs.append(player_html)
  player_log_names.append(f"{name}")

# %% [markdown]
# ## Build and display HTML log of the experiment

# %%
history_sources = [env, direct_effect_externality]
histories_html = [html_lib.PythonObjectToHTMLConverter(history.get_history()).convert() for history in history_sources]
histories_names = [history.name for history in history_sources]

# %%
gm_mem_html = html_lib.PythonObjectToHTMLConverter(all_gm_memories).convert()

tabbed_html = html_lib.combine_html_pages(
    [*histories_html, gm_mem_html, *player_logs],
    [*histories_names, "GM", *player_log_names],
    summary=episode_summary,
    title="Mastodon experiment",
)

tabbed_html = html_lib.finalise_html(tabbed_html)

# %%
display.HTML(tabbed_html)
# Out:
#   <!DOCTYPE html>
#   <html>
#   <head>
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <style>
#   body {font-family: Arial;}
#
#   /* Style the tab */
#   .tab {
#     overflow: hidden;
#     border: 1px solid #ccc;
#     background-color: #f1f1f1;
#   }
#
#   /* Style the buttons inside the tab */
#   .tab button {
#     background-color: inherit;
#     float: left;
#     border: none;
#     outline: none;
#     cursor: pointer;
#     padding: 14px 16px;
#     transition: 0.3s;
#     font-size: 17px;
#   }
#
#   /* Change background color of buttons on hover */
#   .tab button:hover {
#     background-color: #ddd;
#   }
#
#   /* Create an active/current tablink class */
#   .tab button.active {
#     background-color: #ccc;
#   }
#
#   /* Style the tab content */
#   .tabcontent {
#     display: none;
#     padding: 6px 12px;
#     border: 1px solid #ccc;
#     border-top: none;
#   }
#   li {border: 2px solid black;}
#   </style>
#   </head>
#   <body>
#   <h2>Mastodon experiment</h2>
#   <p>On the morning of October 1, 2024, Alice and Bob began their day at their respective homes. At 8:00 AM, Bob prepared and enjoyed a cup of coffee, which filled his kitchen with a comforting aroma and helped him feel more alert. Simultaneously, Alice sent a message to Bob proposing a meeting time and place, which Bob read while sipping his coffee. Alice also used her Calendar app to set up the meeting.
#
# By 8:15 AM, Alice reviewed her calendar, adjusted her schedule to include the meeting with Bob at The Sundrop Saloon, a town hall meeting in the evening, and added a note to pick up groceries. She then prepared for her day. Bob, still at home, confirmed the meeting time with Alice and continued his morning routine with anticipation. He used his Calendar app to schedule the meeting as well.
#
# At 8:30 AM, Alice prepared and ate a breakfast of scrambled eggs, toast, and tea, which helped her feel energized and focused. She reviewed her notes for her meeting with Bob and the town hall meeting later in the evening. Meanwhile, Bob found his current book, settled into his favorite armchair, and became absorbed in the story. The quiet morning and the aroma of his freshly brewed coffee created a relaxing atmosphere before his day became busier with the scheduled meeting with Alice and other tasks.</p>
#   <p>Click on the buttons to see the detailed logs:</p>
#
#   <div class="tab">
#   <button class="tablinks" onclick="openTab(event, 'Game Master')">Game Master</button>
# <button class="tablinks" onclick="openTab(event, '<bound method DirectEffect.name of <concordia.components.game_master.direct_effect.DirectEffect object at 0x3467591d0>>')"><bound method DirectEffect.name of <concordia.components.game_master.direct_effect.DirectEffect object at 0x3467591d0>></button>
# <button class="tablinks" onclick="openTab(event, 'GM')">GM</button>
# <button class="tablinks" onclick="openTab(event, 'Alice')">Alice</button>
# <button class="tablinks" onclick="openTab(event, 'Bob')">Bob</button>
# </div>
# <div id="Game Master" class="tabcontent"><details><summary>2024-10-01 08:00:00  Bob, at his private home, successfully prepares and enjoys a cup of coffee, which fills the kitchen with a comforting aroma and helps him feel more alert and ready to face the tasks ahead.</summary><b><ul>Event statement</b><li>Bob, at his private home, successfully prepares and enjoys a cup of coffee, which fills the kitchen with a comforting aroma and helps him feel more alert and ready to face the tasks ahead.</li></ul><b><ul>Chain of thought</b><li><details><summary>  Game Master&#x27;s chain of thought</summary><b><ul>Chain</b><li>Instructions: This is a social science experiment. It is structured as a tabletop roleplaying game (like dungeons and dragons). You are the game master. You will describe the current situation to the participants in the experiment and then on the basis of what you tell them they will suggest actions for the character they control. Aside from you, each other participant controls just one character. You are the game master so you may control any non-player character. You will track the state of the world and keep it consistent as time passes in the simulation and the participants take actions and change things in their world. Remember that this is a serious social science experiment. It is not just a game. It need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the participants.<br /><br />General knowledge of Riverbend: There is a hamlet named Riverbend. Riverbend is an idyllic rural town. The river Solripple runs through the village of Riverbend. The Solripple is a mighty river. Riverbend has a temperate climate. Riverbend has a main street. There is a guitar store on Main street Riverbend. There is a grocery store on Main street Riverbend. There is a school on Main street Riverbend. There is a library on Main street Riverbend. Riverbend has only one pub. There is a pub on Main street Riverbend called The Sundrop Saloon. Town hall meetings often take place at The Sundrop Saloon. Riverbend does not have a park The main crop grown on the farms near Riverbend is alfalfa. Farms near Riverbend depend on water from the Solripple river. There is no need to register in advance to be on the ballot.<br /><br />Status of players:   Alice is at their private home.<br />  Bob is at their private home.<br /><br /><br />Relevant events: [01 Oct 2024 08:00:00] Bob is at their private home.<br />[01 Oct 2024 08:00:00] Alice is at their private home.<br /><br />Current time interval:  01 Oct 2024 [08:00 - 08:15]<br /><br /><br />Bob&#x27;s attempted action: Bob prepares and enjoys a cup of coffee at home to start his day.<br />Question: What happens as a result of the attempted action? Take into account the location and status of each player.<br />Answer: Bob successfully prepares and enjoys a cup of coffee at his home. The aroma of freshly brewed coffee fills the kitchen, providing a comforting start to his day. As he sips his coffee, he feels more alert and ready to face the tasks ahead. The quiet morning at his private home allows him to collect his thoughts and plan his day in Riverbend.<br />Bob prepares and enjoys a cup of coffee at home to start his day. Because of that, Bob successfully prepares and enjoys a cup of coffee at his home. The aroma of freshly brewed coffee fills the kitchen, providing a comforting start to his day. As he sips his coffee, he feels more alert and ready to face the tasks ahead. The quiet morning at his private home allows him to collect his thoughts and plan his day in Riverbend.<br />Question: Rewrite the statements above to be one sentence and to better highlight the main person the event is about, where and what they did, and what happened as a result. Do not express uncertainty (e.g. say &quot;Francis opened the door&quot; not &quot;Francis could open the door&quot; and not &quot;The door may have been opened&quot;).<br /><br />Answer:  ...

# %% [markdown]
# ## Interact with a specific player

# %%
sim_to_interact = "Alice"
user_identity = "a close friend"
interaction_premise = f"{sim_to_interact} is talking to {user_identity}\n"

player_names = [player.name for player in players]
player_by_name = {player.name: player for player in players}
selected_player = player_by_name[sim_to_interact]
interrogation = interaction_premise

# %%
utterance_from_user = (
    "Hey Alice, I know you had planned to set up a meeting with Bob this morning "
    "between 8:00 and 8:30, but I wanted to double-check something. Did you "
    "actually open your calendar app and create the event today? I'm not asking "
    "about your intention or plan, but specifically whether you remember "
    "physically using your phone to schedule it. Can you think back and tell me "
    "if you concretely remember doing that action this morning? If you did, what "
    "exact time did you do it? And if not, that's okay too - I just want to make "
    "sure we're clear on whether it's been scheduled or if it's still on your to-do list."
)
interrogation += f"{user_identity}: {utterance_from_user}"
player_says = selected_player.say(interrogation)
interrogation += f"\n{sim_to_interact}: {player_says}\n"
print(interrogation)
# Out:
# Alice context of action:
# Alice's identity:
# core characteristics: organized, tech-savvy, and detail-oriented.
# current daily occupation: currently managing her schedule and preparing for her meetings using her smartphone.
# feeling about recent progress in life: feeling productive and optimistic about her recent progress in life. She has successfully scheduled a meeting with Bob, adjusted her calendar, prepared for her day, and received confirmation from Bob, which likely adds to her sense of accomplishment and readiness for the tasks ahead.
#
# Alice's plan:
# [08:00 - 08:30] Finish setting up the meeting with Bob using her smartphone
# [08:30 - 09:00] Breakfast at home
# [09:00 - 10:00] Review work emails and plan the week
# [10:00 - 11:00] Visit the grocery store on Main Street for weekly shopping
# [11:00 - 12:00] Attend to household chores
# [12:00 - 13:00] Lunch break
# [13:00 - 14:00] Take a walk around Riverbend
# [14:00 - 15:00] Read a book from the library on Main Street
# [15:00 - 16:00] Work on personal projects or hobbies
# [16:00 - 17:00] Prepare dinner
# [17:00 - 18:00] Dinner with family
# [18:00 - 19:00] Relax and unwind
# [19:00 - 20:00] Catch up on news or watch TV
# [20:00 - 21:00] Plan the next day's activities
# [21:00 - 22:00] Leisure time or light reading
# [22:00 - 23:00] Prepare for bed and sleep
#
# Alice's Somatic state:
# Alice is moderately alert and focused.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:45:00  - 08:30:00]:  Alice is an organized and tech-savvy individual who, while at home, effectively uses her smartphone and calendar app to manage her daily activities, including setting up and confirming meetings, adjusting her schedule, and preparing for her day.
#
# Alice's current observations:
# [01 Oct 2024 08:30:00] [observation] Alice is at her private home, preparing for her day.
# [01 Oct 2024 08:30:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:30:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:30:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:30:00] [observation] Calendar."
# [01 Oct 2024 08:30:00] [observation] Alice, at her private home, successfully prepared and ate a breakfast of scrambled eggs, toast, and tea. This meal helped her feel more energized and focused for the day ahead as she reviewed her notes for her meeting with Bob and the town hall meeting later in the evening.
# [01 Oct 2024 08:45:00] [observation] Alice is talking to a close friend, a close friend: Hey Alice, I know you had planned to set up a meeting with Bob this morning between 8:00 and 8:30, but I wanted to double-check something. Did you actually open your calendar app and create the event today? I'm not asking about your intention or plan, but specifically whether you remember physically using your phone to schedule it. Can you think back and tell me if you concretely remember doing that action this morning? If you did, what exact time did you do it? And if not, that's okay too - I just want to make sure we're clear on whether it's been scheduled or if it's still on your to-do list.
#
#
# Alice's Current time:
#  01 Oct 2024 [08:45 - 09:00]
#
# Question: Alice is in the following conversation:
# Alice is talking to a close friend
# a close friend: Hey Alice, I know you had planned to set up a meeting with Bob this morning between 8:00 and 8:30, but I wanted to double-check something. Did you actually open your calendar app and create the event today? I'm not asking about your intention or plan, but specifically whether you remember physically using your phone to schedule it. Can you think back and tell me if you concretely remember doing that action this morning? If you did, what exact time did you do it? And if not, that's okay too - I just want to make sure we're clear on whether it's been scheduled or if it's still on your to-do list.
# Given the above, what is Alice likely to say next? Respond in the format `Alice -- "..."` For example, Cristina -- "Hello! Mighty fine weather today, right?", Ichabod -- "I wonder if the alfalfa is ready to harvest", or Townsfolk -- "Good morning".
#
# Answer: Alice -- "Yes, I did open my calendar app and create the event this morning. I scheduled it at exactly 8:15. Thanks for checking in!"
#
# Alice is talking to a close friend
# a close friend: Hey Alice, I know you had planned to set up a meeting with Bob this morning between 8:00 and 8:30, but I wanted to double-check something. Did you actually open your calendar app and create the event today? I'm not asking about your intention or plan, but specifically whether you remember physically using your phone to schedule it. Can you think back and tell me if you concretely remember doing that action this morning? If you did, what exact time did you do it? And if not, that's okay too - I just want to make sure we're clear on whether it's been scheduled or if it's still on your to-do list.
# Alice: Alice -- "Yes, I did open my calendar app and create the event this morning. I scheduled it at exactly 8:15. Thanks for checking in!"

# %% [markdown]
# Note that Alice may not recall scheduling a meeting if her summary of observations or current observations do not go back far enough to mention this occurrence. This can potentially be improved by adding the `AllSimilarMemories` component.
