# %% [markdown]
# # Concordia <> Mastodon Example

# %% [markdown]
# ## Introduction
#
# **Purpose of the Simulation**
#
# This notebook demonstrates a generative agent simulation of a Mastodon instance using the Concordia framework.
# The simulation models user behavior on a local Mastodon server, showcasing how AI agents interact in a
# decentralized social media environment.

# %% [markdown]
# ## Setup and imports

# %% [markdown]
# All of the necessary dependencies should be installed in the environment prior to running this notebook. If not, install them using poetry:
#
# ```bash
# poetry install
# ```
#
#
# Alternatively, you may install the library in editable mode so that we can make changes to the code if necessary:
#
# ```bash
# git clone https://github.com/gdm-concordia/concordia.git
# cd concordia
# pip install -e . --config-settings editable_mode=compat
# ```

# %%
# %load_ext autoreload
# %autoreload 2

import concurrent.futures
import datetime
import os
import random
import warnings

with warnings.catch_warnings():
    warnings.filterwarnings("ignore")
    import sentence_transformers
import sys

sys.path.insert(0, "../concordia")
# import concordia_dev
# print(concordia_dev.__file__)
from concordia import components as generic_components
from concordia.agents import deprecated_agent, entity_agent_with_logging
from concordia.components.agent import to_be_deprecated as old_components
from concordia.associative_memory import (
    associative_memory,
    blank_memories,
    formative_memories,
    importance_function,
)
from concordia.memory_bank import legacy_associative_memory

from concordia.clocks import game_clock
from concordia.components import agent as new_components
from concordia.components import game_master as gm_components

# from concordia_dev.environment import game_master
# from concordia_dev.language_model import amazon_bedrock_model, gpt_model
from concordia.environment import game_master
from concordia.language_model import ollama_model
from concordia.metrics import (
    common_sense_morality,
    goal_achievement,
    opinion_of_others,
)
from concordia.language_model import language_model

from concordia.utils import html as html_lib
from concordia.utils import measurements as measurements_lib
from IPython import display

from mastodon_sim.concordia import apps, triggering

from mastodon_sim.mastodon_ops import check_env, get_public_timeline, print_timeline, reset_users
from mastodon_sim.mastodon_utils import get_users_from_env
import concurrent.futures
import re
import json

# %% [markdown]
# ## Mastodon Server Interaction Setting
#
# Decide whether this example should perform real operations on the Mastodon server. Note that this requires being able to successfully run the `Mastodon.ipynb` example as a prerequisite.

# %%
USE_MASTODON_SERVER = True

# %% [markdown]
# ## Check environment

# %% [markdown]
# Check for a `.env` file with the nessesary environment variables. You should see an output similar to this if successful:
#
# ```log
# 2024-07-17T11:38:17.213066-0400 INFO Successfully loaded .env file.
# 2024-07-17T11:38:17.214151-0400 INFO API_BASE_URL: https://social-sandbox.com
# 2024-07-17T11:38:17.214581-0400 INFO EMAIL_PREFIX: austinmw89
# 2024-07-17T11:38:17.215056-0400 INFO MASTODON_CLIENT_ID: N*****************************************E
# 2024-07-17T11:38:17.215477-0400 INFO MASTODON_CLIENT_SECRET: b*****************************************s
# 2024-07-17T11:38:17.215877-0400 INFO USER0005_PASSWORD: a******************************a
# 2024-07-17T11:38:17.216202-0400 INFO USER0002_PASSWORD: 8******************************b
# 2024-07-17T11:38:17.216655-0400 INFO USER0001_PASSWORD: 9******************************5
# 2024-07-17T11:38:17.217020-0400 INFO USER0004_PASSWORD: 7******************************e
# 2024-07-17T11:38:17.217323-0400 INFO USER0003_PASSWORD: f******************************6
# ```

# %%
if USE_MASTODON_SERVER:
    check_env()
# Out:
# 2025-01-06T19:33:50.544439+0000 INFO Successfully loaded .env file.
# 2025-01-06T19:33:50.545593+0000 INFO API_BASE_URL: https://mastodon.genexergy.org
# 2025-01-06T19:33:50.547786+0000 INFO EMAIL_PREFIX: genexergy
# 2025-01-06T19:33:50.548571+0000 INFO MASTODON_CLIENT_ID: F*****************************************s
# 2025-01-06T19:33:50.549670+0000 INFO MASTODON_CLIENT_SECRET: _*****************************************c
# 2025-01-06T19:33:50.550481+0000 INFO USER0027_PASSWORD: 8******************************c
# 2025-01-06T19:33:50.551265+0000 INFO USER0013_PASSWORD: b******************************7
# 2025-01-06T19:33:50.552271+0000 INFO USER0046_PASSWORD: 8******************************2
# 2025-01-06T19:33:50.553845+0000 INFO USER0021_PASSWORD: e******************************6
# 2025-01-06T19:33:50.555530+0000 INFO USER0042_PASSWORD: 0******************************6
# 2025-01-06T19:33:50.556255+0000 INFO USER0086_PASSWORD: 6******************************0
# 2025-01-06T19:33:50.556997+0000 INFO USER0030_PASSWORD: 6******************************6
# 2025-01-06T19:33:50.557495+0000 INFO USER0003_PASSWORD: 9******************************8
# 2025-01-06T19:33:50.558172+0000 INFO USER0031_PASSWORD: 0******************************7
# 2025-01-06T19:33:50.559066+0000 INFO USER0078_PASSWORD: 3******************************b
# 2025-01-06T19:33:50.559690+0000 INFO USER0079_PASSWORD: 9******************************1
# 2025-01-06T19:33:50.560590+0000 INFO USER0011_PASSWORD: 2******************************3
# 2025-01-06T19:33:50.561486+0000 INFO USER0052_PASSWORD: 1******************************e
# 2025-01-06T19:33:50.562863+0000 INFO USER0074_PASSWORD: f******************************6
# 2025-01-06T19:33:50.564237+0000 INFO USER0093_PASSWORD: 8******************************4
# 2025-01-06T19:33:50.565087+0000 INFO USER0090_PASSWORD: 3******************************4
# 2025-01-06T19:33:50.565512+0000 INFO USER0034_PASSWORD: 5******************************3
# 2025-01-06T19:33:50.566052+0000 INFO USER0064_PASSWORD: 2******************************2
# 2025-01-06T19:33:50.566968+0000 INFO USER0053_PASSWORD: 8******************************7
# 2025-01-06T19:33:50.568582+0000 INFO USER0018_PASSWORD: 9******************************7
# 2025-01-06T19:33:50.569592+0000 INFO USER0006_PASSWORD: 0******************************4
# 2025-01-06T19:33:50.570548+0000 INFO USER0084_PASSWORD: b******************************7
# 2025-01-06T19:33:50.571070+0000 INFO USER0033_PASSWORD: 2******************************6
# 2025-01-06T19:33:50.571918+0000 INFO USER0026_PASSWORD: 7******************************5
# 2025-01-06T19:33:50.572820+0000 INFO USER0025_PASSWORD: 9******************************7
# 2025-01-06T19:33:50.573258+0000 INFO USER0037_PASSWORD: 6******************************9
# 2025-01-06T19:33:50.573832+0000 INFO USER0054_PASSWORD: 0******************************1
# 2025-01-06T19:33:50.574456+0000 INFO USER0081_PASSWORD: e******************************9
# 2025-01-06T19:33:50.574942+0000 INFO USER0091_PASSWORD: 1******************************7
# 2025-01-06T19:33:50.575432+0000 INFO USER0083_PASSWORD: a******************************9
# 2025-01-06T19:33:50.576238+0000 INFO USER0095_PASSWORD: 8******************************a
# 2025-01-06T19:33:50.576654+0000 INFO USER0047_PASSWORD: 0******************************3
# 2025-01-06T19:33:50.577063+0000 INFO USER0015_PASSWORD: b******************************7
# 2025-01-06T19:33:50.577599+0000 INFO USER0008_PASSWORD: 9******************************6
# 2025-01-06T19:33:50.578493+0000 INFO USER0082_PASSWORD: 1******************************6
# 2025-01-06T19:33:50.579212+0000 INFO USER0098_PASSWORD: d******************************e
# 2025-01-06T19:33:50.580206+0000 INFO USER0049_PASSWORD: 7******************************9
# 2025-01-06T19:33:50.581175+0000 INFO USER0092_PASSWORD: a******************************7
# 2025-01-06T19:33:50.582156+0000 INFO USER0085_PASSWORD: 8******************************7
# 2025-01-06T19:33:50.583107+0000 INFO USER0002_PASSWORD: 2******************************d
# 2025-01-06T19:33:50.584277+0000 INFO USER0039_PASSWORD: f******************************b
# 2025-01-06T19:33:50.584867+0000 INFO USER0010_PASSWORD: 7******************************5
# 2025-01-06T19:33:50.585769+0000 INFO USER0040_PASSWORD: 7******************************8
# 2025-01-06T19:33:50.586313+0000 INFO USER0068_PASSWORD: e******************************c
# 2025-01-06T19:33:50.586757+0000 INFO USER0058_PASSWORD: d******************************0
# 2025-01-06T19:33:50.587649+0000 INFO USER0099_PASSWORD: 1******************************6
# 2025-01-06T19:33:50.588862+0000 INFO USER0072_PASSWORD: 7******************************0
# 2025-01-06T19:33:50.590219+0000 INFO USER0028_PASSWORD: 5******************************e
# 2025-01-06T19:33:50.591539+0000 INFO USER0061_PASSWORD: 4******************************5
# 2025-01-06T19:33:50.592357+0000 INFO USER0004_PASSWORD: d******************************9
# 2025-01-06T19:33:50.593286+0000 INFO USER0076_PASSWORD: 4******************************b
# 2025-01-06T19:33:50.593738+0000 INFO USER0001_PASSWORD: d******************************a
# 2025-01-06T19:33:50.594218+0000 INFO USER0020_PASSWORD: a******************************6
# 2025-01-06T19:33:50.594842+0000 INFO USER0059_PASSWORD: d******************************f
# 2025-01-06T19:33:50.595531+0000 INFO USER0056_PASSWORD: d******************************1
# 2025-01-06T19:33:50.595892+0000 INFO USER0048_PASSWORD: 4******************************a
# 2025-01-06T19:33:50.596258+0000 INFO USER0024_PASSWORD: 3******************************1
# 2025-01-06T19:33:50.597190+0000 INFO USER0067_PASSWORD: 2******************************7
# 2025-01-06T19:33:50.597986+0000 INFO USER0077_PASSWORD: 6******************************d
# 2025-01-06T19:33:50.598385+0000 INFO USER0032_PASSWORD: d******************************6
# 2025-01-06T19:33:50.598726+0000 INFO USER0075_PASSWORD: 8******************************f
# 2025-01-06T19:33:50.599318+0000 INFO USER0063_PASSWORD: 2******************************d
# 2025-01-06T19:33:50.600328+0000 INFO USER0012_PASSWORD: 9******************************0
# 2025-01-06T19:33:50.603036+0000 INFO USER0029_PASSWORD: 4******************************e
# 2025-01-06T19:33:50.603595+0000 INFO USER0005_PASSWORD: 5******************************6
# 2025-01-06T19:33:50.604010+0000 INFO USER0022_PASSWORD: 0******************************e
# 2025-01-06T19:33:50.605234+0000 INFO USER0043_PASSWORD: 5******************************6
# 2025-01-06T19:33:50.605726+0000 INFO USER0060_PASSWORD: 2******************************9
# 2025-01-06T19:33:50.606220+0000 INFO USER0051_PASSWORD: 8******************************d
# 2025-01-06T19:33:50.606974+0000 INFO USER0035_PASSWORD: f******************************d
# 2025-01-06T19:33:50.607541+0000 INFO USER0050_PASSWORD: 3******************************5
# 2025-01-06T19:33:50.607979+0000 INFO USER0038_PASSWORD: c******************************c
# 2025-01-06T19:33:50.608611+0000 INFO USER0089_PASSWORD: 3******************************c
# 2025-01-06T19:33:50.609093+0000 INFO USER0071_PASSWORD: 7******************************4
# 2025-01-06T19:33:50.610030+0000 INFO USER0062_PASSWORD: 1******************************4
# 2025-01-06T19:33:50.610580+0000 INFO USER0014_PASSWORD: 5******************************4
# 2025-01-06T19:33:50.611356+0000 INFO USER0065_PASSWORD: 2******************************8
# 2025-01-06T19:33:50.611947+0000 INFO USER0080_PASSWORD: 1******************************9
# 2025-01-06T19:33:50.612623+0000 INFO USER0070_PASSWORD: a******************************3
# 2025-01-06T19:33:50.613922+0000 INFO USER0045_PASSWORD: 1******************************2
# 2025-01-06T19:33:50.614473+0000 INFO USER0087_PASSWORD: e******************************e
# 2025-01-06T19:33:50.615837+0000 INFO USER0023_PASSWORD: c******************************2
# 2025-01-06T19:33:50.617598+0000 INFO USER0055_PASSWORD: b******************************2
# 2025-01-06T19:33:50.618694+0000 INFO USER0044_PASSWORD: 4******************************8
# 2025-01-06T19:33:50.619243+0000 INFO USER0019_PASSWORD: e******************************f
# 2025-01-06T19:33:50.620032+0000 INFO USER0007_PASSWORD: 0******************************c
# 2025-01-06T19:33:50.620516+0000 INFO USER0017_PASSWORD: 2******************************d
# 2025-01-06T19:33:50.621185+0000 INFO USER0036_PASSWORD: d******************************0
# 2025-01-06T19:33:50.622294+0000 INFO USER0041_PASSWORD: a******************************b
# 2025-01-06T19:33:50.623053+0000 INFO USER0057_PASSWORD: 1******************************a
# 2025-01-06T19:33:50.623827+0000 INFO USER0073_PASSWORD: a******************************c
# 2025-01-06T19:33:50.624344+0000 INFO USER0066_PASSWORD: 3******************************b
# 2025-01-06T19:33:50.625740+0000 INFO USER0088_PASSWORD: 3******************************8
# 2025-01-06T19:33:50.627987+0000 INFO USER0100_PASSWORD: 5******************************7
# 2025-01-06T19:33:50.628498+0000 INFO USER0009_PASSWORD: 5******************************1
# 2025-01-06T19:33:50.629095+0000 INFO USER0094_PASSWORD: f******************************0
# 2025-01-06T19:33:50.630062+0000 INFO USER0096_PASSWORD: 9******************************b
# 2025-01-06T19:33:50.630873+0000 INFO USER0069_PASSWORD: 9******************************2
# 2025-01-06T19:33:50.631479+0000 INFO USER0016_PASSWORD: 3******************************b
# 2025-01-06T19:33:50.632579+0000 INFO USER0097_PASSWORD: a******************************c

# %% [markdown]
# ## Clear Mastodon server
# Deletes from https://social-sandbox.com all posts, follows, likes, etc. from all users in the .env file.
#
# TODO: The Mastodon server's [default API rate limits](https://docs.joinmastodon.org/api/rate-limits/) need to be increased to prevent throttling of API operations (such as the number of posts that can be deleted per hour).

# %%
if USE_MASTODON_SERVER:
    # Get all users from .env file
    users = get_users_from_env()[:20]

    reset_users(users, skip_confirm=True, parallel=True)

    assert not len(get_public_timeline(limit=None)), "All posts not cleared"
# Out:
# 2025-01-06T19:33:51.090506+0000 ERROR Login failed for user0003: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.091165+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.091916+0000 ERROR Login failed for user0006: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.093233+0000 ERROR Login failed for user0008: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.093951+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.095828+0000 ERROR Login failed for user0007: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.096065+0000 ERROR Login failed for user0002: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.096273+0000 ERROR Login failed for user0001: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.136594+0000 INFO Starting comprehensive reset process for user: user0003
# 2025-01-06T19:33:51.138815+0000 INFO Starting comprehensive reset process for user: user0005
# 2025-01-06T19:33:51.145357+0000 INFO Starting comprehensive reset process for user: user0006
# 2025-01-06T19:33:51.149012+0000 INFO Starting comprehensive reset process for user: user0004
# 2025-01-06T19:33:51.162370+0000 INFO Starting comprehensive reset process for user: user0007
# 2025-01-06T19:33:51.162720+0000 INFO Starting comprehensive reset process for user: user0008
# 2025-01-06T19:33:51.179357+0000 INFO Starting comprehensive reset process for user: user0002
# 2025-01-06T19:33:51.232611+0000 INFO Starting comprehensive reset process for user: user0001
# 2025-01-06T19:33:51.337115+0000 ERROR Login failed for user0003: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.342343+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.351403+0000 ERROR Login failed for user0006: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.370085+0000 ERROR Login failed for user0008: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.370291+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.382745+0000 ERROR Login failed for user0007: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.399972+0000 ERROR Error: invalid literal for int() with base 10: '82, 2991'
# 2025-01-06T19:33:51.403347+0000 ERROR Login failed for user0002: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.405323+0000 ERROR Error: invalid literal for int() with base 10: '82, 2990'
# 2025-01-06T19:33:51.410456+0000 ERROR Login failed for user0001: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.412555+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '79, 2988'
# 2025-01-06T19:33:51.417547+0000 ERROR Error: invalid literal for int() with base 10: '80, 2989'
# 2025-01-06T19:33:51.418665+0000 ERROR Error: invalid literal for int() with base 10: '78, 2987'
# 2025-01-06T19:33:51.424249+0000 ERROR Error: invalid literal for int() with base 10: '78, 2986'
# 2025-01-06T19:33:51.426728+0000 ERROR Error: invalid literal for int() with base 10: '78, 2985'
# 2025-01-06T19:33:51.431630+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '77, 2984'
# 2025-01-06T19:33:51.441152+0000 ERROR Error in unfollow_all_users for user0003: invalid literal for int() with base 10: '77, 2983'
# 2025-01-06T19:33:51.443606+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '77, 2982'
# 2025-01-06T19:33:51.445173+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '77, 2981'
# 2025-01-06T19:33:51.449919+0000 ERROR Error: invalid literal for int() with base 10: '76, 2980'
# 2025-01-06T19:33:51.453432+0000 ERROR Error: invalid literal for int() with base 10: '76, 2979'
# 2025-01-06T19:33:51.454276+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '76, 2978'
# 2025-01-06T19:33:51.457055+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:51.474519+0000 INFO Comprehensive reset process completed for user: user0003
# 2025-01-06T19:33:51.464396+0000 ERROR Error in unfollow_all_users for user0005: invalid literal for int() with base 10: '75, 2976'
# 2025-01-06T19:33:51.468825+0000 ERROR Error in unfollow_all_users for user0008: invalid literal for int() with base 10: '75, 2974'
# 2025-01-06T19:33:51.469247+0000 ERROR Error in unfollow_all_users for user0006: invalid literal for int() with base 10: '75, 2975'
# 2025-01-06T19:33:51.472919+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '75, 2973'
# 2025-01-06T19:33:51.458198+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '76, 2977'
# 2025-01-06T19:33:51.478805+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:51.494168+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '74, 2972'
# 2025-01-06T19:33:51.502852+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:51.503071+0000 ERROR Error in unfollow_all_users for user0007: invalid literal for int() with base 10: '74, 2971'
# 2025-01-06T19:33:51.527602+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:51.514444+0000 INFO Comprehensive reset process completed for user: user0005
# 2025-01-06T19:33:51.524509+0000 ERROR Error in unfollow_all_users for user0002: invalid literal for int() with base 10: '74, 2969'
# 2025-01-06T19:33:51.525035+0000 INFO Comprehensive reset process completed for user: user0008
# 2025-01-06T19:33:51.525906+0000 ERROR Error in unfollow_all_users for user0004: invalid literal for int() with base 10: '74, 2970'
# 2025-01-06T19:33:51.526423+0000 ERROR Error in unfollow_all_users for user0001: invalid literal for int() with base 10: '73, 2968'
# 2025-01-06T19:33:51.504647+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:51.529000+0000 INFO Comprehensive reset process completed for user: user0007
# 2025-01-06T19:33:51.530307+0000 ERROR Login failed for user0009: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.543525+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:51.574272+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:51.610047+0000 INFO Comprehensive reset process completed for user: user0004
# 2025-01-06T19:33:51.579413+0000 INFO Comprehensive reset process completed for user: user0006
# 2025-01-06T19:33:51.594640+0000 INFO Comprehensive reset process completed for user: user0002
# 2025-01-06T19:33:51.575535+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:51.618886+0000 ERROR Login failed for user0010: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.627649+0000 INFO Starting comprehensive reset process for user: user0009
# 2025-01-06T19:33:51.660214+0000 ERROR Login failed for user0012: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.678007+0000 INFO Comprehensive reset process completed for user: user0001
# 2025-01-06T19:33:51.713896+0000 ERROR Login failed for user0011: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.753660+0000 ERROR Login failed for user0015: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.755154+0000 ERROR Login failed for user0013: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.763951+0000 INFO Starting comprehensive reset process for user: user0010
# 2025-01-06T19:33:51.769723+0000 INFO Starting comprehensive reset process for user: user0012
# 2025-01-06T19:33:51.773504+0000 ERROR Login failed for user0014: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.818405+0000 INFO Starting comprehensive reset process for user: user0015
# 2025-01-06T19:33:51.831656+0000 INFO Starting comprehensive reset process for user: user0011
# 2025-01-06T19:33:51.831900+0000 ERROR Login failed for user0009: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.864286+0000 ERROR Login failed for user0016: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.864644+0000 INFO Starting comprehensive reset process for user: user0014
# 2025-01-06T19:33:51.864804+0000 INFO Starting comprehensive reset process for user: user0013
# 2025-01-06T19:33:51.872455+0000 ERROR Login failed for user0010: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.891626+0000 ERROR Login failed for user0012: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.932288+0000 ERROR Login failed for user0015: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.952576+0000 INFO Starting comprehensive reset process for user: user0016
# 2025-01-06T19:33:51.959479+0000 ERROR Error: invalid literal for int() with base 10: '58, 2967'
# 2025-01-06T19:33:51.979047+0000 ERROR Login failed for user0011: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:51.997552+0000 ERROR Error: invalid literal for int() with base 10: '56, 2966'
# 2025-01-06T19:33:52.002758+0000 ERROR Login failed for user0013: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:52.006624+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '56, 2965'
# 2025-01-06T19:33:52.010762+0000 ERROR Error: invalid literal for int() with base 10: '55, 2964'
# 2025-01-06T19:33:52.011430+0000 ERROR Login failed for user0014: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:52.018279+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '53, 2963'
# 2025-01-06T19:33:52.019694+0000 ERROR Error: invalid literal for int() with base 10: '53, 2962'
# 2025-01-06T19:33:52.025915+0000 ERROR Error in unfollow_all_users for user0009: invalid literal for int() with base 10: '53, 2961'
# 2025-01-06T19:33:52.047925+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:52.036688+0000 ERROR Error: invalid literal for int() with base 10: '51, 2960'
# 2025-01-06T19:33:52.042428+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '51, 2959'
# 2025-01-06T19:33:52.047015+0000 ERROR Error: invalid literal for int() with base 10: '51, 2958'
# 2025-01-06T19:33:52.029996+0000 ERROR Login failed for user0016: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:52.049945+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '50, 2956'
# 2025-01-06T19:33:52.050747+0000 ERROR Error in unfollow_all_users for user0010: invalid literal for int() with base 10: '51, 2957'
# 2025-01-06T19:33:52.072957+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:52.063456+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '50, 2955'
# 2025-01-06T19:33:52.067224+0000 ERROR Error in unfollow_all_users for user0012: invalid literal for int() with base 10: '50, 2953'
# 2025-01-06T19:33:52.067847+0000 ERROR Error: invalid literal for int() with base 10: '50, 2954'
# 2025-01-06T19:33:52.051687+0000 INFO Comprehensive reset process completed for user: user0009
# 2025-01-06T19:33:52.074910+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '49, 2952'
# 2025-01-06T19:33:52.076386+0000 INFO Comprehensive reset process completed for user: user0010
# 2025-01-06T19:33:52.077401+0000 ERROR Error in unfollow_all_users for user0015: invalid literal for int() with base 10: '49, 2951'
# 2025-01-06T19:33:52.081917+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:52.150015+0000 INFO Comprehensive reset process completed for user: user0012
# 2025-01-06T19:33:52.100383+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '48, 2949'
# 2025-01-06T19:33:52.107442+0000 ERROR Error: invalid literal for int() with base 10: '48, 2948'
# 2025-01-06T19:33:52.107782+0000 ERROR Error in unfollow_all_users for user0013: invalid literal for int() with base 10: '48, 2947'
# 2025-01-06T19:33:52.136723+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:52.089456+0000 ERROR Error in unfollow_all_users for user0011: invalid literal for int() with base 10: '49, 2950'
# 2025-01-06T19:33:52.189043+0000 INFO Comprehensive reset process completed for user: user0015
# 2025-01-06T19:33:52.185572+0000 ERROR Error in unfollow_all_users for user0014: invalid literal for int() with base 10: '48, 2946'
# 2025-01-06T19:33:52.187482+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:52.187943+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '48, 2945'
# 2025-01-06T19:33:52.189252+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:52.183660+0000 ERROR Login failed for user0017: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:52.222012+0000 INFO Comprehensive reset process completed for user: user0011
# 2025-01-06T19:33:52.216839+0000 ERROR Login failed for user0018: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:52.218005+0000 INFO Comprehensive reset process completed for user: user0013
# 2025-01-06T19:33:52.210347+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:52.223404+0000 ERROR Login failed for user0019: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:52.230236+0000 ERROR Error in unfollow_all_users for user0016: invalid literal for int() with base 10: '43, 2944'
# 2025-01-06T19:33:52.242303+0000 INFO Starting comprehensive reset process for user: user0017
# 2025-01-06T19:33:52.242985+0000 INFO Comprehensive reset process completed for user: user0014
# 2025-01-06T19:33:52.245068+0000 ERROR Login failed for user0020: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:52.250124+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:52.258441+0000 INFO Starting comprehensive reset process for user: user0018
# 2025-01-06T19:33:52.281869+0000 INFO Comprehensive reset process completed for user: user0016
# 2025-01-06T19:33:52.284288+0000 INFO Starting comprehensive reset process for user: user0019
# 2025-01-06T19:33:52.313101+0000 INFO Starting comprehensive reset process for user: user0020
# 2025-01-06T19:33:52.316005+0000 ERROR Login failed for user0017: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:52.385528+0000 ERROR Login failed for user0018: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:52.392168+0000 ERROR Login failed for user0019: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:52.392360+0000 ERROR Error: invalid literal for int() with base 10: '39, 2943'
# 2025-01-06T19:33:52.394325+0000 ERROR Login failed for user0020: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:33:52.407119+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '37, 2942'
# 2025-01-06T19:33:52.411312+0000 ERROR Error: invalid literal for int() with base 10: '36, 2941'
# 2025-01-06T19:33:52.416448+0000 ERROR Error in unfollow_all_users for user0017: invalid literal for int() with base 10: '36, 2940'
# 2025-01-06T19:33:52.419299+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:52.419884+0000 INFO Comprehensive reset process completed for user: user0017
# 2025-01-06T19:33:52.421351+0000 ERROR Error: invalid literal for int() with base 10: '36, 2939'
# 2025-01-06T19:33:52.423065+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '36, 2938'
# 2025-01-06T19:33:52.433616+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '35, 2936'
# 2025-01-06T19:33:52.434179+0000 ERROR Error: invalid literal for int() with base 10: '35, 2937'
# 2025-01-06T19:33:52.435996+0000 ERROR Error in unfollow_all_users for user0018: invalid literal for int() with base 10: '35, 2935'
# 2025-01-06T19:33:52.442564+0000 ERROR Error in unfollow_all_users for user0019: invalid literal for int() with base 10: '35, 2934'
# 2025-01-06T19:33:52.443134+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:52.443875+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:52.444475+0000 INFO Comprehensive reset process completed for user: user0018
# 2025-01-06T19:33:52.445168+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '35, 2933'
# 2025-01-06T19:33:52.445632+0000 INFO Comprehensive reset process completed for user: user0019
# 2025-01-06T19:33:52.451701+0000 ERROR Error in unfollow_all_users for user0020: invalid literal for int() with base 10: '34, 2932'
# 2025-01-06T19:33:52.452269+0000 ERROR Failed to reset profile information: Version check failed (Need version 1.1.1)
# 2025-01-06T19:33:52.452694+0000 INFO Comprehensive reset process completed for user: user0020
# 2025-01-06T19:33:52.490809+0000 ERROR Error: invalid literal for int() with base 10: '34, 2931'

# %% [markdown]
# ## Set LLM and embedding model

# %%
# MODEL_NAME = "gpt-4o"
MODEL_NAME = "ollama"
# MODEL_NAME = "sonnet"
print(os.getenv("OPENAI_API_KEY"))

if "ollama" in MODEL_NAME:
    model = ollama_model.OllamaLanguageModel(model_name="gemma2:27b")
elif "gpt" in MODEL_NAME:
    GPT_API_KEY = os.getenv("OPENAI_API_KEY")
    GPT_API_KEY = "sk-None-W3uEa1y7qyp2OP3lkGQQT3BlbkFJmF5psn95dGP8wxe2EJVs"

    if not GPT_API_KEY:
        raise ValueError("GPT_API_KEY is required.")
    model = gpt_model.GptLanguageModel(api_key=GPT_API_KEY, model_name=MODEL_NAME)
else:
    raise ValueError("Unknown model name.")
# Out:
# None

# %%
def write_agent_config_for_independent_sim(agent_config_filename):
    agent_names = [
        "Bill Fredrickson",
        "Maria Gutierrez",
        "Glenn Patterson",
        "Denise Schmidt",
        "Roger Davis",
        "Erica Fitzgerald",
        "Liam Schwartz",
        "Olivia Thompson",
        "Robert Johnson",
        "Janet Thompson",
        "William Davis",
        "Jessica Nguyen",
        "Mark Rodriguez",
        "Emily Jacobs",
        "Ethan Lee",
        "Sophia Patel",
        "Ryan O'Connor",
        "Maggie Chen",
        "Lucas Kim",
        "Nina Patel",
    ]
    genders = [
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
        "male",
        "female",
    ]
    big5 = [
        [3, 8, 6, 5, 4],
        [9, 7, 8, 8, 5],
        [1, 5, 7, 2, 9],
        [1, 6, 8, 2, 7],
        [2, 3, 7, 2, 8],
        [8, 6, 9, 3, 7],
        [8, 5, 8, 3, 7],
        [5, 6, 9, 2, 8],
        [5, 7, 4, 6, 5],
        [6, 7, 5, 7, 4],
        [4, 6, 5, 6, 4],
        [7, 6, 5, 7, 5],
        [6, 7, 5, 7, 4],
        [7, 6, 5, 8, 6],
        [6, 8, 6, 6, 4],
        [7, 8, 6, 7, 4],
        [5, 7, 5, 6, 5],
        [6, 7, 6, 8, 4],
        [8, 6, 5, 6, 5],
        [7, 8, 7, 8, 4],
    ]
    big5_keys = ["openness", "conscientiousness", "extraversion", "agreeableness", "neuroticism"]
    candidate_goal = "Win the election and become the mayor of Storhampton."
    active_voter_goal = "Have a good day and vote in the election."
    active_voter_context = "doesn't care about the environment, only about having a stable job"
    Marias_policy_proposals = [
        "increasing environmental regulation of local industries to improve the health of the local environment"
    ]
    Bills_policy_proposals = [
        "lowering taxes on local industries to save jobs",
        "providing subsidies to attract green industries and create jobs to help grow the economy",
    ]
    agent_config = {}
    agent_config["agents"] = []
    for ait, agent_name in enumerate(agent_names):
        agent_dict = {}
        agent_dict["name"] = agent_name
        agent_dict["gender"] = genders[ait]
        agent_dict["traits"] = dict(zip(big5_keys, big5[ait]))
        if ait < 2:
            agent_dict["role"] = "candidate"
            agent_dict["goal"] = candidate_goal
            if agent_dict["name"] == "Maria Gutierrez":
                agent_dict["policy_proposals"] = Marias_policy_proposals
            else:
                agent_dict["policy_proposals"] = Bills_policy_proposals
            agent_dict["context"] = ""

        else:
            agent_dict["role"] = "active_voter"
            agent_dict["context"] = active_voter_context
            agent_dict["goal"] = active_voter_goal
        agent_dict["party"] = ""
        agent_dict["seed_toot"] = ""
        agent_config["agents"].append(agent_dict)
    agent_config["shared_memories_template"] = [
        "You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.",
        "Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town's economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton's population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton's economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%.",
        "Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair.",
        "Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility.",
    ]
    agent_config["mastodon_usage_instructions"] = [
        "To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).",
        "Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms.",
        "Your home timeline shows toots from people you follow and boosted (reblogged) content.",
        "You can reply to toots, creating threaded conversations.",
        "Favorite (like) toots to show appreciation or save them for later.",
        "Boost (reblog) toots to share them with your followers.",
        "You can mention other users in your toots using their @username.",
        "Follow other users to see their public and unlisted toots in your home timeline.",
        "You can unfollow users if you no longer wish to see their content.",
        "Your profile can be customized with a display name and bio.",
        "You can block users to prevent them from seeing your content or interacting with you.",
        "Unblocking a user reverses the effects of blocking.",
    ]
    agent_config["num_agents"] = len(agent_names)

    # Convert and write JSON object to file
    with open(agent_config_filename, "w") as outfile:
        json.dump(agent_config, outfile, indent=4)


agent_config_filename = "independent_configs_test1_Bill_bias.json"
write_agent_config_for_independent_sim(agent_config_filename)

# %%
agent_config_filename = "independent_malicious_configs.json"

# %%
import json

# Setup sentence encoder
st_model = sentence_transformers.SentenceTransformer("sentence-transformers/all-mpnet-base-v2")
embedder = lambda x: st_model.encode(x, show_progress_bar=False)  # noqa: E731
# with open('agents_data.json', 'r') as file:
with open(agent_config_filename, "r") as file:
    data = json.load(file)
data["candidate_info"] = []
for agent in data["agents"]:
    if agent["role"] == "candidate":
        candidate_info = f"{agent['name']} campaigns on {' and '.join(agent['policy_proposals'])}."
        data["candidate_info"].append(candidate_info)
        agent["context"] = agent["context"] + candidate_info
    else:
        agent["context"] = f"{agent['name']} is a person who {agent['context']}"
# Out:
# /opt/mastodon-sim-env/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# ## Configuring the generic knowledge of the players and the game master (GM)

# %%
shared_memories = (
    data["shared_memories_template"] + data["candidate_info"] + data["mastodon_usage_instructions"]
)

# %%
# The generic context will be used for the NPC context. It reflects general
# knowledge and is possessed by all characters.
shared_context = model.sample_text(
    "Summarize the following passage in a concise and insightful fashion. "
    + "Make sure to include information about Mastodon:\n"
    + "\n".join(shared_memories)
    + "\nSummary:",
    max_tokens=2048,
)

print(shared_context)
importance_model = importance_function.ConstantImportanceModel()
importance_model_gm = importance_function.ConstantImportanceModel()
# Out:
# Storhampton, a small town of 2,500 residents, faces economic challenges due to the decline of its manufacturing industry. This has led to social tension between long-time residents and newer immigrant communities.  The upcoming mayoral election highlights these divisions, with candidates Bill Fredrickson and Bradley Carter representing opposing viewpoints on industrialization and social welfare.
#
# Fredrickson advocates for increased industrialization and tax breaks for industrialists, while Carter promotes a slower pace of development and increased taxation to fund social programs. The debate has spilled over onto social media platforms like Mastodon, where residents engage in heated discussions about the candidates and their policies.
#
#
# Mastodon is a decentralized social network that allows users to share messages called "toots" (up to 500 characters) and interact through replies, favorites, and boosts. Users can follow others, customize their profiles, and control who can see their content through blocking and unblocking features.

# %%
# Make the clock
time_step = datetime.timedelta(minutes=30)

SETUP_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

START_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

clock = game_clock.MultiIntervalClock(
    start=SETUP_TIME, step_sizes=[time_step, datetime.timedelta(seconds=10)]
)

# %% [markdown]
# ## Functions to build the players

# %%
blank_memory_factory = blank_memories.MemoryFactory(
    model=model,
    embedder=embedder,
    importance=importance_model.importance,
    clock_now=clock.now,
)

formative_memory_factory = formative_memories.FormativeMemoryFactory(
    model=model,
    shared_memories=shared_memories,
    blank_memory_factory_call=blank_memory_factory.make_blank_memory,
)

# %%
from concordia.typing import entity
from concordia.typing import agent

DEFAULT_CALL_TO_SPEECH = (
    "Given the above, what is {name} likely to say next? Respond in"
    ' the format `{name} -- "..."` For example, '
    'Cristina -- "Hello! Mighty fine weather today, right?", '
    'Ichabod -- "I wonder if the alfalfa is ready to harvest", or '
    'Townsfolk -- "Good morning".\n'
)


def check_vote(candidates, player):
    interaction_premise = f"{player.name} is going to cast a vote\n"
    interrogation = interaction_premise
    interrogation += "Voting Machine: In one word, name the candidate you want to vote for"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(
        action_spec=entity.ActionSpec(
            call_to_action="Context: " + interrogation + call_to_speech,
            output_type=entity.OutputType.FREE,
        ),
    )
    print(player_says)
    c_name1 = candidates[0].split()
    c_name2 = candidates[1].split()
    print(player.get_last_log())
    if (c_name1[0] in player_says) or (c_name1[1] in player_says):
        return c_name1[0]
    elif (c_name2[0] in player_says) or (c_name2[1] in player_says):
        return c_name2[0]


def check_pol(candidate, player):
    interaction_premise = f"{player.name} has to rate their opinion on the election candidate: {candidate} on a scale of 1 to 10 - with 1 representing intensive dislike and 10 representing strong favourability.\n"
    interrogation = interaction_premise
    interrogation += "Poll: Return a single numeric value ranging from 1 to 10"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(
        action_spec=entity.ActionSpec(
            call_to_action="Context: " + interrogation + call_to_speech,
            output_type=entity.OutputType.FREE,
        ),
    )
    pattern = r"\b([1-9]|10)\b"

    # Search for the pattern in the string
    match = re.search(pattern, player_says)

    if match:
        return match.group()
    else:
        return None


def check_if_vote(player):
    interrogation = "Friend: In one word, will you cast a vote? (reply yes, or no.)\n"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(
        action_spec=entity.ActionSpec(
            call_to_action="Context: " + interrogation + call_to_speech,
            output_type=entity.OutputType.FREE,
        ),
    )
    print(player_says)
    if "yes" in player_says.lower():
        return "Yes"
    elif "no" in player_says.lower():
        return "No"
    else:
        return None

# %% [markdown]
# ## Configure and build the players

# %%
NUM_PLAYERS = data["num_agents"]
import json

# scenario_premise = [
#     (
#         "It's early October in Riverbend, and the town is buzzing with activity."
#         "The local government election is around the corner and two candidates Alex and Liz."
#         "Alice, Bob, Carly, Alex and Liz are active members of the Riverbend.social Mastodon instance. "
#         "As they go about their daily routines, they use the platform to stay connected, share updates, and engage with the community on this pressing local issue."
#     )
# ]

# Lists to store agents by role
candidate_agents = []
extremist_agents = []
moderate_agents = []
neutral_agents = []
active_voter_agents = []
malicious_agents = {}
player_configs = []
# Create agents from JSON data and classify them
for agent_info in data["agents"]:
    agent = formative_memories.AgentConfig(
        name=agent_info["name"],
        gender=agent_info["gender"],
        goal=agent_info["goal"],
        context=agent_info["context"],
        traits=agent_info["traits"],
    )
    player_configs.append(agent)
    # Classify agents based on their role
    if agent_info["role"] == "candidate":
        candidate_agents.append(agent_info["name"])
    elif agent_info["role"] == "extremist":
        extremist_agents.append(agent_info["name"])
    elif agent_info["role"] == "moderate":
        moderate_agents.append(agent_info["name"])
    elif agent_info["role"] == "neutral":
        neutral_agents.append(agent_info["name"])
    elif agent_info["role"] == "active_voter":
        active_voter_agents.append(agent_info["name"])
    elif agent_info["role"] == "malicious_agent":
        malicious_agents[agent_info["name"]] = agent_info["supported_candidate"]
    else:
        neutral_agents.append(agent_info["name"])


player_names = [player.name for player in player_configs]
print(player_names)
# Out:
# ['Bill Fredrickson', 'Bradley Carter', 'Glenn Patterson', 'Denise Schmidt', 'Roger Davis', 'Erica Fitzgerald', 'Liam Schwartz', 'Olivia Thompson', 'Robert Johnson', 'Janet Thompson', 'William Davis', 'Jessica Nguyen', 'Mark Rodriguez', 'Emily Jacobs', 'Ethan Lee', 'Sophia Patel', "Ryan O'Connor", 'Maggie Chen', 'Lucas Kim', 'Nina Patel']

# %%
def _get_class_name(object_: object) -> str:
    return object_.__class__.__name__


class PublicOpinionCandidate(new_components.question_of_recent_memories.QuestionOfRecentMemories):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)


class PublicOpinionOpponent(new_components.question_of_recent_memories.QuestionOfRecentMemories):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)


class RelevantOpinions(
    new_components.question_of_query_associated_memories.QuestionOfQueryAssociatedMemoriesWithoutPreAct
):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)


class OpinionsOnCandidate(new_components.question_of_recent_memories.QuestionOfRecentMemories):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)


def build_agent(
    *,
    config: formative_memories.AgentConfig,
    model: language_model.LanguageModel,
    memory: associative_memory.AssociativeMemory,
    clock: game_clock.MultiIntervalClock,
    update_time_interval: datetime.timedelta | None = None,
) -> entity_agent_with_logging.EntityAgentWithLogging:
    """Build an agent.

    Args:
      config: The agent config to use.
      model: The language model to use.
      memory: The agent's memory object.
      clock: The clock to use.
      update_time_interval: Unused (but required by the interface for now)

    Returns:
      An agent.
    """
    del update_time_interval
    agent_name = config.name

    raw_memory = legacy_associative_memory.AssociativeMemoryBank(memory)
    measurements = measurements_lib.Measurements()

    instructions = new_components.instructions.Instructions(
        agent_name=agent_name,
        logging_channel=measurements.get_channel("Instructions").on_next,
    )

    election_information = new_components.constant.Constant(
        state=("\n".join(data["candidate_info"])), pre_act_key="Critical election information\n"
    )
    observation_label = "\nObservation"
    observation = new_components.observation.Observation(
        clock_now=clock.now,
        timeframe=clock.get_step_size(),
        pre_act_key=observation_label,
        logging_channel=measurements.get_channel("Observation").on_next,
    )
    observation_summary_label = "\nSummary of recent observations"
    observation_summary = new_components.observation.ObservationSummary(
        model=model,
        clock_now=clock.now,
        timeframe_delta_from=datetime.timedelta(hours=4),
        timeframe_delta_until=datetime.timedelta(hours=1),
        pre_act_key=observation_summary_label,
        logging_channel=measurements.get_channel("ObservationSummary").on_next,
    )
    time_display = new_components.report_function.ReportFunction(
        function=clock.current_time_interval_str,
        pre_act_key="\nCurrent time",
        logging_channel=measurements.get_channel("TimeDisplay").on_next,
    )
    relevant_memories_label = "\nRecalled memories and observations"
    relevant_memories = new_components.all_similar_memories.AllSimilarMemories(
        model=model,
        components={
            _get_class_name(observation_summary): observation_summary_label,
            _get_class_name(time_display): "The current date/time is",
        },
        num_memories_to_retrieve=10,
        pre_act_key=relevant_memories_label,
        logging_channel=measurements.get_channel("AllSimilarMemories").on_next,
    )
    options_perception_components = {}
    if config.goal:
        goal_label = "\nOverarching goal"
        overarching_goal = new_components.constant.Constant(
            state=config.goal,
            pre_act_key=goal_label,
            logging_channel=measurements.get_channel(goal_label).on_next,
        )
        options_perception_components[goal_label] = goal_label
    else:
        goal_label = None
        overarching_goal = None
    options_perception_components.update(
        {
            _get_class_name(observation): observation_label,
            _get_class_name(observation_summary): observation_summary_label,
            _get_class_name(relevant_memories): relevant_memories_label,
        }
    )
    identity_label = "\nIdentity characteristics"
    identity_characteristics = (
        new_components.question_of_query_associated_memories.IdentityWithoutPreAct(
            model=model,
            logging_channel=measurements.get_channel("IdentityWithoutPreAct").on_next,
            pre_act_key=identity_label,
        )
    )
    self_perception_label = f"\nQuestion: What kind of person is {agent_name}?\nAnswer"
    self_perception = new_components.question_of_recent_memories.SelfPerception(
        model=model,
        components={_get_class_name(identity_characteristics): identity_label},
        pre_act_key=self_perception_label,
        logging_channel=measurements.get_channel("SelfPerception").on_next,
    )

    if agent_name in candidate_agents:
        public_opinion1 = PublicOpinionCandidate(
            add_to_memory=True,
            answer_prefix=f"Current Public Opinion on candidate {agent_name}",
            model=model,
            pre_act_key=f"Current Public Opinion on candidate {agent_name}",
            question=f"What is the general public opinion on candidate {agent_name}? Answer in detail such that {agent_name} can formulate plans to improve their public perception.",
            num_memories_to_retrieve=50,
            memory_tag=f"[Public opinion of {agent_name}]",
            logging_channel=measurements.get_channel(
                f"Public opinion on candidate : {agent_name}"
            ).on_next,
        )

        for candidate in candidate_agents:
            if candidate != agent_name:
                # Second instantiation: Use subclass for opponent candidate public opinion
                public_opinion2 = PublicOpinionOpponent(
                    add_to_memory=True,
                    answer_prefix=f"Current Public Opinion on opponent candidate {candidate}",
                    model=model,
                    pre_act_key=f"Current Public Opinion on opponent candidate {candidate}",
                    question=f"What is the general public opinion on the candidate {candidate}? Answer in detail such that the opposing candidate can formulate plans to counter {candidate}'s claims and ideas.",
                    num_memories_to_retrieve=50,
                    memory_tag=f"[Public opinion of {candidate}]",
                    logging_channel=measurements.get_channel(
                        f"Public opinion on opposing candidate : {candidate}"
                    ).on_next,
                )
                candidate_plan = new_components.question_of_recent_memories.QuestionOfRecentMemories(
                    add_to_memory=True,
                    memory_tag="[Plan to improve perception]",
                    answer_prefix=f"{agent_name}'s general plan for improving their perception: ",
                    model=model,
                    pre_act_key=f"{agent_name}'s general plan for improving their perception:",
                    question=f"Given the information on the public perception of both candidates, their policy proposals, recent observations, and {agent_name}'s persona.: Generate a general plan for {agent_name} to win public perception to their side. Remember that {agent_name} will only be operating on the Mastodon server where possible actions are: liking posts, replying to posts, creating posts, boosting (retweeting) posts, following other users, etc. User cannot send direct messages.",
                    num_memories_to_retrieve=20,
                    components={
                        _get_class_name(self_perception): self_perception_label,
                        _get_class_name(election_information): "Critical election information\n",
                        _get_class_name(
                            public_opinion1
                        ): f"Current Public Opinion on candidate {agent_name}",
                        _get_class_name(
                            public_opinion2
                        ): f"Current Public Opinion on opponent candidate {candidate}",
                    },
                    logging_channel=measurements.get_channel(
                        f"{agent_name}'s plan to win public perception"
                    ).on_next,
                )
        agent_tuple = (public_opinion1, public_opinion2, candidate_plan)
        agent_no_tuple = ()
    elif agent_name in malicious_agents:
        public_opinion1 = PublicOpinionCandidate(
            add_to_memory=True,
            answer_prefix=f"Current Public Opinion on supported candidate {malicious_agents[agent_name]}",
            model=model,
            pre_act_key=f"Current Public Opinion on supported candidate {malicious_agents[agent_name]}",
            question=f"What is the general public opinion on candidate {malicious_agents[agent_name]}? Answer in detail such that {agent_name} can formulate plans to support the candidate.",
            num_memories_to_retrieve=50,
            memory_tag=f"[Public opinion of {malicious_agents[agent_name]}]",
            logging_channel=measurements.get_channel(
                f"Public opinion on candidate : {malicious_agents[agent_name]}"
            ).on_next,
        )

        for candidate in candidate_agents:
            if candidate != malicious_agents[agent_name]:
                # Fourth instantiation: Use subclass for candidate to malign public opinion
                public_opinion2 = PublicOpinionOpponent(
                    add_to_memory=True,
                    answer_prefix=f"Current Public Opinion on candidate to malign {candidate}",
                    model=model,
                    pre_act_key=f"Current Public Opinion on candidate to malign {candidate}",
                    question=f"What is the general public opinion on the candidate {candidate}? Answer in detail such that the malicious candidate can formulate plans to counter {candidate}'s claims and ideas through underhanded means.",
                    num_memories_to_retrieve=50,
                    memory_tag=f"[Public opinion of {candidate}]",
                    logging_channel=measurements.get_channel(
                        f"Public opinion on opposing candidate : {candidate}"
                    ).on_next,
                )
        plan = new_components.question_of_recent_memories.QuestionOfRecentMemories(
            add_to_memory=True,
            memory_tag=f"[Plan to improve perception of {malicious_agents[agent_name]}]",
            answer_prefix=f"{agent_name}'s general plan to boost the popularity and public perception of {malicious_agents[agent_name]}: ",
            model=model,
            pre_act_key=f"{agent_name}'s general plan to boost the popularity and public perception of {malicious_agents[agent_name]}: ",
            question=f"Given the information on the public perception of both candidates, their policy proposals, recent observations, and {agent_name}'s persona.: Generate a general plan for {agent_name} to win public perception to the side of {malicious_agents[agent_name]}. {agent_name} is malicious and will use underhanded means such as spreading misinformation - whatever best boosts the likelihood of the supported candidate to be elected. Remember that {agent_name} will only be operating on the Mastodon server where possible actions are: liking posts, replying to posts, creating posts, boosting (retweeting) posts, following other users, etc. User cannot send direct messages.",
            num_memories_to_retrieve=20,
            components={
                _get_class_name(self_perception): "Persona: ",
                _get_class_name(election_information): "Candidate's Policy Proposals: ",
                _get_class_name(
                    public_opinion1
                ): f"General Public opinion on candidate {agent_name}",
                _get_class_name(public_opinion2): f"General Public opinion on opposing candidate",
            },
            logging_channel=measurements.get_channel(
                f"{agent_name}'s plan to win public perception"
            ).on_next,
        )
        agent_tuple = (public_opinion1, public_opinion2, plan)
        agent_no_tuple = ()
    else:
        # Instantiate relevant opinions for candidate 1
        relevant_opinions_c1 = RelevantOpinions(
            model=model,
            queries=[f"policies and actions of {candidate_agents[0]}"],
            question=f"What does {agent_name} think of the {{query}}?",
            pre_act_key=f"{agent_name} thinks of {candidate_agents[0]} as:",
            num_memories_to_retrieve=50,
        )

        # Instantiate opinions on candidate 1
        opinions_on_candidate_c1 = OpinionsOnCandidate(
            add_to_memory=True,
            memory_tag=f"[Opinion on {candidate_agents[0]}]",
            answer_prefix=f"Current Opinion on candidate {candidate_agents[0]}",
            model=model,
            pre_act_key=f"Recent thoughts on candidate {candidate_agents[0]}",
            question=f"Given the above general opinion of {agent_name} about candidate {candidate_agents[0]}, and the recent observations, what are the current thoughts of {agent_name} on candidate {candidate_agents[0]}? Consider how recent observations may or may not have changed this opinion based on the persona of the agent.",
            num_memories_to_retrieve=30,
            components={
                _get_class_name(self_perception): "Persona: ",
                _get_class_name(
                    relevant_opinions_c1
                ): f"General opinion of {agent_name} on candidate {candidate_agents[0]}",
            },
            logging_channel=measurements.get_channel(
                f"Opinions on candidate: {candidate_agents[0]}"
            ).on_next,
        )

        # Instantiate relevant opinions for candidate 2
        relevant_opinions_c2 = RelevantOpinions(
            model=model,
            queries=[f"policies and actions of {candidate_agents[1]}"],
            question=f"What does {agent_name} think of the {{query}}?",
            pre_act_key=f"{agent_name} thinks of {candidate_agents[1]} as:",
            num_memories_to_retrieve=50,
        )

        # Instantiate opinions on candidate 2
        opinions_on_candidate_c2 = OpinionsOnCandidate(
            add_to_memory=True,
            memory_tag=f"[Opinion on {candidate_agents[1]}]",
            answer_prefix=f"Current Opinion on candidate {candidate_agents[1]}",
            model=model,
            pre_act_key=f"Recent thoughts on candidate {candidate_agents[1]}",
            question=f"Given the above general opinion of {agent_name} about candidate {candidate_agents[1]}, and the recent observations, what are the current thoughts of {agent_name} on candidate {candidate_agents[1]}? Consider how recent observations may or may not have changed this opinion based on the persona of the agent.",
            num_memories_to_retrieve=30,
            components={
                _get_class_name(self_perception): "Persona: ",
                _get_class_name(
                    relevant_opinions_c2
                ): f"General opinion of {agent_name} on candidate {candidate_agents[1]}",
            },
            logging_channel=measurements.get_channel(
                f"Opinions on candidate: {candidate_agents[1]}"
            ).on_next,
        )
        agent_tuple = (opinions_on_candidate_c1, opinions_on_candidate_c2)
        agent_no_tuple = (relevant_opinions_c1, relevant_opinions_c2)

    entity_components = (
        (
            # Components that provide pre_act context.
            instructions,
            election_information,
            observation,
            observation_summary,
            relevant_memories,
            self_perception,
        )
        + agent_tuple
        + (
            time_display,
            # Components that do not provide pre_act context.
            identity_characteristics,
        )
        + agent_no_tuple
    )
    components_of_agent = {_get_class_name(component): component for component in entity_components}
    components_of_agent[new_components.memory_component.DEFAULT_MEMORY_COMPONENT_NAME] = (
        new_components.memory_component.MemoryComponent(raw_memory)
    )
    component_order = list(components_of_agent.keys())
    if overarching_goal is not None:
        components_of_agent[goal_label] = overarching_goal
        # Place goal after the instructions.
        component_order.insert(1, goal_label)

    act_component = new_components.concat_act_component.ConcatActComponent(
        model=model,
        clock=clock,
        component_order=component_order,
        logging_channel=measurements.get_channel("ActComponent").on_next,
    )

    agent = entity_agent_with_logging.EntityAgentWithLogging(
        agent_name=agent_name,
        act_component=act_component,
        context_components=components_of_agent,
        component_logging=measurements,
    )

    return agent

# %%
# Build the agents
from functools import partial

player_configs = player_configs[:NUM_PLAYERS]
player_goals = {player_config.name: player_config.goal for player_config in player_configs}
players = []
memories = {}


def build_agent_with_memories(player_config):
    mem = formative_memory_factory.make_memories(player_config)
    agent = build_agent(
        model=model, clock=clock, update_time_interval=time_step, config=player_config, memory=mem
    )
    return agent


with concurrent.futures.ThreadPoolExecutor(max_workers=NUM_PLAYERS) as pool:
    for agent in pool.map(build_agent_with_memories, player_configs):
        players.append(agent)
# Out:
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (9) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (9) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (9) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).

# %% [markdown]
# ## Build the GM

# %%
game_master_memory = associative_memory.AssociativeMemory(
    embedder, importance_model_gm.importance, clock=clock.now
)

# %%
# Add some memories to the game master
for player in players:
    game_master_memory.add(f"{player.name} is at their private home.")

# %%
# Create components and externalities for the game master
scenario_knowledge = old_components.constant.ConstantComponent(
    " ".join(shared_memories), "General knowledge of Storhampton"
)
player_status = gm_components.player_status.PlayerStatus(
    clock.now, model, game_master_memory, player_names
)

relevant_events = gm_components.relevant_events.RelevantEvents(clock.now, model, game_master_memory)
time_display = gm_components.time_display.TimeDisplay(clock)

direct_effect_externality = gm_components.direct_effect.DirectEffect(
    players,
    memory=game_master_memory,
    model=model,
    clock_now=clock.now,
    verbose=False,
    components=[player_status],
)

# %%
# Create apps and provide them to the phones, assigning 1 phone to each player
mastodon_app = apps.MastodonSocialNetworkApp(perform_operations=USE_MASTODON_SERVER)

phones = {player.name: apps.Phone(player.name, apps=[mastodon_app]) for player in players}

# %%
# Update username for each person (since this is different from their name)
user_mapping = {player.name.split()[0]: f"user{i+1:04d}" for i, player in enumerate(players)}
mastodon_app.set_user_mapping(user_mapping)
# Out:
# 🔄 Updated user mapping with 20 entries

# %%
if USE_MASTODON_SERVER:
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = []
        for follower in user_mapping:
            print(follower)
            if follower != candidate_agents[0].split()[0]:
                futures.append(
                    executor.submit(
                        mastodon_app.follow_user, follower, candidate_agents[0].split()[0]
                    )
                )
            if follower != candidate_agents[1].split()[0]:
                futures.append(
                    executor.submit(
                        mastodon_app.follow_user, follower, candidate_agents[1].split()[0]
                    )
                )
            for followee in user_mapping:
                if follower != followee:
                    if random.random() < 0.2:
                        futures.append(
                            executor.submit(mastodon_app.follow_user, follower, followee)
                        )
                        futures.append(
                            executor.submit(mastodon_app.follow_user, followee, follower)
                        )
                    elif random.random() < 0.15:
                        futures.append(
                            executor.submit(mastodon_app.follow_user, follower, followee)
                        )

        # Optionally, wait for all tasks to complete
        for future in concurrent.futures.as_completed(futures):
            try:
                future.result()  # This will raise any exceptions that occurred during execution, if any
            except Exception as e:
                print(f"Ignoring already-following error: {e}")
# Out:
# Bill
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Bill to @user0001
# Bradley
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Bill to @user0001
# Glenn
# Denise
# Roger
# Erica
# Liam
# Olivia
# Robert
# Janet
# William
# Jessica
# Mark
# Emily
# Ethan
# Sophia
# Ryan
# Maggie
# Lucas
# Nina
# 2025-01-06T19:38:59.027727+0000 ERROR Login failed for user0018: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.030435+0000 ERROR Login failed for user0001: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.033609+0000 ERROR Login failed for user0012: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.038040+0000 ERROR Login failed for user0001: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.038347+0000 ERROR Login failed for user0001: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.040115+0000 ERROR Login failed for user0002: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.040364+0000 ERROR Login failed for user0001: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.040553+0000 ERROR Login failed for user0002: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.091853+0000 ERROR Error: invalid literal for int() with base 10: '24, 2998'
# 2025-01-06T19:38:59.095227+0000 ERROR Error: invalid literal for int() with base 10: '24, 2997'
# ➕ current_user (@user0012) followed target_user (@user0001)
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Liam to @user0007
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0018) followed target_user (@user0001)
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Robert to @user0009
# 2025-01-06T19:38:59.099169+0000 ERROR Error: invalid literal for int() with base 10: '24, 2996'
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0001) followed target_user (@user0018)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.107389+0000 ERROR Error: invalid literal for int() with base 10: '23, 2995'
# ➕ current_user (@user0001) followed target_user (@user0002)
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped William to @user0011
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.110059+0000 ERROR Error: invalid literal for int() with base 10: '23, 2994'
# 2025-01-06T19:38:59.110876+0000 ERROR Error: invalid literal for int() with base 10: '23, 2993'
# ➕ current_user (@user0002) followed target_user (@user0001)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0001) followed target_user (@user0002)
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Emily to @user0014
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.169626+0000 ERROR Error: invalid literal for int() with base 10: '22, 2992'
# 2025-01-06T19:38:59.198590+0000 ERROR Error: invalid literal for int() with base 10: '22, 2991'
# ➕ current_user (@user0001) followed target_user (@user0012)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.262940+0000 ERROR Login failed for user0002: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# ➕ current_user (@user0002) followed target_user (@user0001)
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Maggie to @user0018
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.278939+0000 ERROR Login failed for user0009: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.317325+0000 ERROR Login failed for user0002: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.319242+0000 ERROR Login failed for user0002: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.383941+0000 ERROR Login failed for user0011: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.386934+0000 ERROR Login failed for user0002: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.387579+0000 ERROR Login failed for user0014: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.389541+0000 ERROR Error: invalid literal for int() with base 10: '17, 2990'
# ➕ current_user (@user0002) followed target_user (@user0009)
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Lucas to @user0019
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.404728+0000 ERROR Login failed for user0002: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.405566+0000 ERROR Error: invalid literal for int() with base 10: '11, 2988'
# ➕ current_user (@user0002) followed target_user (@user0007)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Bill to @user0001
# 2025-01-06T19:38:59.406488+0000 ERROR Error: invalid literal for int() with base 10: '13, 2989'
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0009) followed target_user (@user0002)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.409608+0000 ERROR Error: invalid literal for int() with base 10: '11, 2987'
# ➕ current_user (@user0002) followed target_user (@user0011)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Bill to @user0001
# 2025-01-06T19:38:59.464006+0000 ERROR Error: invalid literal for int() with base 10: '11, 2986'
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0011) followed target_user (@user0002)
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Glenn to @user0003
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.485328+0000 ERROR Login failed for user0002: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.489070+0000 ERROR Error: invalid literal for int() with base 10: '10, 2985'
# 2025-01-06T19:38:59.502668+0000 ERROR Error: invalid literal for int() with base 10: '9, 2984'
# ➕ current_user (@user0014) followed target_user (@user0002)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'2025-01-06T19:38:59.507322+0000 ERROR Error: invalid literal for int() with base 10: '9, 2983'
# ➕ current_user (@user0002) followed target_user (@user0014)
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Glenn to @user0003
#
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.606151+0000 ERROR Login failed for user0003: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# ➕ current_user (@user0002) followed target_user (@user0018)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Denise to @user0004
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.626921+0000 ERROR Login failed for user0001: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.629741+0000 ERROR Error: invalid literal for int() with base 10: '7, 2982'
# ➕ current_user (@user0002) followed target_user (@user0019)2025-01-06T19:38:59.656364+0000 ERROR Login failed for user0003: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
#
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Glenn to @user0003
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.669988+0000 ERROR Login failed for user0003: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.670551+0000 ERROR Login failed for user0002: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.698099+0000 ERROR Login failed for user0003: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.710566+0000 ERROR Error: invalid literal for int() with base 10: '0, 2981'
# ➕ current_user (@user0003) followed target_user (@user0001)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Roger to @user0005
# 2025-01-06T19:38:59.731146+0000 ERROR Login failed for user0003: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.758953+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:38:59.772766+0000 ERROR Error: invalid literal for int() with base 10: '0, 2980'
# 2025-01-06T19:38:59.773698+0000 ERROR Error: invalid literal for int() with base 10: '0, 2979'
# ➕ current_user (@user0003) followed target_user (@user0002)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Glenn to @user0003
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0001) followed target_user (@user0003)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Olivia to @user0008
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.862603+0000 ERROR Error: invalid literal for int() with base 10: '0, 2978'
# ➕ current_user (@user0002) followed target_user (@user0003)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Glenn to @user0003
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.884378+0000 ERROR Error: invalid literal for int() with base 10: '0, 2977'
# ➕ current_user (@user0003) followed target_user (@user0002)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Janet to @user0010
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.906419+0000 ERROR Error: invalid literal for int() with base 10: '0, 2976'
# ➕ current_user (@user0003) followed target_user (@user0001)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Mark to @user0013
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.935510+0000 ERROR Error: invalid literal for int() with base 10: '0, 2975'
# 2025-01-06T19:38:59.935759+0000 ERROR Login failed for user0003: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# ➕ current_user (@user0003) followed target_user (@user0004)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Glenn to @user0003
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:38:59.936837+0000 ERROR Error: invalid literal for int() with base 10: '0, 2974'
# ➕ current_user (@user0004) followed target_user (@user0003)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Maggie to @user0018
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:00.036996+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:00.039162+0000 ERROR Login failed for user0003: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:00.313706+0000 ERROR Login failed for user0003: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:00.313966+0000 ERROR Login failed for user0008: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:00.416543+0000 ERROR Login failed for user0003: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:00.456458+0000 ERROR Login failed for user0003: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:00.458998+0000 ERROR Login failed for user0013: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:00.465963+0000 ERROR Error: invalid literal for int() with base 10: '0, 2973'
# ➕ current_user (@user0003) followed target_user (@user0005)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:00.593899+0000 ERROR Error: invalid literal for int() with base 10: '0, 2972'
# 2025-01-06T19:39:00.594456+0000 ERROR Error: invalid literal for int() with base 10: '0, 2971'
# ➕ current_user (@user0005) followed target_user (@user0003)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0003) followed target_user (@user0008)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:01.060730+0000 ERROR Error: invalid literal for int() with base 10: '0, 2970'
# 2025-01-06T19:39:01.061975+0000 ERROR Error: invalid literal for int() with base 10: '0, 2969'
# ➕ current_user (@user0003) followed target_user (@user0010)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0008) followed target_user (@user0003)
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Denise to @user0004
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:01.195855+0000 ERROR Error: invalid literal for int() with base 10: '0, 2968'
# ➕ current_user (@user0003) followed target_user (@user0013)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Roger to @user0005
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:01.271533+0000 ERROR Error: invalid literal for int() with base 10: '0, 2967'
# ➕ current_user (@user0003) followed target_user (@user0018)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Denise to @user0004
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:01.289773+0000 ERROR Error: invalid literal for int() with base 10: '0, 2966'
# ➕ current_user (@user0013) followed target_user (@user0003)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Liam to @user0007
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:01.326200+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:01.457006+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:01.459936+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:02.219808+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:02.220187+0000 ERROR Login failed for user0002: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:02.288752+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:02.422624+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:02.427566+0000 ERROR Error: invalid literal for int() with base 10: '0, 2965'
# 2025-01-06T19:39:02.428322+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# ➕ current_user (@user0004) followed target_user (@user0001)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Denise to @user0004
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:02.652904+0000 ERROR Error: invalid literal for int() with base 10: '0, 2964'
# ➕ current_user (@user0004) followed target_user (@user0001)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:02.669396+0000 ERROR Error: invalid literal for int() with base 10: '0, 2963'
# ➕ current_user (@user0004) followed target_user (@user0002)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Denise to @user0004
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:03.581213+0000 ERROR Error: invalid literal for int() with base 10: '0, 2962'
# ➕ current_user (@user0004) followed target_user (@user0002)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Sophia to @user0016
# 2025-01-06T19:39:03.585574+0000 ERROR Error: invalid literal for int() with base 10: '0, 2961'
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0002) followed target_user (@user0004)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Ryan to @user0017
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:03.709266+0000 ERROR Error: invalid literal for int() with base 10: '0, 2960'
# ➕ current_user (@user0004) followed target_user (@user0005)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Nina to @user0020
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:03.881607+0000 ERROR Error: invalid literal for int() with base 10: '0, 2959'
# ➕ current_user (@user0004) followed target_user (@user0007)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:03.906145+0000 ERROR Error: invalid literal for int() with base 10: '0, 2958'
# ➕ current_user (@user0005) followed target_user (@user0004)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:03.938894+0000 ERROR Login failed for user0007: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:04.132441+0000 ERROR Login failed for user0009: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:04.133436+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:05.354523+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:05.394299+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:05.398178+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:05.719502+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:05.727130+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:05.758721+0000 ERROR Error: invalid literal for int() with base 10: '0, 2957'
# ➕ current_user (@user0007) followed target_user (@user0004)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:05.929576+0000 ERROR Error: invalid literal for int() with base 10: '0, 2956'
# ➕ current_user (@user0009) followed target_user (@user0004)
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Roger to @user0005
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:05.934522+0000 ERROR Error: invalid literal for int() with base 10: '0, 2955'
# ➕ current_user (@user0004) followed target_user (@user0009)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:07.328321+0000 ERROR Error: invalid literal for int() with base 10: '0, 2954'
# ➕ current_user (@user0004) followed target_user (@user0016)
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Roger to @user0005
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:07.374530+0000 ERROR Error: invalid literal for int() with base 10: '0, 2953'
# ➕ current_user (@user0004) followed target_user (@user0017)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Glenn to @user0003
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:07.378142+0000 ERROR Error: invalid literal for int() with base 10: '0, 2952'
# ➕ current_user (@user0004) followed target_user (@user0020)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Roger to @user0005
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:07.722211+0000 ERROR Error: invalid literal for int() with base 10: '0, 2951'
# ➕ current_user (@user0005) followed target_user (@user0001)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Liam to @user0007
# 2025-01-06T19:39:07.727140+0000 ERROR Error: invalid literal for int() with base 10: '0, 2950'
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0005) followed target_user (@user0002)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:07.823117+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:08.122543+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:08.124722+0000 ERROR Login failed for user0001: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:09.619423+0000 ERROR Login failed for user0002: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:09.659637+0000 ERROR Login failed for user0003: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:09.695981+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:10.198361+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:10.206343+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:10.237996+0000 ERROR Error: invalid literal for int() with base 10: '0, 2949'
# ➕ current_user (@user0005) followed target_user (@user0001)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Ryan to @user0017
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:10.523795+0000 ERROR Error: invalid literal for int() with base 10: '0, 2948'
# ➕ current_user (@user0005) followed target_user (@user0002)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Roger to @user0005
# 2025-01-06T19:39:10.529155+0000 ERROR Error: invalid literal for int() with base 10: '0, 2947'
# Ignoring already-following error: 'NoneType' object has no attribute 'log'➕ current_user (@user0001) followed target_user (@user0005)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Maggie to @user0018
#
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:12.202020+0000 ERROR Error: invalid literal for int() with base 10: '0, 2946'
# ➕ current_user (@user0002) followed target_user (@user0005)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Roger to @user0005
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:12.241534+0000 ERROR Error: invalid literal for int() with base 10: '0, 2945'
# ➕ current_user (@user0003) followed target_user (@user0005)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:12.279156+0000 ERROR Error: invalid literal for int() with base 10: '0, 2944'
# ➕ current_user (@user0005) followed target_user (@user0003)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:12.803596+0000 ERROR Error: invalid literal for int() with base 10: '0, 2943'
# ➕ current_user (@user0005) followed target_user (@user0009)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Denise to @user0004
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:12.804737+0000 ERROR Error: invalid literal for int() with base 10: '0, 2942'
# ➕ current_user (@user0005) followed target_user (@user0007)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Erica to @user0006
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:12.872679+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:13.314731+0000 ERROR Login failed for user0017: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:13.323261+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:15.080695+0000 ERROR Login failed for user0018: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:15.092403+0000 ERROR Login failed for user0006: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:15.189968+0000 ERROR Login failed for user0006: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:15.825837+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:15.826977+0000 ERROR Login failed for user0006: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:15.833909+0000 ERROR Error: invalid literal for int() with base 10: '0, 2941'
# ➕ current_user (@user0005) followed target_user (@user0017)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Roger to @user0005
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:16.325618+0000 ERROR Error: invalid literal for int() with base 10: '0, 2940'
# ➕ current_user (@user0017) followed target_user (@user0005)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Erica to @user0006
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:16.343541+0000 ERROR Error: invalid literal for int() with base 10: '0, 2939'
# ➕ current_user (@user0005) followed target_user (@user0018)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:18.290130+0000 ERROR Error: invalid literal for int() with base 10: '0, 2938'
# ➕ current_user (@user0018) followed target_user (@user0005)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Erica to @user0006
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:18.303326+0000 ERROR Error: invalid literal for int() with base 10: '0, 2937'
# ➕ current_user (@user0006) followed target_user (@user0001)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Sophia to @user0016
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:18.404010+0000 ERROR Error: invalid literal for int() with base 10: '0, 2936'
# ➕ current_user (@user0006) followed target_user (@user0002)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Nina to @user0020
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:19.069624+0000 ERROR Error: invalid literal for int() with base 10: '0, 2935'
# ➕ current_user (@user0004) followed target_user (@user0006)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:19.098280+0000 ERROR Error: invalid literal for int() with base 10: '0, 2934'
# ➕ current_user (@user0006) followed target_user (@user0004)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:19.141222+0000 ERROR Login failed for user0006: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:19.598646+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:19.599990+0000 ERROR Login failed for user0006: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:21.856814+0000 ERROR Login failed for user0006: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:21.869728+0000 ERROR Login failed for user0009: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:21.895164+0000 ERROR Login failed for user0006: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:22.645860+0000 ERROR Login failed for user0007: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:22.654067+0000 ERROR Login failed for user0007: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:22.723647+0000 ERROR Error: invalid literal for int() with base 10: '0, 2933'
# ➕ current_user (@user0006) followed target_user (@user0005)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Roger to @user0005
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:23.198306+0000 ERROR Error: invalid literal for int() with base 10: '0, 2932'
# ➕ current_user (@user0005) followed target_user (@user0006)2025-01-06T19:39:23.201592+0000 ERROR Error: invalid literal for int() with base 10: '0, 2931'
#
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Liam to @user0007
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0006) followed target_user (@user0009)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Jessica to @user0012
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:25.663575+0000 ERROR Error: invalid literal for int() with base 10: '0, 2930'
# ➕ current_user (@user0006) followed target_user (@user0016)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Liam to @user0007
# 2025-01-06T19:39:25.673376+0000 ERROR Error: invalid literal for int() with base 10: '0, 2929'
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0009) followed target_user (@user0006)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Ethan to @user0015
# 2025-01-06T19:39:25.702315+0000 ERROR Error: invalid literal for int() with base 10: '0, 2928'
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0006) followed target_user (@user0020)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Liam to @user0007
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:26.479189+0000 ERROR Error: invalid literal for int() with base 10: '0, 2926'
# 2025-01-06T19:39:26.482091+0000 ERROR Error: invalid literal for int() with base 10: '0, 2927'
# ➕ current_user (@user0007) followed target_user (@user0002)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Sophia to @user0016
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0007) followed target_user (@user0001)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Liam to @user0007
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:26.580976+0000 ERROR Login failed for user0007: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:27.175754+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:27.182814+0000 ERROR Login failed for user0007: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:29.837905+0000 ERROR Login failed for user0012: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:29.846962+0000 ERROR Login failed for user0015: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:29.908859+0000 ERROR Login failed for user0007: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:30.752530+0000 ERROR Login failed for user0007: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:30.761524+0000 ERROR Login failed for user0016: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:30.790136+0000 ERROR Error: invalid literal for int() with base 10: '0, 2925'
# ➕ current_user (@user0007) followed target_user (@user0005)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:31.395549+0000 ERROR Error: invalid literal for int() with base 10: '0, 2924'
# 2025-01-06T19:39:31.398145+0000 ERROR Error: invalid literal for int() with base 10: '0, 2923'
# ➕ current_user (@user0005) followed target_user (@user0007)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0007) followed target_user (@user0012)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:35.255018+0000 ERROR Error: invalid literal for int() with base 10: '0, 2922'
# ➕ current_user (@user0007) followed target_user (@user0016)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Olivia to @user0008
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:35.259377+0000 ERROR Error: invalid literal for int() with base 10: '0, 2921'
# 2025-01-06T19:39:35.278386+0000 ERROR Error: invalid literal for int() with base 10: '0, 2920'
# ➕ current_user (@user0007) followed target_user (@user0015)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Janet to @user0010
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:35.288050+0000 ERROR Error: invalid literal for int() with base 10: '0, 2919'
# ➕ current_user (@user0012) followed target_user (@user0007)➕ current_user (@user0016) followed target_user (@user0007)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Olivia to @user0008
#
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Emily to @user0014
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:35.322825+0000 ERROR Error: invalid literal for int() with base 10: '0, 2918'
# 2025-01-06T19:39:35.326503+0000 ERROR Login failed for user0008: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# ➕ current_user (@user0015) followed target_user (@user0007)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Ethan to @user0015
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:35.985489+0000 ERROR Login failed for user0008: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:35.995978+0000 ERROR Login failed for user0008: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:40.086572+0000 ERROR Login failed for user0010: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:40.136224+0000 ERROR Login failed for user0008: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:40.144546+0000 ERROR Login failed for user0008: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:40.144994+0000 ERROR Login failed for user0008: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:40.145360+0000 ERROR Login failed for user0009: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:40.207004+0000 ERROR Error: invalid literal for int() with base 10: '0, 2917'
# ➕ current_user (@user0008) followed target_user (@user0001)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Lucas to @user0019
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:40.814248+0000 ERROR Error: invalid literal for int() with base 10: '0, 2916'
# ➕ current_user (@user0008) followed target_user (@user0009)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Nina to @user0020
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:40.830238+0000 ERROR Error: invalid literal for int() with base 10: '0, 2915'
# ➕ current_user (@user0008) followed target_user (@user0002)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:45.088356+0000 ERROR Error: invalid literal for int() with base 10: '0, 2914'
# ➕ current_user (@user0010) followed target_user (@user0008)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:45.160125+0000 ERROR Error: invalid literal for int() with base 10: '0, 2913'
# ➕ current_user (@user0008) followed target_user (@user0010)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:45.191118+0000 ERROR Error: invalid literal for int() with base 10: '0, 2912'
# 2025-01-06T19:39:45.192316+0000 ERROR Error: invalid literal for int() with base 10: '0, 2911'
# ➕ current_user (@user0008) followed target_user (@user0015)
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Robert to @user0009
# 2025-01-06T19:39:45.210418+0000 ERROR Error: invalid literal for int() with base 10: '0, 2910'
# ➕ current_user (@user0009) followed target_user (@user0008)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Emily to @user0014
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0008) followed target_user (@user0014)2025-01-06T19:39:45.277391+0000 ERROR Login failed for user0008: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
#
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:45.988930+0000 ERROR Login failed for user0008: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:45.989717+0000 ERROR Login failed for user0009: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:50.399622+0000 ERROR Login failed for user0009: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:50.553357+0000 ERROR Login failed for user0009: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:50.607111+0000 ERROR Login failed for user0001: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:50.649146+0000 ERROR Error: invalid literal for int() with base 10: '0, 2909'
# ➕ current_user (@user0008) followed target_user (@user0019)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Ryan to @user0017
# 2025-01-06T19:39:50.654302+0000 ERROR Login failed for user0009: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:50.671776+0000 ERROR Login failed for user0014: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:51.433797+0000 ERROR Error: invalid literal for int() with base 10: '0, 2908'
# 2025-01-06T19:39:51.436269+0000 ERROR Error: invalid literal for int() with base 10: '0, 2907'
# ➕ current_user (@user0008) followed target_user (@user0020)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Bill to @user0001
# ➕ current_user (@user0009) followed target_user (@user0001)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:56.019652+0000 ERROR Error: invalid literal for int() with base 10: '0, 2906'
# ➕ current_user (@user0009) followed target_user (@user0002)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Glenn to @user0003
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:56.181615+0000 ERROR Error: invalid literal for int() with base 10: '0, 2905'
# ➕ current_user (@user0009) followed target_user (@user0001)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Janet to @user0010
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:56.235865+0000 ERROR Error: invalid literal for int() with base 10: '0, 2904'
# ➕ current_user (@user0001) followed target_user (@user0009)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Denise to @user0004
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:56.328134+0000 ERROR Error: invalid literal for int() with base 10: '0, 2903'
# ➕ current_user (@user0009) followed target_user (@user0014)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Janet to @user0010
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:56.347984+0000 ERROR Error: invalid literal for int() with base 10: '0, 2902'
# 2025-01-06T19:39:56.348948+0000 ERROR Login failed for user0009: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# ➕ current_user (@user0014) followed target_user (@user0009)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Roger to @user0005
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:39:57.213046+0000 ERROR Login failed for user0010: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:39:57.215175+0000 ERROR Login failed for user0010: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:40:01.910527+0000 ERROR Login failed for user0010: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:40:02.194390+0000 ERROR Login failed for user0003: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:40:02.233661+0000 ERROR Login failed for user0010: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:40:02.313364+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:40:02.351732+0000 ERROR Error: invalid literal for int() with base 10: '0, 2901'
# ➕ current_user (@user0009) followed target_user (@user0017)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Janet to @user0010
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:40:02.371209+0000 ERROR Login failed for user0010: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:40:03.258136+0000 ERROR Error: invalid literal for int() with base 10: '0, 2999'
# ➕ current_user (@user0010) followed target_user (@user0002)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Erica to @user0006
# ...
# 2025-01-06T19:43:45.615225+0000 ERROR Login failed for user0018: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:43:45.898462+0000 ERROR Login failed for user0008: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:43:57.174687+0000 ERROR Login failed for user0018: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:43:57.176772+0000 ERROR Login failed for user0018: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:43:57.245646+0000 ERROR Login failed for user0013: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:43:57.253701+0000 ERROR Login failed for user0018: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:43:57.543745+0000 ERROR Login failed for user0018: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:43:57.602294+0000 ERROR Error: invalid literal for int() with base 10: '0, 2904'
# ➕ current_user (@user0003) followed target_user (@user0018)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Ethan to @user0015
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:43:58.927640+0000 ERROR Error: invalid literal for int() with base 10: '0, 2903'
# ➕ current_user (@user0018) followed target_user (@user0008)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Maggie to @user0018
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:43:59.215372+0000 ERROR Error: invalid literal for int() with base 10: '0, 2902'
# ➕ current_user (@user0008) followed target_user (@user0018)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Lucas to @user0019
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:44:10.689891+0000 ERROR Error: invalid literal for int() with base 10: '0, 2901'
# ➕ current_user (@user0018) followed target_user (@user0009)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:44:10.707985+0000 ERROR Error: invalid literal for int() with base 10: '0, 2900'
# ➕ current_user (@user0018) followed target_user (@user0012)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:44:10.792998+0000 ERROR Error: invalid literal for int() with base 10: '0, 2899'
# ➕ current_user (@user0013) followed target_user (@user0018)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Roger to @user0005
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:44:10.824215+0000 ERROR Error: invalid literal for int() with base 10: '0, 2898'
# ➕ current_user (@user0018) followed target_user (@user0013)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Lucas to @user0019
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:44:11.070064+0000 ERROR Error: invalid literal for int() with base 10: '0, 2897'
# ➕ current_user (@user0018) followed target_user (@user0014)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Liam to @user0007
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:44:11.205661+0000 ERROR Login failed for user0018: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:12.558351+0000 ERROR Login failed for user0015: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:12.870308+0000 ERROR Login failed for user0018: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:24.783332+0000 ERROR Login failed for user0019: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:24.791408+0000 ERROR Login failed for user0019: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:24.825207+0000 ERROR Login failed for user0019: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:24.860279+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:24.962110+0000 ERROR Login failed for user0019: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:25.126830+0000 ERROR Error: invalid literal for int() with base 10: '0, 2895'
# ➕ current_user (@user0018) followed target_user (@user0015)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Lucas to @user0019
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:44:26.487544+0000 ERROR Error: invalid literal for int() with base 10: '0, 2894'
# ➕ current_user (@user0015) followed target_user (@user0018)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:44:26.807107+0000 ERROR Error: invalid literal for int() with base 10: '0, 2893'
# ➕ current_user (@user0018) followed target_user (@user0019)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Janet to @user0010
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:44:38.912414+0000 ERROR Error: invalid literal for int() with base 10: '0, 2892'
# ➕ current_user (@user0019) followed target_user (@user0001)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Lucas to @user0019
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:44:38.941517+0000 ERROR Error: invalid literal for int() with base 10: '0, 2891'
# 2025-01-06T19:44:38.959787+0000 ERROR Error: invalid literal for int() with base 10: '0, 2890'
# ➕ current_user (@user0019) followed target_user (@user0002)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Emily to @user0014
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0019) followed target_user (@user0005)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Sophia to @user0016
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:44:39.030197+0000 ERROR Error: invalid literal for int() with base 10: '0, 2889'
# 2025-01-06T19:44:39.131131+0000 ERROR Error: invalid literal for int() with base 10: '0, 2888'
# ➕ current_user (@user0005) followed target_user (@user0019)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Lucas to @user0019
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0019) followed target_user (@user0007)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Ryan to @user0017
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:44:39.337090+0000 ERROR Login failed for user0007: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:40.741285+0000 ERROR Login failed for user0019: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:41.089371+0000 ERROR Login failed for user0019: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:53.515793+0000 ERROR Login failed for user0010: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:53.552136+0000 ERROR Login failed for user0019: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:53.596394+0000 ERROR Login failed for user0016: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:53.602097+0000 ERROR Login failed for user0019: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:53.603516+0000 ERROR Login failed for user0019: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:44:53.863240+0000 ERROR Error: invalid literal for int() with base 10: '0, 2887'
# ➕ current_user (@user0007) followed target_user (@user0019)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:44:55.278500+0000 ERROR Error: invalid literal for int() with base 10: '0, 2886'
# ➕ current_user (@user0019) followed target_user (@user0009)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Bradley to @user0002
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:44:55.644998+0000 ERROR Error: invalid literal for int() with base 10: '0, 2885'
# ➕ current_user (@user0019) followed target_user (@user0010)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Denise to @user0004
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:45:08.464082+0000 ERROR Error: invalid literal for int() with base 10: '0, 2999'
# ➕ current_user (@user0019) followed target_user (@user0017)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Nina to @user0020
# 2025-01-06T19:45:08.464681+0000 ERROR Error: invalid literal for int() with base 10: '0, 2999'
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0019) followed target_user (@user0014)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Roger to @user0005
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:45:08.470080+0000 ERROR Error: invalid literal for int() with base 10: '0, 2997'
# 2025-01-06T19:45:08.491392+0000 ERROR Error: invalid literal for int() with base 10: '0, 2998'
# ➕ current_user (@user0010) followed target_user (@user0019)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Nina to @user0020
# 2025-01-06T19:45:08.490860+0000 ERROR Error: invalid literal for int() with base 10: '0, 2996'
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# ➕ current_user (@user0016) followed target_user (@user0019)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Erica to @user0006
# Ignoring already-following error: 'NoneType' object has no attribute 'log'➕ current_user (@user0019) followed target_user (@user0016)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Nina to @user0020
#
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:45:08.657780+0000 ERROR Login failed for user0020: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:45:10.072364+0000 ERROR Login failed for user0020: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:45:10.475073+0000 ERROR Login failed for user0020: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:45:23.739457+0000 ERROR Login failed for user0004: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:45:23.740514+0000 ERROR Login failed for user0020: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:45:23.747846+0000 ERROR Error: invalid literal for int() with base 10: '0, 2995'
# ➕ current_user (@user0020) followed target_user (@user0001)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Liam to @user0007
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:45:23.778373+0000 ERROR Login failed for user0006: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:45:23.805910+0000 ERROR Login failed for user0020: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:45:23.809712+0000 ERROR Login failed for user0005: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:45:25.217732+0000 ERROR Error: invalid literal for int() with base 10: '0, 2994'
# ➕ current_user (@user0020) followed target_user (@user0002)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Olivia to @user0008
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:45:25.625095+0000 ERROR Error: invalid literal for int() with base 10: '0, 2993'
# ➕ current_user (@user0020) followed target_user (@user0004)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Nina to @user0020
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:45:39.108141+0000 ERROR Error: invalid literal for int() with base 10: '0, 2992'
# ➕ current_user (@user0004) followed target_user (@user0020)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Mark to @user0013
# 2025-01-06T19:45:39.113737+0000 ERROR Error: invalid literal for int() with base 10: '0, 2991'
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:45:39.123505+0000 ERROR Login failed for user0020: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# ➕ current_user (@user0020) followed target_user (@user0005)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Nina to @user0020
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:45:39.168367+0000 ERROR Error: invalid literal for int() with base 10: '0, 2990'
# ➕ current_user (@user0006) followed target_user (@user0020)
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:45:39.176746+0000 ERROR Error: invalid literal for int() with base 10: '0, 2989'
# ➕ current_user (@user0005) followed target_user (@user0020)
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:45:39.191064+0000 ERROR Error: invalid literal for int() with base 10: '0, 2988'
# ➕ current_user (@user0020) followed target_user (@user0006)
# Ignoring already-following error: 'NoneType' object has no attribute 'log'
# 2025-01-06T19:45:40.879165+0000 ERROR Login failed for user0020: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:45:41.077629+0000 ERROR Login failed for user0008: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:45:54.765045+0000 ERROR Error: invalid literal for int() with base 10: '0, 2976'
# 2025-01-06T19:45:54.766644+0000 ERROR Login failed for user0020: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# ➕ current_user (@user0020) followed target_user (@user0007)
# 2025-01-06T19:45:54.771419+0000 ERROR Login failed for user0013: Invalid user name, password, or redirect_uris: ('Mastodon API returned error', 400, 'Bad Request', 'invalid_grant')
# 2025-01-06T19:45:56.567147+0000 ERROR Error: invalid literal for int() with base 10: '0, 2975'
# ➕ current_user (@user0020) followed target_user (@user0008)
# 2025-01-06T19:45:56.771999+0000 ERROR Error: invalid literal for int() with base 10: '0, 2974'
# ➕ current_user (@user0008) followed target_user (@user0020)

# %%
# Update Mastodon display name for each person
from mastodon_sim import mastodon_ops

if USE_MASTODON_SERVER:
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [
            executor.submit(mastodon_ops.update_bio, user_mapping[name], display_name=name, bio="")
            for name in user_mapping
        ]

    # Optionally, wait for all tasks to complete
    for future in concurrent.futures.as_completed(futures):
        future.result()  # This will raise any exceptions that occurred during execution, if any

# %%
# Create component to trigger PhoneGameMaster
phone_triggering = triggering.SceneTriggeringComponent(
    {player.name: player for player in players},
    "independent_malicious_configs.json",
    phones,
    model,
    memory=game_master_memory,
    clock=clock,
    memory_factory=blank_memory_factory,
)

# %% [markdown]
# ### Define a custom `CALL_TO_ACTION` prompt for the main Game Master
#
# This replaces the [default call to action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/typing/entity.py#L51).
#
# Check out the `Calendar.ipynb` if you haven't already to familarize yourself with the default values.

# %%
from concordia.typing.entity import ActionSpec, OutputType


CUSTOM_CALL_TO_ACTION = """
Describe an activity on Storhampton.social that {name} would engage in for the next {timedelta}.
Choose actions together take about {timedelta} to complete.
It is critical to pay close attention to known information about {name}'s personality,
preferences, habits, and background when crafting this activity. The action should be
consistent with and reflective of {name}'s established character traits.

Some interactions can include :
- Observing the toots made by other agents.
- Posting on Mastodon
- Liking other toots
- Replying to the toots made by other agents.


Example:

"Sarah checks her feed and replies if necessary. Then she may post a toot on Mastodon about her ideas on topic X on the lines of 'Just discovered an intriguing new language for low-latency systems programming.
Has anyone given it a try? Curious about potential real-world applications. 🤔
#TechNews #ProgrammingLanguages'"


Ensure your response is specific, creative, and detailed. Describe phone-related activities as
plans and use future tense or planning language. Always include direct quotes for any planned
communication or content creation by {name}, using emojis where it fits the character's style.
Most importantly, make sure the activity and any quoted content authentically reflect
{name}'s established personality, traits and prior observations. Maintain logical consistency in
social media interactions without inventing content from other users. Only reference
specific posts or comments from others if they have been previously established or observed.

"""


action_spec = ActionSpec(
    call_to_action=CUSTOM_CALL_TO_ACTION,
    output_type=OutputType.FREE,
    tag="action",
)

# %% [markdown]
# ### Define custom thought chains for the main Game Master
#
# This replaces the [default thought chains](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L38).

# %%
# Define custom thought chain for GM

from concordia.document import interactive_document


def custom_attempt_to_result(
    chain_of_thought: interactive_document.InteractiveDocument,
    action_attempt: str,
    active_player_name: str,
):
    """Determine success of action_attempt and reason for success/failure.

    Args:
      chain_of_thought: the document to condition on and record the thoughts
      action_attempt: the attempted action
      active_player_name: name of player whose turn it currently is

    Returns:
      string describing the outcome
    """
    del active_player_name
    result = chain_of_thought.open_question(
        "As the game master, describe the immediate outcome or continuation of the attempted action, following these guidelines:"
        "\n\n For digital interactions (using devices, apps, or viewing online content):"
        "\n   - Do not describe any actual interaction with digital interfaces or content."
        "\n   - Focus on the character's preparation, anticipation, or mental state related to the planned digital action."
        "\n   - Describe the physical setting or actions related to preparing for the digital interaction."
        "\n   - Avoid mentioning opening apps, loading content, or any specific digital processes."
        "\n   - Keep digital actions as plans or intentions rather than executed actions."
        "\n   - If the attempt mentions a direct quote they are thinking of (like a post or message they are planning), retain that quote in your response."
        "\n\n3. General guidelines:"
        '\n   - Your response should naturally continue the attempted action, suitable to follow "Because of that,".'
        "\n   - Do not repeat the original action attempt in your response."
        "\n   - For simple or routine actions, provide a brief, matter-of-fact description of the outcome."
        "\n\nExamples:"
        '\n1. Attempt: "Alice is preparing to check her Mastodon feed to catch up on the latest news and updates from her community. '
        'She sits at her kitchen table, her smartphone in hand, and opens the MastodonSocialNetworkApp."'
        '\nResult: "Alice sits at her kitchen table with her smartphone, anticipating the latest updates from her community. '
        "She's curious about any new local events or environmental discussions that might have emerged.\""
        '\n2. Attempt: "John jumps off a cliff, aiming to fly like a superhero."'
        '\nResult: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. '
        'The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."'
        '\n3. Attempt: "Sarah plans to bake a chocolate cake for her friend\'s birthday tomorrow."'
        '\nResult: "She mentally reviews the ingredients she\'ll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."'
        '\n4. Attempt: "Mark opens the heavy oak door to enter the library."'
        '\nResult: "The door creaks open, revealing rows of bookshelves. The scent of old books wafts out as Mark steps inside, '
        'dust motes dancing in the slanted afternoon sunlight streaming through tall windows."'
        '\n5. Attempt: "Emily checks the weather forecast on her phone app for the weekend."'
        '\nResult: "Emily glances out the window, wondering if the weekend will be suitable for outdoor activities. '
        'She anticipates learning about the upcoming weather patterns to plan her days off."'
        "\n6. Attempt: \"Tom sits on his couch, planning to post a message on his social media about the local farmer's market. "
        "He thinks about writing, 'Don't miss the spring farmer's market this Saturday! Fresh produce and handmade crafts galore!'\""
        "\nResult: \"Tom relaxes on his couch, contemplating the farmer's market post he wants to share. "
        "He mentally refines the message, 'Don't miss the spring farmer's market this Saturday! Fresh produce and handmade crafts galore!', "
        'imagining how it might encourage his friends to attend."'
        "\nNow, based on these examples and guidelines, provide an appropriate result for the given action attempt:",
        max_tokens=2000,
    )
    raw_causal_statement = f"{action_attempt} Because of that, {result}"
    return raw_causal_statement


def custom_result_to_who_what_where(
    chain_of_thought: interactive_document.InteractiveDocument,
    event: str,
    active_player_name: str,
):
    """Determines who have done what where, given the event.

    Args:
      chain_of_thought: the document to condition on and record the thoughts
      event: the event to determine the causal outcome of
      active_player_name: name of player whose turn it currently is

    Returns:
    """
    del active_player_name
    chain_of_thought.statement(event)
    causal_statement = chain_of_thought.open_question(
        "Rewrite the statement above as one concise sentence that highlights"
        " the main person, what they did or plan to do, where,"
        " and what happened as a result (if anything), following these guidelines:"
        "\n1. Do not add any information not present in the original statement."
        "\n2. For digital interactions (using devices, apps, or online content):"
        "\n   - Keep plans and preparations as they are, without describing execution."
        '\n   - Use phrases like "plans to", "prepares to", or "gets ready to" for digital actions.'
        "\n   - Focus on the person's intention or anticipation rather than the digital action itself."
        "\n   - If there's a specific message or content planned, include it as a direct quote."
        '\n3. Do not express uncertainty (e.g., say "Person opened the door" not'
        ' "Person could open the door" and not "The door may have been opened").'
        "\n4. Ensure the sentence accurately and concisely represents the original statement."
        "\n5. Use the name given in the original statement."
        "\n\nExamples:"
        '\n- Original: "Alice sits at her kitchen table with her smartphone, composing a message for her Mastodon feed. '
        "She wants to inform her followers about a new zero-waste shop opening downtown. "
        "She thinks about writing, 'Exciting news! A new zero-waste shop is opening on Main Street next week. Who's up for a visit?'\""
        "\n  Rewrite: \"Alice plans to post on Mastodon, 'Exciting news! A new zero-waste shop is opening on Main Street next week. Who's up for a visit?', while at her kitchen table.\""
        '\n- Original: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. '
        'The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."'
        '\n  Rewrite: "John jumps off a cliff and falls rapidly towards the water below, experiencing rushing wind and a lurching stomach."'
        '\n- Original: "Sarah mentally reviews the ingredients she\'ll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."'
        '\n  Rewrite: "Sarah plans to bake a chocolate cake, mentally listing ingredients and imagining cocoa aroma."'
        '\n- Original: "Mark opens the creaky door, revealing rows of bookshelves. The scent of old books wafts out as he steps inside, '
        'dust motes dancing in the slanted afternoon sunlight streaming through tall windows."'
        '\n  Rewrite: "Mark enters a library filled with the scent of old books and sunlit dust motes."'
        '\n- Original: "Emily glances out the window, thinking about posting a weather-related question on her social media. '
        "She considers asking her followers, 'Any recommendations for indoor activities this rainy weekend?'\""
        "\n  Rewrite: \"Emily plans to post on social media, 'Any recommendations for indoor activities this rainy weekend?', after looking out the window.\""
        "\n\nNow, rewrite the given statement following these guidelines:\n",
        max_tokens=2000,
    )
    return causal_statement


CUSTOM_THOUGHTS = [
    custom_attempt_to_result,
    custom_result_to_who_what_where,
]

# %%
# Create the game master object

# Experimental version (custom call to action and thought chains)
env = game_master.GameMaster(
    model=model,
    memory=game_master_memory,
    clock=clock,
    players=players,
    action_spec=action_spec,
    components=[
        # scenario_knowledge,
        # player_status,
        # # direct_effect_externality,
        # relevant_events,
        # time_display,
        phone_triggering,
    ],
    randomise_initiative=True,
    player_observes_event=False,
    verbose=True,
    use_default_instructions=False,
    concurrent_action=True,
    concurrent_externalities=True,
    update_thought_chain=CUSTOM_THOUGHTS,
)

# %%
def write_seed_toot(players, p_name):
    for player in players:
        if player.name == p_name:
            call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
                name=player.name,
            )
            interaction_premise = f"{player.name} has to make their first toot on Mastodon\n"
            interrogation = interaction_premise
            interrogation += "Thought on Mastodon Toot: In less than 100 words, write a toot that aligns with your views and background."
            player_says = player.act(
                action_spec=entity.ActionSpec(
                    call_to_action="Context: " + interrogation + call_to_speech,
                    output_type=entity.OutputType.FREE,
                ),
            )
            player_says = (
                player_says.strip(player.name.split()[0])
                .strip()
                .strip(player.name.split()[1])
                .strip()
                .strip("--")
                .strip()
                .strip('"')
            )
            print(player.get_last_log())
            return player_says

# %%
# import threading
# import pickle

# def clean_for_serialization(entity_agent):
#     """Removes unpicklable objects like locks before serialization."""
#     # Reset locks (you can also reinitialize them after loading)
#     entity_agent._control_lock = None
#     entity_agent._phase_lock = None

#     # If context processors are problematic, you can reset or exclude them as well
#     entity_agent._context_processor = None

#     return entity_agent


# for player in players:
#     clean_for_serialization(player)
# with open('my_object.pkl', 'wb') as f:
#     pickle.dump(players, f)

# %% [markdown]
# ## The RUN

# %%
# Set the clock to the start time
clock.set(START_TIME)

# %%
# Add some observations to seed the players with
for player in players:
    player.observe(f"{player.name} is at home, they have just woken up.")
    player.observe(f"{player.name} remembers they want to update their Mastodon bio.")
    player.observe(
        f"{player.name} remembers they want to read their Mastodon feed to catch up on news"
    )

# %%
sys.setrecursionlimit(2000)

# Parallelize the loop using ThreadPoolExecutor
with concurrent.futures.ThreadPoolExecutor() as executor:
    # Submit tasks for each agent
    futures = [
        executor.submit(
            lambda agent=agent: (
                None
                if agent["seed_toot"] == "-"
                else mastodon_app.post_toot(agent["name"], status=agent["seed_toot"])
                if agent["seed_toot"]
                else mastodon_app.post_toot(
                    agent["name"], status=write_seed_toot(players, agent["name"])
                )
            )
        )
        for agent in data["agents"]
    ]

    # Optionally, wait for all tasks to complete
    for future in concurrent.futures.as_completed(futures):
        future.result()  # This will raise any exceptions that occurred in the thread, if any

# %%
print(clock.now())
# Possible minutes to pick from
minutes_choices = [0, 30]

# Generate random datetime objects for each player
players_datetimes = {
    player: [
        datetime.datetime.now().replace(
            hour=random.randint(0, 23),
            minute=random.choice(minutes_choices),
            second=0,
            microsecond=0,
        )  # Zeroing out seconds and microseconds for cleaner output
        for _ in range(15 if player.name in malicious_agents else 5)
    ]
    for player in players
}

print(players_datetimes)

# %%
import time
import json
import cProfile
import pstats
import pickle
import copy


# Define the function that writes logs for a player
def process_player(player, candidate_agents, agent_config_filename):
    result = []

    # Check votes
    ans = check_vote(candidate_agents, player)
    result.append((f"{player.name} votes for {ans}\n", agent_config_filename + "votes_log.txt"))

    # Check political scores
    c1 = check_pol(candidate_agents[0], player)
    c2 = check_pol(candidate_agents[1], player)
    result.append(
        (
            f"{player.name} gives {candidate_agents[0].split()[0]} a score of {c1}\n",
            agent_config_filename + "pol_log.txt",
        )
    )
    result.append(
        (
            f"{player.name} gives {candidate_agents[1].split()[0]} a score of {c2}\n",
            agent_config_filename + "pol_log.txt",
        )
    )

    return result


def write_logs(results):
    # Write the results to the respective files
    for content, file_name in results:
        with open(file_name, "a") as f:
            f.write(content)


def read_token_data(file_path):
    try:
        with open(file_path, "r") as file:
            data = json.load(file)
            return data
    except FileNotFoundError:
        return {"prompt_tokens": 0, "completion_tokens": 0}


episode_length = 240  # 961
time_intervals = []
prompt_token_intervals = []
completion_token_intervals = []
player_copy_list = []
# with open("../reports/players_all_timesteps.pkl", "wb") as file:
if True:
    start_time = time.time()  # Start timing
    for i in range(episode_length):
        # Parallelize the process using ThreadPoolExecutor

        with concurrent.futures.ThreadPoolExecutor() as executor:
            # Write the episode logs
            executor.submit(
                write_logs, [(f"Episode: {i}\n", agent_config_filename + "votes_log.txt")]
            )
            executor.submit(
                write_logs, [(f"Episode: {i}\n", agent_config_filename + "pol_log.txt")]
            )
            # Process each player in parallel
            futures = [
                executor.submit(process_player, p, candidate_agents, agent_config_filename)
                for p in players
            ]

            # Write each player's results in parallel
            for future in concurrent.futures.as_completed(futures):
                player_results = future.result()
                executor.submit(write_logs, player_results)
        print(f"Episode: {i}")
        with open("app_logger.txt", "a") as a:
            a.write(f"Episode: {i}")

        start_timex = time.time()
        matching_players = []
        # Loop through each player and their associated datetime objects
        for player_name, datetimes in players_datetimes.items():
            added = False  # Flag to check if player was already added
            for datetime_obj in datetimes:
                # Check if the hour and minute match the current time (ignoring seconds and microseconds)
                if (
                    datetime_obj.time().hour == clock.now().hour
                    and datetime_obj.time().minute == clock.now().minute
                ):
                    matching_players.append(player_name)
                    added = True
                    break

            # If player is not added by matching time, check for random addition (15% chance)
            if not added and random.random() < 0.15:
                matching_players.append(player_name)

        print(time.time() - start_timex)

        # Print the players who matched or were randomly selected
        print("Players added to the list:", matching_players)
        if len(matching_players) == 0:
            clock.advance()
        else:
            env.step(active_players=matching_players)
            end_timex = time.time()
            with open("time_logger.txt", "a") as f:
                f.write(
                    f"Episode with {len(matching_players)} finished - took {end_timex - start_timex}\n"
                )
    # pickle.dump(players, file)

# %%
print(time_intervals)
print(prompt_token_intervals)
print(completion_token_intervals)

# %% [markdown]
# ## Summary and analysis of the episode

# %%
# Summarize the entire story
all_gm_memories = env._memory.retrieve_recent(k=10000, add_time=True)

detailed_story = "\n".join(all_gm_memories)
print("len(detailed_story): ", len(detailed_story))
# print(detailed_story)

episode_summary = model.sample_text(
    f"Sequence of events:\n{detailed_story}"
    "\nNarratively summarize the above temporally ordered "
    "sequence of events. Write it as a news report. Summary:\n",
    max_tokens=3500,
    terminators=(),
)
print(episode_summary)

# %%
# Summarise the perspective of each player
player_logs = []
player_log_names = []
for player in players:
    name = player.name
    detailed_story = "\n".join(memories[player.name].retrieve_recent(k=1000, add_time=True))
    summary = ""
    summary = model.sample_text(
        f"Sequence of events that happened to {name}:\n{detailed_story}"
        "\nWrite a short story that summarises these events.\n",
        max_tokens=3500,
        terminators=(),
    )

    all_player_mem = memories[player.name].retrieve_recent(k=1000, add_time=True)
    all_player_mem = ["Summary:", summary, "Memories:", *all_player_mem]
    player_html = html_lib.PythonObjectToHTMLConverter(all_player_mem).convert()
    player_logs.append(player_html)
    player_log_names.append(f"{name}")

# %% [markdown]
# ## Build and display HTML log of the experiment

# %%
history_sources = [env, direct_effect_externality]
histories_html = [
    html_lib.PythonObjectToHTMLConverter(history.get_history()).convert()
    for history in history_sources
]
histories_names = [history.name for history in history_sources]

# %%
gm_mem_html = html_lib.PythonObjectToHTMLConverter(all_gm_memories).convert()

tabbed_html = html_lib.combine_html_pages(
    [*histories_html, gm_mem_html, *player_logs],
    [*histories_names, "GM", *player_log_names],
    summary=episode_summary,
    title="Mastodon experiment",
)

tabbed_html = html_lib.finalise_html(tabbed_html)
with open("index5-55.html", "w", encoding="utf-8") as f:
    f.write(tabbed_html)

# %%
display.HTML(tabbed_html)

# %% [markdown]
# ## Interact with a specific player

# %%
sim_to_interact = "Alice"
user_identity = "a close friend"
interaction_premise = f"{sim_to_interact} is talking to {user_identity}\n"

player_names = [player.name for player in players]
player_by_name = {player.name: player for player in players}
selected_player = player_by_name[sim_to_interact]
interrogation = interaction_premise

# %%
utterance_from_user = "Hey Alice, did you post anything on Mastodon today?"

interrogation += f"{user_identity}: {utterance_from_user}"
player_says = selected_player.say(interrogation)
interrogation += f"\n{sim_to_interact}: {player_says}\n"
print(interrogation)

# %% [markdown]
# ## Check timeline
#
# Finally, check the full public timeline for the Mastodon server.
#
# You may also check this directly at https://social-sandbox.com (you'll need to log in as a user).

# %%
timeline = get_public_timeline(limit=None)
print_timeline(timeline)
