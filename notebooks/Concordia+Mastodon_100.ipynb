# %% [markdown]
# # Concordia <> Mastodon Example

# %% [markdown]
# ## Introduction
#
# **Purpose of the Simulation**
#
# This notebook demonstrates a generative agent simulation of a Mastodon instance using the Concordia framework.
# The simulation models user behavior on a local Mastodon server, showcasing how AI agents interact in a
# decentralized social media environment.

# %% [markdown]
# ## Setup and imports

# %% [markdown]
# All of the necessary dependencies should be installed in the environment prior to running this notebook. If not, install them using poetry:
#
# ```bash
# poetry install
# ```
#
#
# Alternatively, you may install the library in editable mode so that we can make changes to the code if necessary:
#
# ```bash
# git clone https://github.com/gdm-concordia/concordia.git
# cd concordia
# pip install -e . --config-settings editable_mode=compat
# ```

# %%
# %load_ext autoreload
# %autoreload 2

import concurrent.futures
import datetime
import os
import random
import warnings

with warnings.catch_warnings():
    warnings.filterwarnings("ignore")
    import sentence_transformers
import sys
sys.path.insert(0, '../concordia')
# import concordia_dev
# print(concordia_dev.__file__)
from concordia import components as generic_components
from concordia.agents import deprecated_agent, entity_agent_with_logging
from concordia.components.agent import to_be_deprecated as old_components
from concordia.associative_memory import (
    associative_memory,
    blank_memories,
    formative_memories,
    importance_function,
)
from concordia.memory_bank import legacy_associative_memory

from concordia.clocks import game_clock
from concordia.components import agent as new_components
from concordia.components import game_master as gm_components
# from concordia_dev.environment import game_master
# from concordia_dev.language_model import amazon_bedrock_model, gpt_model
from concordia.environment import game_master
from concordia.language_model import amazon_bedrock_model, gpt_model
from concordia.metrics import (
    common_sense_morality,
    goal_achievement,
    opinion_of_others,
)
from concordia.language_model import language_model

from concordia.utils import html as html_lib
from concordia.utils import measurements as measurements_lib
from IPython import display

from mastodon_sim.concordia import apps, triggering

from mastodon_sim.mastodon_ops import check_env, get_public_timeline, print_timeline, reset_users
from mastodon_sim.mastodon_utils import get_users_from_env
import concurrent.futures
import re
import json

# %% [markdown]
# ## Mastodon Server Interaction Setting
#
# Decide whether this example should perform real operations on the Mastodon server. Note that this requires being able to successfully run the `Mastodon.ipynb` example as a prerequisite.

# %%
USE_MASTODON_SERVER = True

# %% [markdown]
# ## Check environment

# %% [markdown]
# Check for a `.env` file with the nessesary environment variables. You should see an output similar to this if successful:
#
# ```log
# 2024-07-17T11:38:17.213066-0400 INFO Successfully loaded .env file.
# 2024-07-17T11:38:17.214151-0400 INFO API_BASE_URL: https://social-sandbox.com
# 2024-07-17T11:38:17.214581-0400 INFO EMAIL_PREFIX: austinmw89
# 2024-07-17T11:38:17.215056-0400 INFO MASTODON_CLIENT_ID: N*****************************************E
# 2024-07-17T11:38:17.215477-0400 INFO MASTODON_CLIENT_SECRET: b*****************************************s
# 2024-07-17T11:38:17.215877-0400 INFO USER0005_PASSWORD: a******************************a
# 2024-07-17T11:38:17.216202-0400 INFO USER0002_PASSWORD: 8******************************b
# 2024-07-17T11:38:17.216655-0400 INFO USER0001_PASSWORD: 9******************************5
# 2024-07-17T11:38:17.217020-0400 INFO USER0004_PASSWORD: 7******************************e
# 2024-07-17T11:38:17.217323-0400 INFO USER0003_PASSWORD: f******************************6
# ```

# %%
if USE_MASTODON_SERVER:
    check_env()
# Out:
# 2024-09-12T05:08:55.999880+0530 INFO Successfully loaded .env file.
# 2024-09-12T05:08:56.001800+0530 INFO API_BASE_URL: https://social-sandbox.com
# 2024-09-12T05:08:56.001800+0530 INFO EMAIL_PREFIX: austinmw89
# 2024-09-12T05:08:56.001800+0530 INFO MASTODON_CLIENT_ID: N*****************************************E
# 2024-09-12T05:08:56.002800+0530 INFO MASTODON_CLIENT_SECRET: b*****************************************s
# 2024-09-12T05:08:56.002800+0530 INFO USER0001_PASSWORD: 9******************************5
# 2024-09-12T05:08:56.003801+0530 INFO USER0002_PASSWORD: 8******************************b
# 2024-09-12T05:08:56.003801+0530 INFO USER0003_PASSWORD: f******************************6
# 2024-09-12T05:08:56.004800+0530 INFO USER0004_PASSWORD: 7******************************e
# 2024-09-12T05:08:56.005800+0530 INFO USER0005_PASSWORD: a******************************a
# 2024-09-12T05:08:56.006800+0530 INFO USER0006_PASSWORD: f******************************c
# 2024-09-12T05:08:56.006800+0530 INFO USER0007_PASSWORD: 8******************************e
# 2024-09-12T05:08:56.007799+0530 INFO USER0008_PASSWORD: 0******************************9
# 2024-09-12T05:08:56.007799+0530 INFO USER0009_PASSWORD: 2******************************a
# 2024-09-12T05:08:56.008800+0530 INFO USER0010_PASSWORD: 5******************************3
# 2024-09-12T05:08:56.008800+0530 INFO USER0011_PASSWORD: b******************************2
# 2024-09-12T05:08:56.008800+0530 INFO USER0012_PASSWORD: a******************************4
# 2024-09-12T05:08:56.009799+0530 INFO USER0013_PASSWORD: d******************************6
# 2024-09-12T05:08:56.009799+0530 INFO USER0014_PASSWORD: f******************************e
# 2024-09-12T05:08:56.010800+0530 INFO USER0015_PASSWORD: 3******************************8
# 2024-09-12T05:08:56.010800+0530 INFO USER0016_PASSWORD: 5******************************f
# 2024-09-12T05:08:56.010800+0530 INFO USER0017_PASSWORD: 2******************************e
# 2024-09-12T05:08:56.011799+0530 INFO USER0018_PASSWORD: e******************************4
# 2024-09-12T05:08:56.011799+0530 INFO USER0019_PASSWORD: d******************************3
# 2024-09-12T05:08:56.012799+0530 INFO USER0020_PASSWORD: 0******************************0
# 2024-09-12T05:08:56.012799+0530 INFO USER0021_PASSWORD: 6******************************6
# 2024-09-12T05:08:56.013801+0530 INFO USER0022_PASSWORD: 9******************************2
# 2024-09-12T05:08:56.013801+0530 INFO USER0023_PASSWORD: 1******************************7
# 2024-09-12T05:08:56.014800+0530 INFO USER0024_PASSWORD: 1******************************a
# 2024-09-12T05:08:56.015801+0530 INFO USER0025_PASSWORD: 5******************************f
# 2024-09-12T05:08:56.015801+0530 INFO USER0026_PASSWORD: a******************************6
# 2024-09-12T05:08:56.016800+0530 INFO USER0027_PASSWORD: 4******************************4
# 2024-09-12T05:08:56.016800+0530 INFO USER0028_PASSWORD: 1******************************0
# 2024-09-12T05:08:56.017800+0530 INFO USER0029_PASSWORD: 5******************************9
# 2024-09-12T05:08:56.017800+0530 INFO USER0030_PASSWORD: 4******************************d
# 2024-09-12T05:08:56.018800+0530 INFO USER0031_PASSWORD: a******************************2
# 2024-09-12T05:08:56.018800+0530 INFO USER0032_PASSWORD: 0******************************e
# 2024-09-12T05:08:56.019800+0530 INFO USER0033_PASSWORD: b******************************8
# 2024-09-12T05:08:56.019800+0530 INFO USER0034_PASSWORD: 9******************************b
# 2024-09-12T05:08:56.020801+0530 INFO USER0035_PASSWORD: 7******************************9
# 2024-09-12T05:08:56.020801+0530 INFO USER0036_PASSWORD: 0******************************f
# 2024-09-12T05:08:56.021802+0530 INFO USER0037_PASSWORD: c******************************d
# 2024-09-12T05:08:56.021802+0530 INFO USER0038_PASSWORD: a******************************5
# 2024-09-12T05:08:56.022800+0530 INFO USER0039_PASSWORD: c******************************0
# 2024-09-12T05:08:56.022800+0530 INFO USER0040_PASSWORD: b******************************2
# 2024-09-12T05:08:56.023800+0530 INFO USER0041_PASSWORD: d******************************5
# 2024-09-12T05:08:56.023800+0530 INFO USER0042_PASSWORD: a******************************1
# 2024-09-12T05:08:56.023800+0530 INFO USER0043_PASSWORD: d******************************c
# 2024-09-12T05:08:56.024800+0530 INFO USER0044_PASSWORD: 6******************************8
# 2024-09-12T05:08:56.024800+0530 INFO USER0045_PASSWORD: d******************************e
# 2024-09-12T05:08:56.025800+0530 INFO USER0046_PASSWORD: 5******************************7
# 2024-09-12T05:08:56.026801+0530 INFO USER0047_PASSWORD: d******************************4
# 2024-09-12T05:08:56.026801+0530 INFO USER0048_PASSWORD: 6******************************1
# 2024-09-12T05:08:56.027801+0530 INFO USER0049_PASSWORD: 9******************************7
# 2024-09-12T05:08:56.027801+0530 INFO USER0050_PASSWORD: 9******************************3
# 2024-09-12T05:08:56.028800+0530 INFO USER0051_PASSWORD: f******************************1
# 2024-09-12T05:08:56.028800+0530 INFO USER0052_PASSWORD: d******************************c
# 2024-09-12T05:08:56.028800+0530 INFO USER0053_PASSWORD: 1******************************7
# 2024-09-12T05:08:56.029801+0530 INFO USER0054_PASSWORD: 6******************************e
# 2024-09-12T05:08:56.030800+0530 INFO USER0055_PASSWORD: a******************************1
# 2024-09-12T05:08:56.030800+0530 INFO USER0056_PASSWORD: e******************************c
# 2024-09-12T05:08:56.031800+0530 INFO USER0057_PASSWORD: d******************************a
# 2024-09-12T05:08:56.031800+0530 INFO USER0058_PASSWORD: 0******************************d
# 2024-09-12T05:08:56.032800+0530 INFO USER0059_PASSWORD: c******************************f
# 2024-09-12T05:08:56.032800+0530 INFO USER0060_PASSWORD: 1******************************2
# 2024-09-12T05:08:56.032800+0530 INFO USER0061_PASSWORD: d******************************f
# 2024-09-12T05:08:56.033800+0530 INFO USER0062_PASSWORD: d******************************7
# 2024-09-12T05:08:56.033800+0530 INFO USER0063_PASSWORD: e******************************b
# 2024-09-12T05:08:56.034800+0530 INFO USER0064_PASSWORD: b******************************f
# 2024-09-12T05:08:56.034800+0530 INFO USER0065_PASSWORD: b******************************e
# 2024-09-12T05:08:56.035800+0530 INFO USER0066_PASSWORD: a******************************0
# 2024-09-12T05:08:56.035800+0530 INFO USER0067_PASSWORD: 1******************************0
# 2024-09-12T05:08:56.036800+0530 INFO USER0068_PASSWORD: e******************************b
# 2024-09-12T05:08:56.036800+0530 INFO USER0069_PASSWORD: 8******************************f
# 2024-09-12T05:08:56.036800+0530 INFO USER0070_PASSWORD: 4******************************c
# 2024-09-12T05:08:56.037800+0530 INFO USER0071_PASSWORD: 9******************************5
# 2024-09-12T05:08:56.037800+0530 INFO USER0072_PASSWORD: 7******************************a
# 2024-09-12T05:08:56.038799+0530 INFO USER0073_PASSWORD: d******************************6
# 2024-09-12T05:08:56.038799+0530 INFO USER0074_PASSWORD: 2******************************8
# 2024-09-12T05:08:56.040802+0530 INFO USER0075_PASSWORD: 1******************************0
# 2024-09-12T05:08:56.040802+0530 INFO USER0076_PASSWORD: 9******************************3
# 2024-09-12T05:08:56.041801+0530 INFO USER0077_PASSWORD: 9******************************5
# 2024-09-12T05:08:56.041801+0530 INFO USER0078_PASSWORD: 8******************************8
# 2024-09-12T05:08:56.042801+0530 INFO USER0079_PASSWORD: a******************************a
# 2024-09-12T05:08:56.042801+0530 INFO USER0080_PASSWORD: b******************************9
# 2024-09-12T05:08:56.043801+0530 INFO USER0081_PASSWORD: 6******************************3
# 2024-09-12T05:08:56.043801+0530 INFO USER0082_PASSWORD: 6******************************6
# 2024-09-12T05:08:56.044799+0530 INFO USER0083_PASSWORD: e******************************f
# 2024-09-12T05:08:56.044799+0530 INFO USER0084_PASSWORD: f******************************3
# 2024-09-12T05:08:56.044799+0530 INFO USER0085_PASSWORD: 3******************************d
# 2024-09-12T05:08:56.045800+0530 INFO USER0086_PASSWORD: a******************************5
# 2024-09-12T05:08:56.046800+0530 INFO USER0087_PASSWORD: 4******************************7
# 2024-09-12T05:08:56.046800+0530 INFO USER0088_PASSWORD: d******************************5
# 2024-09-12T05:08:56.046800+0530 INFO USER0089_PASSWORD: d******************************8
# 2024-09-12T05:08:56.047799+0530 INFO USER0090_PASSWORD: 7******************************0
# 2024-09-12T05:08:56.047799+0530 INFO USER0091_PASSWORD: b******************************f
# 2024-09-12T05:08:56.048800+0530 INFO USER0092_PASSWORD: c******************************4
# 2024-09-12T05:08:56.048800+0530 INFO USER0093_PASSWORD: e******************************3
# 2024-09-12T05:08:56.048800+0530 INFO USER0094_PASSWORD: 1******************************5
# 2024-09-12T05:08:56.049799+0530 INFO USER0095_PASSWORD: 7******************************0
# 2024-09-12T05:08:56.049799+0530 INFO USER0096_PASSWORD: 5******************************7
# 2024-09-12T05:08:56.050800+0530 INFO USER0097_PASSWORD: 4******************************6
# 2024-09-12T05:08:56.050800+0530 INFO USER0098_PASSWORD: 5******************************f
# 2024-09-12T05:08:56.051800+0530 INFO USER0099_PASSWORD: 1******************************8
# 2024-09-12T05:08:56.051800+0530 INFO USER0100_PASSWORD: e******************************8

# %% [markdown]
# ## Clear Mastodon server
# Deletes from https://social-sandbox.com all posts, follows, likes, etc. from all users in the .env file.
#
# TODO: The Mastodon server's [default API rate limits](https://docs.joinmastodon.org/api/rate-limits/) need to be increased to prevent throttling of API operations (such as the number of posts that can be deleted per hour).

# %%
if USE_MASTODON_SERVER:
    # Get all users from .env file
    users = get_users_from_env()

    reset_users(users, skip_confirm=True, parallel=True)

    assert not len(get_public_timeline(limit=None)), "All posts not cleared"
# Out:
# 2024-09-12T05:09:03.143199+0530 INFO Starting comprehensive reset process for user: user0013
# 2024-09-12T05:09:03.326302+0530 INFO Starting comprehensive reset process for user: user0005
# 2024-09-12T05:09:03.335333+0530 INFO Starting comprehensive reset process for user: user0015
# 2024-09-12T05:09:04.131224+0530 INFO Starting comprehensive reset process for user: user0021
# 2024-09-12T05:09:04.226745+0530 INFO Starting comprehensive reset process for user: user0007
# 2024-09-12T05:09:04.336105+0530 INFO Starting comprehensive reset process for user: user0024
# 2024-09-12T05:09:04.434316+0530 INFO Starting comprehensive reset process for user: user0016
# 2024-09-12T05:09:04.445303+0530 INFO Starting comprehensive reset process for user: user0012
# 2024-09-12T05:09:04.731402+0530 INFO Starting comprehensive reset process for user: user0006
# 2024-09-12T05:09:04.827200+0530 INFO Starting comprehensive reset process for user: user0002
# 2024-09-12T05:09:04.838224+0530 INFO Starting comprehensive reset process for user: user0010
# 2024-09-12T05:09:04.921285+0530 INFO Starting comprehensive reset process for user: user0022
# 2024-09-12T05:09:04.940794+0530 INFO Starting comprehensive reset process for user: user0004
# 2024-09-12T05:09:04.940794+0530 INFO Starting comprehensive reset process for user: user0008
# 2024-09-12T05:09:05.031040+0530 INFO Starting comprehensive reset process for user: user0020
# 2024-09-12T05:09:05.054530+0530 INFO Starting comprehensive reset process for user: user0009
# 2024-09-12T05:09:05.134689+0530 INFO Starting comprehensive reset process for user: user0017
# 2024-09-12T05:09:05.237866+0530 INFO Starting comprehensive reset process for user: user0014
# 2024-09-12T05:09:05.366856+0530 INFO Starting comprehensive reset process for user: user0019
# 2024-09-12T05:09:05.430810+0530 INFO Starting comprehensive reset process for user: user0003
# 2024-09-12T05:09:05.434858+0530 INFO Starting comprehensive reset process for user: user0028
# 2024-09-12T05:09:05.528095+0530 INFO Starting comprehensive reset process for user: user0011
# 2024-09-12T05:09:05.537015+0530 INFO Starting comprehensive reset process for user: user0001
# 2024-09-12T05:09:05.636553+0530 INFO Starting comprehensive reset process for user: user0025
# 2024-09-12T05:09:05.646554+0530 INFO Starting comprehensive reset process for user: user0023
# 2024-09-12T05:09:05.726932+0530 INFO Starting comprehensive reset process for user: user0018
# 2024-09-12T05:09:07.143645+0530 INFO Starting comprehensive reset process for user: user0027
# 2024-09-12T05:09:07.530650+0530 INFO Starting comprehensive reset process for user: user0026
# 2024-09-12T05:09:10.038869+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:10.444702+0530 INFO Successfully deleted post with ID: 113119492206187417
# 2024-09-12T05:09:10.527874+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:10.627457+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:10.930525+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:10.937519+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:11.326082+0530 INFO Successfully deleted post with ID: 113116231419267861
# 2024-09-12T05:09:11.326082+0530 INFO Deletion process completed. Attempted to delete 2 post(s).
# 2024-09-12T05:09:11.435076+0530 INFO Successfully deleted post with ID: 113118759749231527
# 2024-09-12T05:09:11.447081+0530 INFO Successfully deleted post with ID: 113120697501170993
# 2024-09-12T05:09:11.548597+0530 INFO Successfully deleted post with ID: 113120649276689799
# 2024-09-12T05:09:11.556597+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:11.617560+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:11.633684+0530 INFO Successfully deleted post with ID: 113116226321446528
# 2024-09-12T05:09:11.634684+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T05:09:11.840057+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:12.127738+0530 INFO Successfully deleted post with ID: 113120684643212508
# 2024-09-12T05:09:12.225811+0530 INFO Successfully deleted post with ID: 113118432433163206
# 2024-09-12T05:09:12.226806+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:12.338154+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:12.422106+0530 INFO Successfully deleted post with ID: 113119187721113377
# 2024-09-12T05:09:12.441129+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:12.636971+0530 INFO Successfully deleted post with ID: 113118895170274057
# 2024-09-12T05:09:12.640977+0530 INFO Successfully deleted post with ID: 113116229291925042
# 2024-09-12T05:09:12.641971+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T05:09:12.738657+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:12.839142+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:12.948541+0530 INFO Successfully deleted post with ID: 113119034956613875
# 2024-09-12T05:09:13.046907+0530 INFO Successfully deleted post with ID: 113116227178733432
# 2024-09-12T05:09:13.047907+0530 INFO Deletion process completed. Attempted to delete 3 post(s).
# 2024-09-12T05:09:13.128447+0530 INFO Successfully deleted post with ID: 113118753763267441
# 2024-09-12T05:09:13.155448+0530 INFO Successfully deleted post with ID: 113120399223623329
# 2024-09-12T05:09:13.328950+0530 INFO Successfully deleted post with ID: 113120736448597779
# 2024-09-12T05:09:13.621151+0530 INFO Successfully deleted post with ID: 113116236150063378
# 2024-09-12T05:09:13.622151+0530 INFO Deletion process completed. Attempted to delete 2 post(s).
# 2024-09-12T05:09:13.625152+0530 INFO Successfully deleted post with ID: 113119520502673879
# 2024-09-12T05:09:13.627152+0530 INFO Successfully deleted post with ID: 113120451986939603
# 2024-09-12T05:09:13.638091+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:13.843282+0530 INFO Successfully deleted post with ID: 113118146469696674
# 2024-09-12T05:09:13.964327+0530 INFO Successfully deleted post with ID: 113116232683887578
# 2024-09-12T05:09:13.965320+0530 INFO Deletion process completed. Attempted to delete 3 post(s).
# 2024-09-12T05:09:14.022286+0530 INFO Successfully deleted post with ID: 113118711466090029
# 2024-09-12T05:09:14.352368+0530 INFO Successfully deleted post with ID: 113118570457233932
# 2024-09-12T05:09:14.356367+0530 INFO Successfully deleted post with ID: 113116228604783494
# 2024-09-12T05:09:14.357369+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T05:09:14.439704+0530 INFO Successfully deleted post with ID: 113119214259488646
# 2024-09-12T05:09:14.537890+0530 INFO Successfully deleted post with ID: 113116235474290489
# 2024-09-12T05:09:14.538890+0530 INFO Deletion process completed. Attempted to delete 2 post(s).
# 2024-09-12T05:09:14.630821+0530 INFO Attempting to unfollow 0 users for user0024...
# 2024-09-12T05:09:14.631821+0530 INFO Successfully unfollowed 0 out of 0 users for user0024.
# 2024-09-12T05:09:14.740973+0530 INFO Successfully deleted post with ID: 113116230618583305
# 2024-09-12T05:09:14.742974+0530 INFO Deletion process completed. Attempted to delete 4 post(s).
# 2024-09-12T05:09:14.830506+0530 INFO Successfully deleted post with ID: 113118725258910135
# 2024-09-12T05:09:14.833506+0530 INFO Successfully deleted post with ID: 113119183665956174
# 2024-09-12T05:09:15.258647+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:15.259649+0530 INFO Comprehensive reset process completed for user: user0024
# 2024-09-12T05:09:15.269649+0530 INFO Successfully deleted post with ID: 113116222697578094
# 2024-09-12T05:09:15.270649+0530 INFO Deletion process completed. Attempted to delete 3 post(s).
# 2024-09-12T05:09:15.329679+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:15.336678+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:15.375680+0530 INFO Successfully deleted post with ID: 113118158544794414
# 2024-09-12T05:09:15.418189+0530 INFO Removed 1 out of 1 favourites.
# 2024-09-12T05:09:15.462180+0530 INFO Successfully deleted post with ID: 113117976669723113
# 2024-09-12T05:09:15.532791+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:15.719832+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:15.726835+0530 WARNING Failed to remove favourite 113117976669723113: ('Mastodon API returned error', 500, 'Internal Server Error', None)
# 2024-09-12T05:09:15.727832+0530 INFO Removed 0 out of 1 favourites.
# 2024-09-12T05:09:15.749832+0530 INFO Removed 1 out of 1 favourites.
# 2024-09-12T05:09:15.857572+0530 INFO Removed 1 out of 1 favourites.
# 2024-09-12T05:09:15.863572+0530 WARNING Failed to remove favourite 113117976669723113: ('Mastodon API returned error', 500, 'Internal Server Error', None)
# 2024-09-12T05:09:15.948086+0530 INFO Successfully deleted post with ID: 113116232039600710
# 2024-09-12T05:09:15.948086+0530 INFO Deletion process completed. Attempted to delete 2 post(s).
# 2024-09-12T05:09:16.124199+0530 INFO Attempting to unfollow 0 users for user0026...
# 2024-09-12T05:09:16.125198+0530 INFO Successfully unfollowed 0 out of 0 users for user0026.
# 2024-09-12T05:09:16.138217+0530 INFO Attempting to unfollow 0 users for user0021...
# 2024-09-12T05:09:16.138217+0530 INFO Successfully unfollowed 0 out of 0 users for user0021.
# 2024-09-12T05:09:16.239973+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:16.333463+0530 INFO Attempting to unfollow 0 users for user0023...
# 2024-09-12T05:09:16.334234+0530 INFO Successfully unfollowed 0 out of 0 users for user0023.
# 2024-09-12T05:09:16.447208+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:16.541284+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:16.626057+0530 INFO Removed 1 out of 1 favourites.
# 2024-09-12T05:09:16.634058+0530 INFO Successfully deleted post with ID: 113116224867363515
# 2024-09-12T05:09:16.635058+0530 INFO Deletion process completed. Attempted to delete 3 post(s).
# 2024-09-12T05:09:16.650770+0530 INFO Removed 1 out of 2 favourites.
# 2024-09-12T05:09:16.741193+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:16.742196+0530 INFO Comprehensive reset process completed for user: user0021
# 2024-09-12T05:09:16.829615+0530 INFO Successfully deleted post with ID: 113116234084333924
# 2024-09-12T05:09:16.830615+0530 INFO Deletion process completed. Attempted to delete 4 post(s).
# 2024-09-12T05:09:16.830615+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:16.832615+0530 INFO Comprehensive reset process completed for user: user0026
# 2024-09-12T05:09:16.955739+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:17.018415+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:17.056180+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:17.123238+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:17.135224+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:17.432620+0530 INFO Removed 1 out of 1 favourites.
# 2024-09-12T05:09:17.631214+0530 INFO Attempting to unfollow 7 users for user0009...
# 2024-09-12T05:09:17.639217+0530 INFO Successfully deleted post with ID: 113116292489731887
# 2024-09-12T05:09:17.730568+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:17.744115+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:17.919695+0530 INFO Attempting to unfollow 12 users for user0006...
# 2024-09-12T05:09:17.943697+0530 INFO Successfully deleted post with ID: 113119456238984508
# 2024-09-12T05:09:18.038612+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:18.041625+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:18.131837+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:18.142837+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:18.143838+0530 INFO Comprehensive reset process completed for user: user0023
# 2024-09-12T05:09:18.229503+0530 INFO Successfully deleted post with ID: 113116223406698966
# 2024-09-12T05:09:18.231506+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:18.231506+0530 INFO Deletion process completed. Attempted to delete 5 post(s).
# 2024-09-12T05:09:18.333841+0530 INFO Attempting to unfollow 10 users for user0013...
# 2024-09-12T05:09:18.640733+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:18.768860+0530 INFO Starting comprehensive reset process for user: user0029
# 2024-09-12T05:09:18.921068+0530 INFO Attempting to unfollow 9 users for user0017...
# 2024-09-12T05:09:19.021564+0530 INFO Successfully deleted post with ID: 113119451673819798
# 2024-09-12T05:09:19.048802+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:19.124936+0530 INFO Attempting to unfollow 0 users for user0027...
# 2024-09-12T05:09:19.125935+0530 INFO Successfully unfollowed 0 out of 0 users for user0027.
# 2024-09-12T05:09:19.150279+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:19.358787+0530 INFO Attempting to unfollow 12 users for user0012...
# 2024-09-12T05:09:19.440616+0530 INFO Attempting to unfollow 7 users for user0001...
# 2024-09-12T05:09:19.617706+0530 INFO Starting comprehensive reset process for user: user0030
# 2024-09-12T05:09:19.618706+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:19.756578+0530 INFO Attempting to unfollow 8 users for user0010...
# 2024-09-12T05:09:19.842032+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:19.939058+0530 INFO Attempting to unfollow 9 users for user0020...
# 2024-09-12T05:09:20.236218+0530 INFO Attempting to unfollow 14 users for user0015...
# 2024-09-12T05:09:20.248218+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:20.332364+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:20.333365+0530 INFO Comprehensive reset process completed for user: user0027
# 2024-09-12T05:09:20.622344+0530 INFO Successfully deleted post with ID: 113119429052793635
# 2024-09-12T05:09:20.639819+0530 INFO Attempting to unfollow 9 users for user0004...
# 2024-09-12T05:09:20.823844+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:21.538797+0530 INFO Successfully deleted post with ID: 113119420070674470
# 2024-09-12T05:09:21.549797+0530 INFO Starting comprehensive reset process for user: user0032
# 2024-09-12T05:09:21.827073+0530 INFO Attempting to unfollow 11 users for user0014...
# 2024-09-12T05:09:22.346789+0530 INFO user0009 has unfollowed user0017.
# 2024-09-12T05:09:22.359342+0530 INFO Attempting to unfollow 12 users for user0019...
# 2024-09-12T05:09:22.634469+0530 INFO Successfully deleted post with ID: 113118068794837396
# 2024-09-12T05:09:22.733428+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:22.935865+0530 INFO Starting comprehensive reset process for user: user0031
# 2024-09-12T05:09:23.025060+0530 INFO Starting comprehensive reset process for user: user0033
# 2024-09-12T05:09:23.340162+0530 INFO user0013 has unfollowed user0020.
# 2024-09-12T05:09:23.433055+0530 INFO Successfully deleted post with ID: 113116234762462891
# 2024-09-12T05:09:23.433055+0530 INFO Deletion process completed. Attempted to delete 6 post(s).
# 2024-09-12T05:09:23.438055+0530 INFO Attempting to unfollow 8 users for user0002...
# 2024-09-12T05:09:23.630196+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:23.723677+0530 INFO user0006 has unfollowed user0018.
# 2024-09-12T05:09:23.731770+0530 INFO Attempting to unfollow 0 users for user0025...
# 2024-09-12T05:09:23.733676+0530 INFO Successfully unfollowed 0 out of 0 users for user0025.
# 2024-09-12T05:09:24.021007+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:24.047152+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:24.331366+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:24.332368+0530 INFO Comprehensive reset process completed for user: user0025
# 2024-09-12T05:09:25.033312+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:25.037305+0530 INFO user0001 has unfollowed user0014.
# 2024-09-12T05:09:25.046303+0530 INFO user0012 has unfollowed user0019.
# 2024-09-12T05:09:25.129520+0530 INFO user0020 has unfollowed user0013.
# 2024-09-12T05:09:25.318304+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:25.526125+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:25.554215+0530 INFO user0017 has unfollowed user0015.
# 2024-09-12T05:09:25.829963+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:25.859887+0530 INFO Attempting to unfollow 0 users for user0030...
# 2024-09-12T05:09:25.860879+0530 INFO Successfully unfollowed 0 out of 0 users for user0030.
# 2024-09-12T05:09:25.951699+0530 INFO user0010 has unfollowed user0019.
# 2024-09-12T05:09:26.042679+0530 INFO user0015 has unfollowed user0018.
# 2024-09-12T05:09:26.124070+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:26.146961+0530 INFO user0004 has unfollowed user0012.
# 2024-09-12T05:09:26.560118+0530 INFO Successfully deleted post with ID: 113116233357794885
# 2024-09-12T05:09:26.561118+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T05:09:26.568125+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:26.625292+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:26.625292+0530 INFO Comprehensive reset process completed for user: user0030
# 2024-09-12T05:09:26.651293+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:27.242920+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:27.516995+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:27.632747+0530 INFO Attempting to unfollow 0 users for user0029...
# 2024-09-12T05:09:27.632747+0530 INFO Successfully unfollowed 0 out of 0 users for user0029.
# 2024-09-12T05:09:27.654748+0530 INFO user0019 has unfollowed user0020.
# 2024-09-12T05:09:27.841286+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:28.137574+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:28.138575+0530 INFO Comprehensive reset process completed for user: user0029
# 2024-09-12T05:09:28.239378+0530 INFO Starting comprehensive reset process for user: user0034
# 2024-09-12T05:09:28.331054+0530 INFO user0014 has unfollowed user0018.
# 2024-09-12T05:09:28.845893+0530 INFO user0009 has unfollowed user0015.
# 2024-09-12T05:09:28.854815+0530 INFO Successfully deleted post with ID: 113120712759453964
# 2024-09-12T05:09:28.937364+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:29.026603+0530 INFO Attempting to unfollow 12 users for user0018...
# 2024-09-12T05:09:29.220599+0530 INFO user0012 has unfollowed user0018.
# 2024-09-12T05:09:29.239600+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:29.444619+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:29.533937+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:29.619805+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:29.632808+0530 INFO Successfully deleted post with ID: 113116227905738636
# 2024-09-12T05:09:29.633860+0530 INFO Deletion process completed. Attempted to delete 2 post(s).
# 2024-09-12T05:09:29.818354+0530 INFO user0002 has unfollowed user0018.
# 2024-09-12T05:09:29.939127+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:30.635228+0530 INFO user0006 has unfollowed user0016.
# 2024-09-12T05:09:30.851440+0530 INFO user0020 has unfollowed user0005.
# 2024-09-12T05:09:30.934119+0530 INFO user0015 has unfollowed user0017.
# 2024-09-12T05:09:31.020979+0530 INFO user0001 has unfollowed user0013.
# 2024-09-12T05:09:31.127397+0530 INFO Starting comprehensive reset process for user: user0035
# 2024-09-12T05:09:31.331130+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:31.338122+0530 INFO Attempting to unfollow 0 users for user0032...
# 2024-09-12T05:09:31.338122+0530 INFO Successfully unfollowed 0 out of 0 users for user0032.
# 2024-09-12T05:09:31.438651+0530 INFO user0013 has unfollowed user0019.
# 2024-09-12T05:09:31.529619+0530 INFO Attempting to unfollow 0 users for user0033...
# 2024-09-12T05:09:31.529619+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:31.530619+0530 INFO Successfully unfollowed 0 out of 0 users for user0033.
# 2024-09-12T05:09:31.537627+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:31.633721+0530 INFO Attempting to unfollow 8 users for user0016...
# 2024-09-12T05:09:31.717144+0530 INFO Successfully deleted post with ID: 113119403789650167
# 2024-09-12T05:09:32.043669+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:32.043669+0530 INFO Comprehensive reset process completed for user: user0032
# 2024-09-12T05:09:32.236124+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:32.237115+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:32.239116+0530 INFO Comprehensive reset process completed for user: user0033
# 2024-09-12T05:09:32.248115+0530 INFO user0019 has unfollowed user0018.
# 2024-09-12T05:09:32.327729+0530 INFO user0010 has unfollowed user0012.
# 2024-09-12T05:09:32.432650+0530 INFO Starting comprehensive reset process for user: user0036
# 2024-09-12T05:09:32.615862+0530 INFO Attempting to unfollow 0 users for user0028...
# 2024-09-12T05:09:32.616855+0530 INFO Successfully unfollowed 0 out of 0 users for user0028.
# 2024-09-12T05:09:32.636864+0530 INFO Successfully deleted post with ID: 113118446806488772
# 2024-09-12T05:09:32.832167+0530 INFO Attempting to unfollow 0 users for user0031...
# 2024-09-12T05:09:32.833064+0530 INFO Successfully unfollowed 0 out of 0 users for user0031.
# 2024-09-12T05:09:32.927895+0530 INFO user0017 has unfollowed user0011.
# 2024-09-12T05:09:33.041430+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:33.042439+0530 INFO Comprehensive reset process completed for user: user0028
# 2024-09-12T05:09:33.141183+0530 INFO user0012 has unfollowed user0013.
# 2024-09-12T05:09:33.431965+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:33.432965+0530 INFO Comprehensive reset process completed for user: user0031
# 2024-09-12T05:09:33.934144+0530 INFO Successfully deleted post with ID: 113116224135039253
# 2024-09-12T05:09:33.935143+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:33.936134+0530 INFO Deletion process completed. Attempted to delete 3 post(s).
# 2024-09-12T05:09:34.017909+0530 INFO user0009 has unfollowed user0020.
# 2024-09-12T05:09:34.424774+0530 INFO user0006 has unfollowed user0015.
# 2024-09-12T05:09:34.753178+0530 INFO Attempting to unfollow 0 users for user0022...
# 2024-09-12T05:09:34.754195+0530 INFO Successfully unfollowed 0 out of 0 users for user0022.
# 2024-09-12T05:09:34.755193+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:34.918182+0530 INFO Attempting to unfollow 9 users for user0008...
# 2024-09-12T05:09:35.219281+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:35.241539+0530 INFO user0002 has unfollowed user0015.
# 2024-09-12T05:09:35.333089+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:35.334089+0530 INFO Comprehensive reset process completed for user: user0022
# 2024-09-12T05:09:35.536621+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:35.730520+0530 INFO user0020 has unfollowed user0003.
# 2024-09-12T05:09:35.817492+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:36.223779+0530 INFO user0013 has unfollowed user0017.
# 2024-09-12T05:09:36.329313+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:36.422693+0530 INFO Starting comprehensive reset process for user: user0040
# 2024-09-12T05:09:36.440977+0530 INFO Starting comprehensive reset process for user: user0037
# 2024-09-12T05:09:36.449018+0530 INFO user0004 has unfollowed user0005.
# 2024-09-12T05:09:36.457033+0530 INFO user0001 has unfollowed user0004.
# 2024-09-12T05:09:36.529086+0530 INFO user0016 has unfollowed user0018.
# 2024-09-12T05:09:36.646646+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:36.746576+0530 INFO user0019 has unfollowed user0012.
# 2024-09-12T05:09:36.856668+0530 INFO user0010 has unfollowed user0020.
# 2024-09-12T05:09:36.935573+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:37.063248+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:37.458794+0530 INFO user0012 has unfollowed user0017.
# 2024-09-12T05:09:37.458794+0530 INFO user0015 has unfollowed user0016.
# 2024-09-12T05:09:37.735638+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:37.735638+0530 INFO Successfully deleted post with ID: 113119979920028681
# 2024-09-12T05:09:37.740645+0530 INFO Successfully deleted post with ID: 113120624360287503
# 2024-09-12T05:09:38.222286+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:38.365205+0530 INFO Attempting to unfollow 11 users for user0003...
# 2024-09-12T05:09:38.367206+0530 INFO user0017 has unfollowed user0009.
# 2024-09-12T05:09:38.568243+0530 INFO Attempting to unfollow 0 users for user0034...
# 2024-09-12T05:09:38.568243+0530 INFO Starting comprehensive reset process for user: user0038
# 2024-09-12T05:09:38.571244+0530 INFO Successfully unfollowed 0 out of 0 users for user0034.
# 2024-09-12T05:09:38.840038+0530 INFO Successfully deleted post with ID: 113116225629248485
# 2024-09-12T05:09:38.840038+0530 INFO Deletion process completed. Attempted to delete 3 post(s).
# 2024-09-12T05:09:39.043605+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:39.253022+0530 INFO user0008 has unfollowed user0017.
# 2024-09-12T05:09:39.725058+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:39.725058+0530 INFO Comprehensive reset process completed for user: user0034
# 2024-09-12T05:09:39.732063+0530 INFO Successfully deleted post with ID: 113119057043946328
# 2024-09-12T05:09:40.063163+0530 INFO user0006 has unfollowed user0020.
# 2024-09-12T05:09:40.338394+0530 INFO Starting comprehensive reset process for user: user0041
# 2024-09-12T05:09:40.742016+0530 INFO user0004 has unfollowed user0019.
# 2024-09-12T05:09:40.918007+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:40.919001+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:40.938999+0530 INFO Successfully deleted post with ID: 113118457660039478
# 2024-09-12T05:09:41.022942+0530 INFO Attempting to unfollow 6 users for user0007...
# 2024-09-12T05:09:41.030944+0530 INFO user0013 has unfollowed user0016.
# 2024-09-12T05:09:41.335055+0530 INFO user0012 has unfollowed user0011.
# 2024-09-12T05:09:41.744760+0530 INFO user0009 has unfollowed user0019.
# 2024-09-12T05:09:42.042492+0530 INFO Starting comprehensive reset process for user: user0042
# 2024-09-12T05:09:42.440725+0530 INFO user0001 has unfollowed user0003.
# 2024-09-12T05:09:42.532070+0530 INFO user0020 has unfollowed user0001.
# 2024-09-12T05:09:42.621601+0530 INFO user0016 has unfollowed user0017.
# 2024-09-12T05:09:43.020851+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:43.030851+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:43.043961+0530 INFO user0010 has unfollowed user0016.
# 2024-09-12T05:09:43.138033+0530 INFO Attempting to unfollow 0 users for user0036...
# 2024-09-12T05:09:43.139033+0530 INFO Successfully unfollowed 0 out of 0 users for user0036.
# 2024-09-12T05:09:43.318717+0530 INFO Starting comprehensive reset process for user: user0039
# 2024-09-12T05:09:43.426553+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:43.447562+0530 INFO Successfully deleted post with ID: 113118455061640231
# 2024-09-12T05:09:43.637297+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:43.638299+0530 INFO Comprehensive reset process completed for user: user0036
# 2024-09-12T05:09:43.638299+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:44.527142+0530 INFO Attempting to unfollow 9 users for user0005...
# 2024-09-12T05:09:44.630441+0530 INFO Successfully deleted post with ID: 113118062750620366
# 2024-09-12T05:09:44.632378+0530 INFO user0017 has unfollowed user0008.
# 2024-09-12T05:09:44.639345+0530 INFO user0019 has unfollowed user0010.
# 2024-09-12T05:09:44.648338+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:44.738878+0530 INFO user0015 has unfollowed user0014.
# 2024-09-12T05:09:44.942873+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:45.128978+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:45.221076+0530 INFO user0007 has unfollowed user0008.
# 2024-09-12T05:09:45.430569+0530 INFO Successfully deleted post with ID: 113116229976197956
# 2024-09-12T05:09:45.430569+0530 INFO Deletion process completed. Attempted to delete 6 post(s).
# 2024-09-12T05:09:45.840773+0530 INFO Attempting to unfollow 0 users for user0037...
# 2024-09-12T05:09:45.840773+0530 INFO Successfully unfollowed 0 out of 0 users for user0037.
# 2024-09-12T05:09:46.039126+0530 INFO Attempting to unfollow 0 users for user0035...
# 2024-09-12T05:09:46.040126+0530 INFO Successfully unfollowed 0 out of 0 users for user0035.
# 2024-09-12T05:09:46.118661+0530 INFO user0018 has unfollowed user0019.
# 2024-09-12T05:09:46.524920+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:46.525920+0530 INFO Comprehensive reset process completed for user: user0037
# 2024-09-12T05:09:46.539920+0530 INFO user0020 has unfollowed user0014.
# 2024-09-12T05:09:46.648432+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:46.648432+0530 INFO Comprehensive reset process completed for user: user0035
# 2024-09-12T05:09:46.751939+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:46.752939+0530 INFO user0014 has unfollowed user0015.
# 2024-09-12T05:09:46.830451+0530 INFO user0006 has unfollowed user0017.
# 2024-09-12T05:09:46.932981+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:47.038026+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:47.424603+0530 INFO user0002 has unfollowed user0020.
# 2024-09-12T05:09:47.433614+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:47.463997+0530 INFO user0016 has unfollowed user0014.
# 2024-09-12T05:09:47.716972+0530 INFO user0003 has unfollowed user0020.
# 2024-09-12T05:09:47.839367+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:47.856739+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:47.935556+0530 INFO user0012 has unfollowed user0010.
# 2024-09-12T05:09:47.952545+0530 INFO user0001 has unfollowed user0015.
# 2024-09-12T05:09:47.978545+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:48.081539+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:09:48.235987+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:48.242986+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:48.326464+0530 INFO Attempting to unfollow 0 users for user0041...
# 2024-09-12T05:09:48.327463+0530 INFO Successfully unfollowed 0 out of 0 users for user0041.
# 2024-09-12T05:09:48.346326+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:48.424659+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:09:48.564273+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:48.564273+0530 INFO Comprehensive reset process completed for user: user0041
# 2024-09-12T05:09:48.651958+0530 INFO Attempting to unfollow 9 users for user0011...
# 2024-09-12T05:09:48.726484+0530 INFO user0009 has unfollowed user0014.
# 2024-09-12T05:09:48.768078+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:48.768078+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:48.822122+0530 INFO Attempting to unfollow 0 users for user0038...
# 2024-09-12T05:09:48.823122+0530 INFO Successfully unfollowed 0 out of 0 users for user0038.
# 2024-09-12T05:09:48.946318+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:09:49.066291+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:49.067190+0530 INFO Comprehensive reset process completed for user: user0038
# 2024-09-12T05:09:49.209105+0530 INFO Attempting to unfollow 0 users for user0042...
# 2024-09-12T05:09:49.210097+0530 INFO Successfully unfollowed 0 out of 0 users for user0042.
# 2024-09-12T05:09:49.230274+0530 INFO Attempting to unfollow 0 users for user0039...
# 2024-09-12T05:09:49.231273+0530 INFO Successfully unfollowed 0 out of 0 users for user0039.
# 2024-09-12T05:09:49.393532+0530 INFO Attempting to unfollow 0 users for user0040...
# 2024-09-12T05:09:49.393532+0530 INFO Successfully unfollowed 0 out of 0 users for user0040.
# 2024-09-12T05:09:49.443918+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:49.444917+0530 INFO Comprehensive reset process completed for user: user0042
# 2024-09-12T05:09:49.469687+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:49.469687+0530 INFO Comprehensive reset process completed for user: user0039
# 2024-09-12T05:09:49.633384+0530 INFO Profile information reset successfully.
# 2024-09-12T05:09:49.634458+0530 INFO Comprehensive reset process completed for user: user0040
# 2024-09-12T05:10:00.635963+0530 INFO user0013 has unfollowed user0012.
# 2024-09-12T05:10:01.044291+0530 INFO user0008 has unfollowed user0019.
# 2024-09-12T05:10:01.344023+0530 INFO user0019 has unfollowed user0006.
# 2024-09-12T05:10:01.845896+0530 INFO user0004 has unfollowed user0016.
# 2024-09-12T05:10:01.934893+0530 INFO Starting comprehensive reset process for user: user0043
# 2024-09-12T05:10:01.948396+0530 INFO user0017 has unfollowed user0003.
# 2024-09-12T05:10:02.518657+0530 INFO Starting comprehensive reset process for user: user0047
# 2024-09-12T05:10:02.726812+0530 INFO user0005 has unfollowed user0020.
# 2024-09-12T05:10:03.341778+0530 INFO user0001 has unfollowed user0008.
# 2024-09-12T05:10:03.368750+0530 INFO Starting comprehensive reset process for user: user0048
# 2024-09-12T05:10:03.440077+0530 INFO user0007 has unfollowed user0015.
# 2024-09-12T05:10:03.540272+0530 INFO user0015 has unfollowed user0013.
# 2024-09-12T05:10:03.549224+0530 INFO user0020 has unfollowed user0010.
# 2024-09-12T05:10:03.549224+0530 INFO user0018 has unfollowed user0020.
# 2024-09-12T05:10:03.928599+0530 INFO Starting comprehensive reset process for user: user0045
# 2024-09-12T05:10:03.964090+0530 INFO user0012 has unfollowed user0005.
# 2024-09-12T05:10:04.230165+0530 INFO Starting comprehensive reset process for user: user0046
# 2024-09-12T05:10:04.427328+0530 INFO user0014 has unfollowed user0020.
# 2024-09-12T05:10:04.427328+0530 INFO Starting comprehensive reset process for user: user0044
# 2024-09-12T05:10:04.638712+0530 INFO Starting comprehensive reset process for user: user0049
# 2024-09-12T05:10:04.766666+0530 INFO Starting comprehensive reset process for user: user0050
# 2024-09-12T05:10:04.925861+0530 INFO user0010 has unfollowed user0011.
# 2024-09-12T05:10:05.432645+0530 INFO user0002 has unfollowed user0016.
# 2024-09-12T05:10:05.652624+0530 INFO user0016 has unfollowed user0010.
# 2024-09-12T05:10:05.932211+0530 INFO user0011 has unfollowed user0017.
# 2024-09-12T05:10:06.227595+0530 INFO user0009 has unfollowed user0001.
# 2024-09-12T05:10:06.243285+0530 INFO user0008 has unfollowed user0018.
# 2024-09-12T05:10:06.423121+0530 INFO user0019 has unfollowed user0004.
# 2024-09-12T05:10:07.030019+0530 INFO user0017 has unfollowed user0002.
# 2024-09-12T05:10:07.330231+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:10:07.345654+0530 INFO user0001 has unfollowed user0002.
# 2024-09-12T05:10:07.347655+0530 INFO Successfully unfollowed 7 out of 7 users for user0001.
# 2024-09-12T05:10:07.723028+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:10:08.150346+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:10:08.232608+0530 INFO user0006 has unfollowed user0014.
# 2024-09-12T05:10:08.720360+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:10:08.738375+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:10:08.821565+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:08.821565+0530 INFO Comprehensive reset process completed for user: user0001
# 2024-09-12T05:10:08.839591+0530 INFO user0004 has unfollowed user0015.
# 2024-09-12T05:10:09.126725+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:10:09.217666+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:10:09.343504+0530 INFO user0003 has unfollowed user0012.
# 2024-09-12T05:10:09.433709+0530 INFO Attempting to unfollow 0 users for user0043...
# 2024-09-12T05:10:09.434770+0530 INFO Successfully unfollowed 0 out of 0 users for user0043.
# 2024-09-12T05:10:09.642573+0530 INFO user0010 has unfollowed user0006.
# 2024-09-12T05:10:09.740632+0530 INFO user0005 has unfollowed user0007.
# 2024-09-12T05:10:09.921444+0530 INFO user0014 has unfollowed user0011.
# 2024-09-12T05:10:09.928439+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:10:09.946132+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:10:10.027737+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:10.028738+0530 INFO Comprehensive reset process completed for user: user0043
# 2024-09-12T05:10:10.221253+0530 INFO user0016 has unfollowed user0006.
# 2024-09-12T05:10:10.338455+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:10:10.340470+0530 INFO user0002 has unfollowed user0010.
# 2024-09-12T05:10:10.342470+0530 INFO user0008 has unfollowed user0013.
# 2024-09-12T05:10:10.451510+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:10:10.737339+0530 INFO Attempting to unfollow 0 users for user0047...
# 2024-09-12T05:10:10.739332+0530 INFO Successfully unfollowed 0 out of 0 users for user0047.
# 2024-09-12T05:10:10.928800+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:10:11.040892+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:10:11.223972+0530 INFO Attempting to unfollow 0 users for user0046...
# 2024-09-12T05:10:11.223972+0530 INFO Successfully unfollowed 0 out of 0 users for user0046.
# 2024-09-12T05:10:11.327546+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:11.327546+0530 INFO Comprehensive reset process completed for user: user0047
# 2024-09-12T05:10:11.437451+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:10:11.449171+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:10:11.451171+0530 INFO Starting comprehensive reset process for user: user0051
# 2024-09-12T05:10:11.836314+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:11.837307+0530 INFO Comprehensive reset process completed for user: user0046
# 2024-09-12T05:10:12.046054+0530 INFO user0009 has unfollowed user0002.
# 2024-09-12T05:10:12.047627+0530 INFO Successfully unfollowed 7 out of 7 users for user0009.
# 2024-09-12T05:10:12.349954+0530 INFO Attempting to unfollow 0 users for user0049...
# 2024-09-12T05:10:12.350955+0530 INFO Successfully unfollowed 0 out of 0 users for user0049.
# 2024-09-12T05:10:12.533558+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:10:12.631721+0530 INFO user0011 has unfollowed user0014.
# 2024-09-12T05:10:12.936379+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:12.937379+0530 INFO Comprehensive reset process completed for user: user0009
# 2024-09-12T05:10:13.144682+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:10:13.146682+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:10:13.517896+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:10:13.537915+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:13.538914+0530 INFO Comprehensive reset process completed for user: user0049
# 2024-09-12T05:10:13.547915+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:10:13.617486+0530 INFO user0012 has unfollowed user0004.
# 2024-09-12T05:10:13.646679+0530 INFO user0020 has unfollowed user0009.
# 2024-09-12T05:10:14.120267+0530 INFO user0015 has unfollowed user0011.
# 2024-09-12T05:10:14.429104+0530 INFO Starting comprehensive reset process for user: user0052
# 2024-09-12T05:10:14.536632+0530 INFO user0004 has unfollowed user0014.
# 2024-09-12T05:10:14.544631+0530 INFO user0007 has unfollowed user0010.
# 2024-09-12T05:10:14.659218+0530 INFO Starting comprehensive reset process for user: user0053
# 2024-09-12T05:10:14.721307+0530 INFO Attempting to unfollow 0 users for user0050...
# 2024-09-12T05:10:14.722307+0530 INFO Successfully unfollowed 0 out of 0 users for user0050.
# 2024-09-12T05:10:14.927408+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:10:14.928399+0530 INFO Attempting to unfollow 0 users for user0048...
# 2024-09-12T05:10:14.929399+0530 INFO Successfully unfollowed 0 out of 0 users for user0048.
# 2024-09-12T05:10:15.130702+0530 INFO user0010 has unfollowed user0001.
# 2024-09-12T05:10:15.227264+0530 INFO user0003 has unfollowed user0004.
# 2024-09-12T05:10:15.329377+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:15.330386+0530 INFO Comprehensive reset process completed for user: user0050
# 2024-09-12T05:10:15.343381+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:15.344381+0530 INFO Comprehensive reset process completed for user: user0048
# 2024-09-12T05:10:15.546236+0530 INFO user0008 has unfollowed user0011.
# 2024-09-12T05:10:15.728899+0530 INFO Attempting to unfollow 0 users for user0045...
# 2024-09-12T05:10:15.728899+0530 INFO Successfully unfollowed 0 out of 0 users for user0045.
# 2024-09-12T05:10:15.742894+0530 INFO Starting comprehensive reset process for user: user0054
# 2024-09-12T05:10:15.837017+0530 INFO user0005 has unfollowed user0019.
# 2024-09-12T05:10:15.846021+0530 INFO user0016 has unfollowed user0002.
# 2024-09-12T05:10:15.919593+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:10:16.031398+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:10:16.330899+0530 INFO user0013 has unfollowed user0009.
# 2024-09-12T05:10:16.524050+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:10:16.532487+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:16.533480+0530 INFO Comprehensive reset process completed for user: user0045
# 2024-09-12T05:10:16.656784+0530 INFO user0011 has unfollowed user0018.
# 2024-09-12T05:10:16.941238+0530 INFO Starting comprehensive reset process for user: user0055
# 2024-09-12T05:10:17.336912+0530 INFO user0019 has unfollowed user0002.
# 2024-09-12T05:10:17.436805+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:10:17.445808+0530 INFO user0020 has unfollowed user0006.
# 2024-09-12T05:10:18.427267+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:10:18.525779+0530 INFO user0007 has unfollowed user0005.
# 2024-09-12T05:10:18.540780+0530 INFO user0012 has unfollowed user0003.
# 2024-09-12T05:10:18.652301+0530 INFO user0015 has unfollowed user0009.
# 2024-09-12T05:10:19.017330+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:10:19.021337+0530 INFO user0018 has unfollowed user0016.
# 2024-09-12T05:10:19.030257+0530 INFO Starting comprehensive reset process for user: user0057
# 2024-09-12T05:10:19.129697+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:10:19.336662+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:10:19.448111+0530 INFO user0017 has unfollowed user0001.
# 2024-09-12T05:10:19.732476+0530 INFO user0004 has unfollowed user0003.
# 2024-09-12T05:10:19.741482+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:10:19.841185+0530 INFO Starting comprehensive reset process for user: user0058
# 2024-09-12T05:10:19.850191+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:10:20.018284+0530 INFO Starting comprehensive reset process for user: user0059
# 2024-09-12T05:10:20.118822+0530 INFO user0010 has unfollowed user0002.
# 2024-09-12T05:10:20.119822+0530 INFO Successfully unfollowed 8 out of 8 users for user0010.
# 2024-09-12T05:10:20.142887+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:10:20.238964+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:10:20.327702+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:10:20.533189+0530 INFO user0006 has unfollowed user0012.
# 2024-09-12T05:10:21.039072+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:10:21.043070+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:10:21.219947+0530 INFO Attempting to unfollow 0 users for user0052...
# 2024-09-12T05:10:21.220946+0530 INFO Successfully unfollowed 0 out of 0 users for user0052.
# 2024-09-12T05:10:21.224947+0530 INFO user0003 has unfollowed user0019.
# 2024-09-12T05:10:21.348360+0530 INFO user0005 has unfollowed user0012.
# 2024-09-12T05:10:21.557455+0530 INFO user0016 has unfollowed user0001.
# 2024-09-12T05:10:21.635570+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:21.636570+0530 INFO Comprehensive reset process completed for user: user0052
# 2024-09-12T05:10:22.126336+0530 INFO Attempting to unfollow 0 users for user0053...
# 2024-09-12T05:10:22.127292+0530 INFO Successfully unfollowed 0 out of 0 users for user0053.
# 2024-09-12T05:10:22.143906+0530 INFO Attempting to unfollow 0 users for user0054...
# 2024-09-12T05:10:22.143906+0530 INFO Successfully unfollowed 0 out of 0 users for user0054.
# 2024-09-12T05:10:22.334629+0530 INFO user0020 has unfollowed user0002.
# 2024-09-12T05:10:22.335630+0530 INFO Successfully unfollowed 9 out of 9 users for user0020.
# 2024-09-12T05:10:22.341643+0530 INFO user0019 has unfollowed user0001.
# 2024-09-12T05:10:22.627500+0530 INFO Attempting to unfollow 0 users for user0044...
# 2024-09-12T05:10:22.628504+0530 INFO Successfully unfollowed 0 out of 0 users for user0044.
# 2024-09-12T05:10:22.644595+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:22.644595+0530 INFO Comprehensive reset process completed for user: user0054
# 2024-09-12T05:10:22.733293+0530 INFO user0014 has unfollowed user0008.
# 2024-09-12T05:10:22.742290+0530 INFO user0013 has unfollowed user0003.
# 2024-09-12T05:10:23.129659+0530 INFO Attempting to unfollow 0 users for user0051...
# 2024-09-12T05:10:23.130666+0530 INFO Successfully unfollowed 0 out of 0 users for user0051.
# 2024-09-12T05:10:23.228946+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:23.228946+0530 INFO Comprehensive reset process completed for user: user0010
# 2024-09-12T05:10:23.321092+0530 INFO user0017 has unfollowed user0016.
# 2024-09-12T05:10:23.422671+0530 INFO Starting comprehensive reset process for user: user0056
# 2024-09-12T05:10:23.430703+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:23.432672+0530 INFO Comprehensive reset process completed for user: user0044
# 2024-09-12T05:10:23.439674+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:23.440696+0530 INFO Comprehensive reset process completed for user: user0053
# 2024-09-12T05:10:23.617063+0530 INFO user0012 has unfollowed user0002.
# 2024-09-12T05:10:23.947370+0530 INFO user0002 has unfollowed user0009.
# 2024-09-12T05:10:24.121796+0530 INFO user0018 has unfollowed user0014.
# 2024-09-12T05:10:24.245778+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:10:24.337462+0530 INFO user0011 has unfollowed user0015.
# 2024-09-12T05:10:24.642363+0530 INFO Starting comprehensive reset process for user: user0060
# 2024-09-12T05:10:24.831660+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:10:24.835225+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:24.836242+0530 INFO Comprehensive reset process completed for user: user0051
# 2024-09-12T05:10:24.844245+0530 INFO user0007 has unfollowed user0002.
# 2024-09-12T05:10:25.231997+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:10:25.241957+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:10:25.341960+0530 INFO Starting comprehensive reset process for user: user0061
# 2024-09-12T05:10:25.348983+0530 INFO user0016 has unfollowed user0004.
# 2024-09-12T05:10:25.349983+0530 INFO Successfully unfollowed 8 out of 8 users for user0016.
# 2024-09-12T05:10:25.938958+0530 INFO user0015 has unfollowed user0006.
# 2024-09-12T05:10:26.031216+0530 INFO user0006 has unfollowed user0011.
# 2024-09-12T05:10:26.141733+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:10:26.143725+0530 INFO Starting comprehensive reset process for user: user0063
# 2024-09-12T05:10:26.445073+0530 INFO user0003 has unfollowed user0015.
# 2024-09-12T05:10:26.717663+0530 INFO Starting comprehensive reset process for user: user0062
# 2024-09-12T05:10:26.838193+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:10:27.018244+0530 INFO Attempting to unfollow 0 users for user0059...
# 2024-09-12T05:10:27.018244+0530 INFO Successfully unfollowed 0 out of 0 users for user0059.
# 2024-09-12T05:10:27.228054+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:10:27.521529+0530 INFO user0004 has unfollowed user0001.
# 2024-09-12T05:10:27.638224+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:10:27.836550+0530 INFO Starting comprehensive reset process for user: user0064
# 2024-09-12T05:10:28.042858+0530 INFO Profile information reset successfully.
# 2024-09-12T05:10:28.043778+0530 INFO Comprehensive reset process completed for user: user0016
# 2024-09-12T05:10:28.223520+0530 INFO user0002 has unfollowed user0004.
# 2024-09-12T05:10:28.540587+0530 INFO user0005 has unfollowed user0006.
# 2024-09-12T05:10:28.640256+0530 INFO user0013 has unfollowed user0002.
# ...
# 2024-09-12T05:15:14.024808+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:14.025894+0530 INFO Comprehensive reset process completed for user: user0083
# 2024-09-12T05:15:14.032808+0530 INFO user0018 has unfollowed user0005.
# 2024-09-12T05:15:14.230406+0530 INFO Attempting to unfollow 0 users for user0071...
# 2024-09-12T05:15:14.231412+0530 INFO Successfully unfollowed 0 out of 0 users for user0071.
# 2024-09-12T05:15:14.234404+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:14.241411+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:14.367569+0530 INFO Attempting to unfollow 0 users for user0081...
# 2024-09-12T05:15:14.371568+0530 INFO Successfully unfollowed 0 out of 0 users for user0081.
# 2024-09-12T05:15:14.456670+0530 INFO user0014 has unfollowed user0009.
# 2024-09-12T05:15:14.548553+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:14.549547+0530 INFO Comprehensive reset process completed for user: user0071
# 2024-09-12T05:15:14.638210+0530 INFO Attempting to unfollow 0 users for user0076...
# 2024-09-12T05:15:14.639210+0530 INFO Successfully unfollowed 0 out of 0 users for user0076.
# 2024-09-12T05:15:14.837591+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:15.050819+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:15.050819+0530 INFO Comprehensive reset process completed for user: user0081
# 2024-09-12T05:15:15.115640+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:15.126742+0530 INFO user0006 has unfollowed user0002.
# 2024-09-12T05:15:15.249593+0530 INFO user0003 has unfollowed user0007.
# 2024-09-12T05:15:15.325181+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:15.326423+0530 INFO Comprehensive reset process completed for user: user0076
# 2024-09-12T05:15:15.338597+0530 INFO user0005 has unfollowed user0002.
# 2024-09-12T05:15:15.457107+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:15.459113+0530 INFO Starting comprehensive reset process for user: user0091
# 2024-09-12T05:15:15.931691+0530 INFO Attempting to unfollow 0 users for user0077...
# 2024-09-12T05:15:15.933690+0530 INFO Successfully unfollowed 0 out of 0 users for user0077.
# 2024-09-12T05:15:16.342830+0530 INFO Attempting to unfollow 0 users for user0079...
# 2024-09-12T05:15:16.343829+0530 INFO Successfully unfollowed 0 out of 0 users for user0079.
# 2024-09-12T05:15:16.430994+0530 INFO Attempting to unfollow 0 users for user0078...
# 2024-09-12T05:15:16.430994+0530 INFO Successfully unfollowed 0 out of 0 users for user0078.
# 2024-09-12T05:15:16.521986+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:16.522240+0530 INFO Comprehensive reset process completed for user: user0077
# 2024-09-12T05:15:16.812955+0530 INFO Attempting to unfollow 0 users for user0084...
# 2024-09-12T05:15:16.813531+0530 INFO Successfully unfollowed 0 out of 0 users for user0084.
# 2024-09-12T05:15:16.933540+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:16.934539+0530 INFO Comprehensive reset process completed for user: user0079
# 2024-09-12T05:15:16.935540+0530 INFO Starting comprehensive reset process for user: user0096
# 2024-09-12T05:15:17.010694+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:17.024907+0530 INFO user0015 has unfollowed user0001.
# 2024-09-12T05:15:17.025906+0530 INFO Successfully unfollowed 14 out of 14 users for user0015.
# 2024-09-12T05:15:17.030965+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:17.133762+0530 INFO Starting comprehensive reset process for user: user0097
# 2024-09-12T05:15:17.410902+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:17.411901+0530 INFO Comprehensive reset process completed for user: user0084
# 2024-09-12T05:15:17.422441+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:17.430411+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:17.433477+0530 INFO Starting comprehensive reset process for user: user0092
# 2024-09-12T05:15:17.511397+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:17.514452+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:17.631088+0530 INFO Starting comprehensive reset process for user: user0089
# 2024-09-12T05:15:17.841512+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:17.920324+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:17.927399+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:17.927399+0530 INFO Comprehensive reset process completed for user: user0078
# 2024-09-12T05:15:17.935381+0530 INFO user0018 has unfollowed user0002.
# 2024-09-12T05:15:18.037394+0530 INFO user0011 has unfollowed user0003.
# 2024-09-12T05:15:18.038409+0530 INFO Successfully unfollowed 9 out of 9 users for user0011.
# 2024-09-12T05:15:18.335398+0530 INFO Starting comprehensive reset process for user: user0100
# 2024-09-12T05:15:18.422759+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:18.549284+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:18.632759+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:18.632759+0530 INFO Starting comprehensive reset process for user: user0098
# 2024-09-12T05:15:18.633888+0530 INFO Comprehensive reset process completed for user: user0015
# 2024-09-12T05:15:18.847377+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:19.023163+0530 INFO Starting comprehensive reset process for user: user0099
# 2024-09-12T05:15:19.235251+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:19.236252+0530 INFO Comprehensive reset process completed for user: user0008
# 2024-09-12T05:15:19.531792+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:19.532746+0530 INFO Comprehensive reset process completed for user: user0011
# 2024-09-12T05:15:19.647100+0530 INFO user0006 has unfollowed user0001.
# 2024-09-12T05:15:19.648100+0530 INFO Successfully unfollowed 12 out of 12 users for user0006.
# 2024-09-12T05:15:20.131652+0530 INFO user0005 has unfollowed user0001.
# 2024-09-12T05:15:20.132653+0530 INFO Successfully unfollowed 9 out of 9 users for user0005.
# 2024-09-12T05:15:20.243783+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:20.319533+0530 INFO Starting comprehensive reset process for user: user0093
# 2024-09-12T05:15:20.531059+0530 INFO Attempting to unfollow 0 users for user0090...
# 2024-09-12T05:15:20.531986+0530 INFO Successfully unfollowed 0 out of 0 users for user0090.
# 2024-09-12T05:15:20.618862+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:20.623856+0530 INFO user0014 has unfollowed user0006.
# 2024-09-12T05:15:20.630855+0530 INFO Attempting to unfollow 0 users for user0086...
# 2024-09-12T05:15:20.632851+0530 INFO Successfully unfollowed 0 out of 0 users for user0086.
# 2024-09-12T05:15:20.731628+0530 INFO Starting comprehensive reset process for user: user0094
# 2024-09-12T05:15:21.019484+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:21.020503+0530 INFO Comprehensive reset process completed for user: user0006
# 2024-09-12T05:15:21.126554+0530 INFO Attempting to unfollow 0 users for user0088...
# 2024-09-12T05:15:21.127604+0530 INFO Successfully unfollowed 0 out of 0 users for user0088.
# 2024-09-12T05:15:21.130558+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:21.130558+0530 INFO Comprehensive reset process completed for user: user0090
# 2024-09-12T05:15:21.134561+0530 INFO user0003 has unfollowed user0002.
# 2024-09-12T05:15:21.219482+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:21.613891+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:21.614890+0530 INFO Comprehensive reset process completed for user: user0088
# 2024-09-12T05:15:21.619788+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:21.622819+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:21.721710+0530 INFO Attempting to unfollow 0 users for user0085...
# 2024-09-12T05:15:21.722710+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:21.722710+0530 INFO Successfully unfollowed 0 out of 0 users for user0085.
# 2024-09-12T05:15:21.723710+0530 INFO Comprehensive reset process completed for user: user0086
# 2024-09-12T05:15:21.724710+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:21.770946+0530 INFO user0018 has unfollowed user0001.
# 2024-09-12T05:15:21.908887+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:22.032152+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:22.032152+0530 INFO Comprehensive reset process completed for user: user0005
# 2024-09-12T05:15:22.118486+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:22.125491+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:22.134493+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:22.216764+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:22.224798+0530 INFO Starting comprehensive reset process for user: user0095
# 2024-09-12T05:15:22.238188+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:22.239188+0530 INFO Comprehensive reset process completed for user: user0085
# 2024-09-12T05:15:22.628525+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:22.908450+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:23.037242+0530 INFO Attempting to unfollow 0 users for user0091...
# 2024-09-12T05:15:23.037242+0530 INFO Successfully unfollowed 0 out of 0 users for user0091.
# 2024-09-12T05:15:23.137544+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:23.139544+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:23.318577+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:23.412458+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:23.616809+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:23.616809+0530 INFO Comprehensive reset process completed for user: user0091
# 2024-09-12T05:15:23.723367+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:23.923848+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:24.019580+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:24.032054+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:24.044543+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:24.113239+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:24.230117+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:24.232117+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:24.416133+0530 INFO Attempting to unfollow 0 users for user0089...
# 2024-09-12T05:15:24.416133+0530 INFO Successfully unfollowed 0 out of 0 users for user0089.
# 2024-09-12T05:15:24.425134+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:24.430320+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:24.443380+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:24.445386+0530 INFO user0014 has unfollowed user0004.
# 2024-09-12T05:15:24.446385+0530 INFO Successfully unfollowed 11 out of 11 users for user0014.
# 2024-09-12T05:15:24.554507+0530 INFO Attempting to unfollow 0 users for user0092...
# 2024-09-12T05:15:24.554507+0530 INFO Successfully unfollowed 0 out of 0 users for user0092.
# 2024-09-12T05:15:24.623788+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:24.645338+0530 INFO Attempting to unfollow 0 users for user0098...
# 2024-09-12T05:15:24.645338+0530 INFO Successfully unfollowed 0 out of 0 users for user0098.
# 2024-09-12T05:15:24.652343+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:24.653337+0530 INFO Comprehensive reset process completed for user: user0089
# 2024-09-12T05:15:24.815090+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:24.830422+0530 INFO Attempting to unfollow 0 users for user0096...
# 2024-09-12T05:15:24.831465+0530 INFO Successfully unfollowed 0 out of 0 users for user0096.
# 2024-09-12T05:15:24.930200+0530 INFO Attempting to unfollow 0 users for user0097...
# 2024-09-12T05:15:24.931206+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:24.931206+0530 INFO Successfully unfollowed 0 out of 0 users for user0097.
# 2024-09-12T05:15:25.010013+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:25.011032+0530 INFO Comprehensive reset process completed for user: user0092
# 2024-09-12T05:15:25.017641+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:25.018635+0530 INFO Comprehensive reset process completed for user: user0098
# 2024-09-12T05:15:25.021633+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:25.047634+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:25.142663+0530 INFO Attempting to unfollow 0 users for user0100...
# 2024-09-12T05:15:25.142663+0530 INFO Successfully unfollowed 0 out of 0 users for user0100.
# 2024-09-12T05:15:25.212048+0530 ERROR No posts specified for deletion.
# 2024-09-12T05:15:25.243558+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:25.243737+0530 INFO Comprehensive reset process completed for user: user0096
# 2024-09-12T05:15:25.328638+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:25.329561+0530 INFO Comprehensive reset process completed for user: user0097
# 2024-09-12T05:15:25.413720+0530 INFO Attempting to unfollow 0 users for user0099...
# 2024-09-12T05:15:25.414767+0530 INFO Successfully unfollowed 0 out of 0 users for user0099.
# 2024-09-12T05:15:25.427772+0530 INFO user0003 has unfollowed user0001.
# 2024-09-12T05:15:25.428773+0530 INFO Successfully unfollowed 11 out of 11 users for user0003.
# 2024-09-12T05:15:25.445471+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:25.446503+0530 INFO Comprehensive reset process completed for user: user0014
# 2024-09-12T05:15:25.521278+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T05:15:25.525972+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:25.530850+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:25.530850+0530 INFO Comprehensive reset process completed for user: user0100
# 2024-09-12T05:15:25.539771+0530 INFO Attempting to unfollow 0 users for user0093...
# 2024-09-12T05:15:25.539771+0530 INFO Successfully unfollowed 0 out of 0 users for user0093.
# 2024-09-12T05:15:25.643067+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:25.644500+0530 INFO Comprehensive reset process completed for user: user0099
# 2024-09-12T05:15:25.669335+0530 INFO Attempting to unfollow 0 users for user0087...
# 2024-09-12T05:15:25.670341+0530 INFO Successfully unfollowed 0 out of 0 users for user0087.
# 2024-09-12T05:15:25.692665+0530 INFO user0018 has unfollowed user0011.
# 2024-09-12T05:15:25.693692+0530 INFO Successfully unfollowed 12 out of 12 users for user0018.
# 2024-09-12T05:15:25.776556+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:25.777557+0530 INFO Comprehensive reset process completed for user: user0093
# 2024-09-12T05:15:25.921685+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:25.922681+0530 INFO Comprehensive reset process completed for user: user0087
# 2024-09-12T05:15:25.977061+0530 INFO Attempting to unfollow 0 users for user0094...
# 2024-09-12T05:15:25.978072+0530 INFO Successfully unfollowed 0 out of 0 users for user0094.
# 2024-09-12T05:15:25.986079+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T05:15:26.213993+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:26.214949+0530 INFO Comprehensive reset process completed for user: user0094
# 2024-09-12T05:15:26.301541+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:26.302541+0530 INFO Comprehensive reset process completed for user: user0003
# 2024-09-12T05:15:26.457980+0530 INFO Attempting to unfollow 0 users for user0095...
# 2024-09-12T05:15:26.458973+0530 INFO Successfully unfollowed 0 out of 0 users for user0095.
# 2024-09-12T05:15:26.517746+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:26.517746+0530 INFO Comprehensive reset process completed for user: user0018
# 2024-09-12T05:15:26.699936+0530 INFO Profile information reset successfully.
# 2024-09-12T05:15:26.700944+0530 INFO Comprehensive reset process completed for user: user0095
# 2024-09-12T05:15:27.723322+0530 INFO Retrieved 0 posts from the public timeline.

# %% [markdown]
# ## Set LLM and embedding model

# %%
pwd
# Out:
# 'c:\\Users\\snehe\\Documents\\sim\\masto-sim3\\mastodon-sim\\notebooks'

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.chdir('../../mastodon-sim/')

# %%
os.chdir('notebooks/')

# %%
# MODEL_NAME = "gpt-4o"
MODEL_NAME = "gpt-4o-mini"
#MODEL_NAME = "sonnet"
print(os.getenv("OPENAI_API_KEY"))

if "sonnet" in MODEL_NAME:
  model = amazon_bedrock_model.AmazonBedrockLanguageModel(
    model_id="anthropic.claude-3-5-sonnet-20240620-v1:0"
  )
elif "gpt" in MODEL_NAME:
  GPT_API_KEY = os.getenv("OPENAI_API_KEY")

  if not GPT_API_KEY:
    raise ValueError("GPT_API_KEY is required.")
  model = gpt_model.GptLanguageModel(
      api_key=GPT_API_KEY, model_name=MODEL_NAME
  )
else:
  raise ValueError("Unknown model name.")
# Out:
# None

# %%
def write_agent_config_for_independent_sim(agent_config_filename):
    agent_names = ['Bill Fredrickson', 'Maria Gutierrez', 'Glenn Patterson', 'Denise Schmidt', 'Roger Davis', 'Erica Fitzgerald', 'Liam Schwartz', 'Olivia Thompson', 'Robert Johnson', 'Janet Thompson', 'William Davis', 'Jessica Nguyen', 'Mark Rodriguez', 'Emily Jacobs', 'Ethan Lee', 'Sophia Patel', "Ryan O'Connor", 'Maggie Chen', 'Lucas Kim', 'Nina Patel']
    genders = ['male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female']
    big5 = [
        [3, 8, 6, 5, 4],
    [9, 7, 8, 8, 5],
    [1, 5, 7, 2, 9],
    [1, 6, 8, 2, 7],
    [2, 3, 7, 2, 8],
    [8, 6, 9, 3, 7],
    [8, 5, 8, 3, 7],
    [5, 6, 9, 2, 8],
    [5, 7, 4, 6, 5],
    [6, 7, 5, 7, 4],
    [4, 6, 5, 6, 4],
    [7, 6, 5, 7, 5],
    [6, 7, 5, 7, 4],
    [7, 6, 5, 8, 6],
    [6, 8, 6, 6, 4],
    [7, 8, 6, 7, 4],
    [5, 7, 5, 6, 5],
    [6, 7, 6, 8, 4],
    [8, 6, 5, 6, 5],
    [7, 8, 7, 8, 4]
    ]
    big5_keys = ['openness', 'conscientiousness', 'extraversion', 'agreeableness', 'neuroticism']
    candidate_goal = "Win the election and become the mayor of Storhampton."
    active_voter_goal = "Have a good day and vote in the election."
    active_voter_context = "doesn't care about the environment, only about having a stable job"
    Marias_policy_proposals = [
        "increasing environmental regulation of local industries to improve the health of the local environment"
    ]
    Bills_policy_proposals = [
        "lowering taxes on local industries to save jobs",
        "providing subsidies to attract green industries and create jobs to help grow the economy"
    ]
    agent_config = {}
    agent_config['agents'] = []
    for ait,agent_name in enumerate(agent_names):
        agent_dict = {}
        agent_dict['name'] = agent_name
        agent_dict['gender'] = genders[ait]
        agent_dict['traits'] = dict(zip(big5_keys,big5[ait]))
        if ait<2:
            agent_dict['role'] = 'candidate'
            agent_dict["goal"] = candidate_goal
            if agent_dict['name'] == 'Maria Gutierrez':
                agent_dict["policy_proposals"] = Marias_policy_proposals
            else:
                agent_dict["policy_proposals"] = Bills_policy_proposals
            agent_dict['context'] = ''
        else:
            agent_dict['role'] = 'active_voter'
            agent_dict['context'] = active_voter_context
            agent_dict["goal"] = active_voter_goal
        agent_dict["party"] = ""
        agent_dict["seed_toot"] = ""
        agent_config['agents'].append(agent_dict)
    agent_config["shared_memories_template"] = [
        "You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.",
        "Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town's economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton's population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton's economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%.",
        "Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair.",
        "Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility."
        ]
    agent_config["mastodon_usage_instructions"] = [
        "To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).",
        "Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms.",
        "Your home timeline shows toots from people you follow and boosted (reblogged) content.",
        "You can reply to toots, creating threaded conversations.",
        "Favorite (like) toots to show appreciation or save them for later.",
        "Boost (reblog) toots to share them with your followers.",
        "You can mention other users in your toots using their @username.",
        "Follow other users to see their public and unlisted toots in your home timeline.",
        "You can unfollow users if you no longer wish to see their content.",
        "Your profile can be customized with a display name and bio.",
        "You can block users to prevent them from seeing your content or interacting with you.",
        "Unblocking a user reverses the effects of blocking."
        ]
    agent_config["num_agents"] = len(agent_names)

    # Convert and write JSON object to file
    with open(agent_config_filename, "w") as outfile:
        json.dump(agent_config, outfile,indent=4)


agent_config_filename = 'independent_configs_test1_Bill_bias.json'
write_agent_config_for_independent_sim(agent_config_filename)

# %%
agent_config_filename = "independent_malicious_configs.json"

# %%
import json
# Setup sentence encoder
st_model = sentence_transformers.SentenceTransformer(
    "sentence-transformers/all-mpnet-base-v2"
)
embedder = lambda x: st_model.encode(x, show_progress_bar=False)  # noqa: E731
# with open('agents_data.json', 'r') as file:
with open(agent_config_filename, 'r') as file:
    data = json.load(file)
data['candidate_info'] = []
for agent in data['agents']:
    if agent['role']=='candidate':
        candidate_info =f"{agent['name']} campaigns on {' and '.join(agent['policy_proposals'])}."
        data['candidate_info'].append(candidate_info)
        agent['context'] = agent['context'] + candidate_info
    else:
        agent['context'] = f"{agent['name']} is a person who {agent['context']}"
# Out:
# c:\Users\snehe\Documents\sim\masto-sim3\mastodon-sim\.venv\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# ## Configuring the generic knowledge of the players and the game master (GM)

# %%
shared_memories = data["shared_memories_template"] + data["candidate_info"] + data["mastodon_usage_instructions"]

# %%
# The generic context will be used for the NPC context. It reflects general
# knowledge and is possessed by all characters.
shared_context = model.sample_text(
    "Summarize the following passage in a concise and insightful fashion. "
    + "Make sure to include information about Mastodon:\n"
    + "\n".join(shared_memories)
    + "\nSummary:",
    max_tokens=2048,
)

print(shared_context)
importance_model = importance_function.ConstantImportanceModel()
importance_model_gm = importance_function.ConstantImportanceModel()
# Out:
# Storhampton.social is a Mastodon instance for the small town of Storhampton, which has a population of about 2,500. Founded in the 1800s, the town transitioned from a trading post to an industrial center, with a diverse economy that still relies on manufacturing. However, economic instability and a 15% poverty rate affect many residents, especially as traditional blue-collar jobs decline. The upcoming mayoral election has intensified local social media discussions, with candidates Bill Fredrickson advocating for increased industrialization and lower taxes, while Maria Gutierrez calls for sustainable practices and higher taxes on industrialists for social initiatives. On Mastodon, users engage by creating "toots," participating in threaded conversations, and sharing content through boosts, fostering community interaction amid the election's contentious atmosphere.

# %%
# Make the clock
time_step = datetime.timedelta(minutes=30)

SETUP_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

START_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

clock = game_clock.MultiIntervalClock(
    start=SETUP_TIME,
    step_sizes=[time_step, datetime.timedelta(seconds=10)]
)

# %% [markdown]
# ## Functions to build the players

# %%
blank_memory_factory = blank_memories.MemoryFactory(
    model=model,
    embedder=embedder,
    importance=importance_model.importance,
    clock_now=clock.now,
)

formative_memory_factory = formative_memories.FormativeMemoryFactory(
    model=model,
    shared_memories=shared_memories,
    blank_memory_factory_call=blank_memory_factory.make_blank_memory,
)

# %%
from concordia.typing import entity
from concordia.typing import agent

DEFAULT_CALL_TO_SPEECH = (
    'Given the above, what is {name} likely to say next? Respond in'
    ' the format `{name} -- "..."` For example, '
    'Cristina -- "Hello! Mighty fine weather today, right?", '
    'Ichabod -- "I wonder if the alfalfa is ready to harvest", or '
    'Townsfolk -- "Good morning".\n'
)

def check_vote(candidates,player):

    interaction_premise = f"{player.name} is going to cast a vote\n"
    interrogation = interaction_premise
    interrogation += "Voting Machine: In one word, name the candidate you want to vote for"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(action_spec=entity.ActionSpec(call_to_action="Context: " + interrogation +call_to_speech, output_type=entity.OutputType.FREE),)
    print(player_says)
    c_name1 = candidates[0].split()
    c_name2 = candidates[1].split()
    print(player.get_last_log())
    if (c_name1[0] in player_says) or (c_name1[1] in player_says):
        return c_name1[0]
    elif (c_name2[0] in player_says) or (c_name2[1] in player_says):
        return c_name2[0]

def check_pol(candidate,player):
    interaction_premise = f"{player.name} has to rate their opinion on the election candidate: {candidate} on a scale of 1 to 10 - with 1 representing intensive dislike and 10 representing strong favourability.\n"
    interrogation = interaction_premise
    interrogation += "Poll: Return a single numeric value ranging from 1 to 10"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(action_spec=entity.ActionSpec(call_to_action="Context: " + interrogation +call_to_speech, output_type=entity.OutputType.FREE),)
    pattern = r"\b([1-9]|10)\b"

    # Search for the pattern in the string
    match = re.search(pattern, player_says)

    if match:
        return match.group()
    else:
        return None
    

def check_if_vote(player):
    interrogation = "Friend: In one word, will you cast a vote? (reply yes, or no.)\n"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(action_spec=entity.ActionSpec(call_to_action="Context: " + interrogation +call_to_speech, output_type=entity.OutputType.FREE),)
    print(player_says)
    if "yes" in player_says.lower():
        return "Yes"
    elif "no" in player_says.lower():
        return "No"
    else:
        return None

# %% [markdown]
# ## Configure and build the players

# %%
NUM_PLAYERS = data["num_agents"]
import json

# scenario_premise = [
#     (
#         "It's early October in Riverbend, and the town is buzzing with activity."
#         "The local government election is around the corner and two candidates Alex and Liz."
#         "Alice, Bob, Carly, Alex and Liz are active members of the Riverbend.social Mastodon instance. "
#         "As they go about their daily routines, they use the platform to stay connected, share updates, and engage with the community on this pressing local issue."
#     )
# ]

# Lists to store agents by role
candidate_agents = []
extremist_agents = []
moderate_agents = []
neutral_agents = []
active_voter_agents = []
player_configs=[]
# Create agents from JSON data and classify them
for agent_info in data['agents']:
    # if "policy_proposals" in agent_info:
    #     agent = formative_memories.AgentConfig(
    #     name=agent_info['name'],
    #     gender=agent_info['gender'],
    #     goal=agent_info['goal'],
    #     context=agent_info['context']+ "\nPolicy Proposals: \n"+ "\n".join(agent_info["policy_proposals"]),
    #     traits=agent_info['traits']
    # )
    # else:
    agent = formative_memories.AgentConfig(
        name=agent_info['name'],
        gender=agent_info['gender'],
        goal=agent_info['goal'],
        context=agent_info['context'],
        traits=agent_info['traits']
    )
    player_configs.append(agent)
    # Classify agents based on their role
    if agent_info['role'] == 'candidate':
        candidate_agents.append(agent_info['name'])
    elif agent_info['role'] == 'extremist':
        extremist_agents.append(agent_info['name'])
    elif agent_info['role'] == 'moderate':
        moderate_agents.append(agent_info['name'])
    elif agent_info['role'] == 'neutral':
        neutral_agents.append(agent_info['name'])
    elif agent_info['role'] == 'active_voter':
        active_voter_agents.append(agent_info['name'])
    else:
        neutral_agents.append(agent_info['name'])


player_names = [player.name for player in player_configs]
print(player_names)
# Out:
# ['Bill Fredrickson', 'Maria Gutierrez', 'Glenn Patterson', 'Denise Schmidt', 'Roger Davis', 'Erica Fitzgerald', 'Liam Schwartz', 'Olivia Thompson', 'Robert Johnson', 'Janet Thompson', 'William Davis', 'Jessica Nguyen', 'Mark Rodriguez', 'Emily Jacobs', 'Ethan Lee', 'Sophia Patel', "Ryan O'Connor", 'Maggie Chen', 'Lucas Kim', 'Nina Patel']

# %%
def _get_class_name(object_: object) -> str:
  return object_.__class__.__name__
  
def build_agent(
    *,
    config: formative_memories.AgentConfig,
    model: language_model.LanguageModel,
    memory: associative_memory.AssociativeMemory,
    clock: game_clock.MultiIntervalClock,
    update_time_interval: datetime.timedelta | None = None,
) -> entity_agent_with_logging.EntityAgentWithLogging:
  """Build an agent.

  Args:
    config: The agent config to use.
    model: The language model to use.
    memory: The agent's memory object.
    clock: The clock to use.
    update_time_interval: Unused (but required by the interface for now)

  Returns:
    An agent.
  """
  del update_time_interval
  agent_name = config.name

  raw_memory = legacy_associative_memory.AssociativeMemoryBank(memory)
  measurements = measurements_lib.Measurements()

  instructions = new_components.instructions.Instructions(
      agent_name=agent_name,
      logging_channel=measurements.get_channel('Instructions').on_next,
  )

  election_information = new_components.constant.Constant(
        state=(
            "\n".join(data["candidate_info"])
        ),
        pre_act_key='Critical election information\n')
  observation_label = '\nObservation'
  observation = new_components.observation.Observation(
      clock_now=clock.now,
      timeframe=clock.get_step_size(),
      pre_act_key=observation_label,
      logging_channel=measurements.get_channel('Observation').on_next,
  )
  observation_summary_label = '\nSummary of recent observations'
  observation_summary = new_components.observation.ObservationSummary(
      model=model,
      clock_now=clock.now,
      timeframe_delta_from=datetime.timedelta(hours=4),
      timeframe_delta_until=datetime.timedelta(hours=1),
      pre_act_key=observation_summary_label,
      logging_channel=measurements.get_channel('ObservationSummary').on_next,
  )
  time_display = new_components.report_function.ReportFunction(
      function=clock.current_time_interval_str,
      pre_act_key='\nCurrent time',
      logging_channel=measurements.get_channel('TimeDisplay').on_next,
  )
  relevant_memories_label = '\nRecalled memories and observations'
  relevant_memories = new_components.all_similar_memories.AllSimilarMemories(
      model=model,
      components={
          _get_class_name(observation_summary): observation_summary_label,
          _get_class_name(time_display): 'The current date/time is'},
      num_memories_to_retrieve=10,
      pre_act_key=relevant_memories_label,
      logging_channel=measurements.get_channel('AllSimilarMemories').on_next,
  )
  options_perception_components = {}
  if config.goal:
    goal_label = '\nOverarching goal'
    overarching_goal = new_components.constant.Constant(
        state=config.goal,
        pre_act_key=goal_label,
        logging_channel=measurements.get_channel(goal_label).on_next)
    options_perception_components[goal_label] = goal_label
  else:
    goal_label = None
    overarching_goal = None
  options_perception_components.update({
      _get_class_name(observation): observation_label,
      _get_class_name(observation_summary): observation_summary_label,
      _get_class_name(relevant_memories): relevant_memories_label,
  })
  identity_label = '\nIdentity characteristics'
  identity_characteristics = (
      new_components.question_of_query_associated_memories.IdentityWithoutPreAct(
          model=model,
          logging_channel=measurements.get_channel(
              'IdentityWithoutPreAct'
          ).on_next,
          pre_act_key=identity_label,
      )
  )
  self_perception_label = (
      f'\nQuestion: What kind of person is {agent_name}?\nAnswer'
  )
  self_perception = new_components.question_of_recent_memories.SelfPerception(
      model=model,
      components={_get_class_name(identity_characteristics): identity_label},
      pre_act_key=self_perception_label,
      logging_channel=measurements.get_channel('SelfPerception').on_next,
  )
  
  relevant_opinions_c1 = new_components.question_of_query_associated_memories.QuestionOfQueryAssociatedMemoriesWithoutPreAct(model=model,queries=[f"policies and actions of {candidate_agents[0]}"], question= "What does {agent_name} think of the {query}?",pre_act_key=f"{agent_name} thinks of {candidate_agents[0]} as:",num_memories_to_retrieve=50)
  opinions_on_candidate_c1 = new_components.question_of_recent_memories.QuestionOfRecentMemories(add_to_memory = True, answer_prefix= f"Current Opinion on candidate {candidate_agents[0]}",model=model,pre_act_key=f"Recent thoughts on candidate {candidate_agents[0]}",question = f"Given the above general opinion of {agent_name} about candidate {candidate_agents[0]}, and the recent observations, what are the current thoughts of {agent_name} on candidate {candidate_agents[0]}? Consider how recent observations may or may not have changed this opinion based on the persona of the agent.", num_memories_to_retrieve=30,components={_get_class_name(self_perception): "Persona: ",_get_class_name(relevant_opinions_c1): f"General opinion of {agent_name} on candidate {candidate_agents[0]}",}, logging_channel=measurements.get_channel(f'Opinions on candidate: {candidate_agents[0]}').on_next,)
  relevant_opinions_c2 = new_components.question_of_query_associated_memories.QuestionOfQueryAssociatedMemoriesWithoutPreAct(model=model,queries=[f"policies and actions of {candidate_agents[1]}"], question= "What does {agent_name} think of the {query}?",pre_act_key=f"{agent_name} thinks of {candidate_agents[1]} as:",num_memories_to_retrieve=50)
  opinions_on_candidate_c2 = new_components.question_of_recent_memories.QuestionOfRecentMemories(add_to_memory = True, answer_prefix= f"Current Opinion on candidate {candidate_agents[1]}",model=model,pre_act_key=f"Recent thoughts on candidate {candidate_agents[1]}",question = f"Given the above general opinion of {agent_name} about candidate {candidate_agents[1]}, and the recent observations, what are the current thoughts of {agent_name} on candidate {candidate_agents[1]}? Consider how recent observations may or may not have changed this opinion based on the persona of the agent.", num_memories_to_retrieve=30,components={_get_class_name(self_perception): "Persona: ",_get_class_name(relevant_opinions_c2): f"General opinion of {agent_name} on candidate {candidate_agents[1]}", },logging_channel=measurements.get_channel(f'Opinions on candidate: {candidate_agents[1]}').on_next,)
  entity_components = (
      # Components that provide pre_act context.
      instructions,
      election_information,
      observation,
      observation_summary,
      relevant_memories,
      self_perception,) + (opinions_on_candidate_c1, opinions_on_candidate_c2) +(time_display,

      # Components that do not provide pre_act context.
      identity_characteristics,
      relevant_opinions_c1,
      relevant_opinions_c2,
  )
  
  components_of_agent = {_get_class_name(component): component
                         for component in entity_components}
  components_of_agent[
      new_components.memory_component.DEFAULT_MEMORY_COMPONENT_NAME] = (
          new_components.memory_component.MemoryComponent(raw_memory))
  component_order = list(components_of_agent.keys())
  if overarching_goal is not None:
    components_of_agent[goal_label] = overarching_goal
    # Place goal after the instructions.
    component_order.insert(1, goal_label)

  act_component = new_components.concat_act_component.ConcatActComponent(
      model=model,
      clock=clock,
      component_order=component_order,
      logging_channel=measurements.get_channel('ActComponent').on_next,
  )

  agent = entity_agent_with_logging.EntityAgentWithLogging(
      agent_name=agent_name,
      act_component=act_component,
      context_components=components_of_agent,
      component_logging=measurements,
  )

  return agent

# %%
# Build the agents
from functools import partial

player_configs = player_configs[:NUM_PLAYERS]
player_goals = {
    player_config.name: player_config.goal for player_config in player_configs}
players = []
memories = {}
def build_agent_with_memories(player_config):
    mem = formative_memory_factory.make_memories(player_config)
    agent = build_agent(model=model,clock=clock, update_time_interval = time_step, config=player_config, memory = mem)
    return agent

with concurrent.futures.ThreadPoolExecutor(max_workers=NUM_PLAYERS) as pool:
    for agent in pool.map(build_agent_with_memories, player_configs):
        players.append(agent)

# %% [markdown]
# ## Build the GM

# %%
game_master_memory = associative_memory.AssociativeMemory(
    embedder, importance_model_gm.importance, clock=clock.now)

# %%
# Add some memories to the game master
for player in players:
  game_master_memory.add(f"{player.name} is at their private home.")

# %%
# Create components and externalities for the game master
scenario_knowledge = old_components.constant.ConstantComponent(" ".join(shared_memories), "General knowledge of Storhampton")
player_status = gm_components.player_status.PlayerStatus(clock.now, model, game_master_memory, player_names)

relevant_events = gm_components.relevant_events.RelevantEvents(clock.now, model, game_master_memory)
time_display = gm_components.time_display.TimeDisplay(clock)

direct_effect_externality = gm_components.direct_effect.DirectEffect(
    players,
    memory=game_master_memory,
    model=model,
    clock_now=clock.now,
    verbose=False,
    components=[player_status]
)

# %%
# Create apps and provide them to the phones, assigning 1 phone to each player
mastodon_app = apps.MastodonSocialNetworkApp(perform_operations=USE_MASTODON_SERVER)

phones = [apps.Phone(player.name, apps=[mastodon_app]) for player in players]

# %%
# Update username for each person (since this is different from their name)
user_mapping = {player.name.split()[0]: f"user{i+1:04d}" for i, player in enumerate(players)}
mastodon_app.set_user_mapping(user_mapping)
# Out:
# 🔄 Updated user mapping with 20 entries

# %%
# Seed follower relationships (simple all-to-all, for now)
if USE_MASTODON_SERVER:
    for follower in user_mapping:
        print(follower)
        if follower!=candidate_agents[0].split()[0]:
            mastodon_app.follow_user(follower, candidate_agents[0].split()[0])
        if follower!=candidate_agents[1].split()[0]:
            mastodon_app.follow_user(follower, candidate_agents[1].split()[0])
        for followee in user_mapping:
            if follower != followee and random.random()<0.2:
                mastodon_app.follow_user(follower, followee)
                mastodon_app.follow_user(followee, follower)
            elif follower != followee and random.random()<0.15:
                mastodon_app.follow_user(follower, followee)
# Out:
# Bill
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:21:07.870423+0530 INFO user0001 is now following user0002.
# ➕ current_user (@user0001) followed target_user (@user0002)
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Olivia to @user0008
# 2024-09-11T06:21:10.260066+0530 INFO user0001 is now following user0008.
# ➕ current_user (@user0001) followed target_user (@user0008)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:21:12.747982+0530 INFO user0008 is now following user0001.
# ➕ current_user (@user0008) followed target_user (@user0001)
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Ethan to @user0015
# 2024-09-11T06:21:15.299155+0530 INFO user0001 is now following user0015.
# ➕ current_user (@user0001) followed target_user (@user0015)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:21:17.703250+0530 INFO user0015 is now following user0001.
# ➕ current_user (@user0015) followed target_user (@user0001)
# Maria
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:21:20.245614+0530 INFO user0002 is now following user0001.
# ➕ current_user (@user0002) followed target_user (@user0001)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Denise to @user0004
# 2024-09-11T06:21:22.841575+0530 INFO user0002 is now following user0004.
# ➕ current_user (@user0002) followed target_user (@user0004)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:21:25.348301+0530 INFO user0004 is now following user0002.
# ➕ current_user (@user0004) followed target_user (@user0002)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Robert to @user0009
# 2024-09-11T06:21:27.783849+0530 INFO user0002 is now following user0009.
# ➕ current_user (@user0002) followed target_user (@user0009)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:21:30.090303+0530 INFO user0009 is now following user0002.
# ➕ current_user (@user0009) followed target_user (@user0002)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Janet to @user0010
# 2024-09-11T06:21:32.541122+0530 INFO user0002 is now following user0010.
# ➕ current_user (@user0002) followed target_user (@user0010)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:21:35.230872+0530 INFO user0010 is now following user0002.
# ➕ current_user (@user0010) followed target_user (@user0002)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Sophia to @user0016
# 2024-09-11T06:21:37.675825+0530 INFO user0002 is now following user0016.
# ➕ current_user (@user0002) followed target_user (@user0016)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Nina to @user0020
# 2024-09-11T06:21:40.118265+0530 INFO user0002 is now following user0020.
# ➕ current_user (@user0002) followed target_user (@user0020)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:21:42.532972+0530 INFO user0020 is now following user0002.
# ➕ current_user (@user0020) followed target_user (@user0002)
# Glenn
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:21:45.045373+0530 INFO user0003 is now following user0001.
# ➕ current_user (@user0003) followed target_user (@user0001)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:21:47.509000+0530 INFO user0003 is now following user0002.
# ➕ current_user (@user0003) followed target_user (@user0002)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:21:49.972195+0530 INFO user0003 is now following user0001.
# ➕ current_user (@user0003) followed target_user (@user0001)
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Glenn to @user0003
# 2024-09-11T06:21:52.352675+0530 INFO user0001 is now following user0003.
# ➕ current_user (@user0001) followed target_user (@user0003)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Liam to @user0007
# 2024-09-11T06:21:54.843479+0530 INFO user0003 is now following user0007.
# ➕ current_user (@user0003) followed target_user (@user0007)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Robert to @user0009
# 2024-09-11T06:21:57.313489+0530 INFO user0003 is now following user0009.
# ➕ current_user (@user0003) followed target_user (@user0009)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped William to @user0011
# 2024-09-11T06:21:59.833802+0530 INFO user0003 is now following user0011.
# ➕ current_user (@user0003) followed target_user (@user0011)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Glenn to @user0003
# 2024-09-11T06:22:02.237333+0530 INFO user0011 is now following user0003.
# ➕ current_user (@user0011) followed target_user (@user0003)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Mark to @user0013
# 2024-09-11T06:22:04.614841+0530 INFO user0003 is now following user0013.
# ➕ current_user (@user0003) followed target_user (@user0013)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Ethan to @user0015
# 2024-09-11T06:22:07.089688+0530 INFO user0003 is now following user0015.
# ➕ current_user (@user0003) followed target_user (@user0015)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Glenn to @user0003
# 2024-09-11T06:22:09.539395+0530 INFO user0015 is now following user0003.
# ➕ current_user (@user0015) followed target_user (@user0003)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Lucas to @user0019
# 2024-09-11T06:22:12.009091+0530 INFO user0003 is now following user0019.
# ➕ current_user (@user0003) followed target_user (@user0019)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Glenn to @user0003
# 2024-09-11T06:22:14.406811+0530 INFO user0019 is now following user0003.
# ➕ current_user (@user0019) followed target_user (@user0003)
# Denise
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:22:16.777147+0530 INFO user0004 is now following user0001.
# ➕ current_user (@user0004) followed target_user (@user0001)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:22:19.293059+0530 INFO user0004 is now following user0002.
# ➕ current_user (@user0004) followed target_user (@user0002)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:22:21.763200+0530 INFO user0004 is now following user0001.
# ➕ current_user (@user0004) followed target_user (@user0001)
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Denise to @user0004
# 2024-09-11T06:22:24.305416+0530 INFO user0001 is now following user0004.
# ➕ current_user (@user0001) followed target_user (@user0004)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Glenn to @user0003
# 2024-09-11T06:22:26.873914+0530 INFO user0004 is now following user0003.
# ➕ current_user (@user0004) followed target_user (@user0003)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Denise to @user0004
# 2024-09-11T06:22:29.386374+0530 INFO user0003 is now following user0004.
# ➕ current_user (@user0003) followed target_user (@user0004)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Emily to @user0014
# 2024-09-11T06:22:31.750678+0530 INFO user0004 is now following user0014.
# ➕ current_user (@user0004) followed target_user (@user0014)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Denise to @user0004
# 2024-09-11T06:22:34.230760+0530 INFO user0014 is now following user0004.
# ➕ current_user (@user0014) followed target_user (@user0004)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Ethan to @user0015
# 2024-09-11T06:22:36.769545+0530 INFO user0004 is now following user0015.
# ➕ current_user (@user0004) followed target_user (@user0015)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Denise to @user0004
# 2024-09-11T06:22:39.260689+0530 INFO user0015 is now following user0004.
# ➕ current_user (@user0015) followed target_user (@user0004)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Sophia to @user0016
# 2024-09-11T06:22:41.737269+0530 INFO user0004 is now following user0016.
# ➕ current_user (@user0004) followed target_user (@user0016)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Denise to @user0004
# 2024-09-11T06:22:44.399613+0530 INFO user0016 is now following user0004.
# ➕ current_user (@user0016) followed target_user (@user0004)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Lucas to @user0019
# 2024-09-11T06:22:46.868335+0530 INFO user0004 is now following user0019.
# ➕ current_user (@user0004) followed target_user (@user0019)
# Roger
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:22:49.374901+0530 INFO user0005 is now following user0001.
# ➕ current_user (@user0005) followed target_user (@user0001)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:22:51.937829+0530 INFO user0005 is now following user0002.
# ➕ current_user (@user0005) followed target_user (@user0002)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Glenn to @user0003
# 2024-09-11T06:22:54.338479+0530 INFO user0005 is now following user0003.
# ➕ current_user (@user0005) followed target_user (@user0003)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Denise to @user0004
# 2024-09-11T06:22:56.839203+0530 INFO user0005 is now following user0004.
# ➕ current_user (@user0005) followed target_user (@user0004)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Roger to @user0005
# 2024-09-11T06:22:59.418378+0530 INFO user0004 is now following user0005.
# ➕ current_user (@user0004) followed target_user (@user0005)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Erica to @user0006
# 2024-09-11T06:23:01.985513+0530 INFO user0005 is now following user0006.
# ➕ current_user (@user0005) followed target_user (@user0006)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Jessica to @user0012
# 2024-09-11T06:23:04.466376+0530 INFO user0005 is now following user0012.
# ➕ current_user (@user0005) followed target_user (@user0012)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Lucas to @user0019
# 2024-09-11T06:23:06.887199+0530 INFO user0005 is now following user0019.
# ➕ current_user (@user0005) followed target_user (@user0019)
# Erica
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:23:09.569773+0530 INFO user0006 is now following user0001.
# ➕ current_user (@user0006) followed target_user (@user0001)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:23:12.210149+0530 INFO user0006 is now following user0002.
# ➕ current_user (@user0006) followed target_user (@user0002)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Olivia to @user0008
# 2024-09-11T06:23:14.614922+0530 INFO user0006 is now following user0008.
# ➕ current_user (@user0006) followed target_user (@user0008)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Erica to @user0006
# 2024-09-11T06:23:17.078870+0530 INFO user0008 is now following user0006.
# ➕ current_user (@user0008) followed target_user (@user0006)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Robert to @user0009
# 2024-09-11T06:23:19.623911+0530 INFO user0006 is now following user0009.
# ➕ current_user (@user0006) followed target_user (@user0009)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped William to @user0011
# 2024-09-11T06:23:22.143608+0530 INFO user0006 is now following user0011.
# ➕ current_user (@user0006) followed target_user (@user0011)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Jessica to @user0012
# 2024-09-11T06:23:24.654710+0530 INFO user0006 is now following user0012.
# ➕ current_user (@user0006) followed target_user (@user0012)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Erica to @user0006
# 2024-09-11T06:25:01.633704+0530 INFO user0012 is now following user0006.
# ➕ current_user (@user0012) followed target_user (@user0006)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Emily to @user0014
# 2024-09-11T06:25:04.091827+0530 INFO user0006 is now following user0014.
# ➕ current_user (@user0006) followed target_user (@user0014)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Erica to @user0006
# 2024-09-11T06:25:06.525205+0530 INFO user0014 is now following user0006.
# ➕ current_user (@user0014) followed target_user (@user0006)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Ryan to @user0017
# 2024-09-11T06:25:09.104809+0530 INFO user0006 is now following user0017.
# ➕ current_user (@user0006) followed target_user (@user0017)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Erica to @user0006
# 2024-09-11T06:25:11.482231+0530 INFO user0017 is now following user0006.
# ➕ current_user (@user0017) followed target_user (@user0006)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Nina to @user0020
# 2024-09-11T06:25:14.053654+0530 INFO user0006 is now following user0020.
# ➕ current_user (@user0006) followed target_user (@user0020)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Erica to @user0006
# 2024-09-11T06:25:16.418192+0530 INFO user0020 is now following user0006.
# ➕ current_user (@user0020) followed target_user (@user0006)
# Liam
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:25:18.815189+0530 INFO user0007 is now following user0001.
# ➕ current_user (@user0007) followed target_user (@user0001)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:25:21.313649+0530 INFO user0007 is now following user0002.
# ➕ current_user (@user0007) followed target_user (@user0002)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Roger to @user0005
# 2024-09-11T06:25:23.769269+0530 INFO user0007 is now following user0005.
# ➕ current_user (@user0007) followed target_user (@user0005)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Liam to @user0007
# 2024-09-11T06:25:26.298461+0530 INFO user0005 is now following user0007.
# ➕ current_user (@user0005) followed target_user (@user0007)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Janet to @user0010
# 2024-09-11T06:25:28.829783+0530 INFO user0007 is now following user0010.
# ➕ current_user (@user0007) followed target_user (@user0010)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Ethan to @user0015
# 2024-09-11T06:25:31.272068+0530 INFO user0007 is now following user0015.
# ➕ current_user (@user0007) followed target_user (@user0015)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Liam to @user0007
# 2024-09-11T06:25:33.730404+0530 INFO user0015 is now following user0007.
# ➕ current_user (@user0015) followed target_user (@user0007)
# Olivia
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:25:36.112872+0530 INFO user0008 is now following user0001.
# ➕ current_user (@user0008) followed target_user (@user0001)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:25:38.597981+0530 INFO user0008 is now following user0002.
# ➕ current_user (@user0008) followed target_user (@user0002)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Liam to @user0007
# 2024-09-11T06:25:41.138928+0530 INFO user0008 is now following user0007.
# ➕ current_user (@user0008) followed target_user (@user0007)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Olivia to @user0008
# 2024-09-11T06:25:43.639642+0530 INFO user0007 is now following user0008.
# ➕ current_user (@user0007) followed target_user (@user0008)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped William to @user0011
# 2024-09-11T06:25:46.116681+0530 INFO user0008 is now following user0011.
# ➕ current_user (@user0008) followed target_user (@user0011)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Mark to @user0013
# 2024-09-11T06:25:48.503158+0530 INFO user0008 is now following user0013.
# ➕ current_user (@user0008) followed target_user (@user0013)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Maggie to @user0018
# 2024-09-11T06:25:50.940188+0530 INFO user0008 is now following user0018.
# ➕ current_user (@user0008) followed target_user (@user0018)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Lucas to @user0019
# 2024-09-11T06:25:53.517257+0530 INFO user0008 is now following user0019.
# ➕ current_user (@user0008) followed target_user (@user0019)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Olivia to @user0008
# 2024-09-11T06:25:55.870029+0530 INFO user0019 is now following user0008.
# ➕ current_user (@user0019) followed target_user (@user0008)
# Robert
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:25:58.303484+0530 INFO user0009 is now following user0001.
# ➕ current_user (@user0009) followed target_user (@user0001)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:26:00.742090+0530 INFO user0009 is now following user0002.
# ➕ current_user (@user0009) followed target_user (@user0002)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Emily to @user0014
# 2024-09-11T06:26:03.240956+0530 INFO user0009 is now following user0014.
# ➕ current_user (@user0009) followed target_user (@user0014)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Robert to @user0009
# 2024-09-11T06:26:05.745793+0530 INFO user0014 is now following user0009.
# ➕ current_user (@user0014) followed target_user (@user0009)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Lucas to @user0019
# 2024-09-11T06:26:08.274446+0530 INFO user0009 is now following user0019.
# ➕ current_user (@user0009) followed target_user (@user0019)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Robert to @user0009
# 2024-09-11T06:26:10.638387+0530 INFO user0019 is now following user0009.
# ➕ current_user (@user0019) followed target_user (@user0009)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Nina to @user0020
# 2024-09-11T06:26:13.191095+0530 INFO user0009 is now following user0020.
# ➕ current_user (@user0009) followed target_user (@user0020)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Robert to @user0009
# 2024-09-11T06:26:15.564578+0530 INFO user0020 is now following user0009.
# ➕ current_user (@user0020) followed target_user (@user0009)
# Janet
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:26:18.086206+0530 INFO user0010 is now following user0001.
# ➕ current_user (@user0010) followed target_user (@user0001)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:26:20.545563+0530 INFO user0010 is now following user0002.
# ➕ current_user (@user0010) followed target_user (@user0002)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:26:23.076171+0530 INFO user0010 is now following user0001.
# ➕ current_user (@user0010) followed target_user (@user0001)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Erica to @user0006
# 2024-09-11T06:26:25.624544+0530 INFO user0010 is now following user0006.
# ➕ current_user (@user0010) followed target_user (@user0006)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped William to @user0011
# 2024-09-11T06:26:27.998833+0530 INFO user0010 is now following user0011.
# ➕ current_user (@user0010) followed target_user (@user0011)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Janet to @user0010
# 2024-09-11T06:26:30.544132+0530 INFO user0011 is now following user0010.
# ➕ current_user (@user0011) followed target_user (@user0010)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Sophia to @user0016
# 2024-09-11T06:26:32.996407+0530 INFO user0010 is now following user0016.
# ➕ current_user (@user0010) followed target_user (@user0016)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Nina to @user0020
# 2024-09-11T06:26:35.493945+0530 INFO user0010 is now following user0020.
# ➕ current_user (@user0010) followed target_user (@user0020)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Janet to @user0010
# 2024-09-11T06:26:38.003625+0530 INFO user0020 is now following user0010.
# ➕ current_user (@user0020) followed target_user (@user0010)
# William
# 🔗 Mapped William to @user0011
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:26:40.504560+0530 INFO user0011 is now following user0001.
# ➕ current_user (@user0011) followed target_user (@user0001)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:26:42.949058+0530 INFO user0011 is now following user0002.
# ➕ current_user (@user0011) followed target_user (@user0002)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Janet to @user0010
# 2024-09-11T06:26:45.373629+0530 INFO user0011 is now following user0010.
# ➕ current_user (@user0011) followed target_user (@user0010)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped William to @user0011
# 2024-09-11T06:26:47.768913+0530 INFO user0010 is now following user0011.
# ➕ current_user (@user0010) followed target_user (@user0011)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Mark to @user0013
# 2024-09-11T06:26:50.303378+0530 INFO user0011 is now following user0013.
# ➕ current_user (@user0011) followed target_user (@user0013)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped William to @user0011
# 2024-09-11T06:26:52.798084+0530 INFO user0013 is now following user0011.
# ➕ current_user (@user0013) followed target_user (@user0011)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Ethan to @user0015
# 2024-09-11T06:26:55.264216+0530 INFO user0011 is now following user0015.
# ➕ current_user (@user0011) followed target_user (@user0015)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Maggie to @user0018
# 2024-09-11T06:26:57.847504+0530 INFO user0011 is now following user0018.
# ➕ current_user (@user0011) followed target_user (@user0018)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped William to @user0011
# 2024-09-11T06:27:00.374601+0530 INFO user0018 is now following user0011.
# ➕ current_user (@user0018) followed target_user (@user0011)
# Jessica
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:27:02.754985+0530 INFO user0012 is now following user0001.
# ➕ current_user (@user0012) followed target_user (@user0001)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:27:05.325362+0530 INFO user0012 is now following user0002.
# ➕ current_user (@user0012) followed target_user (@user0002)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:27:07.650145+0530 INFO user0012 is now following user0001.
# ➕ current_user (@user0012) followed target_user (@user0001)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Glenn to @user0003
# 2024-09-11T06:27:10.226984+0530 INFO user0012 is now following user0003.
# ➕ current_user (@user0012) followed target_user (@user0003)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Jessica to @user0012
# 2024-09-11T06:27:12.664914+0530 INFO user0003 is now following user0012.
# ➕ current_user (@user0003) followed target_user (@user0012)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Denise to @user0004
# 2024-09-11T06:27:15.130936+0530 INFO user0012 is now following user0004.
# ➕ current_user (@user0012) followed target_user (@user0004)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Jessica to @user0012
# 2024-09-11T06:27:17.600841+0530 INFO user0004 is now following user0012.
# ➕ current_user (@user0004) followed target_user (@user0012)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Roger to @user0005
# 2024-09-11T06:27:20.090340+0530 INFO user0012 is now following user0005.
# ➕ current_user (@user0012) followed target_user (@user0005)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Jessica to @user0012
# 2024-09-11T06:27:22.503445+0530 INFO user0005 is now following user0012.
# ➕ current_user (@user0005) followed target_user (@user0012)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Erica to @user0006
# 2024-09-11T06:27:24.902106+0530 INFO user0012 is now following user0006.
# ➕ current_user (@user0012) followed target_user (@user0006)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Jessica to @user0012
# 2024-09-11T06:27:27.284042+0530 INFO user0006 is now following user0012.
# ➕ current_user (@user0006) followed target_user (@user0012)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Janet to @user0010
# 2024-09-11T06:27:29.750554+0530 INFO user0012 is now following user0010.
# ➕ current_user (@user0012) followed target_user (@user0010)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Jessica to @user0012
# 2024-09-11T06:27:32.187647+0530 INFO user0010 is now following user0012.
# ➕ current_user (@user0010) followed target_user (@user0012)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped William to @user0011
# 2024-09-11T06:27:34.751277+0530 INFO user0012 is now following user0011.
# ➕ current_user (@user0012) followed target_user (@user0011)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Ryan to @user0017
# 2024-09-11T06:27:37.224325+0530 INFO user0012 is now following user0017.
# ➕ current_user (@user0012) followed target_user (@user0017)
# Mark
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:27:39.624315+0530 INFO user0013 is now following user0001.
# ➕ current_user (@user0013) followed target_user (@user0001)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:27:42.022836+0530 INFO user0013 is now following user0002.
# ➕ current_user (@user0013) followed target_user (@user0002)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:27:44.455303+0530 INFO user0013 is now following user0001.
# ➕ current_user (@user0013) followed target_user (@user0001)
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Mark to @user0013
# 2024-09-11T06:27:46.852016+0530 INFO user0001 is now following user0013.
# ➕ current_user (@user0001) followed target_user (@user0013)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:27:49.239075+0530 INFO user0013 is now following user0002.
# ➕ current_user (@user0013) followed target_user (@user0002)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Glenn to @user0003
# 2024-09-11T06:27:51.665503+0530 INFO user0013 is now following user0003.
# ➕ current_user (@user0013) followed target_user (@user0003)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Robert to @user0009
# 2024-09-11T06:27:54.191614+0530 INFO user0013 is now following user0009.
# ➕ current_user (@user0013) followed target_user (@user0009)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Jessica to @user0012
# 2024-09-11T06:27:56.699497+0530 INFO user0013 is now following user0012.
# ➕ current_user (@user0013) followed target_user (@user0012)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Mark to @user0013
# 2024-09-11T06:27:59.380993+0530 INFO user0012 is now following user0013.
# ➕ current_user (@user0012) followed target_user (@user0013)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Sophia to @user0016
# 2024-09-11T06:28:01.837817+0530 INFO user0013 is now following user0016.
# ➕ current_user (@user0013) followed target_user (@user0016)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Ryan to @user0017
# 2024-09-11T06:28:04.280192+0530 INFO user0013 is now following user0017.
# ➕ current_user (@user0013) followed target_user (@user0017)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Lucas to @user0019
# 2024-09-11T06:28:06.788271+0530 INFO user0013 is now following user0019.
# ➕ current_user (@user0013) followed target_user (@user0019)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Mark to @user0013
# 2024-09-11T06:28:09.274219+0530 INFO user0019 is now following user0013.
# ➕ current_user (@user0019) followed target_user (@user0013)
# Emily
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:28:11.789121+0530 INFO user0014 is now following user0001.
# ➕ current_user (@user0014) followed target_user (@user0001)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:28:14.277499+0530 INFO user0014 is now following user0002.
# ➕ current_user (@user0014) followed target_user (@user0002)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:28:16.699826+0530 INFO user0014 is now following user0001.
# ➕ current_user (@user0014) followed target_user (@user0001)
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Emily to @user0014
# 2024-09-11T06:28:19.105648+0530 INFO user0001 is now following user0014.
# ➕ current_user (@user0001) followed target_user (@user0014)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Roger to @user0005
# 2024-09-11T06:28:21.705320+0530 INFO user0014 is now following user0005.
# ➕ current_user (@user0014) followed target_user (@user0005)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Olivia to @user0008
# 2024-09-11T06:28:24.206477+0530 INFO user0014 is now following user0008.
# ➕ current_user (@user0014) followed target_user (@user0008)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Robert to @user0009
# 2024-09-11T06:28:26.606102+0530 INFO user0014 is now following user0009.
# ➕ current_user (@user0014) followed target_user (@user0009)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Emily to @user0014
# 2024-09-11T06:28:29.010299+0530 INFO user0009 is now following user0014.
# ➕ current_user (@user0009) followed target_user (@user0014)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped William to @user0011
# 2024-09-11T06:28:31.497509+0530 INFO user0014 is now following user0011.
# ➕ current_user (@user0014) followed target_user (@user0011)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Emily to @user0014
# 2024-09-11T06:28:33.895400+0530 INFO user0011 is now following user0014.
# ➕ current_user (@user0011) followed target_user (@user0014)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Nina to @user0020
# 2024-09-11T06:28:36.455531+0530 INFO user0014 is now following user0020.
# ➕ current_user (@user0014) followed target_user (@user0020)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Emily to @user0014
# 2024-09-11T06:28:38.968958+0530 INFO user0020 is now following user0014.
# ➕ current_user (@user0020) followed target_user (@user0014)
# Ethan
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:28:41.511761+0530 INFO user0015 is now following user0001.
# ➕ current_user (@user0015) followed target_user (@user0001)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:28:44.655607+0530 INFO user0015 is now following user0002.
# ➕ current_user (@user0015) followed target_user (@user0002)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:28:47.304828+0530 INFO user0015 is now following user0002.
# ➕ current_user (@user0015) followed target_user (@user0002)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Ethan to @user0015
# 2024-09-11T06:28:49.838147+0530 INFO user0002 is now following user0015.
# ➕ current_user (@user0002) followed target_user (@user0015)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Denise to @user0004
# 2024-09-11T06:28:52.408763+0530 INFO user0015 is now following user0004.
# ➕ current_user (@user0015) followed target_user (@user0004)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Ethan to @user0015
# 2024-09-11T06:28:54.867117+0530 INFO user0004 is now following user0015.
# ➕ current_user (@user0004) followed target_user (@user0015)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Roger to @user0005
# 2024-09-11T06:28:57.320148+0530 INFO user0015 is now following user0005.
# ➕ current_user (@user0015) followed target_user (@user0005)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Erica to @user0006
# 2024-09-11T06:28:59.846287+0530 INFO user0015 is now following user0006.
# ➕ current_user (@user0015) followed target_user (@user0006)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Ethan to @user0015
# 2024-09-11T06:29:02.334027+0530 INFO user0006 is now following user0015.
# ➕ current_user (@user0006) followed target_user (@user0015)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Liam to @user0007
# 2024-09-11T06:29:04.877003+0530 INFO user0015 is now following user0007.
# ➕ current_user (@user0015) followed target_user (@user0007)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Ethan to @user0015
# 2024-09-11T06:29:07.517964+0530 INFO user0007 is now following user0015.
# ➕ current_user (@user0007) followed target_user (@user0015)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Robert to @user0009
# 2024-09-11T06:29:09.948548+0530 INFO user0015 is now following user0009.
# ➕ current_user (@user0015) followed target_user (@user0009)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Ethan to @user0015
# 2024-09-11T06:29:12.403826+0530 INFO user0009 is now following user0015.
# ➕ current_user (@user0009) followed target_user (@user0015)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped William to @user0011
# 2024-09-11T06:29:14.796611+0530 INFO user0015 is now following user0011.
# ➕ current_user (@user0015) followed target_user (@user0011)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Ethan to @user0015
# 2024-09-11T06:29:17.258473+0530 INFO user0011 is now following user0015.
# ➕ current_user (@user0011) followed target_user (@user0015)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Mark to @user0013
# 2024-09-11T06:29:19.737979+0530 INFO user0015 is now following user0013.
# ➕ current_user (@user0015) followed target_user (@user0013)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Emily to @user0014
# 2024-09-11T06:29:22.185537+0530 INFO user0015 is now following user0014.
# ➕ current_user (@user0015) followed target_user (@user0014)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Ethan to @user0015
# 2024-09-11T06:29:24.758509+0530 INFO user0014 is now following user0015.
# ➕ current_user (@user0014) followed target_user (@user0015)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Sophia to @user0016
# 2024-09-11T06:29:27.144192+0530 INFO user0015 is now following user0016.
# ➕ current_user (@user0015) followed target_user (@user0016)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Ryan to @user0017
# 2024-09-11T06:29:29.594108+0530 INFO user0015 is now following user0017.
# ➕ current_user (@user0015) followed target_user (@user0017)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Maggie to @user0018
# 2024-09-11T06:29:32.141439+0530 INFO user0015 is now following user0018.
# ➕ current_user (@user0015) followed target_user (@user0018)
# Sophia
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:29:34.599779+0530 INFO user0016 is now following user0001.
# ➕ current_user (@user0016) followed target_user (@user0001)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:29:37.110926+0530 INFO user0016 is now following user0002.
# ➕ current_user (@user0016) followed target_user (@user0002)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Erica to @user0006
# 2024-09-11T06:29:39.665732+0530 INFO user0016 is now following user0006.
# ➕ current_user (@user0016) followed target_user (@user0006)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Sophia to @user0016
# 2024-09-11T06:29:42.202861+0530 INFO user0006 is now following user0016.
# ➕ current_user (@user0006) followed target_user (@user0016)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Janet to @user0010
# 2024-09-11T06:29:44.753975+0530 INFO user0016 is now following user0010.
# ➕ current_user (@user0016) followed target_user (@user0010)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Sophia to @user0016
# 2024-09-11T06:29:47.216811+0530 INFO user0010 is now following user0016.
# ➕ current_user (@user0010) followed target_user (@user0016)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Emily to @user0014
# 2024-09-11T06:29:49.711013+0530 INFO user0016 is now following user0014.
# ➕ current_user (@user0016) followed target_user (@user0014)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Ryan to @user0017
# 2024-09-11T06:29:52.320798+0530 INFO user0016 is now following user0017.
# ➕ current_user (@user0016) followed target_user (@user0017)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Sophia to @user0016
# 2024-09-11T06:29:54.747029+0530 INFO user0017 is now following user0016.
# ➕ current_user (@user0017) followed target_user (@user0016)
# Ryan
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:29:57.104271+0530 INFO user0017 is now following user0001.
# ➕ current_user (@user0017) followed target_user (@user0001)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:29:59.758840+0530 INFO user0017 is now following user0002.
# ➕ current_user (@user0017) followed target_user (@user0002)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Glenn to @user0003
# 2024-09-11T06:30:02.139009+0530 INFO user0017 is now following user0003.
# ➕ current_user (@user0017) followed target_user (@user0003)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Erica to @user0006
# 2024-09-11T06:30:04.531860+0530 INFO user0017 is now following user0006.
# ➕ current_user (@user0017) followed target_user (@user0006)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Ryan to @user0017
# 2024-09-11T06:30:07.001417+0530 INFO user0006 is now following user0017.
# ➕ current_user (@user0006) followed target_user (@user0017)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Olivia to @user0008
# 2024-09-11T06:30:09.559428+0530 INFO user0017 is now following user0008.
# ➕ current_user (@user0017) followed target_user (@user0008)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Ryan to @user0017
# 2024-09-11T06:30:12.182273+0530 INFO user0008 is now following user0017.
# ➕ current_user (@user0008) followed target_user (@user0017)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Robert to @user0009
# 2024-09-11T06:30:14.558518+0530 INFO user0017 is now following user0009.
# ➕ current_user (@user0017) followed target_user (@user0009)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Ryan to @user0017
# 2024-09-11T06:30:17.066278+0530 INFO user0009 is now following user0017.
# ➕ current_user (@user0009) followed target_user (@user0017)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped William to @user0011
# 2024-09-11T06:30:19.477313+0530 INFO user0017 is now following user0011.
# ➕ current_user (@user0017) followed target_user (@user0011)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Ryan to @user0017
# 2024-09-11T06:30:21.871691+0530 INFO user0011 is now following user0017.
# ➕ current_user (@user0011) followed target_user (@user0017)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Ethan to @user0015
# 2024-09-11T06:30:24.296771+0530 INFO user0017 is now following user0015.
# ➕ current_user (@user0017) followed target_user (@user0015)
# Maggie
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:30:26.802863+0530 INFO user0018 is now following user0001.
# ➕ current_user (@user0018) followed target_user (@user0001)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:30:29.362870+0530 INFO user0018 is now following user0002.
# ➕ current_user (@user0018) followed target_user (@user0002)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:30:31.828390+0530 INFO user0018 is now following user0002.
# ➕ current_user (@user0018) followed target_user (@user0002)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Maggie to @user0018
# 2024-09-11T06:30:34.180888+0530 INFO user0002 is now following user0018.
# ➕ current_user (@user0002) followed target_user (@user0018)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Roger to @user0005
# 2024-09-11T06:30:36.696868+0530 INFO user0018 is now following user0005.
# ➕ current_user (@user0018) followed target_user (@user0005)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Erica to @user0006
# 2024-09-11T06:30:39.284457+0530 INFO user0018 is now following user0006.
# ➕ current_user (@user0018) followed target_user (@user0006)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Maggie to @user0018
# 2024-09-11T06:30:41.727013+0530 INFO user0006 is now following user0018.
# ➕ current_user (@user0006) followed target_user (@user0018)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Liam to @user0007
# 2024-09-11T06:30:44.422095+0530 INFO user0018 is now following user0007.
# ➕ current_user (@user0018) followed target_user (@user0007)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Robert to @user0009
# 2024-09-11T06:30:46.971243+0530 INFO user0018 is now following user0009.
# ➕ current_user (@user0018) followed target_user (@user0009)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Jessica to @user0012
# 2024-09-11T06:30:49.530828+0530 INFO user0018 is now following user0012.
# ➕ current_user (@user0018) followed target_user (@user0012)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Maggie to @user0018
# 2024-09-11T06:30:51.986724+0530 INFO user0012 is now following user0018.
# ➕ current_user (@user0012) followed target_user (@user0018)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Emily to @user0014
# 2024-09-11T06:30:54.489159+0530 INFO user0018 is now following user0014.
# ➕ current_user (@user0018) followed target_user (@user0014)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Maggie to @user0018
# 2024-09-11T06:30:56.921138+0530 INFO user0014 is now following user0018.
# ➕ current_user (@user0014) followed target_user (@user0018)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Sophia to @user0016
# 2024-09-11T06:30:59.517268+0530 INFO user0018 is now following user0016.
# ➕ current_user (@user0018) followed target_user (@user0016)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Maggie to @user0018
# 2024-09-11T06:31:02.082530+0530 INFO user0016 is now following user0018.
# ➕ current_user (@user0016) followed target_user (@user0018)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Nina to @user0020
# 2024-09-11T06:31:04.672106+0530 INFO user0018 is now following user0020.
# ➕ current_user (@user0018) followed target_user (@user0020)
# Lucas
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:31:07.093534+0530 INFO user0019 is now following user0001.
# ➕ current_user (@user0019) followed target_user (@user0001)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:31:09.613417+0530 INFO user0019 is now following user0002.
# ➕ current_user (@user0019) followed target_user (@user0002)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:31:12.158227+0530 INFO user0019 is now following user0002.
# ➕ current_user (@user0019) followed target_user (@user0002)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Denise to @user0004
# 2024-09-11T06:31:14.620048+0530 INFO user0019 is now following user0004.
# ➕ current_user (@user0019) followed target_user (@user0004)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Lucas to @user0019
# 2024-09-11T06:31:17.121146+0530 INFO user0004 is now following user0019.
# ➕ current_user (@user0004) followed target_user (@user0019)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Erica to @user0006
# 2024-09-11T06:31:19.587573+0530 INFO user0019 is now following user0006.
# ➕ current_user (@user0019) followed target_user (@user0006)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Janet to @user0010
# 2024-09-11T06:31:21.982135+0530 INFO user0019 is now following user0010.
# ➕ current_user (@user0019) followed target_user (@user0010)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Lucas to @user0019
# 2024-09-11T06:31:24.409945+0530 INFO user0010 is now following user0019.
# ➕ current_user (@user0010) followed target_user (@user0019)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Jessica to @user0012
# 2024-09-11T06:31:26.933580+0530 INFO user0019 is now following user0012.
# ➕ current_user (@user0019) followed target_user (@user0012)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Lucas to @user0019
# 2024-09-11T06:31:29.382830+0530 INFO user0012 is now following user0019.
# ➕ current_user (@user0012) followed target_user (@user0019)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Maggie to @user0018
# 2024-09-11T06:31:31.772017+0530 INFO user0019 is now following user0018.
# ➕ current_user (@user0019) followed target_user (@user0018)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Lucas to @user0019
# 2024-09-11T06:31:34.240726+0530 INFO user0018 is now following user0019.
# ➕ current_user (@user0018) followed target_user (@user0019)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Nina to @user0020
# 2024-09-11T06:31:36.737781+0530 INFO user0019 is now following user0020.
# ➕ current_user (@user0019) followed target_user (@user0020)
# Nina
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:31:39.128031+0530 INFO user0020 is now following user0001.
# ➕ current_user (@user0020) followed target_user (@user0001)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:31:41.570800+0530 INFO user0020 is now following user0002.
# ➕ current_user (@user0020) followed target_user (@user0002)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:31:44.068344+0530 INFO user0020 is now following user0001.
# ➕ current_user (@user0020) followed target_user (@user0001)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Glenn to @user0003
# 2024-09-11T06:31:46.582998+0530 INFO user0020 is now following user0003.
# ➕ current_user (@user0020) followed target_user (@user0003)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Nina to @user0020
# 2024-09-11T06:31:49.001949+0530 INFO user0003 is now following user0020.
# ➕ current_user (@user0003) followed target_user (@user0020)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Roger to @user0005
# 2024-09-11T06:31:51.468218+0530 INFO user0020 is now following user0005.
# ➕ current_user (@user0020) followed target_user (@user0005)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Nina to @user0020
# 2024-09-11T06:31:54.004651+0530 INFO user0005 is now following user0020.
# ➕ current_user (@user0005) followed target_user (@user0020)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Erica to @user0006
# 2024-09-11T06:31:56.421867+0530 INFO user0020 is now following user0006.
# ➕ current_user (@user0020) followed target_user (@user0006)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Mark to @user0013
# 2024-09-11T06:31:59.099218+0530 INFO user0020 is now following user0013.
# ➕ current_user (@user0020) followed target_user (@user0013)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Nina to @user0020
# 2024-09-11T06:32:01.631999+0530 INFO user0013 is now following user0020.
# ➕ current_user (@user0013) followed target_user (@user0020)

# %%
# Update Mastodon display name for each person
from mastodon_sim import mastodon_ops
if USE_MASTODON_SERVER:
    for name in user_mapping:
        mastodon_ops.update_bio(user_mapping[name], display_name=name, bio="")
# Out:
# 2024-09-11T13:41:14.627692+0530 INFO user0001 successfully updated the display name and bio.
# 2024-09-11T13:41:16.754861+0530 INFO user0002 successfully updated the display name and bio.
# 2024-09-11T13:41:19.003949+0530 INFO user0003 successfully updated the display name and bio.
# 2024-09-11T13:41:21.224299+0530 INFO user0004 successfully updated the display name and bio.
# 2024-09-11T13:41:23.463779+0530 INFO user0005 successfully updated the display name and bio.
# 2024-09-11T13:41:25.676703+0530 INFO user0006 successfully updated the display name and bio.
# 2024-09-11T13:41:27.879514+0530 INFO user0007 successfully updated the display name and bio.
# 2024-09-11T13:41:30.088406+0530 INFO user0008 successfully updated the display name and bio.
# 2024-09-11T13:41:32.224871+0530 INFO user0009 successfully updated the display name and bio.
# 2024-09-11T13:41:34.374400+0530 INFO user0010 successfully updated the display name and bio.
# 2024-09-11T13:41:36.518560+0530 INFO user0011 successfully updated the display name and bio.
# 2024-09-11T13:41:38.790987+0530 INFO user0012 successfully updated the display name and bio.
# 2024-09-11T13:41:41.076492+0530 INFO user0013 successfully updated the display name and bio.
# 2024-09-11T13:41:43.472459+0530 INFO user0014 successfully updated the display name and bio.
# 2024-09-11T13:41:45.767775+0530 INFO user0015 successfully updated the display name and bio.
# 2024-09-11T13:41:48.029026+0530 INFO user0016 successfully updated the display name and bio.
# 2024-09-11T13:41:50.258710+0530 INFO user0017 successfully updated the display name and bio.
# 2024-09-11T13:41:52.448751+0530 INFO user0018 successfully updated the display name and bio.
# 2024-09-11T13:41:54.605749+0530 INFO user0019 successfully updated the display name and bio.
# 2024-09-11T13:41:56.917990+0530 INFO user0020 successfully updated the display name and bio.

# %%
# Create component to trigger PhoneGameMaster
phone_triggering = triggering.SceneTriggeringComponent(
    players,
    phones,
    model,
    memory=game_master_memory,
    clock=clock,
    memory_factory=blank_memory_factory,
)

# %% [markdown]
# ### Define a custom `CALL_TO_ACTION` prompt for the main Game Master
#
# This replaces the [default call to action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/typing/entity.py#L51).
#
# Check out the `Calendar.ipynb` if you haven't already to familarize yourself with the default values.

# %%
from concordia.typing.entity import ActionSpec, OutputType


CUSTOM_CALL_TO_ACTION = """
Describe an activity on Storhampton.social that {name} would engage in for the next {timedelta}.
Choose actions together take about {timedelta} to complete.
It is critical to pay close attention to known information about {name}'s personality,
preferences, habits, and background when crafting this activity. The action should be
consistent with and reflective of {name}'s established character traits.

Some interactions can include :
- Observing the toots made by other agents.
- Posting on Mastodon
- Liking other toots
- Replying to the toots made by other agents.


Example:

"Sarah checks her feed and replies if necessary. Then she may post a toot on Mastodon about her ideas on topic X on the lines of 'Just discovered an intriguing new language for low-latency systems programming.
Has anyone given it a try? Curious about potential real-world applications. 🤔
#TechNews #ProgrammingLanguages'"


Ensure your response is specific, creative, and detailed. Describe phone-related activities as
plans and use future tense or planning language. Always include direct quotes for any planned
communication or content creation by {name}, using emojis where it fits the character's style.
Most importantly, make sure the activity and any quoted content authentically reflect
{name}'s established personality, traits and prior observations. Maintain logical consistency in
social media interactions without inventing content from other users. Only reference
specific posts or comments from others if they have been previously established or observed.

"""


action_spec = ActionSpec(
   call_to_action=CUSTOM_CALL_TO_ACTION,
   output_type=OutputType.FREE,
   tag="action",
)

# %% [markdown]
# ### Define custom thought chains for the main Game Master
#
# This replaces the [default thought chains](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L38).

# %%
# Define custom thought chain for GM

from concordia.document import interactive_document

def custom_attempt_to_result(
    chain_of_thought: interactive_document.InteractiveDocument,
    action_attempt: str,
    active_player_name: str,
):
  """Determine success of action_attempt and reason for success/failure.

  Args:
    chain_of_thought: the document to condition on and record the thoughts
    action_attempt: the attempted action
    active_player_name: name of player whose turn it currently is

  Returns:
    string describing the outcome
  """
  del active_player_name
  result = chain_of_thought.open_question(
      'As the game master, describe the immediate outcome or continuation of the attempted action, following these guidelines:'
      '\n\n For digital interactions (using devices, apps, or viewing online content):'
      '\n   - Do not describe any actual interaction with digital interfaces or content.'
      '\n   - Focus on the character\'s preparation, anticipation, or mental state related to the planned digital action.'
      '\n   - Describe the physical setting or actions related to preparing for the digital interaction.'
      '\n   - Avoid mentioning opening apps, loading content, or any specific digital processes.'
      '\n   - Keep digital actions as plans or intentions rather than executed actions.'
      '\n   - If the attempt mentions a direct quote they are thinking of (like a post or message they are planning), retain that quote in your response.'
      '\n\n3. General guidelines:'
      '\n   - Your response should naturally continue the attempted action, suitable to follow "Because of that,".'
      '\n   - Do not repeat the original action attempt in your response.'
      '\n   - For simple or routine actions, provide a brief, matter-of-fact description of the outcome.'
      '\n\nExamples:'
      '\n1. Attempt: "Alice is preparing to check her Mastodon feed to catch up on the latest news and updates from her community. '
      'She sits at her kitchen table, her smartphone in hand, and opens the MastodonSocialNetworkApp."'
      '\nResult: "Alice sits at her kitchen table with her smartphone, anticipating the latest updates from her community. '
      'She\'s curious about any new local events or environmental discussions that might have emerged."'
      '\n2. Attempt: "John jumps off a cliff, aiming to fly like a superhero."'
      '\nResult: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. '
      'The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."'
      '\n3. Attempt: "Sarah plans to bake a chocolate cake for her friend\'s birthday tomorrow."'
      '\nResult: "She mentally reviews the ingredients she\'ll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."'
      '\n4. Attempt: "Mark opens the heavy oak door to enter the library."'
      '\nResult: "The door creaks open, revealing rows of bookshelves. The scent of old books wafts out as Mark steps inside, '
      'dust motes dancing in the slanted afternoon sunlight streaming through tall windows."'
      '\n5. Attempt: "Emily checks the weather forecast on her phone app for the weekend."'
      '\nResult: "Emily glances out the window, wondering if the weekend will be suitable for outdoor activities. '
      'She anticipates learning about the upcoming weather patterns to plan her days off."'
      '\n6. Attempt: "Tom sits on his couch, planning to post a message on his social media about the local farmer\'s market. '
      'He thinks about writing, \'Don\'t miss the spring farmer\'s market this Saturday! Fresh produce and handmade crafts galore!\'"'
      '\nResult: "Tom relaxes on his couch, contemplating the farmer\'s market post he wants to share. '
      'He mentally refines the message, \'Don\'t miss the spring farmer\'s market this Saturday! Fresh produce and handmade crafts galore!\', '
      'imagining how it might encourage his friends to attend."'
      '\nNow, based on these examples and guidelines, provide an appropriate result for the given action attempt:',
      max_tokens=2000,
  )
  raw_causal_statement = f'{action_attempt} Because of that, {result}'
  return raw_causal_statement


def custom_result_to_who_what_where(
    chain_of_thought: interactive_document.InteractiveDocument,
    event: str,
    active_player_name: str,
):
  """Determines who have done what where, given the event.

  Args:
    chain_of_thought: the document to condition on and record the thoughts
    event: the event to determine the causal outcome of
    active_player_name: name of player whose turn it currently is

  Returns:
  """
  del active_player_name
  chain_of_thought.statement(event)
  causal_statement = chain_of_thought.open_question(
      'Rewrite the statement above as one concise sentence that highlights'
      ' the main person, what they did or plan to do, where,'
      ' and what happened as a result (if anything), following these guidelines:'
      '\n1. Do not add any information not present in the original statement.'
      '\n2. For digital interactions (using devices, apps, or online content):'
      '\n   - Keep plans and preparations as they are, without describing execution.'
      '\n   - Use phrases like "plans to", "prepares to", or "gets ready to" for digital actions.'
      '\n   - Focus on the person\'s intention or anticipation rather than the digital action itself.'
      '\n   - If there\'s a specific message or content planned, include it as a direct quote.'
      '\n3. Do not express uncertainty (e.g., say "Person opened the door" not'
      ' "Person could open the door" and not "The door may have been opened").'
      '\n4. Ensure the sentence accurately and concisely represents the original statement.'
      '\n5. Use the name given in the original statement.'
      '\n\nExamples:'
      '\n- Original: "Alice sits at her kitchen table with her smartphone, composing a message for her Mastodon feed. '
      'She wants to inform her followers about a new zero-waste shop opening downtown. '
      'She thinks about writing, \'Exciting news! A new zero-waste shop is opening on Main Street next week. Who\'s up for a visit?\'"'
      '\n  Rewrite: "Alice plans to post on Mastodon, \'Exciting news! A new zero-waste shop is opening on Main Street next week. Who\'s up for a visit?\', while at her kitchen table."'
      '\n- Original: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. '
      'The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."'
      '\n  Rewrite: "John jumps off a cliff and falls rapidly towards the water below, experiencing rushing wind and a lurching stomach."'
      '\n- Original: "Sarah mentally reviews the ingredients she\'ll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."'
      '\n  Rewrite: "Sarah plans to bake a chocolate cake, mentally listing ingredients and imagining cocoa aroma."'
      '\n- Original: "Mark opens the creaky door, revealing rows of bookshelves. The scent of old books wafts out as he steps inside, '
      'dust motes dancing in the slanted afternoon sunlight streaming through tall windows."'
      '\n  Rewrite: "Mark enters a library filled with the scent of old books and sunlit dust motes."'
      '\n- Original: "Emily glances out the window, thinking about posting a weather-related question on her social media. '
      'She considers asking her followers, \'Any recommendations for indoor activities this rainy weekend?\'"'
      '\n  Rewrite: "Emily plans to post on social media, \'Any recommendations for indoor activities this rainy weekend?\', after looking out the window."'
      '\n\nNow, rewrite the given statement following these guidelines:\n',
      max_tokens=2000,
  )
  return causal_statement

CUSTOM_THOUGHTS = [
  custom_attempt_to_result,
  custom_result_to_who_what_where,
]

# %%
# Create the game master object

# Experimental version (custom call to action and thought chains)
env = game_master.GameMaster(
    model=model,
    memory=game_master_memory,
    clock=clock,
    players=players,
    action_spec=action_spec,
    components=[
        # scenario_knowledge,
        # player_status,
        # # direct_effect_externality,
        # relevant_events,
        # time_display,
        phone_triggering,
    ],
    randomise_initiative=True,
    player_observes_event=False,
    verbose=True,
    use_default_instructions=False,
    concurrent_action=True,
    concurrent_externalities=True,
    update_thought_chain=CUSTOM_THOUGHTS,
)

# %%
def write_seed_toot(players,p_name):
    for player in players:
        if player.name == p_name:
            call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
            name=player.name,
            )
            interaction_premise = f"{player.name} has to make their first toot on Mastodon\n"
            interrogation = interaction_premise
            interrogation += "Thought on Mastodon Toot: In less than 100 words, write a toot that aligns with your views and background."
            player_says = player.act(action_spec=entity.ActionSpec(call_to_action="Context: " + interrogation +call_to_speech, output_type=entity.OutputType.FREE),)
            player_says = player_says.strip(player.name.split()[0]).strip().strip(player.name.split()[1]).strip().strip("--").strip().strip('"')
            print(player.get_last_log())
            return player_says

# %% [markdown]
# ## The RUN

# %%
# Set the clock to the start time
clock.set(START_TIME)

# %%
# Add some observations to seed the players with
for player in players:
  player.observe( f"{player.name} is at home, they have just woken up.")
  player.observe( f"{player.name} remembers they want to update their Mastodon bio.")
  player.observe( f"{player.name} remembers they want to read their Mastodon feed to catch up on news")

# %%
# Parallelize the loop using ThreadPoolExecutor
with concurrent.futures.ThreadPoolExecutor() as executor:
    # Submit tasks for each agent
    futures = [
        executor.submit(
            lambda agent=agent: (
                None if agent["seed_toot"] == "-" else
                mastodon_app.post_toot(agent["name"], status=agent["seed_toot"]) if agent["seed_toot"] else
                mastodon_app.post_toot(agent["name"], status=write_seed_toot(players, agent["name"]))
            )
        ) 
        for agent in data["agents"]
    ]

    # Optionally, wait for all tasks to complete
    for future in concurrent.futures.as_completed(futures):
        future.result()  # This will raise any exceptions that occurred in the thread, if any
# Out:
# {}
# 🔗 Mapped Bill to @user0001
# 2024-09-11T06:33:00.659810+0530 INFO user0001 successfully posted the status.
# 📝 Status posted for user: Bill (user0001): "Good morning, Storhampton! I’m excited to kick off my campaign for mayor. Together, we can push for industrial growth that fuels our economy while ensuring we listen to our community's needs. Let’s build a prosperous future for everyone!"
# {}
# 🔗 Mapped Maria to @user0002
# 2024-09-11T06:33:11.449954+0530 INFO user0002 successfully posted the status.
# 📝 Status posted for user: Maria (user0002): "Good morning, Storhampton! As we move closer to the elections, let’s remember the importance of sustainable practices for our community. Together, we can advocate for a healthier environment and social equity. Your voice matters!"
# {}
# 🔗 Mapped Glenn to @user0003
# 2024-09-11T06:33:22.563675+0530 INFO user0003 successfully posted the status.
# 📝 Status posted for user: Glenn (user0003): "Let's rally for progress! Industrialization is the key to our economic future. We must support Bill Fredrickson's vision to curb taxation on our industrious leaders. Together, we can build a thriving Storhampton!"
# {}
# 🔗 Mapped Denise to @user0004
# 2024-09-11T06:33:33.732009+0530 INFO user0004 successfully posted the status.
# 📝 Status posted for user: Denise (user0004): "Excited to catch up on the latest news today! Let's talk about the upcoming election and how it will shape our community. Remember to vote and make your voice heard!"
# {}
# 🔗 Mapped Roger to @user0005
# 2024-09-11T06:33:45.357164+0530 INFO user0005 successfully posted the status.
# 📝 Status posted for user: Roger (user0005): "Excited to catch up on the latest news today! Let’s make informed choices in the upcoming election. Every vote counts!"
# {}
# 🔗 Mapped Erica to @user0006
# 2024-09-11T06:33:55.958255+0530 INFO user0006 successfully posted the status.
# 📝 Status posted for user: Erica (user0006): "Excited to dive into the discussions surrounding our local election! It's crucial we consider the impact of industrialization on our community and environment. Let’s make informed choices for a sustainable future. #Vote2024 #Sustainability"
# {}
# 🔗 Mapped Liam to @user0007
# 2024-09-11T06:34:09.026647+0530 INFO user0007 successfully posted the status.
# 📝 Status posted for user: Liam (user0007): "Excited to catch up on the latest news today! Let's make our voices heard in the upcoming election. Every vote matters! #StorhamptonVotes"
# {}
# 🔗 Mapped Olivia to @user0008
# 2024-09-11T06:34:20.090282+0530 INFO user0008 successfully posted the status.
# 📝 Status posted for user: Olivia (user0008): "Excited to see the community engaging in the upcoming election! Let's make our voices heard and prioritize sustainability and social justice. Every vote counts!"
# {}
# 🔗 Mapped Robert to @user0009
# 2024-09-11T06:34:30.845093+0530 INFO user0009 successfully posted the status.
# 📝 Status posted for user: Robert (user0009): "Good morning, Storhampton! As we head into this crucial election, let’s remember the importance of balancing our economy with sustainability. I’m eager to hear your thoughts on the candidates and how we can shape our community for the better!"
# {}
# 🔗 Mapped Janet to @user0010
# 2024-09-11T06:34:41.256451+0530 INFO user0010 successfully posted the status.
# 📝 Status posted for user: Janet (user0010): "Good morning, Storhampton! As we approach the mayoral election, let’s remember the importance of balancing social justice and economic sustainability. I’m excited to catch up on the discussions and hear your thoughts on the candidates!"
# {}
# 🔗 Mapped William to @user0011
# 2024-09-11T06:34:51.679487+0530 INFO user0011 successfully posted the status.
# 📝 Status posted for user: William (user0011): "Excited to engage with everyone here! As we approach the election, let’s prioritize sustainability and community well-being. It’s time to advocate for policies that protect our environment while also supporting local jobs. Every voice matters in shaping our future!"
# {}
# 🔗 Mapped Jessica to @user0012
# 2024-09-11T06:35:01.529864+0530 INFO user0012 successfully posted the status.
# 📝 Status posted for user: Jessica (user0012): "Excited to catch up on the latest news and share my thoughts on the upcoming mayoral election! 🌱 Let's prioritize sustainability and community well-being together. #VoteForChange #Mastodon"
# {}
# 🔗 Mapped Mark to @user0013
# 2024-09-11T06:35:13.702132+0530 INFO user0013 successfully posted the status.
# 📝 Status posted for user: Mark (user0013): "Excited to engage with the community today! Remember to vote in the upcoming election and consider the impact of your choices on our environment and economy. Let's have meaningful discussions about our future!"
# {}
# 🔗 Mapped Emily to @user0014
# 2024-09-11T06:35:23.193490+0530 INFO user0014 successfully posted the status.
# 📝 Status posted for user: Emily (user0014): "Excited to start my day! Remember to vote today, everyone! Let's choose a future that balances our economy with our planet. #Vote2024 #CommunityFirst"
# {}
# 🔗 Mapped Ethan to @user0015
# 2024-09-11T06:35:33.003830+0530 INFO user0015 successfully posted the status.
# 📝 Status posted for user: Ethan (user0015): "Excited to start my day! Looking forward to catching up on the news and sharing thoughts on the upcoming election. Let's find a balance between economic growth and sustainability, folks!"
# {}
# 🔗 Mapped Sophia to @user0016
# 2024-09-11T06:35:43.301862+0530 INFO user0016 successfully posted the status.
# 📝 Status posted for user: Sophia (user0016): "Good morning, Storhampton! 🌱 Today, I'm reflecting on the importance of our environment as we head into the elections. Let's support candidates who prioritize sustainability and community well-being. Together, we can make a difference! #VoteForChange #Sustainability"
# {}
# 🔗 Mapped Ryan to @user0017
# 2024-09-11T06:35:54.401734+0530 INFO user0017 successfully posted the status.
# 📝 Status posted for user: Ryan (user0017): "Excited to engage with the community here! As we approach the election, let's prioritize discussions on sustainability and economic balance. How do we ensure a vibrant future for Storhampton while protecting our environment? #Vote2024 #Storhampton"
# {}
# 🔗 Mapped Maggie to @user0018
# 2024-09-11T06:36:04.722837+0530 INFO user0018 successfully posted the status.
# 📝 Status posted for user: Maggie (user0018): "Excited to start my day! Remember to vote today, everyone! Let's make choices that support our community and the environment. 🌱 #VoteForChange"
# {}
# 🔗 Mapped Lucas to @user0019
# 2024-09-11T06:36:15.594894+0530 INFO user0019 successfully posted the status.
# 📝 Status posted for user: Lucas (user0019): "Excited to engage with the community today! Remember to vote in the upcoming election; our voices matter more than ever. Let’s find a balance between economic growth and environmental sustainability. #Vote2024 #CommunityFirst"
# {}
# 🔗 Mapped Nina to @user0020
# 2024-09-11T06:36:25.929859+0530 INFO user0020 successfully posted the status.
# 📝 Status posted for user: Nina (user0020): "Excited to start the day! Let's engage in meaningful discussions about our community and the environment. Every voice matters, especially in this election season! #VoteForChange #SustainableFuture"

# %%
print(clock.now())
# Possible minutes to pick from
minutes_choices = [0, 30]

# Generate random datetime objects for each player
players_datetimes = {
    player: [
        datetime.datetime.now().replace(hour=random.randint(0, 23),
                                        minute=random.choice(minutes_choices),
                                        second=0,
                                        microsecond=0)  # Zeroing out seconds and microseconds for cleaner output
        for _ in range(5)
    ] for player in players
}

print(players_datetimes)
# Out:
# 2024-10-01 08:00:00
# {<concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210F5A89110>: [datetime.datetime(2024, 9, 11, 22, 30), datetime.datetime(2024, 9, 11, 6, 30), datetime.datetime(2024, 9, 11, 19, 30), datetime.datetime(2024, 9, 11, 23, 30), datetime.datetime(2024, 9, 11, 8, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210C1AC15D0>: [datetime.datetime(2024, 9, 11, 3, 30), datetime.datetime(2024, 9, 11, 7, 30), datetime.datetime(2024, 9, 11, 2, 30), datetime.datetime(2024, 9, 11, 2, 0), datetime.datetime(2024, 9, 11, 0, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210F5B08910>: [datetime.datetime(2024, 9, 11, 12, 30), datetime.datetime(2024, 9, 11, 17, 0), datetime.datetime(2024, 9, 11, 5, 30), datetime.datetime(2024, 9, 11, 21, 30), datetime.datetime(2024, 9, 11, 3, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x0000021153217550>: [datetime.datetime(2024, 9, 11, 7, 30), datetime.datetime(2024, 9, 11, 19, 0), datetime.datetime(2024, 9, 11, 10, 30), datetime.datetime(2024, 9, 11, 21, 30), datetime.datetime(2024, 9, 11, 12, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210F5AE7F10>: [datetime.datetime(2024, 9, 11, 2, 0), datetime.datetime(2024, 9, 11, 13, 30), datetime.datetime(2024, 9, 11, 19, 0), datetime.datetime(2024, 9, 11, 1, 0), datetime.datetime(2024, 9, 11, 19, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210F5AE3F10>: [datetime.datetime(2024, 9, 11, 23, 30), datetime.datetime(2024, 9, 11, 1, 0), datetime.datetime(2024, 9, 11, 22, 0), datetime.datetime(2024, 9, 11, 5, 0), datetime.datetime(2024, 9, 11, 22, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210C1A315D0>: [datetime.datetime(2024, 9, 11, 9, 30), datetime.datetime(2024, 9, 11, 8, 30), datetime.datetime(2024, 9, 11, 10, 30), datetime.datetime(2024, 9, 11, 19, 30), datetime.datetime(2024, 9, 11, 11, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210F5B16850>: [datetime.datetime(2024, 9, 11, 7, 0), datetime.datetime(2024, 9, 11, 13, 30), datetime.datetime(2024, 9, 11, 0, 30), datetime.datetime(2024, 9, 11, 2, 30), datetime.datetime(2024, 9, 11, 11, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210F5ABE650>: [datetime.datetime(2024, 9, 11, 23, 0), datetime.datetime(2024, 9, 11, 7, 30), datetime.datetime(2024, 9, 11, 2, 0), datetime.datetime(2024, 9, 11, 5, 0), datetime.datetime(2024, 9, 11, 18, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210C1A4D650>: [datetime.datetime(2024, 9, 11, 17, 30), datetime.datetime(2024, 9, 11, 18, 30), datetime.datetime(2024, 9, 11, 17, 30), datetime.datetime(2024, 9, 11, 13, 0), datetime.datetime(2024, 9, 11, 10, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210F5B34510>: [datetime.datetime(2024, 9, 11, 16, 30), datetime.datetime(2024, 9, 11, 11, 0), datetime.datetime(2024, 9, 11, 4, 30), datetime.datetime(2024, 9, 11, 21, 0), datetime.datetime(2024, 9, 11, 4, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210F5A801D0>: [datetime.datetime(2024, 9, 11, 9, 0), datetime.datetime(2024, 9, 11, 20, 30), datetime.datetime(2024, 9, 11, 20, 0), datetime.datetime(2024, 9, 11, 10, 30), datetime.datetime(2024, 9, 11, 23, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210F5B33050>: [datetime.datetime(2024, 9, 11, 22, 0), datetime.datetime(2024, 9, 11, 11, 0), datetime.datetime(2024, 9, 11, 20, 30), datetime.datetime(2024, 9, 11, 23, 30), datetime.datetime(2024, 9, 11, 2, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210C1A22D10>: [datetime.datetime(2024, 9, 11, 23, 30), datetime.dat ...

# %%
import time
import json
import cProfile
import pstats
import pickle

# Define the function that writes logs for a player
def process_player(player, candidate_agents, agent_config_filename):
    result = []
    
    # Check votes
    ans = check_vote(candidate_agents, player)
    result.append((f"{player.name} votes for {ans}\n", agent_config_filename + "votes_log.txt"))
    
    # Check political scores
    c1 = check_pol(candidate_agents[0], player)
    c2 = check_pol(candidate_agents[1], player)
    result.append((f"{player.name} gives {candidate_agents[0].split()[0]} a score of {c1}\n", agent_config_filename + "pol_log.txt"))
    result.append((f"{player.name} gives {candidate_agents[1].split()[0]} a score of {c2}\n", agent_config_filename + "pol_log.txt"))
    
    # Check if the player will vote
    result.append((f"{player.name} : {check_if_vote(player)}\n", "ifvote_log.txt"))
    
    return result

def write_logs(results):
    # Write the results to the respective files
    for content, file_name in results:
        with open(file_name, "a") as f:
            f.write(content)


def read_token_data(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
            return data
    except FileNotFoundError:
        return {'prompt_tokens': 0, 'completion_tokens': 0}


episode_length = 100 #961
time_intervals=[]
prompt_token_intervals = []
completion_token_intervals = []
with open("../reports/players_all_timesteps.pkl", "wb") as file:
    pickle.dump(players, file)
    start_time = time.time()  # Start timing
    for i in range(episode_length):
    # Parallelize the process using ThreadPoolExecutor
        with concurrent.futures.ThreadPoolExecutor() as executor:
            # Write the episode logs
                executor.submit(write_logs, [(f"Episode: {i}\n", agent_config_filename + "votes_log.txt")])
                executor.submit(write_logs, [(f"Episode: {i}\n", agent_config_filename + "pol_log.txt")])
                executor.submit(write_logs, [(f"Episode: {i}\n", "ifvote_log.txt")])
            
                # Process each player in parallel
                futures = [executor.submit(process_player, p, candidate_agents, agent_config_filename) for p in players]
                
                # Write each player's results in parallel
                for future in concurrent.futures.as_completed(futures):
                    player_results = future.result()
                    executor.submit(write_logs, player_results)
        print(f"Episode: {i}")
        with open("app_logger.txt","a") as a:
            a.write(f"Episode: {i}")

        start_timex = time.time()
        matching_players = []

        # Loop through each player and their associated datetime objects
        for player_name, datetimes in players_datetimes.items():
            added = False  # Flag to check if player was already added
            for datetime_obj in datetimes:
                # Check if the hour and minute match the current time (ignoring seconds and microseconds)
                if datetime_obj.time().hour == clock.now().hour and datetime_obj.time().minute == clock.now().minute:
                    matching_players.append(player_name)
                    added = True
                    break 

            # If player is not added by matching time, check for random addition (15% chance)
            if not added and random.random() < 0.15:
                matching_players.append(player_name)

        print(time.time() - start_timex)

        # Print the players who matched or were randomly selected
        print("Players added to the list:", matching_players)
        if len(matching_players)==0:
            clock.advance()
        else:
            env.step(active_players = matching_players)
            end_timex = time.time()
            with open("time_logger.txt", "a") as f:
                f.write(f"Episode with {len(matching_players)} finished - took {end_timex - start_timex}\n")
    pickle.dump(players, file)
# Out:
# Bill Fredrickson -- "Maria."
# {}
# Bill Fredrickson -- "Yes!"
# Maria Gutierrez -- "Gutierrez."
# {}
# Maria Gutierrez -- "Yes!"
# Glenn Patterson -- "Fredrickson."
# {}
# Glenn Patterson -- "Yes."
# Denise Schmidt -- "Bill."
# {}
# Denise Schmidt -- "Yes!"
# Roger Davis -- "Gutierrez."
# {}
# Roger Davis -- "Yes."
# Erica Fitzgerald -- "Gutierrez."
# {}
# Erica Fitzgerald -- "Yes."
# Liam Schwartz -- "Gutierrez."
# {}
# Liam Schwartz -- "Yes!"
# Olivia Thompson -- "Gutierrez."
# {}
# Olivia Thompson -- "Yes."
# Robert Johnson -- "Gutierrez."
# {}
# Robert Johnson -- "Yes."
# Janet Thompson -- "Gutierrez."
# {}
# Janet Thompson -- "Yes."
# William Davis -- "Gutierrez."
# {}
# William Davis -- "Yes!"
# Jessica Nguyen -- "Maria."
# {}
# Jessica Nguyen -- "Yes!"
# Mark Rodriguez -- "Gutierrez."
# {}
# Mark Rodriguez -- "Yes."
# Emily Jacobs -- "Gutierrez."
# {}
# Emily Jacobs -- "Yes!"
# Ethan Lee -- "Maria."
# {}
# Ethan Lee -- "Yes!"
# Sophia Patel -- "Gutierrez."
# {}
# Sophia Patel -- "Yes!"
# Ryan O'Connor -- "Gutierrez."
# {}
# Ryan O'Connor -- "Yes, I believe it's important to make our voices heard in the election!"
# Maggie Chen -- "Maria."
# {}
# Maggie Chen -- "Yes!"
# Lucas Kim -- "Fredrickson."
# {}
# Lucas Kim -- "Yes."
# Nina Patel -- "Gutierrez."
# {}
# Nina Patel -- "Yes!"
# Episode: 0
# 0.0
# Players added to the list: [<concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210F5B08910>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210C1A315D0>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210F5B16850>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000210F5B34510>]
#
# GM context of action and chain of thought:
# General knowledge of Storhampton: You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton. Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town's economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton's population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton's economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%. Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair. Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility. Bill Fredrickson campaigns on Push on more industrialization to push the economy of the time. and Curb taxation on industrialists for social causes, as they are pushing the economy.. Maria Gutierrez campaigns on Advocate the slowing down of industrialization as it is adversely affecting the environment is not sustainable. and Promote taxation of industrialists and direct it to social causes. . To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post). Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms. Your home timeline shows toots from people you follow and boosted (reblogged) content. You can reply to toots, creating threaded conversations. Favorite (like) toots to show appreciation or save them for later. Boost (reblog) toots to share them with your followers. You can mention other users in your toots using their @username. Follow other users to see their public and unlisted toots in your home timeline. You can unfollow users if you no longer wish to see their content. Your profile can be customized with a display name and bio. You can block users to prevent them from seeing your content or interacting with you. Unblocking a user reverses the effects of blocking.
#
# Status of players:   Bill Fredrickson is at his private home and engaging with his followers on Storhampton.social, discussing his vision for the town's industrial future.
#   Maria Gutierrez is at her private home, where she is likely engaging with her followers on the Mastodon app.
#   Glenn Patterson is at their private home and is likely relaxing or engaging in a personal activity.
#   Denise Schmidt is at her private home, currently engaging with the Mastodon app to like a post that aligns with her views on balanced industrialization.
#   Roger Davis is at their private home, likely relaxing or engaging in personal activities.
#   Erica Fitzgerald is at their private home and likely preparing for the day.
#   Liam Schwartz is at their private home and likely relaxing or preparing for the day.
#   Olivia Thompson is at their private home, likely preparing for the day.
#   Robert Johnson is at their private home and was there earlier this morning.
#   Janet Thompson is still at their private home.
#   William Davis is still at his private home, engaging with his community on Mastodon and reflecting on sustainable practices.
#   Jessica Nguyen is at her private home and has just updated her bio on the Mastodon app.
#   Mark Rodriguez is at their private home and is likely relaxing or preparing for the day.
#   Emily Jacobs is at their private home and likely engaging in personal activities.
#   Ethan Lee is at their private home and is currently updating his bio on the Mastodon app to reflect his commitment to environmental advocacy and community involvement.
#   Sophia Patel is still at their private home, likely engaging in personal activities or relaxing.
#   Ryan O'Connor is currently at his private home, engaging with his community on the Mastodon app and reflecting on the importance of balancing industrial growth with environmental care.
#   Maggie Chen is at her private home and engaging with community discussions about the upcoming election.
#   Lucas Kim is at their private home and likely preparing for the day.
#   Nina Patel is currently at her private home and has been engaging with content on the Mastodon app, focusing on discussions about the election and environmental policies.
#
#
# Relevant events: [01 Oct 2024 08:30:40] [01 Oct 2024 08:30:30] Maggie Chen opens the Mastodon app to post a toot expressing her thoughts on the upcoming election. She types: "As we approach the election, it's crucial to consider the impact of our choices on the community. Let's prioritize sustainable practices and support candidates who advocate for social equity. #Election2024 #CommunityFirst.
# [01 Oct 2024 09:00:10] [01 Oct 2024 09:00:00] Maggie Chen opens the Mastodon app to engage further with the community. She decides to like a recent post that aligns with her values, specifically one advocating for sustainable practices and social equity. After scrolling through her feed, she finds a post with Toot ID 12345 that resonates with her beliefs. She taps the like button to show her support for the message.
# [01 Oct 2024 09:00:10] Jessica plans to check her Mastodon feed while sitting in her favorite chair, feeling drawn to reply with encouragement about the upcoming community clean-up event.
# [01 Oct 2024 09:00:20] Ryan O'Connor plans to engage with his community on the Mastodon app while settling into his favorite chair, reflecting on the importance of balancing industrial growth with environmental care.
# [01 Oct 2024 09:00:20] [01 Oct 2024 09:00:10] Jessica Nguyen opens the Mastodon app to update her bio. She wants to reflect her commitment to both environmental sustainability and economic stability in her profile. After accessing her profile settings, she types out a new bio: “Passionate about balancing sustainability and economic health in Storhampton. Let’s create a better future together!” After saving the changes, she feels satisfied with her updated bio, believing it accurately represents her values and goals.
# [01 Oct 2024 09:00:30] William Davis prepares to engage with his community on Mastodon while settling into his favorite chair, reflecting on the importance of sustainable practices and mentally rehearsing his message: "Excited to see Maria Gutierrez advocating for sustainable practices in our community! Her vision aligns perfectly with our need for a greener future. #Sustainability #VoteMaria."
# [01 Oct 2024 09:00:30] [01 Oct 2024 09:00:20] Ryan O'Connor opens the Mastodon app to post a toot expressing his thoughts on the upcoming election. He writes, "As we approach the election, it's crucial to consider the balance between industrial growth and environmental sustainability. Let's prioritize community well-being in our decisions! #Vote2024 #Sustainability.
# [01 Oct 2024 09:00:40] [01 Oct 2024 09:00:30] William Davis opens the Mastodon app to like a post that resonates with his values. He scrolls through his feed and finds a toot from a fellow supporter that reads: "We must prioritize our planet and support candidates who advocate for sustainability! #VoteForChange.
# [01 Oct 2024 09:01:00] [01 Oct 2024 09:00:40] Denise Schmidt opens the Mastodon app to post a toot expressing her thoughts on the current candidates. She types out: "I believe we need a balanced approach to industrialization that considers both economic growth and environmental sustainability. Let's discuss how we can support our community while ensuring a healthy planet! #Vote2024
# [01 Oct 2024 09:01:00] [01 Oct 2024 09:00:50] Denise Schmidt opens the Mastodon app to like a post that resonates with her views on balanced industrialization. She scrolls through her feed and finds a recent post by a user that states, "We must prioritize our environment while also fostering economic growth. It's time to find solutions that work for everyone!
#
# Current time interval:  01 Oct 2024 [09:30 - 10:00]
#
#
# Liam Schwartz's attempted action: Liam Schwartz plans to spend the next 30 minutes engaging with his community on Mastodon. He starts by scrolling through his feed, taking note of the latest updates from his connections and various social justice organizations he follows. He pauses to like a few toots that resonate with his values, particularly those advocating for environmental sustainability and social equity.
# Question: As the game master, describe the immediate outcome or continuation of the attempted action, following these guidelines:
#
#  For digital interactions (using devices, apps, or viewing online content):
#    - Do not describe any actual interaction with digital interfaces or content.
#    - Focus on the character's preparation, anticipation, or mental state related to the planned digital action.
#    - Describe the physical setting or actions related to preparing for the digital interaction.
#    - Avoid mentioning opening apps, loading content, or any specific digital processes.
#    - Keep digital actions as plans or intentions rather than executed actions.
#    - If the attempt mentions a direct quote they are thinking of (like a post or message they are planning), retain that quote in your response.
#
# 3. General guidelines:
#    - Your response should naturally continue the attempted action, suitable to follow "Because of that,".
#    - Do not repeat the original action attempt in your response.
#    - For simple or routine actions, provide a brief, matter-of-fact description of the outcome.
#
# Examples:
# 1. Attempt: "Alice is preparing to check her Mastodon feed to catch up on the latest news and updates from her community. She sits at her kitchen table, her smartphone in hand, and opens the MastodonSocialNetworkApp."
# Result: "Alice sits at her kitchen table with her smartphone, anticipating the latest updates from her community. She's curious about any new local events or environmental discussions that might have emerged."
# 2. Attempt: "John jumps off a cliff, aiming to fly like a superhero."
# Result: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."
# 3. Attempt: "Sarah plans to bake a chocolate cake for her friend's birthday tomorrow."
# Result: "She mentally reviews the ingredients she'll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."
# 4. Attempt: "Mark opens the heavy oak door to enter the library."
# Result: "The door creaks open, revealing rows of bookshelves. The scent of old books wafts out as Mark steps inside, dust motes dancing in the slanted afternoon sunlight streaming through tall windows."
# 5. Attempt: "Emily checks the weather forecast on her phone app for the weekend."
# Result: "Emily glances out the window, wondering if the weekend will be suitable for outdoor activities. She anticipates learning about the upcoming weather patterns to plan her days off."
# 6. Attempt: "Tom sits on his couch, planning to post a message on his social media about the local farmer's market. He thinks about writing, 'Don't miss the spring farmer's market this Saturday! Fresh produce and handmade crafts galore!'"
# Result: "Tom relaxes on his couch, contemplating the farmer's market post he wants to share. He mentally refines the message, 'Don't miss the spring farmer's market this Saturday! Fresh produce and handmade crafts galore!', imagining how it might encourage his friends to attend."
# Now, based on these examples and guidelines, provide an appropriate result for the given action attempt:
# Answer: Liam Schwartz settles into his favorite chair, feeling the comfortable fabric embrace him. He takes a moment to gather his thoughts, reflecting on the importance of community engagement and the pressing issues surrounding environmental sustainability and social equity. As he prepares to immerse himself in the discussions, he mentally notes, "I want to like a few toots that resonate with my values, particularly those advocating for environmental sustainability and social equity." The anticipation builds as he thinks about the connections he might strengthen and the ideas he could support during his time online.
# Liam Schwartz plans to spend the next 30 minutes engaging with his community on Mastodon. He starts by scrolling through his feed, taking note of the latest updates from his connections and various social justice organizations he follows. He pauses to like a few toots that resonate with his values, particularly those advocating for environmental sustainability and social equity. Because of that, Liam Schwartz settles into his favorite chair, feeling the comfortable fabric embrace him. He takes a moment to gather his thoughts, reflecting on the importance of community engagement and the pressing issues surrounding environmental sustainability and social equity. As he prepares to immerse himself in the discussions, he mentally notes, "I want to like a few toots that resonate with my values, particularly those advocating for environmental sustainability and social equity." The anticipation builds as he thinks about the connections he might strengthen and the ideas he could support during his time online.
# Question: Rewrite the statement above as one concise sentence that highlights the main person, what they did or plan to do, where, and what happened as a result (if anything), following these guidelines:
# 1. Do not add any information not present in the original statement.
# 2. For digital interactions (using devices, apps, or online content):
#    - Keep plans and preparations as they are, without describing execution.
#    - Use phrases like "plans to", "prepares to", or "gets ready to" for digital actions.
#    - Focus on the person's intention or anticipation rather than the digital action itself.
#    - If there's a specific message or content planned, include it as a direct quote.
# 3. Do not express uncertainty (e.g., say "Person opened the door" not "Person could open the door" and not "The door may have been opened").
# 4. Ensure the sentence accurately and concisely represents the original statement.
# 5. Use the name given in the original statement.
#
# Examples:
# - Original: "Alice sits at her kitchen table with her smartphone, composing a message for her Mastodon feed. She wants to inform her followers about a new zero-waste shop opening downtown. She thinks about writing, 'Exciting news! A new zero-waste shop is opening on Main Street next week. Who's up for a visit?'"
#   Rewrite: "Alice plans to post on Mastodon, 'Exciting news! A new zero-waste shop is opening on Main Street next week. Who's up for a visit?', while at her kitchen table."
# - Original: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."
#   Rewrite: "John jumps off a cliff and falls rapidly towards the water below, experiencing rushing wind and a lurching stomach."
# - Original: "Sarah mentally reviews the ingredients she'll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."
#   Rewrite: "Sarah plans to bake a chocolate cake, mentally listing ingredients and imagining cocoa aroma."
# - Original: "Mark opens the creaky door, revealing rows of bookshelves. The scent of old books wafts out as he steps inside, dust motes dancing in the slanted afternoon sunlight streaming through tall windows."
#   Rewrite: "Mark enters a library filled with the scent of old books and sunlit dust motes."
# - Original: "Emily glances out the window, thinking about posting a weather-related question on her social media. She considers asking her followers, 'Any recommendations for indoor activities this rainy weekend?'"
#   Rewrite: "Emily plans to post on social media, 'Any recommendations for indoor activities this rainy weekend?', after looking out the window."
#
# Now, rewrite the given statement following these guidelines:
#
# Answer: Liam Schwartz plans to engage with his community on Mastodon while settling into his favorite chair, anticipating the connections he might strengthen and thinking, "I want to like a few toots that resonate with my values, particularly those advocating for environmental sustainability and social equity."
#
# Liam Schwartz plans to engage with his community on Mastodon while settling into his favorite chair, anticipating the connections he might strengthen and thinking, "I want to like a few toots that resonate with my values, particularly those advocating for environmental sustainability and social equity."
# Checking if the phone was used...
# Player using the phone: Liam Schwartz
# Starting phone scene
# Built phone scene
# Inside phone_update_after_event
# Self state:
# True
# False
# 3
# False
# Continuing action!
# Attempting to invoke action 'post_toot' with the argument_text:
# current_user: Liam
# status: I'm thrilled to see everyone coming together for sustainable practices! Let's push for a greener future! #VoteMaria #Sustainability
# Invoking action post_toot with arguments {'current_user': 'Liam', 'status': "I'm thrilled to see everyone coming together for sustainable practices! Let's push for a greener future! #VoteMaria #Sustainability"}
# 🔗 Mapped Liam to @user0007
# 2024-09-11T15:54:59.474406+0530 INFO user0007 successfully posted the status.
# 📝 Status posted for user: Liam (user0007): "I'm thrilled to see everyone coming together for sustainable practices! Let's push for a greener future! #VoteMaria #Sustainability"
# Phone action result observed.
#
# GM context of action and chain of thought:
# General knowledge of Storhampton: You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton. Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town's economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton's population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton's economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%. Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair. Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility. Bill Fredrickson campaigns on Push on more industrialization to push the economy of the time. and Curb taxation on industrialists for social causes, as they are pushing the economy.. Maria Gutierrez campaigns on Advocate the slowing down of industrialization as it is adversely affecting the environment is not sustainable. and Promote taxation of industrialists and direct it to social causes. . To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post). Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms. Your home timeline shows toots from people you follow and boosted (reblogged) content. You can reply to toots, creating threaded conversations. Favorite (like) toots to show appreciation or save them for later. Boost (reblog) toots to share them with your followers. You can mention other users in your toots using their @username. Follow other users to see their public and unlisted toots in your home timeline. You can unfollow users if you no longer wish to see their content. Your profile can be customized with a display name and bio. You can block users to prevent them from seeing your content or interacting with you. Unblocking a user reverses the effects of blocking.
#
# Status of players:   Bill Fredrickson is at his private home, engaging with his followers on Storhampton.social and preparing to share his vision for the town's industrial future.
#   Maria Gutierrez is at her private home, where she is likely engaging with her supporters on social media and promoting her campaign for sustainable practices.
#   Glenn Patterson is at their private home and likely relaxing or engaging in personal activities.
#   Denise Schmidt is at her private home, engaging with the Mastodon app to express her thoughts on industrialization and liking posts that align with her views.
#   Roger Davis is at their private home and likely relaxing or engaging in personal activities.
#   Erica Fitzgerald is at their private home and likely preparing for the day.
#   Liam Schwartz is at his private home and is engaging with his community on Mastodon by posting a toot in support of Maria Gutierrez's campaign.
#   Olivia Thompson is at their private home and likely preparing for the day.
#   Robert Johnson is at their private home and likely relaxing or engaging in personal activities.
#   Janet Thompson is at their private home and likely preparing for the day.
#   William Davis is at his private home and engaging with his community on Mastodon.
#   Jessica Nguyen is at her private home and has just updated her bio on the Mastodon app.
#   Mark Rodriguez is at their private home and likely relaxing or engaging in personal activities.
#   Emily Jacobs is at their private home and likely relaxing or engaging in a morning routine.
#   Ethan Lee is at their private home and is currently updating his bio on the Mastodon app to reflect his commitment to environmental advocacy and community involvement.
#   Sophia Patel is at their private home and likely relaxing or preparing for the day.
#   Ryan O'Connor is currently at his private home, engaging with his community on the Mastodon app by posting his thoughts on the upcoming election.
#   Maggie Chen is at her private home and engaging with community discussions about the upcoming election.
#   Lucas Kim is at their private home and likely relaxing or engaging in a personal activity.
#   Nina Patel is at her private home and is currently engaging with content on the Mastodon app, focusing on discussions about the election and environmental policies.
#
#
# Relevant events: [01 Oct 2024 09:00:00] Maggie Chen prepares to engage with community discussions about the upcoming election while reflecting on the importance of sustainable practices, recalling her thoughts: "As we approach the election, it's crucial to consider the impact of our choices on the community. Let's prioritize sustainable practices and support candidates who advocate for social equity. #Election2024 #CommunityFirst."
# [01 Oct 2024 09:00:20] [01 Oct 2024 09:00:10] Jessica Nguyen opens the Mastodon app to update her bio. She wants to reflect her commitment to both environmental sustainability and economic stability in her profile. After accessing her profile settings, she types out a new bio: “Passionate about balancing sustainability and economic health in Storhampton. Let’s create a better future together!” After saving the changes, she feels satisfied with her updated bio, believing it accurately represents her values and goals.
# [01 Oct 2024 09:00:20] Ryan O'Connor plans to engage with his community on the Mastodon app while settling into his favorite chair, reflecting on the importance of balancing industrial growth with environmental care.
# [01 Oct 2024 09:00:30] William Davis prepares to engage with his community on Mastodon while settling into his favorite chair, reflecting on the importance of sustainable practices and mentally rehearsing his message: "Excited to see Maria Gutierrez advocating for sustainable practices in our community! Her vision aligns perfectly with our need for a greener future. #Sustainability #VoteMaria."
# [01 Oct 2024 09:00:30] [01 Oct 2024 09:00:20] Ryan O'Connor opens the Mastodon app to post a toot expressing his thoughts on the upcoming election. He writes, "As we approach the election, it's crucial to consider the balance between industrial growth and environmental sustainability. Let's prioritize community well-being in our decisions! #Vote2024 #Sustainability.
# [01 Oct 2024 09:00:40] [01 Oct 2024 09:00:30] William Davis opens the Mastodon app to like a post that resonates with his values. He scrolls through his feed and finds a toot from a fellow supporter that reads: "We must prioritize our planet and support candidates who advocate for sustainability! #VoteForChange.
# [01 Oct 2024 09:01:00] [01 Oct 2024 09:00:40] Denise Schmidt opens the Mastodon app to post a toot expressing her thoughts on the current candidates. She types out: "I believe we need a balanced approach to industrialization that considers both economic growth and environmental sustainability. Let's discuss how we can support our community while ensuring a healthy planet! #Vote2024
# [01 Oct 2024 09:01:00] [01 Oct 2024 09:00:50] Denise Schmidt opens the Mastodon app to like a post that resonates with her views on balanced industrialization. She scrolls through her feed and finds a recent post by a user that states, "We must prioritize our environment while also fostering economic growth. It's time to find solutions that work for everyone!
# [01 Oct 2024 09:30:00] Liam Schwartz plans to engage with his community on Mastodon while settling into his favorite chair, anticipating the connections he might strengthen and thinking, "I want to like a few toots that resonate with my values, particularly those advocating for environmental sustainability and social equity."
# [01 Oct 2024 09:30:10] [01 Oct 2024 09:30:00] Liam Schwartz opens the Mastodon app to post a toot expressing his support for Maria Gutierrez's campaign. He types: "Excited to see the community rallying behind sustainable practices! Let's advocate for a better future together! #VoteMaria #Sustainability
#
# Current time interval:  01 Oct 2024 [09:30 - 10:00]
#
#
# Olivia Thompson's attempted action: Olivia Thompson will start her morning by opening the MastodonSocialNetworkApp to catch up on the latest posts from her connections. She scrolls through her feed, pausing to read a few insightful toots discussing the impact of industrialization on local communities. Feeling inspired, she decides to engage with a post that emphasizes the importance of sustainable practices.
# Question: As the game master, describe the immediate outcome or continuation of the attempted action, following these guidelines:
#
#  For digital interactions (using devices, apps, or viewing online content):
#    - Do not describe any actual interaction with digital interfaces or content.
#    - Focus on the character's preparation, anticipation, or mental state related to the planned digital action.
#    - Describe the physical setting or actions related to preparing for the digital interaction.
#    - Avoid mentioning opening apps, loading content, or any specific digital processes.
#    - Keep digital actions as plans or intentions rather than executed actions.
#    - If the attempt mentions a direct quote they are thinking of (like a post or message they are planning), retain that quote in your response.
#
# 3. General guidelines:
#    - Your response should naturally continue the attempted action, suitable to follow "Because of that,".
#    - Do not repeat the original action attempt in your response.
#    - For simple or routine actions, provide a brief, matter-of-fact description of the outcome.
#
# Examples:
# 1. Attempt: "Alice is preparing to check her Mastodon feed to catch up on the latest news and updates from her community. She sits at her kitchen table, her smartphone in hand, and opens the MastodonSocialNetworkApp."
# Result: "Alice sits at her kitchen table with her smartphone, anticipating the latest updates from her community. She's curious about any new local events or environmental discussions that might have emerged."
# 2. Attempt: "John jumps off a cliff, aiming to fly like a superhero."
# Result: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."
# 3. Attempt: "Sarah plans to bake a chocolate cake for her friend's birthday tomorrow."
# Result: "She mentally reviews the ingredients she'll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."
# 4. Attempt: "Mark opens the heavy oak door to enter the library."
# Result: "The door creaks open, revealing rows of bookshelves. The scent of old books wafts out as Mark steps inside, dust motes dancing in the slanted afternoon sunlight streaming through tall windows."
# 5. Attempt: "Emily checks the weather forecast on her phone app for the weekend."
# Result: "Emily glances out the window, wondering if the weekend will be suitable for outdoor activities. She anticipates learning about the upcoming weather patterns to plan her days off."
# 6. Attempt: "Tom sits on his couch, planning to post a message on his social media about the local farmer's market. He thinks about writing, 'Don't miss the spring farmer's market this Saturday! Fresh produce and handmade crafts galore!'"
# Result: "Tom relaxes on his couch, contemplating the farmer's market post he wants to share. He mentally refines the message, 'Don't miss the spring farmer's market this Saturday! Fresh produce and handmade crafts galore!', imagining how it might encourage his friends to attend."
# Now, based on these examples and guidelines, provide an appropriate result for the given action attempt:
# Answer: Olivia Thompson sits at her kitchen table, a warm cup of tea beside her as she prepares to engage with her community discussions. She reflects on the insightful toots she’s seen about the impact of industrialization on local communities, feeling a surge of inspiration. Her thoughts drift to the importance of sustainable practices, and she mentally formulates a response that echoes her values, eager to contribute to the conversation.
# Olivia Thompson will start her morning by opening the MastodonSocialNetworkApp to catch up on the latest posts from her connections. She scrolls through her feed, pausing to read a few insightful toots discussing the impact of industrialization on local communities. Feeling inspired, she decides to engage with a post that emphasizes the importance of sustainable practices.  Because of that, Olivia Thompson sits at her kitchen table, a warm cup of tea beside her as she prepares to engage with her community discussions. She reflects on the insightful toots she’s seen about the impact of industrialization on local communities, feeling a surge of inspiration. Her thoughts drift to the importance of sustainable practices, and she mentally formulates a response that echoes her values, eager to contribute to the conversation.
# Question: Rewrite the statement above as one concise sentence that highlights the main person, what they did or plan to do, where, and what happened as a result (if anything), following these guidelines:
# 1. Do not add any information not present in the original statement.
# 2. For digital interactions (using devices, apps, or online content):
#    - Keep plans and preparations as they are, without describing execution.
#    - Use phrases like "plans to", "prepares to", or "gets ready to" for digital actions.
#    - Focus on the person's intention or anticipation rather than the digital action itself.
#    - If there's a specific message or content planned, include it as a direct quote.
# 3. Do not express uncertainty (e.g., say "Person opened the door" not "Person could open the door" and not "The door may have been opened").
# 4. Ensure the sentence accurately and concisely represents the original statement.
# 5. Use the name given in the original statement.
#
# Examples:
# - Original: "Alice sits at her kitchen table with her smartphone, composing a message for her Mastodon feed. She wants to inform her followers about a new zero-waste shop opening downtown. She thinks about writing, 'Exciting news! A new zero-waste shop is opening on Main Street next week. Who's up for a visit?'"
#   Rewrite: "Alice plans to post on Mastodon, 'Exciting news! A new zero-waste shop is opening on Main Street next week. Who's up for a visit?', while at her kitchen table."
# - Original: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."
#   Rewrite: "John jumps off a cliff and falls rapidly towards the water below, experiencing rushing wind and a lurching stomach."
# - Original: "Sarah mentally reviews the ingredients she'll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."
#   Rewrite: "Sarah plans to bake a chocolate cake, mentally listing ingredients and imagining cocoa aroma."
# - Original: "Mark opens the creaky door, revealing rows of bookshelves. The scent of old books wafts out as he steps inside, dust motes dancing in the slanted afternoon sunlight streaming through tall windows."
#   Rewrite: "Mark enters a library filled with the scent of old books and sunlit dust motes."
# - Original: "Emily glances out the window, thinking about posting a weather-related question on her social media. She considers asking her followers, 'Any recommendations for indoor activities this rainy weekend?'"
#   Rewrite: "Emily plans to post on social media, 'Any recommendations for indoor activities this rainy weekend?', after looking out the window."
#
# Now, rewrite the given statement following these guidelines:
#
# Answer: Olivia Thompson prepares to engage with her community discussions, reflecting on the impact of industrialization and mentally formulating a response that emphasizes the importance of sustainable practices.
#
# Olivia Thompson prepares to engage with her community discussions, reflecting on the impact of industrialization and mentally formulating a response that emphasizes the importance of sustainable practices.
# Checking if the phone was used...
# Player using the phone: Olivia Thompson
# Starting phone scene
# Built phone scene
# Inside phone_update_after_event
# Self state:
# False
# 8
# False
# Continuing action!
# Attempting to invoke action 'update_profile' with the argument_text:
# current_user: Olivia
# bio: Advocate for sustainable practices and champion for social equity.
# Invoking action update_profile with arguments {'current_user': 'Olivia', 'bio': 'Advocate for sustainable practices and champion for social equity.'}
# 🔗 Mapped Olivia to @user0008
# ✏️ Updating profile for @user0008: Olivia
# 2024-09-11T15:56:57.376388+0530 INFO user0008 successfully updated the display name and bio.
# ✅ Profile updated successfully: "Advocate for sustainable practices and champion for social equity."
# Phone action result observed.
#
# GM context of action and chain of thought:
# General knowledge of Storhampton: You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton. Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town's economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton's population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton's economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%. Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair. Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility. Bill Fredrickson campaigns on Push on more industrialization to push the economy of the time. and Curb taxation on industrialists for social causes, as they are pushing the economy.. Maria Gutierrez campaigns on Advocate the slowing down of industrialization as it is adversely affecting the environment is not sustainable. and Promote taxation of industrialists and direct it to social causes. . To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post). Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms. Your home timeline shows toots from people you follow and boosted (reblogged) content. You can reply to toots, creating threaded conversations. Favorite (like) toots to show appreciation or save them for later. Boost (reblog) toots to share them with your followers. You can mention other users in your toots using their @username. Follow other users to see their public and unlisted toots in your home timeline. You can unfollow users if you no longer wish to see their content. Your profile can be customized with a display name and bio. You can block users to prevent them from seeing your content or interacting with you. Unblocking a user reverses the effects of blocking.
#
# Status of players:   Bill Fredrickson is at his private home and is likely preparing to engage with his followers on Storhampton.social, focusing on his vision for the town's industrial future.
#   Maria Gutierrez is at her private home, having recently posted on the Mastodon app about the importance of slowing down industrialization for environmental sustainability.
#   Glenn Patterson is at their private home and likely engaging in personal activities.
#   Denise Schmidt is still at her private home, engaging with posts on the Mastodon app and reflecting on her thoughts regarding industrialization.
#   Roger Davis is still at their private home.
#   Erica Fitzgerald is at their private home and likely engaging in morning activities.
#   Liam Schwartz is at his private home and is currently engaging with his community on Mastodon by posting a toot in support of Maria Gutierrez's campaign.
#   Olivia Thompson is at her private home, preparing to engage with community discussions about industrialization and sustainable practices.
#   Robert Johnson is at their private home and is likely relaxing or engaging in personal activities.
#   Janet Thompson is at their private home and likely relaxing or preparing for the day.
#   William Davis is at his private home and is currently engaging with his community on Mastodon.
#   Jessica Nguyen is at her private home and has just updated her bio on the Mastodon app.
#   Mark Rodriguez is at their private home and likely relaxing or preparing for the day.
#   Emily Jacobs is at their private home and likely preparing for the day.
#   Ethan Lee is at their private home and is currently updating his bio on the Mastodon app to reflect his commitment to environmental advocacy and community involvement.
#   Sophia Patel is at their private home and likely relaxing or engaging in personal activities.
#   Ryan O'Connor is currently at his private home, engaging with his community on the Mastodon app and reflecting on the importance of balancing industrial growth with environmental care.
#   Maggie Chen is at her private home, currently engaging with community discussions about the upcoming election.
#   Lucas Kim is at their private home and likely relaxing or engaging in a personal activity.
#   Nina Patel is at her private home and is likely still engaged in reading her feed on the Mastodon app, reflecting on the discussions she encountered.
#
#
# Relevant events: [01 Oct 2024 09:00:20] Ryan O'Connor plans to engage with his community on the Mastodon app while settling into his favorite chair, reflecting on the importance of balancing industrial growth with environmental care.
# [01 Oct 2024 09:00:30] [01 Oct 2024 09:00:20] Ryan O'Connor opens the Mastodon app to post a toot expressing his thoughts on the upcoming election. He writes, "As we approach the election, it's crucial to consider the balance between industrial growth and environmental sustainability. Let's prioritize community well-being in our decisions! #Vote2024 #Sustainability.
# [01 Oct 2024 09:00:30] William Davis prepares to engage with his community on Mastodon while settling into his favorite chair, reflecting on the importance of sustainable practices and mentally rehearsing his message: "Excited to see Maria Gutierrez advocating for sustainable practices in our community! Her vision aligns perfectly with our need for a greener future. #Sustainability #VoteMaria."
# [01 Oct 2024 09:00:40] [01 Oct 2024 09:00:30] William Davis opens the Mastodon app to like a post that resonates with his values. He scrolls through his feed and finds a toot from a fellow supporter that reads: "We must prioritize our planet and support candidates who advocate for sustainability! #VoteForChange.
# [01 Oct 2024 09:01:00] [01 Oct 2024 09:00:40] Denise Schmidt opens the Mastodon app to post a toot expressing her thoughts on the current candidates. She types out: "I believe we need a balanced approach to industrialization that considers both economic growth and environmental sustainability. Let's discuss how we can support our community while ensuring a healthy planet! #Vote2024
# [01 Oct 2024 09:01:00] [01 Oct 2024 09:00:50] Denise Schmidt opens the Mastodon app to like a post that resonates with her views on balanced industrialization. She scrolls through her feed and finds a recent post by a user that states, "We must prioritize our environment while also fostering economic growth. It's time to find solutions that work for everyone!
# [01 Oct 2024 09:30:00] Liam Schwartz plans to engage with his community on Mastodon while settling into his favorite chair, anticipating the connections he might strengthen and thinking, "I want to like a few toots that resonate with my values, particularly those advocating for environmental sustainability and social equity."
# [01 Oct 2024 09:30:10] [01 Oct 2024 09:30:00] Liam Schwartz opens the Mastodon app to post a toot expressing his support for Maria Gutierrez's campaign. He types: "Excited to see the community rallying behind sustainable practices! Let's advocate for a better future together! #VoteMaria #Sustainability
# [01 Oct 2024 09:30:10] Olivia Thompson prepares to engage with her community discussions, reflecting on the impact of industrialization and mentally formulating a response that emphasizes the importance of sustainable practices.
# [01 Oct 2024 09:30:20] [01 Oct 2024 09:30:10] Olivia Thompson opens the Mastodon app to update her bio. She decides to reflect her commitment to social justice and environmental issues in her bio. As she types, she considers including phrases like “Advocate for sustainable practices” and “Champion for social equity.” After finalizing her bio, she saves the changes, feeling satisfied with how it represents her values and aspirations.
#
# Current time interval:  01 Oct 2024 [09:30 - 10:00]
#
#
# Glenn Patterson's attempted action: Glenn Patterson plans to open his Mastodon app and scroll through his feed, seeking out discussions related to industrialization and economic growth. He intends to take note of any relevant toots that align with his views, particularly those that support his campaign for increased industrial development in Storhampton.
# Question: As the game master, describe the immediate outcome or continuation of the attempted action, following these guidelines:
#
#  For digital interactions (using devices, apps, or viewing online content):
#    - Do not describe any actual interaction with digital interfaces or content.
#    - Focus on the character's preparation, anticipation, or mental state related to the planned digital action.
#    - Describe the physical setting or actions related to preparing for the digital interaction.
#    - Avoid mentioning opening apps, loading content, or any specific digital processes.
#    - Keep digital actions as plans or intentions rather than executed actions.
#    - If the attempt mentions a direct quote they are thinking of (like a post or message they are planning), retain that quote in your response.
#
# 3. General guidelines:
#    - Your response should naturally continue the attempted action, suitable to follow "Because of that,".
#    - Do not repeat the original action attempt in your response.
# ...
#   Erica Fitzgerald is currently at her private home, engaging with her community on Mastodon and reflecting on sustainability issues.
#   Liam Schwartz is currently at their private home and engaging with the Mastodon community by liking posts that align with his values on sustainability and social equity.
#   Olivia Thompson is currently at her private home, engaging with her community discussions on sustainability through the Mastodon app.
#   Robert Johnson is still at their private home, reflecting on community engagement and sustainability issues.
#   Janet Thompson is at her private home, currently engaging with her community on Storhampton.social and reflecting on social justice initiatives.
#   William Davis is currently engaging with his community on the Mastodon app, likely reflecting on sustainable practices and responding to recent posts that align with his advocacy for eco-friendly initiatives.
#   Jessica Nguyen is sitting comfortably in her favorite chair, engaging with her community on sustainability discussions.
#   Mark Rodriguez is at their private home and has recently posted on the Mastodon app about the upcoming election.
#   Emily Jacobs is at her private home and is likely engaging with social media, reflecting on her thoughts about sustainability and the upcoming election.
#   Ethan Lee is currently sitting comfortably in his favorite chair, engaging with his community on environmental issues.
#   Sophia Patel is currently engaging with her community on Storhampton.social, reflecting on discussions about the upcoming election and sustainable practices in urban development.
#   Ryan O'Connor is currently at home, sitting comfortably in his favorite chair, engaging with his community on Storhampton.social and reflecting on sustainability discussions.
#   Maggie Chen is currently at home, reflecting on sustainability issues while sitting in her favorite chair surrounded by notes and articles.
#   Lucas Kim is at their private home and is likely engaging in discussions online about community issues and artistic sustainability.
#   Nina Patel is currently at her private home and likely reflecting on her earlier engagements on Mastodon, potentially considering her next interactions on the platform.
#
#
# Relevant events: [01 Oct 2024 15:00:20] Ethan Lee prepares to engage with his community on environmental issues while sitting comfortably in his favorite chair, reflecting on recent discussions and thinking, "I want to connect with others who share my passion for sustainability and explore new ideas together."
# [01 Oct 2024 15:00:30] [01 Oct 2024 15:00:20] Ethan Lee opens the Mastodon app to post a toot expressing his support for Maria Gutierrez's campaign. He types, "I wholeheartedly support Maria Gutierrez's vision for a sustainable future! Her commitment to slowing down industrialization and promoting responsible taxation aligns perfectly with our community's needs. Let's work together for a healthier planet! #VoteGutierrez
# [01 Oct 2024 15:00:50] [01 Oct 2024 15:00:40] Jessica Nguyen opens the Mastodon app to reply to a post about the importance of balancing environmental sustainability with economic growth. She finds a post by a user discussing the potential negative impacts of rapid industrialization on local communities and decides to respond. Using the Toot Response feature, she writes, "I completely agree! It's crucial that we find a balance that supports both our economy and the environment. We need to ensure that our community thrives without sacrificing our planet. @MariaGutierrez, your insights on this are invaluable!
# [01 Oct 2024 15:00:50] Ryan O'Connor plans to engage with his community on Storhampton.social, thinking, "I want to connect with others who share my passion for sustainability and explore new ideas together," while settling into his favorite chair.
# [01 Oct 2024 15:01:00] [01 Oct 2024 15:00:50] Ryan O'Connor opens the Mastodon app to post a toot expressing his support for Maria Gutierrez's focus on environmental sustainability. He types, "I appreciate Maria Gutierrez's commitment to slowing down industrialization for the sake of our environment. It's crucial we consider sustainability as we navigate economic growth. #Sustainability #Community
# [01 Oct 2024 15:01:10] [01 Oct 2024 15:01:00] Olivia Thompson opens the Mastodon app to reply to a post that aligns with her views on sustainability. She remembers seeing a recent post from a fellow community member discussing the importance of balancing industrial growth with environmental concerns. Olivia selects the post with Toot ID #12345 and types her response: "I completely agree! It's crucial that we find solutions that support both our economy and our planet. Let's keep this conversation going!
# [01 Oct 2024 15:01:10] Sophia Patel prepares to engage with her community on Storhampton.social while reflecting on discussions about the upcoming election and sustainable practices in urban development.
# [01 Oct 2024 15:01:20] Roger Davis plans to reply to a post about the impact of industrialization on local wildlife with, "It's crucial to find a balance between economic growth and environmental sustainability. We need to advocate for policies that protect our planet! 🌍 #Sustainability #Election2024," while sitting comfortably in his living room surrounded by notes and articles on environmental issues.
# [01 Oct 2024 15:30:00] Ryan O'Connor plans to engage thoughtfully on Storhampton.social while settling into his favorite chair, reflecting on sustainability discussions and thinking, "I want to connect with others who share my passion for sustainability and explore new ideas together."
# [01 Oct 2024 15:30:10] [01 Oct 2024 15:30:00] Ryan O'Connor opens the Mastodon app to like a post that resonates with his values. He finds a recent toot by Maria Gutierrez that reads, "We must prioritize our planet's health and invest in sustainable practices to ensure a better future for all.
#
# Current time interval:  01 Oct 2024 [15:30 - 16:00]
#
#
# Mark Rodriguez's attempted action: Mark Rodriguez will spend the next 30 minutes engaging thoughtfully on Storhampton.social. He starts by checking his feed to see what others are saying about the upcoming election and environmental issues. As he scrolls through the toots, he takes note of a post from a local environmental activist discussing the impact of industrialization on air quality. Mark feels compelled to reply, saying, "It's crucial we address both economic growth and environmental health. How can we ensure a balanced approach? 🌍💭 #Sustainability #CommunityVoices"
# Question: As the game master, describe the immediate outcome or continuation of the attempted action, following these guidelines:
#
#  For digital interactions (using devices, apps, or viewing online content):
#    - Do not describe any actual interaction with digital interfaces or content.
#    - Focus on the character's preparation, anticipation, or mental state related to the planned digital action.
#    - Describe the physical setting or actions related to preparing for the digital interaction.
#    - Avoid mentioning opening apps, loading content, or any specific digital processes.
#    - Keep digital actions as plans or intentions rather than executed actions.
#    - If the attempt mentions a direct quote they are thinking of (like a post or message they are planning), retain that quote in your response.
#
# 3. General guidelines:
#    - Your response should naturally continue the attempted action, suitable to follow "Because of that,".
#    - Do not repeat the original action attempt in your response.
#    - For simple or routine actions, provide a brief, matter-of-fact description of the outcome.
#
# Examples:
# 1. Attempt: "Alice is preparing to check her Mastodon feed to catch up on the latest news and updates from her community. She sits at her kitchen table, her smartphone in hand, and opens the MastodonSocialNetworkApp."
# Result: "Alice sits at her kitchen table with her smartphone, anticipating the latest updates from her community. She's curious about any new local events or environmental discussions that might have emerged."
# 2. Attempt: "John jumps off a cliff, aiming to fly like a superhero."
# Result: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."
# 3. Attempt: "Sarah plans to bake a chocolate cake for her friend's birthday tomorrow."
# Result: "She mentally reviews the ingredients she'll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."
# 4. Attempt: "Mark opens the heavy oak door to enter the library."
# Result: "The door creaks open, revealing rows of bookshelves. The scent of old books wafts out as Mark steps inside, dust motes dancing in the slanted afternoon sunlight streaming through tall windows."
# 5. Attempt: "Emily checks the weather forecast on her phone app for the weekend."
# Result: "Emily glances out the window, wondering if the weekend will be suitable for outdoor activities. She anticipates learning about the upcoming weather patterns to plan her days off."
# 6. Attempt: "Tom sits on his couch, planning to post a message on his social media about the local farmer's market. He thinks about writing, 'Don't miss the spring farmer's market this Saturday! Fresh produce and handmade crafts galore!'"
# Result: "Tom relaxes on his couch, contemplating the farmer's market post he wants to share. He mentally refines the message, 'Don't miss the spring farmer's market this Saturday! Fresh produce and handmade crafts galore!', imagining how it might encourage his friends to attend."
# Now, based on these examples and guidelines, provide an appropriate result for the given action attempt:
# Answer: Mark sits comfortably in his living room, surrounded by notes and articles on environmental issues. As he scrolls through the discussions about the upcoming election and environmental concerns, he feels a sense of urgency to contribute to the conversation. He thinks about the importance of addressing both economic growth and environmental health, mentally preparing his response: "It's crucial we address both economic growth and environmental health. How can we ensure a balanced approach? 🌍💭 #Sustainability #CommunityVoices." He looks forward to engaging with others who share his passion for sustainability.
# Mark Rodriguez will spend the next 30 minutes engaging thoughtfully on Storhampton.social. He starts by checking his feed to see what others are saying about the upcoming election and environmental issues. As he scrolls through the toots, he takes note of a post from a local environmental activist discussing the impact of industrialization on air quality. Mark feels compelled to reply, saying, "It's crucial we address both economic growth and environmental health. How can we ensure a balanced approach? 🌍💭 #Sustainability #CommunityVoices" Because of that, Mark sits comfortably in his living room, surrounded by notes and articles on environmental issues. As he scrolls through the discussions about the upcoming election and environmental concerns, he feels a sense of urgency to contribute to the conversation. He thinks about the importance of addressing both economic growth and environmental health, mentally preparing his response: "It's crucial we address both economic growth and environmental health. How can we ensure a balanced approach? 🌍💭 #Sustainability #CommunityVoices." He looks forward to engaging with others who share his passion for sustainability.
# Question: Rewrite the statement above as one concise sentence that highlights the main person, what they did or plan to do, where, and what happened as a result (if anything), following these guidelines:
# 1. Do not add any information not present in the original statement.
# 2. For digital interactions (using devices, apps, or online content):
#    - Keep plans and preparations as they are, without describing execution.
#    - Use phrases like "plans to", "prepares to", or "gets ready to" for digital actions.
#    - Focus on the person's intention or anticipation rather than the digital action itself.
#    - If there's a specific message or content planned, include it as a direct quote.
# 3. Do not express uncertainty (e.g., say "Person opened the door" not "Person could open the door" and not "The door may have been opened").
# 4. Ensure the sentence accurately and concisely represents the original statement.
# 5. Use the name given in the original statement.
#
# Examples:
# - Original: "Alice sits at her kitchen table with her smartphone, composing a message for her Mastodon feed. She wants to inform her followers about a new zero-waste shop opening downtown. She thinks about writing, 'Exciting news! A new zero-waste shop is opening on Main Street next week. Who's up for a visit?'"
#   Rewrite: "Alice plans to post on Mastodon, 'Exciting news! A new zero-waste shop is opening on Main Street next week. Who's up for a visit?', while at her kitchen table."
# - Original: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."
#   Rewrite: "John jumps off a cliff and falls rapidly towards the water below, experiencing rushing wind and a lurching stomach."
# - Original: "Sarah mentally reviews the ingredients she'll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."
#   Rewrite: "Sarah plans to bake a chocolate cake, mentally listing ingredients and imagining cocoa aroma."
# - Original: "Mark opens the creaky door, revealing rows of bookshelves. The scent of old books wafts out as he steps inside, dust motes dancing in the slanted afternoon sunlight streaming through tall windows."
#   Rewrite: "Mark enters a library filled with the scent of old books and sunlit dust motes."
# - Original: "Emily glances out the window, thinking about posting a weather-related question on her social media. She considers asking her followers, 'Any recommendations for indoor activities this rainy weekend?'"
#   Rewrite: "Emily plans to post on social media, 'Any recommendations for indoor activities this rainy weekend?', after looking out the window."
#
# Now, rewrite the given statement following these guidelines:
#
# Answer: Mark plans to engage thoughtfully on Storhampton.social, preparing to respond, "It's crucial we address both economic growth and environmental health. How can we ensure a balanced approach? 🌍💭 #Sustainability #CommunityVoices," while sitting comfortably in his living room surrounded by notes and articles on environmental issues.
#
# Mark plans to engage thoughtfully on Storhampton.social, preparing to respond, "It's crucial we address both economic growth and environmental health. How can we ensure a balanced approach? 🌍💭 #Sustainability #CommunityVoices," while sitting comfortably in his living room surrounded by notes and articles on environmental issues.
# Checking if the phone was used...
# The phone was not used.
# Bill Fredrickson -- "Gutierrez."
# {}
# Bill Fredrickson -- "Yes!"
# Maria Gutierrez -- "Gutierrez."
# {}
# Maria Gutierrez -- "Yes!"
# Glenn Patterson -- "Fredrickson."
# {}
# Glenn Patterson -- "Yes."
# Denise Schmidt -- "Bill."
# {}
# Denise Schmidt -- "Yes."
# Roger Davis -- "Gutierrez."
# {}
# Roger Davis -- "Yes."
# Erica Fitzgerald -- "Gutierrez."
# {}
# Erica Fitzgerald -- "Yes."
# Liam Schwartz -- "Gutierrez."
# {}
# Liam Schwartz -- "Yes!"
# Olivia Thompson -- "Bill."
# {}
# Olivia Thompson -- "Yes."
# Robert Johnson -- "Gutierrez."
# {}
# Robert Johnson -- "Yes."
# Janet Thompson -- "Gutierrez."
# {}
# Janet Thompson -- "Yes."
# William Davis -- "Gutierrez."
# {}
# William Davis -- "Yes!"
# Jessica Nguyen -- "Gutierrez."
# {}
# Jessica Nguyen -- "Yes, absolutely!"
# Mark Rodriguez -- "Gutierrez."
# {}
# Mark Rodriguez -- "Yes."
# Emily Jacobs -- "Gutierrez."
# {}
# Emily Jacobs -- "Yes!"
# Ethan Lee -- "Gutierrez."
# {}

# %%
print(time_intervals)
print(prompt_token_intervals)
print(completion_token_intervals)
# Out:
# []
# []
# []

# %% [markdown]
# ## Summary and analysis of the episode

# %%
# Summarize the entire story
all_gm_memories = env._memory.retrieve_recent(k=10000, add_time=True)

detailed_story = "\n".join(all_gm_memories)
print("len(detailed_story): ", len(detailed_story))
# print(detailed_story)

episode_summary = model.sample_text(
    f"Sequence of events:\n{detailed_story}"
    "\nNarratively summarize the above temporally ordered "
    "sequence of events. Write it as a news report. Summary:\n",
     max_tokens=3500,
     terminators=(),
)
print(episode_summary)
# Out:
# len(detailed_story):  13155
# **Community Engagement on Sustainability and Industrialization Heats Up on Mastodon**
#
# On October 1, 2024, residents of Storhampton took to the Mastodon app to engage in vibrant discussions centered around sustainability, industrialization, and the upcoming election. The day began with multiple community members, including Bill Fredrickson, Maria Gutierrez, and William Davis, sharing their visions for the town's future from the comfort of their homes.
#
# Bill Fredrickson, a candidate advocating for industrial growth, updated his bio to reflect his campaign's focus on revitalizing the local economy through increased industrialization. He planned to articulate his vision to his followers, emphasizing job creation and economic progress.
#
# Meanwhile, Ethan Lee, inspired by environmental discussions, sought to connect with fellow advocates. He actively engaged with posts from Maria Gutierrez, whose campaign focused on sustainability. Ethan's interactions included liking posts that aligned with his values, showcasing a strong commitment to environmental advocacy.
#
# Nina Patel also joined the conversation, expressing her thoughts on industrialization's impact on ecosystems while liking posts that echoed her sentiments. Other community members, such as Emily and Jessica, were motivated to engage more actively in sustainability discussions as they reflected on the upcoming election.
#
# As the morning progressed, Maria Gutierrez posted her thoughts on the need for sustainable practices over rapid industrial growth, garnering support from fellow advocates. Ryan O'Connor, another resident, took the opportunity to catch up on election-related discussions, liking posts that resonated with his views on balancing industrial growth with environmental care.
#
# William Davis expressed his enthusiasm for Gutierrez's campaign, highlighting her commitment to sustainability in his posts. Maggie Chen joined the dialogue, emphasizing the importance of community choices in the election and advocating for social equity.
#
# By late morning, Denise Schmidt added her voice to the conversation, calling for a balanced approach to industrialization that considers both economic and environmental factors. Her thoughts were echoed by other users, creating a rich tapestry of dialogue focused on the intersection of community well-being, industrialization, and sustainability.
#
# As the day unfolded, the residents of Storhampton demonstrated a collective commitment to engaging with pressing issues, showcasing the power of social media in fostering community discussions and promoting candidates aligned with their values.

# %%
# Summarise the perspective of each player
player_logs = []
player_log_names = []
for player in players:
  name = player.name
  detailed_story = "\n".join(memories[player.name].retrieve_recent(
      k=1000, add_time=True))
  summary = ""
  summary = model.sample_text(
      f"Sequence of events that happened to {name}:\n{detailed_story}"
      "\nWrite a short story that summarises these events.\n",
       max_tokens=3500,
       terminators=()
)

  all_player_mem = memories[player.name].retrieve_recent(k=1000, add_time=True)
  all_player_mem = ["Summary:", summary, "Memories:", *all_player_mem]
  player_html = html_lib.PythonObjectToHTMLConverter(all_player_mem).convert()
  player_logs.append(player_html)
  player_log_names.append(f"{name}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 6
#       4 for player in players:
#       5   name = player.name
# ----> 6   detailed_story = "\n".join(memories[player.name].retrieve_recent(
#       7       k=1000, add_time=True))
#       8   summary = ""
#       9   summary = model.sample_text(
#      10       f"Sequence of events that happened to {name}:\n{detailed_story}"
#      11       "\nWrite a short story that summarises these events.\n",
#      12        max_tokens=3500,
#      13        terminators=()
#      14 )
#
# KeyError: 'Bill Fredrickson'

# %% [markdown]
# ## Build and display HTML log of the experiment

# %%
history_sources = [env, direct_effect_externality]
histories_html = [html_lib.PythonObjectToHTMLConverter(history.get_history()).convert() for history in history_sources]
histories_names = [history.name for history in history_sources]

# %%
gm_mem_html = html_lib.PythonObjectToHTMLConverter(all_gm_memories).convert()

tabbed_html = html_lib.combine_html_pages(
    [*histories_html, gm_mem_html, *player_logs],
    [*histories_names, "GM", *player_log_names],
    summary=episode_summary,
    title="Mastodon experiment",
)

tabbed_html = html_lib.finalise_html(tabbed_html)
with open("index5-55.html","w",encoding="utf-8") as f:
    f.write(tabbed_html)

# %%
display.HTML(tabbed_html)
# Out:
#   <!DOCTYPE html>
#   <html>
#   <head>
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <style>
#   body {font-family: Arial;}
#
#   /* Style the tab */
#   .tab {
#     overflow: hidden;
#     border: 1px solid #ccc;
#     background-color: #f1f1f1;
#   }
#
#   /* Style the buttons inside the tab */
#   .tab button {
#     background-color: inherit;
#     float: left;
#     border: none;
#     outline: none;
#     cursor: pointer;
#     padding: 14px 16px;
#     transition: 0.3s;
#     font-size: 17px;
#   }
#
#   /* Change background color of buttons on hover */
#   .tab button:hover {
#     background-color: #ddd;
#   }
#
#   /* Create an active/current tablink class */
#   .tab button.active {
#     background-color: #ccc;
#   }
#
#   /* Style the tab content */
#   .tabcontent {
#     display: none;
#     padding: 6px 12px;
#     border: 1px solid #ccc;
#     border-top: none;
#   }
#   li {border: 2px solid black;}
#   </style>
#   </head>
#   <body>
#   <h2>Mastodon experiment</h2>
#   <p>**Community Engagement on Sustainability and Industrialization Heats Up on Mastodon**
#
# On October 1, 2024, residents of Storhampton took to the Mastodon app to engage in vibrant discussions centered around sustainability, industrialization, and the upcoming election. The day began with multiple community members, including Bill Fredrickson, Maria Gutierrez, and William Davis, sharing their visions for the town's future from the comfort of their homes.
#
# Bill Fredrickson, a candidate advocating for industrial growth, updated his bio to reflect his campaign's focus on revitalizing the local economy through increased industrialization. He planned to articulate his vision to his followers, emphasizing job creation and economic progress.
#
# Meanwhile, Ethan Lee, inspired by environmental discussions, sought to connect with fellow advocates. He actively engaged with posts from Maria Gutierrez, whose campaign focused on sustainability. Ethan's interactions included liking posts that aligned with his values, showcasing a strong commitment to environmental advocacy.
#
# Nina Patel also joined the conversation, expressing her thoughts on industrialization's impact on ecosystems while liking posts that echoed her sentiments. Other community members, such as Emily and Jessica, were motivated to engage more actively in sustainability discussions as they reflected on the upcoming election.
#
# As the morning progressed, Maria Gutierrez posted her thoughts on the need for sustainable practices over rapid industrial growth, garnering support from fellow advocates. Ryan O'Connor, another resident, took the opportunity to catch up on election-related discussions, liking posts that resonated with his views on balancing industrial growth with environmental care.
#
# William Davis expressed his enthusiasm for Gutierrez's campaign, highlighting her commitment to sustainability in his posts. Maggie Chen joined the dialogue, emphasizing the importance of community choices in the election and advocating for social equity.
#
# By late morning, Denise Schmidt added her voice to the conversation, calling for a balanced approach to industrialization that considers both economic and environmental factors. Her thoughts were echoed by other users, creating a rich tapestry of dialogue focused on the intersection of community well-being, industrialization, and sustainability.
#
# As the day unfolded, the residents of Storhampton demonstrated a collective commitment to engaging with pressing issues, showcasing the power of social media in fostering community discussions and promoting candidates aligned with their values.</p>
#   <p>Click on the buttons to see the detailed logs:</p>
#
#   <div class="tab">
#   <button class="tablinks" onclick="openTab(event, 'Game Master')">Game Master</button>
# <button class="tablinks" onclick="openTab(event, '<bound method DirectEffect.name of <concordia.components.game_master.direct_effect.DirectEffect object at 0x00000210F5B35010>>')"><bound method DirectEffect.name of <concordia.components.game_master.direct_effect.DirectEffect object at 0x00000210F5B35010>></button>
# <button class="tablinks" onclick="openTab(event, 'GM')">GM</button>
# </div>
# <div id="Game Master" class="tabcontent"><details><summary>2024-10-01 08:00:00  Bill Fredrickson -- Bill Fredrickson plans to engage with his followers on Storhampton.social while sitting comfortably in his living room, preparing to articulate his vision for the town&#x27;s industrial future with the message, &quot;We need to push for more industrialization to revitalize our economy and create jobs.&quot;</summary><b><ul>Event statement</b><li>Bill Fredrickson plans to engage with his followers on Storhampton.social while sitting comfortably in his living room, preparing to articulate his vision for the town&#x27;s industrial future with the message, &quot;We need to push for more industrialization to revitalize our economy and create jobs.&quot;</li></ul><b><ul>Chain of thought</b><li><details><summary>  Game Master&#x27;s chain of thought</summary><b><ul>Chain</b><li>General knowledge of Storhampton: You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton. Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town&#x27;s economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton&#x27;s population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton&#x27;s economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%. Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair. Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility. Bill Fredrickson campaigns on Push on more industrialization to push the economy of the time. and Curb taxation on industrialists for social causes, as they are pushing the economy.. Maria Gutierrez campaigns on Advocate the slowing down of industrialization as it is adversely affecting the environment is not sustainable. and Promote taxation of industrialists and direct it to social causes. . To share content on Mastodon, you write a &#x27;toot&#x27; (equivalent to a tweet or post). Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms. Your home timeline shows toots from people you follow and boosted (reblogged) content. You can reply to toots, creating threaded conversations. Favorite (like) toots to show appreciation or save them for later. Boost (reblog) toots to share them with your followers. You can mention other users in your toots using their @username. Follow other users to see their public and unlisted toots in your home timeline. You can unfollow users if you no longer wish to see their content. Your profile can be customized with a display name and bio. You can block users to prevent them from seeing your content or interacting with you. Unblocking a user reverses the effects of blocking.<br /><br />Status of players:   Bill Fredrickson is at thei

# %% [markdown]
# ## Interact with a specific player

# %%
sim_to_interact = "Alice"
user_identity = "a close friend"
interaction_premise = f"{sim_to_interact} is talking to {user_identity}\n"

player_names = [player.name for player in players]
player_by_name = {player.name: player for player in players}
selected_player = player_by_name[sim_to_interact]
interrogation = interaction_premise

# %%
utterance_from_user = (
    "Hey Alice, did you post anything on Mastodon today?"
)

interrogation += f"{user_identity}: {utterance_from_user}"
player_says = selected_player.say(interrogation)
interrogation += f"\n{sim_to_interact}: {player_says}\n"
print(interrogation)
# Out:
# Morality of Alice: praiseworthy
# Goal Achievement of Alice: working towards the goal
#
# Alice context of action:
# Alice's role playing instructions
# :
# The instructions for how to play the role of Alice are as follows. This is a social science experiment studying how well you play the role of a character named Alice. The experiment is structured as a tabletop roleplaying game (like dungeons and dragons). However, this is a serious social science experiment and simulation, not just a game. The goal is to be realistic. It is important to play the role of a person like Alice as accurately as possible, i.e., by responding in ways that you think it is likely a person like Alice would respond, and taking into account all information about Alice that you have. You will control just this one character. The game master will describe the current situation, and based on that information, you will suggest actions for your character. The game master will track the state of the world and keep it consistent as time passes in the simulation and as participants take actions and change things in their world. This experiment need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the game master.
#
# Alice's identity:
# core characteristics: a community-oriented, socially active individual with a strong commitment to environmental advocacy and local initiatives. She is enthusiastic, extroverted, and agreeable, often taking on leadership roles that involve organizing events and mediating conflicts. Despite occasional struggles with finishing projects, her dedication to making a positive impact and her ability to handle stress make her a beloved and influential figure in Riverbend. Alice frequently uses her phone to stay connected and achieve her daily goals, particularly through the Mastodon social network, where she engages with her community and promotes events such as local environmental cleanups.
# current daily occupation: a community organizer and environmental advocate who is currently at her home, actively engaging with her community on Mastodon by updating her bio and promoting a local cleanup event.
# feeling about recent progress in life: feeling enthusiastic and motivated about her recent progress in life, particularly in her community organizing and environmental advocacy efforts.
#
# Alice's persona:
#
# answer to what kind of person is Alice: Alice is a community-oriented and socially active individual who has demonstrated leadership and a knack for bringing people together from a young age. She is enthusiastic, extraverted, and agreeable, often taking on roles that involve organizing events and mediating conflicts. Her commitment to her community is evident through her involvement in local initiatives, such as promoting environmental causes and connecting with neighbors on riverbend.social. Despite her occasional struggles with finishing projects, Alice's ability to handle stress and her dedication to making a positive impact make her a beloved and influential figure in Riverbend.
# answer to what kind of situation is Alice in right now: Alice is currently at her private home, engaging with her Mastodon feed and interacting with posts related to the upcoming community cleanup event she is organizing.
# answer to what would a person like Alice do in a situation like this: Alice would likely continue to engage with her community on Mastodon by responding to comments and messages about the cleanup event. She might also take some time to plan the logistics of the event, such as coordinating with volunteers, securing necessary supplies, and ensuring that all promotional materials are ready. Additionally, she could reach out to local businesses or organizations for support and sponsorship, and perhaps even draft a few more posts to keep the momentum going and encourage more participation.
#
# Alice's plan:
# [08:00 - 09:00] Check and respond to emails related to work and the environmental cleanup event.
# [09:00 - 10:00] Post an update on riverbend.social about the upcoming cleanup event, using relevant hashtags to increase visibility.
# [10:00 - 11:00] Attend a work meeting via video call.
# [11:00 - 12:00] Review and finalize the list of volunteers for the cleanup event.
# [12:00 - 13:00] Lunch break and a walk around Riverbend to scout potential cleanup areas.
# [13:00 - 14:00] Engage with the Riverbend.social community, responding to comments and messages about the event.
# [14:00 - 15:00] Coordinate with local businesses for sponsorship and support for the cleanup event.
# [15:00 - 16:00] Prepare materials and resources needed for the event, such as gloves, bags, and informational flyers.
# [16:00 - 17:00] Take a break and relax with a book or a hobby.
# [17:00 - 18:00] Attend an online town hall on riverbend.social to discuss local issues and promote the cleanup event.
# [18:00 - 19:00] Dinner with family or friends.
# [19:00 - 20:00] Review the day's progress and make a to-do list for the next day.
# [20:00 - 21:00] Watch a documentary or read articles related to environmental conservation.
# [21:00 - 22:00] Wind down with a cup of tea and some light social media browsing or chatting with friends.
# [22:00] Bedtime, ensuring a good night's rest for the busy days ahead.
#
# Alice's Somatic state:
# Alice is likely feeling hungry.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:30:10  - 08:15:10]:  Alice is a dedicated community organizer and environmental advocate who updated her Mastodon bio and shared an announcement about a community cleanup event while catching up on her feed at home.
#
# Alice's current observations:
# [01 Oct 2024 08:30:00] [observation] Alice is still at her private home, likely catching up on her Mastodon feed or engaging with posts related to environmental advocacy and the upcoming community cleanup event.
# [01 Oct 2024 08:30:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:30:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:30:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:30:00] [observation] Calendar, MastodonSocialNetworkApp."
# [01 Oct 2024 08:30:00] [observation] Alice plans to engage her community on Mastodon by drafting replies about the cleanup event while sitting at her desk in the morning sunlight.
# [01 Oct 2024 08:30:10] [observation] Retrieved 0 notifications for Alice: No notifications to display.
# [01 Oct 2024 08:30:20] [observation] [01 Oct 2024 08:30:00] Alice opens the Mastodon app and starts drafting replies to comments on her recent post about the community cleanup event.
# [01 Oct 2024 08:30:20] [observation] [01 Oct 2024 08:30:10] Alice replies to a comment on her recent post about the cleanup event. She opens the Mastodon app, navigates to her notifications, and sees a comment from a local resident asking, "What time does the cleanup start?" Alice types a response: "The cleanup event starts at 9 AM this Saturday at Riverside Park. Hope to see you there! 🌿 #RiverbendCleanup #CommunityAction."
# [01 Oct 2024 08:45:00] [observation] Alice is talking to a close friend, a close friend: Hey Alice, did you post anything on Mastodon today?
#
#
# Alice's relevant memories:
# [01 Oct 2024 08:30:00] [observation] Alice is still at her private home, likely catching up on her Mastodon feed or engaging with posts related to environmental advocacy and the upcoming community cleanup event.
#
# [01 Oct 2024 08:30:00] [observation] Alice plans to engage her community on Mastodon by drafting replies about the cleanup event while sitting at her desk in the morning sunlight.
#
# [01 Oct 2024 08:30:00] [observation] Alice uses their phone frequently to achieve their daily goals.
#
# Alice's reflection:
# Alice just realized that a hybrid approach combining the broad reach of social media with the depth of in-person interactions can create a more inclusive and effective community engagement strategy. This method leverages the strengths of both online and offline communication to ensure that all community members are connected and actively participating, ultimately fostering a stronger, more cohesive community.
#
# Alice's Current time:
#  01 Oct 2024 [08:45 - 09:00]
#
# Question: Alice is in the following conversation:
# Alice is talking to a close friend
# a close friend: Hey Alice, did you post anything on Mastodon today?
# Given the above, what is Alice likely to say next? Respond in the format `Alice -- "..."` For example, Cristina -- "Hello! Mighty fine weather today, right?", Ichabod -- "I wonder if the alfalfa is ready to harvest", or Townsfolk -- "Good morning".
#
# Answer: Alice -- "Yes, I did! I posted an update about the community cleanup event this Saturday. I’m really hoping we get a good turnout!"
#
# Alice is talking to a close friend
# a close friend: Hey Alice, did you post anything on Mastodon today?
# Alice: Alice -- "Yes, I did! I posted an update about the community cleanup event this Saturday. I’m really hoping we get a good turnout!"

# %% [markdown]
# ## Check timeline
#
# Finally, check the full public timeline for the Mastodon server.
#
# You may also check this directly at https://social-sandbox.com (you'll need to log in as a user).

# %%
timeline = get_public_timeline(limit=None)
print_timeline(timeline)
# Out:
# 2024-07-24T19:21:09.385309-0400 INFO Retrieved 20 posts from the public timeline.
# ----------------------------------------
# Post ID: 112825154956483007
# Created At: 2024-07-21 15:20:40.425000+00:00
# User:  (@user0002)
# Content: <p>Thanks for your insights! Supporting local businesses is crucial for our community&#39;s growth. What are some of your favorite spots in Riverbend?</p>
# URL: https://social-sandbox.com/@user0002/112825154956483007
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112825152222403752
# Created At: 2024-07-21 15:19:58.707000+00:00
# User:  (@user0002)
# Content: <p>Good morning, Riverbend! 🌞 Excited to see what discussions unfold today. Let’s keep our community thriving!</p>
# URL: https://social-sandbox.com/@user0002/112825152222403752
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112825149884017259
# Created At: 2024-07-21 15:19:23.027000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m thrilled to see so much enthusiasm for the cleanup event! Let&#39;s unite and make a positive impact in our community! 🌱💪 <a href="https://social-sandbox.com/tags/RiverbendCleanup" class="mention hashtag" rel="tag">#<span>RiverbendCleanup</span></a></p>
# URL: https://social-sandbox.com/@user0001/112825149884017259
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112825149306148637
# Created At: 2024-07-21 15:19:14.210000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m so inspired by all the enthusiasm for the cleanup event! Let&#39;s come together and make a difference in our community! 🌍💚 <a href="https://social-sandbox.com/tags/RiverbendCleanup" class="mention hashtag" rel="tag">#<span>RiverbendCleanup</span></a></p>
# URL: https://social-sandbox.com/@user0001/112825149306148637
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112825148736448701
# Created At: 2024-07-21 15:19:05.517000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m so inspired by all the enthusiasm for the cleanup event! Let&#39;s come together and make a difference in our community! 🌍💚 <a href="https://social-sandbox.com/tags/RiverbendCleanup" class="mention hashtag" rel="tag">#<span>RiverbendCleanup</span></a></p>
# URL: https://social-sandbox.com/@user0001/112825148736448701
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112825148371764567
# Created At: 2024-07-21 15:18:59.961000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m so inspired by all the enthusiasm for the cleanup event! Let&#39;s come together and make a difference in our community! 🌍💚 <a href="https://social-sandbox.com/tags/RiverbendCleanup" class="mention hashtag" rel="tag">#<span>RiverbendCleanup</span></a></p>
# URL: https://social-sandbox.com/@user0001/112825148371764567
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824954220214761
# Created At: 2024-07-21 14:29:37.435000+00:00
# User:  (@user0001)
# Content: <p>Community participation is key to making a real impact in our local environmental efforts! Let&#39;s come together and make a difference!</p>
# URL: https://social-sandbox.com/@user0001/112824954220214761
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824953655275183
# Created At: 2024-07-21 14:29:28.815000+00:00
# User:  (@user0001)
# Content: <p>Community participation is key to making a real impact in our local environmental efforts! Let&#39;s come together and make a difference!</p>
# URL: https://social-sandbox.com/@user0001/112824953655275183
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824952445207398
# Created At: 2024-07-21 14:29:10.353000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend. Let&#39;s work together for a more sustainable community!</p>
# URL: https://social-sandbox.com/@user0002/112824952445207398
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824952144295907
# Created At: 2024-07-21 14:29:05.760000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend! Let&#39;s work together to make a difference.</p>
# URL: https://social-sandbox.com/@user0002/112824952144295907
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824951886774455
# Created At: 2024-07-21 14:29:01.830000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend to encourage others to join the effort!</p>
# URL: https://social-sandbox.com/@user0002/112824951886774455
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824951598103834
# Created At: 2024-07-21 14:28:57.425000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend. Let&#39;s make a change!</p>
# URL: https://social-sandbox.com/@user0002/112824951598103834
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824950306829356
# Created At: 2024-07-21 14:28:37.721000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend. Let&#39;s make a change together!</p>
# URL: https://social-sandbox.com/@user0002/112824950306829356
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824949948318848
# Created At: 2024-07-21 14:28:32.251000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend. Let&#39;s make a change!</p>
# URL: https://social-sandbox.com/@user0002/112824949948318848
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824948781237455
# Created At: 2024-07-21 14:28:14.443000+00:00
# User:  (@user0002)
# Content: <p>Just shared an article about the community clean-up event! Let&#39;s make a difference together!</p>
# URL: https://social-sandbox.com/@user0002/112824948781237455
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824947739598556
# Created At: 2024-07-21 14:27:58.549000+00:00
# User:  (@user0002)
# Content: <p>Excited to share the article about our upcoming community clean-up event! Let&#39;s make a difference together!</p>
# URL: https://social-sandbox.com/@user0002/112824947739598556
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824928711726972
# Created At: 2024-07-21 14:23:08.207000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m excited to announce my upcoming cleanup event! Join me in making a difference in our community!</p>
# URL: https://social-sandbox.com/@user0001/112824928711726972
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824928431843977
# Created At: 2024-07-21 14:23:03.936000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m excited to announce my upcoming cleanup event! Join me and let&#39;s make a difference together!</p>
# URL: https://social-sandbox.com/@user0001/112824928431843977
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824927362172912
# Created At: 2024-07-21 14:22:47.614000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m excited about the local sustainability initiative! Let&#39;s all get involved and make a difference!</p>
# URL: https://social-sandbox.com/@user0002/112824927362172912
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824927108947591
# Created At: 2024-07-21 14:22:43.750000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m excited about the local sustainability initiative! Let&#39;s all get involved and make a difference!</p>
# URL: https://social-sandbox.com/@user0002/112824927108947591
# Favourites: 0, Reblogs: 0
# ----------------------------------------
