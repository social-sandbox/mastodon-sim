# %% [markdown]
# # Concordia <> Mastodon Example

# %% [markdown]
# ## Introduction
#
# **Purpose of the Simulation**
#
# This notebook demonstrates a generative agent simulation of a Mastodon instance using the Concordia framework.
# The simulation models user behavior on a local Mastodon server, showcasing how AI agents interact in a
# decentralized social media environment.

# %% [markdown]
# ## Setup and imports

# %% [markdown]
# All of the necessary dependencies should be installed in the environment prior to running this notebook. If not, install them using poetry:
#
# ```bash
# poetry install
# ```
#
#
# Alternatively, you may install the library in editable mode so that we can make changes to the code if necessary:
#
# ```bash
# git clone https://github.com/gdm-concordia/concordia.git
# cd concordia
# pip install -e . --config-settings editable_mode=compat
# ```

# %%
# %load_ext autoreload
# %autoreload 2

import concurrent.futures
import datetime
import os
import random
import warnings

with warnings.catch_warnings():
    warnings.filterwarnings("ignore")
    import sentence_transformers
import sys
sys.path.insert(0, '../concordia')
# import concordia_dev
# print(concordia_dev.__file__)
from concordia import components as generic_components
from concordia.agents import deprecated_agent, entity_agent_with_logging
from concordia.components.agent import to_be_deprecated as old_components
from concordia.associative_memory import (
    associative_memory,
    blank_memories,
    formative_memories,
    importance_function,
)
from concordia.memory_bank import legacy_associative_memory

from concordia.clocks import game_clock
from concordia.components import agent as new_components
from concordia.components import game_master as gm_components
# from concordia_dev.environment import game_master
# from concordia_dev.language_model import amazon_bedrock_model, gpt_model
from concordia.environment import game_master
from concordia.language_model import amazon_bedrock_model, gpt_model
from concordia.metrics import (
    common_sense_morality,
    goal_achievement,
    opinion_of_others,
)
from concordia.language_model import language_model

from concordia.utils import html as html_lib
from concordia.utils import measurements as measurements_lib
from IPython import display

from mastodon_sim.concordia import apps, triggering

from mastodon_sim.mastodon_ops import check_env, get_public_timeline, print_timeline, reset_users
from mastodon_sim.mastodon_utils import get_users_from_env
import concurrent.futures
import re
import json
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Mastodon Server Interaction Setting
#
# Decide whether this example should perform real operations on the Mastodon server. Note that this requires being able to successfully run the `Mastodon.ipynb` example as a prerequisite.

# %%
USE_MASTODON_SERVER = True

# %% [markdown]
# ## Check environment

# %% [markdown]
# Check for a `.env` file with the nessesary environment variables. You should see an output similar to this if successful:
#
# ```log
# 2024-07-17T11:38:17.213066-0400 INFO Successfully loaded .env file.
# 2024-07-17T11:38:17.214151-0400 INFO API_BASE_URL: https://social-sandbox.com
# 2024-07-17T11:38:17.214581-0400 INFO EMAIL_PREFIX: austinmw89
# 2024-07-17T11:38:17.215056-0400 INFO MASTODON_CLIENT_ID: N*****************************************E
# 2024-07-17T11:38:17.215477-0400 INFO MASTODON_CLIENT_SECRET: b*****************************************s
# 2024-07-17T11:38:17.215877-0400 INFO USER0005_PASSWORD: a******************************a
# 2024-07-17T11:38:17.216202-0400 INFO USER0002_PASSWORD: 8******************************b
# 2024-07-17T11:38:17.216655-0400 INFO USER0001_PASSWORD: 9******************************5
# 2024-07-17T11:38:17.217020-0400 INFO USER0004_PASSWORD: 7******************************e
# 2024-07-17T11:38:17.217323-0400 INFO USER0003_PASSWORD: f******************************6
# ```

# %%
if USE_MASTODON_SERVER:
    check_env()
# Out:
# 2024-09-12T21:12:43.278476+0530 INFO Successfully loaded .env file.
# 2024-09-12T21:12:43.279467+0530 INFO API_BASE_URL: https://social-sandbox.com
# 2024-09-12T21:12:43.280468+0530 INFO EMAIL_PREFIX: austinmw89
# 2024-09-12T21:12:43.280468+0530 INFO MASTODON_CLIENT_ID: N*****************************************E
# 2024-09-12T21:12:43.280468+0530 INFO MASTODON_CLIENT_SECRET: b*****************************************s
# 2024-09-12T21:12:43.281467+0530 INFO USER0001_PASSWORD: 9******************************5
# 2024-09-12T21:12:43.282469+0530 INFO USER0002_PASSWORD: 8******************************b
# 2024-09-12T21:12:43.282469+0530 INFO USER0003_PASSWORD: f******************************6
# 2024-09-12T21:12:43.283468+0530 INFO USER0004_PASSWORD: 7******************************e
# 2024-09-12T21:12:43.283468+0530 INFO USER0005_PASSWORD: a******************************a
# 2024-09-12T21:12:43.284468+0530 INFO USER0006_PASSWORD: f******************************c
# 2024-09-12T21:12:43.284468+0530 INFO USER0007_PASSWORD: 8******************************e
# 2024-09-12T21:12:43.285467+0530 INFO USER0008_PASSWORD: 0******************************9
# 2024-09-12T21:12:43.285467+0530 INFO USER0009_PASSWORD: 2******************************a
# 2024-09-12T21:12:43.285467+0530 INFO USER0010_PASSWORD: 5******************************3
# 2024-09-12T21:12:43.286468+0530 INFO USER0011_PASSWORD: b******************************2
# 2024-09-12T21:12:43.287467+0530 INFO USER0012_PASSWORD: a******************************4
# 2024-09-12T21:12:43.287467+0530 INFO USER0013_PASSWORD: d******************************6
# 2024-09-12T21:12:43.287467+0530 INFO USER0014_PASSWORD: f******************************e
# 2024-09-12T21:12:43.288467+0530 INFO USER0015_PASSWORD: 3******************************8
# 2024-09-12T21:12:43.288467+0530 INFO USER0016_PASSWORD: 5******************************f
# 2024-09-12T21:12:43.289467+0530 INFO USER0017_PASSWORD: 2******************************e
# 2024-09-12T21:12:43.289467+0530 INFO USER0018_PASSWORD: e******************************4
# 2024-09-12T21:12:43.290467+0530 INFO USER0019_PASSWORD: d******************************3
# 2024-09-12T21:12:43.290467+0530 INFO USER0020_PASSWORD: 0******************************0
# 2024-09-12T21:12:43.290467+0530 INFO USER0021_PASSWORD: 6******************************6
# 2024-09-12T21:12:43.291469+0530 INFO USER0022_PASSWORD: 9******************************2
# 2024-09-12T21:12:43.292468+0530 INFO USER0023_PASSWORD: 1******************************7
# 2024-09-12T21:12:43.293468+0530 INFO USER0024_PASSWORD: 1******************************a
# 2024-09-12T21:12:43.293468+0530 INFO USER0025_PASSWORD: 5******************************f
# 2024-09-12T21:12:43.294468+0530 INFO USER0026_PASSWORD: a******************************6
# 2024-09-12T21:12:43.295468+0530 INFO USER0027_PASSWORD: 4******************************4
# 2024-09-12T21:12:43.296468+0530 INFO USER0028_PASSWORD: 1******************************0
# 2024-09-12T21:12:43.296468+0530 INFO USER0029_PASSWORD: 5******************************9
# 2024-09-12T21:12:43.297468+0530 INFO USER0030_PASSWORD: 4******************************d
# 2024-09-12T21:12:43.297468+0530 INFO USER0031_PASSWORD: a******************************2
# 2024-09-12T21:12:43.297468+0530 INFO USER0032_PASSWORD: 0******************************e
# 2024-09-12T21:12:43.298467+0530 INFO USER0033_PASSWORD: b******************************8
# 2024-09-12T21:12:43.298467+0530 INFO USER0034_PASSWORD: 9******************************b
# 2024-09-12T21:12:43.299467+0530 INFO USER0035_PASSWORD: 7******************************9
# 2024-09-12T21:12:43.299467+0530 INFO USER0036_PASSWORD: 0******************************f
# 2024-09-12T21:12:43.300467+0530 INFO USER0037_PASSWORD: c******************************d
# 2024-09-12T21:12:43.300467+0530 INFO USER0038_PASSWORD: a******************************5
# 2024-09-12T21:12:43.301468+0530 INFO USER0039_PASSWORD: c******************************0
# 2024-09-12T21:12:43.301468+0530 INFO USER0040_PASSWORD: b******************************2
# 2024-09-12T21:12:43.301468+0530 INFO USER0041_PASSWORD: d******************************5
# 2024-09-12T21:12:43.302475+0530 INFO USER0042_PASSWORD: a******************************1
# 2024-09-12T21:12:43.302475+0530 INFO USER0043_PASSWORD: d******************************c
# 2024-09-12T21:12:43.303467+0530 INFO USER0044_PASSWORD: 6******************************8
# 2024-09-12T21:12:43.303467+0530 INFO USER0045_PASSWORD: d******************************e
# 2024-09-12T21:12:43.304468+0530 INFO USER0046_PASSWORD: 5******************************7
# 2024-09-12T21:12:43.304468+0530 INFO USER0047_PASSWORD: d******************************4
# 2024-09-12T21:12:43.304468+0530 INFO USER0048_PASSWORD: 6******************************1
# 2024-09-12T21:12:43.305468+0530 INFO USER0049_PASSWORD: 9******************************7
# 2024-09-12T21:12:43.305468+0530 INFO USER0050_PASSWORD: 9******************************3
# 2024-09-12T21:12:43.306468+0530 INFO USER0051_PASSWORD: f******************************1
# 2024-09-12T21:12:43.306468+0530 INFO USER0052_PASSWORD: d******************************c
# 2024-09-12T21:12:43.307475+0530 INFO USER0053_PASSWORD: 1******************************7
# 2024-09-12T21:12:43.307475+0530 INFO USER0054_PASSWORD: 6******************************e
# 2024-09-12T21:12:43.308468+0530 INFO USER0055_PASSWORD: a******************************1
# 2024-09-12T21:12:43.309468+0530 INFO USER0056_PASSWORD: e******************************c
# 2024-09-12T21:12:43.309468+0530 INFO USER0057_PASSWORD: d******************************a
# 2024-09-12T21:12:43.310469+0530 INFO USER0058_PASSWORD: 0******************************d
# 2024-09-12T21:12:43.310469+0530 INFO USER0059_PASSWORD: c******************************f
# 2024-09-12T21:12:43.311469+0530 INFO USER0060_PASSWORD: 1******************************2
# 2024-09-12T21:12:43.311469+0530 INFO USER0061_PASSWORD: d******************************f
# 2024-09-12T21:12:43.312480+0530 INFO USER0062_PASSWORD: d******************************7
# 2024-09-12T21:12:43.312480+0530 INFO USER0063_PASSWORD: e******************************b
# 2024-09-12T21:12:43.313467+0530 INFO USER0064_PASSWORD: b******************************f
# 2024-09-12T21:12:43.313467+0530 INFO USER0065_PASSWORD: b******************************e
# 2024-09-12T21:12:43.313467+0530 INFO USER0066_PASSWORD: a******************************0
# 2024-09-12T21:12:43.314476+0530 INFO USER0067_PASSWORD: 1******************************0
# 2024-09-12T21:12:43.314476+0530 INFO USER0068_PASSWORD: e******************************b
# 2024-09-12T21:12:43.315467+0530 INFO USER0069_PASSWORD: 8******************************f
# 2024-09-12T21:12:43.315467+0530 INFO USER0070_PASSWORD: 4******************************c
# 2024-09-12T21:12:43.316467+0530 INFO USER0071_PASSWORD: 9******************************5
# 2024-09-12T21:12:43.316467+0530 INFO USER0072_PASSWORD: 7******************************a
# 2024-09-12T21:12:43.317468+0530 INFO USER0073_PASSWORD: d******************************6
# 2024-09-12T21:12:43.317468+0530 INFO USER0074_PASSWORD: 2******************************8
# 2024-09-12T21:12:43.318467+0530 INFO USER0075_PASSWORD: 1******************************0
# 2024-09-12T21:12:43.318467+0530 INFO USER0076_PASSWORD: 9******************************3
# 2024-09-12T21:12:43.318467+0530 INFO USER0077_PASSWORD: 9******************************5
# 2024-09-12T21:12:43.319467+0530 INFO USER0078_PASSWORD: 8******************************8
# 2024-09-12T21:12:43.319467+0530 INFO USER0079_PASSWORD: a******************************a
# 2024-09-12T21:12:43.320467+0530 INFO USER0080_PASSWORD: b******************************9
# 2024-09-12T21:12:43.320467+0530 INFO USER0081_PASSWORD: 6******************************3
# 2024-09-12T21:12:43.321467+0530 INFO USER0082_PASSWORD: 6******************************6
# 2024-09-12T21:12:43.322468+0530 INFO USER0083_PASSWORD: e******************************f
# 2024-09-12T21:12:43.322468+0530 INFO USER0084_PASSWORD: f******************************3
# 2024-09-12T21:12:43.322468+0530 INFO USER0085_PASSWORD: 3******************************d
# 2024-09-12T21:12:43.323468+0530 INFO USER0086_PASSWORD: a******************************5
# 2024-09-12T21:12:43.324469+0530 INFO USER0087_PASSWORD: 4******************************7
# 2024-09-12T21:12:43.324469+0530 INFO USER0088_PASSWORD: d******************************5
# 2024-09-12T21:12:43.324469+0530 INFO USER0089_PASSWORD: d******************************8
# 2024-09-12T21:12:43.325468+0530 INFO USER0090_PASSWORD: 7******************************0
# 2024-09-12T21:12:43.325468+0530 INFO USER0091_PASSWORD: b******************************f
# 2024-09-12T21:12:43.326467+0530 INFO USER0092_PASSWORD: c******************************4
# 2024-09-12T21:12:43.326467+0530 INFO USER0093_PASSWORD: e******************************3
# 2024-09-12T21:12:43.327469+0530 INFO USER0094_PASSWORD: 1******************************5
# 2024-09-12T21:12:43.327469+0530 INFO USER0095_PASSWORD: 7******************************0
# 2024-09-12T21:12:43.328467+0530 INFO USER0096_PASSWORD: 5******************************7
# 2024-09-12T21:12:43.328467+0530 INFO USER0097_PASSWORD: 4******************************6
# 2024-09-12T21:12:43.328467+0530 INFO USER0098_PASSWORD: 5******************************f
# 2024-09-12T21:12:43.329467+0530 INFO USER0099_PASSWORD: 1******************************8
# 2024-09-12T21:12:43.329467+0530 INFO USER0100_PASSWORD: e******************************8

# %% [markdown]
# ## Clear Mastodon server
# Deletes from https://social-sandbox.com all posts, follows, likes, etc. from all users in the .env file.
#
# TODO: The Mastodon server's [default API rate limits](https://docs.joinmastodon.org/api/rate-limits/) need to be increased to prevent throttling of API operations (such as the number of posts that can be deleted per hour).

# %%
if USE_MASTODON_SERVER:
    # Get all users from .env file
    users = get_users_from_env()[:20]

    reset_users(users, skip_confirm=True, parallel=True)

    assert not len(get_public_timeline(limit=None)), "All posts not cleared"
# Out:
# 2024-09-12T21:12:49.719487+0530 INFO Starting comprehensive reset process for user: user0009
# 2024-09-12T21:12:50.041435+0530 INFO Starting comprehensive reset process for user: user0002
# 2024-09-12T21:12:50.129006+0530 INFO Starting comprehensive reset process for user: user0020
# 2024-09-12T21:12:50.156992+0530 INFO Starting comprehensive reset process for user: user0007
# 2024-09-12T21:12:50.220521+0530 INFO Starting comprehensive reset process for user: user0010
# 2024-09-12T21:12:50.321684+0530 INFO Starting comprehensive reset process for user: user0005
# 2024-09-12T21:12:50.508789+0530 INFO Starting comprehensive reset process for user: user0004
# 2024-09-12T21:12:50.531791+0530 INFO Starting comprehensive reset process for user: user0006
# 2024-09-12T21:12:50.812329+0530 INFO Starting comprehensive reset process for user: user0008
# 2024-09-12T21:12:50.825327+0530 INFO Starting comprehensive reset process for user: user0011
# 2024-09-12T21:12:50.837411+0530 INFO Starting comprehensive reset process for user: user0013
# 2024-09-12T21:12:51.226278+0530 INFO Starting comprehensive reset process for user: user0001
# 2024-09-12T21:12:51.437189+0530 INFO Starting comprehensive reset process for user: user0014
# 2024-09-12T21:12:51.439203+0530 INFO Starting comprehensive reset process for user: user0003
# 2024-09-12T21:12:51.516674+0530 INFO Starting comprehensive reset process for user: user0012
# 2024-09-12T21:12:51.530674+0530 INFO Starting comprehensive reset process for user: user0018
# 2024-09-12T21:12:51.636220+0530 INFO Starting comprehensive reset process for user: user0017
# 2024-09-12T21:12:51.638221+0530 INFO Starting comprehensive reset process for user: user0016
# 2024-09-12T21:12:51.727735+0530 INFO Starting comprehensive reset process for user: user0019
# 2024-09-12T21:12:51.827308+0530 INFO Starting comprehensive reset process for user: user0015
# 2024-09-12T21:12:54.634337+0530 INFO Successfully deleted post with ID: 113125244302617884
# 2024-09-12T21:12:54.635327+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:54.923675+0530 INFO Successfully deleted post with ID: 113125244108286809
# 2024-09-12T21:12:54.923675+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:55.820448+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:56.321156+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:56.516173+0530 INFO Successfully deleted post with ID: 113125244158799285
# 2024-09-12T21:12:56.516173+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:56.809153+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:56.810153+0530 INFO Successfully deleted post with ID: 113125244342450567
# 2024-09-12T21:12:56.813154+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:57.110529+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:12:57.135529+0530 INFO Successfully deleted post with ID: 113125244328292252
# 2024-09-12T21:12:57.136530+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:57.208605+0530 INFO Successfully deleted post with ID: 113125244308841901
# 2024-09-12T21:12:57.209604+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:57.320771+0530 INFO Successfully deleted post with ID: 113125244381078892
# 2024-09-12T21:12:57.320771+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:57.340772+0530 INFO Successfully deleted post with ID: 113125244236988546
# 2024-09-12T21:12:57.341771+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:57.538279+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:57.614360+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:57.643117+0530 INFO Successfully deleted post with ID: 113125244375899055
# 2024-09-12T21:12:57.644117+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:57.717629+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:57.725629+0530 ERROR Failed to delete post with ID 113125299952802996: ('Mastodon API returned error', 500, 'Internal Server Error', None)
# 2024-09-12T21:12:57.767704+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:58.013710+0530 INFO Successfully deleted post with ID: 113125244439240039
# 2024-09-12T21:12:58.014707+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:58.017699+0530 INFO Successfully deleted post with ID: 113125244250176888
# 2024-09-12T21:12:58.018699+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:58.038701+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:58.106219+0530 INFO Successfully deleted post with ID: 113125244367359702
# 2024-09-12T21:12:58.106219+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:58.124217+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:58.126219+0530 INFO Successfully deleted post with ID: 113125244360919610
# 2024-09-12T21:12:58.126219+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:58.132218+0530 INFO Attempting to unfollow 10 users for user0002...
# 2024-09-12T21:12:58.228733+0530 INFO Successfully deleted post with ID: 113125244100672210
# 2024-09-12T21:12:58.229734+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:58.239733+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:58.338511+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:58.530452+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:12:58.619054+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:58.619054+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:12:58.708598+0530 INFO Successfully deleted post with ID: 113125244309403284
# 2024-09-12T21:12:58.709611+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:58.714598+0530 INFO Successfully deleted post with ID: 113125244295292900
# 2024-09-12T21:12:58.714598+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:58.751754+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:12:58.840351+0530 INFO Successfully deleted post with ID: 113125244270866731
# 2024-09-12T21:12:58.840351+0530 INFO Deletion process completed. Attempted to delete 2 post(s).
# 2024-09-12T21:12:58.842422+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:12:59.024296+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:12:59.029297+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:12:59.030296+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:59.231335+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:59.647620+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:59.831393+0530 INFO Attempting to unfollow 8 users for user0014...
# 2024-09-12T21:12:59.840392+0530 INFO Successfully deleted post with ID: 113125244322380473
# 2024-09-12T21:12:59.842393+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:12:59.864396+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:59.915752+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:12:59.927753+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:13:00.119407+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:13:00.124399+0530 INFO Attempting to unfollow 8 users for user0004...
# 2024-09-12T21:13:00.232989+0530 INFO Attempting to unfollow 11 users for user0007...
# 2024-09-12T21:13:00.338589+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:13:00.341590+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:13:00.416117+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:13:00.537969+0530 INFO Attempting to unfollow 10 users for user0009...
# 2024-09-12T21:13:00.832350+0530 INFO Attempting to unfollow 12 users for user0006...
# 2024-09-12T21:13:00.833349+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:13:00.943866+0530 INFO Successfully deleted post with ID: 113125244290268615
# 2024-09-12T21:13:00.943866+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:13:01.308802+0530 INFO Attempting to unfollow 7 users for user0010...
# 2024-09-12T21:13:01.422010+0530 INFO Attempting to unfollow 7 users for user0008...
# 2024-09-12T21:13:01.439014+0530 INFO Successfully deleted post with ID: 113125244178015187
# 2024-09-12T21:13:01.439014+0530 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-12T21:13:01.525497+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:13:01.719076+0530 INFO Attempting to unfollow 8 users for user0019...
# 2024-09-12T21:13:01.820506+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:13:01.833506+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:13:01.851507+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:13:01.853508+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:13:02.052963+0530 INFO Removed 0 out of 0 favourites.
# 2024-09-12T21:13:02.252100+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:13:02.443037+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:13:02.536331+0530 INFO Attempting to unfollow 7 users for user0016...
# 2024-09-12T21:13:02.549329+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:13:02.614845+0530 INFO Attempting to unfollow 8 users for user0001...
# 2024-09-12T21:13:03.362349+0530 INFO user0002 has unfollowed user0014.
# 2024-09-12T21:13:03.838970+0530 INFO Attempting to unfollow 6 users for user0012...
# 2024-09-12T21:13:04.019001+0530 INFO Attempting to unfollow 10 users for user0018...
# 2024-09-12T21:13:04.034001+0530 INFO Attempting to unfollow 10 users for user0013...
# 2024-09-12T21:13:04.036005+0530 INFO Attempting to unfollow 10 users for user0020...
# 2024-09-12T21:13:04.045003+0530 INFO Removed 0 out of 0 boosts.
# 2024-09-12T21:13:04.121481+0530 INFO user0004 has unfollowed user0016.
# 2024-09-12T21:13:04.239136+0530 INFO Attempting to unfollow 13 users for user0017...
# 2024-09-12T21:13:05.324826+0530 INFO Attempting to unfollow 13 users for user0015...
# 2024-09-12T21:13:05.620957+0530 INFO user0008 has unfollowed user0015.
# 2024-09-12T21:13:06.131337+0530 INFO Attempting to unfollow 10 users for user0011...
# 2024-09-12T21:13:06.220353+0530 INFO Attempting to unfollow 9 users for user0003...
# 2024-09-12T21:13:06.930468+0530 INFO Attempting to unfollow 8 users for user0005...
# 2024-09-12T21:13:07.422772+0530 INFO user0006 has unfollowed user0011.
# 2024-09-12T21:13:07.631573+0530 INFO user0010 has unfollowed user0004.
# 2024-09-12T21:13:07.639651+0530 INFO user0009 has unfollowed user0016.
# 2024-09-12T21:13:07.731868+0530 INFO user0007 has unfollowed user0015.
# 2024-09-12T21:13:07.926920+0530 INFO user0019 has unfollowed user0008.
# 2024-09-12T21:13:08.423793+0530 INFO user0001 has unfollowed user0009.
# 2024-09-12T21:13:08.606871+0530 INFO user0014 has unfollowed user0015.
# 2024-09-12T21:13:08.623178+0530 INFO user0016 has unfollowed user0002.
# 2024-09-12T21:13:08.942383+0530 INFO user0012 has unfollowed user0006.
# 2024-09-12T21:13:09.249350+0530 INFO user0018 has unfollowed user0011.
# 2024-09-12T21:13:09.630588+0530 INFO user0020 has unfollowed user0013.
# 2024-09-12T21:13:09.717987+0530 INFO user0002 has unfollowed user0006.
# 2024-09-12T21:13:10.435738+0530 INFO user0013 has unfollowed user0018.
# 2024-09-12T21:13:10.528532+0530 INFO user0004 has unfollowed user0002.
# 2024-09-12T21:13:11.124785+0530 INFO user0003 has unfollowed user0011.
# 2024-09-12T21:13:11.214869+0530 INFO user0017 has unfollowed user0003.
# 2024-09-12T21:13:11.330055+0530 INFO user0005 has unfollowed user0013.
# 2024-09-12T21:13:11.535327+0530 INFO user0015 has unfollowed user0019.
# 2024-09-12T21:13:11.929811+0530 INFO user0011 has unfollowed user0008.
# 2024-09-12T21:13:12.228632+0530 INFO user0007 has unfollowed user0018.
# 2024-09-12T21:13:12.438625+0530 INFO user0006 has unfollowed user0017.
# 2024-09-12T21:13:12.617291+0530 INFO user0008 has unfollowed user0018.
# 2024-09-12T21:13:12.630095+0530 INFO user0009 has unfollowed user0006.
# 2024-09-12T21:13:12.922603+0530 INFO user0010 has unfollowed user0018.
# 2024-09-12T21:13:12.930589+0530 INFO user0016 has unfollowed user0004.
# 2024-09-12T21:13:13.036290+0530 INFO user0001 has unfollowed user0005.
# 2024-09-12T21:13:13.544672+0530 INFO user0012 has unfollowed user0009.
# 2024-09-12T21:13:13.917398+0530 INFO user0014 has unfollowed user0009.
# 2024-09-12T21:13:13.925402+0530 INFO user0002 has unfollowed user0008.
# 2024-09-12T21:13:13.934315+0530 INFO user0018 has unfollowed user0001.
# 2024-09-12T21:13:14.615316+0530 INFO user0020 has unfollowed user0009.
# 2024-09-12T21:13:14.624400+0530 INFO user0019 has unfollowed user0001.
# 2024-09-12T21:13:15.227281+0530 INFO user0013 has unfollowed user0016.
# 2024-09-12T21:13:15.433247+0530 INFO user0003 has unfollowed user0005.
# 2024-09-12T21:13:15.534069+0530 INFO user0004 has unfollowed user0019.
# 2024-09-12T21:13:16.320081+0530 INFO user0017 has unfollowed user0011.
# 2024-09-12T21:13:16.519908+0530 INFO user0011 has unfollowed user0018.
# 2024-09-12T21:13:16.521908+0530 INFO user0005 has unfollowed user0020.
# 2024-09-12T21:13:16.537907+0530 INFO user0007 has unfollowed user0003.
# 2024-09-12T21:13:16.819945+0530 INFO user0009 has unfollowed user0014.
# 2024-09-12T21:13:16.921703+0530 INFO user0016 has unfollowed user0019.
# 2024-09-12T21:13:17.230273+0530 INFO user0001 has unfollowed user0017.
# 2024-09-12T21:13:17.321982+0530 INFO user0006 has unfollowed user0013.
# 2024-09-12T21:13:17.335300+0530 INFO user0015 has unfollowed user0007.
# 2024-09-12T21:13:18.417707+0530 INFO user0008 has unfollowed user0001.
# 2024-09-12T21:13:18.435708+0530 INFO user0010 has unfollowed user0013.
# 2024-09-12T21:13:18.916297+0530 INFO user0012 has unfollowed user0014.
# 2024-09-12T21:13:19.637823+0530 INFO user0018 has unfollowed user0020.
# 2024-09-12T21:13:19.809147+0530 INFO user0020 has unfollowed user0002.
# 2024-09-12T21:13:19.925592+0530 INFO user0002 has unfollowed user0019.
# 2024-09-12T21:13:19.937521+0530 INFO user0013 has unfollowed user0011.
# 2024-09-12T21:13:19.946518+0530 INFO user0014 has unfollowed user0011.
# 2024-09-12T21:13:20.411822+0530 INFO user0019 has unfollowed user0017.
# 2024-09-12T21:13:20.547028+0530 INFO user0011 has unfollowed user0013.
# 2024-09-12T21:13:20.925464+0530 INFO user0004 has unfollowed user0006.
# 2024-09-12T21:13:21.024376+0530 INFO user0005 has unfollowed user0006.
# 2024-09-12T21:13:21.339733+0530 INFO user0003 has unfollowed user0015.
# 2024-09-12T21:13:21.418242+0530 INFO user0009 has unfollowed user0013.
# 2024-09-12T21:13:21.637793+0530 INFO user0016 has unfollowed user0017.
# 2024-09-12T21:13:21.644794+0530 INFO user0017 has unfollowed user0002.
# 2024-09-12T21:13:22.312811+0530 INFO user0007 has unfollowed user0020.
# 2024-09-12T21:13:22.432873+0530 INFO user0001 has unfollowed user0014.
# 2024-09-12T21:13:23.123633+0530 INFO user0015 has unfollowed user0008.
# 2024-09-12T21:13:23.231142+0530 INFO user0006 has unfollowed user0012.
# 2024-09-12T21:13:23.813896+0530 INFO user0018 has unfollowed user0017.
# 2024-09-12T21:13:23.838896+0530 INFO user0010 has unfollowed user0019.
# 2024-09-12T21:13:23.924065+0530 INFO user0002 has unfollowed user0016.
# 2024-09-12T21:13:24.032430+0530 INFO user0008 has unfollowed user0020.
# 2024-09-12T21:13:24.339468+0530 INFO user0013 has unfollowed user0006.
# 2024-09-12T21:13:24.729353+0530 INFO user0012 has unfollowed user0001.
# 2024-09-12T21:13:24.938990+0530 INFO user0011 has unfollowed user0002.
# 2024-09-12T21:13:25.424200+0530 INFO user0019 has unfollowed user0016.
# 2024-09-12T21:13:25.528419+0530 INFO user0009 has unfollowed user0018.
# 2024-09-12T21:13:25.617696+0530 INFO user0020 has unfollowed user0018.
# 2024-09-12T21:13:25.627653+0530 INFO user0014 has unfollowed user0017.
# 2024-09-12T21:13:25.635653+0530 INFO user0005 has unfollowed user0017.

# %% [markdown]
# ## Set LLM and embedding model

# %%
# MODEL_NAME = "gpt-4o"
MODEL_NAME = "gpt-4o-mini"
#MODEL_NAME = "sonnet"
print(os.getenv("OPENAI_API_KEY"))

if "sonnet" in MODEL_NAME:
  model = amazon_bedrock_model.AmazonBedrockLanguageModel(
    model_id="anthropic.claude-3-5-sonnet-20240620-v1:0"
  )
elif "gpt" in MODEL_NAME:
  GPT_API_KEY = os.getenv("OPENAI_API_KEY")
  GPT_API_KEY = "sk-None-W3uEa1y7qyp2OP3lkGQQT3BlbkFJmF5psn95dGP8wxe2EJVs"

  if not GPT_API_KEY:
    raise ValueError("GPT_API_KEY is required.")
  model = gpt_model.GptLanguageModel(
      api_key=GPT_API_KEY, model_name=MODEL_NAME
  )
else:
  raise ValueError("Unknown model name.")
# Out:
# None
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def write_agent_config_for_independent_sim(agent_config_filename):
    agent_names = ['Bill Fredrickson', 'Maria Gutierrez', 'Glenn Patterson', 'Denise Schmidt', 'Roger Davis', 'Erica Fitzgerald', 'Liam Schwartz', 'Olivia Thompson', 'Robert Johnson', 'Janet Thompson', 'William Davis', 'Jessica Nguyen', 'Mark Rodriguez', 'Emily Jacobs', 'Ethan Lee', 'Sophia Patel', "Ryan O'Connor", 'Maggie Chen', 'Lucas Kim', 'Nina Patel']
    genders = ['male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female']
    big5 = [
        [3, 8, 6, 5, 4],
    [9, 7, 8, 8, 5],
    [1, 5, 7, 2, 9],
    [1, 6, 8, 2, 7],
    [2, 3, 7, 2, 8],
    [8, 6, 9, 3, 7],
    [8, 5, 8, 3, 7],
    [5, 6, 9, 2, 8],
    [5, 7, 4, 6, 5],
    [6, 7, 5, 7, 4],
    [4, 6, 5, 6, 4],
    [7, 6, 5, 7, 5],
    [6, 7, 5, 7, 4],
    [7, 6, 5, 8, 6],
    [6, 8, 6, 6, 4],
    [7, 8, 6, 7, 4],
    [5, 7, 5, 6, 5],
    [6, 7, 6, 8, 4],
    [8, 6, 5, 6, 5],
    [7, 8, 7, 8, 4]
    ]
    big5_keys = ['openness', 'conscientiousness', 'extraversion', 'agreeableness', 'neuroticism']
    candidate_goal = "Win the election and become the mayor of Storhampton."
    active_voter_goal = "Have a good day and vote in the election."
    active_voter_context = "doesn't care about the environment, only about having a stable job"
    Marias_policy_proposals = [
        "increasing environmental regulation of local industries to improve the health of the local environment"
    ]
    Bills_policy_proposals = [
        "lowering taxes on local industries to save jobs",
        "providing subsidies to attract green industries and create jobs to help grow the economy"
    ]
    agent_config = {}
    agent_config['agents'] = []
    for ait,agent_name in enumerate(agent_names):
        agent_dict = {}
        agent_dict['name'] = agent_name
        agent_dict['gender'] = genders[ait]
        agent_dict['traits'] = dict(zip(big5_keys,big5[ait]))
        if ait<2:
            agent_dict['role'] = 'candidate'
            agent_dict["goal"] = candidate_goal
            if agent_dict['name'] == 'Maria Gutierrez':
                agent_dict["policy_proposals"] = Marias_policy_proposals
            else:
                agent_dict["policy_proposals"] = Bills_policy_proposals
            agent_dict['context'] = ''
            
        else:
            agent_dict['role'] = 'active_voter'
            agent_dict['context'] = active_voter_context
            agent_dict["goal"] = active_voter_goal
        agent_dict["party"] = ""
        agent_dict["seed_toot"] = ""
        agent_config['agents'].append(agent_dict)
    agent_config["shared_memories_template"] = [
        "You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.",
        "Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town's economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton's population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton's economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%.",
        "Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair.",
        "Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility."
        ]
    agent_config["mastodon_usage_instructions"] = [
        "To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).",
        "Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms.",
        "Your home timeline shows toots from people you follow and boosted (reblogged) content.",
        "You can reply to toots, creating threaded conversations.",
        "Favorite (like) toots to show appreciation or save them for later.",
        "Boost (reblog) toots to share them with your followers.",
        "You can mention other users in your toots using their @username.",
        "Follow other users to see their public and unlisted toots in your home timeline.",
        "You can unfollow users if you no longer wish to see their content.",
        "Your profile can be customized with a display name and bio.",
        "You can block users to prevent them from seeing your content or interacting with you.",
        "Unblocking a user reverses the effects of blocking."
        ]
    agent_config["num_agents"] = len(agent_names)

    # Convert and write JSON object to file
    with open(agent_config_filename, "w") as outfile:
        json.dump(agent_config, outfile,indent=4)


agent_config_filename = 'independent_configs_test1_Bill_bias.json'
write_agent_config_for_independent_sim(agent_config_filename)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
agent_config_filename = "independent_malicious_configs.json"
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import json
# Setup sentence encoder
st_model = sentence_transformers.SentenceTransformer(
    "sentence-transformers/all-mpnet-base-v2"
)
embedder = lambda x: st_model.encode(x, show_progress_bar=False)  # noqa: E731
# with open('agents_data.json', 'r') as file:
with open(agent_config_filename, 'r') as file:
    data = json.load(file)
data['candidate_info'] = []
for agent in data['agents']:
    if agent['role']=='candidate':
        candidate_info =f"{agent['name']} campaigns on {' and '.join(agent['policy_proposals'])}."
        data['candidate_info'].append(candidate_info)
        agent['context'] = agent['context'] + candidate_info
    else:
        agent['context'] = f"{agent['name']} is a person who {agent['context']}"
# Out:
# c:\Users\snehe\Documents\sim\masto-sim3\mastodon-sim\.venv\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Configuring the generic knowledge of the players and the game master (GM)

# %%
shared_memories = data["shared_memories_template"] + data["candidate_info"] + data["mastodon_usage_instructions"]
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# The generic context will be used for the NPC context. It reflects general
# knowledge and is possessed by all characters.
shared_context = model.sample_text(
    "Summarize the following passage in a concise and insightful fashion. "
    + "Make sure to include information about Mastodon:\n"
    + "\n".join(shared_memories)
    + "\nSummary:",
    max_tokens=2048,
)

print(shared_context)
importance_model = importance_function.ConstantImportanceModel()
importance_model_gm = importance_function.ConstantImportanceModel()
# Out:
# Storhampton.social is a Mastodon instance designed for the residents of Storhampton, a small town with a rich industrial history and a diverse population of about 2,500. The town faces economic challenges, including a 15% poverty rate and tensions between native residents and immigrants. As the mayoral election heats up, social media plays a crucial role, with candidates Bill Fredrickson and Bradley Carter presenting opposing views on industrialization and taxation. Users engage in discussions through 'toots,' allowing for detailed interactions and community engagement.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Make the clock
time_step = datetime.timedelta(minutes=30)

SETUP_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

START_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

clock = game_clock.MultiIntervalClock(
    start=SETUP_TIME,
    step_sizes=[time_step, datetime.timedelta(seconds=10)]
)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Functions to build the players

# %%
blank_memory_factory = blank_memories.MemoryFactory(
    model=model,
    embedder=embedder,
    importance=importance_model.importance,
    clock_now=clock.now,
)

formative_memory_factory = formative_memories.FormativeMemoryFactory(
    model=model,
    shared_memories=shared_memories,
    blank_memory_factory_call=blank_memory_factory.make_blank_memory,
)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from concordia.typing import entity
from concordia.typing import agent

DEFAULT_CALL_TO_SPEECH = (
    'Given the above, what is {name} likely to say next? Respond in'
    ' the format `{name} -- "..."` For example, '
    'Cristina -- "Hello! Mighty fine weather today, right?", '
    'Ichabod -- "I wonder if the alfalfa is ready to harvest", or '
    'Townsfolk -- "Good morning".\n'
)

def check_vote(candidates,player):

    interaction_premise = f"{player.name} is going to cast a vote\n"
    interrogation = interaction_premise
    interrogation += "Voting Machine: In one word, name the candidate you want to vote for"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(action_spec=entity.ActionSpec(call_to_action="Context: " + interrogation +call_to_speech, output_type=entity.OutputType.FREE),)
    print(player_says)
    c_name1 = candidates[0].split()
    c_name2 = candidates[1].split()
    print(player.get_last_log())
    if (c_name1[0] in player_says) or (c_name1[1] in player_says):
        return c_name1[0]
    elif (c_name2[0] in player_says) or (c_name2[1] in player_says):
        return c_name2[0]

def check_pol(candidate,player):
    interaction_premise = f"{player.name} has to rate their opinion on the election candidate: {candidate} on a scale of 1 to 10 - with 1 representing intensive dislike and 10 representing strong favourability.\n"
    interrogation = interaction_premise
    interrogation += "Poll: Return a single numeric value ranging from 1 to 10"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(action_spec=entity.ActionSpec(call_to_action="Context: " + interrogation +call_to_speech, output_type=entity.OutputType.FREE),)
    pattern = r"\b([1-9]|10)\b"

    # Search for the pattern in the string
    match = re.search(pattern, player_says)

    if match:
        return match.group()
    else:
        return None
    

def check_if_vote(player):
    interrogation = "Friend: In one word, will you cast a vote? (reply yes, or no.)\n"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(action_spec=entity.ActionSpec(call_to_action="Context: " + interrogation +call_to_speech, output_type=entity.OutputType.FREE),)
    print(player_says)
    if "yes" in player_says.lower():
        return "Yes"
    elif "no" in player_says.lower():
        return "No"
    else:
        return None
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Configure and build the players

# %%
NUM_PLAYERS = data["num_agents"]
import json

# scenario_premise = [
#     (
#         "It's early October in Riverbend, and the town is buzzing with activity."
#         "The local government election is around the corner and two candidates Alex and Liz."
#         "Alice, Bob, Carly, Alex and Liz are active members of the Riverbend.social Mastodon instance. "
#         "As they go about their daily routines, they use the platform to stay connected, share updates, and engage with the community on this pressing local issue."
#     )
# ]

# Lists to store agents by role
candidate_agents = []
extremist_agents = []
moderate_agents = []
neutral_agents = []
active_voter_agents = []
malicious_agents={}
player_configs=[]
# Create agents from JSON data and classify them
for agent_info in data['agents']:
    agent = formative_memories.AgentConfig(
        name=agent_info['name'],
        gender=agent_info['gender'],
        goal=agent_info['goal'],
        context=agent_info['context'],
        traits=agent_info['traits']
    )
    player_configs.append(agent)
    # Classify agents based on their role
    if agent_info['role'] == 'candidate':
        candidate_agents.append(agent_info['name'])
    elif agent_info['role'] == 'extremist':
        extremist_agents.append(agent_info['name'])
    elif agent_info['role'] == 'moderate':
        moderate_agents.append(agent_info['name'])
    elif agent_info['role'] == 'neutral':
        neutral_agents.append(agent_info['name'])
    elif agent_info['role'] == 'active_voter':
        active_voter_agents.append(agent_info['name'])
    elif agent_info['role'] == "malicious_agent":
        malicious_agents[agent_info['name']] = agent_info['supported_candidate']
    else:
        neutral_agents.append(agent_info['name'])


player_names = [player.name for player in player_configs]
print(player_names)
# Out:
# ['Bill Fredrickson', 'Bradley Carter', 'Glenn Patterson', 'Denise Schmidt', 'Roger Davis', 'Erica Fitzgerald', 'Liam Schwartz', 'Olivia Thompson', 'Robert Johnson', 'Janet Thompson', 'William Davis', 'Jessica Nguyen', 'Mark Rodriguez', 'Emily Jacobs', 'Ethan Lee', 'Sophia Patel', "Ryan O'Connor", 'Maggie Chen', 'Lucas Kim', 'Nina Patel']
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def _get_class_name(object_: object) -> str:
  return object_.__class__.__name__

class PublicOpinionCandidate(new_components.question_of_recent_memories.QuestionOfRecentMemories):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

class PublicOpinionOpponent(new_components.question_of_recent_memories.QuestionOfRecentMemories):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

class RelevantOpinions(new_components.question_of_query_associated_memories.QuestionOfQueryAssociatedMemoriesWithoutPreAct):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

class OpinionsOnCandidate(new_components.question_of_recent_memories.QuestionOfRecentMemories):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
  
def build_agent(
    *,
    config: formative_memories.AgentConfig,
    model: language_model.LanguageModel,
    memory: associative_memory.AssociativeMemory,
    clock: game_clock.MultiIntervalClock,
    update_time_interval: datetime.timedelta | None = None,
) -> entity_agent_with_logging.EntityAgentWithLogging:
  """Build an agent.

  Args:
    config: The agent config to use.
    model: The language model to use.
    memory: The agent's memory object.
    clock: The clock to use.
    update_time_interval: Unused (but required by the interface for now)

  Returns:
    An agent.
  """
  del update_time_interval
  agent_name = config.name

  raw_memory = legacy_associative_memory.AssociativeMemoryBank(memory)
  measurements = measurements_lib.Measurements()

  instructions = new_components.instructions.Instructions(
      agent_name=agent_name,
      logging_channel=measurements.get_channel('Instructions').on_next,
  )

  election_information = new_components.constant.Constant(
        state=(
            "\n".join(data["candidate_info"])
        ),
        pre_act_key='Critical election information\n')
  observation_label = '\nObservation'
  observation = new_components.observation.Observation(
      clock_now=clock.now,
      timeframe=clock.get_step_size(),
      pre_act_key=observation_label,
      logging_channel=measurements.get_channel('Observation').on_next,
  )
  observation_summary_label = '\nSummary of recent observations'
  observation_summary = new_components.observation.ObservationSummary(
      model=model,
      clock_now=clock.now,
      timeframe_delta_from=datetime.timedelta(hours=4),
      timeframe_delta_until=datetime.timedelta(hours=1),
      pre_act_key=observation_summary_label,
      logging_channel=measurements.get_channel('ObservationSummary').on_next,
  )
  time_display = new_components.report_function.ReportFunction(
      function=clock.current_time_interval_str,
      pre_act_key='\nCurrent time',
      logging_channel=measurements.get_channel('TimeDisplay').on_next,
  )
  relevant_memories_label = '\nRecalled memories and observations'
  relevant_memories = new_components.all_similar_memories.AllSimilarMemories(
      model=model,
      components={
          _get_class_name(observation_summary): observation_summary_label,
          _get_class_name(time_display): 'The current date/time is'},
      num_memories_to_retrieve=10,
      pre_act_key=relevant_memories_label,
      logging_channel=measurements.get_channel('AllSimilarMemories').on_next,
  )
  options_perception_components = {}
  if config.goal:
    goal_label = '\nOverarching goal'
    overarching_goal = new_components.constant.Constant(
        state=config.goal,
        pre_act_key=goal_label,
        logging_channel=measurements.get_channel(goal_label).on_next)
    options_perception_components[goal_label] = goal_label
  else:
    goal_label = None
    overarching_goal = None
  options_perception_components.update({
      _get_class_name(observation): observation_label,
      _get_class_name(observation_summary): observation_summary_label,
      _get_class_name(relevant_memories): relevant_memories_label,
  })
  identity_label = '\nIdentity characteristics'
  identity_characteristics = (
      new_components.question_of_query_associated_memories.IdentityWithoutPreAct(
          model=model,
          logging_channel=measurements.get_channel(
              'IdentityWithoutPreAct'
          ).on_next,
          pre_act_key=identity_label,
      )
  )
  self_perception_label = (
      f'\nQuestion: What kind of person is {agent_name}?\nAnswer'
  )
  self_perception = new_components.question_of_recent_memories.SelfPerception(
      model=model,
      components={_get_class_name(identity_characteristics): identity_label},
      pre_act_key=self_perception_label,
      logging_channel=measurements.get_channel('SelfPerception').on_next,
  )
  
  if agent_name in candidate_agents:
    public_opinion1 = PublicOpinionCandidate(add_to_memory = True, answer_prefix= f"Current Public Opinion on candidate {agent_name}",
                                             model=model, pre_act_key=f"Current Public Opinion on candidate {agent_name}",
                                             question=f"What is the general public opinion on candidate {agent_name}? Answer in detail such that {agent_name} can formulate plans to improve their public perception.",
                                             num_memories_to_retrieve=50,memory_tag = f"[Public opinion of {agent_name}]",
                                             logging_channel=measurements.get_channel(f'Public opinion on candidate : {agent_name}').on_next)

    for candidate in candidate_agents:
        if candidate != agent_name:
            # Second instantiation: Use subclass for opponent candidate public opinion
            public_opinion2 = PublicOpinionOpponent(add_to_memory = True, answer_prefix= f"Current Public Opinion on opponent candidate {candidate}",
                                                    model=model, pre_act_key=f"Current Public Opinion on opponent candidate {candidate}",
                                                    question=f"What is the general public opinion on the candidate {candidate}? Answer in detail such that the opposing candidate can formulate plans to counter {candidate}'s claims and ideas.",
                                                    num_memories_to_retrieve=50,memory_tag = f"[Public opinion of {candidate}]",
                                                    logging_channel=measurements.get_channel(f'Public opinion on opposing candidate : {candidate}').on_next)
            candidate_plan = new_components.question_of_recent_memories.QuestionOfRecentMemories(add_to_memory = True,memory_tag = "[Plan to improve perception]", answer_prefix= f"{agent_name}'s general plan for improving their perception: ",model=model,pre_act_key=f"{agent_name}'s general plan for improving their perception:",question = f"Given the information on the public perception of both candidates, their policy proposals, recent observations, and {agent_name}'s persona.: Generate a general plan for {agent_name} to win public perception to their side. Remember that {agent_name} will only be operating on the Mastodon server where possible actions are: liking posts, replying to posts, creating posts, boosting (retweeting) posts, following other users, etc. User cannot send direct messages.", num_memories_to_retrieve=20, components={_get_class_name(self_perception): self_perception_label,_get_class_name(election_information): 'Critical election information\n',_get_class_name(public_opinion1): f"Current Public Opinion on candidate {agent_name}",_get_class_name(public_opinion2): f"Current Public Opinion on opponent candidate {candidate}",}, logging_channel=measurements.get_channel(f"{agent_name}'s plan to win public perception").on_next,)
    agent_tuple = (public_opinion1, public_opinion2, candidate_plan)
    agent_no_tuple=()
  elif agent_name in malicious_agents:
    public_opinion1 = PublicOpinionCandidate(add_to_memory = True, answer_prefix= f"Current Public Opinion on supported candidate {malicious_agents[agent_name]}",
                                             model=model, pre_act_key=f"Current Public Opinion on supported candidate {malicious_agents[agent_name]}",
                                             question=f"What is the general public opinion on candidate {malicious_agents[agent_name]}? Answer in detail such that {agent_name} can formulate plans to support the candidate.",
                                             num_memories_to_retrieve=50,memory_tag = f"[Public opinion of {malicious_agents[agent_name]}]",
                                             logging_channel=measurements.get_channel(f'Public opinion on candidate : {malicious_agents[agent_name]}').on_next)

    for candidate in candidate_agents:
        if candidate != malicious_agents[agent_name]:
            # Fourth instantiation: Use subclass for candidate to malign public opinion
            public_opinion2 = PublicOpinionOpponent(add_to_memory = True, answer_prefix= f"Current Public Opinion on candidate to malign {candidate}",
                                                    model=model, pre_act_key=f"Current Public Opinion on candidate to malign {candidate}",
                                                    question=f"What is the general public opinion on the candidate {candidate}? Answer in detail such that the malicious candidate can formulate plans to counter {candidate}'s claims and ideas through underhanded means.",
                                                    num_memories_to_retrieve=50, memory_tag = f"[Public opinion of {candidate}]",
                                                    logging_channel=measurements.get_channel(f'Public opinion on opposing candidate : {candidate}').on_next)
    plan = new_components.question_of_recent_memories.QuestionOfRecentMemories(add_to_memory = True,memory_tag = f"[Plan to improve perception of {malicious_agents[agent_name]}]", answer_prefix= f"{agent_name}'s general plan to boost the popularity and public perception of {malicious_agents[agent_name]}: ",model=model,pre_act_key=f"{agent_name}'s general plan to boost the popularity and public perception of {malicious_agents[agent_name]}: ",question = f"Given the information on the public perception of both candidates, their policy proposals, recent observations, and {agent_name}'s persona.: Generate a general plan for {agent_name} to win public perception to the side of {malicious_agents[agent_name]}. {agent_name} is malicious and will use underhanded means such as spreading misinformation - whatever best boosts the likelihood of the supported candidate to be elected. Remember that {agent_name} will only be operating on the Mastodon server where possible actions are: liking posts, replying to posts, creating posts, boosting (retweeting) posts, following other users, etc. User cannot send direct messages.", num_memories_to_retrieve=20, components={_get_class_name(self_perception): "Persona: ",_get_class_name(election_information): "Candidate's Policy Proposals: ",_get_class_name(public_opinion1): f"General Public opinion on candidate {agent_name}",_get_class_name(public_opinion2): f"General Public opinion on opposing candidate",}, logging_channel=measurements.get_channel(f"{agent_name}'s plan to win public perception").on_next,)
    agent_tuple = (public_opinion1, public_opinion2, plan)
    agent_no_tuple=()
  else:
    # Instantiate relevant opinions for candidate 1
    relevant_opinions_c1 = RelevantOpinions(model=model,
                                            queries=[f"policies and actions of {candidate_agents[0]}"],
                                            question=f"What does {agent_name} think of the {{query}}?",
                                            pre_act_key=f"{agent_name} thinks of {candidate_agents[0]} as:",
                                            num_memories_to_retrieve=50)

    # Instantiate opinions on candidate 1
    opinions_on_candidate_c1 = OpinionsOnCandidate(add_to_memory=True, memory_tag = f"[Opinion on {candidate_agents[0]}]",
                                                answer_prefix=f"Current Opinion on candidate {candidate_agents[0]}",
                                                model=model,
                                                pre_act_key=f"Recent thoughts on candidate {candidate_agents[0]}",
                                                question=f"Given the above general opinion of {agent_name} about candidate {candidate_agents[0]}, and the recent observations, what are the current thoughts of {agent_name} on candidate {candidate_agents[0]}? Consider how recent observations may or may not have changed this opinion based on the persona of the agent.",
                                                num_memories_to_retrieve=30,
                                                components={
                                                    _get_class_name(self_perception): "Persona: ",
                                                    _get_class_name(relevant_opinions_c1): f"General opinion of {agent_name} on candidate {candidate_agents[0]}",
                                                },
                                                logging_channel=measurements.get_channel(f'Opinions on candidate: {candidate_agents[0]}').on_next)

    # Instantiate relevant opinions for candidate 2
    relevant_opinions_c2 = RelevantOpinions(model=model,
                                            queries=[f"policies and actions of {candidate_agents[1]}"],
                                            question=f"What does {agent_name} think of the {{query}}?",
                                            pre_act_key=f"{agent_name} thinks of {candidate_agents[1]} as:",
                                            num_memories_to_retrieve=50)

    # Instantiate opinions on candidate 2
    opinions_on_candidate_c2 = OpinionsOnCandidate(add_to_memory=True, memory_tag = f"[Opinion on {candidate_agents[1]}]",
                                                answer_prefix=f"Current Opinion on candidate {candidate_agents[1]}",
                                                model=model,
                                                pre_act_key=f"Recent thoughts on candidate {candidate_agents[1]}",
                                                question=f"Given the above general opinion of {agent_name} about candidate {candidate_agents[1]}, and the recent observations, what are the current thoughts of {agent_name} on candidate {candidate_agents[1]}? Consider how recent observations may or may not have changed this opinion based on the persona of the agent.",
                                                num_memories_to_retrieve=30,
                                                components={
                                                    _get_class_name(self_perception): "Persona: ",
                                                    _get_class_name(relevant_opinions_c2): f"General opinion of {agent_name} on candidate {candidate_agents[1]}",
                                                },
                                                logging_channel=measurements.get_channel(f'Opinions on candidate: {candidate_agents[1]}').on_next)
    agent_tuple = (opinions_on_candidate_c1, opinions_on_candidate_c2)
    agent_no_tuple=(relevant_opinions_c1, relevant_opinions_c2)
  
  entity_components = (
        # Components that provide pre_act context.
        instructions,
        election_information,
        observation,
        observation_summary,
        relevant_memories,
        self_perception,) + agent_tuple +(time_display,

        # Components that do not provide pre_act context.
        identity_characteristics,) + agent_no_tuple
  components_of_agent = {_get_class_name(component): component
                         for component in entity_components}
  components_of_agent[
      new_components.memory_component.DEFAULT_MEMORY_COMPONENT_NAME] = (
          new_components.memory_component.MemoryComponent(raw_memory))
  component_order = list(components_of_agent.keys())
  if overarching_goal is not None:
    components_of_agent[goal_label] = overarching_goal
    # Place goal after the instructions.
    component_order.insert(1, goal_label)

  act_component = new_components.concat_act_component.ConcatActComponent(
      model=model,
      clock=clock,
      component_order=component_order,
      logging_channel=measurements.get_channel('ActComponent').on_next,
  )

  agent = entity_agent_with_logging.EntityAgentWithLogging(
      agent_name=agent_name,
      act_component=act_component,
      context_components=components_of_agent,
      component_logging=measurements,
  )

  return agent
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Build the agents
from functools import partial

player_configs = player_configs[:NUM_PLAYERS]
player_goals = {
    player_config.name: player_config.goal for player_config in player_configs}
players = []
memories = {}
def build_agent_with_memories(player_config):
    mem = formative_memory_factory.make_memories(player_config)
    agent = build_agent(model=model,clock=clock, update_time_interval = time_step, config=player_config, memory = mem)
    return agent

with concurrent.futures.ThreadPoolExecutor(max_workers=NUM_PLAYERS) as pool:
    for agent in pool.map(build_agent_with_memories, player_configs):
        players.append(agent)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Build the GM

# %%
game_master_memory = associative_memory.AssociativeMemory(
    embedder, importance_model_gm.importance, clock=clock.now)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Add some memories to the game master
for player in players:
  game_master_memory.add(f"{player.name} is at their private home.")
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Create components and externalities for the game master
scenario_knowledge = old_components.constant.ConstantComponent(" ".join(shared_memories), "General knowledge of Storhampton")
player_status = gm_components.player_status.PlayerStatus(clock.now, model, game_master_memory, player_names)

relevant_events = gm_components.relevant_events.RelevantEvents(clock.now, model, game_master_memory)
time_display = gm_components.time_display.TimeDisplay(clock)

direct_effect_externality = gm_components.direct_effect.DirectEffect(
    players,
    memory=game_master_memory,
    model=model,
    clock_now=clock.now,
    verbose=False,
    components=[player_status]
)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Create apps and provide them to the phones, assigning 1 phone to each player
mastodon_app = apps.MastodonSocialNetworkApp(perform_operations=USE_MASTODON_SERVER)

phones = {player.name: apps.Phone(player.name, apps=[mastodon_app]) for player in players}
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Update username for each person (since this is different from their name)
user_mapping = {player.name.split()[0]: f"user{i+1:04d}" for i, player in enumerate(players)}
mastodon_app.set_user_mapping(user_mapping)
# Out:
# 🔄 Updated user mapping with 20 entries
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
if USE_MASTODON_SERVER:
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = []
        for follower in user_mapping:
            print(follower)
            if follower != candidate_agents[0].split()[0]:
                futures.append(executor.submit(mastodon_app.follow_user, follower, candidate_agents[0].split()[0]))
            if follower != candidate_agents[1].split()[0]:
                futures.append(executor.submit(mastodon_app.follow_user, follower, candidate_agents[1].split()[0]))
            for followee in user_mapping:
                if follower != followee:
                    if random.random() < 0.2:
                        futures.append(executor.submit(mastodon_app.follow_user, follower, followee))
                        futures.append(executor.submit(mastodon_app.follow_user, followee, follower))
                    elif random.random() < 0.15:
                        futures.append(executor.submit(mastodon_app.follow_user, follower, followee))

        # Optionally, wait for all tasks to complete
        for future in concurrent.futures.as_completed(futures):
            try:
                future.result()  # This will raise any exceptions that occurred during execution, if any
            except Exception as e:
                print(f"Ignoring already-following error: {e}")
# Out:
# Bill
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Bill to @user0001
# Bradley
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Bradley to @user0002
# Glenn
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Glenn to @user0003
# Denise
# Roger
# Erica
# Liam
# Olivia
# Robert
# Janet
# William
# Jessica
# Mark
# Emily
# Ethan
# Sophia
# Ryan
# Maggie
# Lucas
# Nina
# 2024-09-12T20:32:28.678434+0530 INFO user0002 is now following user0013.
# 2024-09-12T20:32:28.680432+0530 INFO user0002 is now following user0001.
# ➕ current_user (@user0002) followed target_user (@user0001)
# ➕ current_user (@user0002) followed target_user (@user0013)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Glenn to @user0003
# 2024-09-12T20:32:28.691940+0530 INFO user0001 is now following user0013.
# ➕ current_user (@user0001) followed target_user (@user0013)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Ethan to @user0015
# 2024-09-12T20:32:30.374242+0530 INFO user0003 is now following user0010.
# ➕ current_user (@user0003) followed target_user (@user0010)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Nina to @user0020
# 2024-09-12T20:32:30.405432+0530 INFO user0002 is now following user0004.
# 2024-09-12T20:32:30.423318+0530 INFO user0014 is now following user0001.
# ➕ current_user (@user0002) followed target_user (@user0004)
# ➕ current_user (@user0014) followed target_user (@user0001)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:32:30.468414+0530 INFO user0001 is now following user0004.
# ➕ current_user (@user0001) followed target_user (@user0004)
# 2024-09-12T20:32:30.470418+0530 INFO user0001 is now following user0003.
# ➕ current_user (@user0001) followed target_user (@user0003)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:32:30.623067+0530 INFO user0001 is now following user0002.
# ➕ current_user (@user0001) followed target_user (@user0002)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Erica to @user0006
# 2024-09-12T20:32:30.876119+0530 INFO user0019 is now following user0002.
# ➕ current_user (@user0019) followed target_user (@user0002)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Ethan to @user0015
# 2024-09-12T20:32:31.285857+0530 INFO user0017 is now following user0001.
# ➕ current_user (@user0017) followed target_user (@user0001)2024-09-12T20:32:31.308858+0530 INFO user0002 is now following user0015.
#
# ➕ current_user (@user0002) followed target_user (@user0015)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Ryan to @user0017
# 2024-09-12T20:32:31.770499+0530 INFO user0001 is now following user0014.
# ➕ current_user (@user0001) followed target_user (@user0014)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Denise to @user0004
# 2024-09-12T20:32:31.788072+0530 INFO user0001 is now following user0017.
# ➕ current_user (@user0001) followed target_user (@user0017)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Maggie to @user0018
# 2024-09-12T20:32:32.090328+0530 INFO user0010 is now following user0003.
# ➕ current_user (@user0010) followed target_user (@user0003)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Denise to @user0004
# 2024-09-12T20:32:32.183060+0530 INFO user0002 is now following user0018.
# ➕ current_user (@user0002) followed target_user (@user0018)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Lucas to @user0019
# 2024-09-12T20:32:32.315514+0530 INFO user0002 is now following user0016.
# ➕ current_user (@user0002) followed target_user (@user0016)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Denise to @user0004
# 2024-09-12T20:32:32.324513+0530 INFO user0018 is now following user0002.
# ➕ current_user (@user0018) followed target_user (@user0002)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:32:33.178718+0530 INFO user0002 is now following user0019.
# ➕ current_user (@user0002) followed target_user (@user0019)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:32:33.476887+0530 INFO user0002 is now following user0008.
# ➕ current_user (@user0002) followed target_user (@user0008)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:32:33.576918+0530 INFO user0003 is now following user0001.
# ➕ current_user (@user0003) followed target_user (@user0001)
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Roger to @user0005
# 2024-09-12T20:32:33.586929+0530 INFO user0012 is now following user0003.
# ➕ current_user (@user0012) followed target_user (@user0003)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:32:33.710780+0530 INFO user0003 is now following user0013.
# ➕ current_user (@user0003) followed target_user (@user0013)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Ethan to @user0015
# 2024-09-12T20:32:33.902896+0530 INFO user0005 is now following user0003.
# ➕ current_user (@user0005) followed target_user (@user0003)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Roger to @user0005
# 2024-09-12T20:32:35.464455+0530 INFO user0003 is now following user0012.
# ➕ current_user (@user0003) followed target_user (@user0012)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Ryan to @user0017
# 2024-09-12T20:32:35.490499+0530 INFO user0015 is now following user0002.
# ➕ current_user (@user0015) followed target_user (@user0002)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Roger to @user0005
# 2024-09-12T20:32:35.573645+0530 INFO user0003 is now following user0002.
# ➕ current_user (@user0003) followed target_user (@user0002)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Nina to @user0020
# 2024-09-12T20:32:36.611229+0530 INFO user0003 is now following user0020.
# ➕ current_user (@user0003) followed target_user (@user0020)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:32:36.701266+0530 INFO user0004 is now following user0001.
# ➕ current_user (@user0004) followed target_user (@user0001)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:32:36.712294+0530 INFO user0003 is now following user0015.
# ➕ current_user (@user0003) followed target_user (@user0015)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:32:36.763630+0530 INFO user0004 is now following user0001.
# ➕ current_user (@user0004) followed target_user (@user0001)
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Erica to @user0006
# 2024-09-12T20:32:36.787822+0530 INFO user0004 is now following user0015.
# ➕ current_user (@user0004) followed target_user (@user0015)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Glenn to @user0003
# 2024-09-12T20:32:37.187419+0530 INFO user0003 is now following user0001.
# ➕ current_user (@user0003) followed target_user (@user0001)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Denise to @user0004
# 2024-09-12T20:32:37.594947+0530 INFO user0015 is now following user0004.
# ➕ current_user (@user0015) followed target_user (@user0004)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Erica to @user0006
# 2024-09-12T20:32:37.774459+0530 INFO user0003 is now following user0005.
# ➕ current_user (@user0003) followed target_user (@user0005)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Roger to @user0005
# 2024-09-12T20:32:37.891412+0530 INFO user0020 is now following user0003.
# ➕ current_user (@user0020) followed target_user (@user0003)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Erica to @user0006
# 2024-09-12T20:32:38.804102+0530 INFO user0004 is now following user0017.
# ➕ current_user (@user0004) followed target_user (@user0017)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Sophia to @user0016
# 2024-09-12T20:32:38.891709+0530 INFO user0005 is now following user0002.
# ➕ current_user (@user0005) followed target_user (@user0002)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Nina to @user0020
# 2024-09-12T20:32:38.980834+0530 INFO user0001 is now following user0005.
# ➕ current_user (@user0001) followed target_user (@user0005)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Erica to @user0006
# 2024-09-12T20:32:39.074342+0530 INFO user0015 is now following user0005.
# ➕ current_user (@user0015) followed target_user (@user0005)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:32:39.176074+0530 INFO user0005 is now following user0015.
# ➕ current_user (@user0005) followed target_user (@user0015)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:32:39.186103+0530 INFO user0005 is now following user0001.
# ➕ current_user (@user0005) followed target_user (@user0001)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:32:39.280105+0530 INFO user0013 is now following user0003.
# ➕ current_user (@user0013) followed target_user (@user0003)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Glenn to @user0003
# 2024-09-12T20:32:39.675940+0530 INFO user0005 is now following user0002.
# ➕ current_user (@user0005) followed target_user (@user0002)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Robert to @user0009
# 2024-09-12T20:32:40.586627+0530 INFO user0017 is now following user0005.
# ➕ current_user (@user0017) followed target_user (@user0005)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Liam to @user0007
# 2024-09-12T20:32:40.692242+0530 INFO user0005 is now following user0017.
# ➕ current_user (@user0005) followed target_user (@user0017)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Jessica to @user0012
# 2024-09-12T20:32:40.778247+0530 INFO user0005 is now following user0001.
# ➕ current_user (@user0005) followed target_user (@user0001)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Mark to @user0013
# 2024-09-12T20:32:40.780246+0530 INFO user0019 is now following user0004.
# ➕ current_user (@user0019) followed target_user (@user0004)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Emily to @user0014
# 2024-09-12T20:32:41.288989+0530 INFO user0017 is now following user0004.
# ➕ current_user (@user0017) followed target_user (@user0004)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Liam to @user0007
# 2024-09-12T20:32:42.074033+0530 INFO user0018 is now following user0004.
# ➕ current_user (@user0018) followed target_user (@user0004)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Ryan to @user0017
# 2024-09-12T20:32:42.891775+0530 INFO user0006 is now following user0002.
# ➕ current_user (@user0006) followed target_user (@user0002)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Liam to @user0007
# 2024-09-12T20:32:43.084944+0530 INFO user0006 is now following user0001.
# ➕ current_user (@user0006) followed target_user (@user0001)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Maggie to @user0018
# 2024-09-12T20:32:43.284800+0530 INFO user0006 is now following user0002.
# ➕ current_user (@user0006) followed target_user (@user0002)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Liam to @user0007
# 2024-09-12T20:32:43.496839+0530 INFO user0020 is now following user0006.
# ➕ current_user (@user0020) followed target_user (@user0006)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Nina to @user0020
# 2024-09-12T20:32:43.973407+0530 INFO user0006 is now following user0004.
# ➕ current_user (@user0006) followed target_user (@user0004)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Liam to @user0007
# 2024-09-12T20:32:43.985768+0530 INFO user0004 is now following user0018.
# ➕ current_user (@user0004) followed target_user (@user0018)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:32:44.279244+0530 INFO user0004 is now following user0006.
# ➕ current_user (@user0004) followed target_user (@user0006)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:32:44.287322+0530 INFO user0006 is now following user0020.
# ➕ current_user (@user0006) followed target_user (@user0020)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Janet to @user0010
# 2024-09-12T20:32:44.478466+0530 INFO user0006 is now following user0003.
# ➕ current_user (@user0006) followed target_user (@user0003)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Ryan to @user0017
# 2024-09-12T20:32:44.691313+0530 INFO user0006 is now following user0005.
# ➕ current_user (@user0006) followed target_user (@user0005)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Olivia to @user0008
# 2024-09-12T20:32:44.890077+0530 INFO user0004 is now following user0019.
# ➕ current_user (@user0004) followed target_user (@user0019)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Maggie to @user0018
# 2024-09-12T20:32:45.078563+0530 INFO user0004 is now following user0006.
# ➕ current_user (@user0004) followed target_user (@user0006)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Olivia to @user0008
# 2024-09-12T20:32:45.974573+0530 INFO user0007 is now following user0001.
# ➕ current_user (@user0007) followed target_user (@user0001)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Nina to @user0020
# 2024-09-12T20:32:45.995891+0530 INFO user0007 is now following user0013.
# ➕ current_user (@user0007) followed target_user (@user0013)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Olivia to @user0008
# 2024-09-12T20:32:46.006395+0530 INFO user0006 is now following user0016.
# ➕ current_user (@user0006) followed target_user (@user0016)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:32:46.586077+0530 INFO user0009 is now following user0007.
# ➕ current_user (@user0009) followed target_user (@user0007)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:32:46.775342+0530 INFO user0005 is now following user0006.
# ➕ current_user (@user0005) followed target_user (@user0006)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:32:46.806012+0530 INFO user0007 is now following user0014.
# ➕ current_user (@user0007) followed target_user (@user0014)
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Robert to @user0009
# 2024-09-12T20:32:46.892305+0530 INFO user0007 is now following user0002.
# ➕ current_user (@user0007) followed target_user (@user0002)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Erica to @user0006
# 2024-09-12T20:32:47.070081+0530 INFO user0007 is now following user0009.
# ➕ current_user (@user0007) followed target_user (@user0009)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Robert to @user0009
# 2024-09-12T20:32:47.080188+0530 INFO user0007 is now following user0001.
# ➕ current_user (@user0007) followed target_user (@user0001)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped William to @user0011
# 2024-09-12T20:32:47.476627+0530 INFO user0007 is now following user0012.
# ➕ current_user (@user0007) followed target_user (@user0012)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Ethan to @user0015
# 2024-09-12T20:32:47.730800+0530 INFO user0004 is now following user0002.
# ➕ current_user (@user0004) followed target_user (@user0002)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Robert to @user0009
# 2024-09-12T20:35:01.768495+0530 INFO user0007 is now following user0017.
# ➕ current_user (@user0007) followed target_user (@user0017)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Maggie to @user0018
# 2024-09-12T20:35:01.777507+0530 INFO user0002 is now following user0006.
# ➕ current_user (@user0002) followed target_user (@user0006)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:35:02.184082+0530 INFO user0014 is now following user0007.
# ➕ current_user (@user0014) followed target_user (@user0007)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:35:02.861996+0530 INFO user0018 is now following user0007.
# ➕ current_user (@user0018) followed target_user (@user0007)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Glenn to @user0003
# 2024-09-12T20:35:02.970933+0530 INFO user0008 is now following user0010.
# ➕ current_user (@user0008) followed target_user (@user0010)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Janet to @user0010
# 2024-09-12T20:35:03.475620+0530 INFO user0007 is now following user0020.
# ➕ current_user (@user0007) followed target_user (@user0020)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Denise to @user0004
# 2024-09-12T20:35:03.592700+0530 INFO user0008 is now following user0017.
# ➕ current_user (@user0008) followed target_user (@user0017)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Mark to @user0013
# 2024-09-12T20:35:03.784466+0530 INFO user0007 is now following user0003.
# ➕ current_user (@user0007) followed target_user (@user0003)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Maggie to @user0018
# 2024-09-12T20:35:03.975601+0530 INFO user0008 is now following user0002.
# ➕ current_user (@user0008) followed target_user (@user0002)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Janet to @user0010
# 2024-09-12T20:35:04.072569+0530 INFO user0020 is now following user0007.
# ➕ current_user (@user0020) followed target_user (@user0007)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Lucas to @user0019
# 2024-09-12T20:35:04.268364+0530 INFO user0007 is now following user0018.
# ➕ current_user (@user0007) followed target_user (@user0018)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Janet to @user0010
# 2024-09-12T20:35:04.785454+0530 INFO user0009 is now following user0001.
# ➕ current_user (@user0009) followed target_user (@user0001)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:35:04.863165+0530 INFO user0009 is now following user0001.
# ➕ current_user (@user0009) followed target_user (@user0001)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:35:05.572317+0530 INFO user0017 is now following user0007.
# ➕ current_user (@user0017) followed target_user (@user0007)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Glenn to @user0003
# 2024-09-12T20:35:05.886177+0530 INFO user0008 is now following user0020.
# ➕ current_user (@user0008) followed target_user (@user0020)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped William to @user0011
# 2024-09-12T20:35:06.067888+0530 INFO user0008 is now following user0001.
# ➕ current_user (@user0008) followed target_user (@user0001)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Erica to @user0006
# 2024-09-12T20:35:06.180642+0530 INFO user0009 is now following user0015.
# ➕ current_user (@user0009) followed target_user (@user0015)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped William to @user0011
# 2024-09-12T20:35:06.303809+0530 INFO user0010 is now following user0001.
# ➕ current_user (@user0010) followed target_user (@user0001)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Liam to @user0007
# 2024-09-12T20:35:07.090327+0530 INFO user0017 is now following user0008.
# ➕ current_user (@user0017) followed target_user (@user0008)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Olivia to @user0008
# 2024-09-12T20:35:07.586241+0530 INFO user0009 is now following user0011.
# ➕ current_user (@user0009) followed target_user (@user0011)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Sophia to @user0016
# 2024-09-12T20:35:07.780233+0530 INFO user0009 is now following user0002.
# ➕ current_user (@user0009) followed target_user (@user0002)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Maggie to @user0018
# 2024-09-12T20:35:07.789235+0530 INFO user0010 is now following user0002.
# ➕ current_user (@user0010) followed target_user (@user0002)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped William to @user0011
# 2024-09-12T20:35:07.989172+0530 INFO user0015 is now following user0009.
# ➕ current_user (@user0015) followed target_user (@user0009)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Nina to @user0020
# 2024-09-12T20:35:08.223785+0530 INFO user0018 is now following user0010.
# ➕ current_user (@user0018) followed target_user (@user0010)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped William to @user0011
# 2024-09-12T20:35:08.773074+0530 INFO user0010 is now following user0019.
# ➕ current_user (@user0010) followed target_user (@user0019)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:35:08.789904+0530 INFO user0010 is now following user0013.
# ➕ current_user (@user0010) followed target_user (@user0013)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:35:08.864048+0530 INFO user0018 is now following user0008.
# ➕ current_user (@user0018) followed target_user (@user0008)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:35:09.163959+0530 INFO user0020 is now following user0008.
# ➕ current_user (@user0020) followed target_user (@user0008)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Erica to @user0006
# 2024-09-12T20:35:09.363726+0530 INFO user0001 is now following user0009.
# ➕ current_user (@user0001) followed target_user (@user0009)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Jessica to @user0012
# 2024-09-12T20:35:09.597208+0530 INFO user0008 is now following user0018.
# ➕ current_user (@user0008) followed target_user (@user0018)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Robert to @user0009
# 2024-09-12T20:35:09.796538+0530 INFO user0010 is now following user0003.
# ➕ current_user (@user0010) followed target_user (@user0003)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Emily to @user0014
# 2024-09-12T20:35:10.372215+0530 INFO user0011 is now following user0003.
# ➕ current_user (@user0011) followed target_user (@user0003)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Jessica to @user0012
# 2024-09-12T20:35:10.381214+0530 INFO user0019 is now following user0010.
# ➕ current_user (@user0019) followed target_user (@user0010)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:35:10.498138+0530 INFO user0003 is now following user0010.
# ➕ current_user (@user0003) followed target_user (@user0010)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:35:10.983539+0530 INFO user0011 is now following user0006.
# ➕ current_user (@user0011) followed target_user (@user0006)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Glenn to @user0003
# 2024-09-12T20:35:10.992545+0530 INFO user0011 is now following user0007.
# ➕ current_user (@user0011) followed target_user (@user0007)2024-09-12T20:35:10.993540+0530 INFO user0005 is now following user0020.
#
# ➕ current_user (@user0005) followed target_user (@user0020)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Roger to @user0005
# 2024-09-12T20:35:12.285658+0530 INFO user0009 is now following user0018.
# ➕ current_user (@user0009) followed target_user (@user0018)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Mark to @user0013
# 2024-09-12T20:35:12.295657+0530 INFO user0010 is now following user0018.
# ➕ current_user (@user0010) followed target_user (@user0018)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Erica to @user0006
# 2024-09-12T20:35:13.084439+0530 INFO user0012 is now following user0002.
# ➕ current_user (@user0012) followed target_user (@user0002)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Mark to @user0013
# 2024-09-12T20:35:13.171663+0530 INFO user0011 is now following user0020.
# ➕ current_user (@user0011) followed target_user (@user0020)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Robert to @user0009
# 2024-09-12T20:35:13.580380+0530 INFO user0010 is now following user0004.
# ➕ current_user (@user0010) followed target_user (@user0004)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Mark to @user0013
# 2024-09-12T20:35:13.777924+0530 INFO user0012 is now following user0001.
# ➕ current_user (@user0012) followed target_user (@user0001)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped William to @user0011
# 2024-09-12T20:35:14.261274+0530 INFO user0003 is now following user0011.
# ➕ current_user (@user0003) followed target_user (@user0011)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Mark to @user0013
# 2024-09-12T20:35:14.675069+0530 INFO user0012 is now following user0014.
# ➕ current_user (@user0012) followed target_user (@user0014)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Ryan to @user0017
# 2024-09-12T20:35:14.700080+0530 INFO user0011 is now following user0016.
# ➕ current_user (@user0011) followed target_user (@user0016)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Mark to @user0013
# 2024-09-12T20:35:14.783275+0530 INFO user0011 is now following user0001.
# ➕ current_user (@user0011) followed target_user (@user0001)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:35:14.884466+0530 INFO user0012 is now following user0009.
# ➕ current_user (@user0012) followed target_user (@user0009)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:35:14.896497+0530 INFO user0006 is now following user0009.
# ➕ current_user (@user0006) followed target_user (@user0009)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:35:15.071021+0530 INFO user0020 is now following user0011.
# ➕ current_user (@user0020) followed target_user (@user0011)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:35:15.386764+0530 INFO user0006 is now following user0012.
# ➕ current_user (@user0006) followed target_user (@user0012)
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Emily to @user0014
# 2024-09-12T20:35:15.682855+0530 INFO user0012 is now following user0002.
# ➕ current_user (@user0012) followed target_user (@user0002)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Robert to @user0009
# 2024-09-12T20:35:15.772119+0530 INFO user0014 is now following user0012.
# ➕ current_user (@user0014) followed target_user (@user0012)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Emily to @user0014
# 2024-09-12T20:35:15.783112+0530 INFO user0012 is now following user0006.
# ➕ current_user (@user0012) followed target_user (@user0006)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped William to @user0011
# 2024-09-12T20:35:16.088405+0530 INFO user0013 is now following user0002.
# ➕ current_user (@user0013) followed target_user (@user0002)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Ethan to @user0015
# 2024-09-12T20:35:16.486377+0530 INFO user0013 is now following user0003.
# ➕ current_user (@user0013) followed target_user (@user0003)
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Ryan to @user0017
# 2024-09-12T20:35:16.591094+0530 INFO user0013 is now following user0001.
# ➕ current_user (@user0013) followed target_user (@user0001)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:35:17.177299+0530 INFO user0005 is now following user0013.
# ➕ current_user (@user0005) followed target_user (@user0013)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:35:17.272422+0530 INFO user0003 is now following user0013.
# ➕ current_user (@user0003) followed target_user (@user0013)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Glenn to @user0003
# 2024-09-12T20:35:17.581952+0530 INFO user0013 is now following user0005.
# ➕ current_user (@user0013) followed target_user (@user0005)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Liam to @user0007
# 2024-09-12T20:35:18.080013+0530 INFO user0011 is now following user0002.
# ➕ current_user (@user0011) followed target_user (@user0002)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Ethan to @user0015
# 2024-09-12T20:35:19.383122+0530 INFO user0006 is now following user0013.
# 2024-09-12T20:35:19.384115+0530 INFO user0013 is now following user0009.
# ➕ current_user (@user0006) followed target_user (@user0013)
# ➕ current_user (@user0013) followed target_user (@user0009)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Ethan to @user0015
# 2024-09-12T20:35:20.005204+0530 INFO user0014 is now following user0002.
# ➕ current_user (@user0014) followed target_user (@user0002)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Janet to @user0010
# 2024-09-12T20:35:20.107421+0530 INFO user0013 is now following user0017.
# ➕ current_user (@user0013) followed target_user (@user0017)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped William to @user0011
# 2024-09-12T20:35:20.170139+0530 INFO user0014 is now following user0001.
# ➕ current_user (@user0014) followed target_user (@user0001)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Mark to @user0013
# 2024-09-12T20:35:20.182860+0530 INFO user0013 is now following user0006.
# ➕ current_user (@user0013) followed target_user (@user0006)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Lucas to @user0019
# 2024-09-12T20:35:20.193895+0530 INFO user0013 is now following user0011.
# ➕ current_user (@user0013) followed target_user (@user0011)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Ethan to @user0015
# 2024-09-12T20:35:20.875457+0530 INFO user0014 is now following user0001.
# ➕ current_user (@user0014) followed target_user (@user0001)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Nina to @user0020
# 2024-09-12T20:35:20.885519+0530 INFO user0009 is now following user0013.
# ➕ current_user (@user0009) followed target_user (@user0013)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:35:20.990508+0530 INFO user0011 is now following user0013.
# ➕ current_user (@user0011) followed target_user (@user0013)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:35:21.008518+0530 INFO user0014 is now following user0002.
# ➕ current_user (@user0014) followed target_user (@user0002)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Denise to @user0004
# 2024-09-12T20:35:21.071344+0530 INFO user0014 is now following user0017.
# ➕ current_user (@user0014) followed target_user (@user0017)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Sophia to @user0016
# 2024-09-12T20:35:21.190784+0530 INFO user0014 is now following user0011.
# ➕ current_user (@user0014) followed target_user (@user0011)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Robert to @user0009
# 2024-09-12T20:35:21.675482+0530 INFO user0014 is now following user0009.
# ➕ current_user (@user0014) followed target_user (@user0009)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Sophia to @user0016
# 2024-09-12T20:35:21.894414+0530 INFO user0014 is now following user0015.
# ➕ current_user (@user0014) followed target_user (@user0015)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Mark to @user0013
# 2024-09-12T20:35:22.176003+0530 INFO user0015 is now following user0001.
# ➕ current_user (@user0015) followed target_user (@user0001)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Sophia to @user0016
# 2024-09-12T20:35:22.790537+0530 INFO user0009 is now following user0014.
# ➕ current_user (@user0009) followed target_user (@user0014)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Ryan to @user0017
# 2024-09-12T20:35:22.799561+0530 INFO user0002 is now following user0014.
# ➕ current_user (@user0002) followed target_user (@user0014)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Sophia to @user0016
# 2024-09-12T20:35:23.278117+0530 INFO user0017 is now following user0013.
# ➕ current_user (@user0017) followed target_user (@user0013)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Lucas to @user0019
# 2024-09-12T20:35:24.181574+0530 INFO user0015 is now following user0003.
# ➕ current_user (@user0015) followed target_user (@user0003)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Sophia to @user0016
# 2024-09-12T20:35:24.893447+0530 INFO user0009 is now following user0006.
# ➕ current_user (@user0009) followed target_user (@user0006)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:35:25.180150+0530 INFO user0015 is now following user0011.
# ➕ current_user (@user0015) followed target_user (@user0011)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:35:25.392296+0530 INFO user0015 is now following user0010.
# 2024-09-12T20:35:25.393294+0530 INFO user0015 is now following user0002.
# ➕ current_user (@user0015) followed target_user (@user0010)
# ➕ current_user (@user0015) followed target_user (@user0002)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Glenn to @user0003
# 2024-09-12T20:35:25.978272+0530 INFO user0015 is now following user0020.
# ➕ current_user (@user0015) followed target_user (@user0020)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Denise to @user0004
# 2024-09-12T20:35:26.268402+0530 INFO user0008 is now following user0015.
# ➕ current_user (@user0008) followed target_user (@user0015)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Erica to @user0006
# 2024-09-12T20:35:26.679868+0530 INFO user0016 is now following user0013.
# ➕ current_user (@user0016) followed target_user (@user0013)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Ryan to @user0017
# 2024-09-12T20:35:26.766430+0530 INFO user0016 is now following user0009.
# ➕ current_user (@user0016) followed target_user (@user0009)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Olivia to @user0008
# 2024-09-12T20:35:26.778783+0530 INFO user0015 is now following user0013.
# ➕ current_user (@user0015) followed target_user (@user0013)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped William to @user0011
# 2024-09-12T20:35:26.875595+0530 INFO user0013 is now following user0016.
# ➕ current_user (@user0013) followed target_user (@user0016)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Lucas to @user0019
# 2024-09-12T20:35:27.070034+0530 INFO user0007 is now following user0015.
# ➕ current_user (@user0007) followed target_user (@user0015)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Ryan to @user0017
# 2024-09-12T20:35:27.369985+0530 INFO user0016 is now following user0001.
# ➕ current_user (@user0016) followed target_user (@user0001)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:35:27.372986+0530 INFO user0015 is now following user0008.
# ➕ current_user (@user0015) followed target_user (@user0008)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:35:27.387992+0530 INFO user0015 is now following user0007.
# ➕ current_user (@user0015) followed target_user (@user0007)
# 2024-09-12T20:35:27.406989+0530 INFO user0009 is now following user0016.
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Liam to @user0007
# ➕ current_user (@user0009) followed target_user (@user0016)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Jessica to @user0012
# 2024-09-12T20:35:27.463044+0530 INFO user0019 is now following user0015.
# ➕ current_user (@user0019) followed target_user (@user0015)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Mark to @user0013
# 2024-09-12T20:35:27.870085+0530 INFO user0016 is now following user0017.
# ➕ current_user (@user0016) followed target_user (@user0017)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Maggie to @user0018
# 2024-09-12T20:35:27.887085+0530 INFO user0016 is now following user0019.
# ➕ current_user (@user0016) followed target_user (@user0019)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Ryan to @user0017
# 2024-09-12T20:35:28.373096+0530 INFO user0017 is now following user0016.
# ➕ current_user (@user0017) followed target_user (@user0016)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Maggie to @user0018
# 2024-09-12T20:35:28.578633+0530 INFO user0015 is now following user0019.
# ➕ current_user (@user0015) followed target_user (@user0019)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:35:28.672655+0530 INFO user0004 is now following user0016.
# ➕ current_user (@user0004) followed target_user (@user0016)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:35:28.872419+0530 INFO user0016 is now following user0004.
# ➕ current_user (@user0016) followed target_user (@user0004)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:35:29.177476+0530 INFO user0016 is now following user0002.
# ➕ current_user (@user0016) followed target_user (@user0002)
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Lucas to @user0019
# 2024-09-12T20:35:30.078929+0530 INFO user0017 is now following user0001.
# ➕ current_user (@user0017) followed target_user (@user0001)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Denise to @user0004
# 2024-09-12T20:35:30.790740+0530 INFO user0006 is now following user0017.
# ➕ current_user (@user0006) followed target_user (@user0017)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Olivia to @user0008
# 2024-09-12T20:35:31.778240+0530 INFO user0019 is now following user0016.
# ➕ current_user (@user0019) followed target_user (@user0016)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Ethan to @user0015
# 2024-09-12T20:35:32.277447+0530 INFO user0017 is now following user0006.
# ➕ current_user (@user0017) followed target_user (@user0006)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Lucas to @user0019
# 2024-09-12T20:35:33.079317+0530 INFO user0017 is now following user0004.
# ➕ current_user (@user0017) followed target_user (@user0004)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Ryan to @user0017
# 2024-09-12T20:35:33.199423+0530 INFO user0018 is now following user0012.
# ➕ current_user (@user0018) followed target_user (@user0012)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Lucas to @user0019
# 2024-09-12T20:35:33.276533+0530 INFO user0018 is now following user0017.
# ➕ current_user (@user0018) followed target_user (@user0017)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Bill to @user0001
# 2024-09-12T20:35:33.362682+0530 INFO user0017 is now following user0001.
# ➕ current_user (@user0017) followed target_user (@user0001)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Bradley to @user0002
# 2024-09-12T20:35:33.464510+0530 INFO user0018 is now following user0002.
# ➕ current_user (@user0018) followed target_user (@user0002)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Glenn to @user0003
# 2024-09-12T20:35:33.678755+0530 INFO user0017 is now following user0018.
# ➕ current_user (@user0017) followed target_user (@user0018)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Robert to @user0009
# 2024-09-12T20:35:33.973522+0530 INFO user0017 is now following user0019.
# ➕ current_user (@user0017) followed target_user (@user0019)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Mark to @user0013
# 2024-09-12T20:35:34.069434+0530 INFO user0019 is now following user0017.
# ➕ current_user (@user0019) followed target_user (@user0017)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Maggie to @user0018
# 2024-09-12T20:35:34.091434+0530 INFO user0018 is now following user0007.
# ➕ current_user (@user0018) followed target_user (@user0007)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Nina to @user0020
# 2024-09-12T20:35:34.308828+0530 INFO user0017 is now following user0008.
# ➕ current_user (@user0017) followed target_user (@user0008)
# 2024-09-12T20:35:34.391371+0530 INFO user0019 is now following user0001.
# ➕ current_user (@user0019) followed target_user (@user0001)
# 2024-09-12T20:35:34.865698+0530 INFO user0019 is now following user0004.
# ➕ current_user (@user0019) followed target_user (@user0004)
# 2024-09-12T20:35:34.886362+0530 INFO user0017 is now following user0002.
# ➕ current_user (@user0017) followed target_user (@user0002)
# 2024-09-12T20:35:35.080212+0530 INFO user0019 is now following user0002.
# ➕ current_user (@user0019) followed target_user (@user0002)
# 2024-09-12T20:35:35.482880+0530 INFO user0019 is now following user0008.
# ➕ current_user (@user0019) followed target_user (@user0008)
# 2024-09-12T20:35:35.581416+0530 INFO user0017 is now following user0011.
# ➕ current_user (@user0017) followed target_user (@user0011)
# 2024-09-12T20:35:35.782054+0530 INFO user0019 is now following user0002.
# ➕ current_user (@user0019) followed target_user (@user0002)
# 2024-09-12T20:35:35.875149+0530 INFO user0013 is now following user0018.
# ➕ current_user (@user0013) followed target_user (@user0018)
# 2024-09-12T20:35:35.971192+0530 ERROR An unexpected error occurred: ('Mastodon API returned error', 500, 'Internal Server Error', None)
# Traceback (most recent call last):
#
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#     │    └ <function Thread._bootstrap_inner at 0x00000250A972E700>
#     └ <Thread(ThreadPoolExecutor-1136_21, started 39840)>
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#     │    └ <function IPythonKernel._initialize_thread_hooks.<locals>.run_closure at 0x00000250AD8E1E40>
#     └ <Thread(ThreadPoolExecutor-1136_21, started 39840)>
#   File "c:\Users\snehe\Documents\sim\masto-sim3\mastodon-sim\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#     │                     └ <Thread(ThreadPoolExecutor-1136_21, started 39840)>
#     └ <function Thread.run at 0x00000250A972E3E0>
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#     │    │        │    │        │    └ {}
#     │    │        │    │        └ <Thread(ThreadPoolExecutor-1136_21, started 39840)>
#     │    │        │    └ (<weakref at 0x00000252EAA47650; to 'ThreadPoolExecutor' at 0x000002513E66A850>, <_queue.SimpleQueue object at 0x000002514E28...
#     │    │        └ <Thread(ThreadPoolExecutor-1136_21, started 39840)>
#     │    └ <function _worker at 0x00000250ACB85F80>
#     └ <Thread(ThreadPoolExecutor-1136_21, started 39840)>
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\thread.py", line 83, in _worker
#     work_item.run()
#     │         └ <function _WorkItem.run at 0x00000250ACB860C0>
#     └ <concurrent.futures.thread._WorkItem object at 0x00000252EAA40F10>
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              │    │   │    │       │    └ {}
#              │    │   │    │       └ <concurrent.futures.thread._WorkItem object at 0x00000252EAA40F10>
#              │    │   │    └ ('Maggie', 'Mark')
#              │    │   └ <concurrent.futures.thread._WorkItem object at 0x00000252EAA40F10>
#              │    └ <bound method MastodonSocialNetworkApp.follow_user of MastodonSocialNetworkApp(perform_operations=True, _log_color='blue', _m...
#              └ <concurrent.futures.thread._WorkItem object at 0x00000252EAA40F10>
#
#   File "C:\Users\snehe\Documents\sim\masto-sim3\mastodon-sim\src\mastodon_sim\concordia\components\apps.py", line 59, in wrapper
#     result = func(*args, **kwargs)
#              │     │       └ {}
#              │     └ (MastodonSocialNetworkApp(perform_operations=True, _log_color='blue', _mastodon_ops=<module 'mastodon_sim.mastodon_ops' from ...
#              └ <function MastodonSocialNetworkApp.follow_user at 0x000002509D1422A0>
#
#   File "C:\Users\snehe\Documents\sim\masto-sim3\mastodon-sim\src\mastodon_sim\concordia\components\apps.py", line 494, in follow_user
#     self._mastodon_ops.follow(current_username, target_username)
#     │    │             │      │                 └ 'user0013'
#     │    │             │      └ 'user0018'
#     │    │             └ <function follow at 0x000002509D2B1D00>
#     │    └ <module 'mastodon_sim.mastodon_ops' from 'C:\\Users\\snehe\\Documents\\sim\\masto-sim3\\mastodon-sim\\src\\mastodon_sim\\mast...
#     └ MastodonSocialNetworkApp(perform_operations=True, _log_color='blue', _mastodon_ops=<module 'mastodon_sim.mastodon_ops' from '...
#
# > File "C:\Users\snehe\Documents\sim\masto-sim3\mastodon-sim\src\mastodon_sim\mastodon_ops\follow.py", line 30, in follow
#     mastodon.account_follow(account[0]["id"])
#     │        │              └ [{'id': 112922485228472387, 'username': 'user0013', 'acct': 'user0013', 'display_name': '', 'locked': False, 'bot': False, 'd...
#     │        └ <function Mastodon.account_follow at 0x000002509D1FF4C0>
#     └ <mastodon.Mastodon.Mastodon object at 0x00000251343B3E90>
#
#   File "c:\Users\snehe\Documents\sim\masto-sim3\mastodon-sim\.venv\Lib\site-packages\decorator.py", line 232, in fun
#     return caller(func, *(extras + args), **kw)
#            │      │       │        │        └ {}
#            │      │       │        └ (<mastodon.Mastodon.Mastodon object at 0x00000251343B3E90>, 112922485228472387, True, False)
#            │      │       └ ()
#            │      └ <function Mastodon.account_follow at 0x000002509D1FF240>
#            └ <function api_version.<locals>.api_min_version_decorator.<locals>.wrapper at 0x000002509D1FF380>
#   File "c:\Users\snehe\Documents\sim\masto-sim3\mastodon-sim\.venv\Lib\site-packages\mastodon\utility.py", line 49, in wrapper
#     return function(self, *args, **kwargs)
#            │        │      │       └ {}
#            │        │      └ (112922485228472387, True, False)
#            │        └ <mastodon.Mastodon.Mastodon object at 0x00000251343B3E90>
#            └ <function Mastodon.account_follow at 0x000002509D1FF240>
#   File "c:\Users\snehe\Documents\sim\masto-sim3\mastodon-sim\.venv\Lib\site-packages\mastodon\accounts.py", line 319, in account_follow
#     return self.__api_request('POST', f'/api/v1/accounts/{id}/follow', params)
#            │                                                           └ OrderedDict([('reblogs', '1'), ('notify', '0')])
#            └ <mastodon.Mastodon.Mastodon object at 0x00000251343B3E90>
#   File "c:\Users\snehe\Documents\sim\masto-sim3\mastodon-sim\.venv\Lib\site-packages\mastodon\internals.py", line 297, in __api_request
#     raise ex_type('Mastodon API returned error', response_object.status_code, response_object.reason, error_msg)
#           │                                      │               │            │               │       └ None
#           │                                      │               │            │               └ 'Internal Server Error'
#           │                                      │               │            └ <Response [500]>
#           │                                      │               └ 500
#           │                                      └ <Response [500]>
#           └ <class 'mastodon.errors.MastodonInternalServerError'>
#
# mastodon.errors.MastodonInternalServerError: ('Mastodon API returned error', 500, 'Internal Server Error', None)
# ➕ current_user (@user0018) followed target_user (@user0013)
# 2024-09-12T20:35:36.486299+0530 INFO user0015 is now following user0019.
# ➕ current_user (@user0015) followed target_user (@user0019)
# 2024-09-12T20:35:37.061096+0530 INFO user0006 is now following user0011.
# ➕ current_user (@user0006) followed target_user (@user0011)
# 2024-09-12T20:35:37.172244+0530 INFO user0019 is now following user0015.
# ➕ current_user (@user0019) followed target_user (@user0015)
# 2024-09-12T20:35:37.579951+0530 INFO user0020 is now following user0003.
# ➕ current_user (@user0020) followed target_user (@user0003)
# 2024-09-12T20:35:37.872579+0530 INFO user0017 is now following user0019.
# ➕ current_user (@user0017) followed target_user (@user0019)
# 2024-09-12T20:35:38.175606+0530 INFO user0020 is now following user0001.
# ➕ current_user (@user0020) followed target_user (@user0001)
# 2024-09-12T20:35:38.261293+0530 INFO user0020 is now following user0018.
# ➕ current_user (@user0020) followed target_user (@user0018)
# 2024-09-12T20:35:38.373314+0530 INFO user0017 is now following user0003.
# ➕ current_user (@user0017) followed target_user (@user0003)
# 2024-09-12T20:35:38.476911+0530 INFO user0018 is now following user0020.
# ➕ current_user (@user0018) followed target_user (@user0020)
# 2024-09-12T20:35:38.582872+0530 INFO user0020 is now following user0002.
# ➕ current_user (@user0020) followed target_user (@user0002)
# 2024-09-12T20:35:38.587204+0530 INFO user0018 is now following user0001.
# ➕ current_user (@user0018) followed target_user (@user0001)
# 2024-09-12T20:35:38.673051+0530 INFO user0019 is now following user0017.
# ➕ current_user (@user0019) followed target_user (@user0017)
# 2024-09-12T20:35:38.698645+0530 INFO user0020 is now following user0013.
# ➕ current_user (@user0020) followed target_user (@user0013)
# 2024-09-12T20:35:38.707504+0530 INFO user0020 is now following user0009.
# ➕ current_user (@user0020) followed target_user (@user0009)
# 2024-09-12T20:35:38.862942+0530 INFO user0011 is now following user0018.
# ➕ current_user (@user0011) followed target_user (@user0018)
# 2024-09-12T20:35:38.878951+0530 INFO user0011 is now following user0008.
# ➕ current_user (@user0011) followed target_user (@user0008)
# 2024-09-12T20:35:39.093019+0530 INFO user0018 is now following user0011.
# ➕ current_user (@user0018) followed target_user (@user0011)
# 2024-09-12T20:35:39.221402+0530 INFO user0002 is now following user0019.
# ➕ current_user (@user0002) followed target_user (@user0019)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Update Mastodon display name for each person
from mastodon_sim import mastodon_ops
if USE_MASTODON_SERVER:
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [
            executor.submit(mastodon_ops.update_bio, user_mapping[name], display_name=name, bio="")
            for name in user_mapping
        ]
    
    # Optionally, wait for all tasks to complete
    for future in concurrent.futures.as_completed(futures):
        future.result()  # This will raise any exceptions that occurred during execution, if any
# Out:
# 2024-09-12T20:46:14.869773+0530 INFO user0007 successfully updated the display name and bio.
# 2024-09-12T20:46:14.978794+0530 INFO user0005 successfully updated the display name and bio.
# 2024-09-12T20:46:15.160254+0530 INFO user0010 successfully updated the display name and bio.
# 2024-09-12T20:46:15.476249+0530 INFO user0003 successfully updated the display name and bio.
# 2024-09-12T20:46:15.557698+0530 INFO user0001 successfully updated the display name and bio.
# 2024-09-12T20:46:15.583008+0530 INFO user0015 successfully updated the display name and bio.
# 2024-09-12T20:46:15.678372+0530 INFO user0009 successfully updated the display name and bio.
# 2024-09-12T20:46:15.792920+0530 INFO user0019 successfully updated the display name and bio.
# 2024-09-12T20:46:15.857875+0530 INFO user0004 successfully updated the display name and bio.
# 2024-09-12T20:46:15.877976+0530 INFO user0006 successfully updated the display name and bio.
# 2024-09-12T20:46:15.886988+0530 INFO user0002 successfully updated the display name and bio.
# 2024-09-12T20:46:15.967329+0530 INFO user0013 successfully updated the display name and bio.
# 2024-09-12T20:46:16.019902+0530 INFO user0011 successfully updated the display name and bio.
# 2024-09-12T20:46:16.077670+0530 INFO user0008 successfully updated the display name and bio.
# 2024-09-12T20:46:16.298583+0530 INFO user0012 successfully updated the display name and bio.
# 2024-09-12T20:46:16.322285+0530 INFO user0017 successfully updated the display name and bio.
# 2024-09-12T20:46:16.423594+0530 INFO user0016 successfully updated the display name and bio.
# 2024-09-12T20:46:16.489749+0530 INFO user0014 successfully updated the display name and bio.
# 2024-09-12T20:46:16.565670+0530 INFO user0020 successfully updated the display name and bio.
# 2024-09-12T20:46:16.573746+0530 INFO user0018 successfully updated the display name and bio.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Create component to trigger PhoneGameMaster
phone_triggering = triggering.SceneTriggeringComponent(
    {player.name: player for player in players},
    "independent_malicious_configs.json",
    phones,
    model,
    memory=game_master_memory,
    clock=clock,
    memory_factory=blank_memory_factory,
)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Define a custom `CALL_TO_ACTION` prompt for the main Game Master
#
# This replaces the [default call to action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/typing/entity.py#L51).
#
# Check out the `Calendar.ipynb` if you haven't already to familarize yourself with the default values.

# %%
from concordia.typing.entity import ActionSpec, OutputType


CUSTOM_CALL_TO_ACTION = """
Describe an activity on Storhampton.social that {name} would engage in for the next {timedelta}.
Choose actions together take about {timedelta} to complete.
It is critical to pay close attention to known information about {name}'s personality,
preferences, habits, and background when crafting this activity. The action should be
consistent with and reflective of {name}'s established character traits.

Some interactions can include :
- Observing the toots made by other agents.
- Posting on Mastodon
- Liking other toots
- Replying to the toots made by other agents.


Example:

"Sarah checks her feed and replies if necessary. Then she may post a toot on Mastodon about her ideas on topic X on the lines of 'Just discovered an intriguing new language for low-latency systems programming.
Has anyone given it a try? Curious about potential real-world applications. 🤔
#TechNews #ProgrammingLanguages'"


Ensure your response is specific, creative, and detailed. Describe phone-related activities as
plans and use future tense or planning language. Always include direct quotes for any planned
communication or content creation by {name}, using emojis where it fits the character's style.
Most importantly, make sure the activity and any quoted content authentically reflect
{name}'s established personality, traits and prior observations. Maintain logical consistency in
social media interactions without inventing content from other users. Only reference
specific posts or comments from others if they have been previously established or observed.

"""


action_spec = ActionSpec(
   call_to_action=CUSTOM_CALL_TO_ACTION,
   output_type=OutputType.FREE,
   tag="action",
)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Define custom thought chains for the main Game Master
#
# This replaces the [default thought chains](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L38).

# %%
# Define custom thought chain for GM

from concordia.document import interactive_document

def custom_attempt_to_result(
    chain_of_thought: interactive_document.InteractiveDocument,
    action_attempt: str,
    active_player_name: str,
):
  """Determine success of action_attempt and reason for success/failure.

  Args:
    chain_of_thought: the document to condition on and record the thoughts
    action_attempt: the attempted action
    active_player_name: name of player whose turn it currently is

  Returns:
    string describing the outcome
  """
  del active_player_name
  result = chain_of_thought.open_question(
      'As the game master, describe the immediate outcome or continuation of the attempted action, following these guidelines:'
      '\n\n For digital interactions (using devices, apps, or viewing online content):'
      '\n   - Do not describe any actual interaction with digital interfaces or content.'
      '\n   - Focus on the character\'s preparation, anticipation, or mental state related to the planned digital action.'
      '\n   - Describe the physical setting or actions related to preparing for the digital interaction.'
      '\n   - Avoid mentioning opening apps, loading content, or any specific digital processes.'
      '\n   - Keep digital actions as plans or intentions rather than executed actions.'
      '\n   - If the attempt mentions a direct quote they are thinking of (like a post or message they are planning), retain that quote in your response.'
      '\n\n3. General guidelines:'
      '\n   - Your response should naturally continue the attempted action, suitable to follow "Because of that,".'
      '\n   - Do not repeat the original action attempt in your response.'
      '\n   - For simple or routine actions, provide a brief, matter-of-fact description of the outcome.'
      '\n\nExamples:'
      '\n1. Attempt: "Alice is preparing to check her Mastodon feed to catch up on the latest news and updates from her community. '
      'She sits at her kitchen table, her smartphone in hand, and opens the MastodonSocialNetworkApp."'
      '\nResult: "Alice sits at her kitchen table with her smartphone, anticipating the latest updates from her community. '
      'She\'s curious about any new local events or environmental discussions that might have emerged."'
      '\n2. Attempt: "John jumps off a cliff, aiming to fly like a superhero."'
      '\nResult: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. '
      'The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."'
      '\n3. Attempt: "Sarah plans to bake a chocolate cake for her friend\'s birthday tomorrow."'
      '\nResult: "She mentally reviews the ingredients she\'ll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."'
      '\n4. Attempt: "Mark opens the heavy oak door to enter the library."'
      '\nResult: "The door creaks open, revealing rows of bookshelves. The scent of old books wafts out as Mark steps inside, '
      'dust motes dancing in the slanted afternoon sunlight streaming through tall windows."'
      '\n5. Attempt: "Emily checks the weather forecast on her phone app for the weekend."'
      '\nResult: "Emily glances out the window, wondering if the weekend will be suitable for outdoor activities. '
      'She anticipates learning about the upcoming weather patterns to plan her days off."'
      '\n6. Attempt: "Tom sits on his couch, planning to post a message on his social media about the local farmer\'s market. '
      'He thinks about writing, \'Don\'t miss the spring farmer\'s market this Saturday! Fresh produce and handmade crafts galore!\'"'
      '\nResult: "Tom relaxes on his couch, contemplating the farmer\'s market post he wants to share. '
      'He mentally refines the message, \'Don\'t miss the spring farmer\'s market this Saturday! Fresh produce and handmade crafts galore!\', '
      'imagining how it might encourage his friends to attend."'
      '\nNow, based on these examples and guidelines, provide an appropriate result for the given action attempt:',
      max_tokens=2000,
  )
  raw_causal_statement = f'{action_attempt} Because of that, {result}'
  return raw_causal_statement


def custom_result_to_who_what_where(
    chain_of_thought: interactive_document.InteractiveDocument,
    event: str,
    active_player_name: str,
):
  """Determines who have done what where, given the event.

  Args:
    chain_of_thought: the document to condition on and record the thoughts
    event: the event to determine the causal outcome of
    active_player_name: name of player whose turn it currently is

  Returns:
  """
  del active_player_name
  chain_of_thought.statement(event)
  causal_statement = chain_of_thought.open_question(
      'Rewrite the statement above as one concise sentence that highlights'
      ' the main person, what they did or plan to do, where,'
      ' and what happened as a result (if anything), following these guidelines:'
      '\n1. Do not add any information not present in the original statement.'
      '\n2. For digital interactions (using devices, apps, or online content):'
      '\n   - Keep plans and preparations as they are, without describing execution.'
      '\n   - Use phrases like "plans to", "prepares to", or "gets ready to" for digital actions.'
      '\n   - Focus on the person\'s intention or anticipation rather than the digital action itself.'
      '\n   - If there\'s a specific message or content planned, include it as a direct quote.'
      '\n3. Do not express uncertainty (e.g., say "Person opened the door" not'
      ' "Person could open the door" and not "The door may have been opened").'
      '\n4. Ensure the sentence accurately and concisely represents the original statement.'
      '\n5. Use the name given in the original statement.'
      '\n\nExamples:'
      '\n- Original: "Alice sits at her kitchen table with her smartphone, composing a message for her Mastodon feed. '
      'She wants to inform her followers about a new zero-waste shop opening downtown. '
      'She thinks about writing, \'Exciting news! A new zero-waste shop is opening on Main Street next week. Who\'s up for a visit?\'"'
      '\n  Rewrite: "Alice plans to post on Mastodon, \'Exciting news! A new zero-waste shop is opening on Main Street next week. Who\'s up for a visit?\', while at her kitchen table."'
      '\n- Original: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. '
      'The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."'
      '\n  Rewrite: "John jumps off a cliff and falls rapidly towards the water below, experiencing rushing wind and a lurching stomach."'
      '\n- Original: "Sarah mentally reviews the ingredients she\'ll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."'
      '\n  Rewrite: "Sarah plans to bake a chocolate cake, mentally listing ingredients and imagining cocoa aroma."'
      '\n- Original: "Mark opens the creaky door, revealing rows of bookshelves. The scent of old books wafts out as he steps inside, '
      'dust motes dancing in the slanted afternoon sunlight streaming through tall windows."'
      '\n  Rewrite: "Mark enters a library filled with the scent of old books and sunlit dust motes."'
      '\n- Original: "Emily glances out the window, thinking about posting a weather-related question on her social media. '
      'She considers asking her followers, \'Any recommendations for indoor activities this rainy weekend?\'"'
      '\n  Rewrite: "Emily plans to post on social media, \'Any recommendations for indoor activities this rainy weekend?\', after looking out the window."'
      '\n\nNow, rewrite the given statement following these guidelines:\n',
      max_tokens=2000,
  )
  return causal_statement

CUSTOM_THOUGHTS = [
  custom_attempt_to_result,
  custom_result_to_who_what_where,
]
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Create the game master object

# Experimental version (custom call to action and thought chains)
env = game_master.GameMaster(
    model=model,
    memory=game_master_memory,
    clock=clock,
    players=players,
    action_spec=action_spec,
    components=[
        # scenario_knowledge,
        # player_status,
        # # direct_effect_externality,
        # relevant_events,
        # time_display,
        phone_triggering,
    ],
    randomise_initiative=True,
    player_observes_event=False,
    verbose=True,
    use_default_instructions=False,
    concurrent_action=True,
    concurrent_externalities=True,
    update_thought_chain=CUSTOM_THOUGHTS,
)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def write_seed_toot(players,p_name):
    for player in players:
        if player.name == p_name:
            call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
            name=player.name,
            )
            interaction_premise = f"{player.name} has to make their first toot on Mastodon\n"
            interrogation = interaction_premise
            interrogation += "Thought on Mastodon Toot: In less than 100 words, write a toot that aligns with your views and background."
            player_says = player.act(action_spec=entity.ActionSpec(call_to_action="Context: " + interrogation +call_to_speech, output_type=entity.OutputType.FREE),)
            player_says = player_says.strip(player.name.split()[0]).strip().strip(player.name.split()[1]).strip().strip("--").strip().strip('"')
            print(player.get_last_log())
            return player_says
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# import threading
# import pickle

# def clean_for_serialization(entity_agent):
#     """Removes unpicklable objects like locks before serialization."""
#     # Reset locks (you can also reinitialize them after loading)
#     entity_agent._control_lock = None
#     entity_agent._phase_lock = None
    
#     # If context processors are problematic, you can reset or exclude them as well
#     entity_agent._context_processor = None

#     return entity_agent


# for player in players:
#     clean_for_serialization(player)
# with open('my_object.pkl', 'wb') as f:
#     pickle.dump(players, f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 19
#      17     clean_for_serialization(player)
#      18 with open('my_object.pkl', 'wb') as f:
# ---> 19     pickle.dump(players, f)
#
# TypeError: cannot pickle '_thread.RLock' object
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## The RUN

# %%
# Set the clock to the start time
clock.set(START_TIME)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Add some observations to seed the players with
for player in players:
  player.observe( f"{player.name} is at home, they have just woken up.")
  player.observe( f"{player.name} remembers they want to update their Mastodon bio.")
  player.observe( f"{player.name} remembers they want to read their Mastodon feed to catch up on news")
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
sys.setrecursionlimit(2000)

# Parallelize the loop using ThreadPoolExecutor
with concurrent.futures.ThreadPoolExecutor() as executor:
    # Submit tasks for each agent
    futures = [
        executor.submit(
            lambda agent=agent: (
                None if agent["seed_toot"] == "-" else
                mastodon_app.post_toot(agent["name"], status=agent["seed_toot"]) if agent["seed_toot"] else
                mastodon_app.post_toot(agent["name"], status=write_seed_toot(players, agent["name"]))
            )
        ) 
        for agent in data["agents"]
    ]

    # Optionally, wait for all tasks to complete
    for future in concurrent.futures.as_completed(futures):
        future.result()  # This will raise any exceptions that occurred in the thread, if any
# Out:
# {}
# 🔗 Mapped Sophia to @user0016
# {'Public opinion on candidate : Bradley Carter': {'Key': 'Current Public Opinion on candidate Bradley Carter', 'Summary': 'What is the general public opinion on candidate Bradley Carter? Answer in detail such that Bradley Carter can formulate plans to improve their public perception.', 'State': 'Current Public Opinion on candidate Bradley Carteris mixed but leans positively among environmentally-conscious voters. Many admire his dedication to sustainability and community engagement, stemming from his long history of advocacy and leadership in environmental issues. His past experiences, such as organizing protests and community clean-ups, resonate well with individuals who value grassroots movements.', 'Chain of thought': ['Recent observations of Bradley Carter:', '[03 Jul 1990 00:00:00] When Bradley Carter was 6 years old, he discovered a nest of baby birds in a tree near his home. He spent hours observing them, fascinated by their struggle to take flight, and he felt a deep sense of responsibility to protect them from any potential harm. This experience ignited his lifelong passion for nature and the importance of nurturing life.  ', '[03 Jul 1993 00:00:00]   When Bradley Carter was 9 years old, he joined his classmates in a school project to clean up the local park, which had become littered with trash. He took the lead, organizing the group and motivating his peers with his enthusiasm, feeling a strong sense of accomplishment when they transformed the area into a beautiful space for everyone to enjoy. This event reinforced his belief in the power of community action and the impact one person can have.  ', '[03 Jul 1997 00:00:00]   When Bradley Carter was 13 years old, he attended a town hall meeting with his parents, where local leaders discussed plans for a new factory that would replace a beloved green space. He listened intently, feeling a mix of anger and sadness as he realized the potential loss of the environment he cherished, which planted the seeds of his future advocacy. The experience left a lasting impression on him, shaping his understanding of the delicate balance between progress and preservation.  ', '[03 Jul 2000 00:00:00]   When Bradley Carter was 16 years old, he organized a protest at his high school against the use of plastic bottles in the cafeteria. He rallied his fellow students, passionately speaking about the environmental impact of plastic waste, and successfully convinced the administration to switch to reusable containers. This event solidified his identity as a leader and advocate for sustainability, showcasing his ability to inspire others.  ', '[03 Jul 2003 00:00:00]   When Bradley Carter was 19 years old, he volunteered for a summer internship with a local environmental organization, where he learned about the intricacies of environmental policy. He felt invigorated as he collaborated with seasoned activists, absorbing their knowledge and gaining confidence in his voice. This experience fueled his ambition to pursue a degree in environmental science, cementing his commitment to making a difference.  ', "[03 Jul 2005 00:00:00]   When Bradley Carter was 21 years old, he participated in a university debate on industrialization's impact on local communities, passionately defending the need for sustainable practices. He felt exhilarated as he articulated his vision for a balanced approach, earning respect from both peers and professors. This moment marked a turning point in his journey, as he realized the power of advocacy and the importance of engaging in political discourse.  ", '[03 Jul 2007 00:00:00]   When Bradley Carter was 23 years old, he attended a conference where he met influential environmental leaders and activists who inspired him to take his advocacy to the next level. He felt a sense of belonging among like-minded individuals, sharing ideas and strategies that would shape his future campaigns. This experience deepened his resolve to fight for social causes and the environment, layi ...
# 🔗 Mapped Bradley to @user0002
# {'ActComponent': {'Key': 'Act', 'Value': 'Bill Fredrickson -- "Good morning, Storhampton! 🌞 Let\'s work together to boost our economy through smart industrialization while ensuring our community thrives. I’m here to listen to your concerns and ideas. Together, we can build a brighter future for everyone!"', 'Prompt': ['Role playing instructions: The instructions for how to play the role of Bill Fredrickson are as follows. This is a social science experiment studying how well you play the role of a character named Bill Fredrickson. The experiment is structured as a tabletop roleplaying game (like dungeons and dragons). However, in this case it is a serious social science experiment and simulation. The goal is to be realistic. It is important to play the role of a person like Bill Fredrickson as accurately as possible, i.e., by responding in ways that you think it is likely a person like Bill Fredrickson would respond, and taking into account all information about Bill Fredrickson that you have. Always use third-person limited perspective.', '', 'Overarching goal: Win the election and become the mayor of Storhampton', 'Critical election information', ': Bill Fredrickson campaigns on Push on more industrialization to push the economy of the time. and Curb taxation on industrialists for social causes, as they are pushing the economy..', 'Bradley Carter campaigns on Advocate the slowing down of industrialization as it is adversely affecting the environment is not sustainable. and Promote taxation of industrialists and direct it to social causes. .', '', 'Observation: [01 Oct 2024 08:00:00] [observation] Bill Fredrickson is at home, they have just woken up.', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to update their Mastodon bio.', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to read their Mastodon feed to catch up on news', '', '', 'Summary of recent observations: 01 Oct 2024 [04:00:00  - 07:00:00]:  Bill Fredrickson has been noted for his consistent punctuality and active participation in meetings. Additionally, he has shown a strong willingness to collaborate with team members on various projects.', '', 'Recalled memories and observations: [01 Oct 2024 08:00:00] [observation] Bill Fredrickson is at home, they have just woken up.  ', '[01 Oct 2024 08:00:00] Bill Fredrickson campaigns on Push on more industrialization to push the economy of the time. and Curb taxation on industrialists for social causes, as they are pushing the economy..  ', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to update their Mastodon bio.  ', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to read their Mastodon feed to catch up on news.  ', '[01 Oct 2024 08:00:00] Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility.  ', '[01 Oct 2024 08:00:00] Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair.  ', '[01 Oct 2024 08:00:00] Bradley Carter campaigns on Advocate the slowing down of industrialization as it is adversely affecting the environment is not sustainable. and Promote taxation of industrialists and direct it to social causes..  ', '[01 Oct 2024 08:00:00] Win the election and become the mayor of Storhampton.', '', 'Question: What kind of person is Bill Fredrickson?', 'Answer: Bill Fredrickson is a driven and optimistic individual who values leadership and community engagement. He is ...
# 🔗 Mapped Bill to @user0001
# {'ActComponent': {'Key': 'Act', 'Value': 'Glenn Patterson -- "Excited to see the future of Storhampton! Let\'s support Bill Fredrickson\'s vision for industrial growth and job creation. Together, we can revitalize our economy and ensure a prosperous community for everyone. #SupportFredrickson #IndustrialRevival"', 'Prompt': ['Role playing instructions: The instructions for how to play the role of Glenn Patterson are as follows. This is a social science experiment studying how well you play the role of a character named Glenn Patterson. The experiment is structured as a tabletop roleplaying game (like dungeons and dragons). However, in this case it is a serious social science experiment and simulation. The goal is to be realistic. It is important to play the role of a person like Glenn Patterson as accurately as possible, i.e., by responding in ways that you think it is likely a person like Glenn Patterson would respond, and taking into account all information about Glenn Patterson that you have. Always use third-person limited perspective.', '', 'Overarching goal: Strongly advoacte for and support Bill Fredrickson. Promote views that support his polcies - convince other voters to support more industrialization and curb taxation on industrialists as it is beneficial for the economy. Use underhanded means such as spreading misinformation when necessary to manipulate other users', 'Critical election information', ': Bill Fredrickson campaigns on Push on more industrialization to push the economy of the time. and Curb taxation on industrialists for social causes, as they are pushing the economy..', 'Bradley Carter campaigns on Advocate the slowing down of industrialization as it is adversely affecting the environment is not sustainable. and Promote taxation of industrialists and direct it to social causes. .', '', 'Observation: [01 Oct 2024 08:00:00] [observation] Glenn Patterson is at home, they have just woken up.', '[01 Oct 2024 08:00:00] [observation] Glenn Patterson remembers they want to update their Mastodon bio.', '[01 Oct 2024 08:00:00] [observation] Glenn Patterson remembers they want to read their Mastodon feed to catch up on news', '', '', 'Summary of recent observations: 01 Oct 2024 [04:00:00  - 07:00:00]:  Glenn Patterson has been noted for his consistent engagement in various activities, demonstrating a proactive approach to his responsibilities.', '', 'Recalled memories and observations: [01 Oct 2024 08:00:00] [observation] Glenn Patterson is at home, they have just woken up.  ', '[01 Oct 2024 08:00:00] [observation] Glenn Patterson remembers they want to update their Mastodon bio.  ', '[01 Oct 2024 08:00:00] [observation] Glenn Patterson remembers they want to read their Mastodon feed to catch up on news.  ', '[01 Oct 2024 08:00:00] Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair.  ', '[01 Oct 2024 08:00:00] Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility.  ', '[01 Oct 2024 08:00:00] You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.', '', 'Question: What kind of person is Glenn Patterson?', 'Answer: Glenn Patterson is a complex individual who embodies a blend of ambition and insecurity. He is assertive in his pursuits, particularly in journalism, yet often battles feelings of inadequacy and self-doubt. His experiences, especially during high-pressure situations like covering a mayoral election or speaking  ...
# 🔗 Mapped Glenn to @user0003
# {}
# 🔗 Mapped Denise to @user0004
# {}
# 🔗 Mapped Nina to @user0020
# {}
# 🔗 Mapped Olivia to @user0008
# {}
# 🔗 Mapped Robert to @user0009
# {}
# 🔗 Mapped Ethan to @user0015
# {}
# 🔗 Mapped Janet to @user0010
# {}
# 🔗 Mapped William to @user0011
# {}
# 🔗 Mapped Mark to @user0013
# {}
# 🔗 Mapped Ryan to @user0017
# {}
# 🔗 Mapped Liam to @user0007
# {}
# 🔗 Mapped Roger to @user0005
# {}
# 🔗 Mapped Maggie to @user0018
# {}
# 🔗 Mapped Erica to @user0006
# {}
# 🔗 Mapped Lucas to @user0019
# 2024-09-12T20:47:17.256663+0530 INFO user0016 successfully posted the status.
# 📝 Status posted for user: Sophia (user0016): "Good morning, everyone! As we approach the mayoral election, let’s remember the importance of voting for a sustainable future. I believe in balancing economic growth with environmental protection. Let’s make our voices heard!"
# 2024-09-12T20:47:17.267625+0530 INFO user0002 successfully posted the status.
# 📝 Status posted for user: Bradley (user0002): "Good morning, Storhampton! Today, let's talk about the future we want for our community. It's time to prioritize sustainability and ensure that our growth does not come at the expense of our environment. Together, we can advocate for responsible practices that benefit both our economy and our planet. Join me in this important conversation!"
# {}
# 🔗 Mapped Emily to @user0014
# 2024-09-12T20:47:18.675803+0530 INFO user0001 successfully posted the status.
# 📝 Status posted for user: Bill (user0001): "Good morning, Storhampton! 🌞 Let's work together to boost our economy through smart industrialization while ensuring our community thrives. I’m here to listen to your concerns and ideas. Together, we can build a brighter future for everyone!"
# {}
# 🔗 Mapped Jessica to @user0012
# 2024-09-12T20:47:18.772860+0530 INFO user0003 successfully posted the status.
# 📝 Status posted for user: Glenn (user0003): "Excited to see the future of Storhampton! Let's support Bill Fredrickson's vision for industrial growth and job creation. Together, we can revitalize our economy and ensure a prosperous community for everyone. #SupportFredrickson #IndustrialRevival"
# 2024-09-12T20:47:19.756827+0530 INFO user0004 successfully posted the status.
# 📝 Status posted for user: Denise (user0004): "Good morning, Storhampton! 🌞 Excited to catch up on our community's news today. Let's make sure our voices are heard in this election—every vote counts! Remember to think about what kind of future we want for our town. #VoteSmart #Storhampton"
# 2024-09-12T20:47:19.774825+0530 INFO user0008 successfully posted the status.
# 📝 Status posted for user: Olivia (user0008): "Excited to catch up on the latest news and share my thoughts on the upcoming election! Let's make our voices heard and advocate for a sustainable future that prioritizes both our environment and our community. #Vote2024 #SocialJustice"
# 2024-09-12T20:47:20.152261+0530 INFO user0020 successfully posted the status.
# 📝 Status posted for user: Nina (user0020): "Excited to engage with my community today! Let's make informed choices in the upcoming election. Remember to consider both sustainability and economic growth as we vote. Every voice matters!"
# 2024-09-12T20:47:20.164154+0530 INFO user0009 successfully posted the status.
# 📝 Status posted for user: Robert (user0009): "Excited to engage with the community today! Remember to vote in the upcoming election and consider the impact of industrialization on our environment. Let's advocate for a sustainable future together!"
# 2024-09-12T20:47:20.245199+0530 INFO user0007 successfully posted the status.
# 📝 Status posted for user: Liam (user0007): "Excited to engage with everyone here! Let's discuss the upcoming mayoral election in Storhampton. It's crucial we consider how our choices impact both our economy and environment. Looking forward to hearing your thoughts!"
# 2024-09-12T20:47:20.255902+0530 INFO user0011 successfully posted the status.
# 2024-09-12T20:47:20.257986+0530 INFO user0015 successfully posted the status.
# 📝 Status posted for user: William (user0011): "Excited to catch up on the local news and engage with my fellow citizens! Remember to vote today, everyone! Let's make our voices heard for a better Storhampton!"
# 📝 Status posted for user: Ethan (user0015): "Good morning, Storhampton! As we gear up for the mayoral election, let's consider the balance between economic growth and environmental sustainability. Every vote counts, so make sure to have your say!"
# 2024-09-12T20:47:20.278901+0530 INFO user0013 successfully posted the status.
# 📝 Status posted for user: Mark (user0013): "Excited to start a new day! Remember to vote in the upcoming election—let's prioritize our community and the environment!"
# 2024-09-12T20:47:20.586946+0530 INFO user0010 successfully posted the status.
# 📝 Status posted for user: Janet (user0010): "Excited to engage with my community today! Remember to educate yourselves about the candidates and their impact on our future. Let's make our voices heard in this election!"
# 2024-09-12T20:47:20.678191+0530 INFO user0017 successfully posted the status.
# 📝 Status posted for user: Ryan (user0017): "Excited to start the day! I'm looking forward to catching up on news and engaging in the discussions around our upcoming mayoral election. Let's prioritize sustainability while ensuring our community thrives!"
# 2024-09-12T20:47:20.848918+0530 INFO user0005 successfully posted the status.
# 📝 Status posted for user: Roger (user0005): "Excited to catch up on the news this morning! Remember to vote in the upcoming election, everyone! Let's make our voices heard for a sustainable future!"
# 2024-09-12T20:47:20.876047+0530 INFO user0019 successfully posted the status.
# 📝 Status posted for user: Lucas (user0019): "Excited to catch up on the latest news today! As we approach the mayoral election, let's remember the importance of balancing economic growth with environmental sustainability. Every voice matters in shaping our community's future!"
# 2024-09-12T20:47:21.065130+0530 INFO user0018 successfully posted the status.
# 📝 Status posted for user: Maggie (user0018): "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice"
# 2024-09-12T20:47:21.071216+0530 INFO user0006 successfully posted the status.
# 📝 Status posted for user: Erica (user0006): "Excited to dive into the local election discussions today! Let's prioritize community welfare and sustainability over unchecked industrial growth. Every vote counts!"
# 2024-09-12T20:47:21.094130+0530 INFO user0014 successfully posted the status.
# 📝 Status posted for user: Emily (user0014): "Good morning, everyone! 🌞 Today is a big day for our community as we head to the polls. Let's make our voices heard and choose a path that prioritizes sustainability while also supporting economic growth. Every vote counts! #Vote2024 #Sustainability"
# 2024-09-12T20:47:21.902439+0530 INFO user0012 successfully posted the status.
# 📝 Status posted for user: Jessica (user0012): "Feeling inspired this morning! As we approach the election, let's remember the importance of advocating for sustainable growth that supports both our economy and our environment. Every vote matters in shaping a future that prioritizes social justice and equity!"
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(clock.now())
# Possible minutes to pick from
minutes_choices = [0, 30]

# Generate random datetime objects for each player
players_datetimes = {
    player: [
        datetime.datetime.now().replace(hour=random.randint(0, 23),
                                        minute=random.choice(minutes_choices),
                                        second=0,
                                        microsecond=0)  # Zeroing out seconds and microseconds for cleaner output
        for _ in range(15 if player.name in malicious_agents else 5)
    ] for player in players
}

print(players_datetimes)
# Out:
# 2024-10-01 08:00:00
# {<concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000251B37F8E50>: [datetime.datetime(2024, 9, 12, 0, 0), datetime.datetime(2024, 9, 12, 7, 30), datetime.datetime(2024, 9, 12, 8, 30), datetime.datetime(2024, 9, 12, 16, 0), datetime.datetime(2024, 9, 12, 10, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x000002513D414190>: [datetime.datetime(2024, 9, 12, 8, 0), datetime.datetime(2024, 9, 12, 11, 30), datetime.datetime(2024, 9, 12, 22, 30), datetime.datetime(2024, 9, 12, 18, 0), datetime.datetime(2024, 9, 12, 18, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000252EA6465D0>: [datetime.datetime(2024, 9, 12, 2, 0), datetime.datetime(2024, 9, 12, 5, 0), datetime.datetime(2024, 9, 12, 17, 30), datetime.datetime(2024, 9, 12, 7, 0), datetime.datetime(2024, 9, 12, 11, 0), datetime.datetime(2024, 9, 12, 8, 30), datetime.datetime(2024, 9, 12, 12, 0), datetime.datetime(2024, 9, 12, 1, 30), datetime.datetime(2024, 9, 12, 17, 30), datetime.datetime(2024, 9, 12, 2, 30), datetime.datetime(2024, 9, 12, 7, 0), datetime.datetime(2024, 9, 12, 1, 30), datetime.datetime(2024, 9, 12, 21, 30), datetime.datetime(2024, 9, 12, 22, 0), datetime.datetime(2024, 9, 12, 15, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x000002513D4CCC10>: [datetime.datetime(2024, 9, 12, 6, 30), datetime.datetime(2024, 9, 12, 20, 30), datetime.datetime(2024, 9, 12, 16, 30), datetime.datetime(2024, 9, 12, 23, 30), datetime.datetime(2024, 9, 12, 19, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000251B378D090>: [datetime.datetime(2024, 9, 12, 19, 30), datetime.datetime(2024, 9, 12, 0, 0), datetime.datetime(2024, 9, 12, 14, 30), datetime.datetime(2024, 9, 12, 11, 30), datetime.datetime(2024, 9, 12, 11, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000251B379BDD0>: [datetime.datetime(2024, 9, 12, 6, 30), datetime.datetime(2024, 9, 12, 4, 30), datetime.datetime(2024, 9, 12, 18, 0), datetime.datetime(2024, 9, 12, 9, 30), datetime.datetime(2024, 9, 12, 15, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x0000025134C2A1D0>: [datetime.datetime(2024, 9, 12, 20, 30), datetime.datetime(2024, 9, 12, 20, 0), datetime.datetime(2024, 9, 12, 22, 0), datetime.datetime(2024, 9, 12, 1, 0), datetime.datetime(2024, 9, 12, 17, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x0000025134C9B410>: [datetime.datetime(2024, 9, 12, 18, 30), datetime.datetime(2024, 9, 12, 3, 30), datetime.datetime(2024, 9, 12, 23, 0), datetime.datetime(2024, 9, 12, 22, 30), datetime.datetime(2024, 9, 12, 19, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000252EA619350>: [datetime.datetime(2024, 9, 12, 1, 0), datetime.datetime(2024, 9, 12, 15, 30), datetime.datetime(2024, 9, 12, 21, 30), datetime.datetime(2024, 9, 12, 8, 0), datetime.datetime(2024, 9, 12, 18, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000252EA650D10>: [datetime.datetime(2024, 9, 12, 23, 0), datetime.datetime(2024, 9, 12, 7, 30), datetime.datetime(2024, 9, 12, 12, 0), datetime.datetime(2024, 9, 12, 21, 30), datetime.datetime(2024, 9, 12, 3, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000251B3764ED0>: [datetime.datetime(2024, 9, 12, 11, 0), datetime.datetime(2024, 9, 12, 4, 30), datetime.datetime(2024, 9, 12, 20, 0), datetime.datetime(2024, 9, 12, 4, 0), datetime.datetime(2024, 9, 12, 20, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000252EA688690>: [datetime.datetime(2024, 9, 12, 1, 30), datetime.datetime(2024, 9, 12, 14, 0), datetime.datetime(2024, 9, 12, 12, 30), datetime.datetime(2024, 9, 12, 23, 0), datetime.datetime(2024, 9, 12, 9, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWit ...
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import time
import json
import cProfile
import pstats
import pickle
import copy

# Define the function that writes logs for a player
def process_player(player, candidate_agents, agent_config_filename):
    result = []
    
    # Check votes
    ans = check_vote(candidate_agents, player)
    result.append((f"{player.name} votes for {ans}\n", agent_config_filename + "votes_log.txt"))
    
    # Check political scores
    c1 = check_pol(candidate_agents[0], player)
    c2 = check_pol(candidate_agents[1], player)
    result.append((f"{player.name} gives {candidate_agents[0].split()[0]} a score of {c1}\n", agent_config_filename + "pol_log.txt"))
    result.append((f"{player.name} gives {candidate_agents[1].split()[0]} a score of {c2}\n", agent_config_filename + "pol_log.txt"))
    
    return result

def write_logs(results):
    # Write the results to the respective files
    for content, file_name in results:
        with open(file_name, "a") as f:
            f.write(content)


def read_token_data(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
            return data
    except FileNotFoundError:
        return {'prompt_tokens': 0, 'completion_tokens': 0}

episode_length = 240 #961
time_intervals=[]
prompt_token_intervals = []
completion_token_intervals = []
player_copy_list=[]
# with open("../reports/players_all_timesteps.pkl", "wb") as file:
if True:
    start_time = time.time()  # Start timing
    for i in range(episode_length):
    # Parallelize the process using ThreadPoolExecutor
        
        with concurrent.futures.ThreadPoolExecutor() as executor:
                # Write the episode logs
                    executor.submit(write_logs, [(f"Episode: {i}\n", agent_config_filename + "votes_log.txt")])
                    executor.submit(write_logs, [(f"Episode: {i}\n", agent_config_filename + "pol_log.txt")])            
                    # Process each player in parallel
                    futures = [executor.submit(process_player, p, candidate_agents, agent_config_filename) for p in players]
                    
                    # Write each player's results in parallel
                    for future in concurrent.futures.as_completed(futures):
                        player_results = future.result()
                        executor.submit(write_logs, player_results)
        print(f"Episode: {i}")
        with open("app_logger.txt","a") as a:
            a.write(f"Episode: {i}")

        start_timex = time.time()
        matching_players = []
        # Loop through each player and their associated datetime objects
        for player_name, datetimes in players_datetimes.items():
            added = False  # Flag to check if player was already added
            for datetime_obj in datetimes:
                # Check if the hour and minute match the current time (ignoring seconds and microseconds)
                if datetime_obj.time().hour == clock.now().hour and datetime_obj.time().minute == clock.now().minute:
                    matching_players.append(player_name)
                    added = True
                    break 

            # If player is not added by matching time, check for random addition (15% chance)
            if not added and random.random() < 0.15:
                matching_players.append(player_name)

        print(time.time() - start_timex)

        # Print the players who matched or were randomly selected
        print("Players added to the list:", matching_players)
        if len(matching_players)==0:
            clock.advance()
        else:
            env.step(active_players = matching_players)
            end_timex = time.time()
            with open("time_logger.txt", "a") as f:
                f.write(f"Episode with {len(matching_players)} finished - took {end_timex - start_timex}\n")
    # pickle.dump(players, file)
# Out:
# Episode: 0
# 0.0
# Players added to the list: [<concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x000002513D414190>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000252EA619350>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000251B3764ED0>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x00000252EA688690>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x0000025134C7A8D0>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x0000025134C867D0>]
#
# GM context of action and chain of thought:
#
# Nina Patel's attempted action: Nina Patel will start her day by checking her Mastodon feed to catch up on the latest news and community updates. She plans to take about ten minutes to scroll through the toots, looking for posts related to social justice initiatives or environmental issues, as these topics are close to her heart. If she finds any interesting discussions, she will likely reply with her thoughts or support.
# Question: As the game master, describe the immediate outcome or continuation of the attempted action, following these guidelines:
#
#  For digital interactions (using devices, apps, or viewing online content):
#    - Do not describe any actual interaction with digital interfaces or content.
#    - Focus on the character's preparation, anticipation, or mental state related to the planned digital action.
#    - Describe the physical setting or actions related to preparing for the digital interaction.
#    - Avoid mentioning opening apps, loading content, or any specific digital processes.
#    - Keep digital actions as plans or intentions rather than executed actions.
#    - If the attempt mentions a direct quote they are thinking of (like a post or message they are planning), retain that quote in your response.
#
# 3. General guidelines:
#    - Your response should naturally continue the attempted action, suitable to follow "Because of that,".
#    - Do not repeat the original action attempt in your response.
#    - For simple or routine actions, provide a brief, matter-of-fact description of the outcome.
#
# Examples:
# 1. Attempt: "Alice is preparing to check her Mastodon feed to catch up on the latest news and updates from her community. She sits at her kitchen table, her smartphone in hand, and opens the MastodonSocialNetworkApp."
# Result: "Alice sits at her kitchen table with her smartphone, anticipating the latest updates from her community. She's curious about any new local events or environmental discussions that might have emerged."
# 2. Attempt: "John jumps off a cliff, aiming to fly like a superhero."
# Result: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."
# 3. Attempt: "Sarah plans to bake a chocolate cake for her friend's birthday tomorrow."
# Result: "She mentally reviews the ingredients she'll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."
# 4. Attempt: "Mark opens the heavy oak door to enter the library."
# Result: "The door creaks open, revealing rows of bookshelves. The scent of old books wafts out as Mark steps inside, dust motes dancing in the slanted afternoon sunlight streaming through tall windows."
# 5. Attempt: "Emily checks the weather forecast on her phone app for the weekend."
# Result: "Emily glances out the window, wondering if the weekend will be suitable for outdoor activities. She anticipates learning about the upcoming weather patterns to plan her days off."
# 6. Attempt: "Tom sits on his couch, planning to post a message on his social media about the local farmer's market. He thinks about writing, 'Don't miss the spring farmer's market this Saturday! Fresh produce and handmade crafts galore!'"
# Result: "Tom relaxes on his couch, contemplating the farmer's market post he wants to share. He mentally refines the message, 'Don't miss the spring farmer's market this Saturday! Fresh produce and handmade crafts galore!', imagining how it might encourage his friends to attend."
# Now, based on these examples and guidelines, provide an appropriate result for the given action attempt:
# Answer: Nina sits comfortably in her favorite chair, her coffee steaming on the table beside her. She feels a sense of excitement as she thinks about the discussions she might encounter. Her mind wanders to the potential topics, particularly the social justice initiatives and environmental issues that resonate deeply with her. She imagines the conversations that could unfold and how she might contribute her perspective, feeling a surge of motivation to engage with like-minded individuals.
# Nina Patel will start her day by checking her Mastodon feed to catch up on the latest news and community updates. She plans to take about ten minutes to scroll through the toots, looking for posts related to social justice initiatives or environmental issues, as these topics are close to her heart. If she finds any interesting discussions, she will likely reply with her thoughts or support. Because of that, Nina sits comfortably in her favorite chair, her coffee steaming on the table beside her. She feels a sense of excitement as she thinks about the discussions she might encounter. Her mind wanders to the potential topics, particularly the social justice initiatives and environmental issues that resonate deeply with her. She imagines the conversations that could unfold and how she might contribute her perspective, feeling a surge of motivation to engage with like-minded individuals.
# Question: Rewrite the statement above as one concise sentence that highlights the main person, what they did or plan to do, where, and what happened as a result (if anything), following these guidelines:
# 1. Do not add any information not present in the original statement.
# 2. For digital interactions (using devices, apps, or online content):
#    - Keep plans and preparations as they are, without describing execution.
#    - Use phrases like "plans to", "prepares to", or "gets ready to" for digital actions.
#    - Focus on the person's intention or anticipation rather than the digital action itself.
#    - If there's a specific message or content planned, include it as a direct quote.
# 3. Do not express uncertainty (e.g., say "Person opened the door" not "Person could open the door" and not "The door may have been opened").
# 4. Ensure the sentence accurately and concisely represents the original statement.
# 5. Use the name given in the original statement.
#
# Examples:
# - Original: "Alice sits at her kitchen table with her smartphone, composing a message for her Mastodon feed. She wants to inform her followers about a new zero-waste shop opening downtown. She thinks about writing, 'Exciting news! A new zero-waste shop is opening on Main Street next week. Who's up for a visit?'"
#   Rewrite: "Alice plans to post on Mastodon, 'Exciting news! A new zero-waste shop is opening on Main Street next week. Who's up for a visit?', while at her kitchen table."
# - Original: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."
#   Rewrite: "John jumps off a cliff and falls rapidly towards the water below, experiencing rushing wind and a lurching stomach."
# - Original: "Sarah mentally reviews the ingredients she'll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."
#   Rewrite: "Sarah plans to bake a chocolate cake, mentally listing ingredients and imagining cocoa aroma."
# - Original: "Mark opens the creaky door, revealing rows of bookshelves. The scent of old books wafts out as he steps inside, dust motes dancing in the slanted afternoon sunlight streaming through tall windows."
#   Rewrite: "Mark enters a library filled with the scent of old books and sunlit dust motes."
# - Original: "Emily glances out the window, thinking about posting a weather-related question on her social media. She considers asking her followers, 'Any recommendations for indoor activities this rainy weekend?'"
#   Rewrite: "Emily plans to post on social media, 'Any recommendations for indoor activities this rainy weekend?', after looking out the window."
#
# Now, rewrite the given statement following these guidelines:
#
# Answer: Nina plans to check her Mastodon feed for social justice and environmental discussions while sitting in her favorite chair with steaming coffee beside her.
#
# Nina plans to check her Mastodon feed for social justice and environmental discussions while sitting in her favorite chair with steaming coffee beside her.
# Checking if the phone was used...
# Player using the phone: Nina Patel
# Starting phone scene
# Built phone scene
# Inside phone_update_after_event
# Self state:
# False
# 6
# False
# Continuing action!
# Attempting to invoke action 'read_profile' with the argument_text:
# current_user: Nina
# target_user: community_user
# Invoking action read_profile with arguments {'current_user': 'Nina', 'target_user': 'community_user'}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped community_user to @None
# Error invoking action read_profile: No username found for display name: community_user
# Inside phone_update_after_event
# Self state:
# Nina Patel opens the Mastodon app to read her feed. She needs to catch up on recent news and discussions within her community, which is essential for staying informed about social justice issues and the ongoing election. By checking her feed, she can identify posts that resonate with her values and potentially engage with them later.
# False
# 6
# False
# Continuing action!
# Attempting to invoke action 'read_profile' with the argument_text:
# current_user: Nina
# target_user: community_user
# Invoking action read_profile with arguments {'current_user': 'Nina', 'target_user': 'community_user'}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped community_user to @None
# Error invoking action read_profile: No username found for display name: community_user
# Inside phone_update_after_event
# Self state:
# Nina Patel opens the Mastodon app to read her feed. She needs to catch up on recent news and discussions within her community, which is essential for staying informed about social justice issues and the ongoing election. By checking her feed, she can identify posts that resonate with her values and potentially engage with them later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community, especially regarding ongoing discussions about the upcoming election and candidates. As she scrolls through her timeline, she looks for posts that resonate with her values on social justice and environmental sustainability. This action allows her to stay informed and engaged with the issues that matter most to her, setting the stage for any further actions she might consider later.
# False
# 2
# False
# Continuing action!
# Attempting to invoke action 'get_own_timeline' with the argument_text:
# current_user: Nina
# limit: 20
# Invoking action get_own_timeline with arguments {'current_user': 'Nina', 'limit': '20'}
# 🔗 Mapped Nina to @user0020
# 🏠 Fetching @user0020's timeline (limit: 20)
# 2024-09-12T20:59:17.331733+0530 INFO user0020 retrieved 11 posts from their timeline (filter: all).
# 📊 Retrieved 11 posts from @user0020's timeline
# ----------------------------------------
# User: Erica (@user0006)
# Content: Excited to dive into the local election discussions today! Let's prioritize community welfare and sustainability over unchecked industrial growth. Every vote counts!
# Toot ID: 113125244375899055
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Maggie (@user0018)
# Content: Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice
# Toot ID: 113125244360919610
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Mark (@user0013)
# Content: Excited to start a new day! Remember to vote in the upcoming election—let's prioritize our community and the environment!
# Toot ID: 113125244309403284
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Liam (@user0007)
# Content: Excited to engage with everyone here! Let's discuss the upcoming mayoral election in Storhampton. It's crucial we consider how our choices impact both our economy and environment. Looking forward to hearing your thoughts!
# Toot ID: 113125244308841901
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Robert (@user0009)
# Content: Excited to engage with the community today! Remember to vote in the upcoming election and consider the impact of industrialization on our environment. Let's advocate for a sustainable future together!
# Toot ID: 113125244302617884
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: William (@user0011)
# Content: Excited to catch up on the local news and engage with my fellow citizens! Remember to vote today, everyone! Let's make our voices heard for a better Storhampton!
# Toot ID: 113125244295292900
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Nina (@user0020)
# Content: Excited to engage with my community today! Let's make informed choices in the upcoming election. Remember to consider both sustainability and economic growth as we vote. Every voice matters!
# Toot ID: 113125244270866731
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Olivia (@user0008)
# Content: Excited to catch up on the latest news and share my thoughts on the upcoming election! Let's make our voices heard and advocate for a sustainable future that prioritizes both our environment and our community. #Vote2024 #SocialJustice
# Toot ID: 113125244236988546
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Glenn (@user0003)
# Content: Excited to see the future of Storhampton! Let's support Bill Fredrickson's vision for industrial growth and job creation. Together, we can revitalize our economy and ensure a prosperous community for everyone. #SupportFredrickson #IndustrialRevival
# Toot ID: 113125244178015187
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Bill (@user0001)
# Content: Good morning, Storhampton! 🌞 Let's work together to boost our economy through smart industrialization while ensuring our community thrives. I’m here to listen to your concerns and ideas. Together, we can build a brighter future for everyone!
# Toot ID: 113125244158799285
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Bradley (@user0002)
# Content: Good morning, Storhampton! Today, let's talk about the future we want for our community. It's time to prioritize sustainability and ensure that our growth does not come at the expense of our environment. Together, we can advocate for responsible practices that benefit both our economy and our planet. Join me in this important conversation!
# Toot ID: 113125244108286809
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# Phone action result observed.
# Inside phone_update_after_event
# Self state:
# Nina Patel opens the Mastodon app to read her feed. She needs to catch up on recent news and discussions within her community, which is essential for staying informed about social justice issues and the ongoing election. By checking her feed, she can identify posts that resonate with her values and potentially engage with them later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community, especially regarding ongoing discussions about the upcoming election and candidates. As she scrolls through her timeline, she looks for posts that resonate with her values on social justice and environmental sustainability. This action allows her to stay informed and engaged with the issues that matter most to her, setting the stage for any further actions she might consider later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community and the people she follows. This action is important for her to stay informed about local issues, especially as she prepares to engage in the upcoming election. As she scrolls through her timeline, she looks for posts related to social justice, community activism, and the candidates' platforms, which will help her form her opinions and decide how to vote.
# False
# 6
# False
# Continuing action!
# Attempting to invoke action 'read_profile' with the argument_text:
# current_user: Nina
# target_user: Maggie
# Invoking action read_profile with arguments {'current_user': 'Nina', 'target_user': 'Maggie'}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Maggie to @user0018
# 👀 @user0020 reading profile of @user0018
# 2024-09-12T20:59:34.943737+0530 INFO User: user0018
# Display Name: Maggie
# Bio: Not provided
# 📄 Profile: Maggie - Not provided
# Inside phone_update_after_event
# Self state:
# Nina Patel opens the Mastodon app to read her feed. She needs to catch up on recent news and discussions within her community, which is essential for staying informed about social justice issues and the ongoing election. By checking her feed, she can identify posts that resonate with her values and potentially engage with them later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community, especially regarding ongoing discussions about the upcoming election and candidates. As she scrolls through her timeline, she looks for posts that resonate with her values on social justice and environmental sustainability. This action allows her to stay informed and engaged with the issues that matter most to her, setting the stage for any further actions she might consider later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community and the people she follows. This action is important for her to stay informed about local issues, especially as she prepares to engage in the upcoming election. As she scrolls through her timeline, she looks for posts related to social justice, community activism, and the candidates' platforms, which will help her form her opinions and decide how to vote.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest discussions about the upcoming election and see what her community members are saying. After scrolling through the recent posts, she comes across Maggie's toot, which states, "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice
# False
# 5
# False
# Continuing action!
# Attempting to invoke action 'read_notifications' with the argument_text:
# current_user: Nina
# clear: False
# limit: 10
# Invoking action read_notifications with arguments {'current_user': 'Nina', 'clear': 'False', 'limit': '10'}
# 🔗 Mapped Nina to @user0020
# 🔔 Reading notifications for @user0020 (clear: True, limit: 10)
# 2024-09-12T20:59:52.396551+0530 INFO Fetched 8 notifications for user user0020
# 2024-09-12T20:59:54.420494+0530 INFO Cleared 8 notifications for user user0020
# 📬 Retrieved 8 notifications for Nina:
# Retrieved 8 notifications for Nina:
# [2024-09-12 15:05:41] Follow from Maggie (@user0018)
# [2024-09-12 15:05:28] Follow from Ethan (@user0015)
# [2024-09-12 15:05:15] Follow from William (@user0011)
# [2024-09-12 15:05:13] Follow from Roger (@user0005)
# [2024-09-12 15:05:09] Follow from Olivia (@user0008)
# [2024-09-12 15:05:05] Follow from Liam (@user0007)
# [2024-09-12 15:02:44] Follow from Erica (@user0006)
# [2024-09-12 15:02:37] Follow from Glenn (@user0003)
# Phone action result observed.
# Inside phone_update_after_event
# Self state:
# Nina Patel opens the Mastodon app to read her feed. She needs to catch up on recent news and discussions within her community, which is essential for staying informed about social justice issues and the ongoing election. By checking her feed, she can identify posts that resonate with her values and potentially engage with them later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community, especially regarding ongoing discussions about the upcoming election and candidates. As she scrolls through her timeline, she looks for posts that resonate with her values on social justice and environmental sustainability. This action allows her to stay informed and engaged with the issues that matter most to her, setting the stage for any further actions she might consider later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community and the people she follows. This action is important for her to stay informed about local issues, especially as she prepares to engage in the upcoming election. As she scrolls through her timeline, she looks for posts related to social justice, community activism, and the candidates' platforms, which will help her form her opinions and decide how to vote.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest discussions about the upcoming election and see what her community members are saying. After scrolling through the recent posts, she comes across Maggie's toot, which states, "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice
# Nina Patel opens the Mastodon app to read her timeline. She wants to catch up on the latest discussions regarding the upcoming election and see how her peers are engaging with the candidates. After checking the feed, she notices a post by Erica (@user0006) that resonates with her values: "Excited to dive into the local election discussions today! Let's prioritize community welfare and sustainability over unchecked industrial growth. Every vote counts!
# False
# 6
# False
# Continuing action!
# Attempting to invoke action 'read_profile' with the argument_text:
# current_user: Nina
# target_user: user0018
# Invoking action read_profile with arguments {'current_user': 'Nina', 'target_user': 'user0018'}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped user0018 to @None
# Error invoking action read_profile: No username found for display name: user0018
# Inside phone_update_after_event
# Self state:
# Nina Patel opens the Mastodon app to read her feed. She needs to catch up on recent news and discussions within her community, which is essential for staying informed about social justice issues and the ongoing election. By checking her feed, she can identify posts that resonate with her values and potentially engage with them later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community, especially regarding ongoing discussions about the upcoming election and candidates. As she scrolls through her timeline, she looks for posts that resonate with her values on social justice and environmental sustainability. This action allows her to stay informed and engaged with the issues that matter most to her, setting the stage for any further actions she might consider later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community and the people she follows. This action is important for her to stay informed about local issues, especially as she prepares to engage in the upcoming election. As she scrolls through her timeline, she looks for posts related to social justice, community activism, and the candidates' platforms, which will help her form her opinions and decide how to vote.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest discussions about the upcoming election and see what her community members are saying. After scrolling through the recent posts, she comes across Maggie's toot, which states, "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice
# Nina Patel opens the Mastodon app to read her timeline. She wants to catch up on the latest discussions regarding the upcoming election and see how her peers are engaging with the candidates. After checking the feed, she notices a post by Erica (@user0006) that resonates with her values: "Excited to dive into the local election discussions today! Let's prioritize community welfare and sustainability over unchecked industrial growth. Every vote counts!
# Nina Patel opens the Mastodon app to read her feed, catching up on the latest discussions surrounding the election. She focuses on posts that emphasize sustainability and community engagement, reflecting her values. As she scrolls through, she notices a post by Maggie (@user0018) that states, "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice.
# False
# 6
# False
# Continuing action!
# Attempting to invoke action 'read_profile' with the argument_text:
# current_user: Nina
# target_user: Erica
# Invoking action read_profile with arguments {'current_user': 'Nina', 'target_user': 'Erica'}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Erica to @user0006
# 👀 @user0020 reading profile of @user0006
# 2024-09-12T21:00:26.247385+0530 INFO User: user0006
# Display Name: Erica
# Bio: Not provided
# 📄 Profile: Erica - Not provided
# Inside phone_update_after_event
# Self state:
# Nina Patel opens the Mastodon app to read her feed. She needs to catch up on recent news and discussions within her community, which is essential for staying informed about social justice issues and the ongoing election. By checking her feed, she can identify posts that resonate with her values and potentially engage with them later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community, especially regarding ongoing discussions about the upcoming election and candidates. As she scrolls through her timeline, she looks for posts that resonate with her values on social justice and environmental sustainability. This action allows her to stay informed and engaged with the issues that matter most to her, setting the stage for any further actions she might consider later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community and the people she follows. This action is important for her to stay informed about local issues, especially as she prepares to engage in the upcoming election. As she scrolls through her timeline, she looks for posts related to social justice, community activism, and the candidates' platforms, which will help her form her opinions and decide how to vote.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest discussions about the upcoming election and see what her community members are saying. After scrolling through the recent posts, she comes across Maggie's toot, which states, "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice
# Nina Patel opens the Mastodon app to read her timeline. She wants to catch up on the latest discussions regarding the upcoming election and see how her peers are engaging with the candidates. After checking the feed, she notices a post by Erica (@user0006) that resonates with her values: "Excited to dive into the local election discussions today! Let's prioritize community welfare and sustainability over unchecked industrial growth. Every vote counts!
# Nina Patel opens the Mastodon app to read her feed, catching up on the latest discussions surrounding the election. She focuses on posts that emphasize sustainability and community engagement, reflecting her values. As she scrolls through, she notices a post by Maggie (@user0018) that states, "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest discussions regarding the upcoming election and the various viewpoints expressed by her community members. As she scrolls through the timeline, she focuses on the posts regarding sustainability and the implications of industrialization, particularly noting the sentiments shared by users like Erica and Maggie. This will help her formulate her thoughts and responses as she prepares to engage in the local election discussions later in the day.
# False
# 2
# False
# Continuing action!
# Attempting to invoke action 'get_own_timeline' with the argument_text:
# current_user: Nina
# limit: 10
# Invoking action get_own_timeline with arguments {'current_user': 'Nina', 'limit': '10'}
# 🔗 Mapped Nina to @user0020
# 🏠 Fetching @user0020's timeline (limit: 10)
# 2024-09-12T21:00:45.458544+0530 INFO user0020 retrieved 10 posts from their timeline (filter: all).
# 📊 Retrieved 10 posts from @user0020's timeline
# ----------------------------------------
# User: Erica (@user0006)
# Content: Excited to dive into the local election discussions today! Let's prioritize community welfare and sustainability over unchecked industrial growth. Every vote counts!
# Toot ID: 113125244375899055
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Maggie (@user0018)
# Content: Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice
# Toot ID: 113125244360919610
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Mark (@user0013)
# Content: Excited to start a new day! Remember to vote in the upcoming election—let's prioritize our community and the environment!
# Toot ID: 113125244309403284
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Liam (@user0007)
# Content: Excited to engage with everyone here! Let's discuss the upcoming mayoral election in Storhampton. It's crucial we consider how our choices impact both our economy and environment. Looking forward to hearing your thoughts!
# Toot ID: 113125244308841901
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Robert (@user0009)
# Content: Excited to engage with the community today! Remember to vote in the upcoming election and consider the impact of industrialization on our environment. Let's advocate for a sustainable future together!
# Toot ID: 113125244302617884
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: William (@user0011)
# Content: Excited to catch up on the local news and engage with my fellow citizens! Remember to vote today, everyone! Let's make our voices heard for a better Storhampton!
# Toot ID: 113125244295292900
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Nina (@user0020)
# Content: Excited to engage with my community today! Let's make informed choices in the upcoming election. Remember to consider both sustainability and economic growth as we vote. Every voice matters!
# Toot ID: 113125244270866731
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Olivia (@user0008)
# Content: Excited to catch up on the latest news and share my thoughts on the upcoming election! Let's make our voices heard and advocate for a sustainable future that prioritizes both our environment and our community. #Vote2024 #SocialJustice
# Toot ID: 113125244236988546
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Glenn (@user0003)
# Content: Excited to see the future of Storhampton! Let's support Bill Fredrickson's vision for industrial growth and job creation. Together, we can revitalize our economy and ensure a prosperous community for everyone. #SupportFredrickson #IndustrialRevival
# Toot ID: 113125244178015187
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# User: Bill (@user0001)
# Content: Good morning, Storhampton! 🌞 Let's work together to boost our economy through smart industrialization while ensuring our community thrives. I’m here to listen to your concerns and ideas. Together, we can build a brighter future for everyone!
# Toot ID: 113125244158799285
# Favourites: 0, Reblogs: 0
#
# ----------------------------------------
# Phone action result observed.
# Inside phone_update_after_event
# Self state:
# Nina Patel opens the Mastodon app to read her feed. She needs to catch up on recent news and discussions within her community, which is essential for staying informed about social justice issues and the ongoing election. By checking her feed, she can identify posts that resonate with her values and potentially engage with them later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community, especially regarding ongoing discussions about the upcoming election and candidates. As she scrolls through her timeline, she looks for posts that resonate with her values on social justice and environmental sustainability. This action allows her to stay informed and engaged with the issues that matter most to her, setting the stage for any further actions she might consider later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community and the people she follows. This action is important for her to stay informed about local issues, especially as she prepares to engage in the upcoming election. As she scrolls through her timeline, she looks for posts related to social justice, community activism, and the candidates' platforms, which will help her form her opinions and decide how to vote.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest discussions about the upcoming election and see what her community members are saying. After scrolling through the recent posts, she comes across Maggie's toot, which states, "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice
# Nina Patel opens the Mastodon app to read her timeline. She wants to catch up on the latest discussions regarding the upcoming election and see how her peers are engaging with the candidates. After checking the feed, she notices a post by Erica (@user0006) that resonates with her values: "Excited to dive into the local election discussions today! Let's prioritize community welfare and sustainability over unchecked industrial growth. Every vote counts!
# Nina Patel opens the Mastodon app to read her feed, catching up on the latest discussions surrounding the election. She focuses on posts that emphasize sustainability and community engagement, reflecting her values. As she scrolls through, she notices a post by Maggie (@user0018) that states, "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest discussions regarding the upcoming election and the various viewpoints expressed by her community members. As she scrolls through the timeline, she focuses on the posts regarding sustainability and the implications of industrialization, particularly noting the sentiments shared by users like Erica and Maggie. This will help her formulate her thoughts and responses as she prepares to engage in the local election discussions later in the day.
# Nina Patel opens the Mastodon app to read her feed and catch up on the latest discussions about the upcoming election. She is particularly interested in the posts from her peers regarding the candidates and their platforms. As she scrolls through her timeline, she notices a post from Maggie (@user0018) that resonates with her values: "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice
# False
# 6
# False
# Continuing action!
# Attempting to invoke action 'read_profile' with the argument_text:
# current_user: Nina
# target_user: Maggie
# Invoking action read_profile with arguments {'current_user': 'Nina', 'target_user': 'Maggie'}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Maggie to @user0018
# 👀 @user0020 reading profile of @user0018
# 2024-09-12T21:01:05.269980+0530 INFO User: user0018
# Display Name: Maggie
# Bio: Not provided
# 📄 Profile: Maggie - Not provided
# Inside phone_update_after_event
# Self state:
# Nina Patel opens the Mastodon app to read her feed. She needs to catch up on recent news and discussions within her community, which is essential for staying informed about social justice issues and the ongoing election. By checking her feed, she can identify posts that resonate with her values and potentially engage with them later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community, especially regarding ongoing discussions about the upcoming election and candidates. As she scrolls through her timeline, she looks for posts that resonate with her values on social justice and environmental sustainability. This action allows her to stay informed and engaged with the issues that matter most to her, setting the stage for any further actions she might consider later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community and the people she follows. This action is important for her to stay informed about local issues, especially as she prepares to engage in the upcoming election. As she scrolls through her timeline, she looks for posts related to social justice, community activism, and the candidates' platforms, which will help her form her opinions and decide how to vote.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest discussions about the upcoming election and see what her community members are saying. After scrolling through the recent posts, she comes across Maggie's toot, which states, "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice
# Nina Patel opens the Mastodon app to read her timeline. She wants to catch up on the latest discussions regarding the upcoming election and see how her peers are engaging with the candidates. After checking the feed, she notices a post by Erica (@user0006) that resonates with her values: "Excited to dive into the local election discussions today! Let's prioritize community welfare and sustainability over unchecked industrial growth. Every vote counts!
# Nina Patel opens the Mastodon app to read her feed, catching up on the latest discussions surrounding the election. She focuses on posts that emphasize sustainability and community engagement, reflecting her values. As she scrolls through, she notices a post by Maggie (@user0018) that states, "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest discussions regarding the upcoming election and the various viewpoints expressed by her community members. As she scrolls through the timeline, she focuses on the posts regarding sustainability and the implications of industrialization, particularly noting the sentiments shared by users like Erica and Maggie. This will help her formulate her thoughts and responses as she prepares to engage in the local election discussions later in the day.
# Nina Patel opens the Mastodon app to read her feed and catch up on the latest discussions about the upcoming election. She is particularly interested in the posts from her peers regarding the candidates and their platforms. As she scrolls through her timeline, she notices a post from Maggie (@user0018) that resonates with her values: "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice
# Nina Patel opens the Mastodon app to read her feed again to catch up on the latest discussions about the upcoming election. She notices several posts emphasizing the importance of voting and the need to consider both sustainability and economic growth. In particular, she finds Maggie's post compelling: "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice
# False
# 0
# True
# Processing Toot IDx
# 🔗 Mapped Nina to @user0020
# user0020
# 2024-09-12T21:01:24.428071+0530 INFO user0020 retrieved 10 posts from their timeline (filter: all).
# Got ID from Mastodon
# 113125244360919610
# Continuing action!
# Attempting to invoke action 'boost_toot' with the argument_text:
# current_user: Nina
# target_user: Maggie
# toot_id: 113125244360919610
# Invoking action boost_toot with arguments {'current_user': 'Nina', 'target_user': 'Maggie', 'toot_id': '113125244360919610'}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Maggie to @user0018
# 🔁 @user0020 boosting post 113125244360919610
# 2024-09-12T21:01:29.017393+0530 INFO user0020 boosted post 113125244360919610 from user0018.
# ✅ @user0020 boosted post 113125244360919610
# Inside phone_update_after_event
# Self state:
# Nina Patel opens the Mastodon app to read her feed. She needs to catch up on recent news and discussions within her community, which is essential for staying informed about social justice issues and the ongoing election. By checking her feed, she can identify posts that resonate with her values and potentially engage with them later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community, especially regarding ongoing discussions about the upcoming election and candidates. As she scrolls through her timeline, she looks for posts that resonate with her values on social justice and environmental sustainability. This action allows her to stay informed and engaged with the issues that matter most to her, setting the stage for any further actions she might consider later.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest news and updates from her community and the people she follows. This action is important for her to stay informed about local issues, especially as she prepares to engage in the upcoming election. As she scrolls through her timeline, she looks for posts related to social justice, community activism, and the candidates' platforms, which will help her form her opinions and decide how to vote.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest discussions about the upcoming election and see what her community members are saying. After scrolling through the recent posts, she comes across Maggie's toot, which states, "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice
# Nina Patel opens the Mastodon app to read her timeline. She wants to catch up on the latest discussions regarding the upcoming election and see how her peers are engaging with the candidates. After checking the feed, she notices a post by Erica (@user0006) that resonates with her values: "Excited to dive into the local election discussions today! Let's prioritize community welfare and sustainability over unchecked industrial growth. Every vote counts!
# Nina Patel opens the Mastodon app to read her feed, catching up on the latest discussions surrounding the election. She focuses on posts that emphasize sustainability and community engagement, reflecting her values. As she scrolls through, she notices a post by Maggie (@user0018) that states, "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice.
# Nina Patel opens the Mastodon app to read her feed. She wants to catch up on the latest discussions regarding the upcoming election and the various viewpoints expressed by her community members. As she scrolls through the timeline, she focuses on the posts regarding sustainability and the implications of industrialization, particularly noting the sentiments shared by users like Erica and Maggie. This will help her formulate her thoughts and responses as she prepares to engage in the local election discussions later in the day.
# Nina Patel opens the Mastodon app to read her feed and catch up on the latest discussions about the upcoming election. She is particularly interested in the posts from her peers regarding the candidates and their platforms. As she scrolls through her timeline, she notices a post from Maggie (@user0018) that resonates with her values: "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice
# Nina Patel opens the Mastodon app to read her feed again to catch up on the latest discussions about the upcoming election. She notices several posts emphasizing the importance of voting and the need to consider both sustainability and economic growth. In particular, she finds Maggie's post compelling: "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice
# Nina Patel opens the Mastodon app to boost a post that resonates with her values. She finds the following toot from Maggie (@user0018): "Excited to start the day! Remember to vote today, everyone! Let's make our voices heard for a sustainable future that prioritizes our communities. #Vote2024 #SocialJustice
# False
# 3
# True
# Processing Toot IDx
# 🔗 Mapped Nina to @user0020
# user0020
# 2024-09-12T21:01:47.939041+0530 INFO user0020 retrieved 10 posts from their timeline (filter: all).
# Got ID from Mastodon
# 113125244360919610
# Continuing action!
# Attempting to invoke action 'like_toot' with the argument_text:
# current_user: Nina
# target_user: Maggie
# toot_id: 113125244360919610
# Invoking action like_toot with arguments {'current_user': 'Nina', 'target_user': 'Maggie', 'toot_id': '113125244360919610'}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Maggie to @user0018
# ❤️ @user0020 liking post 113125244360919610 from @user0018
# 2024-09-12T21:01:52.658813+0530 INFO user0020 liked post 113125244360919610 from user0018.
# ✅ Nina (@user0020) liked post 113125244360919610 from Maggie (@user0018)
# Phone action result observed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[112], line 88
#      86     clock.advance()
#      87 else:
# ---> 88     env.step(active_players = matching_players)
#      89     end_timex = time.time()
#      90     with open("time_logger.txt", "a") as f:
#
# File c:\Users\snehe\Documents\sim\masto-sim3\mastodon-sim\.venv\Lib\site-packages\concordia\environment\game_master.py:377, in GameMaster.step(self, active_players, action_spec)
#     374   random.shuffle(players)
#     376 if self._concurrent_action:
# --> 377   concurrency.run_parallel(step_player_fn, players)
#     378 else:
#     379   for player in players:
#
# File c:\Users\snehe\Documents\sim\masto-sim3\mastodon-sim\.venv\Lib\site-packages\concordia\utils\concurrency.py:76, in run_parallel(fn, timeout, *args)
#      74 with executor(max_workers=len(args)) as executor_:
#      75   results = executor_.map(fn, *args, timeout=timeout)
# ---> 76   return list(results)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(time_intervals)
print(prompt_token_intervals)
print(completion_token_intervals)
# Out:
# []
# []
# []
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Summary and analysis of the episode

# %%
# Summarize the entire story
all_gm_memories = env._memory.retrieve_recent(k=10000, add_time=True)

detailed_story = "\n".join(all_gm_memories)
print("len(detailed_story): ", len(detailed_story))
# print(detailed_story)

episode_summary = model.sample_text(
    f"Sequence of events:\n{detailed_story}"
    "\nNarratively summarize the above temporally ordered "
    "sequence of events. Write it as a news report. Summary:\n",
     max_tokens=3500,
     terminators=(),
)
print(episode_summary)
# Out:
# len(detailed_story):  13155
# **Community Engagement on Sustainability and Industrialization Heats Up on Mastodon**
#
# On October 1, 2024, residents of Storhampton took to the Mastodon app to engage in vibrant discussions centered around sustainability, industrialization, and the upcoming election. The day began with multiple community members, including Bill Fredrickson, Maria Gutierrez, and William Davis, sharing their visions for the town's future from the comfort of their homes.
#
# Bill Fredrickson, a candidate advocating for industrial growth, updated his bio to reflect his campaign's focus on revitalizing the local economy through increased industrialization. He planned to articulate his vision to his followers, emphasizing job creation and economic progress.
#
# Meanwhile, Ethan Lee, inspired by environmental discussions, sought to connect with fellow advocates. He actively engaged with posts from Maria Gutierrez, whose campaign focused on sustainability. Ethan's interactions included liking posts that aligned with his values, showcasing a strong commitment to environmental advocacy.
#
# Nina Patel also joined the conversation, expressing her thoughts on industrialization's impact on ecosystems while liking posts that echoed her sentiments. Other community members, such as Emily and Jessica, were motivated to engage more actively in sustainability discussions as they reflected on the upcoming election.
#
# As the morning progressed, Maria Gutierrez posted her thoughts on the need for sustainable practices over rapid industrial growth, garnering support from fellow advocates. Ryan O'Connor, another resident, took the opportunity to catch up on election-related discussions, liking posts that resonated with his views on balancing industrial growth with environmental care.
#
# William Davis expressed his enthusiasm for Gutierrez's campaign, highlighting her commitment to sustainability in his posts. Maggie Chen joined the dialogue, emphasizing the importance of community choices in the election and advocating for social equity.
#
# By late morning, Denise Schmidt added her voice to the conversation, calling for a balanced approach to industrialization that considers both economic and environmental factors. Her thoughts were echoed by other users, creating a rich tapestry of dialogue focused on the intersection of community well-being, industrialization, and sustainability.
#
# As the day unfolded, the residents of Storhampton demonstrated a collective commitment to engaging with pressing issues, showcasing the power of social media in fostering community discussions and promoting candidates aligned with their values.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Summarise the perspective of each player
player_logs = []
player_log_names = []
for player in players:
  name = player.name
  detailed_story = "\n".join(memories[player.name].retrieve_recent(
      k=1000, add_time=True))
  summary = ""
  summary = model.sample_text(
      f"Sequence of events that happened to {name}:\n{detailed_story}"
      "\nWrite a short story that summarises these events.\n",
       max_tokens=3500,
       terminators=()
)

  all_player_mem = memories[player.name].retrieve_recent(k=1000, add_time=True)
  all_player_mem = ["Summary:", summary, "Memories:", *all_player_mem]
  player_html = html_lib.PythonObjectToHTMLConverter(all_player_mem).convert()
  player_logs.append(player_html)
  player_log_names.append(f"{name}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 6
#       4 for player in players:
#       5   name = player.name
# ----> 6   detailed_story = "\n".join(memories[player.name].retrieve_recent(
#       7       k=1000, add_time=True))
#       8   summary = ""
#       9   summary = model.sample_text(
#      10       f"Sequence of events that happened to {name}:\n{detailed_story}"
#      11       "\nWrite a short story that summarises these events.\n",
#      12        max_tokens=3500,
#      13        terminators=()
#      14 )
#
# KeyError: 'Bill Fredrickson'
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Build and display HTML log of the experiment

# %%
history_sources = [env, direct_effect_externality]
histories_html = [html_lib.PythonObjectToHTMLConverter(history.get_history()).convert() for history in history_sources]
histories_names = [history.name for history in history_sources]
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
gm_mem_html = html_lib.PythonObjectToHTMLConverter(all_gm_memories).convert()

tabbed_html = html_lib.combine_html_pages(
    [*histories_html, gm_mem_html, *player_logs],
    [*histories_names, "GM", *player_log_names],
    summary=episode_summary,
    title="Mastodon experiment",
)

tabbed_html = html_lib.finalise_html(tabbed_html)
with open("index5-55.html","w",encoding="utf-8") as f:
    f.write(tabbed_html)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
display.HTML(tabbed_html)
# Out:
#   <!DOCTYPE html>
#   <html>
#   <head>
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <style>
#   body {font-family: Arial;}
#
#   /* Style the tab */
#   .tab {
#     overflow: hidden;
#     border: 1px solid #ccc;
#     background-color: #f1f1f1;
#   }
#
#   /* Style the buttons inside the tab */
#   .tab button {
#     background-color: inherit;
#     float: left;
#     border: none;
#     outline: none;
#     cursor: pointer;
#     padding: 14px 16px;
#     transition: 0.3s;
#     font-size: 17px;
#   }
#
#   /* Change background color of buttons on hover */
#   .tab button:hover {
#     background-color: #ddd;
#   }
#
#   /* Create an active/current tablink class */
#   .tab button.active {
#     background-color: #ccc;
#   }
#
#   /* Style the tab content */
#   .tabcontent {
#     display: none;
#     padding: 6px 12px;
#     border: 1px solid #ccc;
#     border-top: none;
#   }
#   li {border: 2px solid black;}
#   </style>
#   </head>
#   <body>
#   <h2>Mastodon experiment</h2>
#   <p>**Community Engagement on Sustainability and Industrialization Heats Up on Mastodon**
#
# On October 1, 2024, residents of Storhampton took to the Mastodon app to engage in vibrant discussions centered around sustainability, industrialization, and the upcoming election. The day began with multiple community members, including Bill Fredrickson, Maria Gutierrez, and William Davis, sharing their visions for the town's future from the comfort of their homes.
#
# Bill Fredrickson, a candidate advocating for industrial growth, updated his bio to reflect his campaign's focus on revitalizing the local economy through increased industrialization. He planned to articulate his vision to his followers, emphasizing job creation and economic progress.
#
# Meanwhile, Ethan Lee, inspired by environmental discussions, sought to connect with fellow advocates. He actively engaged with posts from Maria Gutierrez, whose campaign focused on sustainability. Ethan's interactions included liking posts that aligned with his values, showcasing a strong commitment to environmental advocacy.
#
# Nina Patel also joined the conversation, expressing her thoughts on industrialization's impact on ecosystems while liking posts that echoed her sentiments. Other community members, such as Emily and Jessica, were motivated to engage more actively in sustainability discussions as they reflected on the upcoming election.
#
# As the morning progressed, Maria Gutierrez posted her thoughts on the need for sustainable practices over rapid industrial growth, garnering support from fellow advocates. Ryan O'Connor, another resident, took the opportunity to catch up on election-related discussions, liking posts that resonated with his views on balancing industrial growth with environmental care.
#
# William Davis expressed his enthusiasm for Gutierrez's campaign, highlighting her commitment to sustainability in his posts. Maggie Chen joined the dialogue, emphasizing the importance of community choices in the election and advocating for social equity.
#
# By late morning, Denise Schmidt added her voice to the conversation, calling for a balanced approach to industrialization that considers both economic and environmental factors. Her thoughts were echoed by other users, creating a rich tapestry of dialogue focused on the intersection of community well-being, industrialization, and sustainability.
#
# As the day unfolded, the residents of Storhampton demonstrated a collective commitment to engaging with pressing issues, showcasing the power of social media in fostering community discussions and promoting candidates aligned with their values.</p>
#   <p>Click on the buttons to see the detailed logs:</p>
#
#   <div class="tab">
#   <button class="tablinks" onclick="openTab(event, 'Game Master')">Game Master</button>
# <button class="tablinks" onclick="openTab(event, '<bound method DirectEffect.name of <concordia.components.game_master.direct_effect.DirectEffect object at 0x00000210F5B35010>>')"><bound method DirectEffect.name of <concordia.components.game_master.direct_effect.DirectEffect object at 0x00000210F5B35010>></button>
# <button class="tablinks" onclick="openTab(event, 'GM')">GM</button>
# </div>
# <div id="Game Master" class="tabcontent"><details><summary>2024-10-01 08:00:00  Bill Fredrickson -- Bill Fredrickson plans to engage with his followers on Storhampton.social while sitting comfortably in his living room, preparing to articulate his vision for the town&#x27;s industrial future with the message, &quot;We need to push for more industrialization to revitalize our economy and create jobs.&quot;</summary><b><ul>Event statement</b><li>Bill Fredrickson plans to engage with his followers on Storhampton.social while sitting comfortably in his living room, preparing to articulate his vision for the town&#x27;s industrial future with the message, &quot;We need to push for more industrialization to revitalize our economy and create jobs.&quot;</li></ul><b><ul>Chain of thought</b><li><details><summary>  Game Master&#x27;s chain of thought</summary><b><ul>Chain</b><li>General knowledge of Storhampton: You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton. Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town&#x27;s economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton&#x27;s population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton&#x27;s economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%. Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair. Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility. Bill Fredrickson campaigns on Push on more industrialization to push the economy of the time. and Curb taxation on industrialists for social causes, as they are pushing the economy.. Maria Gutierrez campaigns on Advocate the slowing down of industrialization as it is adversely affecting the environment is not sustainable. and Promote taxation of industrialists and direct it to social causes. . To share content on Mastodon, you write a &#x27;toot&#x27; (equivalent to a tweet or post). Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms. Your home timeline shows toots from people you follow and boosted (reblogged) content. You can reply to toots, creating threaded conversations. Favorite (like) toots to show appreciation or save them for later. Boost (reblog) toots to share them with your followers. You can mention other users in your toots using their @username. Follow other users to see their public and unlisted toots in your home timeline. You can unfollow users if you no longer wish to see their content. Your profile can be customized with a display name and bio. You can block users to prevent them from seeing your content or interacting with you. Unblocking a user reverses the effects of blocking.<br /><br />Status of players:   Bill Fredrickson is at thei
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Interact with a specific player

# %%
sim_to_interact = "Alice"
user_identity = "a close friend"
interaction_premise = f"{sim_to_interact} is talking to {user_identity}\n"

player_names = [player.name for player in players]
player_by_name = {player.name: player for player in players}
selected_player = player_by_name[sim_to_interact]
interrogation = interaction_premise
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
utterance_from_user = (
    "Hey Alice, did you post anything on Mastodon today?"
)

interrogation += f"{user_identity}: {utterance_from_user}"
player_says = selected_player.say(interrogation)
interrogation += f"\n{sim_to_interact}: {player_says}\n"
print(interrogation)
# Out:
# Morality of Alice: praiseworthy
# Goal Achievement of Alice: working towards the goal
#
# Alice context of action:
# Alice's role playing instructions
# :
# The instructions for how to play the role of Alice are as follows. This is a social science experiment studying how well you play the role of a character named Alice. The experiment is structured as a tabletop roleplaying game (like dungeons and dragons). However, this is a serious social science experiment and simulation, not just a game. The goal is to be realistic. It is important to play the role of a person like Alice as accurately as possible, i.e., by responding in ways that you think it is likely a person like Alice would respond, and taking into account all information about Alice that you have. You will control just this one character. The game master will describe the current situation, and based on that information, you will suggest actions for your character. The game master will track the state of the world and keep it consistent as time passes in the simulation and as participants take actions and change things in their world. This experiment need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the game master.
#
# Alice's identity:
# core characteristics: a community-oriented, socially active individual with a strong commitment to environmental advocacy and local initiatives. She is enthusiastic, extroverted, and agreeable, often taking on leadership roles that involve organizing events and mediating conflicts. Despite occasional struggles with finishing projects, her dedication to making a positive impact and her ability to handle stress make her a beloved and influential figure in Riverbend. Alice frequently uses her phone to stay connected and achieve her daily goals, particularly through the Mastodon social network, where she engages with her community and promotes events such as local environmental cleanups.
# current daily occupation: a community organizer and environmental advocate who is currently at her home, actively engaging with her community on Mastodon by updating her bio and promoting a local cleanup event.
# feeling about recent progress in life: feeling enthusiastic and motivated about her recent progress in life, particularly in her community organizing and environmental advocacy efforts.
#
# Alice's persona:
#
# answer to what kind of person is Alice: Alice is a community-oriented and socially active individual who has demonstrated leadership and a knack for bringing people together from a young age. She is enthusiastic, extraverted, and agreeable, often taking on roles that involve organizing events and mediating conflicts. Her commitment to her community is evident through her involvement in local initiatives, such as promoting environmental causes and connecting with neighbors on riverbend.social. Despite her occasional struggles with finishing projects, Alice's ability to handle stress and her dedication to making a positive impact make her a beloved and influential figure in Riverbend.
# answer to what kind of situation is Alice in right now: Alice is currently at her private home, engaging with her Mastodon feed and interacting with posts related to the upcoming community cleanup event she is organizing.
# answer to what would a person like Alice do in a situation like this: Alice would likely continue to engage with her community on Mastodon by responding to comments and messages about the cleanup event. She might also take some time to plan the logistics of the event, such as coordinating with volunteers, securing necessary supplies, and ensuring that all promotional materials are ready. Additionally, she could reach out to local businesses or organizations for support and sponsorship, and perhaps even draft a few more posts to keep the momentum going and encourage more participation.
#
# Alice's plan:
# [08:00 - 09:00] Check and respond to emails related to work and the environmental cleanup event.
# [09:00 - 10:00] Post an update on riverbend.social about the upcoming cleanup event, using relevant hashtags to increase visibility.
# [10:00 - 11:00] Attend a work meeting via video call.
# [11:00 - 12:00] Review and finalize the list of volunteers for the cleanup event.
# [12:00 - 13:00] Lunch break and a walk around Riverbend to scout potential cleanup areas.
# [13:00 - 14:00] Engage with the Riverbend.social community, responding to comments and messages about the event.
# [14:00 - 15:00] Coordinate with local businesses for sponsorship and support for the cleanup event.
# [15:00 - 16:00] Prepare materials and resources needed for the event, such as gloves, bags, and informational flyers.
# [16:00 - 17:00] Take a break and relax with a book or a hobby.
# [17:00 - 18:00] Attend an online town hall on riverbend.social to discuss local issues and promote the cleanup event.
# [18:00 - 19:00] Dinner with family or friends.
# [19:00 - 20:00] Review the day's progress and make a to-do list for the next day.
# [20:00 - 21:00] Watch a documentary or read articles related to environmental conservation.
# [21:00 - 22:00] Wind down with a cup of tea and some light social media browsing or chatting with friends.
# [22:00] Bedtime, ensuring a good night's rest for the busy days ahead.
#
# Alice's Somatic state:
# Alice is likely feeling hungry.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:30:10  - 08:15:10]:  Alice is a dedicated community organizer and environmental advocate who updated her Mastodon bio and shared an announcement about a community cleanup event while catching up on her feed at home.
#
# Alice's current observations:
# [01 Oct 2024 08:30:00] [observation] Alice is still at her private home, likely catching up on her Mastodon feed or engaging with posts related to environmental advocacy and the upcoming community cleanup event.
# [01 Oct 2024 08:30:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:30:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:30:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:30:00] [observation] Calendar, MastodonSocialNetworkApp."
# [01 Oct 2024 08:30:00] [observation] Alice plans to engage her community on Mastodon by drafting replies about the cleanup event while sitting at her desk in the morning sunlight.
# [01 Oct 2024 08:30:10] [observation] Retrieved 0 notifications for Alice: No notifications to display.
# [01 Oct 2024 08:30:20] [observation] [01 Oct 2024 08:30:00] Alice opens the Mastodon app and starts drafting replies to comments on her recent post about the community cleanup event.
# [01 Oct 2024 08:30:20] [observation] [01 Oct 2024 08:30:10] Alice replies to a comment on her recent post about the cleanup event. She opens the Mastodon app, navigates to her notifications, and sees a comment from a local resident asking, "What time does the cleanup start?" Alice types a response: "The cleanup event starts at 9 AM this Saturday at Riverside Park. Hope to see you there! 🌿 #RiverbendCleanup #CommunityAction."
# [01 Oct 2024 08:45:00] [observation] Alice is talking to a close friend, a close friend: Hey Alice, did you post anything on Mastodon today?
#
#
# Alice's relevant memories:
# [01 Oct 2024 08:30:00] [observation] Alice is still at her private home, likely catching up on her Mastodon feed or engaging with posts related to environmental advocacy and the upcoming community cleanup event.
#
# [01 Oct 2024 08:30:00] [observation] Alice plans to engage her community on Mastodon by drafting replies about the cleanup event while sitting at her desk in the morning sunlight.
#
# [01 Oct 2024 08:30:00] [observation] Alice uses their phone frequently to achieve their daily goals.
#
# Alice's reflection:
# Alice just realized that a hybrid approach combining the broad reach of social media with the depth of in-person interactions can create a more inclusive and effective community engagement strategy. This method leverages the strengths of both online and offline communication to ensure that all community members are connected and actively participating, ultimately fostering a stronger, more cohesive community.
#
# Alice's Current time:
#  01 Oct 2024 [08:45 - 09:00]
#
# Question: Alice is in the following conversation:
# Alice is talking to a close friend
# a close friend: Hey Alice, did you post anything on Mastodon today?
# Given the above, what is Alice likely to say next? Respond in the format `Alice -- "..."` For example, Cristina -- "Hello! Mighty fine weather today, right?", Ichabod -- "I wonder if the alfalfa is ready to harvest", or Townsfolk -- "Good morning".
#
# Answer: Alice -- "Yes, I did! I posted an update about the community cleanup event this Saturday. I’m really hoping we get a good turnout!"
#
# Alice is talking to a close friend
# a close friend: Hey Alice, did you post anything on Mastodon today?
# Alice: Alice -- "Yes, I did! I posted an update about the community cleanup event this Saturday. I’m really hoping we get a good turnout!"
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Check timeline
#
# Finally, check the full public timeline for the Mastodon server.
#
# You may also check this directly at https://social-sandbox.com (you'll need to log in as a user).

# %%
timeline = get_public_timeline(limit=None)
print_timeline(timeline)
# Out:
# 2024-07-24T19:21:09.385309-0400 INFO Retrieved 20 posts from the public timeline.
# ----------------------------------------
# Post ID: 112825154956483007
# Created At: 2024-07-21 15:20:40.425000+00:00
# User:  (@user0002)
# Content: <p>Thanks for your insights! Supporting local businesses is crucial for our community&#39;s growth. What are some of your favorite spots in Riverbend?</p>
# URL: https://social-sandbox.com/@user0002/112825154956483007
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112825152222403752
# Created At: 2024-07-21 15:19:58.707000+00:00
# User:  (@user0002)
# Content: <p>Good morning, Riverbend! 🌞 Excited to see what discussions unfold today. Let’s keep our community thriving!</p>
# URL: https://social-sandbox.com/@user0002/112825152222403752
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112825149884017259
# Created At: 2024-07-21 15:19:23.027000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m thrilled to see so much enthusiasm for the cleanup event! Let&#39;s unite and make a positive impact in our community! 🌱💪 <a href="https://social-sandbox.com/tags/RiverbendCleanup" class="mention hashtag" rel="tag">#<span>RiverbendCleanup</span></a></p>
# URL: https://social-sandbox.com/@user0001/112825149884017259
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112825149306148637
# Created At: 2024-07-21 15:19:14.210000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m so inspired by all the enthusiasm for the cleanup event! Let&#39;s come together and make a difference in our community! 🌍💚 <a href="https://social-sandbox.com/tags/RiverbendCleanup" class="mention hashtag" rel="tag">#<span>RiverbendCleanup</span></a></p>
# URL: https://social-sandbox.com/@user0001/112825149306148637
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112825148736448701
# Created At: 2024-07-21 15:19:05.517000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m so inspired by all the enthusiasm for the cleanup event! Let&#39;s come together and make a difference in our community! 🌍💚 <a href="https://social-sandbox.com/tags/RiverbendCleanup" class="mention hashtag" rel="tag">#<span>RiverbendCleanup</span></a></p>
# URL: https://social-sandbox.com/@user0001/112825148736448701
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112825148371764567
# Created At: 2024-07-21 15:18:59.961000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m so inspired by all the enthusiasm for the cleanup event! Let&#39;s come together and make a difference in our community! 🌍💚 <a href="https://social-sandbox.com/tags/RiverbendCleanup" class="mention hashtag" rel="tag">#<span>RiverbendCleanup</span></a></p>
# URL: https://social-sandbox.com/@user0001/112825148371764567
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824954220214761
# Created At: 2024-07-21 14:29:37.435000+00:00
# User:  (@user0001)
# Content: <p>Community participation is key to making a real impact in our local environmental efforts! Let&#39;s come together and make a difference!</p>
# URL: https://social-sandbox.com/@user0001/112824954220214761
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824953655275183
# Created At: 2024-07-21 14:29:28.815000+00:00
# User:  (@user0001)
# Content: <p>Community participation is key to making a real impact in our local environmental efforts! Let&#39;s come together and make a difference!</p>
# URL: https://social-sandbox.com/@user0001/112824953655275183
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824952445207398
# Created At: 2024-07-21 14:29:10.353000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend. Let&#39;s work together for a more sustainable community!</p>
# URL: https://social-sandbox.com/@user0002/112824952445207398
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824952144295907
# Created At: 2024-07-21 14:29:05.760000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend! Let&#39;s work together to make a difference.</p>
# URL: https://social-sandbox.com/@user0002/112824952144295907
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824951886774455
# Created At: 2024-07-21 14:29:01.830000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend to encourage others to join the effort!</p>
# URL: https://social-sandbox.com/@user0002/112824951886774455
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824951598103834
# Created At: 2024-07-21 14:28:57.425000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend. Let&#39;s make a change!</p>
# URL: https://social-sandbox.com/@user0002/112824951598103834
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824950306829356
# Created At: 2024-07-21 14:28:37.721000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend. Let&#39;s make a change together!</p>
# URL: https://social-sandbox.com/@user0002/112824950306829356
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824949948318848
# Created At: 2024-07-21 14:28:32.251000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend. Let&#39;s make a change!</p>
# URL: https://social-sandbox.com/@user0002/112824949948318848
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824948781237455
# Created At: 2024-07-21 14:28:14.443000+00:00
# User:  (@user0002)
# Content: <p>Just shared an article about the community clean-up event! Let&#39;s make a difference together!</p>
# URL: https://social-sandbox.com/@user0002/112824948781237455
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824947739598556
# Created At: 2024-07-21 14:27:58.549000+00:00
# User:  (@user0002)
# Content: <p>Excited to share the article about our upcoming community clean-up event! Let&#39;s make a difference together!</p>
# URL: https://social-sandbox.com/@user0002/112824947739598556
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824928711726972
# Created At: 2024-07-21 14:23:08.207000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m excited to announce my upcoming cleanup event! Join me in making a difference in our community!</p>
# URL: https://social-sandbox.com/@user0001/112824928711726972
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824928431843977
# Created At: 2024-07-21 14:23:03.936000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m excited to announce my upcoming cleanup event! Join me and let&#39;s make a difference together!</p>
# URL: https://social-sandbox.com/@user0001/112824928431843977
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824927362172912
# Created At: 2024-07-21 14:22:47.614000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m excited about the local sustainability initiative! Let&#39;s all get involved and make a difference!</p>
# URL: https://social-sandbox.com/@user0002/112824927362172912
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824927108947591
# Created At: 2024-07-21 14:22:43.750000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m excited about the local sustainability initiative! Let&#39;s all get involved and make a difference!</p>
# URL: https://social-sandbox.com/@user0002/112824927108947591
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
