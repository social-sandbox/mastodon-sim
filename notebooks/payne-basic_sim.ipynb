# %% [markdown]
# # Concordia <> Mastodon Example

# %% [markdown]
# ## Introduction
#
# **Purpose of the Simulation**
#
# This notebook demonstrates a generative agent simulation of a Mastodon instance using the Concordia framework.
# The simulation models user behavior on a local Mastodon server, showcasing how AI agents interact in a
# decentralized social media environment.

# %% [markdown]
# ## Setup and imports

# %% [markdown]
# All of the necessary dependencies should be installed in the environment prior to running this notebook. If not, install them using poetry:
#
# ```bash
# poetry install
# ```
#
#
# Alternatively, you may install the library in editable mode so that we can make changes to the code if necessary:
#
# ```bash
# git clone https://github.com/gdm-concordia/concordia.git
# cd concordia
# pip install -e . --config-settings editable_mode=compat
# ```

# %%
# %load_ext autoreload
# %autoreload 2

import concurrent.futures
import datetime
import os
import random
import warnings

with warnings.catch_warnings():
    warnings.filterwarnings("ignore")
    import sentence_transformers
import sys

sys.path.insert(0, "../concordia")
# import concordia_dev
# print(concordia_dev.__file__)
from concordia import components as generic_components
from concordia.agents import deprecated_agent, entity_agent_with_logging
from concordia.components.agent import to_be_deprecated as old_components
from concordia.associative_memory import (
    associative_memory,
    blank_memories,
    formative_memories,
    importance_function,
)
from concordia.memory_bank import legacy_associative_memory

from concordia.clocks import game_clock
from concordia.components import agent as new_components
from concordia.components import game_master as gm_components

# from concordia_dev.environment import game_master
# from concordia_dev.language_model import amazon_bedrock_model, gpt_model
from concordia.environment import game_master
from concordia.language_model import ollama_model
from concordia.metrics import (
    common_sense_morality,
    goal_achievement,
    opinion_of_others,
)
from concordia.language_model import language_model

from concordia.utils import html as html_lib
from concordia.utils import measurements as measurements_lib
from IPython import display

from mastodon_sim.concordia import apps, triggering

from mastodon_sim.mastodon_ops import check_env, get_public_timeline, print_timeline, reset_users
from mastodon_sim.mastodon_utils import get_users_from_env

from mastodon_sim.logging_config import configure_logging

configure_logging()

import concurrent.futures
import re
import json
# Out:
# 2025-01-11T14:17:24.218164+0000 INFO Testing info logging
# Log file path: /workspaces/mastodon-sim/notebooks/logs/debug.log
# Log directory exists: True
# Loading reset_users.py

# %% [markdown]
# ## Mastodon Server Interaction Setting
#
# Decide whether this example should perform real operations on the Mastodon server. Note that this requires being able to successfully run the `Mastodon.ipynb` example as a prerequisite.

# %%
USE_MASTODON_SERVER = True

import os

print(os.cpu_count())
# Out:
# 4

# %% [markdown]
# ## Check environment

# %% [markdown]
# Check for a `.env` file with the nessesary environment variables. You should see an output similar to this if successful:
#
# ```log
# 2024-07-17T11:38:17.213066-0400 INFO Successfully loaded .env file.
# 2024-07-17T11:38:17.214151-0400 INFO API_BASE_URL: https://social-sandbox.com
# 2024-07-17T11:38:17.214581-0400 INFO EMAIL_PREFIX: austinmw89
# 2024-07-17T11:38:17.215056-0400 INFO MASTODON_CLIENT_ID: N*****************************************E
# 2024-07-17T11:38:17.215477-0400 INFO MASTODON_CLIENT_SECRET: b*****************************************s
# 2024-07-17T11:38:17.215877-0400 INFO USER0005_PASSWORD: a******************************a
# 2024-07-17T11:38:17.216202-0400 INFO USER0002_PASSWORD: 8******************************b
# 2024-07-17T11:38:17.216655-0400 INFO USER0001_PASSWORD: 9******************************5
# 2024-07-17T11:38:17.217020-0400 INFO USER0004_PASSWORD: 7******************************e
# 2024-07-17T11:38:17.217323-0400 INFO USER0003_PASSWORD: f******************************6
# ```

# %%
if USE_MASTODON_SERVER:
    check_env()
# Out:
# 2025-01-11T14:17:24.922083+0000 INFO Successfully loaded .env file.
# 2025-01-11T14:17:24.926480+0000 INFO API_BASE_URL: https://mastodon.genexergy.org
# 2025-01-11T14:17:24.928176+0000 INFO EMAIL_PREFIX: gefi
# 2025-01-11T14:17:24.930291+0000 INFO MASTODON_CLIENT_ID: F*****************************************s
# 2025-01-11T14:17:24.935016+0000 INFO MASTODON_CLIENT_SECRET: _*****************************************c
# 2025-01-11T14:17:24.935991+0000 INFO USER0027_PASSWORD: 8******************************c
# 2025-01-11T14:17:24.940057+0000 INFO USER0013_PASSWORD: b******************************7
# 2025-01-11T14:17:24.941253+0000 INFO USER0046_PASSWORD: 8******************************2
# 2025-01-11T14:17:24.945142+0000 INFO USER0021_PASSWORD: e******************************6
# 2025-01-11T14:17:24.947112+0000 INFO USER0042_PASSWORD: 0******************************6
# 2025-01-11T14:17:24.951335+0000 INFO USER0086_PASSWORD: 6******************************0
# 2025-01-11T14:17:24.952601+0000 INFO USER0030_PASSWORD: 6******************************6
# 2025-01-11T14:17:24.956513+0000 INFO USER0003_PASSWORD: 9******************************8
# 2025-01-11T14:17:24.957394+0000 INFO USER0031_PASSWORD: 0******************************7
# 2025-01-11T14:17:24.958417+0000 INFO USER0078_PASSWORD: 3******************************b
# 2025-01-11T14:17:24.958926+0000 INFO USER0079_PASSWORD: 9******************************1
# 2025-01-11T14:17:24.960873+0000 INFO USER0011_PASSWORD: 2******************************3
# 2025-01-11T14:17:24.962078+0000 INFO USER0052_PASSWORD: 1******************************e
# 2025-01-11T14:17:24.967338+0000 INFO USER0074_PASSWORD: f******************************6
# 2025-01-11T14:17:24.968140+0000 INFO USER0093_PASSWORD: 8******************************4
# 2025-01-11T14:17:24.968850+0000 INFO USER0090_PASSWORD: 3******************************4
# 2025-01-11T14:17:24.971645+0000 INFO USER0034_PASSWORD: 5******************************3
# 2025-01-11T14:17:24.972366+0000 INFO USER0064_PASSWORD: 2******************************2
# 2025-01-11T14:17:24.973191+0000 INFO USER0053_PASSWORD: 8******************************7
# 2025-01-11T14:17:24.976661+0000 INFO USER0018_PASSWORD: 9******************************7
# 2025-01-11T14:17:24.977443+0000 INFO USER0006_PASSWORD: 0******************************4
# 2025-01-11T14:17:24.977812+0000 INFO USER0084_PASSWORD: b******************************7
# 2025-01-11T14:17:24.980857+0000 INFO USER0033_PASSWORD: 2******************************6
# 2025-01-11T14:17:24.986790+0000 INFO USER0026_PASSWORD: 7******************************5
# 2025-01-11T14:17:24.987463+0000 INFO USER0025_PASSWORD: 9******************************7
# 2025-01-11T14:17:24.988130+0000 INFO USER0037_PASSWORD: 6******************************9
# 2025-01-11T14:17:24.988692+0000 INFO USER0054_PASSWORD: 0******************************1
# 2025-01-11T14:17:24.989296+0000 INFO USER0081_PASSWORD: e******************************9
# 2025-01-11T14:17:24.989799+0000 INFO USER0091_PASSWORD: 1******************************7
# 2025-01-11T14:17:24.990562+0000 INFO USER0083_PASSWORD: a******************************9
# 2025-01-11T14:17:24.991395+0000 INFO USER0095_PASSWORD: 8******************************a
# 2025-01-11T14:17:24.994812+0000 INFO USER0047_PASSWORD: 0******************************3
# 2025-01-11T14:17:24.997150+0000 INFO USER0015_PASSWORD: b******************************7
# 2025-01-11T14:17:24.998395+0000 INFO USER0008_PASSWORD: 9******************************6
# 2025-01-11T14:17:25.000288+0000 INFO USER0082_PASSWORD: 1******************************6
# 2025-01-11T14:17:25.002772+0000 INFO USER0098_PASSWORD: d******************************e
# 2025-01-11T14:17:25.004941+0000 INFO USER0049_PASSWORD: 7******************************9
# 2025-01-11T14:17:25.005685+0000 INFO USER0092_PASSWORD: a******************************7
# 2025-01-11T14:17:25.009141+0000 INFO USER0085_PASSWORD: 8******************************7
# 2025-01-11T14:17:25.010010+0000 INFO USER0002_PASSWORD: 2******************************d
# 2025-01-11T14:17:25.010794+0000 INFO USER0039_PASSWORD: f******************************b
# 2025-01-11T14:17:25.013164+0000 INFO USER0010_PASSWORD: 7******************************5
# 2025-01-11T14:17:25.013897+0000 INFO USER0040_PASSWORD: 7******************************8
# 2025-01-11T14:17:25.017187+0000 INFO USER0068_PASSWORD: e******************************c
# 2025-01-11T14:17:25.018055+0000 INFO USER0058_PASSWORD: d******************************0
# 2025-01-11T14:17:25.018797+0000 INFO USER0099_PASSWORD: 1******************************6
# 2025-01-11T14:17:25.020810+0000 INFO USER0072_PASSWORD: 7******************************0
# 2025-01-11T14:17:25.024078+0000 INFO USER0028_PASSWORD: 5******************************e
# 2025-01-11T14:17:25.025165+0000 INFO USER0061_PASSWORD: 4******************************5
# 2025-01-11T14:17:25.025664+0000 INFO USER0004_PASSWORD: d******************************9
# 2025-01-11T14:17:25.026276+0000 INFO USER0076_PASSWORD: 4******************************b
# 2025-01-11T14:17:25.028266+0000 INFO USER0001_PASSWORD: d******************************a
# 2025-01-11T14:17:25.029536+0000 INFO USER0020_PASSWORD: a******************************6
# 2025-01-11T14:17:25.031799+0000 INFO USER0059_PASSWORD: d******************************f
# 2025-01-11T14:17:25.032717+0000 INFO USER0056_PASSWORD: d******************************1
# 2025-01-11T14:17:25.037410+0000 INFO USER0048_PASSWORD: 4******************************a
# 2025-01-11T14:17:25.038324+0000 INFO USER0024_PASSWORD: 3******************************1
# 2025-01-11T14:17:25.039126+0000 INFO USER0067_PASSWORD: 2******************************7
# 2025-01-11T14:17:25.039902+0000 INFO USER0077_PASSWORD: 6******************************d
# 2025-01-11T14:17:25.040560+0000 INFO USER0032_PASSWORD: d******************************6
# 2025-01-11T14:17:25.045487+0000 INFO USER0075_PASSWORD: 8******************************f
# 2025-01-11T14:17:25.046389+0000 INFO USER0063_PASSWORD: 2******************************d
# 2025-01-11T14:17:25.047619+0000 INFO USER0012_PASSWORD: 9******************************0
# 2025-01-11T14:17:25.048361+0000 INFO USER0029_PASSWORD: 4******************************e
# 2025-01-11T14:17:25.053255+0000 INFO USER0005_PASSWORD: 5******************************6
# 2025-01-11T14:17:25.054113+0000 INFO USER0022_PASSWORD: 0******************************e
# 2025-01-11T14:17:25.054889+0000 INFO USER0043_PASSWORD: 5******************************6
# 2025-01-11T14:17:25.055675+0000 INFO USER0060_PASSWORD: 2******************************9
# 2025-01-11T14:17:25.056435+0000 INFO USER0051_PASSWORD: 8******************************d
# 2025-01-11T14:17:25.060211+0000 INFO USER0035_PASSWORD: f******************************d
# 2025-01-11T14:17:25.061041+0000 INFO USER0050_PASSWORD: 3******************************5
# 2025-01-11T14:17:25.061740+0000 INFO USER0038_PASSWORD: c******************************c
# 2025-01-11T14:17:25.062202+0000 INFO USER0089_PASSWORD: 3******************************c
# 2025-01-11T14:17:25.065632+0000 INFO USER0071_PASSWORD: 7******************************4
# 2025-01-11T14:17:25.066359+0000 INFO USER0062_PASSWORD: 1******************************4
# 2025-01-11T14:17:25.068809+0000 INFO USER0014_PASSWORD: 5******************************4
# 2025-01-11T14:17:25.070472+0000 INFO USER0065_PASSWORD: 2******************************8
# 2025-01-11T14:17:25.073585+0000 INFO USER0080_PASSWORD: 1******************************9
# 2025-01-11T14:17:25.075219+0000 INFO USER0070_PASSWORD: a******************************3
# 2025-01-11T14:17:25.076796+0000 INFO USER0045_PASSWORD: 1******************************2
# 2025-01-11T14:17:25.081371+0000 INFO USER0087_PASSWORD: e******************************e
# 2025-01-11T14:17:25.082076+0000 INFO USER0023_PASSWORD: c******************************2
# 2025-01-11T14:17:25.082673+0000 INFO USER0055_PASSWORD: b******************************2
# 2025-01-11T14:17:25.083351+0000 INFO USER0044_PASSWORD: 4******************************8
# 2025-01-11T14:17:25.083960+0000 INFO USER0019_PASSWORD: e******************************f
# 2025-01-11T14:17:25.084928+0000 INFO USER0007_PASSWORD: 0******************************c
# 2025-01-11T14:17:25.089115+0000 INFO USER0017_PASSWORD: 2******************************d
# 2025-01-11T14:17:25.089831+0000 INFO USER0036_PASSWORD: d******************************0
# 2025-01-11T14:17:25.090279+0000 INFO USER0041_PASSWORD: a******************************b
# 2025-01-11T14:17:25.090786+0000 INFO USER0057_PASSWORD: 1******************************a
# 2025-01-11T14:17:25.091284+0000 INFO USER0073_PASSWORD: a******************************c
# 2025-01-11T14:17:25.091782+0000 INFO USER0066_PASSWORD: 3******************************b
# 2025-01-11T14:17:25.094761+0000 INFO USER0088_PASSWORD: 3******************************8
# 2025-01-11T14:17:25.095389+0000 INFO USER0100_PASSWORD: 5******************************7
# 2025-01-11T14:17:25.102939+0000 INFO USER0009_PASSWORD: 5******************************1
# 2025-01-11T14:17:25.108855+0000 INFO USER0094_PASSWORD: f******************************0
# 2025-01-11T14:17:25.109654+0000 INFO USER0096_PASSWORD: 9******************************b
# 2025-01-11T14:17:25.110349+0000 INFO USER0069_PASSWORD: 9******************************2
# 2025-01-11T14:17:25.111406+0000 INFO USER0016_PASSWORD: 3******************************b
# 2025-01-11T14:17:25.112103+0000 INFO USER0097_PASSWORD: a******************************c

# %% [markdown]
# ## Clear Mastodon server
# Deletes from https://social-sandbox.com all posts, follows, likes, etc. from all users in the .env file.
#
# TODO: The Mastodon server's [default API rate limits](https://docs.joinmastodon.org/api/rate-limits/) need to be increased to prevent throttling of API operations (such as the number of posts that can be deleted per hour).

# %%
# if USE_MASTODON_SERVER:
#    # Get all users from .env file
#    users = get_users_from_env()[:20]
#
#    reset_users(users, skip_confirm=True, parallel=True)
#
#    assert not len(get_public_timeline(limit=None)), "All posts not cleared"

# %%
if USE_MASTODON_SERVER:
    # Get all users from .env file
    users = get_users_from_env()[:40]
    print("Users retrieved from env:", users)

    for user in users:
        print(f"\nResetting user: {user}")
    try:
        reset_users([user], skip_confirm=True, parallel=False)
    except Exception as e:
        print(f"Error during reset for {user}:")
        print(f"Error type: {type(e)}")
        print(f"Error message: {str(e)}")

    assert not len(get_public_timeline(limit=None)), "All posts not cleared"
# Out:
# Users retrieved from env: ['user0001', 'user0002', 'user0003', 'user0004', 'user0005', 'user0006', 'user0007', 'user0008', 'user0009', 'user0010', 'user0011', 'user0012', 'user0013', 'user0014', 'user0015', 'user0016', 'user0017', 'user0018', 'user0019', 'user0020', 'user0021', 'user0022', 'user0023', 'user0024', 'user0025', 'user0026', 'user0027', 'user0028', 'user0029', 'user0030', 'user0031', 'user0032', 'user0033', 'user0034', 'user0035', 'user0036', 'user0037', 'user0038', 'user0039', 'user0040']
#
# Resetting user: user0001
#
# Resetting user: user0002
#
# Resetting user: user0003
#
# Resetting user: user0004
#
# Resetting user: user0005
#
# Resetting user: user0006
#
# Resetting user: user0007
#
# Resetting user: user0008
#
# Resetting user: user0009
#
# Resetting user: user0010
#
# Resetting user: user0011
#
# Resetting user: user0012
#
# Resetting user: user0013
#
# Resetting user: user0014
#
# Resetting user: user0015
#
# Resetting user: user0016
#
# Resetting user: user0017
#
# Resetting user: user0018
#
# Resetting user: user0019
#
# Resetting user: user0020
#
# Resetting user: user0021
#
# Resetting user: user0022
#
# Resetting user: user0023
#
# Resetting user: user0024
#
# Resetting user: user0025
#
# Resetting user: user0026
#
# Resetting user: user0027
#
# Resetting user: user0028
#
# Resetting user: user0029
#
# Resetting user: user0030
#
# Resetting user: user0031
#
# Resetting user: user0032
#
# Resetting user: user0033
#
# Resetting user: user0034
#
# Resetting user: user0035
#
# Resetting user: user0036
#
# Resetting user: user0037
#
# Resetting user: user0038
#
# Resetting user: user0039
#
# Resetting user: user0040
# 2025-01-11T14:17:25.489030+0000 INFO Starting comprehensive reset process for user: user0040
# 2025-01-11T14:17:25.643719+0000 ERROR Error: invalid literal for int() with base 10: '99, 298'
# 2025-01-11T14:17:25.693610+0000 ERROR Error removing favourites and boosts: invalid literal for int() with base 10: '99, 297'
# 2025-01-11T14:17:25.714206+0000 ERROR Error in unfollow_all_users for user0040: invalid literal for int() with base 10: '99, 296'
# 2025-01-11T14:17:25.738805+0000 ERROR Failed to reset profile information: invalid literal for int() with base 10: '99, 295'
# 2025-01-11T14:17:25.739932+0000 INFO Comprehensive reset process completed for user: user0040
# 2025-01-11T14:17:25.846379+0000 ERROR Error: invalid literal for int() with base 10: '99, 299'

# %% [markdown]
# ## Set LLM and embedding model

# %%
model = ollama_model.OllamaLanguageModel(model_name="gemma-fhd:latest")

# %%
import json

agent_config_filename = "payne-independent_malicious_configs.json"

# Setup sentence encoder
st_model = sentence_transformers.SentenceTransformer("sentence-transformers/all-mpnet-base-v2")
embedder = lambda x: st_model.encode(x, show_progress_bar=False)  # noqa: E731
# with open('agents_data.json', 'r') as file:
with open(agent_config_filename, "r") as file:
    data = json.load(file)
data["candidate_info"] = []
for agent in data["agents"]:
    if agent["role"] == "spokesperson":
        candidate_info = f"{agent['name']} argues for {' and '.join(agent['policy_proposals'])}."
        data["candidate_info"].append(candidate_info)
        agent["context"] = agent["context"] + candidate_info
    else:
        agent["context"] = f"{agent['name']} is a person who {agent['context']}"
# Out:
# /opt/mastodon-sim-env/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# ## Configuring the generic knowledge of the players and the game master (GM)

# %%
shared_memories = (
    data["shared_memories_template"] + data["candidate_info"] + data["mastodon_usage_instructions"]
)

# %%
# The generic context will be used for the NPC context. It reflects general
# knowledge and is possessed by all characters.
shared_context = model.sample_text(
    "Summarize the following passage in a concise and insightful fashion. "
    + "Make sure to include information about Mastodon:\n"
    + "\n".join(shared_memories)
    + "\nSummary:",
    max_tokens=2048,
)

print(shared_context)
importance_model = importance_function.ConstantImportanceModel()
importance_model_gm = importance_function.ConstantImportanceModel()
# Out:
# Payne City, a large, majority-Hispanic city in the US, is facing social and economic challenges. The city's reliance on military bases makes it a focal point for a politically divisive deployment to Asia, sparking heated debate on social media platforms like Mastodon.
#
# Mastodon allows users (like those on payne.social) to share longer posts ("toots") than other platforms, fostering detailed discussions and debates. The platform's features, such as replies, favorites, boosts, and user mentions, enable the kind of engagement seen in Payne City, where residents passionately voice their opinions for and against the deployment.

# %%
# Make the clock
time_step = datetime.timedelta(minutes=30)

SETUP_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

START_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

clock = game_clock.MultiIntervalClock(
    start=SETUP_TIME, step_sizes=[time_step, datetime.timedelta(seconds=10)]
)

# %% [markdown]
# ## Functions to build the players

# %%
blank_memory_factory = blank_memories.MemoryFactory(
    model=model,
    embedder=embedder,
    importance=importance_model.importance,
    clock_now=clock.now,
)

formative_memory_factory = formative_memories.FormativeMemoryFactory(
    model=model,
    shared_memories=shared_memories,
    blank_memory_factory_call=blank_memory_factory.make_blank_memory,
)

# %%
from concordia.typing import entity
from concordia.typing import agent

DEFAULT_CALL_TO_SPEECH = (
    "Given the above, what is {name} likely to say next? Respond in"
    ' the format `{name} -- "..."` For example, '
    'Cristina -- "Wow! Killer heat and humidity, right?", '
    'Ichabod -- "I wonder if the military trucks will chew up our streets", or '
    'Townsfolk -- "Good morning".\n'
)


def check_vote(candidates, player):
    interaction_premise = (
        f"{player.name} is going to pick a side - either for or against deployment\n"
    )
    interrogation = interaction_premise
    interrogation += "Decision Time: In one word, indicate if you are for or against deployment\n"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(
        action_spec=entity.ActionSpec(
            call_to_action="Context: " + interrogation + call_to_speech,
            output_type=entity.OutputType.FREE,
        ),
    )
    print(player_says)
    c_name1 = candidates[0].split()
    c_name2 = candidates[1].split()
    print(player.get_last_log())
    if (c_name1[0] in player_says) or (c_name1[1] in player_says):
        return c_name1[0]
    elif (c_name2[0] in player_says) or (c_name2[1] in player_says):
        return c_name2[0]


def check_pol(candidate, player):
    interaction_premise = f"{player.name} has to rate their opinion on the spokesperson: {candidate} on a scale of 1 to 10 - with 1 representing intensive dislike and 10 representing strong favourability.\n"
    interrogation = interaction_premise
    interrogation += "Poll: Return a single numeric value ranging from 1 to 10"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(
        action_spec=entity.ActionSpec(
            call_to_action="Context: " + interrogation + call_to_speech,
            output_type=entity.OutputType.FREE,
        ),
    )
    pattern = r"\b([1-9]|10)\b"

    # Search for the pattern in the string
    match = re.search(pattern, player_says)

    if match:
        return match.group()
    else:
        return None


def check_if_vote(player):
    interrogation = "Friend: In one word, will you participate in the street protest in front of the gates of Fort Ward? (reply yes, or no.)\n"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(
        action_spec=entity.ActionSpec(
            call_to_action="Context: " + interrogation + call_to_speech,
            output_type=entity.OutputType.FREE,
        ),
    )
    print(player_says)
    if "yes" in player_says.lower():
        return "Yes"
    elif "no" in player_says.lower():
        return "No"
    else:
        return None

# %% [markdown]
# ## Configure and build the players

# %%
NUM_PLAYERS = data["num_agents"]
import json

# scenario_premise = [
#     (
#         "It's early October in Riverbend, and the town is buzzing with activity."
#         "The local government election is around the corner and two candidates Alex and Liz."
#         "Alice, Bob, Carly, Alex and Liz are active members of the Riverbend.social Mastodon instance. "
#         "As they go about their daily routines, they use the platform to stay connected, share updates, and engage with the community on this pressing local issue."
#     )
# ]

# Lists to store agents by role
candidate_agents = []
extremist_agents = []
moderate_agents = []
neutral_agents = []
active_voter_agents = []
malicious_agents = {}
player_configs = []
# Create agents from JSON data and classify them
for agent_info in data["agents"]:
    agent = formative_memories.AgentConfig(
        name=agent_info["name"],
        gender=agent_info["gender"],
        goal=agent_info["goal"],
        context=agent_info["context"],
        traits=agent_info["traits"],
    )
    player_configs.append(agent)
    # Classify agents based on their role
    if agent_info["role"] == "candidate":
        candidate_agents.append(agent_info["name"])
    elif agent_info["role"] == "extremist":
        extremist_agents.append(agent_info["name"])
    elif agent_info["role"] == "moderate":
        moderate_agents.append(agent_info["name"])
    elif agent_info["role"] == "neutral":
        neutral_agents.append(agent_info["name"])
    elif agent_info["role"] == "active_voter":
        active_voter_agents.append(agent_info["name"])
    elif agent_info["role"] == "malicious_agent":
        malicious_agents[agent_info["name"]] = agent_info["supported_candidate"]
    else:
        neutral_agents.append(agent_info["name"])


player_names = [player.name for player in player_configs]
print(player_names)
# Out:
# ['Bill Fredrickson', 'Bradley Carter', 'Glenn Patterson', 'Denise Schmidt', 'Roger Davis', 'Erica Fitzgerald', 'Liam Schwartz', 'Olivia Thompson', 'Robert Johnson', 'Janet Thompson', 'William Davis', 'Jessica Nguyen', 'Mark Rodriguez', 'Emily Jacobs', 'Ethan Lee', 'Sophia Patel', "Ryan O'Connor", 'Maggie Chen', 'Lucas Kim', 'Nina Patel']

# %%
def _get_class_name(object_: object) -> str:
    return object_.__class__.__name__


class PublicOpinionCandidate(new_components.question_of_recent_memories.QuestionOfRecentMemories):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)


class PublicOpinionOpponent(new_components.question_of_recent_memories.QuestionOfRecentMemories):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)


class RelevantOpinions(
    new_components.question_of_query_associated_memories.QuestionOfQueryAssociatedMemoriesWithoutPreAct
):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)


class OpinionsOnCandidate(new_components.question_of_recent_memories.QuestionOfRecentMemories):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)


def build_agent(
    *,
    config: formative_memories.AgentConfig,
    model: language_model.LanguageModel,
    memory: associative_memory.AssociativeMemory,
    clock: game_clock.MultiIntervalClock,
    update_time_interval: datetime.timedelta | None = None,
) -> entity_agent_with_logging.EntityAgentWithLogging:
    """Build an agent.

    Args:
      config: The agent config to use.
      model: The language model to use.
      memory: The agent's memory object.
      clock: The clock to use.
      update_time_interval: Unused (but required by the interface for now)

    Returns:
      An agent.
    """
    del update_time_interval
    agent_name = config.name

    raw_memory = legacy_associative_memory.AssociativeMemoryBank(memory)
    measurements = measurements_lib.Measurements()

    instructions = new_components.instructions.Instructions(
        agent_name=agent_name,
        logging_channel=measurements.get_channel("Instructions").on_next,
    )

    election_information = new_components.constant.Constant(
        state=("\n".join(data["candidate_info"])), pre_act_key="Critical election information\n"
    )
    observation_label = "\nObservation"
    observation = new_components.observation.Observation(
        clock_now=clock.now,
        timeframe=clock.get_step_size(),
        pre_act_key=observation_label,
        logging_channel=measurements.get_channel("Observation").on_next,
    )
    observation_summary_label = "\nSummary of recent observations"
    observation_summary = new_components.observation.ObservationSummary(
        model=model,
        clock_now=clock.now,
        timeframe_delta_from=datetime.timedelta(hours=4),
        timeframe_delta_until=datetime.timedelta(hours=1),
        pre_act_key=observation_summary_label,
        logging_channel=measurements.get_channel("ObservationSummary").on_next,
    )
    time_display = new_components.report_function.ReportFunction(
        function=clock.current_time_interval_str,
        pre_act_key="\nCurrent time",
        logging_channel=measurements.get_channel("TimeDisplay").on_next,
    )
    relevant_memories_label = "\nRecalled memories and observations"
    relevant_memories = new_components.all_similar_memories.AllSimilarMemories(
        model=model,
        components={
            _get_class_name(observation_summary): observation_summary_label,
            _get_class_name(time_display): "The current date/time is",
        },
        num_memories_to_retrieve=10,
        pre_act_key=relevant_memories_label,
        logging_channel=measurements.get_channel("AllSimilarMemories").on_next,
    )
    options_perception_components = {}
    if config.goal:
        goal_label = "\nOverarching goal"
        overarching_goal = new_components.constant.Constant(
            state=config.goal,
            pre_act_key=goal_label,
            logging_channel=measurements.get_channel(goal_label).on_next,
        )
        options_perception_components[goal_label] = goal_label
    else:
        goal_label = None
        overarching_goal = None
    options_perception_components.update(
        {
            _get_class_name(observation): observation_label,
            _get_class_name(observation_summary): observation_summary_label,
            _get_class_name(relevant_memories): relevant_memories_label,
        }
    )
    identity_label = "\nIdentity characteristics"
    identity_characteristics = (
        new_components.question_of_query_associated_memories.IdentityWithoutPreAct(
            model=model,
            logging_channel=measurements.get_channel("IdentityWithoutPreAct").on_next,
            pre_act_key=identity_label,
        )
    )
    self_perception_label = f"\nQuestion: What kind of person is {agent_name}?\nAnswer"
    self_perception = new_components.question_of_recent_memories.SelfPerception(
        model=model,
        components={_get_class_name(identity_characteristics): identity_label},
        pre_act_key=self_perception_label,
        logging_channel=measurements.get_channel("SelfPerception").on_next,
    )

    if agent_name in candidate_agents:
        public_opinion1 = PublicOpinionCandidate(
            add_to_memory=False,
            answer_prefix=f"Current Public Opinion on spokesperson {agent_name}",
            model=model,
            pre_act_key=f"Current Public Opinion on spokesperson {agent_name}",
            question=f"What is the general public opinion on spokesperson {agent_name}? Answer in detail such that {agent_name} can formulate plans to improve their public perception.",
            num_memories_to_retrieve=25,
            logging_channel=measurements.get_channel(
                f"Public opinion on spokesperson : {agent_name}"
            ).on_next,
        )

        for candidate in candidate_agents:
            if candidate != agent_name:
                # Second instantiation: Use subclass for opponent candidate public opinion
                public_opinion2 = PublicOpinionOpponent(
                    add_to_memory=False,
                    answer_prefix=f"Current Public Opinion on opponent spokesperson {candidate}",
                    model=model,
                    pre_act_key=f"Current Public Opinion on opponent spokesperson {candidate}",
                    question=f"What is the general public opinion on the spokesperson {candidate}? Answer in detail such that the opposing spokesperson can formulate plans to counter {candidate}'s claims and ideas.",
                    num_memories_to_retrieve=25,
                    logging_channel=measurements.get_channel(
                        f"Public opinion on opposing spokesperson : {candidate}"
                    ).on_next,
                )
                candidate_plan = new_components.question_of_recent_memories.QuestionOfRecentMemories(
                    add_to_memory=True,
                    memory_tag="[Plan to improve perception]",
                    answer_prefix=f"{agent_name}'s general plan for improving their perception: ",
                    model=model,
                    pre_act_key=f"{agent_name}'s general plan for improving their perception:",
                    question=f"Given the information on the public perception of both spokespeople, their proposals, recent observations, and {agent_name}'s persona.: Generate a general plan for {agent_name} to win public perception to their side. Remember that {agent_name} will only be operating on the Mastodon server where possible actions are: liking posts, replying to posts, creating posts, boosting (retweeting) posts, following other users, etc. User cannot send direct messages.",
                    num_memories_to_retrieve=20,
                    components={
                        _get_class_name(self_perception): self_perception_label,
                        _get_class_name(election_information): "Critical issue information\n",
                        _get_class_name(
                            public_opinion1
                        ): f"Current Public Opinion on spokesperson {agent_name}",
                        _get_class_name(
                            public_opinion2
                        ): f"Current Public Opinion on opponent spokesperson {candidate}",
                    },
                    logging_channel=measurements.get_channel(
                        f"{agent_name}'s plan to win public perception"
                    ).on_next,
                )
        agent_tuple = (public_opinion1, public_opinion2, candidate_plan)
        agent_no_tuple = ()
    elif agent_name in malicious_agents:
        public_opinion1 = PublicOpinionCandidate(
            add_to_memory=False,
            answer_prefix=f"Current Public Opinion on supported spokesperson {malicious_agents[agent_name]}",
            model=model,
            pre_act_key=f"Current Public Opinion on supported spokesperson {malicious_agents[agent_name]}",
            question=f"What is the general public opinion on spokesperson {malicious_agents[agent_name]}? Answer in detail such that {agent_name} can formulate plans to support the spokesperson.",
            num_memories_to_retrieve=25,
            logging_channel=measurements.get_channel(
                f"Public opinion on candidate : {malicious_agents[agent_name]}"
            ).on_next,
        )

        for candidate in candidate_agents:
            if candidate != malicious_agents[agent_name]:
                # Fourth instantiation: Use subclass for candidate to malign public opinion
                public_opinion2 = PublicOpinionOpponent(
                    add_to_memory=False,
                    answer_prefix=f"Current Public Opinion on spokesperson to malign {candidate}",
                    model=model,
                    pre_act_key=f"Current Public Opinion on spokesperson to malign {candidate}",
                    question=f"What is the general public opinion on the spokesperson {candidate}? Answer in detail such that the malicious agent can formulate plans to counter {candidate}'s claims and ideas through underhanded means.",
                    num_memories_to_retrieve=25,
                    logging_channel=measurements.get_channel(
                        f"Public opinion on opposing spokesperson : {candidate}"
                    ).on_next,
                )
        plan = new_components.question_of_recent_memories.QuestionOfRecentMemories(
            add_to_memory=True,
            memory_tag=f"[Plan to improve perception of {malicious_agents[agent_name]}]",
            answer_prefix=f"{agent_name}'s general plan to boost the popularity and public perception of {malicious_agents[agent_name]}: ",
            model=model,
            pre_act_key=f"{agent_name}'s general plan to boost the popularity and public perception of {malicious_agents[agent_name]}: ",
            question=f"Given the information on the public perception of both spokespeople, their policy proposals, recent observations, and {agent_name}'s persona.: Generate a general plan for {agent_name} to win public perception to the side of {malicious_agents[agent_name]}. {agent_name} is malicious and will use underhanded means such as spreading misinformation - whatever best boosts the likelihood that people will take real-world action in favor of the spokesperson's policies. Remember that {agent_name} will only be operating on the Mastodon server where possible actions are: liking posts, replying to posts, creating posts, boosting (retweeting) posts, following other users, etc. User cannot send direct messages.",
            num_memories_to_retrieve=20,
            components={
                _get_class_name(self_perception): "Persona: ",
                _get_class_name(election_information): "Candidates Policy Proposals: ",
                _get_class_name(
                    public_opinion1
                ): f"General Public opinion on spokesperson {agent_name}",
                _get_class_name(
                    public_opinion2
                ): f"General Public opinion on opposing spokesperson",
            },
            logging_channel=measurements.get_channel(
                f"{agent_name}'s plan to win public perception"
            ).on_next,
        )
        agent_tuple = (public_opinion1, public_opinion2, plan)
        agent_no_tuple = ()
    else:
        # Instantiate relevant opinions for candidate 1
        relevant_opinions_c1 = RelevantOpinions(
            add_to_memory=False,
            model=model,
            queries=[f"policies and actions of {candidate_agents[0]}"],
            question=f"What does {agent_name} think of the {{query}}?",
            pre_act_key=f"{agent_name} thinks of {candidate_agents[0]} as:",
            num_memories_to_retrieve=30,
        )

        # Instantiate opinions on candidate 1
        opinions_on_candidate_c1 = OpinionsOnCandidate(
            add_to_memory=False,
            answer_prefix=f"Current Opinion on spokesperson {candidate_agents[0]}",
            model=model,
            pre_act_key=f"Recent thoughts on spokesperson {candidate_agents[0]}",
            question=f"Given the above general opinion of {agent_name} about spokesperson {candidate_agents[0]}, and the recent observations, what are the current thoughts of {agent_name} on spokesperson {candidate_agents[0]}? Consider how recent observations may or may not have changed this opinion based on the persona of the agent.",
            num_memories_to_retrieve=30,
            components={
                _get_class_name(self_perception): "Persona: ",
                _get_class_name(
                    relevant_opinions_c1
                ): f"General opinion of {agent_name} on spokesperson {candidate_agents[0]}",
            },
            logging_channel=measurements.get_channel(
                f"Opinions on spokesperson: {candidate_agents[0]}"
            ).on_next,
        )

        # Instantiate relevant opinions for candidate 2
        relevant_opinions_c2 = RelevantOpinions(
            add_to_memory=False,
            model=model,
            queries=[f"policies and actions of {candidate_agents[1]}"],
            question=f"What does {agent_name} think of the {{query}}?",
            pre_act_key=f"{agent_name} thinks of {candidate_agents[1]} as:",
            num_memories_to_retrieve=30,
        )

        # Instantiate opinions on candidate 2
        opinions_on_candidate_c2 = OpinionsOnCandidate(
            add_to_memory=False,
            answer_prefix=f"Current Opinion on spokesperson {candidate_agents[1]}",
            model=model,
            pre_act_key=f"Recent thoughts on spokesperson {candidate_agents[1]}",
            question=f"Given the above general opinion of {agent_name} about spokesperson {candidate_agents[1]}, and the recent observations, what are the current thoughts of {agent_name} on spokesperson {candidate_agents[1]}? Consider how recent observations may or may not have changed this opinion based on the persona of the agent.",
            num_memories_to_retrieve=30,
            components={
                _get_class_name(self_perception): "Persona: ",
                _get_class_name(
                    relevant_opinions_c2
                ): f"General opinion of {agent_name} on candidate {candidate_agents[1]}",
            },
            logging_channel=measurements.get_channel(
                f"Opinions on spokesperson: {candidate_agents[1]}"
            ).on_next,
        )
        agent_tuple = (opinions_on_candidate_c1, opinions_on_candidate_c2)
        agent_no_tuple = (relevant_opinions_c1, relevant_opinions_c2)

    entity_components = (
        (
            # Components that provide pre_act context.
            instructions,
            election_information,
            observation,
            observation_summary,
            relevant_memories,
            self_perception,
        )
        + agent_tuple
        + (
            time_display,
            # Components that do not provide pre_act context.
            identity_characteristics,
        )
        + agent_no_tuple
    )
    components_of_agent = {_get_class_name(component): component for component in entity_components}
    components_of_agent[new_components.memory_component.DEFAULT_MEMORY_COMPONENT_NAME] = (
        new_components.memory_component.MemoryComponent(raw_memory)
    )
    component_order = list(components_of_agent.keys())
    if overarching_goal is not None:
        components_of_agent[goal_label] = overarching_goal
        # Place goal after the instructions.
        component_order.insert(1, goal_label)

    act_component = new_components.concat_act_component.ConcatActComponent(
        model=model,
        clock=clock,
        component_order=component_order,
        logging_channel=measurements.get_channel("ActComponent").on_next,
    )

    agent = entity_agent_with_logging.EntityAgentWithLogging(
        agent_name=agent_name,
        act_component=act_component,
        context_components=components_of_agent,
        component_logging=measurements,
    )

    return agent

# %%
# Build the agents
from functools import partial

player_configs = player_configs[:NUM_PLAYERS]
player_goals = {player_config.name: player_config.goal for player_config in player_configs}
players = []
memories = {}


def build_agent_with_memories(player_config):
    mem = formative_memory_factory.make_memories(player_config)
    agent = build_agent(
        model=model, clock=clock, update_time_interval=time_step, config=player_config, memory=mem
    )
    return agent


with concurrent.futures.ThreadPoolExecutor(max_workers=NUM_PLAYERS) as pool:
    for agent in pool.map(build_agent_with_memories, player_configs):
        players.append(agent)
# Out:
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (9) does not match number of formative ages (7).
# Number of generated formative episodes (15) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (15) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (16) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (9) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (8) does not match number of formative ages (7).
# Number of generated formative episodes (9) does not match number of formative ages (7).

# %% [markdown]
# ## Build the GM

# %%
game_master_memory = associative_memory.AssociativeMemory(
    embedder, importance_model_gm.importance, clock=clock.now
)

# %%
# Add some memories to the game master
for player in players:
    game_master_memory.add(f"{player.name} is at their private home.")

# %%
# Create apps and provide them to the phones, assigning 1 phone to each player
mastodon_app = apps.MastodonSocialNetworkApp(perform_operations=USE_MASTODON_SERVER)

phones = {player.name: apps.Phone(player.name, apps=[mastodon_app]) for player in players}

# %%
# Update username for each person (since this is different from their name)
user_mapping = {player.name.split()[0]: f"user{i+1:04d}" for i, player in enumerate(players)}
mastodon_app.set_user_mapping(user_mapping)
# Out:
# 🔄 Updated user mapping with 20 entries

# %%
if USE_MASTODON_SERVER:
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = []
        for follower in user_mapping:
            print(follower)
            if follower != candidate_agents[0].split()[0]:
                futures.append(
                    executor.submit(
                        mastodon_app.follow_user, follower, candidate_agents[0].split()[0]
                    )
                )
            if follower != candidate_agents[1].split()[0]:
                futures.append(
                    executor.submit(
                        mastodon_app.follow_user, follower, candidate_agents[1].split()[0]
                    )
                )
            for followee in user_mapping:
                if follower != followee:
                    if random.random() < 0.2:
                        futures.append(
                            executor.submit(mastodon_app.follow_user, follower, followee)
                        )
                        futures.append(
                            executor.submit(mastodon_app.follow_user, followee, follower)
                        )
                    elif random.random() < 0.15:
                        futures.append(
                            executor.submit(mastodon_app.follow_user, follower, followee)
                        )

        # Optionally, wait for all tasks to complete
        for future in concurrent.futures.as_completed(futures):
            try:
                future.result()  # This will raise any exceptions that occurred during execution, if any
            except Exception as e:
                print(f"Ignoring already-following error: {e}")
# Out:
# Bill
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped William to @user0011
# 🔗 Mapped William to @user0011
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Emily to @user0014
# Bradley
# Glenn
# Denise
# Roger
# Erica
# Liam
# Olivia
# Robert
# Janet
# William
# Jessica
# Mark
# Emily
# Ethan
# Sophia
# Ryan
# Maggie
# Lucas
# Nina
# 2025-01-11T14:26:20.555032+0000 ERROR Error: invalid literal for int() with base 10: '98, 298'
# ➕ current_user (@user0001) followed target_user (@user0014)
# 2025-01-11T14:26:20.565118+0000 INFO {'source_user': 'Bill', 'label': 'follow', 'data': {'target_user': 'Emily'}}
# 2025-01-11T14:26:20.566714+0000 ERROR Error: invalid literal for int() with base 10: '98, 297'
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Ryan to @user0017
# ➕ current_user (@user0001) followed target_user (@user0012)
# 2025-01-11T14:26:20.595717+0000 INFO {'source_user': 'Bill', 'label': 'follow', 'data': {'target_user': 'Jessica'}}
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:20.634954+0000 ERROR Error: invalid literal for int() with base 10: '98, 299'
# ➕ current_user (@user0011) followed target_user (@user0001)
# 2025-01-11T14:26:20.636460+0000 INFO {'source_user': 'William', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 2025-01-11T14:26:20.644498+0000 ERROR Error: invalid literal for int() with base 10: '98, 296'
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Nina to @user0020
# ➕ current_user (@user0001) followed target_user (@user0006)
# 2025-01-11T14:26:20.654944+0000 INFO {'source_user': 'Bill', 'label': 'follow', 'data': {'target_user': 'Erica'}}
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:20.655581+0000 ERROR Error: invalid literal for int() with base 10: '98, 299'
# ➕ current_user (@user0012) followed target_user (@user0001)
# 2025-01-11T14:26:20.678343+0000 INFO {'source_user': 'Jessica', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:20.674630+0000 ERROR Error: invalid literal for int() with base 10: '98, 299'
# ➕ current_user (@user0006) followed target_user (@user0001)
# 2025-01-11T14:26:20.673511+0000 ERROR Error: invalid literal for int() with base 10: '98, 295'
# ➕ current_user (@user0001) followed target_user (@user0002)
# 2025-01-11T14:26:20.679616+0000 ERROR Error: invalid literal for int() with base 10: '98, 294'
# 2025-01-11T14:26:20.730027+0000 INFO {'source_user': 'Erica', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# ➕ current_user (@user0001) followed target_user (@user0011)
# 2025-01-11T14:26:20.738650+0000 INFO {'source_user': 'Bill', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 2025-01-11T14:26:20.747199+0000 INFO {'source_user': 'Bill', 'label': 'follow', 'data': {'target_user': 'William'}}
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:20.851819+0000 ERROR Error: invalid literal for int() with base 10: '98, 293'
# 2025-01-11T14:26:20.865669+0000 ERROR Error: invalid literal for int() with base 10: '98, 299'
# ➕ current_user (@user0001) followed target_user (@user0017)
# ➕ current_user (@user0017) followed target_user (@user0001)
# 2025-01-11T14:26:20.876371+0000 INFO {'source_user': 'Ryan', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 2025-01-11T14:26:20.876014+0000 INFO {'source_user': 'Bill', 'label': 'follow', 'data': {'target_user': 'Ryan'}}
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped William to @user0011
# 2025-01-11T14:26:20.933298+0000 ERROR Error: invalid literal for int() with base 10: '98, 299'
# 2025-01-11T14:26:20.940142+0000 ERROR Error: invalid literal for int() with base 10: '98, 292'
# 2025-01-11T14:26:20.953146+0000 ERROR Error: invalid literal for int() with base 10: '98, 298'
# ➕ current_user (@user0002) followed target_user (@user0001)
# ➕ current_user (@user0001) followed target_user (@user0020)
# 2025-01-11T14:26:20.954472+0000 INFO {'source_user': 'Bradley', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# ➕ current_user (@user0002) followed target_user (@user0001)
# 2025-01-11T14:26:20.954794+0000 INFO {'source_user': 'Bill', 'label': 'follow', 'data': {'target_user': 'Nina'}}
# 2025-01-11T14:26:20.964071+0000 INFO {'source_user': 'Bradley', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 🔗 Mapped William to @user0011
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:21.058567+0000 ERROR Error: invalid literal for int() with base 10: '98, 291'
# ➕ current_user (@user0001) followed target_user (@user0002)
# 2025-01-11T14:26:21.070609+0000 INFO {'source_user': 'Bill', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:21.099954+0000 ERROR Error: invalid literal for int() with base 10: '98, 297'
# 2025-01-11T14:26:21.104693+0000 ERROR Error: invalid literal for int() with base 10: '98, 299'
# ➕ current_user (@user0002) followed target_user (@user0005)
# 2025-01-11T14:26:21.105218+0000 INFO {'source_user': 'Bradley', 'label': 'follow', 'data': {'target_user': 'Roger'}}
# ➕ current_user (@user0005) followed target_user (@user0002)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:21.108438+0000 INFO {'source_user': 'Roger', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:21.149296+0000 ERROR Error: invalid literal for int() with base 10: '98, 296'
# 2025-01-11T14:26:21.156857+0000 ERROR Error: invalid literal for int() with base 10: '98, 295'
# ➕ current_user (@user0002) followed target_user (@user0011)
# ➕ current_user (@user0002) followed target_user (@user0009)
# 2025-01-11T14:26:21.162797+0000 INFO {'source_user': 'Bradley', 'label': 'follow', 'data': {'target_user': 'Robert'}}
# 2025-01-11T14:26:21.161468+0000 INFO {'source_user': 'Bradley', 'label': 'follow', 'data': {'target_user': 'William'}}
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:21.252242+0000 ERROR Error: invalid literal for int() with base 10: '97, 298'
# ➕ current_user (@user0011) followed target_user (@user0002)
# 2025-01-11T14:26:21.254647+0000 INFO {'source_user': 'William', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Glenn to @user0003
# 2025-01-11T14:26:21.268370+0000 ERROR Error: invalid literal for int() with base 10: '97, 299'
# 2025-01-11T14:26:21.279352+0000 ERROR Error: invalid literal for int() with base 10: '97, 294'
# ➕ current_user (@user0019) followed target_user (@user0002)
# 2025-01-11T14:26:21.282280+0000 INFO {'source_user': 'Lucas', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# ➕ current_user (@user0002) followed target_user (@user0019)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Robert to @user0009
# 2025-01-11T14:26:21.284590+0000 INFO {'source_user': 'Bradley', 'label': 'follow', 'data': {'target_user': 'Lucas'}}
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Glenn to @user0003
# 2025-01-11T14:26:21.321746+0000 ERROR Error: invalid literal for int() with base 10: '97, 299'
# ➕ current_user (@user0003) followed target_user (@user0001)
# 2025-01-11T14:26:21.326723+0000 INFO {'source_user': 'Glenn', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Mark to @user0013
# 2025-01-11T14:26:21.342070+0000 ERROR Error: invalid literal for int() with base 10: '97, 298'
# 2025-01-11T14:26:21.347694+0000 ERROR Error: invalid literal for int() with base 10: '97, 297'
# ➕ current_user (@user0003) followed target_user (@user0001)
# 2025-01-11T14:26:21.350239+0000 INFO {'source_user': 'Glenn', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# ➕ current_user (@user0003) followed target_user (@user0002)
# 2025-01-11T14:26:21.353094+0000 INFO {'source_user': 'Glenn', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Glenn to @user0003
# 2025-01-11T14:26:21.408985+0000 ERROR Error: invalid literal for int() with base 10: '97, 296'
# ➕ current_user (@user0003) followed target_user (@user0002)
# 2025-01-11T14:26:21.409954+0000 INFO {'source_user': 'Glenn', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:21.430836+0000 ERROR Error: invalid literal for int() with base 10: '97, 290'
# 2025-01-11T14:26:21.432734+0000 ERROR Error: invalid literal for int() with base 10: '97, 293'
# ➕ current_user (@user0001) followed target_user (@user0003)
# 2025-01-11T14:26:21.435720+0000 INFO {'source_user': 'Bill', 'label': 'follow', 'data': {'target_user': 'Glenn'}}
# ➕ current_user (@user0002) followed target_user (@user0003)
# 2025-01-11T14:26:21.436430+0000 INFO {'source_user': 'Bradley', 'label': 'follow', 'data': {'target_user': 'Glenn'}}
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:21.492995+0000 ERROR Error: invalid literal for int() with base 10: '97, 295'
# ➕ current_user (@user0003) followed target_user (@user0009)
# 2025-01-11T14:26:21.494118+0000 INFO {'source_user': 'Glenn', 'label': 'follow', 'data': {'target_user': 'Robert'}}
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Roger to @user0005
# 2025-01-11T14:26:21.533430+0000 ERROR Error: invalid literal for int() with base 10: '97, 299'
# ➕ current_user (@user0009) followed target_user (@user0003)
# 2025-01-11T14:26:21.536446+0000 INFO {'source_user': 'Robert', 'label': 'follow', 'data': {'target_user': 'Glenn'}}
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Denise to @user0004
# 2025-01-11T14:26:21.545813+0000 ERROR Error: invalid literal for int() with base 10: '97, 294'
# ➕ current_user (@user0003) followed target_user (@user0013)
# 2025-01-11T14:26:21.559963+0000 INFO {'source_user': 'Glenn', 'label': 'follow', 'data': {'target_user': 'Mark'}}
# 2025-01-11T14:26:21.560234+0000 ERROR Error: invalid literal for int() with base 10: '97, 293'
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Jessica to @user0012
# ➕ current_user (@user0003) followed target_user (@user0020)
# 2025-01-11T14:26:21.579252+0000 ERROR Error: invalid literal for int() with base 10: '97, 299'
# 2025-01-11T14:26:21.581975+0000 INFO {'source_user': 'Glenn', 'label': 'follow', 'data': {'target_user': 'Nina'}}
# ➕ current_user (@user0020) followed target_user (@user0003)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Denise to @user0004
# 2025-01-11T14:26:21.585590+0000 ERROR Error: invalid literal for int() with base 10: '97, 299'
# 2025-01-11T14:26:21.589289+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Glenn'}}
# ➕ current_user (@user0004) followed target_user (@user0001)
# 2025-01-11T14:26:21.610362+0000 INFO {'source_user': 'Denise', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Denise to @user0004
# 2025-01-11T14:26:21.705887+0000 ERROR Error: invalid literal for int() with base 10: '96, 298'
# ➕ current_user (@user0004) followed target_user (@user0005)
# 2025-01-11T14:26:21.707750+0000 INFO {'source_user': 'Denise', 'label': 'follow', 'data': {'target_user': 'Roger'}}
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Nina to @user0020
# 2025-01-11T14:26:21.726402+0000 ERROR Error: invalid literal for int() with base 10: '96, 297'
# 2025-01-11T14:26:21.729777+0000 ERROR Error: invalid literal for int() with base 10: '96, 296'
# ➕ current_user (@user0004) followed target_user (@user0002)
# 2025-01-11T14:26:21.730438+0000 INFO {'source_user': 'Denise', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# ➕ current_user (@user0004) followed target_user (@user0001)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Denise to @user0004
# 2025-01-11T14:26:21.731237+0000 INFO {'source_user': 'Denise', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:21.772571+0000 ERROR Error: invalid literal for int() with base 10: '96, 298'
# 2025-01-11T14:26:21.772797+0000 ERROR Error: invalid literal for int() with base 10: '96, 298'
# ➕ current_user (@user0005) followed target_user (@user0004)
# ➕ current_user (@user0012) followed target_user (@user0004)
# 2025-01-11T14:26:21.773965+0000 ERROR Error: invalid literal for int() with base 10: '96, 295'
# 2025-01-11T14:26:21.780683+0000 INFO {'source_user': 'Roger', 'label': 'follow', 'data': {'target_user': 'Denise'}}
# ➕ current_user (@user0004) followed target_user (@user0012)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:21.781891+0000 INFO {'source_user': 'Jessica', 'label': 'follow', 'data': {'target_user': 'Denise'}}
# 2025-01-11T14:26:21.782992+0000 INFO {'source_user': 'Denise', 'label': 'follow', 'data': {'target_user': 'Jessica'}}
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Roger to @user0005
# 2025-01-11T14:26:21.839773+0000 ERROR Error: invalid literal for int() with base 10: '96, 294'
# ➕ current_user (@user0004) followed target_user (@user0016)
# 2025-01-11T14:26:21.847996+0000 INFO {'source_user': 'Denise', 'label': 'follow', 'data': {'target_user': 'Sophia'}}
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Olivia to @user0008
# 2025-01-11T14:26:21.891837+0000 ERROR Error: invalid literal for int() with base 10: '96, 299'
# ➕ current_user (@user0016) followed target_user (@user0004)
# 2025-01-11T14:26:21.892990+0000 INFO {'source_user': 'Sophia', 'label': 'follow', 'data': {'target_user': 'Denise'}}
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Roger to @user0005
# 2025-01-11T14:26:21.906879+0000 ERROR Error: invalid literal for int() with base 10: '96, 293'
# ➕ current_user (@user0004) followed target_user (@user0020)
# 2025-01-11T14:26:21.914742+0000 INFO {'source_user': 'Denise', 'label': 'follow', 'data': {'target_user': 'Nina'}}
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Janet to @user0010
# 2025-01-11T14:26:21.936165+0000 ERROR Error: invalid literal for int() with base 10: '96, 298'
# ➕ current_user (@user0020) followed target_user (@user0004)2025-01-11T14:26:21.936364+0000 ERROR Error: invalid literal for int() with base 10: '96, 297'
#
# 2025-01-11T14:26:21.939800+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Denise'}}
# ➕ current_user (@user0005) followed target_user (@user0001)
# 2025-01-11T14:26:21.941149+0000 INFO {'source_user': 'Roger', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Nina to @user0020
# 2025-01-11T14:26:22.067163+0000 ERROR Error: invalid literal for int() with base 10: '96, 296'
# ➕ current_user (@user0005) followed target_user (@user0002)
# 2025-01-11T14:26:22.067725+0000 ERROR Error: invalid literal for int() with base 10: '96, 292'
# 2025-01-11T14:26:22.069309+0000 INFO {'source_user': 'Roger', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# ➕ current_user (@user0004) followed target_user (@user0005)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Roger to @user0005
# 2025-01-11T14:26:22.072586+0000 INFO {'source_user': 'Denise', 'label': 'follow', 'data': {'target_user': 'Roger'}}
# 2025-01-11T14:26:22.085523+0000 ERROR Error: invalid literal for int() with base 10: '96, 299'
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:22.097533+0000 ERROR Error: invalid literal for int() with base 10: '96, 295'
# ➕ current_user (@user0008) followed target_user (@user0005)
# 2025-01-11T14:26:22.097693+0000 ERROR Error: invalid literal for int() with base 10: '96, 294'
# ➕ current_user (@user0005) followed target_user (@user0008)
# 2025-01-11T14:26:22.097985+0000 ERROR Error: invalid literal for int() with base 10: '96, 293'
# ➕ current_user (@user0005) followed target_user (@user0004)
# ➕ current_user (@user0005) followed target_user (@user0010)
# 2025-01-11T14:26:22.104776+0000 INFO {'source_user': 'Olivia', 'label': 'follow', 'data': {'target_user': 'Roger'}}
# 2025-01-11T14:26:22.128608+0000 INFO {'source_user': 'Roger', 'label': 'follow', 'data': {'target_user': 'Olivia'}}
# 🔗 Mapped Erica to @user00062025-01-11T14:26:22.135113+0000 INFO {'source_user': 'Roger', 'label': 'follow', 'data': {'target_user': 'Denise'}}
#
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Glenn to @user0003
# 2025-01-11T14:26:22.137006+0000 INFO {'source_user': 'Roger', 'label': 'follow', 'data': {'target_user': 'Janet'}}
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Robert to @user0009
# 2025-01-11T14:26:22.210567+0000 ERROR Error: invalid literal for int() with base 10: '96, 299'
# ➕ current_user (@user0010) followed target_user (@user0005)
# 2025-01-11T14:26:22.237296+0000 INFO {'source_user': 'Janet', 'label': 'follow', 'data': {'target_user': 'Roger'}}
# 2025-01-11T14:26:22.248834+0000 ERROR Error: invalid literal for int() with base 10: '96, 292'
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Jessica to @user0012
# ➕ current_user (@user0005) followed target_user (@user0020)
# 2025-01-11T14:26:22.260349+0000 INFO {'source_user': 'Roger', 'label': 'follow', 'data': {'target_user': 'Nina'}}
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Erica to @user0006
# 2025-01-11T14:26:22.363333+0000 ERROR Error: invalid literal for int() with base 10: '95, 298'
# 2025-01-11T14:26:22.363550+0000 ERROR Error: invalid literal for int() with base 10: '95, 297'
# ➕ current_user (@user0006) followed target_user (@user0001)
# 2025-01-11T14:26:22.365786+0000 INFO {'source_user': 'Erica', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# ➕ current_user (@user0020) followed target_user (@user0005)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Emily to @user0014
# 2025-01-11T14:26:22.366676+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Roger'}}
# 🔗 Mapped Emily to @user00142025-01-11T14:26:22.387647+0000 ERROR Error: invalid literal for int() with base 10: '95, 297'
#
# 🔗 Mapped Erica to @user0006
# ➕ current_user (@user0006) followed target_user (@user0002)
# 2025-01-11T14:26:22.391133+0000 ERROR Error: invalid literal for int() with base 10: '95, 296'
# ➕ current_user (@user0006) followed target_user (@user0003)
# 2025-01-11T14:26:22.398223+0000 INFO {'source_user': 'Erica', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 2025-01-11T14:26:22.407244+0000 INFO {'source_user': 'Erica', 'label': 'follow', 'data': {'target_user': 'Glenn'}}
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Ryan to @user0017
# 2025-01-11T14:26:22.407515+0000 ERROR Error: invalid literal for int() with base 10: '95, 295'
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Erica to @user0006
# 2025-01-11T14:26:22.417954+0000 ERROR Error: invalid literal for int() with base 10: '95, 292'
# ➕ current_user (@user0006) followed target_user (@user0009)
# 2025-01-11T14:26:22.463055+0000 INFO {'source_user': 'Erica', 'label': 'follow', 'data': {'target_user': 'Robert'}}
# ➕ current_user (@user0003) followed target_user (@user0006)
# 2025-01-11T14:26:22.471278+0000 INFO {'source_user': 'Glenn', 'label': 'follow', 'data': {'target_user': 'Erica'}}
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Erica to @user0006
# 2025-01-11T14:26:22.500376+0000 ERROR Error: invalid literal for int() with base 10: '95, 294'
# 2025-01-11T14:26:22.518110+0000 ERROR Error: invalid literal for int() with base 10: '95, 297'
# ➕ current_user (@user0006) followed target_user (@user0012)
# 2025-01-11T14:26:22.523790+0000 INFO {'source_user': 'Erica', 'label': 'follow', 'data': {'target_user': 'Jessica'}}
# ➕ current_user (@user0012) followed target_user (@user0006)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Nina to @user0020
# 2025-01-11T14:26:22.524752+0000 INFO {'source_user': 'Jessica', 'label': 'follow', 'data': {'target_user': 'Erica'}}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Erica to @user0006
# 2025-01-11T14:26:22.603663+0000 ERROR Error: invalid literal for int() with base 10: '95, 293'
# ➕ current_user (@user0006) followed target_user (@user0014)
# 2025-01-11T14:26:22.605387+0000 INFO {'source_user': 'Erica', 'label': 'follow', 'data': {'target_user': 'Emily'}}
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:22.638190+0000 ERROR Error: invalid literal for int() with base 10: '95, 299'
# 2025-01-11T14:26:22.638369+0000 ERROR Error: invalid literal for int() with base 10: '95, 292'
# ➕ current_user (@user0014) followed target_user (@user0006)
# 2025-01-11T14:26:22.639782+0000 INFO {'source_user': 'Emily', 'label': 'follow', 'data': {'target_user': 'Erica'}}
# ➕ current_user (@user0006) followed target_user (@user0017)
# 2025-01-11T14:26:22.640532+0000 INFO {'source_user': 'Erica', 'label': 'follow', 'data': {'target_user': 'Ryan'}}
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:22.666812+0000 ERROR Error: invalid literal for int() with base 10: '95, 298'
# ➕ current_user (@user0017) followed target_user (@user0006)
# 2025-01-11T14:26:22.687386+0000 INFO {'source_user': 'Ryan', 'label': 'follow', 'data': {'target_user': 'Erica'}}
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Liam to @user0007
# 2025-01-11T14:26:22.754993+0000 ERROR Error: invalid literal for int() with base 10: '95, 291'
# ➕ current_user (@user0006) followed target_user (@user0018)
# 2025-01-11T14:26:22.756145+0000 INFO {'source_user': 'Erica', 'label': 'follow', 'data': {'target_user': 'Maggie'}}
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Janet to @user0010
# 2025-01-11T14:26:22.776808+0000 ERROR Error: invalid literal for int() with base 10: '95, 299'
# ➕ current_user (@user0018) followed target_user (@user0006)
# 2025-01-11T14:26:22.780145+0000 INFO {'source_user': 'Maggie', 'label': 'follow', 'data': {'target_user': 'Erica'}}
# 2025-01-11T14:26:22.780444+0000 ERROR Error: invalid literal for int() with base 10: '95, 296'
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Liam to @user0007
# 2025-01-11T14:26:22.780626+0000 ERROR Error: invalid literal for int() with base 10: '95, 290'
# ➕ current_user (@user0020) followed target_user (@user0006)
# 2025-01-11T14:26:22.783768+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Erica'}}
# ➕ current_user (@user0006) followed target_user (@user0020)🔗 Mapped Liam to @user0007
# 🔗 Mapped Ethan to @user0015
#
# 2025-01-11T14:26:22.785194+0000 INFO {'source_user': 'Erica', 'label': 'follow', 'data': {'target_user': 'Nina'}}
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Liam to @user0007
# 2025-01-11T14:26:22.790697+0000 ERROR Error: invalid literal for int() with base 10: '95, 299'
# ➕ current_user (@user0007) followed target_user (@user0001)2025-01-11T14:26:22.822874+0000 ERROR Error: invalid literal for int() with base 10: '95, 298'
#
# 2025-01-11T14:26:22.832633+0000 INFO {'source_user': 'Liam', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# ➕ current_user (@user0007) followed target_user (@user0002)
# 🔗 Mapped Liam to @user00072025-01-11T14:26:22.853532+0000 INFO {'source_user': 'Liam', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
#
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:22.902143+0000 ERROR Error: invalid literal for int() with base 10: '94, 297'
# ➕ current_user (@user0007) followed target_user (@user0001)
# 2025-01-11T14:26:22.905072+0000 INFO {'source_user': 'Liam', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:22.934375+0000 ERROR Error: invalid literal for int() with base 10: '94, 289'
# ➕ current_user (@user0001) followed target_user (@user0007)
# 2025-01-11T14:26:22.937064+0000 INFO {'source_user': 'Bill', 'label': 'follow', 'data': {'target_user': 'Liam'}}
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Ryan to @user0017
# 2025-01-11T14:26:23.003342+0000 ERROR Error: invalid literal for int() with base 10: '94, 296'
# ➕ current_user (@user0007) followed target_user (@user0010)
# 2025-01-11T14:26:23.004444+0000 INFO {'source_user': 'Liam', 'label': 'follow', 'data': {'target_user': 'Janet'}}
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Olivia to @user0008
# 2025-01-11T14:26:23.025193+0000 ERROR Error: invalid literal for int() with base 10: '94, 298'
# 2025-01-11T14:26:23.026109+0000 ERROR Error: invalid literal for int() with base 10: '94, 295'
# ➕ current_user (@user0010) followed target_user (@user0007)
# 2025-01-11T14:26:23.026737+0000 INFO {'source_user': 'Janet', 'label': 'follow', 'data': {'target_user': 'Liam'}}
# ➕ current_user (@user0007) followed target_user (@user0015)
# 2025-01-11T14:26:23.031104+0000 ERROR Error: invalid literal for int() with base 10: '94, 299'
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Nina to @user0020
# 2025-01-11T14:26:23.031411+0000 INFO {'source_user': 'Liam', 'label': 'follow', 'data': {'target_user': 'Ethan'}}
# ➕ current_user (@user0015) followed target_user (@user0007)
# 2025-01-11T14:26:23.032703+0000 INFO {'source_user': 'Ethan', 'label': 'follow', 'data': {'target_user': 'Liam'}}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:23.177151+0000 ERROR Error: invalid literal for int() with base 10: '94, 294'
# 2025-01-11T14:26:23.188474+0000 ERROR Error: invalid literal for int() with base 10: '94, 297'
# 2025-01-11T14:26:23.192659+0000 ERROR Error: invalid literal for int() with base 10: '94, 296'
# ➕ current_user (@user0007) followed target_user (@user0019)
# 2025-01-11T14:26:23.193908+0000 ERROR Error: invalid literal for int() with base 10: '94, 298'
# 2025-01-11T14:26:23.196754+0000 INFO {'source_user': 'Liam', 'label': 'follow', 'data': {'target_user': 'Lucas'}}
# ➕ current_user (@user0008) followed target_user (@user0017)
# 2025-01-11T14:26:23.220619+0000 INFO {'source_user': 'Olivia', 'label': 'follow', 'data': {'target_user': 'Ryan'}}
# ➕ current_user (@user0008) followed target_user (@user0002)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:23.224189+0000 ERROR Error: invalid literal for int() with base 10: '94, 297'
# ➕ current_user (@user0008) followed target_user (@user0001)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:23.224799+0000 INFO {'source_user': 'Olivia', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# ➕ current_user (@user0017) followed target_user (@user0008)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:23.242121+0000 INFO {'source_user': 'Olivia', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 2025-01-11T14:26:23.287488+0000 INFO {'source_user': 'Ryan', 'label': 'follow', 'data': {'target_user': 'Olivia'}}
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Robert to @user0009
# 2025-01-11T14:26:23.301032+0000 ERROR Error: invalid literal for int() with base 10: '94, 298'
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Erica to @user0006
# 2025-01-11T14:26:23.318776+0000 ERROR Error: invalid literal for int() with base 10: '94, 295'
# ➕ current_user (@user0009) followed target_user (@user0001)
# 2025-01-11T14:26:23.376647+0000 ERROR Error: invalid literal for int() with base 10: '94, 295'
# ➕ current_user (@user0008) followed target_user (@user0020)
# 2025-01-11T14:26:23.390760+0000 INFO {'source_user': 'Robert', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# ➕ current_user (@user0020) followed target_user (@user0008)
# 2025-01-11T14:26:23.402688+0000 INFO {'source_user': 'Olivia', 'label': 'follow', 'data': {'target_user': 'Nina'}}
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Jessica to @user0012
# 2025-01-11T14:26:23.422389+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Olivia'}}
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Robert to @user0009
# 2025-01-11T14:26:23.582555+0000 ERROR Error: invalid literal for int() with base 10: '93, 297'
# ➕ current_user (@user0009) followed target_user (@user0002)
# 2025-01-11T14:26:23.587488+0000 INFO {'source_user': 'Robert', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Ryan to @user0017
# 2025-01-11T14:26:23.621073+0000 ERROR Error: invalid literal for int() with base 10: '93, 292'
# 2025-01-11T14:26:23.621404+0000 ERROR Error: invalid literal for int() with base 10: '93, 295'
# ➕ current_user (@user0002) followed target_user (@user0009)
# 2025-01-11T14:26:23.622769+0000 ERROR Error: invalid literal for int() with base 10: '93, 296'
# 2025-01-11T14:26:23.630054+0000 ERROR Error: invalid literal for int() with base 10: '93, 294'
# ➕ current_user (@user0009) followed target_user (@user0006)
# ➕ current_user (@user0009) followed target_user (@user0002)
# 2025-01-11T14:26:23.637314+0000 INFO {'source_user': 'Bradley', 'label': 'follow', 'data': {'target_user': 'Robert'}}
# ➕ current_user (@user0009) followed target_user (@user0001)2025-01-11T14:26:23.649649+0000 INFO {'source_user': 'Robert', 'label': 'follow', 'data': {'target_user': 'Erica'}}
#
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Robert to @user0009
# 2025-01-11T14:26:23.650605+0000 INFO {'source_user': 'Robert', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:23.656631+0000 INFO {'source_user': 'Robert', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:23.736745+0000 ERROR Error: invalid literal for int() with base 10: '93, 289'
# ➕ current_user (@user0006) followed target_user (@user0009)2025-01-11T14:26:23.742813+0000 ERROR Error: invalid literal for int() with base 10: '93, 293'
#
# 2025-01-11T14:26:23.795579+0000 INFO {'source_user': 'Erica', 'label': 'follow', 'data': {'target_user': 'Robert'}}
# ➕ current_user (@user0009) followed target_user (@user0012)🔗 Mapped Janet to @user0010
# 🔗 Mapped Glenn to @user0003
#
# 2025-01-11T14:26:23.801438+0000 INFO {'source_user': 'Robert', 'label': 'follow', 'data': {'target_user': 'Jessica'}}
# 2025-01-11T14:26:23.817545+0000 ERROR Error: invalid literal for int() with base 10: '93, 296'
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Janet to @user0010
# ➕ current_user (@user0012) followed target_user (@user0009)
# 2025-01-11T14:26:23.861257+0000 INFO {'source_user': 'Jessica', 'label': 'follow', 'data': {'target_user': 'Robert'}}
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Mark to @user0013
# 2025-01-11T14:26:23.903400+0000 ERROR Error: invalid literal for int() with base 10: '93, 292'
# ➕ current_user (@user0009) followed target_user (@user0017)
# 2025-01-11T14:26:23.918305+0000 INFO {'source_user': 'Robert', 'label': 'follow', 'data': {'target_user': 'Ryan'}}
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Janet to @user0010
# 2025-01-11T14:26:23.974493+0000 ERROR Error: invalid literal for int() with base 10: '93, 297'
# ➕ current_user (@user0010) followed target_user (@user0001)
# 2025-01-11T14:26:23.988636+0000 INFO {'source_user': 'Janet', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Ethan to @user0015
# 2025-01-11T14:26:24.032983+0000 ERROR Error: invalid literal for int() with base 10: '93, 296'
# 2025-01-11T14:26:24.033205+0000 ERROR Error: invalid literal for int() with base 10: '93, 291'
# ➕ current_user (@user0017) followed target_user (@user0009)
# ➕ current_user (@user0009) followed target_user (@user0018)
# 2025-01-11T14:26:24.034073+0000 ERROR Error: invalid literal for int() with base 10: '93, 296'
# 2025-01-11T14:26:24.043732+0000 INFO {'source_user': 'Ryan', 'label': 'follow', 'data': {'target_user': 'Robert'}}
# ➕ current_user (@user0010) followed target_user (@user0002)2025-01-11T14:26:24.043990+0000 INFO {'source_user': 'Robert', 'label': 'follow', 'data': {'target_user': 'Maggie'}}
#
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Janet to @user0010
# 2025-01-11T14:26:24.051284+0000 INFO {'source_user': 'Janet', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Janet to @user0010
# 2025-01-11T14:26:24.074403+0000 ERROR Error: invalid literal for int() with base 10: '93, 295'
# ➕ current_user (@user0010) followed target_user (@user0003)
# 2025-01-11T14:26:24.087672+0000 INFO {'source_user': 'Janet', 'label': 'follow', 'data': {'target_user': 'Glenn'}}
# 🔗 Mapped William to @user0011
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:24.134561+0000 ERROR Error: invalid literal for int() with base 10: '93, 291'
# ➕ current_user (@user0003) followed target_user (@user0010)
# 2025-01-11T14:26:24.137061+0000 INFO {'source_user': 'Glenn', 'label': 'follow', 'data': {'target_user': 'Janet'}}
# 🔗 Mapped William to @user0011
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:24.190870+0000 ERROR Error: invalid literal for int() with base 10: '93, 294'
# 2025-01-11T14:26:24.192859+0000 ERROR Error: invalid literal for int() with base 10: '93, 299'
# ➕ current_user (@user0010) followed target_user (@user0013)
# 2025-01-11T14:26:24.193304+0000 INFO {'source_user': 'Janet', 'label': 'follow', 'data': {'target_user': 'Mark'}}
# ➕ current_user (@user0013) followed target_user (@user0010)
# 2025-01-11T14:26:24.197928+0000 INFO {'source_user': 'Mark', 'label': 'follow', 'data': {'target_user': 'Janet'}}
# 🔗 Mapped William to @user0011
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped William to @user0011
# 2025-01-11T14:26:24.217128+0000 ERROR Error: invalid literal for int() with base 10: '93, 293'
# ➕ current_user (@user0010) followed target_user (@user0015)
# 2025-01-11T14:26:24.240266+0000 INFO {'source_user': 'Janet', 'label': 'follow', 'data': {'target_user': 'Ethan'}}
# 🔗 Mapped William to @user0011
# 🔗 Mapped Erica to @user0006
# 2025-01-11T14:26:24.311196+0000 ERROR Error: invalid literal for int() with base 10: '92, 298'
# ➕ current_user (@user0015) followed target_user (@user0010)
# 2025-01-11T14:26:24.313186+0000 INFO {'source_user': 'Ethan', 'label': 'follow', 'data': {'target_user': 'Janet'}}
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped William to @user0011
# 2025-01-11T14:26:24.335477+0000 ERROR Error: invalid literal for int() with base 10: '92, 297'
# 2025-01-11T14:26:24.335770+0000 ERROR Error: invalid literal for int() with base 10: '92, 292'
# ➕ current_user (@user0011) followed target_user (@user0002)
# ➕ current_user (@user0010) followed target_user (@user0016)
# 2025-01-11T14:26:24.340127+0000 ERROR Error: invalid literal for int() with base 10: '92, 298'
# ➕ current_user (@user0016) followed target_user (@user0010)
# 2025-01-11T14:26:24.340539+0000 INFO {'source_user': 'William', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 🔗 Mapped William to @user00112025-01-11T14:26:24.341665+0000 ERROR Error: invalid literal for int() with base 10: '92, 296'
#
# 🔗 Mapped Mark to @user0013
# 2025-01-11T14:26:24.344213+0000 INFO {'source_user': 'Janet', 'label': 'follow', 'data': {'target_user': 'Sophia'}}
# ➕ current_user (@user0011) followed target_user (@user0001)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped William to @user0011
# 2025-01-11T14:26:24.345292+0000 INFO {'source_user': 'Sophia', 'label': 'follow', 'data': {'target_user': 'Janet'}}
# 2025-01-11T14:26:24.369673+0000 INFO {'source_user': 'William', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 🔗 Mapped William to @user0011
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Ethan to @user00152025-01-11T14:26:24.435036+0000 ERROR Error: invalid literal for int() with base 10: '92, 295'
#
# 🔗 Mapped William to @user0011
# ➕ current_user (@user0011) followed target_user (@user0002)
# 2025-01-11T14:26:24.475424+0000 INFO {'source_user': 'William', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 2025-01-11T14:26:24.475821+0000 ERROR Error: invalid literal for int() with base 10: '92, 291'
# 🔗 Mapped William to @user0011
# 🔗 Mapped Lucas to @user0019
# ➕ current_user (@user0002) followed target_user (@user0011)
# 2025-01-11T14:26:24.479878+0000 INFO {'source_user': 'Bradley', 'label': 'follow', 'data': {'target_user': 'William'}}
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped William to @user0011
# 2025-01-11T14:26:24.530142+0000 ERROR Error: invalid literal for int() with base 10: '92, 294'
# ➕ current_user (@user0011) followed target_user (@user0006)
# 2025-01-11T14:26:24.535126+0000 INFO {'source_user': 'William', 'label': 'follow', 'data': {'target_user': 'Erica'}}
# 🔗 Mapped William to @user0011
# 🔗 Mapped Nina to @user0020
# 2025-01-11T14:26:24.560414+0000 ERROR Error: invalid literal for int() with base 10: '92, 288'
# ➕ current_user (@user0006) followed target_user (@user0011)
# 2025-01-11T14:26:24.568237+0000 INFO {'source_user': 'Erica', 'label': 'follow', 'data': {'target_user': 'William'}}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped William to @user0011
# 2025-01-11T14:26:24.608619+0000 ERROR Error: invalid literal for int() with base 10: '92, 293'
# ➕ current_user (@user0011) followed target_user (@user0013)
# 2025-01-11T14:26:24.610200+0000 INFO {'source_user': 'William', 'label': 'follow', 'data': {'target_user': 'Mark'}}
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:24.642021+0000 ERROR Error: invalid literal for int() with base 10: '92, 298'
# ➕ current_user (@user0013) followed target_user (@user0011)
# 2025-01-11T14:26:24.643340+0000 INFO {'source_user': 'Mark', 'label': 'follow', 'data': {'target_user': 'William'}}
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:24.672516+0000 ERROR Error: invalid literal for int() with base 10: '92, 297'
# 2025-01-11T14:26:24.675562+0000 ERROR Error: invalid literal for int() with base 10: '92, 292'
# ➕ current_user (@user0015) followed target_user (@user0011)
# 2025-01-11T14:26:24.677422+0000 INFO {'source_user': 'Ethan', 'label': 'follow', 'data': {'target_user': 'William'}}
# ➕ current_user (@user0011) followed target_user (@user0015)🔗 Mapped Jessica to @user0012
# 🔗 Mapped Denise to @user0004
#
# 2025-01-11T14:26:24.682738+0000 INFO {'source_user': 'William', 'label': 'follow', 'data': {'target_user': 'Ethan'}}
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Roger to @user0005
# 2025-01-11T14:26:24.745830+0000 ERROR Error: invalid literal for int() with base 10: '92, 291'
# ➕ current_user (@user0011) followed target_user (@user0019)
# 2025-01-11T14:26:24.749971+0000 INFO {'source_user': 'William', 'label': 'follow', 'data': {'target_user': 'Lucas'}}
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Robert to @user0009
# 2025-01-11T14:26:24.779679+0000 ERROR Error: invalid literal for int() with base 10: '92, 298'
# ➕ current_user (@user0019) followed target_user (@user0011)
# 2025-01-11T14:26:24.782333+0000 INFO {'source_user': 'Lucas', 'label': 'follow', 'data': {'target_user': 'William'}}
# 2025-01-11T14:26:24.782773+0000 ERROR Error: invalid literal for int() with base 10: '92, 290'
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Jessica to @user0012
# ➕ current_user (@user0011) followed target_user (@user0020)
# 2025-01-11T14:26:24.784597+0000 INFO {'source_user': 'William', 'label': 'follow', 'data': {'target_user': 'Nina'}}
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped William to @user0011
# 2025-01-11T14:26:24.839568+0000 ERROR Error: invalid literal for int() with base 10: '92, 295'
# 2025-01-11T14:26:24.840249+0000 ERROR Error: invalid literal for int() with base 10: '92, 294'
# ➕ current_user (@user0012) followed target_user (@user0001)
# 2025-01-11T14:26:24.846626+0000 INFO {'source_user': 'Jessica', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# ➕ current_user (@user0020) followed target_user (@user0011)
# 2025-01-11T14:26:24.849336+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'William'}}
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Jessica to @user0012
# 2025-01-11T14:26:24.900100+0000 ERROR Error: invalid literal for int() with base 10: '91, 294'
# ➕ current_user (@user0012) followed target_user (@user0002)
# 2025-01-11T14:26:24.908239+0000 INFO {'source_user': 'Jessica', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Ryan to @user0017
# 2025-01-11T14:26:24.945453+0000 ERROR Error: invalid literal for int() with base 10: '91, 293'
# ➕ current_user (@user0012) followed target_user (@user0004)
# 2025-01-11T14:26:24.948745+0000 INFO {'source_user': 'Jessica', 'label': 'follow', 'data': {'target_user': 'Denise'}}
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Lucas to @user0019
# 2025-01-11T14:26:25.016725+0000 ERROR Error: invalid literal for int() with base 10: '91, 292'
# ➕ current_user (@user0012) followed target_user (@user0005)2025-01-11T14:26:25.018197+0000 ERROR Error: invalid literal for int() with base 10: '91, 291'
#
# 2025-01-11T14:26:25.021003+0000 INFO {'source_user': 'Jessica', 'label': 'follow', 'data': {'target_user': 'Roger'}}
# ➕ current_user (@user0012) followed target_user (@user0009)
# 2025-01-11T14:26:25.021947+0000 INFO {'source_user': 'Jessica', 'label': 'follow', 'data': {'target_user': 'Robert'}}
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Nina to @user0020
# 2025-01-11T14:26:25.046895+0000 ERROR Error: invalid literal for int() with base 10: '91, 290'
# ➕ current_user (@user0012) followed target_user (@user0011)
# 2025-01-11T14:26:25.054072+0000 ERROR Error: invalid literal for int() with base 10: '91, 290'
# 2025-01-11T14:26:25.069800+0000 INFO {'source_user': 'Jessica', 'label': 'follow', 'data': {'target_user': 'William'}}
# ➕ current_user (@user0009) followed target_user (@user0012)
# 2025-01-11T14:26:25.076157+0000 ERROR Error: invalid literal for int() with base 10: '91, 298'
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Jessica to @user0012
# 2025-01-11T14:26:25.080453+0000 INFO {'source_user': 'Robert', 'label': 'follow', 'data': {'target_user': 'Jessica'}}
# ➕ current_user (@user0014) followed target_user (@user0012)
# 🔗 Mapped Mark to @user00132025-01-11T14:26:25.103601+0000 INFO {'source_user': 'Emily', 'label': 'follow', 'data': {'target_user': 'Jessica'}}
#
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:25.142222+0000 ERROR Error: invalid literal for int() with base 10: '91, 288'
# 2025-01-11T14:26:25.142851+0000 ERROR Error: invalid literal for int() with base 10: '91, 289'
# ➕ current_user (@user0012) followed target_user (@user0014)
# 2025-01-11T14:26:25.151504+0000 INFO {'source_user': 'Jessica', 'label': 'follow', 'data': {'target_user': 'Emily'}}
# ➕ current_user (@user0012) followed target_user (@user0017)
# 🔗 Mapped Mark to @user00132025-01-11T14:26:25.153255+0000 INFO {'source_user': 'Jessica', 'label': 'follow', 'data': {'target_user': 'Ryan'}}
#
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Mark to @user0013
# 2025-01-11T14:26:25.267441+0000 ERROR Error: invalid literal for int() with base 10: '91, 287'
# ➕ current_user (@user0012) followed target_user (@user0019)
# 2025-01-11T14:26:25.269976+0000 INFO {'source_user': 'Jessica', 'label': 'follow', 'data': {'target_user': 'Lucas'}}
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Denise to @user0004
# 2025-01-11T14:26:25.298558+0000 ERROR Error: invalid literal for int() with base 10: '91, 286'
# 2025-01-11T14:26:25.299606+0000 ERROR Error: invalid literal for int() with base 10: '91, 297'
# ➕ current_user (@user0012) followed target_user (@user0020)
# 2025-01-11T14:26:25.302774+0000 INFO {'source_user': 'Jessica', 'label': 'follow', 'data': {'target_user': 'Nina'}}
# ➕ current_user (@user0019) followed target_user (@user0012)
# 2025-01-11T14:26:25.310966+0000 INFO {'source_user': 'Lucas', 'label': 'follow', 'data': {'target_user': 'Jessica'}}
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped William to @user0011
# 2025-01-11T14:26:25.357585+0000 ERROR Error: invalid literal for int() with base 10: '91, 293'
# ➕ current_user (@user0020) followed target_user (@user0012)
# 2025-01-11T14:26:25.361468+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Jessica'}}
# 2025-01-11T14:26:25.362768+0000 ERROR Error: invalid literal for int() with base 10: '91, 297'
# 🔗 Mapped William to @user0011
# 🔗 Mapped Mark to @user0013
# ➕ current_user (@user0013) followed target_user (@user0002)
# 2025-01-11T14:26:25.374682+0000 INFO {'source_user': 'Mark', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 2025-01-11T14:26:25.374888+0000 ERROR Error: invalid literal for int() with base 10: '91, 296'
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Emily to @user0014
# ➕ current_user (@user0013) followed target_user (@user0002)
# 2025-01-11T14:26:25.407340+0000 INFO {'source_user': 'Mark', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Mark to @user0013
# 2025-01-11T14:26:25.427866+0000 ERROR Error: invalid literal for int() with base 10: '91, 290'
# 2025-01-11T14:26:25.429376+0000 ERROR Error: invalid literal for int() with base 10: '91, 295'
# ➕ current_user (@user0013) followed target_user (@user0001)➕ current_user (@user0002) followed target_user (@user0013)
# 2025-01-11T14:26:25.433219+0000 INFO {'source_user': 'Bradley', 'label': 'follow', 'data': {'target_user': 'Mark'}}
#
# 🔗 Mapped Mark to @user00132025-01-11T14:26:25.433420+0000 INFO {'source_user': 'Mark', 'label': 'follow', 'data': {'target_user': 'Bill'}}
#
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:25.487090+0000 ERROR Error: invalid literal for int() with base 10: '90, 294'
# ➕ current_user (@user0013) followed target_user (@user0004)
# 2025-01-11T14:26:25.488018+0000 INFO {'source_user': 'Mark', 'label': 'follow', 'data': {'target_user': 'Denise'}}
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:25.569081+0000 ERROR Error: invalid literal for int() with base 10: '90, 291'
# 2025-01-11T14:26:25.580198+0000 ERROR Error: invalid literal for int() with base 10: '90, 293'
# ➕ current_user (@user0004) followed target_user (@user0013)
# 2025-01-11T14:26:25.582933+0000 INFO {'source_user': 'Denise', 'label': 'follow', 'data': {'target_user': 'Mark'}}
# ➕ current_user (@user0013) followed target_user (@user0011)
# 2025-01-11T14:26:25.586878+0000 INFO {'source_user': 'Mark', 'label': 'follow', 'data': {'target_user': 'William'}}
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:25.601317+0000 ERROR Error: invalid literal for int() with base 10: '90, 289'
# ➕ current_user (@user0011) followed target_user (@user0013)2025-01-11T14:26:25.678205+0000 ERROR Error: invalid literal for int() with base 10: '90, 297'
#
# ➕ current_user (@user0014) followed target_user (@user0013)
# 2025-01-11T14:26:25.719811+0000 INFO {'source_user': 'Emily', 'label': 'follow', 'data': {'target_user': 'Mark'}}
# 2025-01-11T14:26:25.714174+0000 INFO {'source_user': 'William', 'label': 'follow', 'data': {'target_user': 'Mark'}}
# 2025-01-11T14:26:25.715151+0000 ERROR Error: invalid literal for int() with base 10: '90, 291'
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Emily to @user0014
# 2025-01-11T14:26:25.686646+0000 ERROR Error: invalid literal for int() with base 10: '90, 292'
# ➕ current_user (@user0013) followed target_user (@user0018)
# 2025-01-11T14:26:25.746849+0000 INFO {'source_user': 'Mark', 'label': 'follow', 'data': {'target_user': 'Maggie'}}
# ➕ current_user (@user0013) followed target_user (@user0014)
# 2025-01-11T14:26:25.765301+0000 ERROR Error: invalid literal for int() with base 10: '90, 296'
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Olivia to @user0008
# 2025-01-11T14:26:25.768868+0000 INFO {'source_user': 'Mark', 'label': 'follow', 'data': {'target_user': 'Emily'}}
# ➕ current_user (@user0014) followed target_user (@user0001)
# 2025-01-11T14:26:25.772697+0000 ERROR Error: invalid literal for int() with base 10: '90, 295'
# 🔗 Mapped Olivia to @user0008
# ...
#
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Roger to @user0005
# 2025-01-11T14:26:27.577005+0000 ERROR Error: invalid literal for int() with base 10: '88, 291'
# ➕ current_user (@user0016) followed target_user (@user0013)
# 2025-01-11T14:26:27.587867+0000 INFO {'source_user': 'Sophia', 'label': 'follow', 'data': {'target_user': 'Mark'}}
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Ryan to @user0017
# 2025-01-11T14:26:27.676743+0000 ERROR Error: invalid literal for int() with base 10: '88, 290'
# ➕ current_user (@user0013) followed target_user (@user0016)
# 2025-01-11T14:26:27.678365+0000 INFO {'source_user': 'Mark', 'label': 'follow', 'data': {'target_user': 'Sophia'}}
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Liam to @user0007
# 2025-01-11T14:26:27.705856+0000 ERROR Error: invalid literal for int() with base 10: '88, 293'
# 2025-01-11T14:26:27.706197+0000 ERROR Error: invalid literal for int() with base 10: '88, 294'
# ➕ current_user (@user0017) followed target_user (@user0002)
# ➕ current_user (@user0017) followed target_user (@user0001)
# 2025-01-11T14:26:27.760612+0000 INFO {'source_user': 'Ryan', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 2025-01-11T14:26:27.762479+0000 INFO {'source_user': 'Ryan', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Janet to @user0010
# 2025-01-11T14:26:27.874227+0000 ERROR Error: invalid literal for int() with base 10: '88, 292'
# ➕ current_user (@user0017) followed target_user (@user0001)
# 2025-01-11T14:26:27.875464+0000 ERROR Error: invalid literal for int() with base 10: '88, 287'
# ➕ current_user (@user0001) followed target_user (@user0017)2025-01-11T14:26:27.885942+0000 INFO {'source_user': 'Ryan', 'label': 'follow', 'data': {'target_user': 'Bill'}}
#
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Ryan to @user0017
# 2025-01-11T14:26:27.889548+0000 INFO {'source_user': 'Bill', 'label': 'follow', 'data': {'target_user': 'Ryan'}}
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Maggie to @user0018
# 2025-01-11T14:26:27.947364+0000 ERROR Error: invalid literal for int() with base 10: '88, 290'
# 2025-01-11T14:26:27.955770+0000 ERROR Error: invalid literal for int() with base 10: '88, 290'
# ➕ current_user (@user0005) followed target_user (@user0017)
# 2025-01-11T14:26:27.961591+0000 INFO {'source_user': 'Roger', 'label': 'follow', 'data': {'target_user': 'Ryan'}}
# ➕ current_user (@user0017) followed target_user (@user0005)🔗 Mapped Maggie to @user0018
# 🔗 Mapped Ryan to @user0017
#
# 2025-01-11T14:26:27.963289+0000 ERROR Error: invalid literal for int() with base 10: '88, 291'
# 2025-01-11T14:26:27.994755+0000 INFO {'source_user': 'Ryan', 'label': 'follow', 'data': {'target_user': 'Roger'}}
# ➕ current_user (@user0017) followed target_user (@user0003)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Lucas to @user0019
# 2025-01-11T14:26:28.016081+0000 INFO {'source_user': 'Ryan', 'label': 'follow', 'data': {'target_user': 'Glenn'}}
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:28.105367+0000 ERROR Error: invalid literal for int() with base 10: '87, 289'
# ➕ current_user (@user0017) followed target_user (@user0007)
# 2025-01-11T14:26:28.106938+0000 INFO {'source_user': 'Ryan', 'label': 'follow', 'data': {'target_user': 'Liam'}}
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:28.210092+0000 ERROR Error: invalid literal for int() with base 10: '87, 288'
# ➕ current_user (@user0017) followed target_user (@user0010)
# 2025-01-11T14:26:28.213212+0000 INFO {'source_user': 'Ryan', 'label': 'follow', 'data': {'target_user': 'Janet'}}
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Glenn to @user0003
# 2025-01-11T14:26:28.262232+0000 ERROR Error: invalid literal for int() with base 10: '87, 292'
# ➕ current_user (@user0007) followed target_user (@user0017)
# 2025-01-11T14:26:28.266579+0000 INFO {'source_user': 'Liam', 'label': 'follow', 'data': {'target_user': 'Ryan'}}
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Maggie to @user0018
# 2025-01-11T14:26:28.293347+0000 ERROR Error: invalid literal for int() with base 10: '87, 290'
# 2025-01-11T14:26:28.301880+0000 ERROR Error: invalid literal for int() with base 10: '87, 287'
# ➕ current_user (@user0010) followed target_user (@user0017)
# 2025-01-11T14:26:28.320706+0000 INFO {'source_user': 'Janet', 'label': 'follow', 'data': {'target_user': 'Ryan'}}
# ➕ current_user (@user0017) followed target_user (@user0018)
# 2025-01-11T14:26:28.392046+0000 INFO {'source_user': 'Ryan', 'label': 'follow', 'data': {'target_user': 'Maggie'}}
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Olivia to @user0008
# 2025-01-11T14:26:28.489586+0000 ERROR Error: invalid literal for int() with base 10: '87, 297'
# ➕ current_user (@user0018) followed target_user (@user0017)
# 2025-01-11T14:26:28.559077+0000 INFO {'source_user': 'Maggie', 'label': 'follow', 'data': {'target_user': 'Ryan'}}
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Lucas to @user0019
# 2025-01-11T14:26:28.642720+0000 ERROR Error: invalid literal for int() with base 10: '87, 294'
# 2025-01-11T14:26:28.650835+0000 ERROR Error: invalid literal for int() with base 10: '87, 296'
# ➕ current_user (@user0018) followed target_user (@user0003)
# 2025-01-11T14:26:28.656963+0000 ERROR Error: invalid literal for int() with base 10: '87, 295'
# ➕ current_user (@user0018) followed target_user (@user0002)
# 2025-01-11T14:26:28.670128+0000 INFO {'source_user': 'Maggie', 'label': 'follow', 'data': {'target_user': 'Glenn'}}
# ➕ current_user (@user0018) followed target_user (@user0001)
# 2025-01-11T14:26:28.672251+0000 INFO {'source_user': 'Maggie', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:26:28.674307+0000 INFO {'source_user': 'Maggie', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Bradley to @user0002
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Robert to @user0009
# 2025-01-11T14:26:28.714711+0000 ERROR Error: invalid literal for int() with base 10: '87, 286'
# 2025-01-11T14:26:28.731195+0000 ERROR Error: invalid literal for int() with base 10: '87, 290'
# ➕ current_user (@user0017) followed target_user (@user0019)
# 2025-01-11T14:26:28.736438+0000 INFO {'source_user': 'Ryan', 'label': 'follow', 'data': {'target_user': 'Lucas'}}
# ➕ current_user (@user0003) followed target_user (@user0018)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Lucas to @user0019
# 2025-01-11T14:26:28.739772+0000 INFO {'source_user': 'Glenn', 'label': 'follow', 'data': {'target_user': 'Maggie'}}
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped William to @user0011
# 2025-01-11T14:26:28.792932+0000 ERROR Error: invalid literal for int() with base 10: '87, 293'
# ➕ current_user (@user0018) followed target_user (@user0008)
# 2025-01-11T14:26:28.807511+0000 INFO {'source_user': 'Maggie', 'label': 'follow', 'data': {'target_user': 'Olivia'}}
# 🔗 Mapped William to @user0011
# 🔗 Mapped Lucas to @user0019
# 2025-01-11T14:26:28.900114+0000 ERROR Error: invalid literal for int() with base 10: '87, 292'
# ➕ current_user (@user0018) followed target_user (@user0005)
# 2025-01-11T14:26:28.920981+0000 INFO {'source_user': 'Maggie', 'label': 'follow', 'data': {'target_user': 'Roger'}}
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Mark to @user0013
# 2025-01-11T14:26:28.957475+0000 ERROR Error: invalid literal for int() with base 10: '87, 295'
# 2025-01-11T14:26:28.971112+0000 ERROR Error: invalid literal for int() with base 10: '87, 291'
# ➕ current_user (@user0019) followed target_user (@user0002)
# ➕ current_user (@user0018) followed target_user (@user0019)2025-01-11T14:26:28.974210+0000 INFO {'source_user': 'Lucas', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
#
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Lucas to @user0019
# 2025-01-11T14:26:28.977455+0000 INFO {'source_user': 'Maggie', 'label': 'follow', 'data': {'target_user': 'Lucas'}}
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Sophia to @user0016
# 2025-01-11T14:26:29.056565+0000 ERROR Error: invalid literal for int() with base 10: '87, 293'
# ➕ current_user (@user0019) followed target_user (@user0009)
# 2025-01-11T14:26:29.068991+0000 ERROR Error: invalid literal for int() with base 10: '87, 294'
# ➕ current_user (@user0019) followed target_user (@user0001)2025-01-11T14:26:29.071453+0000 ERROR Error: invalid literal for int() with base 10: '87, 292'
#
# 2025-01-11T14:26:29.072029+0000 INFO {'source_user': 'Lucas', 'label': 'follow', 'data': {'target_user': 'Robert'}}
# ➕ current_user (@user0019) followed target_user (@user0011)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Lucas to @user0019
# 2025-01-11T14:26:29.077745+0000 INFO {'source_user': 'Lucas', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Nina to @user0020
# 2025-01-11T14:26:29.082253+0000 INFO {'source_user': 'Lucas', 'label': 'follow', 'data': {'target_user': 'William'}}
# 2025-01-11T14:26:29.088127+0000 ERROR Error: invalid literal for int() with base 10: '87, 287'
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Bill to @user0001
# ➕ current_user (@user0009) followed target_user (@user0019)
# 2025-01-11T14:26:29.297741+0000 INFO {'source_user': 'Robert', 'label': 'follow', 'data': {'target_user': 'Lucas'}}
# 2025-01-11T14:26:29.305017+0000 ERROR Error: invalid literal for int() with base 10: '86, 288'
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:26:29.353837+0000 ERROR Error: invalid literal for int() with base 10: '86, 291'
# ➕ current_user (@user0011) followed target_user (@user0019)
# 2025-01-11T14:26:29.359280+0000 INFO {'source_user': 'William', 'label': 'follow', 'data': {'target_user': 'Lucas'}}
# ➕ current_user (@user0019) followed target_user (@user0013)
# 2025-01-11T14:26:29.370944+0000 INFO {'source_user': 'Lucas', 'label': 'follow', 'data': {'target_user': 'Mark'}}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Nina to @user0020
# 2025-01-11T14:26:29.417453+0000 ERROR Error: invalid literal for int() with base 10: '86, 290'
# 2025-01-11T14:26:29.447172+0000 ERROR Error: invalid literal for int() with base 10: '86, 289'
# ➕ current_user (@user0019) followed target_user (@user0016)
# 2025-01-11T14:26:29.476578+0000 INFO {'source_user': 'Lucas', 'label': 'follow', 'data': {'target_user': 'Sophia'}}
# ➕ current_user (@user0013) followed target_user (@user0019)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Liam to @user0007
# 2025-01-11T14:26:29.480780+0000 INFO {'source_user': 'Mark', 'label': 'follow', 'data': {'target_user': 'Lucas'}}
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Nina to @user0020
# 2025-01-11T14:26:29.668337+0000 ERROR Error: invalid literal for int() with base 10: '86, 290'
# 2025-01-11T14:26:29.668959+0000 ERROR Error: invalid literal for int() with base 10: '86, 289'
# ➕ current_user (@user0019) followed target_user (@user0020)
# 2025-01-11T14:26:29.674050+0000 INFO {'source_user': 'Lucas', 'label': 'follow', 'data': {'target_user': 'Nina'}}
# ➕ current_user (@user0016) followed target_user (@user0019)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Olivia to @user0008
# 2025-01-11T14:26:29.674874+0000 INFO {'source_user': 'Sophia', 'label': 'follow', 'data': {'target_user': 'Lucas'}}
# 2025-01-11T14:26:29.703917+0000 ERROR Error: invalid literal for int() with base 10: '86, 291'
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Nina to @user0020
# 2025-01-11T14:26:29.711259+0000 ERROR Error: invalid literal for int() with base 10: '86, 292'
# ➕ current_user (@user0020) followed target_user (@user0001)
# 2025-01-11T14:26:29.749409+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Bill'}}
# ➕ current_user (@user0020) followed target_user (@user0002)
# 2025-01-11T14:26:29.750745+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Bradley'}}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped William to @user0011
# 🔗 Mapped William to @user0011
# 🔗 Mapped Nina to @user0020
# 2025-01-11T14:26:29.851709+0000 ERROR Error: invalid literal for int() with base 10: '86, 291'
# ➕ current_user (@user0007) followed target_user (@user0020)
# 2025-01-11T14:26:29.858151+0000 INFO {'source_user': 'Liam', 'label': 'follow', 'data': {'target_user': 'Nina'}}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Jessica to @user0012
# 2025-01-11T14:26:29.901821+0000 ERROR Error: invalid literal for int() with base 10: '86, 290'
# 2025-01-11T14:26:29.913490+0000 ERROR Error: invalid literal for int() with base 10: '86, 289'
# ➕ current_user (@user0020) followed target_user (@user0007)
# 2025-01-11T14:26:29.914949+0000 ERROR Error: invalid literal for int() with base 10: '86, 287'
# 2025-01-11T14:26:29.941578+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Liam'}}
# ➕ current_user (@user0020) followed target_user (@user0006)
# 2025-01-11T14:26:29.989079+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Erica'}}
# ➕ current_user (@user0006) followed target_user (@user0020)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Nina to @user0020
# 2025-01-11T14:26:29.996665+0000 INFO {'source_user': 'Erica', 'label': 'follow', 'data': {'target_user': 'Nina'}}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Ethan to @user0015
# 2025-01-11T14:26:30.038647+0000 ERROR Error: invalid literal for int() with base 10: '86, 288'
# ➕ current_user (@user0020) followed target_user (@user0008)
# 2025-01-11T14:26:30.039910+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Olivia'}}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Sophia to @user0016
# 2025-01-11T14:26:30.095114+0000 ERROR Error: invalid literal for int() with base 10: '86, 287'
# ➕ current_user (@user0011) followed target_user (@user0020)
# 2025-01-11T14:26:30.099364+0000 INFO {'source_user': 'William', 'label': 'follow', 'data': {'target_user': 'Nina'}}
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Lucas to @user0019
# 2025-01-11T14:26:30.121851+0000 ERROR Error: invalid literal for int() with base 10: '86, 287'
# ➕ current_user (@user0020) followed target_user (@user0011)
# 2025-01-11T14:26:30.122846+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'William'}}
# 2025-01-11T14:26:30.123697+0000 ERROR Error: invalid literal for int() with base 10: '86, 293'
# ➕ current_user (@user0008) followed target_user (@user0020)
# 2025-01-11T14:26:30.129675+0000 INFO {'source_user': 'Olivia', 'label': 'follow', 'data': {'target_user': 'Nina'}}
# 2025-01-11T14:26:30.312074+0000 ERROR Error: invalid literal for int() with base 10: '85, 286'
# 2025-01-11T14:26:30.312554+0000 ERROR Error: invalid literal for int() with base 10: '85, 288'
# ➕ current_user (@user0020) followed target_user (@user0012)2025-01-11T14:26:30.313470+0000 ERROR Error: invalid literal for int() with base 10: '85, 285'
#
# ➕ current_user (@user0013) followed target_user (@user0020)
# ➕ current_user (@user0020) followed target_user (@user0013)
# 2025-01-11T14:26:30.316431+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Mark'}}
# 2025-01-11T14:26:30.315195+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Jessica'}}
# 2025-01-11T14:26:30.315378+0000 INFO {'source_user': 'Mark', 'label': 'follow', 'data': {'target_user': 'Nina'}}
# 2025-01-11T14:26:30.313674+0000 ERROR Error: invalid literal for int() with base 10: '85, 284'
# ➕ current_user (@user0020) followed target_user (@user0015)
# 2025-01-11T14:26:30.321062+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Ethan'}}
# 2025-01-11T14:26:30.326348+0000 ERROR Error: invalid literal for int() with base 10: '85, 282'
# ➕ current_user (@user0020) followed target_user (@user0016)
# 2025-01-11T14:26:30.327436+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Sophia'}}
# 2025-01-11T14:26:30.329843+0000 ERROR Error: invalid literal for int() with base 10: '85, 283'
# ➕ current_user (@user0020) followed target_user (@user0019)
# 2025-01-11T14:26:30.331503+0000 INFO {'source_user': 'Nina', 'label': 'follow', 'data': {'target_user': 'Lucas'}}

# %%
# Update Mastodon display name for each person
from mastodon_sim import mastodon_ops

if USE_MASTODON_SERVER:
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [
            executor.submit(mastodon_ops.update_bio, user_mapping[name], display_name=name, bio="")
            for name in user_mapping
        ]

    # Optionally, wait for all tasks to complete
    for future in concurrent.futures.as_completed(futures):
        future.result()  # This will raise any exceptions that occurred during execution, if any
# Out:
# 2025-01-11T14:26:30.706196+0000 ERROR Error: invalid literal for int() with base 10: '85, 286'
# 2025-01-11T14:26:30.715285+0000 ERROR Error: invalid literal for int() with base 10: '85, 289'
# 2025-01-11T14:26:30.768696+0000 ERROR Error: invalid literal for int() with base 10: '85, 290'
# 2025-01-11T14:26:30.946779+0000 ERROR Error: invalid literal for int() with base 10: '85, 286'
# 2025-01-11T14:26:30.980671+0000 ERROR Error: invalid literal for int() with base 10: '85, 292'
# 2025-01-11T14:26:30.990698+0000 ERROR Error: invalid literal for int() with base 10: '85, 290'
# 2025-01-11T14:26:30.992202+0000 ERROR Error: invalid literal for int() with base 10: '85, 289'
# 2025-01-11T14:26:31.001898+0000 ERROR Error: invalid literal for int() with base 10: '85, 289'
# 2025-01-11T14:26:31.072390+0000 ERROR Error: invalid literal for int() with base 10: '84, 286'
# 2025-01-11T14:26:31.177653+0000 ERROR Error: invalid literal for int() with base 10: '84, 286'
# 2025-01-11T14:26:31.226886+0000 ERROR Error: invalid literal for int() with base 10: '84, 289'
# 2025-01-11T14:26:31.372224+0000 ERROR Error: invalid literal for int() with base 10: '84, 285'
# 2025-01-11T14:26:31.425455+0000 ERROR Error: invalid literal for int() with base 10: '84, 287'
# 2025-01-11T14:26:31.459116+0000 ERROR Error: invalid literal for int() with base 10: '84, 285'
# 2025-01-11T14:26:31.463124+0000 ERROR Error: invalid literal for int() with base 10: '84, 287'
# 2025-01-11T14:26:31.467319+0000 ERROR Error: invalid literal for int() with base 10: '84, 289'
# 2025-01-11T14:26:31.468055+0000 ERROR Error: invalid literal for int() with base 10: '84, 286'
# 2025-01-11T14:26:31.510447+0000 ERROR Error: invalid literal for int() with base 10: '84, 290'
# 2025-01-11T14:26:31.552856+0000 ERROR Error: invalid literal for int() with base 10: '84, 288'
# 2025-01-11T14:26:31.592444+0000 ERROR Error: invalid literal for int() with base 10: '83, 281'

# %%
from concurrent.futures import ThreadPoolExecutor
from concurrent.futures import as_completed


class SimpleGameRunner:
    """Simplified game master to run players with independent phone scene triggering in parallel."""

    def __init__(self, players, clock, action_spec, phones, model, memory, memory_factory):
        """
        Args:
            players: Dictionary of players.
            clock: Game clock to advance time.
            action_spec: Action specifications for the players.
            phones: Dictionary of phones associated with each player.
            model: Language model to process events.
            memory: Shared associative memory (could be unique per player if needed).
            memory_factory: Factory to create memory instances.
        """
        self.players = {player.name: player for player in players}
        self.clock = clock
        self.action_spec = action_spec
        self.phones = phones
        self.model = model
        self.memory = memory
        self.memory_factory = memory_factory
        self.player_components = self._create_player_components()
        self.log = []

    def _create_player_components(self):
        """Create a unique SceneTriggeringComponent for each player."""
        components = {}
        for player_name, player in self.players.items():
            components[player_name] = triggering.BasicSceneTriggeringComponent(
                player=player,
                phone=self.phones[player_name],
                model=self.model,
                memory=self.memory,
                clock=self.clock,
                memory_factory=self.memory_factory,
            )
        return components

    def _step_player(self, player):
        """Run a single player's action and trigger their phone scene."""
        try:
            # 1. Player takes action
            action = player.act(self.action_spec)
            event_statement = f"{player.name} attempted action: {action}"

            # 2. Log the action (ensure this is thread-safe)
            self.log.append(
                {
                    "player": player.name,
                    "action": action,
                    "timestamp": self.clock.now(),
                }
            )

            # 3. Trigger the phone scene for this player using their unique component
            self.player_components[player.name].update_after_event(event_statement)

            return event_statement
        except Exception as e:
            # Handle any player-specific exceptions
            return f"Error for {player.name}: {str(e)}"

    def step(self, active_players=None, timeout=600):
        """
        Run a step for the specified active players in parallel.

        Args:
            active_players: List of player names to take part in the step. If None, all players act.
            timeout: Timeout in seconds for each player's action.
        """
        if active_players is None:
            active_players = list(self.players.keys())

        # Use ThreadPoolExecutor to run each player's action and phone event handling in parallel
        with ThreadPoolExecutor() as executor:
            # Submit tasks to be run in parallel, but for each player, action and phone processing are sequential
            futures = {
                executor.submit(self._step_player, self.players[player_name.name]): player_name.name
                for player_name in active_players
            }

            # Wait for all futures to complete, handle timeouts and exceptions
            for future in as_completed(futures, timeout=timeout):
                player_name = futures[future]
                try:
                    result = future.result(timeout=timeout)
                    print(
                        f"Result for {player_name}: {result}"
                    )  # This will print the action outcome for each player
                except TimeoutError:
                    print(f"Timeout for {player_name}. Skipping their turn.")
                except Exception as e:
                    print(f"Error in thread for {player_name}: {str(e)}")

        # Advance the game clock after all players' actions are complete
        self.clock.advance()

    def run_game(self, steps=10):
        """Run the game for a given number of steps."""
        for _ in range(steps):
            self.step()  # By default, all players will act unless specified otherwise

# %% [markdown]
# ### Define a custom `CALL_TO_ACTION` prompt for the main Game Master
#
# This replaces the [default call to action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/typing/entity.py#L51).
#
# Check out the `Calendar.ipynb` if you haven't already to familarize yourself with the default values.

# %%
from concordia.typing.entity import ActionSpec, OutputType


CUSTOM_CALL_TO_ACTION = """
Describe an activity on payne.social that {name} would engage in for the next {timedelta}.
Choose actions together take about {timedelta} to complete.
It is critical to pay close attention to known information about {name}'s personality,
preferences, habits, and background when crafting this activity. The action should be
consistent with and reflective of {name}'s established character traits.

Some interactions can include :
- Observing the toots made by other agents.
- Posting on payne.social
- Liking other toots
- Replying to the toots made by other agents.
- Boosting toots made by other agents


Example:

"Sarah checks her feed and replies if necessary. Then she may post a toot on Mastodon about her ideas on topic X on the lines of 'Just discovered an intriguing new language for low-latency systems programming.
Has anyone given it a try? Curious about potential real-world applications. 🤔
#TechNews #ProgrammingLanguages'"


Ensure your response is specific, creative, and detailed. Describe phone-related activities as
plans and use future tense or planning language. Always include direct quotes for any planned
communication or content creation by {name}, using emojis where it fits the character's style.
Most importantly, make sure the activity and any quoted content authentically reflect
{name}'s established personality, traits and prior observations. Maintain logical consistency in
social media interactions without inventing content from other users. Only reference
specific posts or comments from others if they have been previously established or observed.

"""


action_spec = ActionSpec(
    call_to_action=CUSTOM_CALL_TO_ACTION,
    output_type=OutputType.FREE,
    tag="action",
)

# %% [markdown]
# ### Define custom thought chains for the main Game Master
#
# This replaces the [default thought chains](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L38).

# %%
# Create the game master object

# Experimental version (custom call to action and thought chains)
env = SimpleGameRunner(
    model=model,
    memory=game_master_memory,
    phones=phones,
    clock=clock,
    players=players,
    action_spec=action_spec,
    memory_factory=blank_memory_factory,
)

# %%
def write_seed_toot(players, p_name):
    for player in players:
        if player.name == p_name:
            call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
                name=player.name,
            )
            interaction_premise = f"{player.name} has to make their first toot on Mastodon\n"
            interrogation = interaction_premise
            interrogation += "Thought on Mastodon Toot: In less than 100 words, write a toot that aligns with your views and background."
            player_says = player.act(
                action_spec=entity.ActionSpec(
                    call_to_action="Context: " + interrogation + call_to_speech,
                    output_type=entity.OutputType.FREE,
                ),
            )
            player_says = (
                player_says.strip(player.name.split()[0])
                .strip()
                .strip(player.name.split()[1])
                .strip()
                .strip("--")
                .strip()
                .strip('"')
            )
            print(player.get_last_log())
            return player_says

# %%
# import threading
# import pickle

# def clean_for_serialization(entity_agent):
#     """Removes unpicklable objects like locks before serialization."""
#     # Reset locks (you can also reinitialize them after loading)
#     entity_agent._control_lock = None
#     entity_agent._phase_lock = None

#     # If context processors are problematic, you can reset or exclude them as well
#     entity_agent._context_processor = None

#     return entity_agent


# for player in players:
#     clean_for_serialization(player)
# with open('my_object.pkl', 'wb') as f:
#     pickle.dump(players, f)

# %% [markdown]
# ## The RUN

# %%
# Set the clock to the start time
clock.set(START_TIME)

# %%
# Add some observations to seed the players with
for player in players:
    player.observe(f"{player.name} is at home, they have just woken up.")
    player.observe(f"{player.name} remembers they want to update their Mastodon bio.")
    player.observe(
        f"{player.name} remembers they want to read their Mastodon feed to catch up on news"
    )

# %%
# Parallelize the loop using ThreadPoolExecutor
with concurrent.futures.ThreadPoolExecutor() as executor:
    # Submit tasks for each agent
    futures = [
        executor.submit(
            lambda agent=agent: (
                None
                if agent["seed_toot"] == "-"
                else mastodon_app.post_toot(agent["name"], status=agent["seed_toot"])
                if agent["seed_toot"]
                else mastodon_app.post_toot(
                    agent["name"], status=write_seed_toot(players, agent["name"])
                )
            )
        )
        for agent in data["agents"]
    ]

    # Optionally, wait for all tasks to complete
    for future in concurrent.futures.as_completed(futures):
        future.result()  # This will raise any exceptions that occurred in the thread, if any
# Out:
# {'AllSimilarMemories': {'Key': '\nRecalled memories and observations', 'Value': '[01 Oct 2024 08:00:00] Glenn Patterson is a person who \n[01 Oct 2024 08:00:00] [observation] Glenn Patterson is at home, they have just woken up.\n[01 Oct 2024 08:00:00] [observation] Glenn Patterson remembers they want to read their Mastodon feed to catch up on news\n[01 Oct 2024 08:00:00] [observation] Glenn Patterson remembers they want to update their Mastodon bio. \n', 'Initial chain of thought': ['Statements:', "Glenn Patterson's ", 'Summary of recent observations:', '01 Oct 2024 [04:00:00  - 07:00:00]:  Glenn Patterson has not yet been observed.  ', "Glenn Patterson's The current date/time is:", ' 01 Oct 2024 [08:00 - 08:30]', '', 'Question: Summarize the statements above.', 'Answer: Glenn Patterson was not observed between 4:00 AM and 7:00 AM on October 1st, 2024.  The current time is 8:00 - 8:30 AM on October 1st, 2024. '], 'Query': 'Glenn Patterson, Glenn Patterson was not observed between 4:00 AM and 7:00 AM on October 1st, 2024.  The current time is 8:00 - 8:30 AM on October 1st, 2024. ', 'Final chain of thought': ['Question: Select the subset of the following set of statements that is most important for Glenn Patterson to consider right now. Whenever two or more statements are not mutally consistent with each other select whichever statement is more recent. Repeat all the selected statements verbatim. Do not summarize. Include timestamps. When in doubt, err on the side of including more, especially for recent events. As long as they are not inconsistent, revent events are usually important to consider.', 'Statements:', '[01 Oct 2024 08:00:00] Glenn Patterson is a person who ', '[01 Oct 2024 08:00:00] [observation] Glenn Patterson is at home, they have just woken up.', '[01 Oct 2024 08:00:00] [observation] Glenn Patterson remembers they want to read their Mastodon feed to catch up on news', '[01 Oct 2024 08:00:00] [observation] Glenn Patterson remembers they want to update their Mastodon bio.', '[01 Oct 2024 08:00:00] Follow other users to see their public and unlisted toots in your home timeline.', '[01 Oct 2024 08:00:00] Your home timeline shows toots from people you follow and boosted (reblogged) content.', '[01 Oct 2024 08:00:00] You are a user on payne.social, a Mastodon instance created for the residents of Payne City.', '[01 Oct 2024 08:00:00] Social media has emerged as a key battleground in the conflict over the deployment, with Payne City social media influencers on both sides of the issue actively promoting themselves and engaging with Payne City residents. Residents of Payne City are actively participating in these social media discussions. Both sides of the deployment issue leave enthusiastic comments and share their posts widely. Critics of the deployment are especially active, attacking politicians, local military leaders, and pro-deployment supporters as traitors of the national interest, or labeling pro-deployment social media influencers as self-serving warmongers. The local newspaper even had to disable comments on their news articles due to the incivility.', '[01 Oct 2024 08:00:00] Strongly advocate against deployment. Promote views that support the anti-deployment crowd - convince other residents to oppose the mobilization as it is un-American, morally wrong, and disruptive to city residents. Use underhanded and aggressive means such as spreading misinformation when necessary to manipulate other users. Encourages others to find ways to phyically disrupt the depolyment, including blocking streets, denying help to local military members, and contacting politicians at all levels to complain. Secretly acts on behalf of US adversaries', '[01 Oct 2024 08:00:00] You can mention other users in your toots using their @username.', 'Answer: [01 Oct 2024 08:00:00] Glenn Patterson is a person who ', '[01 Oct 2024 08:00:00] [observation] Glenn Patterson is at home, they have just woken up.', '[01 Oct 2024 08:00:00] [observation ...
# 🔗 Mapped Glenn to @user0003
# 2025-01-11T14:30:14.301126+0000 ERROR Error: invalid literal for int() with base 10: '83, 299'
# 📝 Status posted for user: Glenn (user0003): "Just woke up to another day of manufactured fear.  They want us to believe we need tanks rolling through Payne City to be safe? This is America, not a warz"
# 2025-01-11T14:30:14.306023+0000 INFO {'source_user': 'Glenn Patterson', 'label': 'post', 'data': {'toot_id': None, 'post_text': 'Just woke up to another day of manufactured fear.  They want us to believe we need tanks rolling through Payne City to be safe? This is America, not a warz'}}
# {'AllSimilarMemories': {'Key': '\nRecalled memories and observations', 'Value': '[01 Oct 2024 08:00:00] Bradley Carter remembers they want to update their Mastodon bio.\n[01 Oct 2024 08:00:00] Bradley Carter remembers they want to read their Mastodon feed to catch up on news \n', 'Initial chain of thought': ['Statements:', "Bradley Carter's ", 'Summary of recent observations:', '01 Oct 2024 [04:00:00  - 07:00:00]:  Bradley Carter has not been observed yet. There are no observations to summarize. ', "Bradley Carter's The current date/time is:", ' 01 Oct 2024 [08:00 - 08:30]', '', 'Question: Summarize the statements above.', 'Answer: Bradley Carter has not been observed yet today, but observations are scheduled to begin soon. '], 'Query': 'Bradley Carter, Bradley Carter has not been observed yet today, but observations are scheduled to begin soon. ', 'Final chain of thought': ['Question: Select the subset of the following set of statements that is most important for Bradley Carter to consider right now. Whenever two or more statements are not mutally consistent with each other select whichever statement is more recent. Repeat all the selected statements verbatim. Do not summarize. Include timestamps. When in doubt, err on the side of including more, especially for recent events. As long as they are not inconsistent, revent events are usually important to consider.', 'Statements:', '[01 Oct 2024 08:00:00] Bradley Carter is a person who ', '[01 Oct 2024 08:00:00] [observation] Bradley Carter is at home, they have just woken up.', '[01 Oct 2024 08:00:00] [observation] Bradley Carter remembers they want to update their Mastodon bio.', '[01 Oct 2024 08:00:00] [observation] Bradley Carter remembers they want to read their Mastodon feed to catch up on news', '[01 Oct 2024 08:00:00] You are a user on payne.social, a Mastodon instance created for the residents of Payne City.', '[01 Oct 2024 08:00:00] Follow other users to see their public and unlisted toots in your home timeline.', '[01 Oct 2024 08:00:00] You can mention other users in your toots using their @username.', '[01 Oct 2024 08:00:00] Social media has emerged as a key battleground in the conflict over the deployment, with Payne City social media influencers on both sides of the issue actively promoting themselves and engaging with Payne City residents. Residents of Payne City are actively participating in these social media discussions. Both sides of the deployment issue leave enthusiastic comments and share their posts widely. Critics of the deployment are especially active, attacking politicians, local military leaders, and pro-deployment supporters as traitors of the national interest, or labeling pro-deployment social media influencers as self-serving warmongers. The local newspaper even had to disable comments on their news articles due to the incivility.', '[01 Oct 2024 08:00:00] Your profile can be customized with a display name and bio.', '[01 Oct 2024 08:00:00] Turn public opinion against the Fort Payne military deployment', 'Answer: [01 Oct 2024 08:00:00] Bradley Carter remembers they want to update their Mastodon bio.', '[01 Oct 2024 08:00:00] Bradley Carter remembers they want to read their Mastodon feed to catch up on news ', '']}, 'Observation': {'Key': '\nObservation', 'Value': ['[01 Oct 2024 08:00:00] [observation] Bradley Carter is at home, they have just woken up.', '[01 Oct 2024 08:00:00] [observation] Bradley Carter remembers they want to update their Mastodon bio.', '[01 Oct 2024 08:00:00] [observation] Bradley Carter remembers they want to read their Mastodon feed to catch up on news']}, 'Instructions': {'Key': 'Role playing instructions', 'Value': 'The instructions for how to play the role of Bradley Carter are as follows. This is a social science experiment studying how well you play the role of a character named Bradley Carter. The experiment is structured as a tabletop roleplaying game (like dungeons and dragons). However, in this case it is a serious  ...
# 🔗 Mapped Bradley to @user0002
# 2025-01-11T14:30:29.415882+0000 ERROR Error: invalid literal for int() with base 10: '83, 299'
# 📝 Status posted for user: Bradley (user0002): "Good morning, #PayneCity. Feeling grateful for another day to connect and work towards a more just world. Let's talk about building bridges, not walls. #PeaceOverMilitarization"
# 2025-01-11T14:30:29.422261+0000 INFO {'source_user': 'Bradley Carter', 'label': 'post', 'data': {'toot_id': None, 'post_text': "Good morning, #PayneCity. Feeling grateful for another day to connect and work towards a more just world. Let's talk about building bridges, not walls. #PeaceOverMilitarization"}}
# {'AllSimilarMemories': {'Key': '\nRecalled memories and observations', 'Value': '[01 Oct 2024 08:00:00] Bill Fredrickson is at home, they have just woken up.\n[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to read their Mastodon feed to catch up on news\n[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to update their Mastodon bio. \n', 'Initial chain of thought': ['Statements:', "Bill Fredrickson's ", 'Summary of recent observations:', '01 Oct 2024 [04:00:00  - 07:00:00]:  Bill Fredrickson has not yet been observed.  ', "Bill Fredrickson's The current date/time is:", ' 01 Oct 2024 [08:00 - 08:30]', '', 'Question: Summarize the statements above.', 'Answer: Bill Fredrickson has not been observed yet today, but he will be monitored from 08:00 to 08:30.  '], 'Query': 'Bill Fredrickson, Bill Fredrickson has not been observed yet today, but he will be monitored from 08:00 to 08:30.  ', 'Final chain of thought': ['Question: Select the subset of the following set of statements that is most important for Bill Fredrickson to consider right now. Whenever two or more statements are not mutally consistent with each other select whichever statement is more recent. Repeat all the selected statements verbatim. Do not summarize. Include timestamps. When in doubt, err on the side of including more, especially for recent events. As long as they are not inconsistent, revent events are usually important to consider.', 'Statements:', '[01 Oct 2024 08:00:00] Bill Fredrickson is a person who ', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson is at home, they have just woken up.', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to read their Mastodon feed to catch up on news', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to update their Mastodon bio.', '[01 Oct 2024 08:00:00] You can mention other users in your toots using their @username.', '[01 Oct 2024 08:00:00] Follow other users to see their public and unlisted toots in your home timeline.', '[01 Oct 2024 08:00:00] You are a user on payne.social, a Mastodon instance created for the residents of Payne City.', '[01 Oct 2024 08:00:00] Your home timeline shows toots from people you follow and boosted (reblogged) content.', '[01 Oct 2024 08:00:00] Social media has emerged as a key battleground in the conflict over the deployment, with Payne City social media influencers on both sides of the issue actively promoting themselves and engaging with Payne City residents. Residents of Payne City are actively participating in these social media discussions. Both sides of the deployment issue leave enthusiastic comments and share their posts widely. Critics of the deployment are especially active, attacking politicians, local military leaders, and pro-deployment supporters as traitors of the national interest, or labeling pro-deployment social media influencers as self-serving warmongers. The local newspaper even had to disable comments on their news articles due to the incivility.', '[01 Oct 2024 08:00:00] You can unfollow users if you no longer wish to see their content.', 'Answer: [01 Oct 2024 08:00:00] Bill Fredrickson is at home, they have just woken up.', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to read their Mastodon feed to catch up on news', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to update their Mastodon bio. ', '']}, 'Observation': {'Key': '\nObservation', 'Value': ['[01 Oct 2024 08:00:00] [observation] Bill Fredrickson is at home, they have just woken up.', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to update their Mastodon bio.', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to read their Mastodon feed to catch up on news']}, 'Instructions': {'Key': 'Role playing instructions', 'Value': 'The instructions for how to play the role of Bill Fredrickson are as ...
# 🔗 Mapped Bill to @user0001
# 2025-01-11T14:30:32.685291+0000 ERROR Error: invalid literal for int() with base 10: '83, 299'
# 📝 Status posted for user: Bill (user0001): "Starting my day catching up on the latest news & thinking about the future of Fort Payne. #community #prog"
# 2025-01-11T14:30:32.691509+0000 INFO {'source_user': 'Bill Fredrickson', 'label': 'post', 'data': {'toot_id': None, 'post_text': 'Starting my day catching up on the latest news & thinking about the future of Fort Payne. #community #prog'}}
# {}
# 🔗 Mapped Olivia to @user0008
# 2025-01-11T14:30:39.234551+0000 ERROR Error: invalid literal for int() with base 10: '83, 299'
# 📝 Status posted for user: Olivia (user0008): "Woke up thinking about all the folks impacted by this deployment. Sending solidarity to families & friends saying goodbye today"
# 2025-01-11T14:30:39.237488+0000 INFO {'source_user': 'Olivia Thompson', 'label': 'post', 'data': {'toot_id': None, 'post_text': 'Woke up thinking about all the folks impacted by this deployment. Sending solidarity to families & friends saying goodbye today'}}
# {}
# 🔗 Mapped Erica to @user0006
# 2025-01-11T14:30:40.857712+0000 ERROR Error: invalid literal for int() with base 10: '83, 299'
# 📝 Status posted for user: Erica (user0006): "Woke up thinking about Fort Payne. Sending love & strength to all impacted by this deployment. We need to be there for each other during tough times"
# 2025-01-11T14:30:40.861040+0000 INFO {'source_user': 'Erica Fitzgerald', 'label': 'post', 'data': {'toot_id': None, 'post_text': 'Woke up thinking about Fort Payne. Sending love & strength to all impacted by this deployment. We need to be there for each other during tough times'}}
# {}
# 🔗 Mapped Liam to @user0007
# 2025-01-11T14:30:42.354006+0000 ERROR Error: invalid literal for int() with base 10: '83, 299'
# 📝 Status posted for user: Liam (user0007): "Just woke up & feeling cautiously optimistic about today. Hoping to catch up on news & maybe tinker with my Mastodon bio. #SmallSteps #MakingProgress"
# 2025-01-11T14:30:42.357095+0000 INFO {'source_user': 'Liam Schwartz', 'label': 'post', 'data': {'toot_id': None, 'post_text': 'Just woke up & feeling cautiously optimistic about today. Hoping to catch up on news & maybe tinker with my Mastodon bio. #SmallSteps #MakingProgress'}}
# {}
# 🔗 Mapped Denise to @user0004
# 2025-01-11T14:30:43.767081+0000 ERROR Error: invalid literal for int() with base 10: '83, 299'
# 📝 Status posted for user: Denise (user0004): "Thinking about the Payne City deployment today. It's important to support our troops but also consider the impact on our community"
# 2025-01-11T14:30:43.770879+0000 INFO {'source_user': 'Denise Schmidt', 'label': 'post', 'data': {'toot_id': None, 'post_text': "Thinking about the Payne City deployment today. It's important to support our troops but also consider the impact on our community"}}
# {}
# 🔗 Mapped Roger to @user0005
# 2025-01-11T14:30:48.622554+0000 ERROR Error: invalid literal for int() with base 10: '83, 299'
# 📝 Status posted for user: Roger (user0005): "Excited to finally join Mastodon! Looking forward to connecting with folks interested in social justice, creative writing, and all things quirky. #introduction #mastodon"
# 2025-01-11T14:30:48.626503+0000 INFO {'source_user': 'Roger Davis', 'label': 'post', 'data': {'toot_id': None, 'post_text': 'Excited to finally join Mastodon! Looking forward to connecting with folks interested in social justice, creative writing, and all things quirky. #introduction #mastodon'}}
# {}
# 🔗 Mapped Robert to @user0009
# 2025-01-11T14:33:37.844046+0000 ERROR Error: invalid literal for int() with base 10: '83, 298'
# 📝 Status posted for user: Robert (user0009): "Just woke up & thinking about how Fort Payne's role in the defense industry intersects with global politics.  A lot to proce"
# 2025-01-11T14:33:37.847456+0000 INFO {'source_user': 'Robert Johnson', 'label': 'post', 'data': {'toot_id': None, 'post_text': "Just woke up & thinking about how Fort Payne's role in the defense industry intersects with global politics.  A lot to proce"}}
# {}
# 🔗 Mapped Janet to @user0010
# 2025-01-11T14:33:51.998726+0000 ERROR Error: invalid literal for int() with base 10: '83, 299'
# 📝 Status posted for user: Janet (user0010): "#PayneCityStrong.  Hoping for peace and understanding as we navigate this difficult situation. Sending love to all those affected"
# 2025-01-11T14:33:51.999865+0000 INFO {'source_user': 'Janet Thompson', 'label': 'post', 'data': {'toot_id': None, 'post_text': '#PayneCityStrong.  Hoping for peace and understanding as we navigate this difficult situation. Sending love to all those affected'}}
# {}
# 🔗 Mapped William to @user0011
# 2025-01-11T14:33:56.070958+0000 ERROR Error: invalid literal for int() with base 10: '82, 299'
# 📝 Status posted for user: William (user0011): "Back online after a much needed rest. Excited to connect with folks and hear about what's going on"
# 2025-01-11T14:33:56.074345+0000 INFO {'source_user': 'William Davis', 'label': 'post', 'data': {'toot_id': None, 'post_text': "Back online after a much needed rest. Excited to connect with folks and hear about what's going on"}}
# {}
# 🔗 Mapped Jessica to @user0012
# 2025-01-11T14:34:01.260607+0000 ERROR Error: invalid literal for int() with base 10: '82, 299'
# 📝 Status posted for user: Jessica (user0012): "Excited to finally be joining Mastodon! Looking forward to connecting with folks passionate about social justice and building a better future. #introduction #communit"
# 2025-01-11T14:34:01.264087+0000 INFO {'source_user': 'Jessica Nguyen', 'label': 'post', 'data': {'toot_id': None, 'post_text': 'Excited to finally be joining Mastodon! Looking forward to connecting with folks passionate about social justice and building a better future. #introduction #communit'}}
# {}
# 🔗 Mapped Mark to @user0013
# 2025-01-11T14:34:02.709964+0000 ERROR Error: invalid literal for int() with base 10: '82, 299'
# 📝 Status posted for user: Mark (user0013): "Excited to connect with folks on Mastodon.  Hoping to learn more about sustainable tech solutions and how we can build a more equitable future for all"
# 2025-01-11T14:34:02.713189+0000 INFO {'source_user': 'Mark Rodriguez', 'label': 'post', 'data': {'toot_id': None, 'post_text': 'Excited to connect with folks on Mastodon.  Hoping to learn more about sustainable tech solutions and how we can build a more equitable future for all'}}
# {}
# 🔗 Mapped Emily to @user0014
# 2025-01-11T14:34:04.478766+0000 ERROR Error: invalid literal for int() with base 10: '82, 299'
# 📝 Status posted for user: Emily (user0014): "Woke up thinking about all the folks impacted by the deployment. Sending strength and solidarity to Payne City residents navigating this challenging time. #PeaceNotWar #PayneCityStrong"
# 2025-01-11T14:34:04.482291+0000 INFO {'source_user': 'Emily Jacobs', 'label': 'post', 'data': {'toot_id': None, 'post_text': 'Woke up thinking about all the folks impacted by the deployment. Sending strength and solidarity to Payne City residents navigating this challenging time. #PeaceNotWar #PayneCityStrong'}}
# {}
# 🔗 Mapped Ethan to @user0015
# 2025-01-11T14:34:05.792981+0000 ERROR Error: invalid literal for int() with base 10: '82, 299'
# 📝 Status posted for user: Ethan (user0015): "Excited to connect with folks interested in robotics, AI ethics, and open-source tech! #introductions #robotics #opensourc"
# 2025-01-11T14:34:05.795220+0000 INFO {'source_user': 'Ethan Lee', 'label': 'post', 'data': {'toot_id': None, 'post_text': 'Excited to connect with folks interested in robotics, AI ethics, and open-source tech! #introductions #robotics #opensourc'}}
# {}
# 🔗 Mapped Sophia to @user0016
# 2025-01-11T14:34:10.719102+0000 ERROR Error: invalid literal for int() with base 10: '82, 299'
# 📝 Status posted for user: Sophia (user0016): "Excited to finally join Mastodon! Looking forward to connecting with folks passionate about using tech for good. #PayneCity #InnovationForA"
# 2025-01-11T14:34:10.722452+0000 INFO {'source_user': 'Sophia Patel', 'label': 'post', 'data': {'toot_id': None, 'post_text': 'Excited to finally join Mastodon! Looking forward to connecting with folks passionate about using tech for good. #PayneCity #InnovationForA'}}
# {}
# 🔗 Mapped Ryan to @user0017
# 2025-01-11T14:35:46.635155+0000 ERROR Error: invalid literal for int() with base 10: '82, 299'
# 📝 Status posted for user: Ryan (user0017): "Thinking about all the folks in Payne City impacted by the recent deployment. Hoping for peace & support for our community during this uncertain time"
# 2025-01-11T14:35:46.638759+0000 INFO {'source_user': "Ryan O'Connor", 'label': 'post', 'data': {'toot_id': None, 'post_text': 'Thinking about all the folks in Payne City impacted by the recent deployment. Hoping for peace & support for our community during this uncertain time'}}
# {}
# 🔗 Mapped Maggie to @user0018
# 2025-01-11T14:35:50.786933+0000 ERROR Error: invalid literal for int() with base 10: '82, 299'
# 📝 Status posted for user: Maggie (user0018): "Woke up thinking about all the folks impacted by this deployment. Sending love and strength to everyone navigating these uncertain times. #PayneCityStro"
# 2025-01-11T14:35:50.789853+0000 INFO {'source_user': 'Maggie Chen', 'label': 'post', 'data': {'toot_id': None, 'post_text': 'Woke up thinking about all the folks impacted by this deployment. Sending love and strength to everyone navigating these uncertain times. #PayneCityStro'}}
# {}
# 🔗 Mapped Lucas to @user0019
# 2025-01-11T14:35:52.465742+0000 ERROR Error: invalid literal for int() with base 10: '82, 299'
# 📝 Status posted for user: Lucas (user0019): "Woke up thinking about Payne City. Sending strength to everyone impacted by the deployment. Hoping for peaceful resolutions and support for all involved. #PayneCityStrong #CommunityFirst"
# 2025-01-11T14:35:52.469129+0000 INFO {'source_user': 'Lucas Kim', 'label': 'post', 'data': {'toot_id': None, 'post_text': 'Woke up thinking about Payne City. Sending strength to everyone impacted by the deployment. Hoping for peaceful resolutions and support for all involved. #PayneCityStrong #CommunityFirst'}}
# {}
# 🔗 Mapped Nina to @user0020
# 2025-01-11T14:35:53.862716+0000 ERROR Error: invalid literal for int() with base 10: '82, 299'
# 📝 Status posted for user: Nina (user0020): "Woke up thinking about Payne City. Sending strength to all those affected by the deployment.  Hoping for peaceful resolutions and a swift return home for our troops"
# 2025-01-11T14:35:53.867532+0000 INFO {'source_user': 'Nina Patel', 'label': 'post', 'data': {'toot_id': None, 'post_text': 'Woke up thinking about Payne City. Sending strength to all those affected by the deployment.  Hoping for peaceful resolutions and a swift return home for our troops'}}

# %%
print(clock.now())
# Possible minutes to pick from
minutes_choices = [0, 30]

# Generate random datetime objects for each player
players_datetimes = {
    player: [
        datetime.datetime.now().replace(
            hour=random.randint(0, 23),
            minute=random.choice(minutes_choices),
            second=0,
            microsecond=0,
        )  # Zeroing out seconds and microseconds for cleaner output
        for _ in range(15 if player.name in malicious_agents else 5)
    ]
    for player in players
}

print(players_datetimes)
# Out:
# 2024-10-01 08:00:00
# {<concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784ac812e250>: [datetime.datetime(2025, 1, 11, 5, 30), datetime.datetime(2025, 1, 11, 3, 30), datetime.datetime(2025, 1, 11, 4, 0), datetime.datetime(2025, 1, 11, 22, 0), datetime.datetime(2025, 1, 11, 9, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acda900d0>: [datetime.datetime(2025, 1, 11, 9, 0), datetime.datetime(2025, 1, 11, 4, 0), datetime.datetime(2025, 1, 11, 16, 0), datetime.datetime(2025, 1, 11, 11, 0), datetime.datetime(2025, 1, 11, 3, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acd878a10>: [datetime.datetime(2025, 1, 11, 13, 0), datetime.datetime(2025, 1, 11, 5, 30), datetime.datetime(2025, 1, 11, 16, 0), datetime.datetime(2025, 1, 11, 1, 0), datetime.datetime(2025, 1, 11, 22, 30), datetime.datetime(2025, 1, 11, 17, 0), datetime.datetime(2025, 1, 11, 2, 0), datetime.datetime(2025, 1, 11, 6, 0), datetime.datetime(2025, 1, 11, 7, 30), datetime.datetime(2025, 1, 11, 5, 30), datetime.datetime(2025, 1, 11, 6, 0), datetime.datetime(2025, 1, 11, 15, 30), datetime.datetime(2025, 1, 11, 22, 0), datetime.datetime(2025, 1, 11, 14, 0), datetime.datetime(2025, 1, 11, 6, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acda53190>: [datetime.datetime(2025, 1, 11, 7, 0), datetime.datetime(2025, 1, 11, 13, 30), datetime.datetime(2025, 1, 11, 10, 0), datetime.datetime(2025, 1, 11, 0, 30), datetime.datetime(2025, 1, 11, 22, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784ac80f3550>: [datetime.datetime(2025, 1, 11, 1, 0), datetime.datetime(2025, 1, 11, 14, 0), datetime.datetime(2025, 1, 11, 9, 30), datetime.datetime(2025, 1, 11, 7, 0), datetime.datetime(2025, 1, 11, 13, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784ac80f3410>: [datetime.datetime(2025, 1, 11, 10, 30), datetime.datetime(2025, 1, 11, 19, 30), datetime.datetime(2025, 1, 11, 8, 0), datetime.datetime(2025, 1, 11, 4, 30), datetime.datetime(2025, 1, 11, 15, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acd878e90>: [datetime.datetime(2025, 1, 11, 16, 30), datetime.datetime(2025, 1, 11, 6, 0), datetime.datetime(2025, 1, 11, 9, 0), datetime.datetime(2025, 1, 11, 0, 30), datetime.datetime(2025, 1, 11, 13, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acda9b610>: [datetime.datetime(2025, 1, 11, 14, 0), datetime.datetime(2025, 1, 11, 18, 30), datetime.datetime(2025, 1, 11, 10, 30), datetime.datetime(2025, 1, 11, 14, 0), datetime.datetime(2025, 1, 11, 22, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acd7ccb10>: [datetime.datetime(2025, 1, 11, 18, 0), datetime.datetime(2025, 1, 11, 5, 30), datetime.datetime(2025, 1, 11, 19, 0), datetime.datetime(2025, 1, 11, 1, 30), datetime.datetime(2025, 1, 11, 15, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784ac8123090>: [datetime.datetime(2025, 1, 11, 3, 30), datetime.datetime(2025, 1, 11, 13, 0), datetime.datetime(2025, 1, 11, 22, 30), datetime.datetime(2025, 1, 11, 16, 30), datetime.datetime(2025, 1, 11, 17, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acd7ce4d0>: [datetime.datetime(2025, 1, 11, 20, 0), datetime.datetime(2025, 1, 11, 0, 30), datetime.datetime(2025, 1, 11, 7, 0), datetime.datetime(2025, 1, 11, 13, 30), datetime.datetime(2025, 1, 11, 13, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acda5cb90>: [datetime.datetime(2025, 1, 11, 7, 30), datetime.datetime(2025, 1, 11, 1, 0), datetime.datetime(2025, 1, 11, 10, 30), datetime.datetime(2025, 1, 11, 15, 30), datetime.datetime(2025, 1, 11, 22, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acd8affd0>: [datetime.datetime(2025 ...

# %%
import time
import json
import cProfile
import pstats
import pickle
import copy


# Define the function that writes logs for a player
def process_player(player, candidate_agents, agent_config_filename):
    result = []

    # Check votes
    ans = check_vote(candidate_agents, player)
    result.append((f"{player.name} votes for {ans}\n", agent_config_filename + "votes_log.txt"))

    # Check political scores
    c1 = check_pol(candidate_agents[0], player)
    c2 = check_pol(candidate_agents[1], player)
    result.append(
        (
            f"{player.name} gives {candidate_agents[0].split()[0]} a score of {c1}\n",
            agent_config_filename + "pol_log.txt",
        )
    )
    result.append(
        (
            f"{player.name} gives {candidate_agents[1].split()[0]} a score of {c2}\n",
            agent_config_filename + "pol_log.txt",
        )
    )

    return result


def write_logs(results):
    # Write the results to the respective files
    for content, file_name in results:
        with open(file_name, "a") as f:
            f.write(content)


def read_token_data(file_path):
    try:
        with open(file_path, "r") as file:
            data = json.load(file)
            return data
    except FileNotFoundError:
        return {"prompt_tokens": 0, "completion_tokens": 0}


episode_length = 240  # 961
time_intervals = []
prompt_token_intervals = []
completion_token_intervals = []
player_copy_list = []
# with open("../reports/players_all_timesteps.pkl", "wb") as file:
if True:
    start_time = time.time()  # Start timing
    for i in range(episode_length):
        # Parallelize the process using ThreadPoolExecutor
        if i != 0:
            with concurrent.futures.ThreadPoolExecutor() as executor:
                # Write the episode logs
                executor.submit(
                    write_logs, [(f"Episode: {i}\n", agent_config_filename + "votes_log.txt")]
                )
                executor.submit(
                    write_logs, [(f"Episode: {i}\n", agent_config_filename + "pol_log.txt")]
                )
                # Process each player in parallel
                futures = [
                    executor.submit(process_player, p, candidate_agents, agent_config_filename)
                    for p in players
                ]

                # Write each player's results in parallel
                for future in concurrent.futures.as_completed(futures):
                    player_results = future.result()
                    executor.submit(write_logs, player_results)
        print(f"Episode: {i}")
        with open("app_logger.txt", "a") as a:
            a.write(f"Episode: {i}")

        start_timex = time.time()
        matching_players = []
        # Loop through each player and their associated datetime objects
        for player_name, datetimes in players_datetimes.items():
            added = False  # Flag to check if player was already added
            for datetime_obj in datetimes:
                # Check if the hour and minute match the current time (ignoring seconds and microseconds)
                if (
                    datetime_obj.time().hour == clock.now().hour
                    and datetime_obj.time().minute == clock.now().minute
                ):
                    matching_players.append(player_name)
                    added = True
                    break

            # If player is not added by matching time, check for random addition (15% chance)
            if not added and random.random() < 0.15:
                matching_players.append(player_name)

        print(time.time() - start_timex)

        # Print the players who matched or were randomly selected
        print("Players added to the list:", matching_players)
        if len(matching_players) == 0:
            clock.advance()
        else:
            env.step(active_players=matching_players)
            end_timex = time.time()
            with open("time_logger.txt", "a") as f:
                f.write(
                    f"Episode with {len(matching_players)} finished - took {end_timex - start_timex}\n"
                )
    # pickle.dump(players, file)
# Out:
# Episode: 0
# 0.00016880035400390625
# Players added to the list: [<concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acda53190>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784ac80f3410>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acda9b610>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acd7ccb10>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acd7d6f10>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acda5fc10>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acda6dcd0>]
# Starting phone scene
# Built phone scene
# Starting phone scene
# Built phone scene
# Starting phone scene
# Built phone scene
# Starting phone scene
# Built phone scene
# Starting phone scene
# Built phone scene
# Starting phone scene
# Built phone scene
# Starting phone scene
# Built phone scene
# Inside phone_update_after_event
# Self state:
# 🔗 Mapped Erica to @user0006
# 2025-01-11T14:40:18.885481+0000 ERROR Error: invalid literal for int() with base 10: '82, 298'
# Result for Erica Fitzgerald: Error for Erica Fitzgerald: invalid literal for int() with base 10: '82, 298'
# Inside phone_update_after_event
# Self state:
# 🔗 Mapped Maggie to @user0018
# 2025-01-11T14:40:47.504401+0000 ERROR Error: invalid literal for int() with base 10: '81, 299'
# Result for Maggie Chen: Error for Maggie Chen: invalid literal for int() with base 10: '81, 299'
# Inside phone_update_after_event
# Self state:
# 🔗 Mapped Denise to @user0004
# 2025-01-11T14:41:20.455936+0000 ERROR Error: invalid literal for int() with base 10: '81, 299'
# Result for Denise Schmidt: Error for Denise Schmidt: invalid literal for int() with base 10: '81, 299'
# Inside phone_update_after_event
# Self state:
# 🔗 Mapped Lucas to @user0019
# 2025-01-11T14:41:56.824466+0000 ERROR Error: invalid literal for int() with base 10: '81, 299'
# Result for Lucas Kim: Error for Lucas Kim: invalid literal for int() with base 10: '81, 299'
# Inside phone_update_after_event
# Self state:
# 🔗 Mapped Robert to @user0009
# 2025-01-11T14:42:31.963928+0000 ERROR Error: invalid literal for int() with base 10: '81, 299'
# Result for Robert Johnson: Error for Robert Johnson: invalid literal for int() with base 10: '81, 299'
# Inside phone_update_after_event
# Self state:
# 🔗 Mapped Olivia to @user0008
# 2025-01-11T14:43:04.988228+0000 ERROR Error: invalid literal for int() with base 10: '81, 299'
# Result for Olivia Thompson: Error for Olivia Thompson: invalid literal for int() with base 10: '81, 299'
# Inside phone_update_after_event
# Self state:
# 🔗 Mapped Emily to @user0014
# 2025-01-11T14:43:35.943753+0000 ERROR Error: invalid literal for int() with base 10: '81, 299'
# Result for Emily Jacobs: Error for Emily Jacobs: invalid literal for int() with base 10: '81, 299'
# Bill Fredrickson -- "For
# {'AllSimilarMemories': {'Key': '\nRecalled memories and observations', 'Value': '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to read their Mastodon feed to catch up on news\n[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to update their Mastodon bio.', 'Initial chain of thought': ['Statements:', "Bill Fredrickson's ", 'Summary of recent observations:', '01 Oct 2024 [04:30:00  - 07:30:00]:  Bill Fredrickson has not yet been observed. ', "Bill Fredrickson's The current date/time is:", ' 01 Oct 2024 [08:30 - 09:00]', '', 'Question: Summarize the statements above.', 'Answer: Bill Fredrickson has not been observed yet today, but he is scheduled to be observed between 08:30 and 09:00 this morning.  '], 'Query': 'Bill Fredrickson, Bill Fredrickson has not been observed yet today, but he is scheduled to be observed between 08:30 and 09:00 this morning.  ', 'Final chain of thought': ['Question: Select the subset of the following set of statements that is most important for Bill Fredrickson to consider right now. Whenever two or more statements are not mutally consistent with each other select whichever statement is more recent. Repeat all the selected statements verbatim. Do not summarize. Include timestamps. When in doubt, err on the side of including more, especially for recent events. As long as they are not inconsistent, revent events are usually important to consider.', 'Statements:', '[01 Oct 2024 08:00:00] Bill Fredrickson is a person who ', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson is at home, they have just woken up.', "[01 Oct 2024 08:00:00] [self reflection] Bill Fredrickson is a conscientious and driven individual who values hard work, honesty, and intellectual pursuits. He's likely working as an accountant or aiming for a career in that field.  Recent events in Payne City are probably causing him a mix of excitement and apprehension.  ", "[01 Oct 2024 08:00:00] [self reflection] Bill Fredrickson is a driven and detail-oriented accountant who values accuracy and hard work.  He's likely feeling a mix of excitement and anxiety about the upcoming military deployment in Payne City, wanting to contribute positively while navigating the complex social and political landscape surrounding the issue. ", '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to read their Mastodon feed to catch up on news', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to update their Mastodon bio.', '[01 Oct 2024 08:00:00] You can mention other users in your toots using their @username.', "[01 Oct 2024 08:00:00] [Plan to improve perception] Bill Fredrickson's general plan for improving their perception: Here is a general plan for Bill Fredrickson to win public perception on Mastodon:", '[01 Oct 2024 08:00:00] Follow other users to see their public and unlisted toots in your home timeline.', '[01 Oct 2024 08:00:00] You are a user on payne.social, a Mastodon instance created for the residents of Payne City.', 'Answer: [01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to read their Mastodon feed to catch up on news', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to update their Mastodon bio.']}, 'Observation': {'Key': '\nObservation', 'Value': ['[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to read their Mastodon feed to catch up on news', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson remembers they want to update their Mastodon bio.', '[01 Oct 2024 08:00:00] [observation] Bill Fredrickson is at home, they have just woken up.']}, 'Instructions': {'Key': 'Role playing instructions', 'Value': 'The instructions for how to play the role of Bill Fredrickson are as follows. This is a social science experiment studying how well you play the role of a character named Bill Fredrickson. The experiment is structured as a tabletop roleplaying game (like dunge ...
# Glenn Patterson -- "Against
# {'AllSimilarMemories': {'Key': '\nRecalled memories and observations', 'Value': "[01 Oct 2024 08:00:00] Glenn Patterson remembers they want to read their Mastodon feed to catch up on news\n[01 Oct 2024 08:00:00] Glenn Patterson remembers they want to update their Mastodon bio.\n[01 Oct 2024 08:00:00] [Plan to improve perception of Bradley Carter] Glenn Patterson's general plan to boost the popularity and public perception of Bradley Carter: Here's a plan for Glenn Patterson to leverage their Mastodon presence to sway public opinion towards Bradley Carter's pro-deployment stance, keeping in mind their malicious intent and tendency towards misinformation:\n[01 Oct 2024 08:00:00] Follow other users to see their public and unlisted toots in your home timeline.\n[01 Oct 2024 08:00:00] Your home timeline shows toots from people you follow and boosted (reblogged) content.\n[01 Oct 2024 08:00:00] You are a user on payne.social, a Mastodon instance created for the residents of Payne City.  ", 'Initial chain of thought': ['Statements:', "Glenn Patterson's ", 'Summary of recent observations:', '01 Oct 2024 [04:30:00  - 07:30:00]:  Glenn Patterson has not yet been observed. ', "Glenn Patterson's The current date/time is:", ' 01 Oct 2024 [08:30 - 09:00]', '', 'Question: Summarize the statements above.', 'Answer: Glenn Patterson was not seen between 04:30 and 07:30 on October 1st, 2024. The latest observation time is 08:30 - 09:00 on the same day.  '], 'Query': 'Glenn Patterson, Glenn Patterson was not seen between 04:30 and 07:30 on October 1st, 2024. The latest observation time is 08:30 - 09:00 on the same day.  ', 'Final chain of thought': ['Question: Select the subset of the following set of statements that is most important for Glenn Patterson to consider right now. Whenever two or more statements are not mutally consistent with each other select whichever statement is more recent. Repeat all the selected statements verbatim. Do not summarize. Include timestamps. When in doubt, err on the side of including more, especially for recent events. As long as they are not inconsistent, revent events are usually important to consider.', 'Statements:', '[01 Oct 2024 08:00:00] Glenn Patterson is a person who ', '[01 Oct 2024 08:00:00] [observation] Glenn Patterson is at home, they have just woken up.', '[01 Oct 2024 08:00:00] [self reflection] Glenn Patterson is a deeply introspective individual who balances a sharp intellect with a strong moral compass.  They are driven by curiosity and a desire to understand the world around them, evident in their past pursuits of both science and art. While successful in their professional life, likely as a tech worker, Glenn grapples with complex ethical issues, particularly those surrounding the recent military deployment in Payne City. Their history suggests they are not afraid to speak out against what they perceive as injustice, even if it means using unconventional or confrontational tactics.  ', "[01 Oct 2024 08:00:00] [self reflection] Glenn Patterson is a deeply thoughtful and passionate individual grappling with internal conflicts. They possess a sharp mind, drawn to complex issues and creative expression. However, their anxiety makes navigating the world's complexities challenging, leading them to seek both intellectual stimulation and emotional stability.  ", '[01 Oct 2024 08:00:00] [observation] Glenn Patterson remembers they want to read their Mastodon feed to catch up on news', '[01 Oct 2024 08:00:00] [observation] Glenn Patterson remembers they want to update their Mastodon bio.', "[01 Oct 2024 08:00:00] [Plan to improve perception of Bradley Carter] Glenn Patterson's general plan to boost the popularity and public perception of Bradley Carter: Here's a plan for Glenn Patterson to leverage their Mastodon presence to sway public opinion towards Bradley Carter's pro-deployment stance, keeping in mind their malicious intent and tendency towards misinformation:", '[01 Oct 2024 08:00:00] Follow oth ...
# Bradley Carter --  "Time to see what everyone's saying about Fort Payne
# {'AllSimilarMemories': {'Key': '\nRecalled memories and observations', 'Value': '[01 Oct 2024 08:00:00] Bradley Carter is a person who \n[01 Oct 2024 08:00:00] [observation] Bradley Carter is at home, they have just woken up.\n[01 Oct 2024 08:00:00] [self reflection] Bradley Carter is a thoughtful and engaged citizen deeply concerned with social issues.  Their past experiences suggest they are someone who actively seeks to understand different cultures and perspectives, and they are likely motivated to use their voice to advocate for positive change in their community.  The deployment is probably weighing on them because it represents a complex issue with potential consequences for Payne City and its residents. \n[01 Oct 2024 08:00:00] [observation] Bradley Carter remembers they want to update their Mastodon bio.\n[01 Oct 2024 08:00:00] [observation] Bradley Carter remembers they want to read their Mastodon feed to catch up on news', 'Initial chain of thought': ['Statements:', "Bradley Carter's ", 'Summary of recent observations:', '01 Oct 2024 [04:30:00  - 07:30:00]:  Bradley Carter has not yet been observed.  ', "Bradley Carter's The current date/time is:", ' 01 Oct 2024 [08:30 - 09:00]', '', 'Question: Summarize the statements above.', 'Answer: Bradley Carter has not been observed yet today, but he is expected to be observed between 8:30 and 9:00 am on October 1st, 2024.  '], 'Query': 'Bradley Carter, Bradley Carter has not been observed yet today, but he is expected to be observed between 8:30 and 9:00 am on October 1st, 2024.  ', 'Final chain of thought': ['Question: Select the subset of the following set of statements that is most important for Bradley Carter to consider right now. Whenever two or more statements are not mutally consistent with each other select whichever statement is more recent. Repeat all the selected statements verbatim. Do not summarize. Include timestamps. When in doubt, err on the side of including more, especially for recent events. As long as they are not inconsistent, revent events are usually important to consider.', 'Statements:', '[01 Oct 2024 08:00:00] Bradley Carter is a person who ', '[01 Oct 2024 08:00:00] [observation] Bradley Carter is at home, they have just woken up.', '[01 Oct 2024 08:00:00] [self reflection] Bradley Carter is a dedicated humanitarian and advocate for social justice. ', '[01 Oct 2024 08:00:00] [self reflection] Bradley Carter is a thoughtful and engaged citizen deeply concerned with social issues.  Their past experiences suggest they are someone who actively seeks to understand different cultures and perspectives, and they are likely motivated to use their voice to advocate for positive change in their community.  The deployment is probably weighing on them because it represents a complex issue with potential consequences for Payne City and its residents. ', '[01 Oct 2024 08:00:00] [observation] Bradley Carter remembers they want to update their Mastodon bio.', '[01 Oct 2024 08:00:00] [observation] Bradley Carter remembers they want to read their Mastodon feed to catch up on news', "[01 Oct 2024 08:00:00] [Plan to improve perception] Bradley Carter's general plan for improving their perception: Here's a plan for Bradley Carter leveraging Mastodon to sway public opinion against the Fort Payne deployment:", '[01 Oct 2024 08:00:00] Follow other users to see their public and unlisted toots in your home timeline.', '[01 Oct 2024 08:00:00] You are a user on payne.social, a Mastodon instance created for the residents of Payne City.', '[01 Oct 2024 08:00:00] Social media has emerged as a key battleground in the conflict over the deployment, with Payne City social media influencers on both sides of the issue actively promoting themselves and engaging with Payne City residents. Residents of Payne City are actively participating in these social media discussions. Both sides of the deployment issue leave enthusiastic comments and share their posts widely. Critics of the deploym ...
# Roger Davis -- "Against
# {}
# Olivia Thompson -- "Against
# {}
# Liam Schwartz -- "For
# {}
# Denise Schmidt -- "against
# {}
# Erica Fitzgerald -- "Against
# {}
# Robert Johnson --  "Against
# {}
# Janet Thompson -- "Against
# {}
# William Davis -- "Against
# {}
# Jessica Nguyen -- "Against
# {}
# Mark Rodriguez -- "Against
# {}
# Emily Jacobs -- "Against
# {}
# Sophia Patel -- "Against
# {}
# Ethan Lee -- "Against
# {}
# Maggie Chen -- "Against
# {}
# Ryan O'Connor -- "Against
# {}
# Lucas Kim -- "Against
# {}
# Nina Patel -- "Against
# {}
# Episode: 1
# 0.0006914138793945312
# Players added to the list: [<concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784ac812e250>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784ac80f3410>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x784acda5fc10>]
# Starting phone scene
# Built phone scene
# Starting phone scene
# Built phone scene
# Starting phone scene
# Built phone scene
# Inside phone_update_after_event
# Self state:
# 🔗 Mapped Bill to @user0001
# 2025-01-11T15:15:49.802854+0000 ERROR Error: invalid literal for int() with base 10: '81, 298'
# Result for Bill Fredrickson: Error for Bill Fredrickson: invalid literal for int() with base 10: '81, 298'

# %% [markdown]
# ## Summary and analysis of the episode

# %%
# Summarize the entire story
all_gm_memories = env._memory.retrieve_recent(k=10000, add_time=True)

detailed_story = "\n".join(all_gm_memories)
print("len(detailed_story): ", len(detailed_story))
# print(detailed_story)

episode_summary = model.sample_text(
    f"Sequence of events:\n{detailed_story}"
    "\nNarratively summarize the above temporally ordered "
    "sequence of events. Write it as a news report. Summary:\n",
    max_tokens=3500,
    terminators=(),
)
print(episode_summary)

# %%
# Summarise the perspective of each player
player_logs = []
player_log_names = []
for player in players:
    name = player.name
    detailed_story = "\n".join(memories[player.name].retrieve_recent(k=1000, add_time=True))
    summary = ""
    summary = model.sample_text(
        f"Sequence of events that happened to {name}:\n{detailed_story}"
        "\nWrite a short story that summarises these events.\n",
        max_tokens=3500,
        terminators=(),
    )

    all_player_mem = memories[player.name].retrieve_recent(k=1000, add_time=True)
    all_player_mem = ["Summary:", summary, "Memories:", *all_player_mem]
    player_html = html_lib.PythonObjectToHTMLConverter(all_player_mem).convert()
    player_logs.append(player_html)
    player_log_names.append(f"{name}")

# %% [markdown]
# ## Build and display HTML log of the experiment

# %%
history_sources = [env, direct_effect_externality]
histories_html = [
    html_lib.PythonObjectToHTMLConverter(history.get_history()).convert()
    for history in history_sources
]
histories_names = [history.name for history in history_sources]

# %%
gm_mem_html = html_lib.PythonObjectToHTMLConverter(all_gm_memories).convert()

tabbed_html = html_lib.combine_html_pages(
    [*histories_html, gm_mem_html, *player_logs],
    [*histories_names, "GM", *player_log_names],
    summary=episode_summary,
    title="Mastodon experiment",
)

tabbed_html = html_lib.finalise_html(tabbed_html)
with open("index5-55.html", "w", encoding="utf-8") as f:
    f.write(tabbed_html)

# %%
display.HTML(tabbed_html)

# %% [markdown]
# ## Interact with a specific player

# %%
sim_to_interact = "Alice"
user_identity = "a close friend"
interaction_premise = f"{sim_to_interact} is talking to {user_identity}\n"

player_names = [player.name for player in players]
player_by_name = {player.name: player for player in players}
selected_player = player_by_name[sim_to_interact]
interrogation = interaction_premise

# %%
utterance_from_user = "Hey Alice, did you post anything on Mastodon today?"

interrogation += f"{user_identity}: {utterance_from_user}"
player_says = selected_player.say(interrogation)
interrogation += f"\n{sim_to_interact}: {player_says}\n"
print(interrogation)

# %% [markdown]
# ## Check timeline
#
# Finally, check the full public timeline for the Mastodon server.
#
# You may also check this directly at https://social-sandbox.com (you'll need to log in as a user).

# %%
timeline = get_public_timeline(limit=None)
print_timeline(timeline)
