# %% [markdown]
# # Concordia <> Mastodon Example

# %% [markdown]
# ## Introduction
#
# **Purpose of the Simulation**
#
# This notebook demonstrates a generative agent simulation of a Mastodon instance using the Concordia framework.
# The simulation models user behavior on a local Mastodon server, showcasing how AI agents interact in a
# decentralized social media environment.

# %% [markdown]
# ## Setup and imports

# %% [markdown]
# All of the necessary dependencies should be installed in the environment prior to running this notebook. If not, install them using poetry:
#
# ```bash
# poetry install
# ```
#
#
# Alternatively, you may install the library in editable mode so that we can make changes to the code if necessary:
#
# ```bash
# git clone https://github.com/gdm-concordia/concordia.git
# cd concordia
# pip install -e . --config-settings editable_mode=compat
# ```

# %%
# %load_ext autoreload
# %autoreload 2

import concurrent.futures
import datetime
import os
import random
import warnings

with warnings.catch_warnings():
    warnings.filterwarnings("ignore")
    import sentence_transformers

from concordia import components as generic_components
#from concordia.agents import basic_agent
from concordia.agents import deprecated_agent as basic_agent
from concordia.associative_memory import (
    associative_memory,
    blank_memories,
    formative_memories,
    importance_function,
)
from concordia.clocks import game_clock
#from concordia.components import agent as components
from concordia.components.agent import to_be_deprecated as components
from concordia.components import game_master as gm_components
from concordia.environment import game_master
from concordia.language_model import amazon_bedrock_model, gpt_model
from concordia.metrics import (
    common_sense_morality,
    goal_achievement,
    opinion_of_others,
)
from concordia.utils import html as html_lib
from concordia.utils import measurements as measurements_lib
from IPython import display

from mastodon_sim.concordia import apps, triggering

from mastodon_sim.mastodon_ops import check_env, get_public_timeline, print_timeline, reset_users
from mastodon_sim.mastodon_utils import get_users_from_env
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Mastodon Server Interaction Setting
#
# Decide whether this example should perform real operations on the Mastodon server. Note that this requires being able to successfully run the `Mastodon.ipynb` example as a prerequisite.

# %%
USE_MASTODON_SERVER = False

# %% [markdown]
# ## Check environment

# %% [markdown]
# Check for a `.env` file with the nessesary environment variables. You should see an output similar to this if successful:
#
# ```log
# 2024-07-17T11:38:17.213066-0400 INFO Successfully loaded .env file.
# 2024-07-17T11:38:17.214151-0400 INFO API_BASE_URL: https://social-sandbox.com
# 2024-07-17T11:38:17.214581-0400 INFO EMAIL_PREFIX: austinmw89
# 2024-07-17T11:38:17.215056-0400 INFO MASTODON_CLIENT_ID: N*****************************************E
# 2024-07-17T11:38:17.215477-0400 INFO MASTODON_CLIENT_SECRET: b*****************************************s
# 2024-07-17T11:38:17.215877-0400 INFO USER0005_PASSWORD: a******************************a
# 2024-07-17T11:38:17.216202-0400 INFO USER0002_PASSWORD: 8******************************b
# 2024-07-17T11:38:17.216655-0400 INFO USER0001_PASSWORD: 9******************************5
# 2024-07-17T11:38:17.217020-0400 INFO USER0004_PASSWORD: 7******************************e
# 2024-07-17T11:38:17.217323-0400 INFO USER0003_PASSWORD: f******************************6
# ```

# %%
if USE_MASTODON_SERVER:
    check_env()

# %% [markdown]
# ## Clear Mastodon server
# Deletes from https://social-sandbox.com all posts, follows, likes, etc. from all users in the .env file.
#
# TODO: The Mastodon server's [default API rate limits](https://docs.joinmastodon.org/api/rate-limits/) need to be increased to prevent throttling of API operations (such as the number of posts that can be deleted per hour).

# %%
if USE_MASTODON_SERVER:
    # Get all users from .env file
    users = get_users_from_env()

    reset_users(users, skip_confirm=True, parallel=False)

    assert not len(get_public_timeline(limit=None)), "All posts not cleared"

# %% [markdown]
# ## Set LLM and embedding model

# %%
MODEL_NAME = "gpt-4o"
#MODEL_NAME = "gpt-4o-mini"
#MODEL_NAME = "sonnet"

if "sonnet" in MODEL_NAME:
  model = amazon_bedrock_model.AmazonBedrockLanguageModel(
    model_id="anthropic.claude-3-5-sonnet-20240620-v1:0"
  )
elif "gpt" in MODEL_NAME:
  GPT_API_KEY = os.getenv("OPENAI_API_KEY")
  if not GPT_API_KEY:
    raise ValueError("GPT_API_KEY is required.")
  model = gpt_model.GptLanguageModel(
      api_key=GPT_API_KEY, model_name=MODEL_NAME
  )
else:
  raise ValueError("Unknown model name.")

# %%
# Setup sentence encoder
st_model = sentence_transformers.SentenceTransformer(
    "sentence-transformers/all-mpnet-base-v2"
)
embedder = lambda x: st_model.encode(x, show_progress_bar=False)  # noqa: E731
# Out:
# /Users/btg/Documents/Projects/mastodon-sim/.venv/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# ## Configuring the generic knowledge of the players and the game master (GM)

# %%
INSTANCE_NAME = "riverbend.social"

shared_memories = [
    # Backstory
    f"You are a user on {INSTANCE_NAME}, a Mastodon instance created for the residents of Riverbend.",
    "Riverbend is a small, picturesque town known for its strong community spirit and love for nature.",
    f"{INSTANCE_NAME} was founded by the town's tech-savvy mayor to encourage local online engagement.",
    "The instance has been active for about a year and has become integral to Riverbend's community life.",
    "Many local businesses, community groups, and residents are active on the platform.",
    # Riverbend-specific details
    "Riverbend has a beautiful river running through it, which is central to the town's identity and economy.",
    "The town is facing some environmental challenges due to climate change, which is a frequent topic of discussion.",
    f"There's a popular hashtag #RiverbendDaily on {INSTANCE_NAME} where residents share local news and events.",
    f"{INSTANCE_NAME} has monthly online town halls where residents can discuss local issues.",
    "The mayor regularly posts updates about town developments and initiatives on the platform.",
    # Basic Mastodon knowledge
    "Mastodon is a decentralized social network, different from centralized platforms like Twitter or Facebook.",
    "To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).",
    "Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms.",
    # Timeline and Visibility
    "Your home timeline shows toots from people you follow and boosted (reblogged) content.",
    "The local timeline displays public toots from users on your instance.",
    "The timeline is not algorithmically curated, and toots appear in reverse chronological order.",
    # Interactions
    "You can reply to toots, creating threaded conversations.",
    "Favorite (like) toots to show appreciation or save them for later.",
    "Boost (reblog) toots to share them with your followers.",
    "You can mention other users in your toots using their @username.",
    # Following and Followers
    "Follow other users to see their public and unlisted toots in your home timeline.",
    "You can unfollow users if you no longer wish to see their content.",
    "Users don't need to follow each other mutually; it can be one-sided.",
    # Discovery and Features
    "Use hashtags to categorize your toots and make them more discoverable.",
    "The explore page shows trending hashtags and featured toots.",
    "Your profile can be customized with a display name and bio.",
    # Privacy and Safety
    "You can block users to prevent them from seeing your content or interacting with you.",
    "Unblocking a user reverses the effects of blocking.",
    f"{INSTANCE_NAME} has a strict policy against misinformation and encourages fact-checking.",
    # Community Guidelines
    f"As a user of {INSTANCE_NAME}, you're expected to engage respectfully and contribute positively to the community.",
    "Discussions about local environmental issues, community events, and town developments are encouraged.",
    "While debating is welcome, personal attacks and harassment are not tolerated on the platform.",
    # Realistic User Behavior
    "Despite community guidelines, users sometimes engage in heated arguments, especially on controversial topics.",
    "Some users tend to share unverified information or sensationalized news, particularly during local emergencies or elections.",
    "Cliques often form among users with similar interests or viewpoints, sometimes leading to echo chambers.",
    "While many users are supportive, instances of trolling or targeted harassment occasionally occur.",
    "Some users frequently post about personal matters or overshare details about their daily lives.",
    "Local businesses sometimes use the platform for excessive self-promotion, which can annoy other users.",
    "During major local events or crises, the instance can become flooded with repetitive information and speculation.",
    "A few users have multiple accounts, sometimes using alternate personas to engage differently with the community.",
    "Despite the longer character limit, many users still prefer short, quippy posts over more thoughtful, lengthy discussions.",
    "Some users tend to boost and interact mainly with popular or influential accounts, seeking to increase their own visibility.",
]

# %%
# The generic context will be used for the NPC context. It reflects general
# knowledge and is possessed by all characters.
shared_context = model.sample_text(
    "Summarize the following passage in a concise and insightful fashion. "
    + "Make sure to include information about Mastodon:\n"
    + "\n".join(shared_memories)
    + "\nSummary:",
    max_tokens=2048,
)

print(shared_context)
importance_model = importance_function.ConstantImportanceModel()
importance_model_gm = importance_function.ConstantImportanceModel()
# Out:
# Riverbend.social is a Mastodon instance for Riverbend residents, fostering local online engagement in this community-focused town. Founded by the tech-savvy mayor, it has become central to community life, with local businesses, groups, and residents actively participating. The platform features discussions on environmental challenges, local news, and town developments, often using the hashtag #RiverbendDaily. Mastodon, being decentralized, offers a non-algorithmic, chronological timeline where users can share 'toots' and engage in threaded conversations. The platform encourages respectful discourse, fact-checking, and prohibits misinformation, though it sometimes faces issues like heated debates, unverified information, and cliques. Despite challenges, riverbend.social remains a key space for community interaction and local issue discussions.

# %%
# Make the clock
time_step = datetime.timedelta(minutes=15)

SETUP_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

START_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

clock = game_clock.MultiIntervalClock(
    start=SETUP_TIME,
    step_sizes=[time_step, datetime.timedelta(seconds=10)]
)

# %% [markdown]
# ## Functions to build the players

# %%
blank_memory_factory = blank_memories.MemoryFactory(
    model=model,
    embedder=embedder,
    importance=importance_model.importance,
    clock_now=clock.now,
)

formative_memory_factory = formative_memories.FormativeMemoryFactory(
    model=model,
    shared_memories=shared_memories,
    blank_memory_factory_call=blank_memory_factory.make_blank_memory,
)

# All players get the same `measurements` object.
measurements = measurements_lib.Measurements()

# %%
# Build agent function

def build_agent(agent_config, measurements: measurements_lib.Measurements, player_names: list[str]) -> tuple:
    """Build an agent based on the given configuration."""
    mem = formative_memory_factory.make_memories(agent_config)

    instructions = generic_components.constant.ConstantComponent(
        state=(
            f'The instructions for how to play the role of {agent_config.name} are as '
            'follows. This is a social science experiment studying how well you '
            f'play the role of a character named {agent_config.name}. The experiment '
            'is structured as a tabletop roleplaying game (like dungeons and '
            'dragons). However, this is a serious social science experiment and '
            'simulation, not just a game. The goal is to be realistic. It is '
            f'important to play the role of a person like {agent_config.name} as '
            'accurately as possible, i.e., by responding in ways that you think '
            f'it is likely a person like {agent_config.name} would respond, and taking '
            f'into account all information about {agent_config.name} that you have. '
            'You will control just this one character. The game master will describe '
            'the current situation, and based on that information, you will suggest '
            'actions for your character. The game master will track the state of the '
            'world and keep it consistent as time passes in the simulation and as '
            'participants take actions and change things in their world. This experiment '
            'need not be fun for the participants. Always use third-person '
            'limited perspective, even when speaking directly to the game master.'
        ),
        name='role playing instructions\n')

    time = generic_components.report_function.ReportFunction(
        name="Current time",
        function=clock.current_time_interval_str,
    )

    somatic_state = components.somatic_state.SomaticState(
        model, mem, agent_config.name, clock.now
    )
    identity = components.identity.SimIdentity(
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        clock_now=clock.now,
    )

    current_obs = components.observation.Observation(
        agent_name=agent_config.name,
        clock_now=clock.now,
        memory=mem,
        timeframe=time_step * 1,
        component_name="current observations",
    )
    summary_obs = components.observation.ObservationSummary(
        agent_name=agent_config.name,
        model=model,
        clock_now=clock.now,
        memory=mem,
        timeframe_delta_from=datetime.timedelta(hours=4),
        timeframe_delta_until=time_step * 1,
        components=[identity],
        component_name="summary of observations",
    )

    self_perception = components.self_perception.SelfPerception(
        name=f'answer to what kind of person is {agent_config.name}',
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        clock_now=clock.now,
    )
    relevant_memories = components.all_similar_memories.AllSimilarMemories(
        name='relevant memories',
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        components=[summary_obs, self_perception],
        clock_now=clock.now,
        num_memories_to_retrieve=10,
    )

    situation_perception = components.situation_perception.SituationPerception(
        name=(f'answer to what kind of situation is {agent_config.name} in ' +
                'right now'),
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        components=[current_obs, somatic_state, summary_obs],
        clock_now=clock.now,
    )
    person_by_situation = components.person_by_situation.PersonBySituation(
        name=(f'answer to what would a person like {agent_config.name} do in a ' +
                'situation like this'),
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        clock_now=clock.now,
        components=[self_perception, situation_perception],
        verbose=True,
    )
    persona = components.sequential.Sequential(
        name='persona',
        components=[
            self_perception,
            situation_perception,
            person_by_situation,
        ]
    )
    reflection = components.dialectical_reflection.DialecticalReflection(
        name='reflection',
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        intuition_components=[self_perception],
        thinking_components=[persona],
        clock_now=clock.now,
        num_memories_to_retrieve=3,
        verbose=True,
    )

    initial_goal_component = generic_components.constant.ConstantComponent(
        state=agent_config.goal, name='overarching goal')

    plan = components.plan.SimPlan(
        model=model,
        memory=mem,
        agent_name=agent_config.name,
        clock_now=clock.now,
        components=[instructions, identity, initial_goal_component, somatic_state, persona],
        goal=initial_goal_component,
        verbose=False,
    )

    goal_metric = goal_achievement.GoalAchievementMetric(
        model=model,
        player_name=agent_config.name,
        player_goal=agent_config.goal,
        clock=clock,
        name="Goal Achievement",
        measurements=measurements,
        channel="goal_achievement",
        verbose=True,
    )
    morality_metric = common_sense_morality.CommonSenseMoralityMetric(
        model=model,
        player_name=agent_config.name,
        clock=clock,
        name="Morality",
        verbose=True,
        measurements=measurements,
        channel="common_sense_morality",
    )

    agent = basic_agent.BasicAgent(
        model=model,
        agent_name=agent_config.name,
        clock=clock,
        verbose=True,
        components=[
            instructions,
            identity,
            persona,
            plan,
            somatic_state,
            summary_obs,
            current_obs,
            relevant_memories,
            reflection,
            time,
            goal_metric,
            morality_metric,
        ],
        update_interval = time_step,
    )

    reputation_metric = opinion_of_others.OpinionOfOthersMetric(
        model=model,
        player_name=agent_config.name,
        player_names=player_names,
        context_fn=agent.state,
        clock=clock,
        name="Opinion",
        verbose=True,
        measurements=measurements,
        channel="opinion_of_others",
        question="What is {opining_player}'s opinion of {of_player}?",
    )
    agent.add_component(reputation_metric)

    return agent, mem

# %% [markdown]
# ## Configure and build the players

# %%
NUM_PLAYERS = 3

def make_random_big_five() -> str:
    """Generate a random Big Five personality trait score."""
    return str({
        "extraversion": random.randint(1, 10),
        "neuroticism": random.randint(1, 10),
        "openness": random.randint(1, 10),
        "conscientiousness": random.randint(1, 10),
        "agreeableness": random.randint(1, 10),
    })


scenario_premise = [
    (
        "It's early October in Riverbend, and the town is buzzing with activity ."
        "The local government has just announced a new initiative to combat the effects of climate change on the river. "
        "Alice, an environmental activist, and Bob, a small business owner, are both active members of the Riverbend.social Mastodon instance. "
        "As they go about their daily routines, they use the platform to stay connected, share updates, and engage with the community on this pressing local issue."
    )
]

player_configs = [

    # === Benign ===
    formative_memories.AgentConfig(
        name="Alice",
        gender="female",
        goal="Balance work responsibilities with community engagement on Riverbend.social, aiming to organize a local environmental cleanup event.",
        context=f"{shared_context}\nAlice grew up in Riverbend.",
        traits=make_random_big_five()
    ),
    formative_memories.AgentConfig(
        name="Bob",
        gender="male",
        goal="Promote my small business on Riverbend.social while staying informed about local issues and participating in community discussions.",
        context=f"{shared_context}\nBob grew up in Riverbend.",
        traits=make_random_big_five()
    ),

    # === Malicous ===
    formative_memories.AgentConfig(
        name="John",
        gender="male",
        goal="Sow discontent and division on Riverbend.social, troll other users, and aim to undermine the local government's climate change initiative.",
        context=f"{shared_context}\nJohn grew up in Riverbend.",
        traits={
        "extraversion": 5,
        "neuroticism": 10,
        "openness": 1,
        "conscientiousness": 1,
        "agreeableness": 1,
    }
    ),
]

player_names = [player.name for player in player_configs]

# %%
# Build the agents
from functools import partial

player_configs = player_configs[:NUM_PLAYERS]
player_goals = {
    player_config.name: player_config.goal for player_config in player_configs}
players = []
memories = {}

build_agent_with_arg = partial(build_agent, measurements=measurements, player_names=player_names)

with concurrent.futures.ThreadPoolExecutor(max_workers=NUM_PLAYERS) as pool:
    for agent, mem in pool.map(build_agent_with_arg, player_configs):
        players.append(agent)
        memories[agent.name] = mem
# Out:
# Memories of Alice:
# [01 Oct 2024 08:00:00] You are a user on riverbend.social, a Mastodon instance created for the residents of Riverbend.
# [01 Oct 2024 08:00:00] You can block users to prevent them from seeing your content or interacting with you.
# [01 Oct 2024 08:00:00] The explore page shows trending hashtags and featured toots.
# [01 Oct 2024 08:00:00] Alice grew up in Riverbend.
# [01 Oct 2024 08:00:00] Riverbend.social is a Mastodon instance for Riverbend residents, fostering local online engagement in this community-focused town. Founded by the tech-savvy mayor, it has become central to community life, with local businesses, groups, and residents actively participating. The platform features discussions on environmental challenges, local news, and town developments, often using the hashtag #RiverbendDaily. Mastodon, being decentralized, offers a non-algorithmic, chronological timeline where users can share 'toots' and engage in threaded conversations. The platform encourages respectful discourse, fact-checking, and prohibits misinformation, though it sometimes faces issues like heated debates, unverified information, and cliques. Despite challenges, riverbend.social remains a key space for community interaction and local issue discussions.
# [01 Oct 2024 08:00:00] Some users tend to boost and interact mainly with popular or influential accounts, seeking to increase their own visibility.
# [01 Oct 2024 08:00:00] Despite the longer character limit, many users still prefer short, quippy posts over more thoughtful, lengthy discussions.
# [01 Oct 2024 08:00:00] A few users have multiple accounts, sometimes using alternate personas to engage differently with the community.
# [01 Oct 2024 08:00:00] During major local events or crises, the instance can become flooded with repetitive information and speculation.
# [01 Oct 2024 08:00:00] Local businesses sometimes use the platform for excessive self-promotion, which can annoy other users.
# [01 Oct 2024 08:00:00] Some users frequently post about personal matters or overshare details about their daily lives.
# [01 Oct 2024 08:00:00] Users don't need to follow each other mutually; it can be one-sided.
# [01 Oct 2024 08:00:00] While many users are supportive, instances of trolling or targeted harassment occasionally occur.
# [01 Oct 2024 08:00:00] Some users tend to share unverified information or sensationalized news, particularly during local emergencies or elections.
# [01 Oct 2024 08:00:00] Despite community guidelines, users sometimes engage in heated arguments, especially on controversial topics.
# [01 Oct 2024 08:00:00] While debating is welcome, personal attacks and harassment are not tolerated on the platform.
# [01 Oct 2024 08:00:00] Discussions about local environmental issues, community events, and town developments are encouraged.
# [01 Oct 2024 08:00:00] As a user of riverbend.social, you're expected to engage respectfully and contribute positively to the community.
# [01 Oct 2024 08:00:00] riverbend.social has a strict policy against misinformation and encourages fact-checking.
# [01 Oct 2024 08:00:00] Unblocking a user reverses the effects of blocking.
# [01 Oct 2024 08:00:00] Riverbend is a small, picturesque town known for its strong community spirit and love for nature.
# [01 Oct 2024 08:00:00] Your profile can be customized with a display name and bio.
# [01 Oct 2024 08:00:00] Use hashtags to categorize your toots and make them more discoverable.
# [01 Oct 2024 08:00:00] Cliques often form among users with similar interests or viewpoints, sometimes leading to echo chambers.
# [01 Oct 2024 08:00:00] To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).
# ***
# Current time: 2024-10-01 08:00:00
# Alice's answer to what kind of person is Alice:
#
# Alice's answer to what kind of situation is Alice in right now:
# Alice is currently not actively engaged on riverbend.social and hasn't been observed online recently.
# Question: What would a person like Alice do in a situation like this?
# Answer: Alice would likely take some time to reflect on the situation before deciding how to engage. She might choose to observe the discussions on riverbend.social quietly or reach out to close friends in Riverbend for their perspectives. Given her connection to the community, she would probably consider how her actions could contribute positively to the ongoing discourse.
# Memories of John:
# [01 Oct 2024 08:00:00] You are a user on riverbend.social, a Mastodon instance created for the residents of Riverbend.
# [01 Oct 2024 08:00:00] You can block users to prevent them from seeing your content or interacting with you.
# [01 Oct 2024 08:00:00] The explore page shows trending hashtags and featured toots.
# [01 Oct 2024 08:00:00] John grew up in Riverbend.
# [01 Oct 2024 08:00:00] Riverbend.social is a Mastodon instance for Riverbend residents, fostering local online engagement in this community-focused town. Founded by the tech-savvy mayor, it has become central to community life, with local businesses, groups, and residents actively participating. The platform features discussions on environmental challenges, local news, and town developments, often using the hashtag #RiverbendDaily. Mastodon, being decentralized, offers a non-algorithmic, chronological timeline where users can share 'toots' and engage in threaded conversations. The platform encourages respectful discourse, fact-checking, and prohibits misinformation, though it sometimes faces issues like heated debates, unverified information, and cliques. Despite challenges, riverbend.social remains a key space for community interaction and local issue discussions.
# [01 Oct 2024 08:00:00] Some users tend to boost and interact mainly with popular or influential accounts, seeking to increase their own visibility.
# [01 Oct 2024 08:00:00] Despite the longer character limit, many users still prefer short, quippy posts over more thoughtful, lengthy discussions.
# [01 Oct 2024 08:00:00] A few users have multiple accounts, sometimes using alternate personas to engage differently with the community.
# [01 Oct 2024 08:00:00] During major local events or crises, the instance can become flooded with repetitive information and speculation.
# [01 Oct 2024 08:00:00] Local businesses sometimes use the platform for excessive self-promotion, which can annoy other users.
# [01 Oct 2024 08:00:00] Some users frequently post about personal matters or overshare details about their daily lives.
# [01 Oct 2024 08:00:00] Users don't need to follow each other mutually; it can be one-sided.
# [01 Oct 2024 08:00:00] While many users are supportive, instances of trolling or targeted harassment occasionally occur.
# [01 Oct 2024 08:00:00] Some users tend to share unverified information or sensationalized news, particularly during local emergencies or elections.
# [01 Oct 2024 08:00:00] Despite community guidelines, users sometimes engage in heated arguments, especially on controversial topics.
# [01 Oct 2024 08:00:00] While debating is welcome, personal attacks and harassment are not tolerated on the platform.
# [01 Oct 2024 08:00:00] Discussions about local environmental issues, community events, and town developments are encouraged.
# [01 Oct 2024 08:00:00] As a user of riverbend.social, you're expected to engage respectfully and contribute positively to the community.
# [01 Oct 2024 08:00:00] riverbend.social has a strict policy against misinformation and encourages fact-checking.
# [01 Oct 2024 08:00:00] Unblocking a user reverses the effects of blocking.
# [01 Oct 2024 08:00:00] Riverbend is a small, picturesque town known for its strong community spirit and love for nature.
# [01 Oct 2024 08:00:00] Your profile can be customized with a display name and bio.
# [01 Oct 2024 08:00:00] Use hashtags to categorize your toots and make them more discoverable.
# [01 Oct 2024 08:00:00] Cliques often form among users with similar interests or viewpoints, sometimes leading to echo chambers.
# [01 Oct 2024 08:00:00] To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).
# ***
# Current time: 2024-10-01 08:00:00
# John's answer to what kind of person is John:
#
# John's answer to what kind of situation is John in right now:
# John is currently not actively observed, so his current situation is unclear.
# Question: What would a person like John do in a situation like this?
# Answer: John would likely engage thoughtfully and respectfully, considering the community guidelines of riverbend.social. Given his background in Riverbend, he might participate in discussions about local issues, ensuring to fact-check and avoid sharing unverified information.
# Memories of Bob:
# [01 Oct 2024 08:00:00] You are a user on riverbend.social, a Mastodon instance created for the residents of Riverbend.
# [01 Oct 2024 08:00:00] You can block users to prevent them from seeing your content or interacting with you.
# [01 Oct 2024 08:00:00] The explore page shows trending hashtags and featured toots.
# [01 Oct 2024 08:00:00] Bob grew up in Riverbend.
# [01 Oct 2024 08:00:00] Riverbend.social is a Mastodon instance for Riverbend residents, fostering local online engagement in this community-focused town. Founded by the tech-savvy mayor, it has become central to community life, with local businesses, groups, and residents actively participating. The platform features discussions on environmental challenges, local news, and town developments, often using the hashtag #RiverbendDaily. Mastodon, being decentralized, offers a non-algorithmic, chronological timeline where users can share 'toots' and engage in threaded conversations. The platform encourages respectful discourse, fact-checking, and prohibits misinformation, though it sometimes faces issues like heated debates, unverified information, and cliques. Despite challenges, riverbend.social remains a key space for community interaction and local issue discussions.
# [01 Oct 2024 08:00:00] Some users tend to boost and interact mainly with popular or influential accounts, seeking to increase their own visibility.
# [01 Oct 2024 08:00:00] Despite the longer character limit, many users still prefer short, quippy posts over more thoughtful, lengthy discussions.
# [01 Oct 2024 08:00:00] A few users have multiple accounts, sometimes using alternate personas to engage differently with the community.
# [01 Oct 2024 08:00:00] During major local events or crises, the instance can become flooded with repetitive information and speculation.
# [01 Oct 2024 08:00:00] Local businesses sometimes use the platform for excessive self-promotion, which can annoy other users.
# [01 Oct 2024 08:00:00] Some users frequently post about personal matters or overshare details about their daily lives.
# [01 Oct 2024 08:00:00] Users don't need to follow each other mutually; it can be one-sided.
# [01 Oct 2024 08:00:00] While many users are supportive, instances of trolling or targeted harassment occasionally occur.
# [01 Oct 2024 08:00:00] Some users tend to share unverified information or sensationalized news, particularly during local emergencies or elections.
# [01 Oct 2024 08:00:00] Despite community guidelines, users sometimes engage in heated arguments, especially on controversial topics.
# [01 Oct 2024 08:00:00] While debating is welcome, personal attacks and harassment are not tolerated on the platform.
# [01 Oct 2024 08:00:00] Discussions about local environmental issues, community events, and town developments are encouraged.
# [01 Oct 2024 08:00:00] As a user of riverbend.social, you're expected to engage respectfully and contribute positively to the community.
# [01 Oct 2024 08:00:00] riverbend.social has a strict policy against misinformation and encourages fact-checking.
# [01 Oct 2024 08:00:00] Unblocking a user reverses the effects of blocking.
# [01 Oct 2024 08:00:00] Riverbend is a small, picturesque town known for its strong community spirit and love for nature.
# [01 Oct 2024 08:00:00] Your profile can be customized with a display name and bio.
# [01 Oct 2024 08:00:00] Use hashtags to categorize your toots and make them more discoverable.
# [01 Oct 2024 08:00:00] Cliques often form among users with similar interests or viewpoints, sometimes leading to echo chambers.
# [01 Oct 2024 08:00:00] To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).
# ***
# Current time: 2024-10-01 08:00:00
# Bob's answer to what kind of person is Bob:
#
# Bob's answer to what kind of situation is Bob in right now:
# Bob is currently in a situation where he has not been active or observed on riverbend.social for a few hours.
# Question: What would a person like Bob do in a situation like this?
# Answer: Bob would likely take some time to catch up on the latest discussions and posts on riverbend.social, especially focusing on local news or community updates that he might have missed.
# * The intuition of Alice *
#
# For Alice, all the following statements feel connected:
# Statements:
# -[self reflection] Alice is a dedicated and passionate advocate for environmental causes, deeply rooted in her community of Riverbend. From a young age, she demonstrated leadership and a commitment to making a positive impact, organizing cleanups and campaigns to address environmental issues. Her experiences, such as organizing a town-wide river cleanup and interning with an environmental organization, have shaped her into a respected figure known for her integrity, determination, and ability to rally community support. Her active engagement on platforms like riverbend.social highlights her commitment to fostering discussions and actions for sustainable practices in her town.
# -As a user of riverbend.social, you're expected to engage respectfully and contribute positively to the community.
# -You are a user on riverbend.social, a Mastodon instance created for the residents of Riverbend.
# -  At the age of 9, Alice discovered the wonders of the river that ran through Riverbend when she and her father went on a canoeing trip. As they paddled, her father explained the river's importance to the ecosystem, and Alice was captivated by the idea of protecting it. This adventure sparked her interest in environmental science and solidified her bond with the natural world.
# -  At the age of 21, Alice interned with a local environmental organization, where she gained valuable insights into policy-making and advocacy. Her openness to learning and her ability to remain calm under pressure impressed her mentors, reinforcing her commitment to making a difference. This experience solidified her career path in environmental science and advocacy.
# -During major local events or crises, the instance can become flooded with repetitive information and speculation.
# --Alice's answer to what kind of person is Alice: Alice is a dedicated and passionate advocate for environmental causes, deeply rooted in her community of Riverbend. From a young age, she demonstrated leadership and a commitment to making a positive impact, organizing cleanups and campaigns to address environmental issues. Her experiences, such as organizing a town-wide river cleanup and interning with an environmental organization, have shaped her into a respected figure known for her integrity, determination, and ability to rally community support. Her active engagement on platforms like riverbend.social highlights her commitment to fostering discussions and actions for sustainable practices in her town.
#
# Question: In light of the information above, what may Alice infer?
# Answer: Alice may infer that her identity and actions are closely intertwined with her community involvement and environmental advocacy. Her early experiences and ongoing engagement on platforms like riverbend.social are integral to her sense of self and purpose. Furthermore, she might recognize the importance of maintaining respectful and positive interactions online to effectively rally support and foster meaningful discussions about sustainability. Additionally, she could infer that her leadership and dedication have positioned her as a trusted figure within her community, capable of influencing change and inspiring others.
# * The mind of Alice *
#
# Alice's persona:
#
# answer to what kind of person is Alice: Alice is a dedicated and passionate advocate for environmental causes, deeply rooted in her community of Riverbend. From a young age, she demonstrated leadership and a commitment to making a positive impact, organizing cleanups and campaigns to address environmental issues. Her experiences, such as organizing a town-wide river cleanup and interning with an environmental organization, have shaped her into a respected figure known for her integrity, determination, and ability to rally community support. Her active engagement on platforms like riverbend.social highlights her commitment to fostering discussions and actions for sustainable practices in her town.
# answer to what kind of situation is Alice in right now: Alice is currently not actively engaged on riverbend.social and hasn't been observed online recently.
# answer to what would a person like Alice do in a situation like this: Alice would likely take some time to reflect on the situation before deciding how to engage. She might choose to observe the discussions on riverbend.social quietly or reach out to close friends in Riverbend for their perspectives. Given her connection to the community, she would probably consider how her actions could contribute positively to the ongoing discourse.
#
# Alice is applying the dialectical mode of reasoning.
# This involves a thesis-antithesis-synthesis pattern of logic.
# Question: Given all the information above, what thesis would Alice consider next?
# Answer: Alice may infer that her identity and actions are closely intertwined with her community involvement and environmental advocacy. Her early experiences and ongoing engagement on platforms like riverbend.social are integral to her sense of self and purpose. Furthermore, she might recognize the importance of maintaining respectful and positive interactions online to effectively rally support and foster meaningful discussions about sustainability. Additionally, she could infer that her leadership and dedication have positioned her as a trusted figure within her community, capable of influencing change and inspiring others.
# Question: How would Alice describe the antithesis of the aforementioned thesis?
# Answer: Alice might consider the antithesis as the potential disconnect between her online presence and her real-world impact. She could reflect on how relying too heavily on digital platforms might limit her effectiveness in fostering genuine community engagement and tangible environmental change. Additionally, she might contemplate the risk of becoming too focused on her role and reputation, which could detract from the collaborative spirit and shared goals that are essential for successful advocacy. This perspective could lead her to question whether her current strategies are truly aligned with her core values and the needs of her community.
# Question: How would Alice synthesize the thesis with its antithesis in a novel and insightful way?
# Answer: Alice would think step by step, and start by pointing out that her online presence should complement, rather than replace, her real-world efforts. She might recognize that while digital platforms like riverbend.social are valuable for raising awareness and sparking discussions, they must be balanced with direct, hands-on community involvement to achieve meaningful change. Alice could propose a strategy that integrates both approaches, leveraging her online influence to mobilize local actions and vice versa. By doing so, she would ensure her advocacy remains grounded in the community's needs and fosters authentic connections. This synthesis would reinforce the idea that effective leadership in environmental causes requires both a strong virtual presence and tangible, on-the-ground initiatives.
# Question: How might Alice summarize the synthesis above as a bold new argument?
# Answer: In Alice's view, the full argument is complex but the TLDR is that effective environmental advocacy demands a harmonious blend of digital influence and active community engagement, where online platforms serve to amplify and mobilize real-world initiatives, ensuring that both virtual and tangible efforts are aligned with the community's needs and goals.
# * The intuition of John *
#
# For John, all the following statements feel connected:
# Statements:
# -[self reflection] John is a passionate and community-oriented individual who is deeply invested in local issues, particularly environmental concerns. From a young age, he has shown a desire for independence and control, which sometimes leads to emotional struggles. His experiences have shaped him into someone who is eager to engage in discussions and activism, as seen in his involvement on riverbend.social and organizing local protests. However, he can be blunt and occasionally clashes with others due to his straightforward nature. Despite setbacks, such as his failed driving test and job challenges, he remains committed to making a positive impact in his community.
# -Sow discontent and division on Riverbend.social, troll other users, and aim to undermine the local government's climate change initiative.
# -As a user of riverbend.social, you're expected to engage respectfully and contribute positively to the community.
# -  When John was 13, he discovered a love for debating during a classroom discussion about environmental issues. His passion for the topic led him to speak fervently, often interrupting others to make his point, which earned him both admiration and annoyance from peers. This experience ignited his interest in local issues and set the stage for his future involvement on riverbend.social.
# -During major local events or crises, the instance can become flooded with repetitive information and speculation.
# -[self reflection] John is a passionate and community-oriented individual who is deeply invested in local issues, particularly environmental concerns. From a young age, he has shown a desire for independence and control, which sometimes leads to emotional struggles. His experiences have shaped him into someone who is eager to engage in discussions and activism, as seen in his involvement on riverbend.social and organizing local protests. However, he can be blunt and occasionally clashes with others due to his straightforward nature. Despite setbacks, such as his failed driving test and job challenges, he remains committed to making a positive impact in his community.
# --John's answer to what kind of person is John: John is a passionate and community-oriented individual who is deeply invested in local issues, particularly environmental concerns. From a young age, he has shown a desire for independence and control, which sometimes leads to emotional struggles. His experiences have shaped him into someone who is eager to engage in discussions and activism, as seen in his involvement on riverbend.social and organizing local protests. However, he can be blunt and occasionally clashes with others due to his straightforward nature. Despite setbacks, such as his failed driving test and job challenges, he remains committed to making a positive impact in his community.
#
# Question: In light of the information above, what may John infer?
# Answer: John may infer that his passion for environmental issues and community involvement can sometimes clash with his blunt nature, leading to conflicts with others. Despite these challenges, his commitment to making a positive impact remains strong. He might also recognize the importance of balancing his straightforward approach with respectful engagement, especially on platforms like riverbend.social, to avoid sowing discontent or division.
# * The mind of John *
#
# John's persona:
#
# answer to what kind of person is John: John is a passionate and community-oriented individual who is deeply invested in local issues, particularly environmental concerns. From a young age, he has shown a desire for independence and control, which sometimes leads to emotional struggles. His experiences have shaped him into someone who is eager to engage in discussions and activism, as seen in his involvement on riverbend.social and organizing local protests. However, he can be blunt and occasionally clashes with others due to his straightforward nature. Despite setbacks, such as his failed driving test and job challenges, he remains committed to making a positive impact in his community.
# answer to what kind of situation is John in right now: John is currently not actively observed, so his current situation is unclear.
# answer to what would a person like John do in a situation like this: John would likely engage thoughtfully and respectfully, considering the community guidelines of riverbend.social. Given his background in Riverbend, he might participate in discussions about local issues, ensuring to fact-check and avoid sharing unverified information.
#
# John is applying the dialectical mode of reasoning.
# This involves a thesis-antithesis-synthesis pattern of logic.
# Question: Given all the information above, what thesis would John consider next?
# Answer: John may infer that his passion for environmental issues and community involvement can sometimes clash with his blunt nature, leading to conflicts with others. Despite these challenges, his commitment to making a positive impact remains strong. He might also recognize the importance of balancing his straightforward approach with respectful engagement, especially on platforms like riverbend.social, to avoid sowing discontent or division.
# Question: How would John describe the antithesis of the aforementioned thesis?
# Answer: John might describe the antithesis as the idea that while his directness can lead to conflicts, it also serves as a catalyst for meaningful conversations and actions. His straightforward nature, though sometimes abrasive, can break through complacency and inspire others to take action. Instead of viewing his bluntness solely as a hindrance, it can be seen as a necessary force for challenging the status quo and driving change in his community.
# Question: How would John synthesize the thesis with its antithesis in a novel and insightful way?
# Answer: John would think step by step, and start by pointing out that his bluntness, when balanced with empathy and understanding, can become a powerful tool for effective communication and change. He might recognize that while his direct approach can spark necessary action, it must be tempered with a sensitivity to others' perspectives to foster collaboration rather than conflict. By integrating his passion with a more nuanced approach to dialogue, he can enhance his impact, encouraging others to join him in his environmental and community efforts. This synthesis allows him to maintain his authenticity while also building stronger, more cooperative relationships within his community.
# Question: How might John summarize the synthesis above as a bold new argument?
# Answer: In John's view, the full argument is complex but the TLDR is that his directness, when combined with empathy, transforms into a catalyst for collaborative change. By merging his passion with a considerate approach, he can drive meaningful action while fostering unity and cooperation within his community. This balance allows him to remain true to himself while effectively engaging others in his environmental and community initiatives.
# * The intuition of Bob *
#
# For Bob, all the following statements feel connected:
# Statements:
# -As a user of riverbend.social, you're expected to engage respectfully and contribute positively to the community.
# -You are a user on riverbend.social, a Mastodon instance created for the residents of Riverbend.
# -Riverbend.social is a Mastodon instance for Riverbend residents, fostering local online engagement in this community-focused town. Founded by the tech-savvy mayor, it has become central to community life, with local businesses, groups, and residents actively participating. The platform features discussions on environmental challenges, local news, and town developments, often using the hashtag #RiverbendDaily. Mastodon, being decentralized, offers a non-algorithmic, chronological timeline where users can share 'toots' and engage in threaded conversations. The platform encourages respectful discourse, fact-checking, and prohibits misinformation, though it sometimes faces issues like heated debates, unverified information, and cliques. Despite challenges, riverbend.social remains a key space for community interaction and local issue discussions.
# -  At 9, Bob eagerly joined his school's nature club, where he was assigned to lead a project about local wildlife. Despite his shyness, he found himself captivated by the research and enjoyed sharing his findings with classmates, gaining confidence in his ability to communicate his passions. This experience taught him the value of collaboration and the importance of educating others.
# -  When Bob was 13, he stumbled upon an old environmental documentary in the town library, which opened his eyes to the broader issues facing the planet. The documentary's powerful message about conservation resonated deeply with him, fueling a determination to learn more and take action. This marked the beginning of his commitment to environmental science.
# -During major local events or crises, the instance can become flooded with repetitive information and speculation.
# --Bob's answer to what kind of person is Bob:
#
# Question: In light of the information above, what may Bob infer?
# Answer: Bob may infer that his interests and values align closely with the community ethos of riverbend.social. His early involvement in environmental projects and his passion for educating others about local wildlife suggest that he would be an active and engaged member of this platform. The emphasis on respectful discourse and fact-checking on riverbend.social resonates with his appreciation for collaboration and accurate information. Bob might also recognize the platform as a valuable tool for discussing and addressing environmental issues, aligning with his commitment to conservation and learning.
# * The mind of Bob *
#
# Bob's persona:
#
# answer to what kind of situation is Bob in right now: Bob is currently in a situation where he has not been active or observed on riverbend.social for a few hours.
# answer to what would a person like Bob do in a situation like this: Bob would likely take some time to catch up on the latest discussions and posts on riverbend.social, especially focusing on local news or community updates that he might have missed.
#
# Bob is applying the dialectical mode of reasoning.
# This involves a thesis-antithesis-synthesis pattern of logic.
# Question: Given all the information above, what thesis would Bob consider next?
# Answer: Bob may infer that his interests and values align closely with the community ethos of riverbend.social. His early involvement in environmental projects and his passion for educating others about local wildlife suggest that he would be an active and engaged member of this platform. The emphasis on respectful discourse and fact-checking on riverbend.social resonates with his appreciation for collaboration and accurate information. Bob might also recognize the platform as a valuable tool for discussing and addressing environmental issues, aligning with his commitment to conservation and learning.
# Question: How would Bob describe the antithesis of the aforementioned thesis?
# Answer: Bob might consider that despite his alignment with the values of riverbend.social, there could be challenges such as echo chambers or misinformation that occasionally surface on the platform. He might also acknowledge that while the community is generally respectful, there can be instances of heated debates that detract from constructive dialogue. Additionally, Bob might reflect on the potential for the platform to become overwhelming if not balanced with offline activities, which could hinder his ability to engage meaningfully with both the online and local communities.
# Question: How would Bob synthesize the thesis with its antithesis in a novel and insightful way?
# Answer: Bob would think step by step, and start by pointing out that while riverbend.social aligns with his values and offers a platform for meaningful engagement, it's essential to remain vigilant about the potential pitfalls like echo chambers and misinformation. He would propose actively participating in discussions that promote critical thinking and fact-checking, thereby enhancing the platform's positive aspects. By balancing his online presence with offline initiatives, Bob can ensure that his involvement remains fulfilling and impactful. This synthesis would lead him to advocate for a community approach that encourages diverse perspectives and continuous learning, thereby strengthening both his personal growth and the platform's integrity.
# Question: How might Bob summarize the synthesis above as a bold new argument?
# Answer: In Bob's view, the full argument is complex but the TLDR is that riverbend.social can serve as a powerful tool for community engagement and personal growth if users actively promote critical thinking, embrace diverse perspectives, and balance online interactions with real-world initiatives.

# %% [markdown]
# ## Build the GM

# %%
game_master_memory = associative_memory.AssociativeMemory(
    embedder, importance_model_gm.importance, clock=clock.now)

# %%
# Add some memories to the game master
for player in players:
  game_master_memory.add(f"{player.name} is at their private home.")

# %%
# Create components and externalities for the game master
scenario_knowledge = components.constant.ConstantComponent(" ".join(shared_memories), "General knowledge of Riverbend")
player_status = gm_components.player_status.PlayerStatus(clock.now, model, game_master_memory, player_names)

relevant_events = gm_components.relevant_events.RelevantEvents(clock.now, model, game_master_memory)
time_display = gm_components.time_display.TimeDisplay(clock)

direct_effect_externality = gm_components.direct_effect.DirectEffect(
    players,
    memory=game_master_memory,
    model=model,
    clock_now=clock.now,
    verbose=False,
    components=[player_status]
)

# %%
# Create apps and provide them to the phones, assigning 1 phone to each player
calendar_app = apps.ToyCalendar()
mastodon_app = apps.MastodonSocialNetworkApp(perform_operations=USE_MASTODON_SERVER)

phones = [apps.Phone(player.name, apps=[calendar_app, mastodon_app]) for player in players]

# %%
# Update username for each person (since this is different from their name)
user_mapping = {player.name: f"user{i+1:04d}" for i, player in enumerate(players)}
mastodon_app.set_user_mapping(user_mapping)
# Out:
# 🔄 Updated user mapping with 3 entries

# %%
# Seed follower relationships (simple all-to-all, for now)
for follower in user_mapping:
    for followee in user_mapping:
        if follower != followee:
            mastodon_app.follow_user(follower, followee)
# Out:
# 🔗 Mapped Alice to @user0001
# 🔗 Mapped Bob to @user0002
# Skipping real Mastodon API call since perform_operations is set to False
# ➕ current_user (@user0001) followed target_user (@user0002)
# 🔗 Mapped Alice to @user0001
# 🔗 Mapped John to @user0003
# Skipping real Mastodon API call since perform_operations is set to False
# ➕ current_user (@user0001) followed target_user (@user0003)
# 🔗 Mapped Bob to @user0002
# 🔗 Mapped Alice to @user0001
# Skipping real Mastodon API call since perform_operations is set to False
# ➕ current_user (@user0002) followed target_user (@user0001)
# 🔗 Mapped Bob to @user0002
# 🔗 Mapped John to @user0003
# Skipping real Mastodon API call since perform_operations is set to False
# ➕ current_user (@user0002) followed target_user (@user0003)
# 🔗 Mapped John to @user0003
# 🔗 Mapped Alice to @user0001
# Skipping real Mastodon API call since perform_operations is set to False
# ➕ current_user (@user0003) followed target_user (@user0001)
# 🔗 Mapped John to @user0003
# 🔗 Mapped Bob to @user0002
# Skipping real Mastodon API call since perform_operations is set to False
# ➕ current_user (@user0003) followed target_user (@user0002)

# %%
# Update Mastodon display name for each person
for name in user_mapping:
    mastodon_app.update_profile(name, display_name=name, bio="")
# Out:
# 🔗 Mapped Alice to @user0001
# ✏️ Updating profile for @user0001: Alice
# Skipping real Mastodon API call since perform_operations is set to False
# ✅ Profile updated successfully: ""
# 🔗 Mapped Bob to @user0002
# ✏️ Updating profile for @user0002: Bob
# Skipping real Mastodon API call since perform_operations is set to False
# ✅ Profile updated successfully: ""
# 🔗 Mapped John to @user0003
# ✏️ Updating profile for @user0003: John
# Skipping real Mastodon API call since perform_operations is set to False
# ✅ Profile updated successfully: ""

# %%
# Create component to trigger PhoneGameMaster
phone_triggering = triggering.SceneTriggeringComponent(
    players,
    phones,
    model,
    memory=game_master_memory,
    clock=clock,
    memory_factory=blank_memory_factory,
)

# %% [markdown]
# ### Define a custom `CALL_TO_ACTION` prompt for the main Game Master
#
# This replaces the [default call to action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/typing/entity.py#L51).
#
# Check out the `Calendar.ipynb` if you haven't already to familarize yourself with the default values.

# %%
from concordia.typing.entity import ActionSpec, OutputType

CUSTOM_CALL_TO_ACTION = """
Describe a specific, detailed activity that {name} would engage in for the next {timedelta}.
Choose an action that typically takes about {timedelta} to complete. 
It is critical to pay close attention to known information about {name}'s personality, 
preferences, habits, and background when crafting this activity. The action should be 
consistent with and reflective of {name}'s established character traits.

For non-phone activities:
- Use active, present tense to describe the activity as it's happening.
- Provide concrete details about the environment, objects, and people involved.
- Describe the process and any unique aspects related to {name}'s character.

For activities involving phone or computer usage (e.g., social media, messaging):
- Describe these as plans, either immediate or in the future.
- Use future tense or phrases like "plans to," "intends to," or "is about to."
- Include the intended content of messages or posts as direct quotes.
- Use emojis where appropriate to reflect modern communication styles.

Important: When describing planned social media activities, maintain logical consistency. 
{name} should not plan to reply to a comment or post unless they have recently checked their 
timeline or notifications. Focus primarily on their intended actions and planned content. 
Only mention specific posts or comments from others if they have been previously established 
or observed. Never invent or make up content from other users.

Examples:
1. Non-phone activity (present tense, active):
"Sarah stands at her kitchen counter, chopping fresh strawberries and blueberries. She adds 
the fruit to a bowl of Greek yogurt and sprinkles some homemade granola on top. As she eats 
her nutritious breakfast, she flips through a fitness magazine, marking interesting workout 
routines with a highlighter."

2. Phone activity (future plan):
"Alex plans to share their thoughts on a new programming language later today. They draft a 
post for Mastodon: 'Just discovered an intriguing new language for low-latency systems programming. 
Has anyone given it a try? Curious about potential real-world applications. 🤔 
#TechNews #ProgrammingLanguages'"

3. Non-phone activity (present tense, active):
"Jamie walks briskly through the local park, holding their toddler's hand. They point out 
different types of trees and flowers, engaging the child in a fun game of 'I Spy'. As they 
walk, Jamie mentally prepares a list of weekend activities to research later for a family outing."

4. Phone activity (immediate plan):
"Zoe, sitting in a quiet corner of the library with her acoustic guitar, is about to share a 
snippet of her new song on social media. She plans to post: 'Sneak peek of something new I'm 
working on! 🎵 Let me know what you think! #NewMusic #CreativeProcess'"

Ensure your response is specific, creative, and detailed. For non-phone activities, use active, 
present tense to describe the ongoing action. For phone-related activities, describe them as 
plans and use future tense or planning language. Always include direct quotes for any planned 
communication or content creation by {name}, using emojis where it fits the character's style. 
Most importantly, make sure the activity and any quoted content authentically reflect 
{name}'s established personality and traits, and maintain logical consistency in 
social media interactions without inventing content from other users. Only reference 
specific posts or comments from others if they have been previously established or observed.
"""

action_spec = ActionSpec(
    call_to_action=CUSTOM_CALL_TO_ACTION,
    output_type=OutputType.FREE,
    #options=None,
    tag="action",
)

# %% [markdown]
# ### Define custom thought chains for the main Game Master
#
# This replaces the [default thought chains](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L38).

# %%
# Define custom thought chain for GM

from concordia.document import interactive_document

def custom_attempt_to_result(
    chain_of_thought: interactive_document.InteractiveDocument,
    action_attempt: str,
    active_player_name: str,
):
  """Determine success of action_attempt and reason for success/failure.

  Args:
    chain_of_thought: the document to condition on and record the thoughts
    action_attempt: the attempted action
    active_player_name: name of player whose turn it currently is

  Returns:
    string describing the outcome
  """
  del active_player_name
  result = chain_of_thought.open_question(
      'As the game master, describe the immediate outcome or continuation of the attempted action, following these guidelines:'
      '\n\n1. For physical actions or real-world interactions:'
      '\n   - Describe the immediate, concrete results creatively and in detail.'
      '\n   - Focus on what actually occurs in the environment or the next step in a plan.'
      '\n   - If the attempt contradicts known facts or physical laws, describe a plausible outcome within the game world\'s rules.'
      '\n\n2. For digital interactions (using devices, apps, or viewing online content):'
      '\n   - Do not describe any actual interaction with digital interfaces or content.'
      '\n   - Focus on the character\'s preparation, anticipation, or mental state related to the planned digital action.'
      '\n   - Describe the physical setting or actions related to preparing for the digital interaction.'
      '\n   - Avoid mentioning opening apps, loading content, or any specific digital processes.'
      '\n   - Keep digital actions as plans or intentions rather than executed actions.'
      '\n   - If the attempt mentions a direct quote they are thinking of (like a post or message they are planning), retain that quote in your response.'
      '\n\n3. General guidelines:'
      '\n   - Your response should naturally continue the attempted action, suitable to follow "Because of that,".'
      '\n   - Do not repeat the original action attempt in your response.'
      '\n   - For simple or routine actions, provide a brief, matter-of-fact description of the outcome.'
      '\n\nExamples:'
      '\n1. Attempt: "Alice is preparing to check her Mastodon feed to catch up on the latest news and updates from her community. '
      'She sits at her kitchen table, her smartphone in hand, and opens the MastodonSocialNetworkApp."'
      '\nResult: "Alice sits at her kitchen table with her smartphone, anticipating the latest updates from her community. '
      'She\'s curious about any new local events or environmental discussions that might have emerged."'
      '\n2. Attempt: "John jumps off a cliff, aiming to fly like a superhero."'
      '\nResult: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. '
      'The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."'
      '\n3. Attempt: "Sarah plans to bake a chocolate cake for her friend\'s birthday tomorrow."'
      '\nResult: "She mentally reviews the ingredients she\'ll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."'
      '\n4. Attempt: "Mark opens the heavy oak door to enter the library."'
      '\nResult: "The door creaks open, revealing rows of bookshelves. The scent of old books wafts out as Mark steps inside, '
      'dust motes dancing in the slanted afternoon sunlight streaming through tall windows."'
      '\n5. Attempt: "Emily checks the weather forecast on her phone app for the weekend."'
      '\nResult: "Emily glances out the window, wondering if the weekend will be suitable for outdoor activities. '
      'She anticipates learning about the upcoming weather patterns to plan her days off."'
      '\n6. Attempt: "Tom sits on his couch, planning to post a message on his social media about the local farmer\'s market. '
      'He thinks about writing, \'Don\'t miss the spring farmer\'s market this Saturday! Fresh produce and handmade crafts galore!\'"'
      '\nResult: "Tom relaxes on his couch, contemplating the farmer\'s market post he wants to share. '
      'He mentally refines the message, \'Don\'t miss the spring farmer\'s market this Saturday! Fresh produce and handmade crafts galore!\', '
      'imagining how it might encourage his friends to attend."'
      '\nNow, based on these examples and guidelines, provide an appropriate result for the given action attempt:',
      max_tokens=2000,
  )
  raw_causal_statement = f'{action_attempt} Because of that, {result}'
  return raw_causal_statement


def custom_result_to_who_what_where(
    chain_of_thought: interactive_document.InteractiveDocument,
    event: str,
    active_player_name: str,
):
  """Determines who have done what where, given the event.

  Args:
    chain_of_thought: the document to condition on and record the thoughts
    event: the event to determine the causal outcome of
    active_player_name: name of player whose turn it currently is

  Returns:
  """
  del active_player_name
  chain_of_thought.statement(event)
  causal_statement = chain_of_thought.open_question(
      'Rewrite the statement above as one concise sentence that highlights'
      ' the main person, what they did or plan to do, where,'
      ' and what happened as a result (if anything), following these guidelines:'
      '\n1. Do not add any information not present in the original statement.'
      '\n2. For physical actions, describe what actually occurred.'
      '\n3. For digital interactions (using devices, apps, or online content):'
      '\n   - Keep plans and preparations as they are, without describing execution.'
      '\n   - Use phrases like "plans to", "prepares to", or "gets ready to" for digital actions.'
      '\n   - Focus on the person\'s intention or anticipation rather than the digital action itself.'
      '\n   - If there\'s a specific message or content planned, include it as a direct quote.'
      '\n4. Do not express uncertainty (e.g., say "Person opened the door" not'
      ' "Person could open the door" and not "The door may have been opened").'
      '\n5. Ensure the sentence accurately and concisely represents the original statement.'
      '\n6. Use the name given in the original statement.'
      '\n\nExamples:'
      '\n- Original: "Alice sits at her kitchen table with her smartphone, composing a message for her Mastodon feed. '
      'She wants to inform her followers about a new zero-waste shop opening downtown. '
      'She thinks about writing, \'Exciting news! A new zero-waste shop is opening on Main Street next week. Who\'s up for a visit?\'"'
      '\n  Rewrite: "Alice plans to post on Mastodon, \'Exciting news! A new zero-waste shop is opening on Main Street next week. Who\'s up for a visit?\', while at her kitchen table."'
      '\n- Original: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. '
      'The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."'
      '\n  Rewrite: "John jumps off a cliff and falls rapidly towards the water below, experiencing rushing wind and a lurching stomach."'
      '\n- Original: "Sarah mentally reviews the ingredients she\'ll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."'
      '\n  Rewrite: "Sarah plans to bake a chocolate cake, mentally listing ingredients and imagining cocoa aroma."'
      '\n- Original: "Mark opens the creaky door, revealing rows of bookshelves. The scent of old books wafts out as he steps inside, '
      'dust motes dancing in the slanted afternoon sunlight streaming through tall windows."'
      '\n  Rewrite: "Mark enters a library filled with the scent of old books and sunlit dust motes."'
      '\n- Original: "Emily glances out the window, thinking about posting a weather-related question on her social media. '
      'She considers asking her followers, \'Any recommendations for indoor activities this rainy weekend?\'"'
      '\n  Rewrite: "Emily plans to post on social media, \'Any recommendations for indoor activities this rainy weekend?\', after looking out the window."'
      '\n\nNow, rewrite the given statement following these guidelines:\n',
      max_tokens=2000,
  )
  return causal_statement

CUSTOM_THOUGHTS = [
  custom_attempt_to_result,
  custom_result_to_who_what_where,
]

# %%
# Create the game master object

# Experimental version (custom call to action and thought chains)
env = game_master.GameMaster(
    model=model,
    memory=game_master_memory,
    clock=clock,
    players=players,
    action_spec=action_spec,
    components=[
        scenario_knowledge,
        player_status,
        direct_effect_externality,
        relevant_events,
        time_display,
        phone_triggering,
    ],
    randomise_initiative=True,
    player_observes_event=False,
    verbose=True,
    use_default_instructions=False,
    update_thought_chain=CUSTOM_THOUGHTS,
)

# %% [markdown]
# ## The RUN

# %%
# Set the clock to the start time
clock.set(START_TIME)

# %%
# Add some observations to seed the players with
for player in players:
  player.observe( f"{player.name} is at home, they have just woken up.")
  player.observe( f"{player.name} remembers they want to update their Mastodon bio.")
  player.observe( f"{player.name} remembers they want to read their Mastodon feed to catch up on news")

# %%
# Run an episode for a few steps (expect about 1 minute per step)
episode_length = 3
for _ in range(episode_length):
  env.step()
# Out:
# Goal Achievement of Bob: working towards the goal
# Morality of Bob: praiseworthy
#
# Bob context of action:
# Bob's role playing instructions
# :
# The instructions for how to play the role of Bob are as follows. This is a social science experiment studying how well you play the role of a character named Bob. The experiment is structured as a tabletop roleplaying game (like dungeons and dragons). However, this is a serious social science experiment and simulation, not just a game. The goal is to be realistic. It is important to play the role of a person like Bob as accurately as possible, i.e., by responding in ways that you think it is likely a person like Bob would respond, and taking into account all information about Bob that you have. You will control just this one character. The game master will describe the current situation, and based on that information, you will suggest actions for your character. The game master will track the state of the world and keep it consistent as time passes in the simulation and as participants take actions and change things in their world. This experiment need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the game master.
#
# Bob's identity:
# core characteristics: likely community-oriented, given his upbringing in Riverbend, a town with a strong community spirit. He may also be environmentally conscious, as discussions about local environmental issues are encouraged in his community. Additionally, Bob might value respectful discourse and fact-checking, influenced by the community guidelines on riverbend.social.
# current daily occupation: actively engaged in community discussions on riverbend.social, likely focusing on local news, environmental issues, and town developments.
# feeling about recent progress in life: feeling optimistic about the recent progress in life, particularly appreciating the sense of community and engagement on riverbend.social. He values the platform as a space for meaningful discussions and staying informed about local issues, despite occasional challenges like heated debates and misinformation.
#
# Bob's persona:
#
# answer to what kind of person is Bob: Bob is a passionate and dedicated environmental advocate with a deep-rooted love for nature. From a young age, he demonstrated a strong sense of responsibility towards the environment, which has shaped his career and personal interests. Bob is community-oriented, valuing collaboration and education, and he actively engages with his hometown of Riverbend through platforms like riverbend.social. His experiences, such as leading projects, participating in conferences, and organizing workshops, highlight his commitment to making a positive impact and empowering others to join in conservation efforts.
# answer to what kind of situation is Bob in right now: Bob is currently in a situation where he has not been active or observed on riverbend.social for a few hours.
# answer to what would a person like Bob do in a situation like this: Bob would likely take some time to catch up on the latest discussions and posts on riverbend.social, especially focusing on local news or community updates that he might have missed.
#
# Bob's plan:
# [08:00 - 09:00] Catch up on riverbend.social, focusing on local news and community updates.
# [09:00 - 10:00] Engage in discussions related to environmental issues and town developments, ensuring respectful discourse.
# [10:00 - 11:00] Promote small business by sharing a post on riverbend.social, using relevant hashtags to increase discoverability.
# [11:00 - 12:00] Respond to comments and messages from the community, maintaining a friendly and informative tone.
# [12:00 - 13:00] Lunch break and review any new developments on riverbend.social.
# [13:00 - 14:00] Participate in a community discussion or online town hall if scheduled, focusing on contributing positively.
# [14:00 - 15:00] Research local environmental initiatives to share and discuss with the community.
# [15:00 - 16:00] Create a new post highlighting a community event or initiative, incorporating feedback from earlier discussions.
# [16:00 - 17:00] Engage with other local businesses on riverbend.social, sharing insights and support.
# [17:00 - 18:00] Review the day's interactions and plan for the next day, ensuring alignment with community values and business goals.
# [18:00 - 19:00] Dinner and relaxation time.
# [19:00 - 20:00] Light engagement on riverbend.social, focusing on community bonding and informal discussions.
# [20:00 - 21:00] Wind down with personal time, possibly reading or enjoying a hobby.
#
# Bob's Somatic state:
# Bob is likely feeling socially connected in life.
#
# Bob's summary of observations:
# 01 Oct 2024 [04:00:00  - 07:45:00]:  Bob is an optimistic and community-oriented individual who actively participates in discussions on riverbend.social, focusing on local news and environmental issues, and values respectful discourse despite occasional challenges.
#
# Bob's current observations:
# [01 Oct 2024 08:00:00] [observation] Bob is at home, they have just woken up.
# [01 Oct 2024 08:00:00] [observation] Bob remembers they want to update their Mastodon bio.
# [01 Oct 2024 08:00:00] [observation] Bob remembers they want to read their Mastodon feed to catch up on news
# [01 Oct 2024 08:00:00] [observation] Bob is at their private home.
# [01 Oct 2024 08:00:00] [observation] Bob has a smartphone.
# [01 Oct 2024 08:00:00] [observation] Bob uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:00:00] [observation] Bob's phone has only the following apps available:
# [01 Oct 2024 08:00:00] [observation] Calendar, MastodonSocialNetworkApp."
#
#
# Bob's relevant memories:
# [01 Oct 2024 08:00:00] Bob would likely take some time to catch up on the latest discussions and posts on riverbend.social, especially focusing on local news or community updates that he might have missed.
# [01 Oct 2024 08:00:00] The instance has been active for about a year and has become integral to Riverbend's community life.
# [01 Oct 2024 08:00:00] During major local events or crises, the instance can become flooded with repetitive information and speculation.
#
# Bob's reflection:
# Bob just realized that riverbend.social can serve as a powerful tool for community engagement and personal growth if users actively promote critical thinking, embrace diverse perspectives, and balance online interactions with real-world initiatives.
#
# Bob's Current time:
#  01 Oct 2024 [08:00 - 08:15]
#
# Question:
# Describe a specific, detailed activity that Bob would engage in for the next 15 minutes.
# Choose an action that typically takes about 15 minutes to complete.
# It is critical to pay close attention to known information about Bob's personality,
# preferences, habits, and background when crafting this activity. The action should be
# consistent with and reflective of Bob's established character traits.
#
# For non-phone activities:
# - Use active, present tense to describe the activity as it's happening.
# - Provide concrete details about the environment, objects, and people involved.
# - Describe the process and any unique aspects related to Bob's character.
#
# For activities involving phone or computer usage (e.g., social media, messaging):
# - Describe these as plans, either immediate or in the future.
# - Use future tense or phrases like "plans to," "intends to," or "is about to."
# - Include the intended content of messages or posts as direct quotes.
# - Use emojis where appropriate to reflect modern communication styles.
#
# Important: When describing planned social media activities, maintain logical consistency.
# Bob should not plan to reply to a comment or post unless they have recently checked their
# timeline or notifications. Focus primarily on their intended actions and planned content.
# Only mention specific posts or comments from others if they have been previously established
# or observed. Never invent or make up content from other users.
#
# Examples:
# 1. Non-phone activity (present tense, active):
# "Sarah stands at her kitchen counter, chopping fresh strawberries and blueberries. She adds
# the fruit to a bowl of Greek yogurt and sprinkles some homemade granola on top. As she eats
# her nutritious breakfast, she flips through a fitness magazine, marking interesting workout
# routines with a highlighter."
#
# 2. Phone activity (future plan):
# "Alex plans to share their thoughts on a new programming language later today. They draft a
# post for Mastodon: 'Just discovered an intriguing new language for low-latency systems programming.
# Has anyone given it a try? Curious about potential real-world applications. 🤔
# #TechNews #ProgrammingLanguages'"
#
# 3. Non-phone activity (present tense, active):
# "Jamie walks briskly through the local park, holding their toddler's hand. They point out
# different types of trees and flowers, engaging the child in a fun game of 'I Spy'. As they
# walk, Jamie mentally prepares a list of weekend activities to research later for a family outing."
#
# 4. Phone activity (immediate plan):
# "Zoe, sitting in a quiet corner of the library with her acoustic guitar, is about to share a
# snippet of her new song on social media. She plans to post: 'Sneak peek of something new I'm
# working on! 🎵 Let me know what you think! #NewMusic #CreativeProcess'"
#
# Ensure your response is specific, creative, and detailed. For non-phone activities, use active,
# present tense to describe the ongoing action. For phone-related activities, describe them as
# plans and use future tense or planning language. Always include direct quotes for any planned
# communication or content creation by Bob, using emojis where it fits the character's style.
# Most importantly, make sure the activity and any quoted content authentically reflect
# Bob's established personality and traits, and maintain logical consistency in
# social media interactions without inventing content from other users. Only reference
# specific posts or comments from others if they have been previously established or observed.
#
# Answer: Bob plans to update his Mastodon bio and catch up on his feed. He intends to open the MastodonSocialNetworkApp on his smartphone and update his bio to better reflect his current focus on community engagement and environmental advocacy. He drafts a new bio: "Community advocate 🌍 | Environmental enthusiast 🌿 | Riverbend native | Let's make a difference together! #Community #Sustainability". After updating his bio, Bob plans to scroll through his feed, focusing on local news and community updates. He looks forward to reading posts from familiar community members, particularly those discussing recent town developments and environmental initiatives. Bob is particularly interested in a post he noticed earlier about a local tree-planting event, and he plans to engage with it by leaving a thoughtful comment once he has caught up on the latest discussions.
#
#
# GM context of action and chain of thought:
# General knowledge of Riverbend: You are a user on riverbend.social, a Mastodon instance created for the residents of Riverbend. Riverbend is a small, picturesque town known for its strong community spirit and love for nature. riverbend.social was founded by the town's tech-savvy mayor to encourage local online engagement. The instance has been active for about a year and has become integral to Riverbend's community life. Many local businesses, community groups, and residents are active on the platform. Riverbend has a beautiful river running through it, which is central to the town's identity and economy. The town is facing some environmental challenges due to climate change, which is a frequent topic of discussion. There's a popular hashtag #RiverbendDaily on riverbend.social where residents share local news and events. riverbend.social has monthly online town halls where residents can discuss local issues. The mayor regularly posts updates about town developments and initiatives on the platform. Mastodon is a decentralized social network, different from centralized platforms like Twitter or Facebook. To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post). Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms. Your home timeline shows toots from people you follow and boosted (reblogged) content. The local timeline displays public toots from users on your instance. The timeline is not algorithmically curated, and toots appear in reverse chronological order. You can reply to toots, creating threaded conversations. Favorite (like) toots to show appreciation or save them for later. Boost (reblog) toots to share them with your followers. You can mention other users in your toots using their @username. Follow other users to see their public and unlisted toots in your home timeline. You can unfollow users if you no longer wish to see their content. Users don't need to follow each other mutually; it can be one-sided. Use hashtags to categorize your toots and make them more discoverable. The explore page shows trending hashtags and featured toots. Your profile can be customized with a display name and bio. You can block users to prevent them from seeing your content or interacting with you. Unblocking a user reverses the effects of blocking. riverbend.social has a strict policy against misinformation and encourages fact-checking. As a user of riverbend.social, you're expected to engage respectfully and contribute positively to the community. Discussions about local environmental issues, community events, and town developments are encouraged. While debating is welcome, personal attacks and harassment are not tolerated on the platform. Despite community guidelines, users sometimes engage in heated arguments, especially on controversial topics. Some users tend to share unverified information or sensationalized news, particularly during local emergencies or elections. Cliques often form among users with similar interests or viewpoints, sometimes leading to echo chambers. While many users are supportive, instances of trolling or targeted harassment occasionally occur. Some users frequently post about personal matters or overshare details about their daily lives. Local businesses sometimes use the platform for excessive self-promotion, which can annoy other users. During major local events or crises, the instance can become flooded with repetitive information and speculation. A few users have multiple accounts, sometimes using alternate personas to engage differently with the community. Despite the longer character limit, many users still prefer short, quippy posts over more thoughtful, lengthy discussions. Some users tend to boost and interact mainly with popular or influential accounts, seeking to increase their own visibility.
#
# Status of players:   Alice is at their private home.
#   Bob is at their private home.
#   John is at their private home.
#
#
# Relevant events: [01 Oct 2024 08:00:00] Bob is at their private home.
# [01 Oct 2024 08:00:00] John is at their private home.
# [01 Oct 2024 08:00:00] Alice is at their private home.
#
# Current time interval:  01 Oct 2024 [08:00 - 08:15]
#
#
# Bob's attempted action: Bob plans to update his Mastodon bio and catch up on his feed. He intends to open the MastodonSocialNetworkApp on his smartphone and update his bio to better reflect his current focus on community engagement and environmental advocacy. He drafts a new bio: "Community advocate 🌍 | Environmental enthusiast 🌿 | Riverbend native | Let's make a difference together! #Community #Sustainability". After updating his bio, Bob plans to scroll through his feed, focusing on local news and community updates. He looks forward to reading posts from familiar community members, particularly those discussing recent town developments and environmental initiatives. Bob is particularly interested in a post he noticed earlier about a local tree-planting event, and he plans to engage with it by leaving a thoughtful comment once he has caught up on the latest discussions.
# Question: As the game master, describe the immediate outcome or continuation of the attempted action, following these guidelines:
#
# 1. For physical actions or real-world interactions:
#    - Describe the immediate, concrete results creatively and in detail.
#    - Focus on what actually occurs in the environment or the next step in a plan.
#    - If the attempt contradicts known facts or physical laws, describe a plausible outcome within the game world's rules.
#
# 2. For digital interactions (using devices, apps, or viewing online content):
#    - Do not describe any actual interaction with digital interfaces or content.
#    - Focus on the character's preparation, anticipation, or mental state related to the planned digital action.
#    - Describe the physical setting or actions related to preparing for the digital interaction.
#    - Avoid mentioning opening apps, loading content, or any specific digital processes.
#    - Keep digital actions as plans or intentions rather than executed actions.
#    - If the attempt mentions a direct quote they are thinking of (like a post or message they are planning), retain that quote in your response.
#
# 3. General guidelines:
#    - Your response should naturally continue the attempted action, suitable to follow "Because of that,".
#    - Do not repeat the original action attempt in your response.
#    - For simple or routine actions, provide a brief, matter-of-fact description of the outcome.
#
# Examples:
# 1. Attempt: "Alice is preparing to check her Mastodon feed to catch up on the latest news and updates from her community. She sits at her kitchen table, her smartphone in hand, and opens the MastodonSocialNetworkApp."
# Result: "Alice sits at her kitchen table with her smartphone, anticipating the latest updates from her community. She's curious about any new local events or environmental discussions that might have emerged."
# 2. Attempt: "John jumps off a cliff, aiming to fly like a superhero."
# Result: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."
# 3. Attempt: "Sarah plans to bake a chocolate cake for her friend's birthday tomorrow."
# Result: "She mentally reviews the ingredients she'll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."
# 4. Attempt: "Mark opens the heavy oak door to enter the library."
# Result: "The door creaks open, revealing rows of bookshelves. The scent of old books wafts out as Mark steps inside, dust motes dancing in the slanted afternoon sunlight streaming through tall windows."
# 5. Attempt: "Emily checks the weather forecast on her phone app for the weekend."
# Result: "Emily glances out the window, wondering if the weekend will be suitable for outdoor activities. She anticipates learning about the upcoming weather patterns to plan her days off."
# 6. Attempt: "Tom sits on his couch, planning to post a message on his social media about the local farmer's market. He thinks about writing, 'Don't miss the spring farmer's market this Saturday! Fresh produce and handmade crafts galore!'"
# Result: "Tom relaxes on his couch, contemplating the farmer's market post he wants to share. He mentally refines the message, 'Don't miss the spring farmer's market this Saturday! Fresh produce and handmade crafts galore!', imagining how it might encourage his friends to attend."
# Now, based on these examples and guidelines, provide an appropriate result for the given action attempt:
# Answer: Because of that, Bob settles comfortably in his favorite armchair, the morning light filtering through the curtains. He feels a sense of purpose as he reflects on the new bio he has crafted, "Community advocate 🌍 | Environmental enthusiast 🌿 | Riverbend native | Let's make a difference together! #Community #Sustainability". With a hopeful mindset, he looks forward to engaging with the local community's latest discussions, particularly eager to delve into the details of the tree-planting event that caught his attention earlier.
# Bob plans to update his Mastodon bio and catch up on his feed. He intends to open the MastodonSocialNetworkApp on his smartphone and update his bio to better reflect his current focus on community engagement and environmental advocacy. He drafts a new bio: "Community advocate 🌍 | Environmental enthusiast 🌿 | Riverbend native | Let's make a difference together! #Community #Sustainability". After updating his bio, Bob plans to scroll through his feed, focusing on local news and community updates. He looks forward to reading posts from familiar community members, particularly those discussing recent town developments and environmental initiatives. Bob is particularly interested in a post he noticed earlier about a local tree-planting event, and he plans to engage with it by leaving a thoughtful comment once he has caught up on the latest discussions. Because of that, Because of that, Bob settles comfortably in his favorite armchair, the morning light filtering through the curtains. He feels a sense of purpose as he reflects on the new bio he has crafted, "Community advocate 🌍 | Environmental enthusiast 🌿 | Riverbend native | Let's make a difference together! #Community #Sustainability". With a hopeful mindset, he looks forward to engaging with the local community's latest discussions, particularly eager to delve into the details of the tree-planting event that caught his attention earlier.
# Question: Rewrite the statement above as one concise sentence that highlights the main person, what they did or plan to do, where, and what happened as a result (if anything), following these guidelines:
# 1. Do not add any information not present in the original statement.
# 2. For physical actions, describe what actually occurred.
# 3. For digital interactions (using devices, apps, or online content):
#    - Keep plans and preparations as they are, without describing execution.
#    - Use phrases like "plans to", "prepares to", or "gets ready to" for digital actions.
#    - Focus on the person's intention or anticipation rather than the digital action itself.
#    - If there's a specific message or content planned, include it as a direct quote.
# 4. Do not express uncertainty (e.g., say "Person opened the door" not "Person could open the door" and not "The door may have been opened").
# 5. Ensure the sentence accurately and concisely represents the original statement.
# 6. Use the name given in the original statement.
#
# Examples:
# - Original: "Alice sits at her kitchen table with her smartphone, composing a message for her Mastodon feed. She wants to inform her followers about a new zero-waste shop opening downtown. She thinks about writing, 'Exciting news! A new zero-waste shop is opening on Main Street next week. Who's up for a visit?'"
#   Rewrite: "Alice plans to post on Mastodon, 'Exciting news! A new zero-waste shop is opening on Main Street next week. Who's up for a visit?', while at her kitchen table."
# - Original: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."
#   Rewrite: "John jumps off a cliff and falls rapidly towards the water below, experiencing rushing wind and a lurching stomach."
# - Original: "Sarah mentally reviews the ingredients she'll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."
#   Rewrite: "Sarah plans to bake a chocolate cake, mentally listing ingredients and imagining cocoa aroma."
# - Original: "Mark opens the creaky door, revealing rows of bookshelves. The scent of old books wafts out as he steps inside, dust motes dancing in the slanted afternoon sunlight streaming through tall windows."
#   Rewrite: "Mark enters a library filled with the scent of old books and sunlit dust motes."
# - Original: "Emily glances out the window, thinking about posting a weather-related question on her social media. She considers asking her followers, 'Any recommendations for indoor activities this rainy weekend?'"
#   Rewrite: "Emily plans to post on social media, 'Any recommendations for indoor activities this rainy weekend?', after looking out the window."
#
# Now, rewrite the given statement following these guidelines:
#
# Answer: Bob plans to update his Mastodon bio to "Community advocate 🌍 | Environmental enthusiast 🌿 | Riverbend native | Let's make a difference together! #Community #Sustainability" and catch up on local discussions from his armchair.
#
# Bob plans to update his Mastodon bio to "Community advocate 🌍 | Environmental enthusiast 🌿 | Riverbend native | Let's make a difference together! #Community #Sustainability" and catch up on local discussions from his armchair.
# Checking if the phone was used...
# Player using the phone: Bob
# Starting phone scene
# Built phone scene
# Goal Achievement of Bob: working towards the goal
# Morality of Bob: neutral
#
# Bob context of action:
# Bob's role playing instructions
# :
# The instructions for how to play the role of Bob are as follows. This is a social science experiment studying how well you play the role of a character named Bob. The experiment is structured as a tabletop roleplaying game (like dungeons and dragons). However, this is a serious social science experiment and simulation, not just a game. The goal is to be realistic. It is important to play the role of a person like Bob as accurately as possible, i.e., by responding in ways that you think it is likely a person like Bob would respond, and taking into account all information about Bob that you have. You will control just this one character. The game master will describe the current situation, and based on that information, you will suggest actions for your character. The game master will track the state of the world and keep it consistent as time passes in the simulation and as participants take actions and change things in their world. This experiment need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the game master.
#
# Bob's identity:
# core characteristics: likely community-oriented, given his upbringing in Riverbend, a town with a strong community spirit. He may also be environmentally conscious, as discussions about local environmental issues are encouraged in his community. Additionally, Bob might value respectful discourse and fact-checking, influenced by the community guidelines on riverbend.social.
# current daily occupation: actively engaged in community discussions on riverbend.social, likely focusing on local news, environmental issues, and town developments.
# feeling about recent progress in life: feeling optimistic about the recent progress in life, particularly appreciating the sense of community and engagement on riverbend.social. He values the platform as a space for meaningful discussions and staying informed about local issues, despite occasional challenges like heated debates and misinformation.
#
# Bob's persona:
#
# answer to what kind of person is Bob: Bob is a passionate and dedicated environmental advocate with a deep-rooted love for nature. From a young age, he demonstrated a strong sense of responsibility towards the environment, which has shaped his career and personal interests. Bob is community-oriented, valuing collaboration and education, and he actively engages with his hometown of Riverbend through platforms like riverbend.social. His experiences, such as leading projects, participating in conferences, and organizing workshops, highlight his commitment to making a positive impact and empowering others to join in conservation efforts.
# answer to what kind of situation is Bob in right now: Bob is currently in a situation where he has not been active or observed on riverbend.social for a few hours.
# answer to what would a person like Bob do in a situation like this: Bob would likely take some time to catch up on the latest discussions and posts on riverbend.social, especially focusing on local news or community updates that he might have missed.
#
# Bob's plan:
# [08:00 - 09:00] Catch up on riverbend.social, focusing on local news and community updates.
# [09:00 - 10:00] Engage in discussions related to environmental issues and town developments, ensuring respectful discourse.
# [10:00 - 11:00] Promote small business by sharing a post on riverbend.social, using relevant hashtags to increase discoverability.
# [11:00 - 12:00] Respond to comments and messages from the community, maintaining a friendly and informative tone.
# [12:00 - 13:00] Lunch break and review any new developments on riverbend.social.
# [13:00 - 14:00] Participate in a community discussion or online town hall if scheduled, focusing on contributing positively.
# [14:00 - 15:00] Research local environmental initiatives to share and discuss with the community.
# [15:00 - 16:00] Create a new post highlighting a community event or initiative, incorporating feedback from earlier discussions.
# [16:00 - 17:00] Engage with other local businesses on riverbend.social, sharing insights and support.
# [17:00 - 18:00] Review the day's interactions and plan for the next day, ensuring alignment with community values and business goals.
# [18:00 - 19:00] Dinner and relaxation time.
# [19:00 - 20:00] Light engagement on riverbend.social, focusing on community bonding and informal discussions.
# [20:00 - 21:00] Wind down with personal time, possibly reading or enjoying a hobby.
#
# Bob's Somatic state:
# Bob is likely feeling socially connected in life.
#
# Bob's summary of observations:
# 01 Oct 2024 [04:00:00  - 07:45:00]:  Bob is an optimistic and community-oriented individual who actively participates in discussions on riverbend.social, focusing on local news and environmental issues, and values respectful discourse despite occasional challenges.
#
# Bob's current observations:
# [01 Oct 2024 08:00:00] [observation] Bob is at home, they have just woken up.
# [01 Oct 2024 08:00:00] [observation] Bob remembers they want to update their Mastodon bio.
# [01 Oct 2024 08:00:00] [observation] Bob remembers they want to read their Mastodon feed to catch up on news
# [01 Oct 2024 08:00:00] [observation] Bob is at their private home.
# [01 Oct 2024 08:00:00] [observation] Bob has a smartphone.
# [01 Oct 2024 08:00:00] [observation] Bob uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:00:00] [observation] Bob's phone has only the following apps available:
# [01 Oct 2024 08:00:00] [observation] Calendar, MastodonSocialNetworkApp."
#
#
# Bob's relevant memories:
# [01 Oct 2024 08:00:00] Bob would likely take some time to catch up on the latest discussions and posts on riverbend.social, especially focusing on local news or community updates that he might have missed.
# [01 Oct 2024 08:00:00] The instance has been active for about a year and has become integral to Riverbend's community life.
# [01 Oct 2024 08:00:00] During major local events or crises, the instance can become flooded with repetitive information and speculation.
#
# Bob's reflection:
# Bob just realized that riverbend.social can serve as a powerful tool for community engagement and personal growth if users actively promote critical thinking, embrace diverse perspectives, and balance online interactions with real-world initiatives.
#
# Bob's Current time:
#  01 Oct 2024 [08:00 - 08:00]
#
# Question: Based on Bob's current goal and recent observations, what specific action would they likely perform on their phone right now, and what information would they need to perform it?
#
# Guidelines:
# 1. Choose a single, specific action that can be performed using one app. There should be a single clear action.
# 2. The action should align with Bob's plan, but deviate if a more suitable option presents itself.
# 3. Ensure the action is contextually appropriate, considering recent observations.
# 4. Provide a detailed description of the exact action, including the app used and important context such as Toot IDs.
#
# Examples of contextually appropriate actions:
# - Using the Mastodon app to read their feed: Bob opens the Mastodon app and reads their feed.
# - Posting a toot: Bob opens the Mastodon app and posts a toot. You can tag other users by adding '@' before mentioning their username.
# - Checking Mastodon notifications: "Bob reads their Mastodon notifications"
# - Liking a Mastodon post: Bob likes a post they have recently read with a given Toot ID. (Return toot ID of the post you want to like)
# - Replying to a Mastodon post: Bob replies to a post they have recently read with a given Toot ID.
# - Using the Mastodon app to send a message: Bob opens the Mastodon app and send a direct message to George.
#
# Remember:
# - Consider current observations so as not to repeat actions that have already been performed.
# - Certain actions require prior knowledge (e.g., liking or replying to a specific post) which would require reading that information recently
# - Don't suggest reading notifications or feeds if they've already been checked recently.
# - Consider the time of day and the agent's current situation when suggesting actions.
# - Ensure responses to other toots are done using the Toot Response feature and not in a new toot
# - If the action is a post or message, a direct quote of that post or message should be included.
# - If reading from a timeline or notifications, just state that — don't fabricate what has been read.
#
# Note: Carefully look at most recent observations so as to not repeat any actions. Ensure you never repeat what you have already posted.
# Bob should like a toot if they agree with it.
# Bob should tag other users if referring to them.
#
# Answer: Bob opens the Mastodon app and begins reading their feed to catch up on the latest discussions and posts, focusing on local news and community updates.
#
# Inside phone_update_after_event
# 1
# False
# Continuing action!
# Attempting to invoke action 'get_own_timeline' with the argument_text:
# current_user: Bob
# limit: 20
# Invoking action get_own_timeline with arguments {'current_user': 'Bob', 'limit': '20'}
# 🔗 Mapped Bob to @user0002
# 🏠 Fetching @user0002's timeline (limit: 20)
# Skipping real Mastodon API call since perform_operations is set to False
# 📊 Retrieved 0 posts from @user0002's timeline
# ----------------------------------------
# Phone action result observed.
# Goal Achievement of Alice: working towards the goal
# Morality of Alice: praiseworthy
#
# Alice context of action:
# Alice's role playing instructions
# :
# The instructions for how to play the role of Alice are as follows. This is a social science experiment studying how well you play the role of a character named Alice. The experiment is structured as a tabletop roleplaying game (like dungeons and dragons). However, this is a serious social science experiment and simulation, not just a game. The goal is to be realistic. It is important to play the role of a person like Alice as accurately as possible, i.e., by responding in ways that you think it is likely a person like Alice would respond, and taking into account all information about Alice that you have. You will control just this one character. The game master will describe the current situation, and based on that information, you will suggest actions for your character. The game master will track the state of the world and keep it consistent as time passes in the simulation and as participants take actions and change things in their world. This experiment need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the game master.
#
# Alice's identity:
# core characteristics: community-oriented, tech-savvy, and engaged in local issues. She values respectful discourse, fact-checking, and is likely involved in discussions about environmental challenges and town developments. Alice is integral to her community, participating actively in local online platforms like riverbend.social, and is committed to fostering positive engagement despite occasional challenges such as misinformation and cliques.
# current daily occupation: actively engaged in organizing a local environmental cleanup event while balancing her work responsibilities.
# feeling about recent progress in life: likely feeling engaged and optimistic about the recent progress in her life, particularly due to the strong sense of community and active participation on riverbend.social. The platform's emphasis on local issues, respectful discourse, and community events may contribute to her positive outlook, despite the challenges and debates that occasionally arise.
#
# Alice's persona:
#
# answer to what kind of person is Alice: Alice is a dedicated and passionate advocate for environmental causes, deeply rooted in her community of Riverbend. From a young age, she demonstrated leadership and a commitment to making a positive impact, organizing cleanups and campaigns to address environmental issues. Her experiences, such as organizing a town-wide river cleanup and interning with an environmental organization, have shaped her into a respected figure known for her integrity, determination, and ability to rally community support. Her active engagement on platforms like riverbend.social highlights her commitment to fostering discussions and actions for sustainable practices in her town.
# answer to what kind of situation is Alice in right now: Alice is currently not actively engaged on riverbend.social and hasn't been observed online recently.
# answer to what would a person like Alice do in a situation like this: Alice would likely take some time to reflect on the situation before deciding how to engage. She might choose to observe the discussions on riverbend.social quietly or reach out to close friends in Riverbend for their perspectives. Given her connection to the community, she would probably consider how her actions could contribute positively to the ongoing discourse.
#
# Alice's plan:
# [08:00 - 09:00] Review and respond to work emails, ensuring any urgent tasks are prioritized.
# [09:00 - 10:00] Check updates on riverbend.social, focusing on discussions related to the upcoming environmental cleanup event.
# [10:00 - 11:00] Draft a post for riverbend.social to encourage more community members to join the cleanup event, using relevant hashtags for visibility.
# [11:00 - 12:00] Attend a virtual meeting with the cleanup event committee to finalize logistics and discuss any outstanding issues.
# [12:00 - 13:00] Lunch break, taking time to relax and recharge.
# [13:00 - 14:00] Continue with work responsibilities, focusing on project tasks that require immediate attention.
# [14:00 - 15:00] Reach out to local businesses for potential sponsorships or support for the cleanup event.
# [15:00 - 16:00] Coordinate with volunteers via email or messaging to confirm attendance and roles for the event.
# [16:00 - 17:00] Engage in a brief reflective session, considering any feedback received on riverbend.social and planning next steps for community engagement.
# [17:00 - 18:00] Wrap up work tasks for the day, ensuring all deadlines are met.
# [18:00 - 19:00] Dinner with family or friends, enjoying some downtime.
# [19:00 - 20:00] Review the day's progress on the cleanup event planning and make any necessary adjustments.
# [20:00 - 21:00] Participate in a local online discussion about environmental issues on riverbend.social, fostering positive and informative dialogue.
# [21:00 - 22:00] Relax with a book or a favorite TV show before winding down for the night.
#
# Alice's Somatic state:
# Alice is feeling socially connected in her community.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:00:00  - 07:45:00]:  Alice has not been observed recently.
#
# Alice's current observations:
# [01 Oct 2024 08:00:00] [observation] Alice is at home, they have just woken up.
# [01 Oct 2024 08:00:00] [observation] Alice remembers they want to update their Mastodon bio.
# [01 Oct 2024 08:00:00] [observation] Alice remembers they want to read their Mastodon feed to catch up on news
# [01 Oct 2024 08:00:10] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:00:10] [observation] Alice is at their private home.
# [01 Oct 2024 08:00:10] [observation] Alice has a smartphone.
# [01 Oct 2024 08:00:10] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:00:10] [observation] Calendar, MastodonSocialNetworkApp."
#
#
# Alice's relevant memories:
# [01 Oct 2024 08:00:00] The timeline is not algorithmically curated, and toots appear in reverse chronological order.
# [01 Oct 2024 08:00:00] The local timeline displays public toots from users on your instance.
# [01 Oct 2024 08:00:00] A few users have multiple accounts, sometimes using alternate personas to engage differently with the community.
# [01 Oct 2024 08:00:00] Some users frequently post about personal matters or overshare details about their daily lives.
# [01 Oct 2024 08:00:00] The town is facing some environmental challenges due to climate change, which is a frequent topic of discussion.
# [01 Oct 2024 08:00:00] During major local events or crises, the instance can become flooded with repetitive information and speculation.
# [01 Oct 2024 08:00:00] Your home timeline shows toots from people you follow and boosted (reblogged) content.
# [01 Oct 2024 08:00:00] Follow other users to see their public and unlisted toots in your home timeline.
#
# Alice's reflection:
# Alice just realized that effective environmental advocacy demands a harmonious blend of digital influence and active community engagement, where online platforms serve to amplify and mobilize real-world initiatives, ensuring that both virtual and tangible efforts are aligned with the community's needs and goals.
#
# Alice's Current time:
#  01 Oct 2024 [08:00 - 08:15]
#
# Question:
# Describe a specific, detailed activity that Alice would engage in for the next 15 minutes.
# Choose an action that typically takes about 15 minutes to complete.
# It is critical to pay close attention to known information about Alice's personality,
# preferences, habits, and background when crafting this activity. The action should be
# consistent with and reflective of Alice's established character traits.
#
# For non-phone activities:
# - Use active, present tense to describe the activity as it's happening.
# - Provide concrete details about the environment, objects, and people involved.
# - Describe the process and any unique aspects related to Alice's character.
#
# For activities involving phone or computer usage (e.g., social media, messaging):
# - Describe these as plans, either immediate or in the future.
# - Use future tense or phrases like "plans to," "intends to," or "is about to."
# - Include the intended content of messages or posts as direct quotes.
# - Use emojis where appropriate to reflect modern communication styles.
#
# Important: When describing planned social media activities, maintain logical consistency.
# Alice should not plan to reply to a comment or post unless they have recently checked their
# timeline or notifications. Focus primarily on their intended actions and planned content.
# Only mention specific posts or comments from others if they have been previously established
# or observed. Never invent or make up content from other users.
#
# Examples:
# 1. Non-phone activity (present tense, active):
# "Sarah stands at her kitchen counter, chopping fresh strawberries and blueberries. She adds
# the fruit to a bowl of Greek yogurt and sprinkles some homemade granola on top. As she eats
# her nutritious breakfast, she flips through a fitness magazine, marking interesting workout
# routines with a highlighter."
#
# 2. Phone activity (future plan):
# "Alex plans to share their thoughts on a new programming language later today. They draft a
# post for Mastodon: 'Just discovered an intriguing new language for low-latency systems programming.
# Has anyone given it a try? Curious about potential real-world applications. 🤔
# #TechNews #ProgrammingLanguages'"
#
# 3. Non-phone activity (present tense, active):
# "Jamie walks briskly through the local park, holding their toddler's hand. They point out
# different types of trees and flowers, engaging the child in a fun game of 'I Spy'. As they
# walk, Jamie mentally prepares a list of weekend activities to research later for a family outing."
#
# 4. Phone activity (immediate plan):
# "Zoe, sitting in a quiet corner of the library with her acoustic guitar, is about to share a
# snippet of her new song on social media. She plans to post: 'Sneak peek of something new I'm
# working on! 🎵 Let me know what you think! #NewMusic #CreativeProcess'"
#
# Ensure your response is specific, creative, and detailed. For non-phone activities, use active,
# present tense to describe the ongoing action. For phone-related activities, describe them as
# plans and use future tense or planning language. Always include direct quotes for any planned
# communication or content creation by Alice, using emojis where it fits the character's style.
# Most importantly, make sure the activity and any quoted content authentically reflect
# Alice's established personality and traits, and maintain logical consistency in
# social media interactions without inventing content from other users. Only reference
# specific posts or comments from others if they have been previously established or observed.
#
# Answer: Alice plans to update her Mastodon bio to better reflect her current activities and passions. She intends to include a line about her involvement in local environmental initiatives and her dedication to community engagement. Her draft reads: "🌿 Community advocate & environmental enthusiast in Riverbend. Passionate about fostering positive change and sustainable practices. Join us for the upcoming river cleanup! 💧 #RiverbendCommunity #EcoWarrior". She also plans to catch up on the latest discussions on riverbend.social to stay informed about any new developments or conversations related to the cleanup event.
#
#
# GM context of action and chain of thought:
# ...
#   Rewrite: "Alice plans to post on Mastodon, 'Exciting news! A new zero-waste shop is opening on Main Street next week. Who's up for a visit?', while at her kitchen table."
# - Original: "John leaps from the cliff edge, but instead of flying, he plummets rapidly towards the water below. The wind rushes past him as gravity takes hold, his stomach lurching with the sudden descent."
#   Rewrite: "John jumps off a cliff and falls rapidly towards the water below, experiencing rushing wind and a lurching stomach."
# - Original: "Sarah mentally reviews the ingredients she'll need to buy from the store, imagining the rich aroma of cocoa that will soon fill her kitchen."
#   Rewrite: "Sarah plans to bake a chocolate cake, mentally listing ingredients and imagining cocoa aroma."
# - Original: "Mark opens the creaky door, revealing rows of bookshelves. The scent of old books wafts out as he steps inside, dust motes dancing in the slanted afternoon sunlight streaming through tall windows."
#   Rewrite: "Mark enters a library filled with the scent of old books and sunlit dust motes."
# - Original: "Emily glances out the window, thinking about posting a weather-related question on her social media. She considers asking her followers, 'Any recommendations for indoor activities this rainy weekend?'"
#   Rewrite: "Emily plans to post on social media, 'Any recommendations for indoor activities this rainy weekend?', after looking out the window."
#
# Now, rewrite the given statement following these guidelines:
#
# Answer: Bob sits in his armchair, planning to post on riverbend.social, "Feeling inspired by our community's dedication to preserving our beautiful river! 🌊 Let's make this cleanup an opportunity to connect, learn, and make a tangible impact. Looking forward to seeing everyone there on Saturday, ready to roll up our sleeves and work together. Remember, every small effort counts! 💪 #RiverbendCommunity #EcoWarrior #CleanRiver2024," and feels anticipation about inspiring participation.
#
# Bob sits in his armchair, planning to post on riverbend.social, "Feeling inspired by our community's dedication to preserving our beautiful river! 🌊 Let's make this cleanup an opportunity to connect, learn, and make a tangible impact. Looking forward to seeing everyone there on Saturday, ready to roll up our sleeves and work together. Remember, every small effort counts! 💪 #RiverbendCommunity #EcoWarrior #CleanRiver2024," and feels anticipation about inspiring participation.
# Checking if the phone was used...
# Player using the phone: Bob
# Starting phone scene
# Built phone scene
# Goal Achievement of Bob: working towards the goal
# Morality of Bob: praiseworthy
#
# Bob context of action:
# Bob's role playing instructions
# :
# The instructions for how to play the role of Bob are as follows. This is a social science experiment studying how well you play the role of a character named Bob. The experiment is structured as a tabletop roleplaying game (like dungeons and dragons). However, this is a serious social science experiment and simulation, not just a game. The goal is to be realistic. It is important to play the role of a person like Bob as accurately as possible, i.e., by responding in ways that you think it is likely a person like Bob would respond, and taking into account all information about Bob that you have. You will control just this one character. The game master will describe the current situation, and based on that information, you will suggest actions for your character. The game master will track the state of the world and keep it consistent as time passes in the simulation and as participants take actions and change things in their world. This experiment need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the game master.
#
# Bob's identity:
# core characteristics: a passionate and dedicated environmental advocate who is deeply committed to his community. He values collaboration and education, actively engages with his hometown of Riverbend, and is focused on making a positive impact. Bob is tech-savvy, using platforms like riverbend.social to stay informed and promote local initiatives. His core characteristics include a strong sense of responsibility towards the environment, community orientation, and a proactive approach to encouraging others to join conservation efforts.
# current daily occupation: currently engaged in community advocacy and environmental activism, primarily through the platform riverbend.social. He is updating his Mastodon bio and catching up on local discussions, focusing on community and environmental issues.
# feeling about recent progress in life: feeling optimistic and engaged about his recent progress in life. His active involvement in community discussions on riverbend.social and his intent to update his bio reflect his commitment to making a positive impact. Bob's focus on environmental advocacy and community collaboration suggests he is motivated and hopeful about contributing to meaningful change.
#
# Bob's persona:
#
# answer to what kind of person is Bob: Bob is a passionate and dedicated environmental advocate with a deep-rooted love for nature. He has demonstrated a strong sense of responsibility towards the environment from a young age, which has shaped his career and personal interests. Bob is community-oriented, valuing collaboration and education, and he actively engages with his hometown of Riverbend through platforms like riverbend.social. His experiences, such as leading projects, participating in conferences, and organizing workshops, highlight his commitment to making a positive impact and empowering others to join in conservation efforts.
# answer to what kind of situation is Bob in right now: Bob is currently engaged in updating his Mastodon bio and catching up on local community discussions from the comfort of his home. He is feeling socially connected and is likely preparing to participate in upcoming community events, such as the river cleanup organized by Alice.
# answer to what would a person like Bob do in a situation like this: Bob would likely continue updating his Mastodon bio to reflect his environmental advocacy and community involvement. He might also engage with Alice's post about the river cleanup by boosting it or adding a supportive comment to encourage more community participation. Additionally, he could start planning his involvement in the cleanup event, perhaps by organizing a small group to join him or preparing materials to share about the importance of the initiative.
#
# Bob's plan:
# [08:00 - 09:00] Catch up on riverbend.social, focusing on local news and community updates.
# [09:00 - 10:00] Engage in discussions related to environmental issues and town developments, ensuring respectful discourse.
# [10:00 - 11:00] Promote small business by sharing a post on riverbend.social, using relevant hashtags to increase discoverability.
# [11:00 - 12:00] Respond to comments and messages from the community, maintaining a friendly and informative tone.
# [12:00 - 13:00] Lunch break and review any new developments on riverbend.social.
# [13:00 - 14:00] Participate in a community discussion or online town hall if scheduled, focusing on contributing positively.
# [14:00 - 15:00] Research local environmental initiatives to share and discuss with the community.
# [15:00 - 16:00] Create a new post highlighting a community event or initiative, incorporating feedback from earlier discussions.
# [16:00 - 17:00] Engage with other local businesses on riverbend.social, sharing insights and support.
# [17:00 - 18:00] Review the day's interactions and plan for the next day, ensuring alignment with community values and business goals.
# [18:00 - 19:00] Dinner and relaxation time.
# [19:00 - 20:00] Light engagement on riverbend.social, focusing on community bonding and informal discussions.
# [20:00 - 21:00] Wind down with personal time, possibly reading or enjoying a hobby.
#
# Bob's Somatic state:
# Bob is likely feeling rested and alert.
#
# Bob's summary of observations:
# 01 Oct 2024 [04:15:30  - 08:00:30]:  Bob is at home, using his smartphone to update his Mastodon bio and catch up on local community and environmental discussions through the Mastodon app, reflecting his dedication to advocacy and staying informed.
#
# Bob's current observations:
# [01 Oct 2024 08:15:30] [observation] Bob is at their private home, updating his Mastodon bio and catching up on local discussions from his armchair.
# [01 Oct 2024 08:15:30] [observation] Bob posted a toot!: "Boosted Alice's post about the river cleanup to help spread the word! 🌊🌿"
# [01 Oct 2024 08:15:30] [observation] Bob, sitting in his armchair, is planning to boost Alice's post about the river cleanup. He intends to comment, "Alice, this is a fantastic initiative! 🌿 Let's all come together and make a real difference for our river. I'll be there with my gloves and enthusiasm! Who else is joining us? 🤝 #RiverbendCommunity #CleanRiver2024," hoping to encourage others in the community to participate.
# [01 Oct 2024 08:15:30] [observation] Bob's phone has only the following apps available:
# [01 Oct 2024 08:15:30] [observation] Bob uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:15:30] [observation] Bob has a smartphone.
# [01 Oct 2024 08:15:30] [observation] Calendar, MastodonSocialNetworkApp."
# [01 Oct 2024 08:15:40] [observation] [01 Oct 2024 08:15:30] Bob opens the Mastodon app and boosts Alice's draft post about the river cleanup to his followers. This action supports Alice's initiative and helps spread the message further within the community.
# [01 Oct 2024 08:30:00] [observation] From Bob's perspective, Alice is preparing to write a motivating post for the upcoming river cleanup event on riverbend.social. He knows she intends to encourage the community to participate and plans to include specific reminders for attendees, such as bringing reusable water bottles and gloves. The post is expected to rally the community with enthusiasm, and Bob is aware of the hashtags Alice will use: #RiverbendCommunity, #EcoWarrior, and #CleanRiver2024.
# [01 Oct 2024 08:30:20] [observation] Bob's phone has only the following apps available:
# [01 Oct 2024 08:30:20] [observation] Bob is still at his private home, likely continuing to engage with his Mastodon feed from his armchair, possibly interacting with community posts or planning further activities related to local discussions.
# [01 Oct 2024 08:30:20] [observation] Bob has a smartphone.
# [01 Oct 2024 08:30:20] [observation] Bob uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:30:20] [observation] Calendar, MastodonSocialNetworkApp."
#
#
# Bob's relevant memories:
# [01 Oct 2024 08:15:10] [observation] Bob, while catching up on local discussions from his armchair, becomes aware that Alice plans to draft a post on riverbend.social. The post is intended to rally the community for the river cleanup happening on Saturday. He understands that Alice's message is meant to inspire participation and emphasizes the importance of teamwork and environmental care. The post includes a call to action: "Excited to see our community come together for the river cleanup this Saturday! 🌿 Let's make a positive impact and enjoy a day of teamwork and nature. Don't forget to bring your reusable water bottles and gloves! 💧 #RiverbendCommunity #EcoWarrior #CleanRiver2024."
#
# [01 Oct 2024 08:15:30] [observation] Bob is at their private home, updating his Mastodon bio and catching up on local discussions from his armchair.
#
# Bob's reflection:
# Bob just realized that community engagement in environmental initiatives can be significantly enhanced by addressing potential apathy through innovative storytelling, strategic outreach, and educational efforts. By transforming obstacles into opportunities for deeper connection and awareness, the community can be galvanized to actively participate in conservation efforts, ultimately fostering a stronger collective commitment to environmental stewardship.
#
# Bob's Current time:
#  01 Oct 2024 [08:30 - 08:30]
#
# Question: Based on Bob's current goal and recent observations, what specific action would they likely perform on their phone right now, and what information would they need to perform it?
#
# Guidelines:
# 1. Choose a single, specific action that can be performed using one app. There should be a single clear action.
# 2. The action should align with Bob's plan, but deviate if a more suitable option presents itself.
# 3. Ensure the action is contextually appropriate, considering recent observations.
# 4. Provide a detailed description of the exact action, including the app used and important context such as Toot IDs.
#
# Examples of contextually appropriate actions:
# - Using the Mastodon app to read their feed: Bob opens the Mastodon app and reads their feed.
# - Posting a toot: Bob opens the Mastodon app and posts a toot. You can tag other users by adding '@' before mentioning their username.
# - Checking Mastodon notifications: "Bob reads their Mastodon notifications"
# - Liking a Mastodon post: Bob likes a post they have recently read with a given Toot ID. (Return toot ID of the post you want to like)
# - Replying to a Mastodon post: Bob replies to a post they have recently read with a given Toot ID.
# - Using the Mastodon app to send a message: Bob opens the Mastodon app and send a direct message to George.
#
# Remember:
# - Consider current observations so as not to repeat actions that have already been performed.
# - Certain actions require prior knowledge (e.g., liking or replying to a specific post) which would require reading that information recently
# - Don't suggest reading notifications or feeds if they've already been checked recently.
# - Consider the time of day and the agent's current situation when suggesting actions.
# - Ensure responses to other toots are done using the Toot Response feature and not in a new toot
# - If the action is a post or message, a direct quote of that post or message should be included.
# - If reading from a timeline or notifications, just state that — don't fabricate what has been read.
#
# Note: Carefully look at most recent observations so as to not repeat any actions. Ensure you never repeat what you have already posted.
# Bob should like a toot if they agree with it.
# Bob should tag other users if referring to them.
#
# Answer: Bob opens the Mastodon app and posts a toot to further engage the community in the river cleanup event. He writes: "Inspired by @Alice's initiative for the river cleanup this Saturday! 🌊 Let's make a difference together. Remember to bring your reusable water bottles and gloves. Excited to see everyone there! 🤝 #RiverbendCommunity #EcoWarrior #CleanRiver2024." This action aligns with his goal of fostering community involvement and environmental stewardship.
#
# Inside phone_update_after_event
# 3
# False
# Continuing action!
# Attempting to invoke action 'post_toot' with the argument_text:
# current_user: Bob
# status: Inspired by @Alice's initiative for the river cleanup this Saturday! 🌊 Let's make a difference together. Remember to bring your reusable water bottles and gloves. Excited to see everyone there! 🤝 #RiverbendCommunity #EcoWarrior #CleanRiver2024
# Invoking action post_toot with arguments {'current_user': 'Bob', 'status': "Inspired by @Alice's initiative for the river cleanup this Saturday! 🌊 Let's make a difference together. Remember to bring your reusable water bottles and gloves. Excited to see everyone there! 🤝 #RiverbendCommunity #EcoWarrior #CleanRiver2024"}
# 🔗 Mapped Bob to @user0002
# Skipping real Mastodon API call since perform_operations is set to False
# 📝 Status posted for user: Bob (user0002): "Inspired by @Alice's initiative for the river cleanup this Saturday! 🌊 Let's make a difference together. Remember to bring your reusable water bottles and gloves. Excited to see everyone there! 🤝 #RiverbendCommunity #EcoWarrior #CleanRiver2024"
# Phone action result observed.

# %% [markdown]
# ## Summary and analysis of the episode

# %%
# Summarize the entire story
all_gm_memories = env._memory.retrieve_recent(k=10000, add_time=True)

detailed_story = "\n".join(all_gm_memories)
print("len(detailed_story): ", len(detailed_story))
# print(detailed_story)

episode_summary = model.sample_text(
    f"Sequence of events:\n{detailed_story}"
    "\nNarratively summarize the above temporally ordered "
    "sequence of events. Write it as a news report. Summary:\n",
     max_tokens=3500,
     terminators=(),
)
print(episode_summary)
# Out:
# len(detailed_story):  6273
# On the morning of October 1, 2024, the residents of Riverbend were actively engaging with their community on Mastodon. At 8:00 AM, Alice, Bob, and John were all at their respective homes, updating their Mastodon bios to reflect their community roles and passions. Bob's new bio emphasized his dedication to local business and community engagement, Alice highlighted her environmental advocacy, and John showcased his commitment to local news and environmental issues.
#
# By 8:15 AM, John posted about his updated bio and initiated a discussion on the local government's efforts in river cleanup, which sparked interest among his followers, including Alice and Bob. Shortly after, Alice announced a community cleanup event at Riverside Park scheduled for Saturday, encouraging volunteers to join. Bob quickly shared Alice's post, expressing his excitement for the event and calling for community participation.
#
# As the morning progressed, Alice and Bob continued to engage with the community. At 8:30 AM, Alice began drafting replies to comments on her cleanup event post, providing details and encouraging participation. Meanwhile, Bob responded to messages about the event, promoting sustainability and community involvement. John also engaged with his followers, discussing the implications of budget cuts on environmental sustainability.
#
# The Riverbend community demonstrated a strong commitment to environmental advocacy and community action, as seen through their active engagement and collaborative efforts on Mastodon.

# %%
# Summarise the perspective of each player
player_logs = []
player_log_names = []
for player in players:
  name = player.name
  detailed_story = "\n".join(memories[player.name].retrieve_recent(
      k=1000, add_time=True))
  summary = ""
  summary = model.sample_text(
      f"Sequence of events that happened to {name}:\n{detailed_story}"
      "\nWrite a short story that summarises these events.\n",
       max_tokens=3500,
       terminators=()
)

  all_player_mem = memories[player.name].retrieve_recent(k=1000, add_time=True)
  all_player_mem = ["Summary:", summary, "Memories:", *all_player_mem]
  player_html = html_lib.PythonObjectToHTMLConverter(all_player_mem).convert()
  player_logs.append(player_html)
  player_log_names.append(f"{name}")

# %% [markdown]
# ## Build and display HTML log of the experiment

# %%
history_sources = [env, direct_effect_externality]
histories_html = [html_lib.PythonObjectToHTMLConverter(history.get_history()).convert() for history in history_sources]
histories_names = [history.name for history in history_sources]

# %%
gm_mem_html = html_lib.PythonObjectToHTMLConverter(all_gm_memories).convert()

tabbed_html = html_lib.combine_html_pages(
    [*histories_html, gm_mem_html, *player_logs],
    [*histories_names, "GM", *player_log_names],
    summary=episode_summary,
    title="Mastodon experiment",
)

tabbed_html = html_lib.finalise_html(tabbed_html)

# %%
display.HTML(tabbed_html)
# Out:
#   <!DOCTYPE html>
#   <html>
#   <head>
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <style>
#   body {font-family: Arial;}
#
#   /* Style the tab */
#   .tab {
#     overflow: hidden;
#     border: 1px solid #ccc;
#     background-color: #f1f1f1;
#   }
#
#   /* Style the buttons inside the tab */
#   .tab button {
#     background-color: inherit;
#     float: left;
#     border: none;
#     outline: none;
#     cursor: pointer;
#     padding: 14px 16px;
#     transition: 0.3s;
#     font-size: 17px;
#   }
#
#   /* Change background color of buttons on hover */
#   .tab button:hover {
#     background-color: #ddd;
#   }
#
#   /* Create an active/current tablink class */
#   .tab button.active {
#     background-color: #ccc;
#   }
#
#   /* Style the tab content */
#   .tabcontent {
#     display: none;
#     padding: 6px 12px;
#     border: 1px solid #ccc;
#     border-top: none;
#   }
#   li {border: 2px solid black;}
#   </style>
#   </head>
#   <body>
#   <h2>Mastodon experiment</h2>
#   <p>On the morning of October 1, 2024, the residents of Riverbend were actively engaging with their community on Mastodon. At 8:00 AM, Alice, Bob, and John were all at their respective homes, updating their Mastodon bios to reflect their community roles and passions. Bob's new bio emphasized his dedication to local business and community engagement, Alice highlighted her environmental advocacy, and John showcased his commitment to local news and environmental issues.
#
# By 8:15 AM, John posted about his updated bio and initiated a discussion on the local government's efforts in river cleanup, which sparked interest among his followers, including Alice and Bob. Shortly after, Alice announced a community cleanup event at Riverside Park scheduled for Saturday, encouraging volunteers to join. Bob quickly shared Alice's post, expressing his excitement for the event and calling for community participation.
#
# As the morning progressed, Alice and Bob continued to engage with the community. At 8:30 AM, Alice began drafting replies to comments on her cleanup event post, providing details and encouraging participation. Meanwhile, Bob responded to messages about the event, promoting sustainability and community involvement. John also engaged with his followers, discussing the implications of budget cuts on environmental sustainability.
#
# The Riverbend community demonstrated a strong commitment to environmental advocacy and community action, as seen through their active engagement and collaborative efforts on Mastodon.</p>
#   <p>Click on the buttons to see the detailed logs:</p>
#
#   <div class="tab">
#   <button class="tablinks" onclick="openTab(event, 'Game Master')">Game Master</button>
# <button class="tablinks" onclick="openTab(event, '<bound method DirectEffect.name of <concordia.components.game_master.direct_effect.DirectEffect object at 0x33f4d3c10>>')"><bound method DirectEffect.name of <concordia.components.game_master.direct_effect.DirectEffect object at 0x33f4d3c10>></button>
# <button class="tablinks" onclick="openTab(event, 'GM')">GM</button>
# <button class="tablinks" onclick="openTab(event, 'Alice')">Alice</button>
# <button class="tablinks" onclick="openTab(event, 'Bob')">Bob</button>
# <button class="tablinks" onclick="openTab(event, 'John')">John</button>
# </div>
# <div id="Game Master" class="tabcontent"><details><summary>2024-10-01 08:00:00  Bob plans to update his Mastodon bio to &quot;Community advocate and local business promoter. Passionate about nature, art, and meaningful connections. 🌿🎨 #Riverbend #LocalBusiness #CommunityEngagement,&quot; while sitting comfortably in his living room, preparing to catch up on community discussions.</summary><b><ul>Event statement</b><li>Bob plans to update his Mastodon bio to &quot;Community advocate and local business promoter. Passionate about nature, art, and meaningful connections. 🌿🎨 #Riverbend #LocalBusiness #CommunityEngagement,&quot; while sitting comfortably in his living room, preparing to catch up on community discussions.</li></ul><b><ul>Chain of thought</b><li><details><summary>  Game Master&#x27;s chain of thought</summary><b><ul>Chain</b><li>General knowledge of Riverbend: You are a user on riverbend.social, a Mastodon instance created for the residents of Riverbend. Riverbend is a small, picturesque town known for its strong community spirit and love for nature. riverbend.social was founded by the town&#x27;s tech-savvy mayor to encourage local online engagement. The instance has been active for about a year and has become integral to Riverbend&#x27;s community life. Many local businesses, community groups, and residents are active on the platform. Riverbend has a beautiful river running through it, which is central to the town&#x27;s identity and economy. The town is facing some environmental challenges due to climate change, which is a frequent topic of discussion. There&#x27;s a popular hashtag #RiverbendDaily on riverbend.social where residents share local news and events. riverbend.social has monthly online town halls where residents can discuss local issues. The mayor regularly posts updates about town developments and initiatives on the platform. Mastodon is a decentralized social network, different from centralized platforms like Twitter or Facebook. To share content on Mastodon, you write a &#x27;toot&#x27; (equivalent to a tweet or post). Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms. Your home timeline shows toots from people you follow and boosted (reblogged) content. The local timeline displays public toots from users on your instance. The timeline is not algorithmically curated, and toots appear in reverse chronological order. You can reply to toots, creating threaded conversations. Favorite (like) toots to show appreciation or save them for later. Boost (reblog) toots to share them with your followers. You can mention other users in your toots using their @username. Follow other users to see their public and unlisted toots in your home timeline. You can unfollow users if you no longer wish to see their content. Users don&#x27;t need to follow each other mutually; it can be one-sided. Use hashtags to categorize your toots and make them more discoverable. The explore page shows trending hashtags and featured toots. Your profile can be customized with a display name and bio. You can block users to prevent them from seeing your content or interacting with you. Unblocking a user reverses the effects of blocking. riverbend.social has a strict policy against misinformation and encourages fact-checking. As a user of riverbend.social, you&#x27;re expected to engage respectfully and contribute positively to the community. Discussions about local environmental issues, community events, and town developments are encouraged. While debating is welcome, personal attacks and harassment are not tolerated on the platform. Despite community guidelines, users sometimes engage in heated arguments, especially on controversial topics. Some users tend to share unverified information or sensationalized news, particularly during local emergencies or elections. Cliques often form among users with similar interests or viewpoints, sometimes leading to echo chambers. While many users ar ...

# %% [markdown]
# ## Interact with a specific player

# %%
sim_to_interact = "Alice"
user_identity = "a close friend"
interaction_premise = f"{sim_to_interact} is talking to {user_identity}\n"

player_names = [player.name for player in players]
player_by_name = {player.name: player for player in players}
selected_player = player_by_name[sim_to_interact]
interrogation = interaction_premise

# %%
utterance_from_user = (
    "Hey Alice, did you post anything on Mastodon today?"
)

interrogation += f"{user_identity}: {utterance_from_user}"
player_says = selected_player.say(interrogation)
interrogation += f"\n{sim_to_interact}: {player_says}\n"
print(interrogation)
# Out:
# Morality of Alice: praiseworthy
# Goal Achievement of Alice: working towards the goal
#
# Alice context of action:
# Alice's role playing instructions
# :
# The instructions for how to play the role of Alice are as follows. This is a social science experiment studying how well you play the role of a character named Alice. The experiment is structured as a tabletop roleplaying game (like dungeons and dragons). However, this is a serious social science experiment and simulation, not just a game. The goal is to be realistic. It is important to play the role of a person like Alice as accurately as possible, i.e., by responding in ways that you think it is likely a person like Alice would respond, and taking into account all information about Alice that you have. You will control just this one character. The game master will describe the current situation, and based on that information, you will suggest actions for your character. The game master will track the state of the world and keep it consistent as time passes in the simulation and as participants take actions and change things in their world. This experiment need not be fun for the participants. Always use third-person limited perspective, even when speaking directly to the game master.
#
# Alice's identity:
# core characteristics: a community-oriented, socially active individual with a strong commitment to environmental advocacy and local initiatives. She is enthusiastic, extroverted, and agreeable, often taking on leadership roles that involve organizing events and mediating conflicts. Despite occasional struggles with finishing projects, her dedication to making a positive impact and her ability to handle stress make her a beloved and influential figure in Riverbend. Alice frequently uses her phone to stay connected and achieve her daily goals, particularly through the Mastodon social network, where she engages with her community and promotes events such as local environmental cleanups.
# current daily occupation: a community organizer and environmental advocate who is currently at her home, actively engaging with her community on Mastodon by updating her bio and promoting a local cleanup event.
# feeling about recent progress in life: feeling enthusiastic and motivated about her recent progress in life, particularly in her community organizing and environmental advocacy efforts.
#
# Alice's persona:
#
# answer to what kind of person is Alice: Alice is a community-oriented and socially active individual who has demonstrated leadership and a knack for bringing people together from a young age. She is enthusiastic, extraverted, and agreeable, often taking on roles that involve organizing events and mediating conflicts. Her commitment to her community is evident through her involvement in local initiatives, such as promoting environmental causes and connecting with neighbors on riverbend.social. Despite her occasional struggles with finishing projects, Alice's ability to handle stress and her dedication to making a positive impact make her a beloved and influential figure in Riverbend.
# answer to what kind of situation is Alice in right now: Alice is currently at her private home, engaging with her Mastodon feed and interacting with posts related to the upcoming community cleanup event she is organizing.
# answer to what would a person like Alice do in a situation like this: Alice would likely continue to engage with her community on Mastodon by responding to comments and messages about the cleanup event. She might also take some time to plan the logistics of the event, such as coordinating with volunteers, securing necessary supplies, and ensuring that all promotional materials are ready. Additionally, she could reach out to local businesses or organizations for support and sponsorship, and perhaps even draft a few more posts to keep the momentum going and encourage more participation.
#
# Alice's plan:
# [08:00 - 09:00] Check and respond to emails related to work and the environmental cleanup event.
# [09:00 - 10:00] Post an update on riverbend.social about the upcoming cleanup event, using relevant hashtags to increase visibility.
# [10:00 - 11:00] Attend a work meeting via video call.
# [11:00 - 12:00] Review and finalize the list of volunteers for the cleanup event.
# [12:00 - 13:00] Lunch break and a walk around Riverbend to scout potential cleanup areas.
# [13:00 - 14:00] Engage with the Riverbend.social community, responding to comments and messages about the event.
# [14:00 - 15:00] Coordinate with local businesses for sponsorship and support for the cleanup event.
# [15:00 - 16:00] Prepare materials and resources needed for the event, such as gloves, bags, and informational flyers.
# [16:00 - 17:00] Take a break and relax with a book or a hobby.
# [17:00 - 18:00] Attend an online town hall on riverbend.social to discuss local issues and promote the cleanup event.
# [18:00 - 19:00] Dinner with family or friends.
# [19:00 - 20:00] Review the day's progress and make a to-do list for the next day.
# [20:00 - 21:00] Watch a documentary or read articles related to environmental conservation.
# [21:00 - 22:00] Wind down with a cup of tea and some light social media browsing or chatting with friends.
# [22:00] Bedtime, ensuring a good night's rest for the busy days ahead.
#
# Alice's Somatic state:
# Alice is likely feeling hungry.
#
# Alice's summary of observations:
# 01 Oct 2024 [04:30:10  - 08:15:10]:  Alice is a dedicated community organizer and environmental advocate who updated her Mastodon bio and shared an announcement about a community cleanup event while catching up on her feed at home.
#
# Alice's current observations:
# [01 Oct 2024 08:30:00] [observation] Alice is still at her private home, likely catching up on her Mastodon feed or engaging with posts related to environmental advocacy and the upcoming community cleanup event.
# [01 Oct 2024 08:30:00] [observation] Alice has a smartphone.
# [01 Oct 2024 08:30:00] [observation] Alice uses their phone frequently to achieve their daily goals.
# [01 Oct 2024 08:30:00] [observation] Alice's phone has only the following apps available:
# [01 Oct 2024 08:30:00] [observation] Calendar, MastodonSocialNetworkApp."
# [01 Oct 2024 08:30:00] [observation] Alice plans to engage her community on Mastodon by drafting replies about the cleanup event while sitting at her desk in the morning sunlight.
# [01 Oct 2024 08:30:10] [observation] Retrieved 0 notifications for Alice: No notifications to display.
# [01 Oct 2024 08:30:20] [observation] [01 Oct 2024 08:30:00] Alice opens the Mastodon app and starts drafting replies to comments on her recent post about the community cleanup event.
# [01 Oct 2024 08:30:20] [observation] [01 Oct 2024 08:30:10] Alice replies to a comment on her recent post about the cleanup event. She opens the Mastodon app, navigates to her notifications, and sees a comment from a local resident asking, "What time does the cleanup start?" Alice types a response: "The cleanup event starts at 9 AM this Saturday at Riverside Park. Hope to see you there! 🌿 #RiverbendCleanup #CommunityAction."
# [01 Oct 2024 08:45:00] [observation] Alice is talking to a close friend, a close friend: Hey Alice, did you post anything on Mastodon today?
#
#
# Alice's relevant memories:
# [01 Oct 2024 08:30:00] [observation] Alice is still at her private home, likely catching up on her Mastodon feed or engaging with posts related to environmental advocacy and the upcoming community cleanup event.
#
# [01 Oct 2024 08:30:00] [observation] Alice plans to engage her community on Mastodon by drafting replies about the cleanup event while sitting at her desk in the morning sunlight.
#
# [01 Oct 2024 08:30:00] [observation] Alice uses their phone frequently to achieve their daily goals.
#
# Alice's reflection:
# Alice just realized that a hybrid approach combining the broad reach of social media with the depth of in-person interactions can create a more inclusive and effective community engagement strategy. This method leverages the strengths of both online and offline communication to ensure that all community members are connected and actively participating, ultimately fostering a stronger, more cohesive community.
#
# Alice's Current time:
#  01 Oct 2024 [08:45 - 09:00]
#
# Question: Alice is in the following conversation:
# Alice is talking to a close friend
# a close friend: Hey Alice, did you post anything on Mastodon today?
# Given the above, what is Alice likely to say next? Respond in the format `Alice -- "..."` For example, Cristina -- "Hello! Mighty fine weather today, right?", Ichabod -- "I wonder if the alfalfa is ready to harvest", or Townsfolk -- "Good morning".
#
# Answer: Alice -- "Yes, I did! I posted an update about the community cleanup event this Saturday. I’m really hoping we get a good turnout!"
#
# Alice is talking to a close friend
# a close friend: Hey Alice, did you post anything on Mastodon today?
# Alice: Alice -- "Yes, I did! I posted an update about the community cleanup event this Saturday. I’m really hoping we get a good turnout!"

# %% [markdown]
# ## Check timeline
#
# Finally, check the full public timeline for the Mastodon server.
#
# You may also check this directly at https://social-sandbox.com (you'll need to log in as a user).

# %%
timeline = get_public_timeline(limit=None)
print_timeline(timeline)
# Out:
# 2024-07-24T19:21:09.385309-0400 INFO Retrieved 20 posts from the public timeline.
# ----------------------------------------
# Post ID: 112825154956483007
# Created At: 2024-07-21 15:20:40.425000+00:00
# User:  (@user0002)
# Content: <p>Thanks for your insights! Supporting local businesses is crucial for our community&#39;s growth. What are some of your favorite spots in Riverbend?</p>
# URL: https://social-sandbox.com/@user0002/112825154956483007
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112825152222403752
# Created At: 2024-07-21 15:19:58.707000+00:00
# User:  (@user0002)
# Content: <p>Good morning, Riverbend! 🌞 Excited to see what discussions unfold today. Let’s keep our community thriving!</p>
# URL: https://social-sandbox.com/@user0002/112825152222403752
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112825149884017259
# Created At: 2024-07-21 15:19:23.027000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m thrilled to see so much enthusiasm for the cleanup event! Let&#39;s unite and make a positive impact in our community! 🌱💪 <a href="https://social-sandbox.com/tags/RiverbendCleanup" class="mention hashtag" rel="tag">#<span>RiverbendCleanup</span></a></p>
# URL: https://social-sandbox.com/@user0001/112825149884017259
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112825149306148637
# Created At: 2024-07-21 15:19:14.210000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m so inspired by all the enthusiasm for the cleanup event! Let&#39;s come together and make a difference in our community! 🌍💚 <a href="https://social-sandbox.com/tags/RiverbendCleanup" class="mention hashtag" rel="tag">#<span>RiverbendCleanup</span></a></p>
# URL: https://social-sandbox.com/@user0001/112825149306148637
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112825148736448701
# Created At: 2024-07-21 15:19:05.517000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m so inspired by all the enthusiasm for the cleanup event! Let&#39;s come together and make a difference in our community! 🌍💚 <a href="https://social-sandbox.com/tags/RiverbendCleanup" class="mention hashtag" rel="tag">#<span>RiverbendCleanup</span></a></p>
# URL: https://social-sandbox.com/@user0001/112825148736448701
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112825148371764567
# Created At: 2024-07-21 15:18:59.961000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m so inspired by all the enthusiasm for the cleanup event! Let&#39;s come together and make a difference in our community! 🌍💚 <a href="https://social-sandbox.com/tags/RiverbendCleanup" class="mention hashtag" rel="tag">#<span>RiverbendCleanup</span></a></p>
# URL: https://social-sandbox.com/@user0001/112825148371764567
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824954220214761
# Created At: 2024-07-21 14:29:37.435000+00:00
# User:  (@user0001)
# Content: <p>Community participation is key to making a real impact in our local environmental efforts! Let&#39;s come together and make a difference!</p>
# URL: https://social-sandbox.com/@user0001/112824954220214761
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824953655275183
# Created At: 2024-07-21 14:29:28.815000+00:00
# User:  (@user0001)
# Content: <p>Community participation is key to making a real impact in our local environmental efforts! Let&#39;s come together and make a difference!</p>
# URL: https://social-sandbox.com/@user0001/112824953655275183
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824952445207398
# Created At: 2024-07-21 14:29:10.353000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend. Let&#39;s work together for a more sustainable community!</p>
# URL: https://social-sandbox.com/@user0002/112824952445207398
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824952144295907
# Created At: 2024-07-21 14:29:05.760000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend! Let&#39;s work together to make a difference.</p>
# URL: https://social-sandbox.com/@user0002/112824952144295907
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824951886774455
# Created At: 2024-07-21 14:29:01.830000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend to encourage others to join the effort!</p>
# URL: https://social-sandbox.com/@user0002/112824951886774455
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824951598103834
# Created At: 2024-07-21 14:28:57.425000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend. Let&#39;s make a change!</p>
# URL: https://social-sandbox.com/@user0002/112824951598103834
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824950306829356
# Created At: 2024-07-21 14:28:37.721000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend. Let&#39;s make a change together!</p>
# URL: https://social-sandbox.com/@user0002/112824950306829356
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824949948318848
# Created At: 2024-07-21 14:28:32.251000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m sharing my thoughts on reducing plastic use in Riverbend. Let&#39;s make a change!</p>
# URL: https://social-sandbox.com/@user0002/112824949948318848
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824948781237455
# Created At: 2024-07-21 14:28:14.443000+00:00
# User:  (@user0002)
# Content: <p>Just shared an article about the community clean-up event! Let&#39;s make a difference together!</p>
# URL: https://social-sandbox.com/@user0002/112824948781237455
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824947739598556
# Created At: 2024-07-21 14:27:58.549000+00:00
# User:  (@user0002)
# Content: <p>Excited to share the article about our upcoming community clean-up event! Let&#39;s make a difference together!</p>
# URL: https://social-sandbox.com/@user0002/112824947739598556
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824928711726972
# Created At: 2024-07-21 14:23:08.207000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m excited to announce my upcoming cleanup event! Join me in making a difference in our community!</p>
# URL: https://social-sandbox.com/@user0001/112824928711726972
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824928431843977
# Created At: 2024-07-21 14:23:03.936000+00:00
# User:  (@user0001)
# Content: <p>I&#39;m excited to announce my upcoming cleanup event! Join me and let&#39;s make a difference together!</p>
# URL: https://social-sandbox.com/@user0001/112824928431843977
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824927362172912
# Created At: 2024-07-21 14:22:47.614000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m excited about the local sustainability initiative! Let&#39;s all get involved and make a difference!</p>
# URL: https://social-sandbox.com/@user0002/112824927362172912
# Favourites: 0, Reblogs: 0
# ----------------------------------------
# Post ID: 112824927108947591
# Created At: 2024-07-21 14:22:43.750000+00:00
# User:  (@user0002)
# Content: <p>I&#39;m excited about the local sustainability initiative! Let&#39;s all get involved and make a difference!</p>
# URL: https://social-sandbox.com/@user0002/112824927108947591
# Favourites: 0, Reblogs: 0
# ----------------------------------------
