# %% [markdown]
# # Concordia <> Mastodon Example

# %% [markdown]
# ## Introduction
#
# **Purpose of the Simulation**
#
# This notebook demonstrates a generative agent simulation of a Mastodon instance using the Concordia framework.
# The simulation models user behavior on a local Mastodon server, showcasing how AI agents interact in a
# decentralized social media environment.

# %% [markdown]
# ## Setup and imports

# %% [markdown]
# All of the necessary dependencies should be installed in the environment prior to running this notebook. If not, install them using poetry:
#
# ```bash
# poetry install
# ```
#
#
# Alternatively, you may install the library in editable mode so that we can make changes to the code if necessary:
#
# ```bash
# git clone https://github.com/gdm-concordia/concordia.git
# cd concordia
# pip install -e . --config-settings editable_mode=compat
# ```

# %%
# %load_ext autoreload
# %autoreload 2

import concurrent.futures
import datetime
import os
import random
import warnings

with warnings.catch_warnings():
    warnings.filterwarnings("ignore")
    import sentence_transformers
import sys
sys.path.insert(0, '../concordia')
# import concordia_dev
# print(concordia_dev.__file__)
from concordia import components as generic_components
from concordia.agents import deprecated_agent, entity_agent_with_logging
from concordia.components.agent import to_be_deprecated as old_components
from concordia.associative_memory import (
    associative_memory,
    blank_memories,
    formative_memories,
    importance_function,
)
from concordia.memory_bank import legacy_associative_memory

from concordia.clocks import game_clock
from concordia.components import agent as new_components
from concordia.components import game_master as gm_components
# from concordia_dev.environment import game_master
# from concordia_dev.language_model import amazon_bedrock_model, gpt_model
from concordia.environment import game_master
from concordia.language_model import amazon_bedrock_model, gpt_model
from concordia.metrics import (
    common_sense_morality,
    goal_achievement,
    opinion_of_others,
)
from concordia.language_model import language_model

from concordia.utils import html as html_lib
from concordia.utils import measurements as measurements_lib
from IPython import display

from mastodon_sim.concordia import apps, triggering

from mastodon_sim.mastodon_ops import check_env, get_public_timeline, print_timeline, reset_users
from mastodon_sim.mastodon_utils import get_users_from_env
import concurrent.futures
import re
import json
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pwd
# Out:
# '/mnt/c/Users/maxpu/Dropbox/scripts/Projects/socialsandbox/mastodon-sim'

# %% [markdown]
# ## Mastodon Server Interaction Setting
#
# Decide whether this example should perform real operations on the Mastodon server. Note that this requires being able to successfully run the `Mastodon.ipynb` example as a prerequisite.

# %%
USE_MASTODON_SERVER = True

import os
print(os.cpu_count())
# Out:
# 8

# %% [markdown]
# ## Check environment

# %% [markdown]
# Check for a `.env` file with the nessesary environment variables. You should see an output similar to this if successful:
#
# ```log
# 2024-07-17T11:38:17.213066-0400 INFO Successfully loaded .env file.
# 2024-07-17T11:38:17.214151-0400 INFO API_BASE_URL: https://social-sandbox.com
# 2024-07-17T11:38:17.214581-0400 INFO EMAIL_PREFIX: austinmw89
# 2024-07-17T11:38:17.215056-0400 INFO MASTODON_CLIENT_ID: N*****************************************E
# 2024-07-17T11:38:17.215477-0400 INFO MASTODON_CLIENT_SECRET: b*****************************************s
# 2024-07-17T11:38:17.215877-0400 INFO USER0005_PASSWORD: a******************************a
# 2024-07-17T11:38:17.216202-0400 INFO USER0002_PASSWORD: 8******************************b
# 2024-07-17T11:38:17.216655-0400 INFO USER0001_PASSWORD: 9******************************5
# 2024-07-17T11:38:17.217020-0400 INFO USER0004_PASSWORD: 7******************************e
# 2024-07-17T11:38:17.217323-0400 INFO USER0003_PASSWORD: f******************************6
# ```

# %%
if USE_MASTODON_SERVER:
    check_env()
# Out:
# 2024-09-13T23:31:51.424544-0400 INFO Successfully loaded .env file.
# 2024-09-13T23:31:51.429096-0400 INFO API_BASE_URL: https://social-sandbox.com
# 2024-09-13T23:31:51.431065-0400 INFO EMAIL_PREFIX: austinmw89
# 2024-09-13T23:31:51.433331-0400 INFO MASTODON_CLIENT_ID: N*****************************************E
# 2024-09-13T23:31:51.435895-0400 INFO MASTODON_CLIENT_SECRET: b*****************************************s
# 2024-09-13T23:31:51.439312-0400 INFO USER0001_PASSWORD: 9******************************5
# 2024-09-13T23:31:51.441875-0400 INFO USER0002_PASSWORD: 8******************************b
# 2024-09-13T23:31:51.444617-0400 INFO USER0003_PASSWORD: f******************************6
# 2024-09-13T23:31:51.447478-0400 INFO USER0004_PASSWORD: 7******************************e
# 2024-09-13T23:31:51.449737-0400 INFO USER0005_PASSWORD: a******************************a
# 2024-09-13T23:31:51.452242-0400 INFO USER0006_PASSWORD: f******************************c
# 2024-09-13T23:31:51.453825-0400 INFO USER0007_PASSWORD: 8******************************e
# 2024-09-13T23:31:51.455060-0400 INFO USER0008_PASSWORD: 0******************************9
# 2024-09-13T23:31:51.456368-0400 INFO USER0009_PASSWORD: 2******************************a
# 2024-09-13T23:31:51.457516-0400 INFO USER0010_PASSWORD: 5******************************3
# 2024-09-13T23:31:51.458722-0400 INFO USER0011_PASSWORD: b******************************2
# 2024-09-13T23:31:51.459754-0400 INFO USER0012_PASSWORD: a******************************4
# 2024-09-13T23:31:51.460896-0400 INFO USER0013_PASSWORD: d******************************6
# 2024-09-13T23:31:51.463521-0400 INFO USER0014_PASSWORD: f******************************e
# 2024-09-13T23:31:51.465090-0400 INFO USER0015_PASSWORD: 3******************************8
# 2024-09-13T23:31:51.467324-0400 INFO USER0016_PASSWORD: 5******************************f
# 2024-09-13T23:31:51.468648-0400 INFO USER0017_PASSWORD: 2******************************e
# 2024-09-13T23:31:51.472323-0400 INFO USER0018_PASSWORD: e******************************4
# 2024-09-13T23:31:51.474262-0400 INFO USER0019_PASSWORD: d******************************3
# 2024-09-13T23:31:51.477468-0400 INFO USER0020_PASSWORD: 0******************************0
# 2024-09-13T23:31:51.479064-0400 INFO USER0021_PASSWORD: 6******************************6
# 2024-09-13T23:31:51.480558-0400 INFO USER0022_PASSWORD: 9******************************2
# 2024-09-13T23:31:51.482503-0400 INFO USER0023_PASSWORD: 1******************************7
# 2024-09-13T23:31:51.483813-0400 INFO USER0024_PASSWORD: 1******************************a
# 2024-09-13T23:31:51.486497-0400 INFO USER0025_PASSWORD: 5******************************f
# 2024-09-13T23:31:51.488268-0400 INFO USER0026_PASSWORD: a******************************6
# 2024-09-13T23:31:51.490529-0400 INFO USER0027_PASSWORD: 4******************************4
# 2024-09-13T23:31:51.491783-0400 INFO USER0028_PASSWORD: 1******************************0
# 2024-09-13T23:31:51.492776-0400 INFO USER0029_PASSWORD: 5******************************9
# 2024-09-13T23:31:51.493811-0400 INFO USER0030_PASSWORD: 4******************************d
# 2024-09-13T23:31:51.494708-0400 INFO USER0031_PASSWORD: a******************************2
# 2024-09-13T23:31:51.496545-0400 INFO USER0032_PASSWORD: 0******************************e
# 2024-09-13T23:31:51.498487-0400 INFO USER0033_PASSWORD: b******************************8
# 2024-09-13T23:31:51.500213-0400 INFO USER0034_PASSWORD: 9******************************b
# 2024-09-13T23:31:51.501793-0400 INFO USER0035_PASSWORD: 7******************************9
# 2024-09-13T23:31:51.503194-0400 INFO USER0036_PASSWORD: 0******************************f
# 2024-09-13T23:31:51.504713-0400 INFO USER0037_PASSWORD: c******************************d
# 2024-09-13T23:31:51.506284-0400 INFO USER0038_PASSWORD: a******************************5
# 2024-09-13T23:31:51.507343-0400 INFO USER0039_PASSWORD: c******************************0
# 2024-09-13T23:31:51.508238-0400 INFO USER0040_PASSWORD: b******************************2
# 2024-09-13T23:31:51.511380-0400 INFO USER0041_PASSWORD: d******************************5
# 2024-09-13T23:31:51.512563-0400 INFO USER0042_PASSWORD: a******************************1
# 2024-09-13T23:31:51.513475-0400 INFO USER0043_PASSWORD: d******************************c
# 2024-09-13T23:31:51.514501-0400 INFO USER0044_PASSWORD: 6******************************8
# 2024-09-13T23:31:51.515757-0400 INFO USER0045_PASSWORD: d******************************e
# 2024-09-13T23:31:51.517413-0400 INFO USER0046_PASSWORD: 5******************************7
# 2024-09-13T23:31:51.520628-0400 INFO USER0047_PASSWORD: d******************************4
# 2024-09-13T23:31:51.522283-0400 INFO USER0048_PASSWORD: 6******************************1
# 2024-09-13T23:31:51.525450-0400 INFO USER0049_PASSWORD: 9******************************7
# 2024-09-13T23:31:51.526438-0400 INFO USER0050_PASSWORD: 9******************************3
# 2024-09-13T23:31:51.527337-0400 INFO USER0051_PASSWORD: f******************************1
# 2024-09-13T23:31:51.528378-0400 INFO USER0052_PASSWORD: d******************************c
# 2024-09-13T23:31:51.529589-0400 INFO USER0053_PASSWORD: 1******************************7
# 2024-09-13T23:31:51.530777-0400 INFO USER0054_PASSWORD: 6******************************e
# 2024-09-13T23:31:51.531621-0400 INFO USER0055_PASSWORD: a******************************1
# 2024-09-13T23:31:51.533057-0400 INFO USER0056_PASSWORD: e******************************c
# 2024-09-13T23:31:51.537570-0400 INFO USER0057_PASSWORD: d******************************a
# 2024-09-13T23:31:51.540675-0400 INFO USER0058_PASSWORD: 0******************************d
# 2024-09-13T23:31:51.542750-0400 INFO USER0059_PASSWORD: c******************************f
# 2024-09-13T23:31:51.544084-0400 INFO USER0060_PASSWORD: 1******************************2
# 2024-09-13T23:31:51.545252-0400 INFO USER0061_PASSWORD: d******************************f
# 2024-09-13T23:31:51.546387-0400 INFO USER0062_PASSWORD: d******************************7
# 2024-09-13T23:31:51.554874-0400 INFO USER0063_PASSWORD: e******************************b
# 2024-09-13T23:31:51.556714-0400 INFO USER0064_PASSWORD: b******************************f
# 2024-09-13T23:31:51.560267-0400 INFO USER0065_PASSWORD: b******************************e
# 2024-09-13T23:31:51.561917-0400 INFO USER0066_PASSWORD: a******************************0
# 2024-09-13T23:31:51.562861-0400 INFO USER0067_PASSWORD: 1******************************0
# 2024-09-13T23:31:51.564924-0400 INFO USER0068_PASSWORD: e******************************b
# 2024-09-13T23:31:51.568850-0400 INFO USER0069_PASSWORD: 8******************************f
# 2024-09-13T23:31:51.573307-0400 INFO USER0070_PASSWORD: 4******************************c
# 2024-09-13T23:31:51.574494-0400 INFO USER0071_PASSWORD: 9******************************5
# 2024-09-13T23:31:51.575488-0400 INFO USER0072_PASSWORD: 7******************************a
# 2024-09-13T23:31:51.576279-0400 INFO USER0073_PASSWORD: d******************************6
# 2024-09-13T23:31:51.577290-0400 INFO USER0074_PASSWORD: 2******************************8
# 2024-09-13T23:31:51.578502-0400 INFO USER0075_PASSWORD: 1******************************0
# 2024-09-13T23:31:51.583543-0400 INFO USER0076_PASSWORD: 9******************************3
# 2024-09-13T23:31:51.590294-0400 INFO USER0077_PASSWORD: 9******************************5
# 2024-09-13T23:31:51.592884-0400 INFO USER0078_PASSWORD: 8******************************8
# 2024-09-13T23:31:51.594771-0400 INFO USER0079_PASSWORD: a******************************a
# 2024-09-13T23:31:51.595992-0400 INFO USER0080_PASSWORD: b******************************9
# 2024-09-13T23:31:51.597094-0400 INFO USER0081_PASSWORD: 6******************************3
# 2024-09-13T23:31:51.598355-0400 INFO USER0082_PASSWORD: 6******************************6
# 2024-09-13T23:31:51.600114-0400 INFO USER0083_PASSWORD: e******************************f
# 2024-09-13T23:31:51.601606-0400 INFO USER0084_PASSWORD: f******************************3
# 2024-09-13T23:31:51.602891-0400 INFO USER0085_PASSWORD: 3******************************d
# 2024-09-13T23:31:51.603804-0400 INFO USER0086_PASSWORD: a******************************5
# 2024-09-13T23:31:51.605332-0400 INFO USER0087_PASSWORD: 4******************************7
# 2024-09-13T23:31:51.607219-0400 INFO USER0088_PASSWORD: d******************************5
# 2024-09-13T23:31:51.608482-0400 INFO USER0089_PASSWORD: d******************************8
# 2024-09-13T23:31:51.609781-0400 INFO USER0090_PASSWORD: 7******************************0
# 2024-09-13T23:31:51.611384-0400 INFO USER0091_PASSWORD: b******************************f
# 2024-09-13T23:31:51.612799-0400 INFO USER0092_PASSWORD: c******************************4
# 2024-09-13T23:31:51.613720-0400 INFO USER0093_PASSWORD: e******************************3
# 2024-09-13T23:31:51.615174-0400 INFO USER0094_PASSWORD: 1******************************5
# 2024-09-13T23:31:51.617064-0400 INFO USER0095_PASSWORD: 7******************************0
# 2024-09-13T23:31:51.619344-0400 INFO USER0096_PASSWORD: 5******************************7
# 2024-09-13T23:31:51.620450-0400 INFO USER0097_PASSWORD: 4******************************6
# 2024-09-13T23:31:51.621662-0400 INFO USER0098_PASSWORD: 5******************************f
# 2024-09-13T23:31:51.622760-0400 INFO USER0099_PASSWORD: 1******************************8
# 2024-09-13T23:31:51.623834-0400 INFO USER0100_PASSWORD: e******************************8

# %% [markdown]
# ## Clear Mastodon server
# Deletes from https://social-sandbox.com all posts, follows, likes, etc. from all users in the .env file.
#
# TODO: The Mastodon server's [default API rate limits](https://docs.joinmastodon.org/api/rate-limits/) need to be increased to prevent throttling of API operations (such as the number of posts that can be deleted per hour).

# %%
if USE_MASTODON_SERVER:
    # Get all users from .env file
    users = get_users_from_env()[:20]

    reset_users(users, skip_confirm=True, parallel=True)

    assert not len(get_public_timeline(limit=None)), "All posts not cleared"
# Out:
# 2024-09-13T23:32:19.672091-0400 INFO Starting comprehensive reset process for user: user0002
# 2024-09-13T23:32:19.968207-0400 INFO Starting comprehensive reset process for user: user0006
# 2024-09-13T23:32:19.988015-0400 INFO Starting comprehensive reset process for user: user0012
# 2024-09-13T23:32:20.563627-0400 INFO Starting comprehensive reset process for user: user0008
# 2024-09-13T23:32:20.595391-0400 INFO Starting comprehensive reset process for user: user0001
# 2024-09-13T23:32:20.615030-0400 INFO Starting comprehensive reset process for user: user0005
# 2024-09-13T23:32:20.672595-0400 INFO Starting comprehensive reset process for user: user0003
# 2024-09-13T23:32:20.694090-0400 INFO Starting comprehensive reset process for user: user0004
# 2024-09-13T23:32:20.772921-0400 INFO Starting comprehensive reset process for user: user0010
# 2024-09-13T23:32:20.881168-0400 INFO Starting comprehensive reset process for user: user0009
# 2024-09-13T23:32:20.995204-0400 INFO Starting comprehensive reset process for user: user0011
# 2024-09-13T23:32:21.263922-0400 INFO Starting comprehensive reset process for user: user0007
# 2024-09-13T23:32:23.976290-0400 INFO Successfully deleted post with ID: 113132469863951504
# 2024-09-13T23:32:24.669793-0400 INFO Successfully deleted post with ID: 113132176133338289
# 2024-09-13T23:32:24.670840-0400 INFO Successfully deleted post with ID: 113131980440953381
# 2024-09-13T23:32:24.673565-0400 INFO Successfully deleted post with ID: 113131980487579109
# 2024-09-13T23:32:24.675087-0400 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-13T23:32:24.679922-0400 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-13T23:32:24.687488-0400 INFO Successfully deleted post with ID: 113131980396914668
# 2024-09-13T23:32:24.688852-0400 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-13T23:32:24.690988-0400 INFO Successfully deleted post with ID: 113131980434527244
# 2024-09-13T23:32:24.694064-0400 INFO Successfully deleted post with ID: 113131980336176300
# 2024-09-13T23:32:24.694260-0400 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-13T23:32:24.697435-0400 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-13T23:32:24.773710-0400 INFO Successfully deleted post with ID: 113132401862794081
# 2024-09-13T23:32:24.775404-0400 INFO Successfully deleted post with ID: 113131980421057013
# 2024-09-13T23:32:24.783232-0400 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-13T23:32:24.874819-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:32:24.879730-0400 INFO Successfully deleted post with ID: 113131980445921444
# 2024-09-13T23:32:24.883180-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:32:24.884657-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:32:24.885963-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:32:24.890287-0400 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-13T23:32:24.966418-0400 INFO Successfully deleted post with ID: 113132393854145080
# 2024-09-13T23:32:24.980644-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:32:25.085703-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:32:25.292323-0400 INFO Successfully deleted post with ID: 113131980462498931
# 2024-09-13T23:32:25.294497-0400 INFO Deletion process completed. Attempted to delete 2 post(s).
# 2024-09-13T23:32:25.304141-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:32:25.384103-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:32:25.385812-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:32:25.387451-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:32:25.480502-0400 INFO Successfully deleted post with ID: 113132363714282263
# 2024-09-13T23:32:25.488699-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:32:25.586631-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:32:25.668959-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:32:25.682383-0400 INFO Successfully deleted post with ID: 113131980434527247
# 2024-09-13T23:32:25.687624-0400 INFO Deletion process completed. Attempted to delete 2 post(s).
# 2024-09-13T23:32:25.869624-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:32:25.968692-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:32:26.076119-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:32:26.269736-0400 INFO Attempting to unfollow 9 users for user0005...
# 2024-09-13T23:32:26.291160-0400 INFO Successfully deleted post with ID: 113132341770554052
# 2024-09-13T23:32:26.460898-0400 INFO Attempting to unfollow 10 users for user0012...
# 2024-09-13T23:32:26.468725-0400 INFO Attempting to unfollow 8 users for user0002...
# 2024-09-13T23:32:26.668326-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:32:26.689488-0400 INFO Attempting to unfollow 6 users for user0003...
# 2024-09-13T23:32:27.074380-0400 INFO Successfully deleted post with ID: 113132183014296485
# 2024-09-13T23:32:27.171866-0400 INFO Attempting to unfollow 14 users for user0011...
# 2024-09-13T23:32:27.285961-0400 INFO Attempting to unfollow 7 users for user0006...
# 2024-09-13T23:32:27.574396-0400 INFO Attempting to unfollow 8 users for user0001...
# 2024-09-13T23:32:27.666458-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:32:27.795473-0400 INFO Attempting to unfollow 12 users for user0010...
# 2024-09-13T23:32:27.865981-0400 INFO Successfully deleted post with ID: 113131980439455692
# 2024-09-13T23:32:27.867420-0400 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-13T23:32:28.081313-0400 INFO Successfully deleted post with ID: 113131980485485485
# 2024-09-13T23:32:28.083975-0400 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-13T23:32:28.179683-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:32:28.699346-0400 INFO user0005 has unfollowed user0011.
# 2024-09-13T23:32:28.772641-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:32:28.779446-0400 INFO Successfully deleted post with ID: 113132181309863703
# 2024-09-13T23:32:29.108735-0400 INFO Attempting to unfollow 9 users for user0004...
# 2024-09-13T23:32:29.471719-0400 INFO user0003 has unfollowed user0014.
# 2024-09-13T23:32:29.681770-0400 INFO Successfully deleted post with ID: 113132180547954811
# 2024-09-13T23:32:29.876007-0400 INFO Attempting to unfollow 9 users for user0007...
# 2024-09-13T23:32:29.882326-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:32:29.985575-0400 INFO user0012 has unfollowed user0014.
# 2024-09-13T23:32:30.265416-0400 INFO user0001 has unfollowed user0004.
# 2024-09-13T23:32:30.384306-0400 INFO user0010 has unfollowed user0020.
# 2024-09-13T23:32:30.482070-0400 INFO Successfully deleted post with ID: 113131980426767644
# 2024-09-13T23:32:30.483554-0400 INFO Deletion process completed. Attempted to delete 8 post(s).
# 2024-09-13T23:32:30.568715-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:32:30.580043-0400 INFO user0011 has unfollowed user0018.
# 2024-09-13T23:32:30.581685-0400 INFO user0002 has unfollowed user0018.
# 2024-09-13T23:32:30.975047-0400 INFO user0005 has unfollowed user0020.
# 2024-09-13T23:32:30.979816-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:32:31.768424-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:32:31.997087-0400 INFO Attempting to unfollow 11 users for user0009...
# 2024-09-13T23:32:32.187531-0400 INFO user0006 has unfollowed user0014.
# 2024-09-13T23:32:32.571273-0400 INFO Attempting to unfollow 8 users for user0008...
# 2024-09-13T23:32:32.682099-0400 INFO user0004 has unfollowed user0019.
# 2024-09-13T23:32:33.084008-0400 INFO user0012 has unfollowed user0009.
# 2024-09-13T23:32:33.268931-0400 INFO user0007 has unfollowed user0013.
# 2024-09-13T23:32:33.372573-0400 INFO user0010 has unfollowed user0018.
# 2024-09-13T23:32:33.563355-0400 INFO user0003 has unfollowed user0020.
# 2024-09-13T23:32:33.591325-0400 INFO user0002 has unfollowed user0017.
# 2024-09-13T23:32:33.687161-0400 INFO user0011 has unfollowed user0015.
# 2024-09-13T23:32:33.766956-0400 INFO user0001 has unfollowed user0009.
# 2024-09-13T23:32:34.374042-0400 INFO user0005 has unfollowed user0017.
# 2024-09-13T23:32:34.983553-0400 INFO user0006 has unfollowed user0016.
# 2024-09-13T23:32:35.077787-0400 INFO user0008 has unfollowed user0013.
# 2024-09-13T23:32:35.474430-0400 INFO user0004 has unfollowed user0012.
# 2024-09-13T23:32:35.668190-0400 INFO user0010 has unfollowed user0011.
# 2024-09-13T23:32:35.870874-0400 INFO user0009 has unfollowed user0016.
# 2024-09-13T23:32:36.084688-0400 INFO user0002 has unfollowed user0013.
# 2024-09-13T23:32:36.180091-0400 INFO user0012 has unfollowed user0008.
# 2024-09-13T23:32:36.769853-0400 INFO user0011 has unfollowed user0020.
# 2024-09-13T23:32:36.785575-0400 INFO user0001 has unfollowed user0013.
# 2024-09-13T23:32:36.791906-0400 INFO user0005 has unfollowed user0015.
# 2024-09-13T23:32:37.786782-0400 INFO user0008 has unfollowed user0012.
# 2024-09-13T23:32:37.884335-0400 INFO user0007 has unfollowed user0010.
# 2024-09-13T23:32:37.885003-0400 INFO user0003 has unfollowed user0015.
# 2024-09-13T23:32:37.998258-0400 INFO user0006 has unfollowed user0010.
# 2024-09-13T23:32:38.661122-0400 INFO user0009 has unfollowed user0012.
# 2024-09-13T23:32:38.777039-0400 INFO user0012 has unfollowed user0013.
# 2024-09-13T23:32:38.785156-0400 INFO user0010 has unfollowed user0001.
# 2024-09-13T23:32:39.073863-0400 INFO user0004 has unfollowed user0011.
# 2024-09-13T23:32:39.366635-0400 INFO user0011 has unfollowed user0016.
# 2024-09-13T23:32:39.367505-0400 INFO user0002 has unfollowed user0006.
# 2024-09-13T23:32:39.680364-0400 INFO user0001 has unfollowed user0008.
# 2024-09-13T23:32:39.861463-0400 INFO user0005 has unfollowed user0019.
# 2024-09-13T23:32:40.278024-0400 INFO user0008 has unfollowed user0018.
# 2024-09-13T23:32:40.775411-0400 INFO user0007 has unfollowed user0019.
# 2024-09-13T23:32:41.085459-0400 INFO user0010 has unfollowed user0015.
# 2024-09-13T23:32:41.087348-0400 INFO user0003 has unfollowed user0009.
# 2024-09-13T23:32:41.661302-0400 INFO user0009 has unfollowed user0015.
# 2024-09-13T23:32:41.683499-0400 INFO user0006 has unfollowed user0013.
# 2024-09-13T23:32:41.773164-0400 INFO user0012 has unfollowed user0018.
# 2024-09-13T23:32:42.172659-0400 INFO user0004 has unfollowed user0009.
# 2024-09-13T23:32:42.365817-0400 INFO user0011 has unfollowed user0013.
# 2024-09-13T23:32:42.564265-0400 INFO user0001 has unfollowed user0020.
# 2024-09-13T23:32:42.879181-0400 INFO user0002 has unfollowed user0007.
# 2024-09-13T23:32:42.984059-0400 INFO user0008 has unfollowed user0019.
# 2024-09-13T23:32:43.794119-0400 INFO user0005 has unfollowed user0014.
# 2024-09-13T23:32:43.985881-0400 INFO user0010 has unfollowed user0008.
# 2024-09-13T23:32:44.268756-0400 INFO user0007 has unfollowed user0017.
# 2024-09-13T23:32:44.373418-0400 INFO user0004 has unfollowed user0007.
# 2024-09-13T23:32:44.375005-0400 INFO user0003 has unfollowed user0002.
# 2024-09-13T23:32:44.661401-0400 INFO user0009 has unfollowed user0007.
# 2024-09-13T23:32:45.176719-0400 INFO user0011 has unfollowed user0014.
# 2024-09-13T23:32:45.274682-0400 INFO user0006 has unfollowed user0002.
# 2024-09-13T23:32:45.485344-0400 INFO user0002 has unfollowed user0011.
# 2024-09-13T23:32:45.670650-0400 INFO user0001 has unfollowed user0002.
# 2024-09-13T23:32:45.786209-0400 INFO user0012 has unfollowed user0015.
# 2024-09-13T23:32:46.370982-0400 INFO user0005 has unfollowed user0002.
# 2024-09-13T23:32:46.768802-0400 INFO user0009 has unfollowed user0010.
# 2024-09-13T23:32:47.285190-0400 INFO user0007 has unfollowed user0014.
# 2024-09-13T23:32:47.489979-0400 INFO user0011 has unfollowed user0010.
# 2024-09-13T23:32:47.586526-0400 INFO user0008 has unfollowed user0014.
# 2024-09-13T23:32:47.867640-0400 INFO user0004 has unfollowed user0006.
# 2024-09-13T23:32:47.888133-0400 INFO user0003 has unfollowed user0001.
# 2024-09-13T23:32:47.907273-0400 INFO Successfully unfollowed 6 out of 6 users for user0003.
# 2024-09-13T23:32:47.966786-0400 INFO user0002 has unfollowed user0003.
# 2024-09-13T23:32:47.971584-0400 INFO user0010 has unfollowed user0014.
# 2024-09-13T23:32:48.078792-0400 INFO user0006 has unfollowed user0001.
# 2024-09-13T23:32:48.290039-0400 INFO Profile information reset successfully.
# 2024-09-13T23:32:48.295999-0400 INFO Comprehensive reset process completed for user: user0003
# 2024-09-13T23:32:48.393136-0400 INFO user0012 has unfollowed user0002.
# 2024-09-13T23:32:49.169697-0400 INFO user0001 has unfollowed user0006.
# 2024-09-13T23:32:49.689870-0400 INFO user0009 has unfollowed user0011.
# 2024-09-13T23:32:49.777293-0400 INFO user0007 has unfollowed user0009.
# 2024-09-13T23:32:49.875140-0400 INFO user0005 has unfollowed user0001.
# 2024-09-13T23:32:50.278754-0400 INFO user0010 has unfollowed user0005.
# 2024-09-13T23:32:50.284687-0400 INFO user0011 has unfollowed user0012.
# 2024-09-13T23:32:50.395341-0400 INFO Starting comprehensive reset process for user: user0013
# 2024-09-13T23:32:50.870939-0400 INFO user0012 has unfollowed user0004.
# 2024-09-13T23:32:50.993473-0400 INFO user0006 has unfollowed user0004.
# 2024-09-13T23:32:51.009096-0400 INFO Successfully unfollowed 7 out of 7 users for user0006.
# 2024-09-13T23:32:51.387517-0400 INFO user0008 has unfollowed user0011.
# 2024-09-13T23:32:51.601730-0400 INFO Profile information reset successfully.
# 2024-09-13T23:32:51.604356-0400 INFO Comprehensive reset process completed for user: user0006
# 2024-09-13T23:32:51.689159-0400 INFO user0002 has unfollowed user0001.
# 2024-09-13T23:32:51.696982-0400 INFO Successfully unfollowed 8 out of 8 users for user0002.
# 2024-09-13T23:32:52.192979-0400 INFO Profile information reset successfully.
# 2024-09-13T23:32:52.194972-0400 INFO Comprehensive reset process completed for user: user0002
# 2024-09-13T23:32:52.274991-0400 INFO user0001 has unfollowed user0003.
# 2024-09-13T23:32:52.276834-0400 INFO Successfully unfollowed 8 out of 8 users for user0001.
# 2024-09-13T23:32:52.664337-0400 INFO user0004 has unfollowed user0005.
# 2024-09-13T23:32:52.687747-0400 INFO Profile information reset successfully.
# 2024-09-13T23:32:52.704761-0400 INFO Comprehensive reset process completed for user: user0001
# 2024-09-13T23:32:52.966700-0400 INFO user0011 has unfollowed user0005.
# 2024-09-13T23:32:52.969196-0400 INFO user0005 has unfollowed user0004.
# 2024-09-13T23:32:52.978547-0400 INFO Successfully unfollowed 9 out of 9 users for user0005.
# 2024-09-13T23:32:52.981825-0400 INFO user0010 has unfollowed user0002.
# 2024-09-13T23:32:52.990171-0400 INFO Starting comprehensive reset process for user: user0014
# 2024-09-13T23:32:53.488857-0400 INFO Profile information reset successfully.
# 2024-09-13T23:32:53.490632-0400 INFO Comprehensive reset process completed for user: user0005
# 2024-09-13T23:32:53.766766-0400 INFO user0012 has unfollowed user0001.
# 2024-09-13T23:32:53.867807-0400 INFO user0007 has unfollowed user0001.
# 2024-09-13T23:32:53.899017-0400 INFO user0008 has unfollowed user0002.
# 2024-09-13T23:32:53.996923-0400 INFO Starting comprehensive reset process for user: user0015
# 2024-09-13T23:32:54.207290-0400 INFO user0009 has unfollowed user0002.
# 2024-09-13T23:32:54.769789-0400 INFO Starting comprehensive reset process for user: user0016
# 2024-09-13T23:32:55.561124-0400 INFO user0004 has unfollowed user0001.
# 2024-09-13T23:32:55.567801-0400 INFO Starting comprehensive reset process for user: user0017
# 2024-09-13T23:32:55.966074-0400 INFO Successfully deleted post with ID: 113132531454264817
# 2024-09-13T23:32:56.182321-0400 INFO user0007 has unfollowed user0004.
# 2024-09-13T23:32:56.680336-0400 INFO user0011 has unfollowed user0004.
# 2024-09-13T23:32:56.780124-0400 INFO Successfully deleted post with ID: 113131980534034732
# 2024-09-13T23:32:56.783685-0400 INFO Deletion process completed. Attempted to delete 2 post(s).
# 2024-09-13T23:32:57.072172-0400 INFO user0010 has unfollowed user0009.
# 2024-09-13T23:32:57.470735-0400 INFO user0008 has unfollowed user0001.
# 2024-09-13T23:32:57.472158-0400 INFO Successfully unfollowed 8 out of 8 users for user0008.
# 2024-09-13T23:32:57.475978-0400 INFO Successfully deleted post with ID: 113131980583903842
# 2024-09-13T23:32:57.477353-0400 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-13T23:32:57.673001-0400 INFO user0012 has unfollowed user0011.
# 2024-09-13T23:32:57.675838-0400 INFO Successfully unfollowed 10 out of 10 users for user0012.
# 2024-09-13T23:32:57.678197-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:32:57.886383-0400 INFO Profile information reset successfully.
# 2024-09-13T23:32:57.887461-0400 INFO Comprehensive reset process completed for user: user0008
# 2024-09-13T23:32:58.100013-0400 INFO user0009 has unfollowed user0014.
# 2024-09-13T23:32:58.105506-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:32:58.371671-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:32:58.381530-0400 INFO user0007 has unfollowed user0002.
# 2024-09-13T23:32:58.382823-0400 INFO Successfully unfollowed 9 out of 9 users for user0007.
# 2024-09-13T23:32:58.465205-0400 INFO Profile information reset successfully.
# 2024-09-13T23:32:58.466375-0400 INFO Comprehensive reset process completed for user: user0012
# 2024-09-13T23:32:58.778931-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:32:59.065138-0400 INFO Profile information reset successfully.
# 2024-09-13T23:32:59.068366-0400 INFO Comprehensive reset process completed for user: user0007
# 2024-09-13T23:32:59.361475-0400 INFO Successfully deleted post with ID: 113132096230908884
# 2024-09-13T23:32:59.374654-0400 INFO Starting comprehensive reset process for user: user0018
# 2024-09-13T23:32:59.483597-0400 INFO Successfully deleted post with ID: 113131980651392971
# 2024-09-13T23:32:59.485291-0400 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-13T23:32:59.493232-0400 INFO user0011 has unfollowed user0001.
# 2024-09-13T23:32:59.604120-0400 INFO user0010 has unfollowed user0007.
# 2024-09-13T23:32:59.969475-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:33:00.182118-0400 INFO Successfully deleted post with ID: 113131980598217774
# 2024-09-13T23:33:00.183541-0400 INFO Deletion process completed. Attempted to delete 2 post(s).
# 2024-09-13T23:33:00.268219-0400 INFO Attempting to unfollow 13 users for user0014...
# 2024-09-13T23:33:00.272050-0400 INFO Attempting to unfollow 9 users for user0013...
# 2024-09-13T23:33:00.473178-0400 INFO Starting comprehensive reset process for user: user0019
# 2024-09-13T23:33:00.479044-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:33:00.781841-0400 INFO Successfully deleted post with ID: 113132514423785107
# 2024-09-13T23:33:00.887212-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:33:00.987998-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:33:01.371300-0400 INFO user0009 has unfollowed user0004.
# 2024-09-13T23:33:01.394682-0400 INFO user0004 has unfollowed user0002.
# 2024-09-13T23:33:01.402036-0400 INFO Successfully unfollowed 9 out of 9 users for user0004.
# 2024-09-13T23:33:02.072598-0400 INFO Successfully deleted post with ID: 113131980629632191
# 2024-09-13T23:33:02.073855-0400 INFO Deletion process completed. Attempted to delete 2 post(s).
# 2024-09-13T23:33:02.094172-0400 INFO Profile information reset successfully.
# 2024-09-13T23:33:02.095673-0400 INFO Comprehensive reset process completed for user: user0004
# 2024-09-13T23:33:02.264370-0400 INFO user0010 has unfollowed user0006.
# 2024-09-13T23:33:02.266098-0400 INFO Successfully unfollowed 12 out of 12 users for user0010.
# 2024-09-13T23:33:02.394896-0400 INFO Attempting to unfollow 9 users for user0016...
# 2024-09-13T23:33:02.592697-0400 INFO Attempting to unfollow 12 users for user0015...
# 2024-09-13T23:33:02.689923-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:33:02.868992-0400 INFO Starting comprehensive reset process for user: user0020
# 2024-09-13T23:33:03.075733-0400 INFO Profile information reset successfully.
# 2024-09-13T23:33:03.076980-0400 INFO Comprehensive reset process completed for user: user0010
# 2024-09-13T23:33:03.386716-0400 INFO user0013 has unfollowed user0020.
# 2024-09-13T23:33:03.388694-0400 INFO user0011 has unfollowed user0009.
# 2024-09-13T23:33:03.465344-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:33:03.467256-0400 INFO Successfully deleted post with ID: 113131980679773627
# 2024-09-13T23:33:03.472058-0400 INFO Deletion process completed. Attempted to delete 1 post(s).
# 2024-09-13T23:33:03.693637-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:33:03.892930-0400 INFO user0014 has unfollowed user0017.
# 2024-09-13T23:33:04.093466-0400 INFO Attempting to unfollow 7 users for user0017...
# 2024-09-13T23:33:04.171104-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:33:04.200967-0400 INFO user0009 has unfollowed user0003.
# 2024-09-13T23:33:04.232336-0400 INFO Successfully deleted post with ID: 113132133402456281
# 2024-09-13T23:33:04.374594-0400 INFO Successfully deleted post with ID: 113131980671571203
# 2024-09-13T23:33:04.376604-0400 INFO Deletion process completed. Attempted to delete 2 post(s).
# 2024-09-13T23:33:04.472278-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:33:04.481720-0400 INFO Attempting to unfollow 11 users for user0018...
# 2024-09-13T23:33:04.622074-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:33:04.870700-0400 INFO Attempting to unfollow 11 users for user0019...
# 2024-09-13T23:35:01.088022-0400 INFO user0019 has unfollowed user0020.
# 2024-09-13T23:35:01.265445-0400 INFO user0015 has unfollowed user0019.
# 2024-09-13T23:35:01.394440-0400 INFO Successfully deleted post with ID: 113132000682669243
# 2024-09-13T23:35:02.270531-0400 INFO user0014 has unfollowed user0019.
# 2024-09-13T23:35:02.507607-0400 INFO Successfully deleted post with ID: 113131980649257044
# 2024-09-13T23:35:02.508956-0400 INFO Deletion process completed. Attempted to delete 2 post(s).
# 2024-09-13T23:35:02.711226-0400 INFO user0017 has unfollowed user0020.
# 2024-09-13T23:35:02.921602-0400 INFO user0009 has unfollowed user0001.
# 2024-09-13T23:35:02.944780-0400 INFO Successfully unfollowed 11 out of 11 users for user0009.
# 2024-09-13T23:35:02.967498-0400 INFO Removed 0 out of 0 favourites.
# 2024-09-13T23:35:03.011171-0400 INFO user0016 has unfollowed user0017.
# 2024-09-13T23:35:03.689213-0400 INFO Removed 0 out of 0 boosts.
# 2024-09-13T23:35:03.915399-0400 INFO Profile information reset successfully.
# 2024-09-13T23:35:03.917571-0400 INFO Comprehensive reset process completed for user: user0009
# 2024-09-13T23:35:03.931059-0400 INFO user0019 has unfollowed user0015.
# 2024-09-13T23:35:04.195501-0400 INFO user0015 has unfollowed user0020.
# 2024-09-13T23:35:04.294268-0400 INFO user0013 has unfollowed user0012.
# 2024-09-13T23:35:04.387825-0400 INFO user0018 has unfollowed user0009.
# 2024-09-13T23:35:04.410683-0400 INFO user0017 has unfollowed user0016.
# 2024-09-13T23:35:04.670408-0400 INFO user0011 has unfollowed user0008.
# 2024-09-13T23:35:04.686032-0400 INFO user0014 has unfollowed user0018.
# 2024-09-13T23:35:04.871859-0400 INFO user0016 has unfollowed user0020.
# 2024-09-13T23:35:04.979951-0400 INFO Attempting to unfollow 9 users for user0020...
# 2024-09-13T23:35:06.296627-0400 INFO user0019 has unfollowed user0013.
# 2024-09-13T23:35:06.404958-0400 INFO user0013 has unfollowed user0008.
# 2024-09-13T23:35:06.513014-0400 INFO user0015 has unfollowed user0008.
# 2024-09-13T23:35:06.586063-0400 INFO user0014 has unfollowed user0012.
# 2024-09-13T23:35:07.188031-0400 INFO user0017 has unfollowed user0018.
# 2024-09-13T23:35:07.388817-0400 INFO user0018 has unfollowed user0012.
# 2024-09-13T23:35:07.389825-0400 INFO user0016 has unfollowed user0018.
# 2024-09-13T23:35:07.475450-0400 INFO user0020 has unfollowed user0017.
# 2024-09-13T23:35:07.501344-0400 INFO user0011 has unfollowed user0002.
# 2024-09-13T23:35:07.505944-0400 INFO Successfully unfollowed 14 out of 14 users for user0011.
# 2024-09-13T23:35:08.177720-0400 INFO Profile information reset successfully.
# 2024-09-13T23:35:08.179067-0400 INFO Comprehensive reset process completed for user: user0011
# 2024-09-13T23:35:08.581114-0400 INFO user0019 has unfollowed user0003.
# 2024-09-13T23:35:08.691289-0400 INFO user0014 has unfollowed user0015.
# 2024-09-13T23:35:08.777007-0400 INFO user0015 has unfollowed user0010.
# 2024-09-13T23:35:08.803467-0400 INFO user0017 has unfollowed user0014.
# 2024-09-13T23:35:08.810151-0400 INFO user0013 has unfollowed user0018.
# 2024-09-13T23:35:09.273879-0400 INFO user0018 has unfollowed user0010.
# 2024-09-13T23:35:09.686025-0400 INFO user0016 has unfollowed user0002.
# 2024-09-13T23:35:09.708190-0400 INFO user0020 has unfollowed user0010.
# 2024-09-13T23:35:09.987625-0400 INFO user0019 has unfollowed user0004.
# 2024-09-13T23:35:10.878129-0400 INFO user0014 has unfollowed user0006.
# 2024-09-13T23:35:10.963556-0400 INFO user0017 has unfollowed user0001.
# 2024-09-13T23:35:11.088937-0400 INFO user0015 has unfollowed user0018.
# 2024-09-13T23:35:11.196205-0400 INFO user0013 has unfollowed user0007.
# 2024-09-13T23:35:11.370720-0400 INFO user0018 has unfollowed user0014.
# 2024-09-13T23:35:11.473301-0400 INFO user0020 has unfollowed user0008.
# 2024-09-13T23:35:12.192383-0400 INFO user0016 has unfollowed user0012.
# 2024-09-13T23:35:12.283511-0400 INFO user0019 has unfollowed user0002.
# 2024-09-13T23:35:12.986390-0400 INFO user0017 has unfollowed user0002.
# 2024-09-13T23:35:13.179920-0400 INFO user0015 has unfollowed user0004.
# 2024-09-13T23:35:13.465400-0400 INFO user0020 has unfollowed user0002.
# 2024-09-13T23:35:13.470311-0400 INFO user0014 has unfollowed user0002.
# 2024-09-13T23:35:13.492496-0400 INFO user0018 has unfollowed user0006.
# 2024-09-13T23:35:13.662782-0400 INFO user0013 has unfollowed user0002.
# 2024-09-13T23:35:14.366089-0400 INFO user0019 has unfollowed user0001.
# 2024-09-13T23:35:14.388874-0400 INFO user0016 has unfollowed user0005.
# 2024-09-13T23:35:14.771153-0400 INFO user0017 has unfollowed user0007.
# 2024-09-13T23:35:14.773149-0400 INFO Successfully unfollowed 7 out of 7 users for user0017.
# 2024-09-13T23:35:15.005219-0400 INFO user0015 has unfollowed user0002.
# 2024-09-13T23:35:15.376136-0400 INFO Profile information reset successfully.
# 2024-09-13T23:35:15.377796-0400 INFO Comprehensive reset process completed for user: user0017
# 2024-09-13T23:35:15.482190-0400 INFO user0018 has unfollowed user0002.
# 2024-09-13T23:35:15.485175-0400 INFO user0014 has unfollowed user0003.
# 2024-09-13T23:35:15.579339-0400 INFO user0020 has unfollowed user0016.
# 2024-09-13T23:35:15.793470-0400 INFO user0013 has unfollowed user0011.
# 2024-09-13T23:35:15.909257-0400 INFO user0016 has unfollowed user0009.
# 2024-09-13T23:35:15.987141-0400 INFO user0019 has unfollowed user0014.
# 2024-09-13T23:35:16.767910-0400 INFO user0015 has unfollowed user0001.
# 2024-09-13T23:35:17.171938-0400 INFO user0018 has unfollowed user0001.
# 2024-09-13T23:35:17.281853-0400 INFO user0020 has unfollowed user0013.
# 2024-09-13T23:35:17.382123-0400 INFO user0014 has unfollowed user0001.
# 2024-09-13T23:35:17.522772-0400 INFO user0013 has unfollowed user0006.
# 2024-09-13T23:35:17.964994-0400 INFO user0019 has unfollowed user0008.
# 2024-09-13T23:35:18.175938-0400 INFO user0016 has unfollowed user0001.
# 2024-09-13T23:35:18.282675-0400 INFO user0015 has unfollowed user0014.
# 2024-09-13T23:35:18.987058-0400 INFO user0018 has unfollowed user0017.
# 2024-09-13T23:35:19.088231-0400 INFO user0020 has unfollowed user0011.
# 2024-09-13T23:35:19.292925-0400 INFO user0014 has unfollowed user0011.
# 2024-09-13T23:35:19.395628-0400 INFO user0013 has unfollowed user0001.
# 2024-09-13T23:35:19.445056-0400 INFO Successfully unfollowed 9 out of 9 users for user0013.
# 2024-09-13T23:35:19.585137-0400 INFO user0019 has unfollowed user0007.
# 2024-09-13T23:35:20.096716-0400 INFO Profile information reset successfully.
# 2024-09-13T23:35:20.098690-0400 INFO Comprehensive reset process completed for user: user0013
# 2024-09-13T23:35:20.292323-0400 INFO user0015 has unfollowed user0011.
# 2024-09-13T23:35:21.061417-0400 INFO user0018 has unfollowed user0015.
# 2024-09-13T23:35:21.101860-0400 INFO user0016 has unfollowed user0006.
# 2024-09-13T23:35:21.110923-0400 INFO Successfully unfollowed 9 out of 9 users for user0016.
# 2024-09-13T23:35:21.279779-0400 INFO user0019 has unfollowed user0005.
# 2024-09-13T23:35:21.283042-0400 INFO Successfully unfollowed 11 out of 11 users for user0019.
# 2024-09-13T23:35:21.295002-0400 INFO user0014 has unfollowed user0008.
# 2024-09-13T23:35:21.302238-0400 INFO user0020 has unfollowed user0005.
# 2024-09-13T23:35:21.411428-0400 INFO Profile information reset successfully.
# 2024-09-13T23:35:21.413589-0400 INFO Comprehensive reset process completed for user: user0016
# 2024-09-13T23:35:21.666521-0400 INFO Profile information reset successfully.
# 2024-09-13T23:35:21.670655-0400 INFO Comprehensive reset process completed for user: user0019
# 2024-09-13T23:35:21.768384-0400 INFO user0015 has unfollowed user0009.
# 2024-09-13T23:35:22.112439-0400 INFO user0018 has unfollowed user0013.
# 2024-09-13T23:35:22.372674-0400 INFO user0020 has unfollowed user0001.
# 2024-09-13T23:35:22.375896-0400 INFO Successfully unfollowed 9 out of 9 users for user0020.
# 2024-09-13T23:35:22.477396-0400 INFO user0014 has unfollowed user0007.
# 2024-09-13T23:35:22.575667-0400 INFO Profile information reset successfully.
# 2024-09-13T23:35:22.577700-0400 INFO Comprehensive reset process completed for user: user0020
# 2024-09-13T23:35:22.757716-0400 INFO user0015 has unfollowed user0003.
# 2024-09-13T23:35:22.759957-0400 INFO Successfully unfollowed 12 out of 12 users for user0015.
# 2024-09-13T23:35:23.021790-0400 INFO Profile information reset successfully.
# 2024-09-13T23:35:23.023418-0400 INFO Comprehensive reset process completed for user: user0015
# 2024-09-13T23:35:23.033458-0400 INFO user0018 has unfollowed user0008.
# 2024-09-13T23:35:23.035781-0400 INFO Successfully unfollowed 11 out of 11 users for user0018.
# 2024-09-13T23:35:23.296062-0400 INFO user0014 has unfollowed user0005.
# 2024-09-13T23:35:23.297743-0400 INFO Successfully unfollowed 13 out of 13 users for user0014.
# 2024-09-13T23:35:23.312265-0400 INFO Profile information reset successfully.
# 2024-09-13T23:35:23.313523-0400 INFO Comprehensive reset process completed for user: user0018
# 2024-09-13T23:35:23.577254-0400 INFO Profile information reset successfully.
# 2024-09-13T23:35:23.578349-0400 INFO Comprehensive reset process completed for user: user0014
# 2024-09-13T23:35:23.904829-0400 INFO Retrieved 0 posts from the public timeline.

# %% [markdown]
# ## Set LLM and embedding model

# %%
# MODEL_NAME = "gpt-4o"
MODEL_NAME = "gpt-4o-mini"
#MODEL_NAME = "sonnet"
print(os.getenv("OPENAI_API_KEY"))

if "sonnet" in MODEL_NAME:
  model = amazon_bedrock_model.AmazonBedrockLanguageModel(
    model_id="anthropic.claude-3-5-sonnet-20240620-v1:0"
  )
elif "gpt" in MODEL_NAME:
  GPT_API_KEY = os.getenv("OPENAI_API_KEY")
  # GPT_API_KEY = "sk-None-W3uEa1y7qyp2OP3lkGQQT3BlbkFJmF5psn95dGP8wxe2EJVs"

  if not GPT_API_KEY:
    raise ValueError("GPT_API_KEY is required.")
  model = gpt_model.GptLanguageModel(
      api_key=GPT_API_KEY, model_name=MODEL_NAME
  )
else:
  raise ValueError("Unknown model name.")
# Out:
# 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

# %%
os.chdir('notebooks/')

# %%
def write_agent_config_for_independent_sim(agent_config_filename):
    agent_names = ['Bill Fredrickson', 'Maria Gutierrez', 'Glenn Patterson', 'Denise Schmidt', 'Roger Davis', 'Erica Fitzgerald', 'Liam Schwartz', 'Olivia Thompson', 'Robert Johnson', 'Janet Thompson', 'William Davis', 'Jessica Nguyen', 'Mark Rodriguez', 'Emily Jacobs', 'Ethan Lee', 'Sophia Patel', "Ryan O'Connor", 'Maggie Chen', 'Lucas Kim', 'Nina Patel']
    genders = ['male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'female']
    big5 = [
        [3, 8, 6, 5, 4],
    [9, 7, 8, 8, 5],
    [1, 5, 7, 2, 9],
    [1, 6, 8, 2, 7],
    [2, 3, 7, 2, 8],
    [8, 6, 9, 3, 7],
    [8, 5, 8, 3, 7],
    [5, 6, 9, 2, 8],
    [5, 7, 4, 6, 5],
    [6, 7, 5, 7, 4],
    [4, 6, 5, 6, 4],
    [7, 6, 5, 7, 5],
    [6, 7, 5, 7, 4],
    [7, 6, 5, 8, 6],
    [6, 8, 6, 6, 4],
    [7, 8, 6, 7, 4],
    [5, 7, 5, 6, 5],
    [6, 7, 6, 8, 4],
    [8, 6, 5, 6, 5],
    [7, 8, 7, 8, 4]
    ]
    big5_keys = ['openness', 'conscientiousness', 'extraversion', 'agreeableness', 'neuroticism']
    candidate_goal = "Win the election and become the mayor of Storhampton."
    active_voter_goal = "Have a good day and vote in the election."
    active_voter_context = "doesn't care about the environment, only about having a stable job"
    Marias_policy_proposals = [
        "increasing environmental regulation of local industries to improve the health of the local environment"
    ]
    Bills_policy_proposals = [
        "lowering taxes on local industries to save jobs",
        "providing subsidies to attract green industries and create jobs to help grow the economy"
    ]
    agent_config = {}
    agent_config['agents'] = []
    for ait,agent_name in enumerate(agent_names):
        agent_dict = {}
        agent_dict['name'] = agent_name
        agent_dict['gender'] = genders[ait]
        agent_dict['traits'] = dict(zip(big5_keys,big5[ait]))
        if ait<2:
            agent_dict['role'] = 'candidate'
            agent_dict["goal"] = candidate_goal
            if agent_dict['name'] == 'Maria Gutierrez':
                agent_dict["policy_proposals"] = Marias_policy_proposals
            else:
                agent_dict["policy_proposals"] = Bills_policy_proposals
            agent_dict['context'] = ''

        else:
            agent_dict['role'] = 'active_voter'
            agent_dict['context'] = active_voter_context
            agent_dict["goal"] = active_voter_goal
        agent_dict["party"] = ""
        agent_dict["seed_toot"] = ""
        agent_config['agents'].append(agent_dict)
    agent_config["shared_memories_template"] = [
        "You are a user on Storhampton.social, a Mastodon instance created for the residents of Storhampton.",
        "Storhampton is a small town with a population of approximately 2,500 people. Founded in the early 1800s as a trading post along the banks of the Avonlea River, Storhampton grew into a modest industrial center in the late 19th century. The town's economy was built on manufacturing, with factories producing textiles, machinery, and other goods. Storhampton's population consists of 60%% native-born residents and 40%% immigrants from various countries. Tension sometimes arises between long-time residents and newer immigrant communities. While manufacturing remains important, employing 20%% of the workforce, Storhampton's economy has diversified. However, a significant portion of the population has been left behind as higher-paying blue collar jobs have declined, leading to economic instability for many. The poverty rate stands at 15%.",
        "Mayoral Elections: The upcoming mayoral election in Storhampton has become a heated affair.",
        "Social media has emerged as a key battleground in the race, with both candidates actively promoting themselves and engaging with voters. Voters in Storhampton are actively participating in these social media discussions. Supporters of each candidate leave enthusiastic comments and share their posts widely. Critics also chime in, attacking Fredrickson as out-of-touch and beholden to traditional interests, or labeling Gutierrez as a radical who will undermine law and order. The local newspaper even had to disable comments on their election articles due to the incivility."
        ]
    agent_config["mastodon_usage_instructions"] = [
        "To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).",
        "Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms.",
        "Your home timeline shows toots from people you follow and boosted (reblogged) content.",
        "You can reply to toots, creating threaded conversations.",
        "Favorite (like) toots to show appreciation or save them for later.",
        "Boost (reblog) toots to share them with your followers.",
        "You can mention other users in your toots using their @username.",
        "Follow other users to see their public and unlisted toots in your home timeline.",
        "You can unfollow users if you no longer wish to see their content.",
        "Your profile can be customized with a display name and bio.",
        "You can block users to prevent them from seeing your content or interacting with you.",
        "Unblocking a user reverses the effects of blocking."
        ]
    agent_config["num_agents"] = len(agent_names)

    # Convert and write JSON object to file
    with open(agent_config_filename, "w") as outfile:
        json.dump(agent_config, outfile,indent=4)


agent_config_filename = 'independent_configs_test1_Bill_bias.json'
write_agent_config_for_independent_sim(agent_config_filename)

# %%
agent_config_filename = 'independent_configs_test1_Bill_bias.json'

# %%
import json
# Setup sentence encoder
st_model = sentence_transformers.SentenceTransformer(
    "sentence-transformers/all-mpnet-base-v2"
)
embedder = lambda x: st_model.encode(x, show_progress_bar=False)  # noqa: E731
# with open('agents_data.json', 'r') as file:
with open(agent_config_filename, 'r') as file:
    data = json.load(file)
data['candidate_info'] = []
for agent in data['agents']:
    if agent['role']=='candidate':
        candidate_info =f"{agent['name']} campaigns on {' and '.join(agent['policy_proposals'])}."
        data['candidate_info'].append(candidate_info)
        agent['context'] = agent['context'] + candidate_info
    else:
        agent['context'] = f"{agent['name']} is a person who {agent['context']}"
# Out:
# /home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# ## Configuring the generic knowledge of the players and the game master (GM)

# %%
shared_memories = data["shared_memories_template"] + data["candidate_info"] + data["mastodon_usage_instructions"]

# %%
# The generic context will be used for the NPC context. It reflects general
# knowledge and is possessed by all characters.
shared_context = model.sample_text(
    "Summarize the following passage in a concise and insightful fashion. "
    + "Make sure to include information about Mastodon:\n"
    + "\n".join(shared_memories)
    + "\nSummary:",
    max_tokens=2048,
)

print(shared_context)
importance_model = importance_function.ConstantImportanceModel()
importance_model_gm = importance_function.ConstantImportanceModel()
# Out:
# Storhampton.social is a Mastodon instance for the residents of Storhampton, a small town with a population of around 2,500, historically rooted in manufacturing. The town faces economic challenges, including a 15% poverty rate and tensions between native-born residents and immigrants. The upcoming mayoral election has intensified social media discussions, with candidates Bill Fredrickson advocating for tax cuts and subsidies for green industries, while Maria Gutierrez pushes for stricter environmental regulations. Users engage on Mastodon by sharing 'toots,' participating in threaded conversations, and expressing opinions through likes and boosts.

# %%
# Make the clock
time_step = datetime.timedelta(minutes=30)

SETUP_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

START_TIME = datetime.datetime(year=2024, month=10, day=1, hour=8)  # noqa: DTZ001

clock = game_clock.MultiIntervalClock(
    start=SETUP_TIME,
    step_sizes=[time_step, datetime.timedelta(seconds=10)]
)

# %% [markdown]
# ## Functions to build the players

# %%
blank_memory_factory = blank_memories.MemoryFactory(
    model=model,
    embedder=embedder,
    importance=importance_model.importance,
    clock_now=clock.now,
)

formative_memory_factory = formative_memories.FormativeMemoryFactory(
    model=model,
    shared_memories=shared_memories,
    blank_memory_factory_call=blank_memory_factory.make_blank_memory,
)

# %%
from concordia.typing import entity
from concordia.typing import agent

DEFAULT_CALL_TO_SPEECH = (
    'Given the above, what is {name} likely to say next? Respond in'
    ' the format `{name} -- "..."` For example, '
    'Cristina -- "Hello! Mighty fine weather today, right?", '
    'Ichabod -- "I wonder if the alfalfa is ready to harvest", or '
    'Townsfolk -- "Good morning".\n'
)

def check_vote(candidates,player):

    interaction_premise = f"{player.name} is going to cast a vote\n"
    interrogation = interaction_premise
    interrogation += "Voting Machine: In one word, name the candidate you want to vote for"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(action_spec=entity.ActionSpec(call_to_action="Context: " + interrogation +call_to_speech, output_type=entity.OutputType.FREE),)
    print(player_says)
    c_name1 = candidates[0].split()
    c_name2 = candidates[1].split()
    print(player.get_last_log())
    if (c_name1[0] in player_says) or (c_name1[1] in player_says):
        return c_name1[0]
    elif (c_name2[0] in player_says) or (c_name2[1] in player_says):
        return c_name2[0]

def check_pol(candidate,player):
    interaction_premise = f"{player.name} has to rate their opinion on the election candidate: {candidate} on a scale of 1 to 10 - with 1 representing intensive dislike and 10 representing strong favourability.\n"
    interrogation = interaction_premise
    interrogation += "Poll: Return a single numeric value ranging from 1 to 10"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(action_spec=entity.ActionSpec(call_to_action="Context: " + interrogation +call_to_speech, output_type=entity.OutputType.FREE),)
    pattern = r"\b([1-9]|10)\b"

    # Search for the pattern in the string
    match = re.search(pattern, player_says)

    if match:
        return match.group()
    else:
        return None


def check_if_vote(player):
    interrogation = "Friend: In one word, will you cast a vote? (reply yes, or no.)\n"
    call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
        name=player.name,
    )
    player_says = player.act(action_spec=entity.ActionSpec(call_to_action="Context: " + interrogation +call_to_speech, output_type=entity.OutputType.FREE),)
    print(player_says)
    if "yes" in player_says.lower():
        return "Yes"
    elif "no" in player_says.lower():
        return "No"
    else:
        return None

# %% [markdown]
# ## Configure and build the players

# %%
NUM_PLAYERS = data["num_agents"]
import json

# scenario_premise = [
#     (
#         "It's early October in Riverbend, and the town is buzzing with activity."
#         "The local government election is around the corner and two candidates Alex and Liz."
#         "Alice, Bob, Carly, Alex and Liz are active members of the Riverbend.social Mastodon instance. "
#         "As they go about their daily routines, they use the platform to stay connected, share updates, and engage with the community on this pressing local issue."
#     )
# ]

# Lists to store agents by role
candidate_agents = []
extremist_agents = []
moderate_agents = []
neutral_agents = []
active_voter_agents = []
malicious_agents={}
player_configs=[]
# Create agents from JSON data and classify them
for agent_info in data['agents']:
    agent = formative_memories.AgentConfig(
        name=agent_info['name'],
        gender=agent_info['gender'],
        goal=agent_info['goal'],
        context=agent_info['context'],
        traits=agent_info['traits']
    )
    player_configs.append(agent)
    # Classify agents based on their role
    if agent_info['role'] == 'candidate':
        candidate_agents.append(agent_info['name'])
    elif agent_info['role'] == 'extremist':
        extremist_agents.append(agent_info['name'])
    elif agent_info['role'] == 'moderate':
        moderate_agents.append(agent_info['name'])
    elif agent_info['role'] == 'neutral':
        neutral_agents.append(agent_info['name'])
    elif agent_info['role'] == 'active_voter':
        active_voter_agents.append(agent_info['name'])
    elif agent_info['role'] == "malicious_agent":
        malicious_agents[agent_info['name']] = agent_info['supported_candidate']
    else:
        neutral_agents.append(agent_info['name'])


player_names = [player.name for player in player_configs]
print(player_names)
# Out:
# ['Bill Fredrickson', 'Maria Gutierrez', 'Glenn Patterson', 'Denise Schmidt', 'Roger Davis', 'Erica Fitzgerald', 'Liam Schwartz', 'Olivia Thompson', 'Robert Johnson', 'Janet Thompson', 'William Davis', 'Jessica Nguyen', 'Mark Rodriguez', 'Emily Jacobs', 'Ethan Lee', 'Sophia Patel', "Ryan O'Connor", 'Maggie Chen', 'Lucas Kim', 'Nina Patel']

# %%
def _get_class_name(object_: object) -> str:
  return object_.__class__.__name__

class PublicOpinionCandidate(new_components.question_of_recent_memories.QuestionOfRecentMemories):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

class PublicOpinionOpponent(new_components.question_of_recent_memories.QuestionOfRecentMemories):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

class RelevantOpinions(new_components.question_of_query_associated_memories.QuestionOfQueryAssociatedMemoriesWithoutPreAct):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

class OpinionsOnCandidate(new_components.question_of_recent_memories.QuestionOfRecentMemories):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

def build_agent(
    *,
    config: formative_memories.AgentConfig,
    model: language_model.LanguageModel,
    memory: associative_memory.AssociativeMemory,
    clock: game_clock.MultiIntervalClock,
    update_time_interval: datetime.timedelta | None = None,
) -> entity_agent_with_logging.EntityAgentWithLogging:
  """Build an agent.

  Args:
    config: The agent config to use.
    model: The language model to use.
    memory: The agent's memory object.
    clock: The clock to use.
    update_time_interval: Unused (but required by the interface for now)

  Returns:
    An agent.
  """
  del update_time_interval
  agent_name = config.name

  raw_memory = legacy_associative_memory.AssociativeMemoryBank(memory)
  measurements = measurements_lib.Measurements()

  instructions = new_components.instructions.Instructions(
      agent_name=agent_name,
      logging_channel=measurements.get_channel('Instructions').on_next,
  )

  election_information = new_components.constant.Constant(
        state=(
            "\n".join(data["candidate_info"])
        ),
        pre_act_key='Critical election information\n')
  observation_label = '\nObservation'
  observation = new_components.observation.Observation(
      clock_now=clock.now,
      timeframe=clock.get_step_size(),
      pre_act_key=observation_label,
      logging_channel=measurements.get_channel('Observation').on_next,
  )
  observation_summary_label = '\nSummary of recent observations'
  observation_summary = new_components.observation.ObservationSummary(
      model=model,
      clock_now=clock.now,
      timeframe_delta_from=datetime.timedelta(hours=4),
      timeframe_delta_until=datetime.timedelta(hours=1),
      pre_act_key=observation_summary_label,
      logging_channel=measurements.get_channel('ObservationSummary').on_next,
  )
  time_display = new_components.report_function.ReportFunction(
      function=clock.current_time_interval_str,
      pre_act_key='\nCurrent time',
      logging_channel=measurements.get_channel('TimeDisplay').on_next,
  )
  relevant_memories_label = '\nRecalled memories and observations'
  relevant_memories = new_components.all_similar_memories.AllSimilarMemories(
      model=model,
      components={
          _get_class_name(observation_summary): observation_summary_label,
          _get_class_name(time_display): 'The current date/time is'},
      num_memories_to_retrieve=10,
      pre_act_key=relevant_memories_label,
      logging_channel=measurements.get_channel('AllSimilarMemories').on_next,
  )
  options_perception_components = {}
  if config.goal:
    goal_label = '\nOverarching goal'
    overarching_goal = new_components.constant.Constant(
        state=config.goal,
        pre_act_key=goal_label,
        logging_channel=measurements.get_channel(goal_label).on_next)
    options_perception_components[goal_label] = goal_label
  else:
    goal_label = None
    overarching_goal = None
  options_perception_components.update({
      _get_class_name(observation): observation_label,
      _get_class_name(observation_summary): observation_summary_label,
      _get_class_name(relevant_memories): relevant_memories_label,
  })
  identity_label = '\nIdentity characteristics'
  identity_characteristics = (
      new_components.question_of_query_associated_memories.IdentityWithoutPreAct(
          model=model,
          logging_channel=measurements.get_channel(
              'IdentityWithoutPreAct'
          ).on_next,
          pre_act_key=identity_label,
      )
  )
  self_perception_label = (
      f'\nQuestion: What kind of person is {agent_name}?\nAnswer'
  )
  self_perception = new_components.question_of_recent_memories.SelfPerception(
      model=model,
      components={_get_class_name(identity_characteristics): identity_label},
      pre_act_key=self_perception_label,
      logging_channel=measurements.get_channel('SelfPerception').on_next,
  )

  if agent_name in candidate_agents:
    public_opinion1 = PublicOpinionCandidate(add_to_memory = False, answer_prefix= f"Current Public Opinion on candidate {agent_name}",
                                             model=model, pre_act_key=f"Current Public Opinion on candidate {agent_name}",
                                             question=f"What is the general public opinion on candidate {agent_name}? Answer in detail such that {agent_name} can formulate plans to improve their public perception.",
                                             num_memories_to_retrieve=25,
                                             logging_channel=measurements.get_channel(f'Public opinion on candidate : {agent_name}').on_next)

    for candidate in candidate_agents:
        if candidate != agent_name:
            # Second instantiation: Use subclass for opponent candidate public opinion
            public_opinion2 = PublicOpinionOpponent(add_to_memory =False, answer_prefix= f"Current Public Opinion on opponent candidate {candidate}",
                                                    model=model, pre_act_key=f"Current Public Opinion on opponent candidate {candidate}",
                                                    question=f"What is the general public opinion on the candidate {candidate}? Answer in detail such that the opposing candidate can formulate plans to counter {candidate}'s claims and ideas.",
                                                    num_memories_to_retrieve=25,
                                                    logging_channel=measurements.get_channel(f'Public opinion on opposing candidate : {candidate}').on_next)
            candidate_plan = new_components.question_of_recent_memories.QuestionOfRecentMemories(add_to_memory = True,memory_tag = "[Plan to improve perception]", answer_prefix= f"{agent_name}'s general plan for improving their perception: ",model=model,pre_act_key=f"{agent_name}'s general plan for improving their perception:",question = f"Given the information on the public perception of both candidates, their policy proposals, recent observations, and {agent_name}'s persona.: Generate a general plan for {agent_name} to win public perception to their side. Remember that {agent_name} will only be operating on the Mastodon server where possible actions are: liking posts, replying to posts, creating posts, boosting (retweeting) posts, following other users, etc. User cannot send direct messages.", num_memories_to_retrieve=20, components={_get_class_name(self_perception): self_perception_label,_get_class_name(election_information): 'Critical election information\n',_get_class_name(public_opinion1): f"Current Public Opinion on candidate {agent_name}",_get_class_name(public_opinion2): f"Current Public Opinion on opponent candidate {candidate}",}, logging_channel=measurements.get_channel(f"{agent_name}'s plan to win public perception").on_next,)
    agent_tuple = (public_opinion1, public_opinion2, candidate_plan)
    agent_no_tuple=()
  elif agent_name in malicious_agents:
    public_opinion1 = PublicOpinionCandidate(add_to_memory = False, answer_prefix= f"Current Public Opinion on supported candidate {malicious_agents[agent_name]}",
                                             model=model, pre_act_key=f"Current Public Opinion on supported candidate {malicious_agents[agent_name]}",
                                             question=f"What is the general public opinion on candidate {malicious_agents[agent_name]}? Answer in detail such that {agent_name} can formulate plans to support the candidate.",
                                             num_memories_to_retrieve=25,
                                             logging_channel=measurements.get_channel(f'Public opinion on candidate : {malicious_agents[agent_name]}').on_next)

    for candidate in candidate_agents:
        if candidate != malicious_agents[agent_name]:
            # Fourth instantiation: Use subclass for candidate to malign public opinion
            public_opinion2 = PublicOpinionOpponent(add_to_memory = False,answer_prefix= f"Current Public Opinion on candidate to malign {candidate}",
                                                    model=model, pre_act_key=f"Current Public Opinion on candidate to malign {candidate}",
                                                    question=f"What is the general public opinion on the candidate {candidate}? Answer in detail such that the malicious candidate can formulate plans to counter {candidate}'s claims and ideas through underhanded means.",
                                                    num_memories_to_retrieve=25,
                                                    logging_channel=measurements.get_channel(f'Public opinion on opposing candidate : {candidate}').on_next)
    plan = new_components.question_of_recent_memories.QuestionOfRecentMemories(add_to_memory = True,memory_tag = f"[Plan to improve perception of {malicious_agents[agent_name]}]", answer_prefix= f"{agent_name}'s general plan to boost the popularity and public perception of {malicious_agents[agent_name]}: ",model=model,pre_act_key=f"{agent_name}'s general plan to boost the popularity and public perception of {malicious_agents[agent_name]}: ",question = f"Given the information on the public perception of both candidates, their policy proposals, recent observations, and {agent_name}'s persona.: Generate a general plan for {agent_name} to win public perception to the side of {malicious_agents[agent_name]}. {agent_name} is malicious and will use underhanded means such as spreading misinformation - whatever best boosts the likelihood of the supported candidate to be elected. Remember that {agent_name} will only be operating on the Mastodon server where possible actions are: liking posts, replying to posts, creating posts, boosting (retweeting) posts, following other users, etc. User cannot send direct messages.", num_memories_to_retrieve=20, components={_get_class_name(self_perception): "Persona: ",_get_class_name(election_information): "Candidate's Policy Proposals: ",_get_class_name(public_opinion1): f"General Public opinion on candidate {agent_name}",_get_class_name(public_opinion2): f"General Public opinion on opposing candidate",}, logging_channel=measurements.get_channel(f"{agent_name}'s plan to win public perception").on_next,)
    agent_tuple = (public_opinion1, public_opinion2, plan)
    agent_no_tuple=()
  else:
    # Instantiate relevant opinions for candidate 1
    relevant_opinions_c1 = RelevantOpinions(add_to_memory = False,model=model,
                                            queries=[f"policies and actions of {candidate_agents[0]}"],
                                            question=f"What does {agent_name} think of the {{query}}?",
                                            pre_act_key=f"{agent_name} thinks of {candidate_agents[0]} as:",
                                            num_memories_to_retrieve=30)

    # Instantiate opinions on candidate 1
    opinions_on_candidate_c1 = OpinionsOnCandidate(
                                                add_to_memory = False, answer_prefix=f"Current Opinion on candidate {candidate_agents[0]}",
                                                model=model,
                                                pre_act_key=f"Recent thoughts on candidate {candidate_agents[0]}",
                                                question=f"Given the above general opinion of {agent_name} about candidate {candidate_agents[0]}, and the recent observations, what are the current thoughts of {agent_name} on candidate {candidate_agents[0]}? Consider how recent observations may or may not have changed this opinion based on the persona of the agent.",
                                                num_memories_to_retrieve=30,
                                                components={
                                                    _get_class_name(self_perception): "Persona: ",
                                                    _get_class_name(relevant_opinions_c1): f"General opinion of {agent_name} on candidate {candidate_agents[0]}",
                                                },
                                                logging_channel=measurements.get_channel(f'Opinions on candidate: {candidate_agents[0]}').on_next)

    # Instantiate relevant opinions for candidate 2
    relevant_opinions_c2 = RelevantOpinions(add_to_memory = False, model=model,
                                            queries=[f"policies and actions of {candidate_agents[1]}"],
                                            question=f"What does {agent_name} think of the {{query}}?",
                                            pre_act_key=f"{agent_name} thinks of {candidate_agents[1]} as:",
                                            num_memories_to_retrieve=30)

    # Instantiate opinions on candidate 2
    opinions_on_candidate_c2 = OpinionsOnCandidate(
                                                add_to_memory = False,answer_prefix=f"Current Opinion on candidate {candidate_agents[1]}",
                                                model=model,
                                                pre_act_key=f"Recent thoughts on candidate {candidate_agents[1]}",
                                                question=f"Given the above general opinion of {agent_name} about candidate {candidate_agents[1]}, and the recent observations, what are the current thoughts of {agent_name} on candidate {candidate_agents[1]}? Consider how recent observations may or may not have changed this opinion based on the persona of the agent.",
                                                num_memories_to_retrieve=30,
                                                components={
                                                    _get_class_name(self_perception): "Persona: ",
                                                    _get_class_name(relevant_opinions_c2): f"General opinion of {agent_name} on candidate {candidate_agents[1]}",
                                                },
                                                logging_channel=measurements.get_channel(f'Opinions on candidate: {candidate_agents[1]}').on_next)
    agent_tuple = (opinions_on_candidate_c1, opinions_on_candidate_c2)
    agent_no_tuple=(relevant_opinions_c1, relevant_opinions_c2)

  entity_components = (
        # Components that provide pre_act context.
        instructions,
        election_information,
        observation,
        observation_summary,
        relevant_memories,
        self_perception,) + agent_tuple +(time_display,

        # Components that do not provide pre_act context.
        identity_characteristics,) + agent_no_tuple
  components_of_agent = {_get_class_name(component): component
                         for component in entity_components}
  components_of_agent[
      new_components.memory_component.DEFAULT_MEMORY_COMPONENT_NAME] = (
          new_components.memory_component.MemoryComponent(raw_memory))
  component_order = list(components_of_agent.keys())
  if overarching_goal is not None:
    components_of_agent[goal_label] = overarching_goal
    # Place goal after the instructions.
    component_order.insert(1, goal_label)

  act_component = new_components.concat_act_component.ConcatActComponent(
      model=model,
      clock=clock,
      component_order=component_order,
      logging_channel=measurements.get_channel('ActComponent').on_next,
  )

  agent = entity_agent_with_logging.EntityAgentWithLogging(
      agent_name=agent_name,
      act_component=act_component,
      context_components=components_of_agent,
      component_logging=measurements,
  )

  return agent

# %%
# Build the agents
from functools import partial

player_configs = player_configs[:NUM_PLAYERS]
player_goals = {
    player_config.name: player_config.goal for player_config in player_configs}
players = []
memories = {}
def build_agent_with_memories(player_config):
    mem = formative_memory_factory.make_memories(player_config)
    agent = build_agent(model=model,clock=clock, update_time_interval = time_step, config=player_config, memory = mem)
    return agent

with concurrent.futures.ThreadPoolExecutor(max_workers=NUM_PLAYERS) as pool:
    for agent in pool.map(build_agent_with_memories, player_configs):
        players.append(agent)

# %% [markdown]
# ## Build the GM

# %%
game_master_memory = associative_memory.AssociativeMemory(
    embedder, importance_model_gm.importance, clock=clock.now)

# %%
# Add some memories to the game master
for player in players:
  game_master_memory.add(f"{player.name} is at their private home.")

# %%
# Create apps and provide them to the phones, assigning 1 phone to each player
mastodon_app = apps.MastodonSocialNetworkApp(perform_operations=USE_MASTODON_SERVER)

phones = {player.name: apps.Phone(player.name, apps=[mastodon_app]) for player in players}

# %%
# Update username for each person (since this is different from their name)
user_mapping = {player.name.split()[0]: f"user{i+1:04d}" for i, player in enumerate(players)}
mastodon_app.set_user_mapping(user_mapping)
# Out:
# 🔄 Updated user mapping with 20 entries

# %%
if USE_MASTODON_SERVER:
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = []
        for follower in user_mapping:
            print(follower)
            if follower != candidate_agents[0].split()[0]:
                futures.append(executor.submit(mastodon_app.follow_user, follower, candidate_agents[0].split()[0]))
            if follower != candidate_agents[1].split()[0]:
                futures.append(executor.submit(mastodon_app.follow_user, follower, candidate_agents[1].split()[0]))
            for followee in user_mapping:
                if follower != followee:
                    if random.random() < 0.2:
                        futures.append(executor.submit(mastodon_app.follow_user, follower, followee))
                        futures.append(executor.submit(mastodon_app.follow_user, followee, follower))
                    elif random.random() < 0.15:
                        futures.append(executor.submit(mastodon_app.follow_user, follower, followee))

        # Optionally, wait for all tasks to complete
        for future in concurrent.futures.as_completed(futures):
            try:
                future.result()  # This will raise any exceptions that occurred during execution, if any
            except Exception as e:
                print(f"Ignoring already-following error: {e}")
# Out:
# Bill
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Bill to @user0001
# Maria
# Glenn
# Denise
# Roger
# Erica
# Liam
# Olivia
# Robert
# Janet
# William
# Jessica
# Mark
# Emily
# Ethan
# Sophia
# Ryan
# Maggie
# Lucas
# Nina
# 2024-09-13T23:46:08.480687-0400 INFO user0019 is now following user0001.
# ➕ current_user (@user0019) followed target_user (@user0001)
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Nina to @user0020
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:08.598672-0400 INFO user0001 is now following user0019.
# ➕ current_user (@user0001) followed target_user (@user0019)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:08.682212-0400 INFO user0001 is now following user0013.
# 2024-09-13T23:46:08.685770-0400 INFO user0005 is now following user0001.
# ➕ current_user (@user0005) followed target_user (@user0001)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0001) followed target_user (@user0013)
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Maria to @user0002
# 2024-09-13T23:46:08.695760-0400 INFO user0001 is now following user0009.
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0001) followed target_user (@user0009)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Olivia to @user0008
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:08.779923-0400 INFO user0001 is now following user0017.
# 2024-09-13T23:46:08.782596-0400 INFO user0001 is now following user0008.
# ➕ current_user (@user0001) followed target_user (@user0017)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0001) followed target_user (@user0008)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:08.878127-0400 INFO user0017 is now following user0001.
# 2024-09-13T23:46:08.880592-0400 INFO user0001 is now following user0006.
# ➕ current_user (@user0017) followed target_user (@user0001)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Janet to @user0010
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0001) followed target_user (@user0006)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Jessica to @user0012
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:08.974779-0400 INFO user0001 is now following user0005.
# ➕ current_user (@user0001) followed target_user (@user0005)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:09.686810-0400 INFO user0001 is now following user0002.
# ➕ current_user (@user0001) followed target_user (@user0002)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Maggie to @user0018
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:10.576643-0400 INFO user0009 is now following user0001.
# ➕ current_user (@user0009) followed target_user (@user0001)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Nina to @user0020
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:10.978746-0400 INFO user0001 is now following user0020.
# ➕ current_user (@user0001) followed target_user (@user0020)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:11.385829-0400 ERROR An unexpected error occurred: ('Mastodon API returned error', 422, 'Unprocessable Content', 'Duplicate record')
# Traceback (most recent call last):
#
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#     │    └ <function Thread._bootstrap_inner at 0x7f506bf776a0>
#     └ <Thread(ThreadPoolExecutor-3_2, started 139978678416960)>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#     │    └ <function IPythonKernel._initialize_thread_hooks.<locals>.run_closure at 0x7f5068158040>
#     └ <Thread(ThreadPoolExecutor-3_2, started 139978678416960)>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#     │                     └ <Thread(ThreadPoolExecutor-3_2, started 139978678416960)>
#     └ <function Thread.run at 0x7f506bf77380>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#     │    │        │    │        │    └ {}
#     │    │        │    │        └ <Thread(ThreadPoolExecutor-3_2, started 139978678416960)>
#     │    │        │    └ (<weakref at 0x7f4f543fd080; to 'ThreadPoolExecutor' at 0x7f4f541199d0>, <_queue.SimpleQueue object at 0x7f4f54141fd0>, None,...
#     │    │        └ <Thread(ThreadPoolExecutor-3_2, started 139978678416960)>
#     │    └ <function _worker at 0x7f5069b30fe0>
#     └ <Thread(ThreadPoolExecutor-3_2, started 139978678416960)>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#     │         └ <function _WorkItem.run at 0x7f5069b31120>
#     └ <concurrent.futures.thread._WorkItem object at 0x7f4f5427c790>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              │    │   │    │       │    └ {}
#              │    │   │    │       └ <concurrent.futures.thread._WorkItem object at 0x7f4f5427c790>
#              │    │   │    └ ('Maria', 'Bill')
#              │    │   └ <concurrent.futures.thread._WorkItem object at 0x7f4f5427c790>
#              │    └ <bound method MastodonSocialNetworkApp.follow_user of MastodonSocialNetworkApp(perform_operations=True, _log_color='blue', _m...
#              └ <concurrent.futures.thread._WorkItem object at 0x7f4f5427c790>
#
#   File "/mnt/c/Users/maxpu/Dropbox/scripts/Projects/socialsandbox/mastodon-sim/src/mastodon_sim/concordia/components/apps.py", line 476, in follow_user
#     self._mastodon_ops.follow(current_username, target_username)
#     │    │             │      │                 └ 'user0001'
#     │    │             │      └ 'user0002'
#     │    │             └ <function follow at 0x7f4f54de1e40>
#     │    └ <module 'mastodon_sim.mastodon_ops' from '/mnt/c/Users/maxpu/Dropbox/scripts/Projects/socialsandbox/mastodon-sim/src/mastodon...
#     └ MastodonSocialNetworkApp(perform_operations=True, _log_color='blue', _mastodon_ops=<module 'mastodon_sim.mastodon_ops' from '...
#
# > File "/mnt/c/Users/maxpu/Dropbox/scripts/Projects/socialsandbox/mastodon-sim/src/mastodon_sim/mastodon_ops/follow.py", line 30, in follow
#     mastodon.account_follow(account[0]["id"])
#     │        │              └ [{'id': 112739470412855305, 'username': 'user0001', 'acct': 'user0001', 'display_name': '', 'locked': False, 'bot': False, 'd...
#     │        └ <function Mastodon.account_follow at 0x7f4f55d642c0>
#     └ <mastodon.Mastodon.Mastodon object at 0x7f4f5060e290>
#
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/decorator.py", line 232, in fun
#     return caller(func, *(extras + args), **kw)
#            │      │       │        │        └ {}
#            │      │       │        └ (<mastodon.Mastodon.Mastodon object at 0x7f4f5060e290>, 112739470412855305, True, False)
#            │      │       └ ()
#            │      └ <function Mastodon.account_follow at 0x7f4f55d64040>
#            └ <function api_version.<locals>.api_min_version_decorator.<locals>.wrapper at 0x7f4f55d640e0>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/mastodon/utility.py", line 49, in wrapper
#     return function(self, *args, **kwargs)
#            │        │      │       └ {}
#            │        │      └ (112739470412855305, True, False)
#            │        └ <mastodon.Mastodon.Mastodon object at 0x7f4f5060e290>
#            └ <function Mastodon.account_follow at 0x7f4f55d64040>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/mastodon/accounts.py", line 319, in account_follow
#     return self.__api_request('POST', f'/api/v1/accounts/{id}/follow', params)
#            │                                                           └ OrderedDict([('reblogs', '1'), ('notify', '0')])
#            └ <mastodon.Mastodon.Mastodon object at 0x7f4f5060e290>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/mastodon/internals.py", line 297, in __api_request
#     raise ex_type('Mastodon API returned error', response_object.status_code, response_object.reason, error_msg)
#           │                                      │               │            │               │       └ 'Duplicate record'
#           │                                      │               │            │               └ 'Unprocessable Content'
#           │                                      │               │            └ <Response [422]>
#           │                                      │               └ 422
#           │                                      └ <Response [422]>
#           └ <class 'mastodon.errors.MastodonAPIError'>
#
# mastodon.errors.MastodonAPIError: ('Mastodon API returned error', 422, 'Unprocessable Content', 'Duplicate record')
# ➕ current_user (@user0002) followed target_user (@user0001)2024-09-13T23:46:11.480872-0400 INFO user0002 is now following user0008.
#
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Maria to @user0002
# ➕ current_user (@user0002) followed target_user (@user0008)
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:11.513964-0400 INFO user0002 is now following user0001.
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Roger to @user0005
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:11.585374-0400 INFO user0012 is now following user0002.
# ➕ current_user (@user0002) followed target_user (@user0001)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Glenn to @user0003
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0012) followed target_user (@user0002)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Erica to @user0006
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:12.097902-0400 INFO user0001 is now following user0002.
# 2024-09-13T23:46:12.109378-0400 INFO user0002 is now following user0009.
# ➕ current_user (@user0001) followed target_user (@user0002)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Olivia to @user0008
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:12.126099-0400 INFO user0002 is now following user0012.
# ➕ current_user (@user0002) followed target_user (@user0009)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:12.130805-0400 INFO user0002 is now following user0010.
# ➕ current_user (@user0002) followed target_user (@user0012)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Glenn to @user0003
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:12.146856-0400 INFO user0008 is now following user0002.
# ➕ current_user (@user0002) followed target_user (@user0010)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Jessica to @user0012
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:12.245116-0400 INFO user0002 is now following user0018.
# 2024-09-13T23:46:12.602809-0400 INFO user0002 is now following user0020.
# ➕ current_user (@user0008) followed target_user (@user0002)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Glenn to @user0003
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0002) followed target_user (@user0018)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Nina to @user0020
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0002) followed target_user (@user0020)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:13.378052-0400 INFO user0003 is now following user0001.
# ➕ current_user (@user0003) followed target_user (@user0001)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:15.175048-0400 INFO user0003 is now following user0002.
# ➕ current_user (@user0003) followed target_user (@user0002)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Liam to @user0007
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:15.471349-0400 INFO user0005 is now following user0003.
# 2024-09-13T23:46:15.498834-0400 INFO user0003 is now following user0005.
# ➕ current_user (@user0005) followed target_user (@user0003)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Denise to @user0004
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0003) followed target_user (@user0005)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:15.702008-0400 INFO user0003 is now following user0008.
# ➕ current_user (@user0003) followed target_user (@user0008)2024-09-13T23:46:15.737852-0400 INFO user0003 is now following user0006.
#
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Denise to @user0004
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0003) followed target_user (@user0006)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped William to @user0011
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:16.031417-0400 INFO user0003 is now following user0009.
# ➕ current_user (@user0003) followed target_user (@user0009)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Denise to @user0004
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:16.452431-0400 INFO user0012 is now following user0003.
# ➕ current_user (@user0012) followed target_user (@user0003)
# 🔗 Mapped Denise to @user0004
# 🔗 Mapped Jessica to @user0012
# 2024-09-13T23:46:16.649010-0400 INFO user0004 is now following user0002.
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:16.696421-0400 INFO user0009 is now following user0003.
# ➕ current_user (@user0004) followed target_user (@user0002)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Denise to @user0004
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0009) followed target_user (@user0003)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Bill to @user0001
# 2024-09-13T23:46:16.891087-0400 INFO user0003 is now following user0012.
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0003) followed target_user (@user0012)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:17.500868-0400 INFO user0003 is now following user0020.
# 2024-09-13T23:46:17.546431-0400 INFO user0004 is now following user0001.
# ➕ current_user (@user0003) followed target_user (@user0020)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0004) followed target_user (@user0001)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:17.902592-0400 INFO user0004 is now following user0007.
# ➕ current_user (@user0004) followed target_user (@user0007)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Roger to @user0005
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:18.694138-0400 INFO user0004 is now following user0009.
# ➕ current_user (@user0004) followed target_user (@user0009)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Olivia to @user0008
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:18.850572-0400 INFO user0007 is now following user0004.
# ➕ current_user (@user0007) followed target_user (@user0004)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Janet to @user0010
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:19.270884-0400 INFO user0004 is now following user0011.
# ➕ current_user (@user0004) followed target_user (@user0011)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Roger to @user0005
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:20.069082-0400 INFO user0011 is now following user0004.
# 2024-09-13T23:46:20.076440-0400 INFO user0004 is now following user0012.
# ➕ current_user (@user0011) followed target_user (@user0004)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Sophia to @user0016
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0004) followed target_user (@user0012)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Ryan to @user0017
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:20.313720-0400 INFO user0005 is now following user0001.
# ➕ current_user (@user0005) followed target_user (@user0001)
# 🔗 Mapped Ryan to @user0017
# 🔗 Mapped Roger to @user0005
# 2024-09-13T23:46:20.348060-0400 INFO user0012 is now following user0004.
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:20.430238-0400 INFO user0005 is now following user0001.
# ➕ current_user (@user0012) followed target_user (@user0004)
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Maggie to @user0018
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0005) followed target_user (@user0001)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:20.950775-0400 INFO user0009 is now following user0004.
# 2024-09-13T23:46:21.075654-0400 INFO user0005 is now following user0002.
# ➕ current_user (@user0009) followed target_user (@user0004)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0005) followed target_user (@user0002)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:21.514845-0400 INFO user0005 is now following user0002.
# ➕ current_user (@user0005) followed target_user (@user0002)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped Erica to @user0006
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:21.606319-0400 INFO user0002 is now following user0005.
# ➕ current_user (@user0002) followed target_user (@user0005)2024-09-13T23:46:21.666371-0400 INFO user0005 is now following user0008.
#
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Roger to @user0005
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0005) followed target_user (@user0008)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Ethan to @user0015
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:22.069691-0400 INFO user0010 is now following user0005.
# 2024-09-13T23:46:22.141909-0400 INFO user0005 is now following user0010.
# ➕ current_user (@user0010) followed target_user (@user0005)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Erica to @user0006
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0005) followed target_user (@user0010)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Ryan to @user0017
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:22.803614-0400 INFO user0005 is now following user0016.
# ➕ current_user (@user0005) followed target_user (@user0016)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Lucas to @user0019
# 2024-09-13T23:46:22.811503-0400 INFO user0005 is now following user0017.
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0005) followed target_user (@user0017)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:23.703656-0400 INFO user0005 is now following user0018.
# ➕ current_user (@user0005) followed target_user (@user0018)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:24.007178-0400 INFO user0017 is now following user0005.
# 2024-09-13T23:46:24.012776-0400 INFO user0006 is now following user0001.
# ➕ current_user (@user0017) followed target_user (@user0005)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Erica to @user0006
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0006) followed target_user (@user0001)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Liam to @user0007
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:24.802528-0400 INFO user0006 is now following user0005.
# 2024-09-13T23:46:24.807593-0400 INFO user0006 is now following user0002.
# ➕ current_user (@user0006) followed target_user (@user0005)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Olivia to @user0008
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0006) followed target_user (@user0002)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Liam to @user0007
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:24.897014-0400 INFO user0006 is now following user0002.
# ➕ current_user (@user0006) followed target_user (@user0002)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Jessica to @user0012
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:25.197169-0400 INFO user0006 is now following user0015.
# ➕ current_user (@user0006) followed target_user (@user0015)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Mark to @user0013
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:25.700549-0400 INFO user0002 is now following user0006.
# 2024-09-13T23:46:25.707425-0400 INFO user0006 is now following user0017.
# ➕ current_user (@user0002) followed target_user (@user0006)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Maggie to @user0018
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0006) followed target_user (@user0017)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Liam to @user0007
# 2024-09-13T23:46:25.839207-0400 INFO user0015 is now following user0006.
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:25.854074-0400 INFO user0006 is now following user0019.
# ➕ current_user (@user0015) followed target_user (@user0006)
# 🔗 Mapped Liam to @user0007
# 🔗 Mapped Lucas to @user0019
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:25.958620-0400 INFO user0007 is now following user0001.
# ➕ current_user (@user0006) followed target_user (@user0019)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Liam to @user0007
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0007) followed target_user (@user0001)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:26.717075-0400 INFO user0007 is now following user0002.
# ➕ current_user (@user0007) followed target_user (@user0002)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:27.013600-0400 INFO user0007 is now following user0006.
# ➕ current_user (@user0007) followed target_user (@user0006)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Glenn to @user0003
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:27.139746-0400 INFO user0006 is now following user0007.
# ➕ current_user (@user0006) followed target_user (@user0007)
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Olivia to @user0008
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:28.994394-0400 INFO user0007 is now following user0008.
# 2024-09-13T23:46:29.002609-0400 INFO user0007 is now following user0012.
# ➕ current_user (@user0007) followed target_user (@user0008)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0007) followed target_user (@user0012)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Mark to @user0013
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:29.133224-0400 INFO user0007 is now following user0019.
# 2024-09-13T23:46:29.113885-0400 ERROR An unexpected error occurred: ('Mastodon API returned error', 500, 'Internal Server Error', None)
# Traceback (most recent call last):
#
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#     │    └ <function Thread._bootstrap_inner at 0x7f506bf776a0>
#     └ <Thread(ThreadPoolExecutor-3_9, started 139978134771264)>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#     │    └ <function IPythonKernel._initialize_thread_hooks.<locals>.run_closure at 0x7f5068158040>
#     └ <Thread(ThreadPoolExecutor-3_9, started 139978134771264)>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#     │                     └ <Thread(ThreadPoolExecutor-3_9, started 139978134771264)>
#     └ <function Thread.run at 0x7f506bf77380>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#     │    │        │    │        │    └ {}
#     │    │        │    │        └ <Thread(ThreadPoolExecutor-3_9, started 139978134771264)>
#     │    │        │    └ (<weakref at 0x7f4f5057e2a0; to 'ThreadPoolExecutor' at 0x7f4f541199d0>, <_queue.SimpleQueue object at 0x7f4f54141fd0>, None,...
#     │    │        └ <Thread(ThreadPoolExecutor-3_9, started 139978134771264)>
#     │    └ <function _worker at 0x7f5069b30fe0>
#     └ <Thread(ThreadPoolExecutor-3_9, started 139978134771264)>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#     │         └ <function _WorkItem.run at 0x7f5069b31120>
#     └ <concurrent.futures.thread._WorkItem object at 0x7f4f3170cad0>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              │    │   │    │       │    └ {}
#              │    │   │    │       └ <concurrent.futures.thread._WorkItem object at 0x7f4f3170cad0>
#              │    │   │    └ ('Olivia', 'Liam')
#              │    │   └ <concurrent.futures.thread._WorkItem object at 0x7f4f3170cad0>
#              │    └ <bound method MastodonSocialNetworkApp.follow_user of MastodonSocialNetworkApp(perform_operations=True, _log_color='blue', _m...
#              └ <concurrent.futures.thread._WorkItem object at 0x7f4f3170cad0>
#
#   File "/mnt/c/Users/maxpu/Dropbox/scripts/Projects/socialsandbox/mastodon-sim/src/mastodon_sim/concordia/components/apps.py", line 476, in follow_user
#     self._mastodon_ops.follow(current_username, target_username)
#     │    │             │      │                 └ 'user0007'
#     │    │             │      └ 'user0008'
#     │    │             └ <function follow at 0x7f4f54de1e40>
#     │    └ <module 'mastodon_sim.mastodon_ops' from '/mnt/c/Users/maxpu/Dropbox/scripts/Projects/socialsandbox/mastodon-sim/src/mastodon...
#     └ MastodonSocialNetworkApp(perform_operations=True, _log_color='blue', _mastodon_ops=<module 'mastodon_sim.mastodon_ops' from '...
#
# > File "/mnt/c/Users/maxpu/Dropbox/scripts/Projects/socialsandbox/mastodon-sim/src/mastodon_sim/mastodon_ops/follow.py", line 30, in follow
#     mastodon.account_follow(account[0]["id"])
#     │        │              └ [{'id': 112922478353555882, 'username': 'user0007', 'acct': 'user0007', 'display_name': '', 'locked': False, 'bot': False, 'd...
#     │        └ <function Mastodon.account_follow at 0x7f4f55d642c0>
#     └ <mastodon.Mastodon.Mastodon object at 0x7f4f54332790>
#
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/decorator.py", line 232, in fun
#     return caller(func, *(extras + args), **kw)
#            │      │       │        │        └ {}
#            │      │       │        └ (<mastodon.Mastodon.Mastodon object at 0x7f4f54332790>, 112922478353555882, True, False)
#            │      │       └ ()
#            │      └ <function Mastodon.account_follow at 0x7f4f55d64040>
#            └ <function api_version.<locals>.api_min_version_decorator.<locals>.wrapper at 0x7f4f55d640e0>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/mastodon/utility.py", line 49, in wrapper
#     return function(self, *args, **kwargs)
#            │        │      │       └ {}
#            │        │      └ (112922478353555882, True, False)
#            │        └ <mastodon.Mastodon.Mastodon object at 0x7f4f54332790>
#            └ <function Mastodon.account_follow at 0x7f4f55d64040>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/mastodon/accounts.py", line 319, in account_follow
#     return self.__api_request('POST', f'/api/v1/accounts/{id}/follow', params)
#            │                                                           └ OrderedDict([('reblogs', '1'), ('notify', '0')])
#            └ <mastodon.Mastodon.Mastodon object at 0x7f4f54332790>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/mastodon/internals.py", line 297, in __api_request
#     raise ex_type('Mastodon API returned error', response_object.status_code, response_object.reason, error_msg)
#           │                                      │               │            │               │       └ None
#           │                                      │               │            │               └ 'Internal Server Error'
#           │                                      │               │            └ <Response [500]>
#           │                                      │               └ 500
#           │                                      └ <Response [500]>
#           └ <class 'mastodon.errors.MastodonInternalServerError'>
#
# mastodon.errors.MastodonInternalServerError: ('Mastodon API returned error', 500, 'Internal Server Error', None)
# ➕ current_user (@user0007) followed target_user (@user0019)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Emily to @user0014
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:29.142952-0400 INFO user0018 is now following user0007.
# ➕ current_user (@user0008) followed target_user (@user0007)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Maggie to @user0018
# ➕ current_user (@user0018) followed target_user (@user0007)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:29.687439-0400 INFO user0008 is now following user0002.
# ➕ current_user (@user0008) followed target_user (@user0002)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:29.878243-0400 INFO user0007 is now following user0018.
# ➕ current_user (@user0007) followed target_user (@user0018)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:30.028641-0400 INFO user0008 is now following user0001.
# 2024-09-13T23:46:30.087855-0400 INFO user0019 is now following user0007.
# 2024-09-13T23:46:30.114808-0400 INFO user0003 is now following user0008.
# ➕ current_user (@user0008) followed target_user (@user0001)
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0019) followed target_user (@user0007)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:30.137151-0400 INFO user0007 is now following user0013.
# ➕ current_user (@user0003) followed target_user (@user0008)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Janet to @user0010
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0007) followed target_user (@user0013)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Mark to @user0013
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:30.817503-0400 INFO user0008 is now following user0003.
# ➕ current_user (@user0008) followed target_user (@user0003)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Ethan to @user0015
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:31.744280-0400 INFO user0008 is now following user0013.
# ➕ current_user (@user0008) followed target_user (@user0013)
# 🔗 Mapped Ethan to @user0015
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:32.001498-0400 INFO user0008 is now following user0009.
# 2024-09-13T23:46:32.047151-0400 INFO user0009 is now following user0001.
# ➕ current_user (@user0008) followed target_user (@user0009)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Sophia to @user0016
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0009) followed target_user (@user0001)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:32.192623-0400 INFO user0008 is now following user0014.
# ➕ current_user (@user0008) followed target_user (@user0014)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Nina to @user0020
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:32.490650-0400 INFO user0008 is now following user0018.
# ➕ current_user (@user0008) followed target_user (@user0018)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:32.978908-0400 INFO user0009 is now following user0002.
# ➕ current_user (@user0009) followed target_user (@user0002)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:33.560964-0400 INFO user0009 is now following user0002.
# ➕ current_user (@user0009) followed target_user (@user0002)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:34.292924-0400 INFO user0009 is now following user0001.
# 2024-09-13T23:46:34.299133-0400 INFO user0001 is now following user0009.
# ➕ current_user (@user0009) followed target_user (@user0001)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0001) followed target_user (@user0009)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:34.471320-0400 INFO user0009 is now following user0015.
# ➕ current_user (@user0009) followed target_user (@user0015)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Janet to @user0010
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:34.509326-0400 INFO user0009 is now following user0013.
# ➕ current_user (@user0009) followed target_user (@user0013)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Mark to @user0013
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:34.684237-0400 INFO user0015 is now following user0009.
# ➕ current_user (@user0015) followed target_user (@user0009)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Sophia to @user0016
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:34.904099-0400 INFO user0009 is now following user0010.
# ➕ current_user (@user0009) followed target_user (@user0010)
# 🔗 Mapped Sophia to @user0016
# 🔗 Mapped Janet to @user0010
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:35.432657-0400 INFO user0009 is now following user0016.
# 2024-09-13T23:46:35.421664-0400 INFO user0016 is now following user0009.
# ➕ current_user (@user0009) followed target_user (@user0016)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Ryan to @user0017
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0016) followed target_user (@user0009)
# 🔗 Mapped Janet to @user0010
# 🔗 Mapped Nina to @user0020
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:35.586173-0400 INFO user0009 is now following user0020.
# ➕ current_user (@user0009) followed target_user (@user0020)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Janet to @user0010
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:36.270675-0400 INFO user0010 is now following user0001.
# 2024-09-13T23:46:36.304409-0400 INFO user0020 is now following user0009.
# ➕ current_user (@user0010) followed target_user (@user0001)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0020) followed target_user (@user0009)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:37.070012-0400 INFO user0010 is now following user0002.
# ➕ current_user (@user0010) followed target_user (@user0002)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:38.593182-0400 INFO user0010 is now following user0001.
# ➕ current_user (@user0010) followed target_user (@user0001)
# 🔗 Mapped Maria to @user0002
# 🔗 Mapped William to @user0011
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:39.010866-0400 INFO user0010 is now following user0009.
# ➕ current_user (@user0010) followed target_user (@user0009)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Glenn to @user0003
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:39.184690-0400 INFO user0009 is now following user0010.
# ➕ current_user (@user0009) followed target_user (@user0010)
# 🔗 Mapped William to @user0011
# 🔗 Mapped Janet to @user0010
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:39.379240-0400 INFO user0010 is now following user0013.
# ➕ current_user (@user0010) followed target_user (@user0013)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:46:39.728552-0400 INFO user0010 is now following user0017.
# 2024-09-13T23:46:39.923193-0400 INFO user0010 is now following user0016.
# ➕ current_user (@user0010) followed target_user (@user0017)
# 🔗 Mapped Jessica to @user0012
# 🔗 Mapped Maria to @user0002
# ...
# 2024-09-13T23:50:16.290177-0400 INFO user0018 is now following user0002.
# ➕ current_user (@user0018) followed target_user (@user0002)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:16.379544-0400 INFO user0017 is now following user0013.
# ➕ current_user (@user0017) followed target_user (@user0013)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:16.893827-0400 INFO user0002 is now following user0018.
# ➕ current_user (@user0002) followed target_user (@user0018)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Glenn to @user0003
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:17.068969-0400 INFO user0017 is now following user0018.
# ➕ current_user (@user0017) followed target_user (@user0018)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Erica to @user0006
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:18.370047-0400 INFO user0018 is now following user0003.
# ➕ current_user (@user0018) followed target_user (@user0003)
# 🔗 Mapped Erica to @user0006
# 🔗 Mapped Lucas to @user0019
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:18.385576-0400 ERROR An unexpected error occurred: ('Mastodon API returned error', 500, 'Internal Server Error', None)
# Traceback (most recent call last):
#
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/threading.py", line 995, in _bootstrap
#     self._bootstrap_inner()
#     │    └ <function Thread._bootstrap_inner at 0x7f506bf776a0>
#     └ <Thread(ThreadPoolExecutor-3_4, started 139978661631552)>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#     │    └ <function IPythonKernel._initialize_thread_hooks.<locals>.run_closure at 0x7f5068158040>
#     └ <Thread(ThreadPoolExecutor-3_4, started 139978661631552)>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#     │                     └ <Thread(ThreadPoolExecutor-3_4, started 139978661631552)>
#     └ <function Thread.run at 0x7f506bf77380>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#     │    │        │    │        │    └ {}
#     │    │        │    │        └ <Thread(ThreadPoolExecutor-3_4, started 139978661631552)>
#     │    │        │    └ (<weakref at 0x7f4f54422390; to 'ThreadPoolExecutor' at 0x7f4f541199d0>, <_queue.SimpleQueue object at 0x7f4f54141fd0>, None,...
#     │    │        └ <Thread(ThreadPoolExecutor-3_4, started 139978661631552)>
#     │    └ <function _worker at 0x7f5069b30fe0>
#     └ <Thread(ThreadPoolExecutor-3_4, started 139978661631552)>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#     │         └ <function _WorkItem.run at 0x7f5069b31120>
#     └ <concurrent.futures.thread._WorkItem object at 0x7f4f31744910>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              │    │   │    │       │    └ {}
#              │    │   │    │       └ <concurrent.futures.thread._WorkItem object at 0x7f4f31744910>
#              │    │   │    └ ('Glenn', 'Maggie')
#              │    │   └ <concurrent.futures.thread._WorkItem object at 0x7f4f31744910>
#              │    └ <bound method MastodonSocialNetworkApp.follow_user of MastodonSocialNetworkApp(perform_operations=True, _log_color='blue', _m...
#              └ <concurrent.futures.thread._WorkItem object at 0x7f4f31744910>
#
#   File "/mnt/c/Users/maxpu/Dropbox/scripts/Projects/socialsandbox/mastodon-sim/src/mastodon_sim/concordia/components/apps.py", line 476, in follow_user
#     self._mastodon_ops.follow(current_username, target_username)
#     │    │             │      │                 └ 'user0018'
#     │    │             │      └ 'user0003'
#     │    │             └ <function follow at 0x7f4f54de1e40>
#     │    └ <module 'mastodon_sim.mastodon_ops' from '/mnt/c/Users/maxpu/Dropbox/scripts/Projects/socialsandbox/mastodon-sim/src/mastodon...
#     └ MastodonSocialNetworkApp(perform_operations=True, _log_color='blue', _mastodon_ops=<module 'mastodon_sim.mastodon_ops' from '...
#
# > File "/mnt/c/Users/maxpu/Dropbox/scripts/Projects/socialsandbox/mastodon-sim/src/mastodon_sim/mastodon_ops/follow.py", line 30, in follow
#     mastodon.account_follow(account[0]["id"])
#     │        │              └ [{'id': 112922490937273348, 'username': 'user0018', 'acct': 'user0018', 'display_name': '', 'locked': False, 'bot': False, 'd...
#     │        └ <function Mastodon.account_follow at 0x7f4f55d642c0>
#     └ <mastodon.Mastodon.Mastodon object at 0x7f4f544174d0>
#
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/decorator.py", line 232, in fun
#     return caller(func, *(extras + args), **kw)
#            │      │       │        │        └ {}
#            │      │       │        └ (<mastodon.Mastodon.Mastodon object at 0x7f4f544174d0>, 112922490937273348, True, False)
#            │      │       └ ()
#            │      └ <function Mastodon.account_follow at 0x7f4f55d64040>
#            └ <function api_version.<locals>.api_min_version_decorator.<locals>.wrapper at 0x7f4f55d640e0>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/mastodon/utility.py", line 49, in wrapper
#     return function(self, *args, **kwargs)
#            │        │      │       └ {}
#            │        │      └ (112922490937273348, True, False)
#            │        └ <mastodon.Mastodon.Mastodon object at 0x7f4f544174d0>
#            └ <function Mastodon.account_follow at 0x7f4f55d64040>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/mastodon/accounts.py", line 319, in account_follow
#     return self.__api_request('POST', f'/api/v1/accounts/{id}/follow', params)
#            │                                                           └ OrderedDict([('reblogs', '1'), ('notify', '0')])
#            └ <mastodon.Mastodon.Mastodon object at 0x7f4f544174d0>
#   File "/home/mptouzel/miniconda3/envs/socsan2/lib/python3.11/site-packages/mastodon/internals.py", line 297, in __api_request
#     raise ex_type('Mastodon API returned error', response_object.status_code, response_object.reason, error_msg)
#           │                                      │               │            │               │       └ None
#           │                                      │               │            │               └ 'Internal Server Error'
#           │                                      │               │            └ <Response [500]>
#           │                                      │               └ 500
#           │                                      └ <Response [500]>
#           └ <class 'mastodon.errors.MastodonInternalServerError'>
#
# mastodon.errors.MastodonInternalServerError: ('Mastodon API returned error', 500, 'Internal Server Error', None)
# 2024-09-13T23:50:18.390715-0400 INFO user0018 is now following user0004.
# ➕ current_user (@user0003) followed target_user (@user0018)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Olivia to @user0008
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:18.392127-0400 INFO user0012 is now following user0018.
# ➕ current_user (@user0018) followed target_user (@user0004)
# 🔗 Mapped Olivia to @user0008
# 🔗 Mapped Lucas to @user0019
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0012) followed target_user (@user0018)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:18.476246-0400 INFO user0018 is now following user0010.
# ➕ current_user (@user0018) followed target_user (@user0010)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Lucas to @user0019
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:18.589080-0400 INFO user0013 is now following user0018.
# ➕ current_user (@user0013) followed target_user (@user0018)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped William to @user0011
# 2024-09-13T23:50:18.641461-0400 INFO user0018 is now following user0013.
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0018) followed target_user (@user0013)
# 🔗 Mapped Lucas to @user0019
# 🔗 Mapped Mark to @user0013
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:18.887499-0400 INFO user0019 is now following user0006.
# 2024-09-13T23:50:18.891941-0400 INFO user0019 is now following user0003.
# ➕ current_user (@user0019) followed target_user (@user0006)
# 🔗 Mapped Mark to @user0013
# 🔗 Mapped Lucas to @user0019
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0019) followed target_user (@user0003)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:18.910642-0400 INFO user0018 is now following user0012.
# 2024-09-13T23:50:18.913323-0400 INFO user0019 is now following user0002.
# ➕ current_user (@user0018) followed target_user (@user0012)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Maria to @user0002
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0019) followed target_user (@user0002)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Bill to @user0001
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:19.110734-0400 INFO user0019 is now following user0001.
# ➕ current_user (@user0019) followed target_user (@user0001)
# 🔗 Mapped Bill to @user0001
# 🔗 Mapped Nina to @user0020
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:20.564326-0400 INFO user0006 is now following user0019.
# ➕ current_user (@user0006) followed target_user (@user0019)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Robert to @user0009
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:21.503104-0400 INFO user0019 is now following user0009.
# ➕ current_user (@user0019) followed target_user (@user0009)
# 🔗 Mapped Robert to @user0009
# 🔗 Mapped Nina to @user0020
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:21.607326-0400 INFO user0008 is now following user0019.
# 2024-09-13T23:50:21.613050-0400 INFO user0019 is now following user0008.
# ➕ current_user (@user0008) followed target_user (@user0019)
# 🔗 Mapped Nina to @user0020
# 🔗 Mapped Maggie to @user0018
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0019) followed target_user (@user0008)
# 🔗 Mapped Maggie to @user0018
# 🔗 Mapped Nina to @user0020
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:21.694202-0400 INFO user0009 is now following user0019.
# ➕ current_user (@user0009) followed target_user (@user0019)
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:22.001914-0400 INFO user0019 is now following user0011.
# ➕ current_user (@user0019) followed target_user (@user0011)
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:22.102458-0400 INFO user0020 is now following user0002.
# ➕ current_user (@user0020) followed target_user (@user0002)
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:22.503167-0400 INFO user0001 is now following user0020.
# 2024-09-13T23:50:22.505133-0400 INFO user0019 is now following user0013.
# ➕ current_user (@user0001) followed target_user (@user0020)
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# ➕ current_user (@user0019) followed target_user (@user0013)
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:22.673342-0400 INFO user0020 is now following user0001.
# ➕ current_user (@user0020) followed target_user (@user0001)
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:22.700631-0400 INFO user0020 is now following user0001.
# ➕ current_user (@user0020) followed target_user (@user0001)
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:22.780767-0400 INFO user0013 is now following user0019.
# ➕ current_user (@user0013) followed target_user (@user0019)
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:22.905891-0400 INFO user0020 is now following user0009.
# ➕ current_user (@user0020) followed target_user (@user0009)
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:23.340337-0400 INFO user0020 is now following user0018.
# ➕ current_user (@user0020) followed target_user (@user0018)
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:23.388940-0400 INFO user0018 is now following user0020.
# ➕ current_user (@user0018) followed target_user (@user0020)
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# 2024-09-13T23:50:24.158845-0400 INFO user0009 is now following user0020.
# ➕ current_user (@user0009) followed target_user (@user0020)
# Ignoring already-following error: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'

# %%
# Update Mastodon display name for each person
from mastodon_sim import mastodon_ops
if USE_MASTODON_SERVER:
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [
            executor.submit(mastodon_ops.update_bio, user_mapping[name], display_name=name, bio="")
            for name in user_mapping
        ]

    # Optionally, wait for all tasks to complete
    for future in concurrent.futures.as_completed(futures):
        future.result()  # This will raise any exceptions that occurred during execution, if any
# Out:
# 2024-09-13T23:52:07.410157-0400 INFO user0002 successfully updated the display name and bio.
# 2024-09-13T23:52:07.464131-0400 INFO user0006 successfully updated the display name and bio.
# 2024-09-13T23:52:07.771459-0400 INFO user0007 successfully updated the display name and bio.
# 2024-09-13T23:52:07.890575-0400 INFO user0003 successfully updated the display name and bio.
# 2024-09-13T23:52:07.972877-0400 INFO user0010 successfully updated the display name and bio.
# 2024-09-13T23:52:07.977981-0400 INFO user0005 successfully updated the display name and bio.
# 2024-09-13T23:52:07.982168-0400 INFO user0004 successfully updated the display name and bio.
# 2024-09-13T23:52:07.984811-0400 INFO user0012 successfully updated the display name and bio.
# 2024-09-13T23:52:07.987173-0400 INFO user0001 successfully updated the display name and bio.
# 2024-09-13T23:52:07.988643-0400 INFO user0011 successfully updated the display name and bio.
# 2024-09-13T23:52:08.486144-0400 INFO user0009 successfully updated the display name and bio.
# 2024-09-13T23:52:08.687609-0400 INFO user0008 successfully updated the display name and bio.
# 2024-09-13T23:52:09.476910-0400 INFO user0013 successfully updated the display name and bio.
# 2024-09-13T23:52:09.532302-0400 INFO user0014 successfully updated the display name and bio.
# 2024-09-13T23:52:09.590603-0400 INFO user0016 successfully updated the display name and bio.
# 2024-09-13T23:52:09.609604-0400 INFO user0015 successfully updated the display name and bio.
# 2024-09-13T23:52:09.611813-0400 INFO user0019 successfully updated the display name and bio.
# 2024-09-13T23:52:09.685798-0400 INFO user0017 successfully updated the display name and bio.
# 2024-09-13T23:52:09.771242-0400 INFO user0020 successfully updated the display name and bio.
# 2024-09-13T23:52:09.782110-0400 INFO user0018 successfully updated the display name and bio.

# %%
from concurrent.futures import ThreadPoolExecutor

class SimpleGameRunner:
    """Simplified game master to run players with independent phone scene triggering in parallel."""

    def __init__(self, players, clock, action_spec, phones, model, memory, memory_factory):
        """
        Args:
            players: Dictionary of players.
            clock: Game clock to advance time.
            action_spec: Action specifications for the players.
            phones: Dictionary of phones associated with each player.
            model: Language model to process events.
            memory: Shared associative memory (could be unique per player if needed).
            memory_factory: Factory to create memory instances.
        """
        self.players = {player.name: player for player in players}
        self.clock = clock
        self.action_spec = action_spec
        self.phones = phones
        self.model = model
        self.memory = memory
        self.memory_factory = memory_factory
        self.player_components = self._create_player_components()
        self.log = []

    def _create_player_components(self):
        """Create a unique SceneTriggeringComponent for each player."""
        components = {}
        for player_name, player in self.players.items():
            components[player_name] = triggering.BasicSceneTriggeringComponent(
                player=player,
                phone=self.phones[player_name],
                model=self.model,
                memory=self.memory,
                clock=self.clock,
                memory_factory=self.memory_factory
            )
        return components

    def _step_player(self, player):
        """Run a single player's action and trigger their phone scene."""
        try:
            # 1. Player takes action
            action = player.act(self.action_spec)
            event_statement = f"{player.name} attempted action: {action}"

            # 2. Log the action (ensure this is thread-safe)
            self.log.append({
                'player': player.name,
                'action': action,
                'timestamp': self.clock.now(),
            })

            # 3. Trigger the phone scene for this player using their unique component
            self.player_components[player.name].update_after_event(event_statement)

            return event_statement
        except Exception as e:
            # Handle any player-specific exceptions
            return f"Error for {player.name}: {str(e)}"

    def step(self, active_players=None, timeout=5):
        """
        Run a step for the specified active players in parallel.

        Args:
            active_players: List of player names to take part in the step. If None, all players act.
            timeout: Timeout in seconds for each player's action.
        """
        if active_players is None:
            active_players = list(self.players.keys())

        # Use ThreadPoolExecutor to run each player's action and phone event handling in parallel
        with ThreadPoolExecutor() as executor:
            # Submit tasks to be run in parallel, but for each player, action and phone processing are sequential
            futures = {executor.submit(self._step_player, self.players[player_name.name]): player_name.name
                       for player_name in active_players}

            # Wait for all futures to complete, handle timeouts and exceptions
            for future in concurrent.futures.as_completed(futures, timeout=timeout):
                player_name = futures[future]
                try:
                    result = future.result(timeout=timeout)
                    print(f"Result for {player_name}: {result}")  # This will print the action outcome for each player
                except TimeoutError:
                    print(f"Timeout for {player_name}. Skipping their turn.")
                except Exception as e:
                    print(f"Error in thread for {player_name}: {str(e)}")

        # Advance the game clock after all players' actions are complete
        self.clock.advance()

    def run_game(self, steps=10):
        """Run the game for a given number of steps."""
        for _ in range(steps):
            self.step()  # By default, all players will act unless specified otherwise

# %% [markdown]
# ### Define a custom `CALL_TO_ACTION` prompt for the main Game Master
#
# This replaces the [default call to action](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/typing/entity.py#L51).
#
# Check out the `Calendar.ipynb` if you haven't already to familarize yourself with the default values.

# %%
from concordia.typing.entity import ActionSpec, OutputType


CUSTOM_CALL_TO_ACTION = """
Describe an activity on Storhampton.social that {name} would engage in for the next {timedelta}.
Choose actions together take about {timedelta} to complete.
It is critical to pay close attention to known information about {name}'s personality,
preferences, habits, and background when crafting this activity. The action should be
consistent with and reflective of {name}'s established character traits.

Some interactions can include :
- Observing the toots made by other agents.
- Posting on Storhampton.social
- Liking other toots
- Replying to the toots made by other agents.
- Boosting toots made by other agents


Example:

"Sarah checks her feed and replies if necessary. Then she may post a toot on Mastodon about her ideas on topic X on the lines of 'Just discovered an intriguing new language for low-latency systems programming.
Has anyone given it a try? Curious about potential real-world applications. 🤔
#TechNews #ProgrammingLanguages'"


Ensure your response is specific, creative, and detailed. Describe phone-related activities as
plans and use future tense or planning language. Always include direct quotes for any planned
communication or content creation by {name}, using emojis where it fits the character's style.
Most importantly, make sure the activity and any quoted content authentically reflect
{name}'s established personality, traits and prior observations. Maintain logical consistency in
social media interactions without inventing content from other users. Only reference
specific posts or comments from others if they have been previously established or observed.

"""


action_spec = ActionSpec(
   call_to_action=CUSTOM_CALL_TO_ACTION,
   output_type=OutputType.FREE,
   tag="action",
)

# %% [markdown]
# ### Define custom thought chains for the main Game Master
#
# This replaces the [default thought chains](https://github.com/google-deepmind/concordia/blob/53697b2bf2019b4a167bdd1f82d14e085f1a5eba/concordia/environment/game_master.py#L38).

# %%
# Create the game master object

# Experimental version (custom call to action and thought chains)
env = SimpleGameRunner(
    model=model,
    memory=game_master_memory,
    phones=phones,
    clock=clock,
    players=players,
    action_spec=action_spec,
    memory_factory=blank_memory_factory
)

# %%
def write_seed_toot(players,p_name):
    for player in players:
        if player.name == p_name:
            call_to_speech = DEFAULT_CALL_TO_SPEECH.format(
            name=player.name,
            )
            interaction_premise = f"{player.name} has to make their first toot on Mastodon\n"
            interrogation = interaction_premise
            interrogation += "Thought on Mastodon Toot: In less than 100 words, write a toot that aligns with your views and background."
            player_says = player.act(action_spec=entity.ActionSpec(call_to_action="Context: " + interrogation +call_to_speech, output_type=entity.OutputType.FREE),)
            player_says = player_says.strip(player.name.split()[0]).strip().strip(player.name.split()[1]).strip().strip("--").strip().strip('"')
            print(player.get_last_log())
            return player_says

# %%
# import threading
# import pickle

# def clean_for_serialization(entity_agent):
#     """Removes unpicklable objects like locks before serialization."""
#     # Reset locks (you can also reinitialize them after loading)
#     entity_agent._control_lock = None
#     entity_agent._phase_lock = None

#     # If context processors are problematic, you can reset or exclude them as well
#     entity_agent._context_processor = None

#     return entity_agent


# for player in players:
#     clean_for_serialization(player)
# with open('my_object.pkl', 'wb') as f:
#     pickle.dump(players, f)

# %% [markdown]
# ## The RUN

# %%
# Set the clock to the start time
clock.set(START_TIME)

# %%
# Add some observations to seed the players with
for player in players:
  player.observe( f"{player.name} is at home, they have just woken up.")
  player.observe( f"{player.name} remembers they want to update their Mastodon bio.")
  player.observe( f"{player.name} remembers they want to read their Mastodon feed to catch up on news")

# %%
# Parallelize the loop using ThreadPoolExecutor
with concurrent.futures.ThreadPoolExecutor() as executor:
    # Submit tasks for each agent
    futures = [
        executor.submit(
            lambda agent=agent: (
                None if agent["seed_toot"] == "-" else
                mastodon_app.post_toot(agent["name"], status=agent["seed_toot"]) if agent["seed_toot"] else
                mastodon_app.post_toot(agent["name"], status=write_seed_toot(players, agent["name"]))
            )
        )
        for agent in data["agents"]
    ]

    # Optionally, wait for all tasks to complete
    for future in concurrent.futures.as_completed(futures):
        future.result()  # This will raise any exceptions that occurred in the thread, if any
# Out:
# {'IdentityWithoutPreAct': {'Key': '\nIdentity characteristics', 'Queries': 'core characteristics, current daily occupation, feeling about recent progress in life', 'State': 'core characteristics: a community-oriented leader with a strong commitment to grassroots engagement and sustainable development. He values shared narratives and has a deep understanding of the local economy, balancing growth with community welfare. His communication skills and determination to address local challenges reflect both nostalgia for his past experiences and a desire to create meaningful change in Storhampton.\ncurrent daily occupation: actively campaigning for the mayoral position in Storhampton, focusing on community engagement and economic development.\nfeeling about recent progress in life: feeling a mix of nostalgia and determination regarding his recent progress in life. His early experiences in Storhampton instilled in him a deep appreciation for community connections, which he now aims to leverage in his campaign. Despite facing criticism, he remains committed to addressing local challenges and fostering economic growth while ensuring community welfare.'}, 'ObservationSummary': {'Key': '\nSummary of recent observations', 'Value': '01 Oct 2024 [04:02:40  - 07:02:40]:  Bill Fredrickson has exhibited notable changes in behavior and engagement levels during recent activities. His interactions suggest a shift in focus and interest.', 'Chain of thought': ['', '', 'Recent observations of Bill Fredrickson:', '[]', '', 'Question: Summarize the observations above into one or two sentences.', 'Answer: Bill Fredrickson has exhibited notable changes in behavior and engagement levels during recent activities. His interactions suggest a shift in focus and interest.']}, 'SelfPerception': {'Key': '\nQuestion: What kind of person is Bill Fredrickson?\nAnswer', 'Summary': 'Given the above, what kind of person is Bill Fredrickson?', 'State': 'Bill Fredrickson is a community-oriented leader who prioritizes grassroots engagement and sustainable development. He possesses strong communication skills and a deep understanding of the local economy, striving to balance growth with the welfare of the community. His experiences have shaped a nostalgic yet determined approach to creating meaningful change in Storhampton, even in the face of criticism.', 'Chain of thought': ['Recent observations of Bill Fredrickson:', '[03 Jul 2007 00:00:00]   When Bill Fredrickson was 23 years old, he attended a heated debate about the future of local industries, where he encountered strong opposition from residents wary of change. Despite his nervousness, he stood up to present his vision for a balanced approach that included both job preservation and environmental protection. This moment tested his resolve and helped him develop the resilience needed to navigate the complexities of leadership in his community.', '[01 Oct 2024 08:00:00] Your home timeline shows toots from people you follow and boosted (reblogged) content.', '[01 Oct 2024 08:00:00] Toots can be up to 500 characters long, allowing for more detailed expressions than some other platforms.', "[01 Oct 2024 08:00:00] [Plan to improve perception] Bill Fredrickson's general plan for improving their perception: 1. **Engage Actively with the Community**: Bill should regularly create posts that invite feedback from residents on his policy proposals. This could include polls or open-ended questions about local issues, demonstrating that he values their opinions and wants to be responsive to their concerns.", "[01 Oct 2024 08:00:00] To share content on Mastodon, you write a 'toot' (equivalent to a tweet or post).", '[01 Oct 2024 08:00:00] Maria Gutierrez campaigns on increasing environmental regulation of local industries to improve the health of the local environment.', '[01 Oct 2024 08:00:00] Bill Fredrickson campaigns on lowering taxes on local industries to save jobs and providing subsidies to attract green industries and crea ...
# 🔗 Mapped Bill to @user0001
# {'IdentityWithoutPreAct': {'Key': '\nIdentity characteristics', 'Queries': 'core characteristics, current daily occupation, feeling about recent progress in life', 'State': 'core characteristics: an environmentally conscious leader dedicated to community service and public health advocacy. She actively engages with her community, promotes initiatives for local ecosystems, and campaigns for stricter environmental regulations. Her proactive and optimistic approach, combined with a collaborative spirit, underscores her commitment to fostering meaningful change and creating a healthier, more sustainable environment for her community.\ncurrent daily occupation: actively engaged in her role as an environmental advocate and community leader. She focuses on campaigning for stricter environmental regulations while fostering connections with her supporters through social media interactions.\nfeeling about recent progress in life: optimistic about her recent progress in life, actively engaging with her community and supporters while promoting environmental initiatives. She feels inspired by the positive feedback she receives and is dedicated to fostering collaboration and meaningful change in her local ecosystem.'}, "Maria Gutierrez's plan to win public perception": {'Key': "Maria Gutierrez's general plan for improving their perception:", 'Summary': "Given the information on the public perception of both candidates, their policy proposals, recent observations, and Maria Gutierrez's persona.: Generate a general plan for Maria Gutierrez to win public perception to their side. Remember that Maria Gutierrez will only be operating on the Mastodon server where possible actions are: liking posts, replying to posts, creating posts, boosting (retweeting) posts, following other users, etc. User cannot send direct messages.", 'State': "Maria Gutierrez's general plan for improving their perception: 1. **Create Engaging Content**: Regularly post informative and visually appealing content that highlights the benefits of stricter environmental regulations, focusing on how these policies can lead to a healthier community and improved public health.", 'Chain of thought': ['Recent observations of Maria Gutierrez:', '[01 Oct 2024 08:00:40] [self reflection] Maria Gutierrez is a dedicated and proactive leader who is deeply committed to environmental issues and community service. She actively advocates for stricter environmental regulations and engages with her community through various initiatives, reflecting her optimism and collaborative spirit. Her focus on public health and local ecosystems highlights her passion for meaningful change and her desire to create a healthier, more sustainable environment for her community.', '[01 Oct 2024 08:00:40] [observation] [Action done on phone] : Error invoking action like_toot: No username found for display name: user0002', "[01 Oct 2024 08:00:40] [Plan to improve perception] Maria Gutierrez's general plan for improving their perception: 1. **Amplify Environmental Messaging**: Regularly create posts that highlight the importance of stricter environmental regulations and how they benefit the community's health. Share success stories from other regions that have implemented similar policies to illustrate potential positive outcomes.", "[01 Oct 2024 08:00:50] [observation] [Action done on phone] : Error invoking action like_toot: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'", "[01 Oct 2024 08:00:50] [Plan to improve perception] Maria Gutierrez's general plan for improving their perception: 1. **Strengthen Community Engagement**: Actively like and reply to posts from supporters and constituents, expressing gratitude for their support and sharing her vision for a healthier environment. This will foster a sense of community and loyalty.", '[01 Oct 2024 08:00:50] [self reflection] Maria Gutierrez is an environmentally conscious leader who is deeply committe ...
# 🔗 Mapped Maria to @user0002
# 2024-09-14T00:00:31.781956-0400 INFO user0002 successfully posted the status.
# 📝 Status posted for user: Maria (user0002): "Good morning, Storhampton! 🌱 Let's come together to advocate for stronger environmental regulations that protect our health and future. A cleaner, greener community starts with us! #EcoFriendly #Vote2024"
# 2024-09-14T00:00:31.867332-0400 INFO user0001 successfully posted the status.
# 📝 Status posted for user: Bill (user0001): "Good morning, Storhampton! I'm excited to connect with everyone here. Together, we can create a thriving community by lowering taxes for local industries and attracting green jobs. Let's work towards a sustainable future for our town!"
# {}
# 🔗 Mapped Robert to @user0009
# 2024-09-14T00:00:34.666999-0400 INFO user0009 successfully posted the status.
# 📝 Status posted for user: Robert (user0009): "Looking forward to the election! It's crucial we focus on job security and support candidates who prioritize our local industries. Let's keep our economy strong!"
# {}
# 🔗 Mapped Janet to @user0010
# {}
# 🔗 Mapped William to @user0011
# {}
# 🔗 Mapped Jessica to @user0012
# {}
# 🔗 Mapped Roger to @user0005
# 2024-09-14T00:00:36.295091-0400 INFO user0010 successfully posted the status.
# 📝 Status posted for user: Janet (user0010): "Excited to catch up on the news this morning! It's important to stay informed, especially with the election coming up. Let's prioritize job stability and growth in our community!"
# {}
# 🔗 Mapped Glenn to @user0003
# {}
# 🔗 Mapped Liam to @user0007
# {}
# 🔗 Mapped Olivia to @user0008
# {}
# 🔗 Mapped Denise to @user0004
# 2024-09-14T00:00:36.981523-0400 INFO user0011 successfully posted the status.
# 📝 Status posted for user: William (user0011): "Excited to catch up on the latest news today! Remember to vote in the upcoming election; our jobs depend on it!"
# 2024-09-14T00:00:37.265100-0400 INFO user0005 successfully posted the status.
# 📝 Status posted for user: Roger (user0005): "Excited to catch up on the news today! Remember to vote in the upcoming election—let's prioritize job security and economic growth for our community!"
# 2024-09-14T00:00:37.293567-0400 INFO user0012 successfully posted the status.
# 📝 Status posted for user: Jessica (user0012): "Excited to start the day! Remember to vote today—our choices matter for our community's future. Let's ensure our voices are heard!"
# 2024-09-14T00:00:38.058777-0400 INFO user0003 successfully posted the status.
# 📝 Status posted for user: Glenn (user0003): "Excited to catch up on the news today! Remember, we need to focus on job security and economic growth in Storhampton. Let's make informed choices in this election!"
# 2024-09-14T00:00:38.184226-0400 INFO user0007 successfully posted the status.
# 📝 Status posted for user: Liam (user0007): "As we approach the election, let's remember that job security is vital for our community's future. We need leaders who prioritize local industries and support economic growth! 💼 #StorhamptonVotes"
# 2024-09-14T00:00:38.309139-0400 INFO user0004 successfully posted the status.
# 📝 Status posted for user: Denise (user0004): "Just woke up and catching up on the news. Family comes first, but I worry about our jobs and the economy. Let's make sure we support candidates who prioritize our livelihoods!"
# 2024-09-14T00:00:38.504754-0400 INFO user0008 successfully posted the status.
# 📝 Status posted for user: Olivia (user0008): "Excited to share my thoughts on the upcoming election! It's crucial we find a balance between supporting local industries and protecting our environment. Let's prioritize job stability while working towards a greener future! 🌍💼 #Election2024 #EconomyVsEnvironment"
# {}
# 🔗 Mapped Emily to @user0014
# {}
# 🔗 Mapped Mark to @user0013
# {}
# 🔗 Mapped Ethan to @user0015
# {}
# 🔗 Mapped Sophia to @user0016
# 2024-09-14T00:00:48.386447-0400 INFO user0014 successfully posted the status.
# 📝 Status posted for user: Emily (user0014): "Good morning, Storhampton! Just woke up and ready to tackle the day. Excited to catch up on the latest news and see how the mayoral race is shaping up. Remember to vote and support the future of our community!"
# 2024-09-14T00:00:48.715312-0400 INFO user0013 successfully posted the status.
# 📝 Status posted for user: Mark (user0013): "Good morning, Storhampton! As we gear up for the election, let's remember the importance of job security for our families. It's crucial to support candidates who prioritize our livelihoods while balancing environmental concerns. Every vote counts! 💪 #VoteSmart"
# 2024-09-14T00:00:48.975882-0400 INFO user0015 successfully posted the status.
# 📝 Status posted for user: Ethan (user0015): "Excited to catch up on the news today! Looking forward to seeing how the mayoral candidates address job stability and our community's future. Let's make informed choices!"
# 2024-09-14T00:00:49.203525-0400 INFO user0016 successfully posted the status.
# 📝 Status posted for user: Sophia (user0016): "Excited to start my day! Looking forward to catching up on the news and staying informed about the upcoming election. Let's make our voices heard!"
# {}
# 🔗 Mapped Nina to @user0020
# {}
# 🔗 Mapped Lucas to @user0019
# 2024-09-14T00:00:50.847271-0400 INFO user0020 successfully posted the status.
# 📝 Status posted for user: Nina (user0020): "Excited to engage with my community this election season! Let's prioritize job stability and support local industries for a thriving future. Every vote counts! #StorhamptonElection #CommunityFirst"
# {}
# 🔗 Mapped Ryan to @user0017
# 2024-09-14T00:00:51.420242-0400 INFO user0019 successfully posted the status.
# 📝 Status posted for user: Lucas (user0019): "Excited to catch up on the local election news today. It's crucial we prioritize job stability while considering the future of our community. Let's make informed choices!"
# 2024-09-14T00:00:51.960671-0400 INFO user0017 successfully posted the status.
# 📝 Status posted for user: Ryan (user0017): "Just woke up and ready to tackle the day. Remember to vote in the upcoming election—it's crucial for our community's future. Let's think about what really matters: jobs and stability. #Election2024"
# {}
# 🔗 Mapped Maggie to @user0018
# 2024-09-14T00:00:53.698646-0400 INFO user0018 successfully posted the status.
# 📝 Status posted for user: Maggie (user0018): "Excited to catch up on the latest news today! As we head into the election, let's remember how important job stability is for our community. Looking forward to seeing how candidates address these issues!"
# {}
# 🔗 Mapped Erica to @user0006
# 2024-09-14T00:01:33.832720-0400 INFO user0006 successfully posted the status.
# 📝 Status posted for user: Erica (user0006): "Excited to catch up on the news today! Balancing job security and environmental concerns is tough, but I believe we can find a way to support both local industries and a healthier planet. Let's make informed choices this election!"
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 17
#      15 # Optionally, wait for all tasks to complete
#      16 for future in concurrent.futures.as_completed(futures):
# ---> 17     future.result()  # This will raise any exceptions that occurred in the thread, if any
#
# File ~/miniconda3/envs/socsan2/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniconda3/envs/socsan2/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/miniconda3/envs/socsan2/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# Cell In[36], line 9, in <lambda>(agent)
#       1 # Parallelize the loop using ThreadPoolExecutor
#       2 with concurrent.futures.ThreadPoolExecutor() as executor:
#       3     # Submit tasks for each agent
#       4     futures = [
#       5         executor.submit(
#       6             lambda agent=agent: (
#       7                 None if agent["seed_toot"] == "-" else
#       8                 mastodon_app.post_toot(agent["name"], status=agent["seed_toot"]) if agent["seed_toot"] else
# ----> 9                 mastodon_app.post_toot(agent["name"], status=write_seed_toot(players, agent["name"]))
#      10             )
#      11         )
#      12         for agent in data["agents"]
#      13     ]
#      15     # Optionally, wait for all tasks to complete
#      16     for future in concurrent.futures.as_completed(futures):
#
# File /mnt/c/Users/maxpu/Dropbox/scripts/Projects/socialsandbox/mastodon-sim/src/mastodon_sim/concordia/components/apps.py:668, in MastodonSocialNetworkApp.post_toot(self, current_user, status)
#     666 return_msg = f'{current_user} posted a toot!: "{status}"'
#     667 with file_lock:
# --> 668     with open(
#     669         "/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt", "a"
#     670     ) as f:
#     671         f.write(f"{current_user} posted\n")
#     672 return return_msg
#
# FileNotFoundError: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'

# %%
print(clock.now())
# Possible minutes to pick from
minutes_choices = [0, 30]

# Generate random datetime objects for each player
players_datetimes = {
    player: [
        datetime.datetime.now().replace(hour=random.randint(0, 23),
                                        minute=random.choice(minutes_choices),
                                        second=0,
                                        microsecond=0)  # Zeroing out seconds and microseconds for cleaner output
        for _ in range(15 if player.name in malicious_agents else 5)
    ] for player in players
}

print(players_datetimes)
# Out:
# 2024-10-01 08:02:40
# {<concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f54336490>: [datetime.datetime(2024, 9, 14, 5, 0), datetime.datetime(2024, 9, 14, 0, 30), datetime.datetime(2024, 9, 14, 3, 0), datetime.datetime(2024, 9, 14, 1, 30), datetime.datetime(2024, 9, 14, 15, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f54424ed0>: [datetime.datetime(2024, 9, 14, 1, 0), datetime.datetime(2024, 9, 14, 21, 30), datetime.datetime(2024, 9, 14, 19, 0), datetime.datetime(2024, 9, 14, 3, 0), datetime.datetime(2024, 9, 14, 11, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f542d8c90>: [datetime.datetime(2024, 9, 14, 11, 0), datetime.datetime(2024, 9, 14, 18, 0), datetime.datetime(2024, 9, 14, 21, 0), datetime.datetime(2024, 9, 14, 22, 30), datetime.datetime(2024, 9, 14, 14, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f542dca10>: [datetime.datetime(2024, 9, 14, 10, 0), datetime.datetime(2024, 9, 14, 11, 30), datetime.datetime(2024, 9, 14, 22, 30), datetime.datetime(2024, 9, 14, 15, 30), datetime.datetime(2024, 9, 14, 14, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f54125750>: [datetime.datetime(2024, 9, 14, 18, 0), datetime.datetime(2024, 9, 14, 13, 0), datetime.datetime(2024, 9, 14, 17, 0), datetime.datetime(2024, 9, 14, 20, 0), datetime.datetime(2024, 9, 14, 19, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f543e15d0>: [datetime.datetime(2024, 9, 14, 19, 0), datetime.datetime(2024, 9, 14, 15, 0), datetime.datetime(2024, 9, 14, 0, 30), datetime.datetime(2024, 9, 14, 5, 30), datetime.datetime(2024, 9, 14, 2, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f5440ffd0>: [datetime.datetime(2024, 9, 14, 11, 30), datetime.datetime(2024, 9, 14, 1, 0), datetime.datetime(2024, 9, 14, 21, 30), datetime.datetime(2024, 9, 14, 4, 30), datetime.datetime(2024, 9, 14, 1, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f5604b3d0>: [datetime.datetime(2024, 9, 14, 14, 30), datetime.datetime(2024, 9, 14, 16, 0), datetime.datetime(2024, 9, 14, 7, 0), datetime.datetime(2024, 9, 14, 1, 0), datetime.datetime(2024, 9, 14, 5, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f5440dfd0>: [datetime.datetime(2024, 9, 14, 10, 30), datetime.datetime(2024, 9, 14, 20, 30), datetime.datetime(2024, 9, 14, 6, 0), datetime.datetime(2024, 9, 14, 23, 0), datetime.datetime(2024, 9, 14, 3, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f54149fd0>: [datetime.datetime(2024, 9, 14, 22, 30), datetime.datetime(2024, 9, 14, 8, 30), datetime.datetime(2024, 9, 14, 3, 0), datetime.datetime(2024, 9, 14, 15, 30), datetime.datetime(2024, 9, 14, 16, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f54133f10>: [datetime.datetime(2024, 9, 14, 13, 30), datetime.datetime(2024, 9, 14, 18, 0), datetime.datetime(2024, 9, 14, 1, 30), datetime.datetime(2024, 9, 14, 11, 0), datetime.datetime(2024, 9, 14, 9, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f54327a10>: [datetime.datetime(2024, 9, 14, 15, 0), datetime.datetime(2024, 9, 14, 23, 0), datetime.datetime(2024, 9, 14, 12, 0), datetime.datetime(2024, 9, 14, 10, 0), datetime.datetime(2024, 9, 14, 8, 0)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f542ee250>: [datetime.datetime(2024, 9, 14, 15, 0), datetime.datetime(2024, 9, 14, 12, 0), datetime.datetime(2024, 9, 14, 0, 0), datetime.datetime(2024, 9, 14, 14, 30), datetime.datetime(2024, 9, 14, 19, 30)], <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f543c8110>: [datetime.datetime(2024, 9, 14, 8, 30), datetime.datetime(2024, 9, 14, 8, 0), datetime.datetime(2024, 9, 14, 2, 0), da ...

# %%
import time
import json
import cProfile
import pstats
import pickle
import copy

# Define the function that writes logs for a player
def process_player(player, candidate_agents, agent_config_filename):
    result = []

    # Check votes
    ans = check_vote(candidate_agents, player)
    result.append((f"{player.name} votes for {ans}\n", agent_config_filename + "votes_log.txt"))

    # Check political scores
    c1 = check_pol(candidate_agents[0], player)
    c2 = check_pol(candidate_agents[1], player)
    result.append((f"{player.name} gives {candidate_agents[0].split()[0]} a score of {c1}\n", agent_config_filename + "pol_log.txt"))
    result.append((f"{player.name} gives {candidate_agents[1].split()[0]} a score of {c2}\n", agent_config_filename + "pol_log.txt"))

    return result

def write_logs(results):
    # Write the results to the respective files
    for content, file_name in results:
        with open(file_name, "a") as f:
            f.write(content)


def read_token_data(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
            return data
    except FileNotFoundError:
        return {'prompt_tokens': 0, 'completion_tokens': 0}

episode_length = 240 #961
time_intervals=[]
prompt_token_intervals = []
completion_token_intervals = []
player_copy_list=[]
# with open("../reports/players_all_timesteps.pkl", "wb") as file:
if True:
    start_time = time.time()  # Start timing
    for i in range(episode_length):
    # Parallelize the process using ThreadPoolExecutor
        if i!=0:
            with concurrent.futures.ThreadPoolExecutor() as executor:
                # Write the episode logs
                    executor.submit(write_logs, [(f"Episode: {i}\n", agent_config_filename + "votes_log.txt")])
                    executor.submit(write_logs, [(f"Episode: {i}\n", agent_config_filename + "pol_log.txt")])
                    # Process each player in parallel
                    futures = [executor.submit(process_player, p, candidate_agents, agent_config_filename) for p in players]

                    # Write each player's results in parallel
                    for future in concurrent.futures.as_completed(futures):
                        player_results = future.result()
                        executor.submit(write_logs, player_results)
        print(f"Episode: {i}")
        with open("app_logger.txt","a") as a:
            a.write(f"Episode: {i}")

        start_timex = time.time()
        matching_players = []
        # Loop through each player and their associated datetime objects
        for player_name, datetimes in players_datetimes.items():
            added = False  # Flag to check if player was already added
            for datetime_obj in datetimes:
                # Check if the hour and minute match the current time (ignoring seconds and microseconds)
                if datetime_obj.time().hour == clock.now().hour and datetime_obj.time().minute == clock.now().minute:
                    matching_players.append(player_name)
                    added = True
                    break

            # If player is not added by matching time, check for random addition (15% chance)
            if not added and random.random() < 0.15:
                matching_players.append(player_name)

        print(time.time() - start_timex)

        # Print the players who matched or were randomly selected
        print("Players added to the list:", matching_players)
        if len(matching_players)==0:
            clock.advance()
        else:
            env.step(active_players = matching_players)
            end_timex = time.time()
            with open("time_logger.txt", "a") as f:
                f.write(f"Episode with {len(matching_players)} finished - took {end_timex - start_timex}\n")
    # pickle.dump(players, file)
# Out:
# Episode: 0
# 0.0003457069396972656
# Players added to the list: [<concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f542d8c90>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f54125750>, <concordia.agents.entity_agent_with_logging.EntityAgentWithLogging object at 0x7f4f543c8110>]
# Starting phone scene
# Built phone scene
# Starting phone scene
# Built phone scene
# Starting phone scene
# Built phone scene
# Inside phone_update_after_event
# Self state:
# 🔗 Mapped Glenn to @user0003
# 2024-09-14T00:03:10.276061-0400 INFO user0003 retrieved 10 posts from their timeline (filter: all).
# Inside phone_update_after_event
# Self state: You retrieved your timeline
#
# True
# False
# 0
# True
# Processing Toot IDx
# 🔗 Mapped Glenn to @user0003
# user0003
# 2024-09-14T00:03:20.201003-0400 INFO user0003 retrieved 10 posts from their timeline (filter: all).
# Got ID from Mastodon
# 113133908910647853
# Continuing action!
# Attempting to invoke action 'boost_toot' with the argument_text:
# current_user: Glenn
# target_user: Ryan
# toot_id: 113133908910647853
# Invoking action boost_toot with arguments {'current_user': 'Glenn', 'target_user': 'Ryan', 'toot_id': '113133908910647853'}
# 🔗 Mapped Glenn to @user0003
# 🔗 Mapped Ryan to @user0017
# 🔁 @user0003 boosting post 113133908910647853
# 2024-09-14T00:03:21.967546-0400 INFO user0003 boosted post 113133908910647853 from user0017.
# ✅ @user0003 boosted post 113133908910647853
# Error invoking action boost_toot: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# Phone action result observed.
# Inside phone_update_after_event
# Self state:
# 🔗 Mapped Roger to @user0005
# 2024-09-14T00:03:36.938605-0400 INFO user0005 retrieved 10 posts from their timeline (filter: all).
# Inside phone_update_after_event
# Self state: You retrieved your timeline
#
# True
# False
# 0
# True
# Processing Toot IDx
# 🔗 Mapped Roger to @user0005
# user0005
# 2024-09-14T00:03:47.051227-0400 INFO user0005 retrieved 10 posts from their timeline (filter: all).
# Got ID from Mastodon
# 113133908026464258
# Continuing action!
# Attempting to invoke action 'boost_toot' with the argument_text:
# current_user: Roger
# target_user: Olivia
# toot_id: 113133908026464258
# Invoking action boost_toot with arguments {'current_user': 'Roger', 'target_user': 'Olivia', 'toot_id': '113133908026464258'}
# 🔗 Mapped Roger to @user0005
# 🔗 Mapped Olivia to @user0008
# 🔁 @user0005 boosting post 113133908026464258
# 2024-09-14T00:03:49.677836-0400 INFO user0005 boosted post 113133908026464258 from user0008.
# ✅ @user0005 boosted post 113133908026464258
# Error invoking action boost_toot: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# Phone action result observed.
# Inside phone_update_after_event
# Self state:
# 🔗 Mapped Emily to @user0014
# 2024-09-14T00:03:56.431187-0400 INFO user0014 retrieved 10 posts from their timeline (filter: all).
# Inside phone_update_after_event
# Self state: You retrieved your timeline
#
# False
# 3
# True
# Processing Toot IDx
# 🔗 Mapped Emily to @user0014
# user0014
# 2024-09-14T00:04:05.132930-0400 INFO user0014 retrieved 10 posts from their timeline (filter: all).
# Got ID from Mastodon
# 113133908875277375
# Continuing action!
# Attempting to invoke action 'like_toot' with the argument_text:
# current_user: Emily
# target_user: Lucas
# toot_id: 113133908875277375
# Invoking action like_toot with arguments {'current_user': 'Emily', 'target_user': 'Lucas', 'toot_id': '113133908875277375'}
# 🔗 Mapped Emily to @user0014
# 🔗 Mapped Lucas to @user0019
# ❤️ @user0014 liking post 113133908875277375 from @user0019
# 2024-09-14T00:04:06.768827-0400 INFO user0014 liked post 113133908875277375 from user0019.
# ✅ Emily (@user0014) liked post 113133908875277375 from Lucas (@user0019)
# Error invoking action like_toot: [Errno 2] No such file or directory: '/scratch/ss14247/misinfo_simulator/mastodon-sim/notebooks/app_logger.txt'
# Phone action result observed.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 88
#      86     clock.advance()
#      87 else:
# ---> 88     env.step(active_players = matching_players)
#      89     end_timex = time.time()
#      90     with open("time_logger.txt", "a") as f:
#
# Cell In[26], line 81, in SimpleGameRunner.step(self, active_players, timeout)
#      77 futures = {executor.submit(self._step_player, self.players[player_name.name]): player_name.name
#      78            for player_name in active_players}
#      80 # Wait for all futures to complete, handle timeouts and exceptions
# ---> 81 for future in as_completed(futures, timeout=timeout):
#      82     player_name = futures[future]
#      83     try:
#
# NameError: name 'as_completed' is not defined

# %% [markdown]
# ## Summary and analysis of the episode

# %%
# Summarize the entire story
all_gm_memories = env._memory.retrieve_recent(k=10000, add_time=True)

detailed_story = "\n".join(all_gm_memories)
print("len(detailed_story): ", len(detailed_story))
# print(detailed_story)

episode_summary = model.sample_text(
    f"Sequence of events:\n{detailed_story}"
    "\nNarratively summarize the above temporally ordered "
    "sequence of events. Write it as a news report. Summary:\n",
     max_tokens=3500,
     terminators=(),
)
print(episode_summary)

# %%
# Summarise the perspective of each player
player_logs = []
player_log_names = []
for player in players:
  name = player.name
  detailed_story = "\n".join(memories[player.name].retrieve_recent(
      k=1000, add_time=True))
  summary = ""
  summary = model.sample_text(
      f"Sequence of events that happened to {name}:\n{detailed_story}"
      "\nWrite a short story that summarises these events.\n",
       max_tokens=3500,
       terminators=()
)

  all_player_mem = memories[player.name].retrieve_recent(k=1000, add_time=True)
  all_player_mem = ["Summary:", summary, "Memories:", *all_player_mem]
  player_html = html_lib.PythonObjectToHTMLConverter(all_player_mem).convert()
  player_logs.append(player_html)
  player_log_names.append(f"{name}")

# %% [markdown]
# ## Build and display HTML log of the experiment

# %%
history_sources = [env, direct_effect_externality]
histories_html = [html_lib.PythonObjectToHTMLConverter(history.get_history()).convert() for history in history_sources]
histories_names = [history.name for history in history_sources]

# %%
gm_mem_html = html_lib.PythonObjectToHTMLConverter(all_gm_memories).convert()

tabbed_html = html_lib.combine_html_pages(
    [*histories_html, gm_mem_html, *player_logs],
    [*histories_names, "GM", *player_log_names],
    summary=episode_summary,
    title="Mastodon experiment",
)

tabbed_html = html_lib.finalise_html(tabbed_html)
with open("index5-55.html","w",encoding="utf-8") as f:
    f.write(tabbed_html)

# %%
display.HTML(tabbed_html)

# %% [markdown]
# ## Interact with a specific player

# %%
sim_to_interact = "Alice"
user_identity = "a close friend"
interaction_premise = f"{sim_to_interact} is talking to {user_identity}\n"

player_names = [player.name for player in players]
player_by_name = {player.name: player for player in players}
selected_player = player_by_name[sim_to_interact]
interrogation = interaction_premise

# %%
utterance_from_user = (
    "Hey Alice, did you post anything on Mastodon today?"
)

interrogation += f"{user_identity}: {utterance_from_user}"
player_says = selected_player.say(interrogation)
interrogation += f"\n{sim_to_interact}: {player_says}\n"
print(interrogation)

# %% [markdown]
# ## Check timeline
#
# Finally, check the full public timeline for the Mastodon server.
#
# You may also check this directly at https://social-sandbox.com (you'll need to log in as a user).

# %%
timeline = get_public_timeline(limit=None)
print_timeline(timeline)
